# %% [raw]
# ## RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **RESIZE 32 -- USING ADAM AND BEST RESULT OF HIDDEN LAYER(4) AND 0.001 LEARNING RATE, 50 EPOCHS**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((32, 32))
image_size = 0
directory_root = "../input/riceleaf"
width=32
height=32
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_145 (Conv2D)          (None, 32, 32, 16)        448
# _________________________________________________________________
# activation_216 (Activation)  (None, 32, 32, 16)        0
# _________________________________________________________________
# batch_normalization_180 (Bat (None, 32, 32, 16)        64
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 10, 10, 16)        0
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 10, 10, 16)        0
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 10, 10, 32)        4640
# _________________________________________________________________
# activation_217 (Activation)  (None, 10, 10, 32)        0
# _________________________________________________________________
# batch_normalization_181 (Bat (None, 10, 10, 32)        128
# _________________________________________________________________
# conv2d_147 (Conv2D)          (None, 10, 10, 64)        18496
# _________________________________________________________________
# activation_218 (Activation)  (None, 10, 10, 64)        0
# _________________________________________________________________
# batch_normalization_182 (Bat (None, 10, 10, 64)        256
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_109 (Dropout)        (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_148 (Conv2D)          (None, 5, 5, 128)         73856
# _________________________________________________________________
# activation_219 (Activation)  (None, 5, 5, 128)         0
# _________________________________________________________________
# batch_normalization_183 (Bat (None, 5, 5, 128)         512
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 3200)              0
# _________________________________________________________________
# dense_72 (Dense)             (None, 1024)              3277824
# _________________________________________________________________
# activation_220 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_184 (Bat (None, 1024)              4096
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_73 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_221 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 3,384,420
# Trainable params: 3,381,892
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/50
# 320/320 [==============================] - 3s 6ms/step - loss: 0.5667 - accuracy: 0.8080 - val_loss: 1.6823 - val_accuracy: 0.5449
#
# Epoch 00001: val_loss improved from inf to 1.68229, saving model to model.h5
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2252 - accuracy: 0.9155 - val_loss: 0.6949 - val_accuracy: 0.8152
#
# Epoch 00002: val_loss improved from 1.68229 to 0.69488, saving model to model.h5
# Epoch 3/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1496 - accuracy: 0.9475 - val_loss: 0.2329 - val_accuracy: 0.9215
#
# Epoch 00003: val_loss improved from 0.69488 to 0.23290, saving model to model.h5
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1256 - accuracy: 0.9569 - val_loss: 0.0891 - val_accuracy: 0.9723
#
# Epoch 00004: val_loss improved from 0.23290 to 0.08908, saving model to model.h5
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1104 - accuracy: 0.9589 - val_loss: 0.3635 - val_accuracy: 0.9051
#
# Epoch 00005: val_loss did not improve from 0.08908
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0962 - accuracy: 0.9667 - val_loss: 0.7769 - val_accuracy: 0.7516
#
# Epoch 00006: val_loss did not improve from 0.08908
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0928 - accuracy: 0.9670 - val_loss: 0.0316 - val_accuracy: 0.9891
#
# Epoch 00007: val_loss improved from 0.08908 to 0.03163, saving model to model.h5
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0664 - accuracy: 0.9762 - val_loss: 0.1779 - val_accuracy: 0.9441
#
# Epoch 00008: val_loss did not improve from 0.03163
# Epoch 9/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0719 - accuracy: 0.9761 - val_loss: 0.0338 - val_accuracy: 0.9902
#
# Epoch 00009: val_loss did not improve from 0.03163
# Epoch 10/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0436 - accuracy: 0.9864 - val_loss: 0.0509 - val_accuracy: 0.9832
#
# Epoch 00010: val_loss did not improve from 0.03163
# Epoch 11/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0536 - accuracy: 0.9820 - val_loss: 0.1121 - val_accuracy: 0.9664
#
# Epoch 00011: val_loss did not improve from 0.03163
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0583 - accuracy: 0.9816 - val_loss: 0.0650 - val_accuracy: 0.9758
#
# Epoch 00012: val_loss did not improve from 0.03163
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0545 - accuracy: 0.9822 - val_loss: 0.0388 - val_accuracy: 0.9840
#
# Epoch 00013: val_loss did not improve from 0.03163
# Epoch 14/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0461 - accuracy: 0.9836 - val_loss: 0.1326 - val_accuracy: 0.9594
#
# Epoch 00014: val_loss did not improve from 0.03163
# Epoch 15/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0379 - accuracy: 0.9882 - val_loss: 0.4223 - val_accuracy: 0.8813
#
# Epoch 00015: val_loss did not improve from 0.03163
# Epoch 16/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0611 - accuracy: 0.9806 - val_loss: 1.4519 - val_accuracy: 0.6672
#
# Epoch 00016: val_loss did not improve from 0.03163
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0643 - accuracy: 0.9796 - val_loss: 0.0443 - val_accuracy: 0.9855
#
# Epoch 00017: val_loss did not improve from 0.03163
# Epoch 18/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0352 - accuracy: 0.9876 - val_loss: 0.3749 - val_accuracy: 0.9141
#
# Epoch 00018: val_loss did not improve from 0.03163
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0344 - accuracy: 0.9890 - val_loss: 0.0150 - val_accuracy: 0.9957
#
# Epoch 00019: val_loss improved from 0.03163 to 0.01495, saving model to model.h5
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0341 - accuracy: 0.9884 - val_loss: 0.0151 - val_accuracy: 0.9957
#
# Epoch 00020: val_loss did not improve from 0.01495
# Epoch 21/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0261 - accuracy: 0.9902 - val_loss: 0.0132 - val_accuracy: 0.9957
#
# Epoch 00021: val_loss improved from 0.01495 to 0.01317, saving model to model.h5
# Epoch 22/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0369 - accuracy: 0.9871 - val_loss: 0.1828 - val_accuracy: 0.9520
#
# Epoch 00022: val_loss did not improve from 0.01317
# Epoch 23/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0359 - accuracy: 0.9881 - val_loss: 0.1855 - val_accuracy: 0.9410
#
# Epoch 00023: val_loss did not improve from 0.01317
# Epoch 24/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0340 - accuracy: 0.9880 - val_loss: 0.0399 - val_accuracy: 0.9879
#
# Epoch 00024: val_loss did not improve from 0.01317
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 0.0094 - val_accuracy: 0.9969
#
# Epoch 00025: val_loss improved from 0.01317 to 0.00939, saving model to model.h5
# Epoch 26/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0266 - accuracy: 0.9917 - val_loss: 0.1045 - val_accuracy: 0.9738
#
# Epoch 00026: val_loss did not improve from 0.00939
# Epoch 27/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0296 - accuracy: 0.9901 - val_loss: 0.0424 - val_accuracy: 0.9867
#
# Epoch 00027: val_loss did not improve from 0.00939
# Epoch 28/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0262 - accuracy: 0.9909 - val_loss: 0.0125 - val_accuracy: 0.9965
#
# Epoch 00028: val_loss did not improve from 0.00939
# Epoch 29/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.0118 - val_accuracy: 0.9957
#
# Epoch 00029: val_loss did not improve from 0.00939
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0419 - accuracy: 0.9867 - val_loss: 0.3989 - val_accuracy: 0.8984
#
# Epoch 00030: val_loss did not improve from 0.00939
# Epoch 31/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0235 - accuracy: 0.9927 - val_loss: 0.0109 - val_accuracy: 0.9965
#
# Epoch 00031: val_loss did not improve from 0.00939
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.1431 - val_accuracy: 0.9645
#
# Epoch 00032: val_loss did not improve from 0.00939
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0246 - accuracy: 0.9927 - val_loss: 0.4322 - val_accuracy: 0.9152
#
# Epoch 00033: val_loss did not improve from 0.00939
# Epoch 34/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0375 - accuracy: 0.9886 - val_loss: 0.0103 - val_accuracy: 0.9953
#
# Epoch 00034: val_loss did not improve from 0.00939
# Epoch 35/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0198 - accuracy: 0.9927 - val_loss: 0.0429 - val_accuracy: 0.9871
#
# Epoch 00035: val_loss did not improve from 0.00939
# Epoch 36/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0226 - accuracy: 0.9920 - val_loss: 0.0513 - val_accuracy: 0.9828
#
# Epoch 00036: val_loss did not improve from 0.00939
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.1569 - val_accuracy: 0.9656
#
# Epoch 00037: val_loss did not improve from 0.00939
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.0112 - val_accuracy: 0.9973
#
# Epoch 00038: val_loss did not improve from 0.00939
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0213 - accuracy: 0.9933 - val_loss: 0.0539 - val_accuracy: 0.9875
#
# Epoch 00039: val_loss did not improve from 0.00939
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 0.3365 - val_accuracy: 0.9262
#
# Epoch 00040: val_loss did not improve from 0.00939
# Epoch 41/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.3172 - val_accuracy: 0.9461
#
# Epoch 00041: val_loss did not improve from 0.00939
# Epoch 42/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.0366 - val_accuracy: 0.9895
#
# Epoch 00042: val_loss did not improve from 0.00939
# Epoch 43/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0211 - accuracy: 0.9933 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00043: val_loss improved from 0.00939 to 0.00445, saving model to model.h5
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.2042 - val_accuracy: 0.9578
#
# Epoch 00044: val_loss did not improve from 0.00445
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.0058 - val_accuracy: 0.9984
#
# Epoch 00045: val_loss did not improve from 0.00445
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.0185 - val_accuracy: 0.9922
#
# Epoch 00046: val_loss did not improve from 0.00445
# Epoch 47/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.1255 - val_accuracy: 0.9680
#
# Epoch 00047: val_loss did not improve from 0.00445
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0145 - accuracy: 0.9949 - val_loss: 0.0231 - val_accuracy: 0.9934
#
# Epoch 00048: val_loss did not improve from 0.00445
# Epoch 49/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0186 - accuracy: 0.9939 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00049: val_loss improved from 0.00445 to 0.00355, saving model to model.h5
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 0.0101 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00355
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9961
# Val Score:  [0.010074326768517494, 0.99609375]
# Training on Fold:  2
# Epoch 1/50
# 320/320 [==============================] - 3s 6ms/step - loss: 0.4620 - accuracy: 0.8498 - val_loss: 4.4723 - val_accuracy: 0.4914
#
# Epoch 00001: val_loss did not improve from 0.00355
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1942 - accuracy: 0.9326 - val_loss: 2.1890 - val_accuracy: 0.7301
#
# Epoch 00002: val_loss did not improve from 0.00355
# Epoch 3/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1472 - accuracy: 0.9481 - val_loss: 0.1779 - val_accuracy: 0.9414
#
# Epoch 00003: val_loss did not improve from 0.00355
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0927 - accuracy: 0.9655 - val_loss: 0.0654 - val_accuracy: 0.9785
#
# Epoch 00004: val_loss did not improve from 0.00355
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0991 - accuracy: 0.9675 - val_loss: 0.1297 - val_accuracy: 0.9473
#
# Epoch 00005: val_loss did not improve from 0.00355
# Epoch 6/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0744 - accuracy: 0.9744 - val_loss: 0.2126 - val_accuracy: 0.9383
#
# Epoch 00006: val_loss did not improve from 0.00355
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0645 - accuracy: 0.9795 - val_loss: 0.1391 - val_accuracy: 0.9504
#
# Epoch 00007: val_loss did not improve from 0.00355
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0535 - accuracy: 0.9828 - val_loss: 0.0971 - val_accuracy: 0.9621
#
# Epoch 00008: val_loss did not improve from 0.00355
# Epoch 9/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0545 - accuracy: 0.9806 - val_loss: 0.0470 - val_accuracy: 0.9832
#
# Epoch 00009: val_loss did not improve from 0.00355
# Epoch 10/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0538 - accuracy: 0.9799 - val_loss: 0.0235 - val_accuracy: 0.9922
#
# Epoch 00010: val_loss did not improve from 0.00355
# Epoch 11/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0390 - accuracy: 0.9862 - val_loss: 0.1997 - val_accuracy: 0.9430
#
# Epoch 00011: val_loss did not improve from 0.00355
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0358 - accuracy: 0.9884 - val_loss: 0.3831 - val_accuracy: 0.9102
#
# Epoch 00012: val_loss did not improve from 0.00355
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0457 - accuracy: 0.9847 - val_loss: 0.0744 - val_accuracy: 0.9777
#
# Epoch 00013: val_loss did not improve from 0.00355
# Epoch 14/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0340 - accuracy: 0.9892 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00014: val_loss did not improve from 0.00355
# Epoch 15/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0400 - accuracy: 0.9854 - val_loss: 0.1244 - val_accuracy: 0.9586
#
# Epoch 00015: val_loss did not improve from 0.00355
# Epoch 16/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0335 - accuracy: 0.9885 - val_loss: 1.1940 - val_accuracy: 0.7883
#
# Epoch 00016: val_loss did not improve from 0.00355
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0344 - accuracy: 0.9892 - val_loss: 0.1732 - val_accuracy: 0.9496
#
# Epoch 00017: val_loss did not improve from 0.00355
# Epoch 18/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0350 - accuracy: 0.9880 - val_loss: 0.0169 - val_accuracy: 0.9949
#
# Epoch 00018: val_loss did not improve from 0.00355
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0320 - accuracy: 0.9900 - val_loss: 0.0071 - val_accuracy: 0.9984
#
# Epoch 00019: val_loss did not improve from 0.00355
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0301 - accuracy: 0.9898 - val_loss: 0.4918 - val_accuracy: 0.8863
#
# Epoch 00020: val_loss did not improve from 0.00355
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.0891 - val_accuracy: 0.9742
#
# Epoch 00021: val_loss did not improve from 0.00355
# Epoch 22/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.0901 - val_accuracy: 0.9711
#
# Epoch 00022: val_loss did not improve from 0.00355
# Epoch 23/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0316 - accuracy: 0.9907 - val_loss: 0.3140 - val_accuracy: 0.9316
#
# Epoch 00023: val_loss did not improve from 0.00355
# Epoch 24/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.1123 - val_accuracy: 0.9707
#
# Epoch 00024: val_loss did not improve from 0.00355
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0195 - accuracy: 0.9924 - val_loss: 0.0290 - val_accuracy: 0.9910
#
# Epoch 00025: val_loss did not improve from 0.00355
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0229 - accuracy: 0.9919 - val_loss: 0.0071 - val_accuracy: 0.9969
#
# Epoch 00026: val_loss did not improve from 0.00355
# Epoch 27/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0283 - accuracy: 0.9896 - val_loss: 0.0662 - val_accuracy: 0.9789
#
# Epoch 00027: val_loss did not improve from 0.00355
# Epoch 28/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0285 - accuracy: 0.9917 - val_loss: 0.5638 - val_accuracy: 0.8945
#
# Epoch 00028: val_loss did not improve from 0.00355
# Epoch 29/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 0.1365 - val_accuracy: 0.9664
#
# Epoch 00029: val_loss did not improve from 0.00355
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0351 - val_accuracy: 0.9883
#
# Epoch 00030: val_loss did not improve from 0.00355
# Epoch 31/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 0.0063 - val_accuracy: 0.9969
#
# Epoch 00031: val_loss did not improve from 0.00355
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0169 - accuracy: 0.9947 - val_loss: 0.0627 - val_accuracy: 0.9805
#
# Epoch 00032: val_loss did not improve from 0.00355
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0234 - accuracy: 0.9924 - val_loss: 0.0125 - val_accuracy: 0.9949
#
# Epoch 00033: val_loss did not improve from 0.00355
# Epoch 34/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0115 - accuracy: 0.9959 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00034: val_loss did not improve from 0.00355
# Epoch 35/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.0296 - val_accuracy: 0.9914
#
# Epoch 00035: val_loss did not improve from 0.00355
# Epoch 36/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0299 - accuracy: 0.9902 - val_loss: 0.0097 - val_accuracy: 0.9953
#
# Epoch 00036: val_loss did not improve from 0.00355
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0160 - accuracy: 0.9941 - val_loss: 0.0288 - val_accuracy: 0.9910
#
# Epoch 00037: val_loss did not improve from 0.00355
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0152 - accuracy: 0.9945 - val_loss: 0.0080 - val_accuracy: 0.9973
#
# Epoch 00038: val_loss did not improve from 0.00355
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0183 - accuracy: 0.9941 - val_loss: 0.0283 - val_accuracy: 0.9898
#
# Epoch 00039: val_loss did not improve from 0.00355
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0238 - accuracy: 0.9923 - val_loss: 0.0061 - val_accuracy: 0.9973
#
# Epoch 00040: val_loss did not improve from 0.00355
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0185 - accuracy: 0.9934 - val_loss: 0.0818 - val_accuracy: 0.9730
#
# Epoch 00041: val_loss did not improve from 0.00355
# Epoch 42/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.0095 - val_accuracy: 0.9969
#
# Epoch 00042: val_loss did not improve from 0.00355
# Epoch 43/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0171 - accuracy: 0.9937 - val_loss: 0.0048 - val_accuracy: 0.9973
#
# Epoch 00043: val_loss did not improve from 0.00355
# Epoch 44/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0205 - accuracy: 0.9922 - val_loss: 0.0047 - val_accuracy: 0.9969
#
# Epoch 00044: val_loss did not improve from 0.00355
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0114 - accuracy: 0.9957 - val_loss: 0.0343 - val_accuracy: 0.9895
#
# Epoch 00045: val_loss did not improve from 0.00355
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0087 - val_accuracy: 0.9957
#
# Epoch 00046: val_loss did not improve from 0.00355
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.3594 - val_accuracy: 0.9023
#
# Epoch 00047: val_loss did not improve from 0.00355
# Epoch 48/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0207 - accuracy: 0.9935 - val_loss: 0.1389 - val_accuracy: 0.9688
#
# Epoch 00048: val_loss did not improve from 0.00355
# Epoch 49/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.0100 - val_accuracy: 0.9961
#
# Epoch 00049: val_loss did not improve from 0.00355
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0031 - val_accuracy: 0.9980
#
# Epoch 00050: val_loss improved from 0.00355 to 0.00314, saving model to model.h5
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.9980
# Val Score:  [0.0031369805801659822, 0.998046875]
# Training on Fold:  3
# Epoch 1/50
# 320/320 [==============================] - 3s 6ms/step - loss: 0.4622 - accuracy: 0.8468 - val_loss: 4.1449 - val_accuracy: 0.4641
#
# Epoch 00001: val_loss did not improve from 0.00314
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1756 - accuracy: 0.9361 - val_loss: 0.4975 - val_accuracy: 0.8340
#
# Epoch 00002: val_loss did not improve from 0.00314
# Epoch 3/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1434 - accuracy: 0.9457 - val_loss: 0.3655 - val_accuracy: 0.8969
#
# Epoch 00003: val_loss did not improve from 0.00314
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1027 - accuracy: 0.9633 - val_loss: 0.2953 - val_accuracy: 0.9160
#
# Epoch 00004: val_loss did not improve from 0.00314
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0803 - accuracy: 0.9710 - val_loss: 0.1198 - val_accuracy: 0.9637
#
# Epoch 00005: val_loss did not improve from 0.00314
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0705 - accuracy: 0.9746 - val_loss: 0.0213 - val_accuracy: 0.9930
#
# Epoch 00006: val_loss did not improve from 0.00314
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0583 - accuracy: 0.9799 - val_loss: 0.2930 - val_accuracy: 0.9207
#
# Epoch 00007: val_loss did not improve from 0.00314
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0541 - accuracy: 0.9810 - val_loss: 0.3202 - val_accuracy: 0.9129
#
# Epoch 00008: val_loss did not improve from 0.00314
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0593 - accuracy: 0.9797 - val_loss: 0.0537 - val_accuracy: 0.9785
#
# Epoch 00009: val_loss did not improve from 0.00314
# Epoch 10/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0498 - accuracy: 0.9823 - val_loss: 0.1409 - val_accuracy: 0.9539
#
# Epoch 00010: val_loss did not improve from 0.00314
# Epoch 11/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0448 - accuracy: 0.9843 - val_loss: 0.4179 - val_accuracy: 0.8980
#
# Epoch 00011: val_loss did not improve from 0.00314
# Epoch 12/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0432 - accuracy: 0.9846 - val_loss: 0.0317 - val_accuracy: 0.9918
#
# Epoch 00012: val_loss did not improve from 0.00314
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0406 - accuracy: 0.9868 - val_loss: 0.0275 - val_accuracy: 0.9910
#
# Epoch 00013: val_loss did not improve from 0.00314
# Epoch 14/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0330 - accuracy: 0.9883 - val_loss: 0.1157 - val_accuracy: 0.9641
#
# Epoch 00014: val_loss did not improve from 0.00314
# Epoch 15/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0433 - accuracy: 0.9861 - val_loss: 0.0556 - val_accuracy: 0.9824
#
# Epoch 00015: val_loss did not improve from 0.00314
# Epoch 16/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0383 - accuracy: 0.9872 - val_loss: 0.0187 - val_accuracy: 0.9934
#
# Epoch 00016: val_loss did not improve from 0.00314
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0233 - accuracy: 0.9909 - val_loss: 0.0841 - val_accuracy: 0.9781
#
# Epoch 00017: val_loss did not improve from 0.00314
# Epoch 18/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0346 - accuracy: 0.9877 - val_loss: 0.8736 - val_accuracy: 0.8035
#
# Epoch 00018: val_loss did not improve from 0.00314
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0368 - accuracy: 0.9879 - val_loss: 0.1482 - val_accuracy: 0.9500
#
# Epoch 00019: val_loss did not improve from 0.00314
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0271 - accuracy: 0.9899 - val_loss: 0.0444 - val_accuracy: 0.9852
#
# Epoch 00020: val_loss did not improve from 0.00314
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0248 - accuracy: 0.9908 - val_loss: 0.0100 - val_accuracy: 0.9965
#
# Epoch 00021: val_loss did not improve from 0.00314
# Epoch 22/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0177 - accuracy: 0.9922 - val_loss: 0.3260 - val_accuracy: 0.9324
#
# Epoch 00022: val_loss did not improve from 0.00314
# Epoch 23/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0379 - accuracy: 0.9874 - val_loss: 0.0383 - val_accuracy: 0.9832
#
# Epoch 00023: val_loss did not improve from 0.00314
# Epoch 24/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0221 - accuracy: 0.9919 - val_loss: 0.0341 - val_accuracy: 0.9902
#
# Epoch 00024: val_loss did not improve from 0.00314
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 0.0112 - val_accuracy: 0.9961
#
# Epoch 00025: val_loss did not improve from 0.00314
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 0.0157 - val_accuracy: 0.9945
#
# Epoch 00026: val_loss did not improve from 0.00314
# Epoch 27/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.0200 - val_accuracy: 0.9945
#
# Epoch 00027: val_loss did not improve from 0.00314
# Epoch 28/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0227 - accuracy: 0.9915 - val_loss: 0.1496 - val_accuracy: 0.9555
#
# Epoch 00028: val_loss did not improve from 0.00314
# Epoch 29/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0385 - accuracy: 0.9882 - val_loss: 0.0192 - val_accuracy: 0.9930
#
# Epoch 00029: val_loss did not improve from 0.00314
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0204 - accuracy: 0.9927 - val_loss: 0.0278 - val_accuracy: 0.9922
#
# Epoch 00030: val_loss did not improve from 0.00314
# Epoch 31/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0197 - accuracy: 0.9927 - val_loss: 0.0198 - val_accuracy: 0.9930
#
# Epoch 00031: val_loss did not improve from 0.00314
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.0628 - val_accuracy: 0.9801
#
# Epoch 00032: val_loss did not improve from 0.00314
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0183 - accuracy: 0.9934 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00033: val_loss did not improve from 0.00314
# Epoch 34/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0190 - accuracy: 0.9933 - val_loss: 0.0242 - val_accuracy: 0.9930
#
# Epoch 00034: val_loss did not improve from 0.00314
# Epoch 35/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0185 - accuracy: 0.9929 - val_loss: 0.0173 - val_accuracy: 0.9961
#
# Epoch 00035: val_loss did not improve from 0.00314
# Epoch 36/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0230 - accuracy: 0.9922 - val_loss: 0.3565 - val_accuracy: 0.9453
#
# Epoch 00036: val_loss did not improve from 0.00314
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.0084 - val_accuracy: 0.9961
#
# Epoch 00037: val_loss did not improve from 0.00314
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.0297 - val_accuracy: 0.9910
#
# Epoch 00038: val_loss did not improve from 0.00314
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0200 - accuracy: 0.9946 - val_loss: 0.0107 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00314
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.1562 - val_accuracy: 0.9570
#
# Epoch 00040: val_loss did not improve from 0.00314
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0142 - accuracy: 0.9946 - val_loss: 0.0056 - val_accuracy: 0.9973
#
# Epoch 00041: val_loss did not improve from 0.00314
# Epoch 42/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0199 - accuracy: 0.9925 - val_loss: 0.0175 - val_accuracy: 0.9934
#
# Epoch 00042: val_loss did not improve from 0.00314
# Epoch 43/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0183 - accuracy: 0.9932 - val_loss: 1.1054 - val_accuracy: 0.8164
#
# Epoch 00043: val_loss did not improve from 0.00314
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0195 - accuracy: 0.9938 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00044: val_loss did not improve from 0.00314
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0168 - accuracy: 0.9939 - val_loss: 0.1329 - val_accuracy: 0.9727
#
# Epoch 00045: val_loss did not improve from 0.00314
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.0028 - val_accuracy: 0.9980
#
# Epoch 00046: val_loss improved from 0.00314 to 0.00283, saving model to model.h5
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.2285 - val_accuracy: 0.9422
#
# Epoch 00047: val_loss did not improve from 0.00283
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0140 - accuracy: 0.9945 - val_loss: 0.1289 - val_accuracy: 0.9777
#
# Epoch 00048: val_loss did not improve from 0.00283
# Epoch 49/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0222 - accuracy: 0.9933 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00049: val_loss did not improve from 0.00283
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0194 - val_accuracy: 0.9922
#
# Epoch 00050: val_loss did not improve from 0.00283
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9922
# Val Score:  [0.01943683996796608, 0.9921875]
# Training on Fold:  4
# Epoch 1/50
# 320/320 [==============================] - 3s 6ms/step - loss: 0.4196 - accuracy: 0.8643 - val_loss: 2.0329 - val_accuracy: 0.4730
#
# Epoch 00001: val_loss did not improve from 0.00283
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1677 - accuracy: 0.9390 - val_loss: 0.2029 - val_accuracy: 0.9312
#
# Epoch 00002: val_loss did not improve from 0.00283
# Epoch 3/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1158 - accuracy: 0.9582 - val_loss: 0.0774 - val_accuracy: 0.9820
#
# Epoch 00003: val_loss did not improve from 0.00283
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0893 - accuracy: 0.9705 - val_loss: 0.0685 - val_accuracy: 0.9742
#
# Epoch 00004: val_loss did not improve from 0.00283
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0801 - accuracy: 0.9714 - val_loss: 0.0639 - val_accuracy: 0.9750
#
# Epoch 00005: val_loss did not improve from 0.00283
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0593 - accuracy: 0.9792 - val_loss: 0.1361 - val_accuracy: 0.9645
#
# Epoch 00006: val_loss did not improve from 0.00283
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0591 - accuracy: 0.9797 - val_loss: 0.0448 - val_accuracy: 0.9824
#
# Epoch 00007: val_loss did not improve from 0.00283
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0546 - accuracy: 0.9820 - val_loss: 0.2601 - val_accuracy: 0.9242
#
# Epoch 00008: val_loss did not improve from 0.00283
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0399 - accuracy: 0.9871 - val_loss: 0.0627 - val_accuracy: 0.9824
#
# Epoch 00009: val_loss did not improve from 0.00283
# Epoch 10/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0399 - accuracy: 0.9869 - val_loss: 0.0114 - val_accuracy: 0.9973
#
# Epoch 00010: val_loss did not improve from 0.00283
# Epoch 11/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0408 - accuracy: 0.9863 - val_loss: 0.0149 - val_accuracy: 0.9953
#
# Epoch 00011: val_loss did not improve from 0.00283
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0359 - accuracy: 0.9864 - val_loss: 0.0159 - val_accuracy: 0.9945
#
# Epoch 00012: val_loss did not improve from 0.00283
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0354 - accuracy: 0.9886 - val_loss: 0.0254 - val_accuracy: 0.9926
#
# Epoch 00013: val_loss did not improve from 0.00283
# Epoch 14/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0352 - accuracy: 0.9883 - val_loss: 0.0642 - val_accuracy: 0.9871
#
# Epoch 00014: val_loss did not improve from 0.00283
# Epoch 15/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0351 - accuracy: 0.9866 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00015: val_loss did not improve from 0.00283
# Epoch 16/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.0097 - val_accuracy: 0.9953
#
# Epoch 00016: val_loss did not improve from 0.00283
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0320 - accuracy: 0.9892 - val_loss: 0.2686 - val_accuracy: 0.9469
#
# Epoch 00017: val_loss did not improve from 0.00283
# Epoch 18/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0240 - accuracy: 0.9910 - val_loss: 0.0537 - val_accuracy: 0.9844
#
# Epoch 00018: val_loss did not improve from 0.00283
# Epoch 19/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0279 - accuracy: 0.9906 - val_loss: 0.1038 - val_accuracy: 0.9723
#
# Epoch 00019: val_loss did not improve from 0.00283
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0315 - accuracy: 0.9894 - val_loss: 0.0139 - val_accuracy: 0.9949
#
# Epoch 00020: val_loss did not improve from 0.00283
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0212 - accuracy: 0.9924 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00021: val_loss did not improve from 0.00283
# Epoch 22/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0217 - accuracy: 0.9927 - val_loss: 0.0162 - val_accuracy: 0.9934
#
# Epoch 00022: val_loss did not improve from 0.00283
# Epoch 23/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0225 - accuracy: 0.9924 - val_loss: 0.0780 - val_accuracy: 0.9727
#
# Epoch 00023: val_loss did not improve from 0.00283
# Epoch 24/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 0.0097 - val_accuracy: 0.9969
#
# Epoch 00024: val_loss did not improve from 0.00283
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00025: val_loss did not improve from 0.00283
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0226 - accuracy: 0.9933 - val_loss: 0.0139 - val_accuracy: 0.9953
#
# Epoch 00026: val_loss did not improve from 0.00283
# Epoch 27/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0638 - val_accuracy: 0.9805
#
# Epoch 00027: val_loss did not improve from 0.00283
# Epoch 28/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0194 - accuracy: 0.9929 - val_loss: 0.0046 - val_accuracy: 0.9980
#
# Epoch 00028: val_loss did not improve from 0.00283
# Epoch 29/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0225 - accuracy: 0.9913 - val_loss: 0.0404 - val_accuracy: 0.9891
#
# Epoch 00029: val_loss did not improve from 0.00283
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.0677 - val_accuracy: 0.9879
#
# Epoch 00030: val_loss did not improve from 0.00283
# Epoch 31/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0137 - val_accuracy: 0.9953
#
# Epoch 00031: val_loss did not improve from 0.00283
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0182 - accuracy: 0.9944 - val_loss: 0.0044 - val_accuracy: 0.9977
#
# Epoch 00032: val_loss did not improve from 0.00283
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00033: val_loss did not improve from 0.00283
# Epoch 34/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.0134 - val_accuracy: 0.9949
#
# Epoch 00034: val_loss did not improve from 0.00283
# Epoch 35/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.0295 - val_accuracy: 0.9902
#
# Epoch 00035: val_loss did not improve from 0.00283
# Epoch 36/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.0084 - val_accuracy: 0.9969
#
# Epoch 00036: val_loss did not improve from 0.00283
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0127 - accuracy: 0.9951 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00037: val_loss improved from 0.00283 to 0.00276, saving model to model.h5
# Epoch 38/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0092 - accuracy: 0.9964 - val_loss: 0.0044 - val_accuracy: 0.9977
#
# Epoch 00038: val_loss did not improve from 0.00276
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0173 - accuracy: 0.9941 - val_loss: 0.0070 - val_accuracy: 0.9973
#
# Epoch 00039: val_loss did not improve from 0.00276
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00040: val_loss improved from 0.00276 to 0.00275, saving model to model.h5
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0105 - accuracy: 0.9951 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00041: val_loss improved from 0.00275 to 0.00252, saving model to model.h5
# Epoch 42/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0178 - accuracy: 0.9930 - val_loss: 0.0050 - val_accuracy: 0.9980
#
# Epoch 00042: val_loss did not improve from 0.00252
# Epoch 43/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.0301 - val_accuracy: 0.9879
#
# Epoch 00043: val_loss did not improve from 0.00252
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00044: val_loss improved from 0.00252 to 0.00199, saving model to model.h5
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.0153 - val_accuracy: 0.9937
#
# Epoch 00045: val_loss did not improve from 0.00199
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 0.0158 - val_accuracy: 0.9945
#
# Epoch 00046: val_loss did not improve from 0.00199
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0151 - accuracy: 0.9938 - val_loss: 0.1200 - val_accuracy: 0.9750
#
# Epoch 00047: val_loss did not improve from 0.00199
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 0.1744 - val_accuracy: 0.9594
#
# Epoch 00048: val_loss did not improve from 0.00199
# Epoch 49/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.0065 - val_accuracy: 0.9973
#
# Epoch 00049: val_loss did not improve from 0.00199
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 0.0050 - val_accuracy: 0.9969
#
# Epoch 00050: val_loss did not improve from 0.00199
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9969
# Val Score:  [0.005012094508856535, 0.996874988079071]
# Training on Fold:  5
# Epoch 1/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.5390 - accuracy: 0.8173 - val_loss: 2.2445 - val_accuracy: 0.5117
#
# Epoch 00001: val_loss did not improve from 0.00199
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2054 - accuracy: 0.9245 - val_loss: 1.1733 - val_accuracy: 0.7391
#
# Epoch 00002: val_loss did not improve from 0.00199
# Epoch 3/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1562 - accuracy: 0.9443 - val_loss: 0.0922 - val_accuracy: 0.9680
#
# Epoch 00003: val_loss did not improve from 0.00199
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1169 - accuracy: 0.9610 - val_loss: 0.2527 - val_accuracy: 0.9137
#
# Epoch 00004: val_loss did not improve from 0.00199
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0862 - accuracy: 0.9688 - val_loss: 0.0678 - val_accuracy: 0.9766
#
# Epoch 00005: val_loss did not improve from 0.00199
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0734 - accuracy: 0.9735 - val_loss: 0.2510 - val_accuracy: 0.9180
#
# Epoch 00006: val_loss did not improve from 0.00199
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0702 - accuracy: 0.9769 - val_loss: 0.0265 - val_accuracy: 0.9914
#
# Epoch 00007: val_loss did not improve from 0.00199
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0478 - accuracy: 0.9823 - val_loss: 0.0566 - val_accuracy: 0.9805
#
# Epoch 00008: val_loss did not improve from 0.00199
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0569 - accuracy: 0.9812 - val_loss: 0.0567 - val_accuracy: 0.9840
#
# Epoch 00009: val_loss did not improve from 0.00199
# Epoch 10/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0513 - accuracy: 0.9820 - val_loss: 0.0575 - val_accuracy: 0.9793
#
# Epoch 00010: val_loss did not improve from 0.00199
# Epoch 11/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0513 - accuracy: 0.9817 - val_loss: 0.0257 - val_accuracy: 0.9918
#
# Epoch 00011: val_loss did not improve from 0.00199
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0412 - accuracy: 0.9845 - val_loss: 0.0113 - val_accuracy: 0.9953
#
# Epoch 00012: val_loss did not improve from 0.00199
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0396 - accuracy: 0.9872 - val_loss: 0.1265 - val_accuracy: 0.9605
#
# Epoch 00013: val_loss did not improve from 0.00199
# Epoch 14/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0447 - accuracy: 0.9852 - val_loss: 0.0314 - val_accuracy: 0.9879
#
# Epoch 00014: val_loss did not improve from 0.00199
# Epoch 15/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0306 - accuracy: 0.9891 - val_loss: 0.1068 - val_accuracy: 0.9664
#
# Epoch 00015: val_loss did not improve from 0.00199
# Epoch 16/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0299 - accuracy: 0.9899 - val_loss: 0.0335 - val_accuracy: 0.9914
#
# Epoch 00016: val_loss did not improve from 0.00199
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0348 - accuracy: 0.9881 - val_loss: 0.0153 - val_accuracy: 0.9953
#
# Epoch 00017: val_loss did not improve from 0.00199
# Epoch 18/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0315 - accuracy: 0.9888 - val_loss: 0.0368 - val_accuracy: 0.9910
#
# Epoch 00018: val_loss did not improve from 0.00199
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0228 - accuracy: 0.9912 - val_loss: 0.0723 - val_accuracy: 0.9742
#
# Epoch 00019: val_loss did not improve from 0.00199
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0133 - val_accuracy: 0.9961
#
# Epoch 00020: val_loss did not improve from 0.00199
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 0.1162 - val_accuracy: 0.9656
#
# Epoch 00021: val_loss did not improve from 0.00199
# Epoch 22/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.0147 - val_accuracy: 0.9945
#
# Epoch 00022: val_loss did not improve from 0.00199
# Epoch 23/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0222 - accuracy: 0.9917 - val_loss: 0.0512 - val_accuracy: 0.9859
#
# Epoch 00023: val_loss did not improve from 0.00199
# Epoch 24/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0229 - accuracy: 0.9917 - val_loss: 0.0058 - val_accuracy: 0.9973
#
# Epoch 00024: val_loss did not improve from 0.00199
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0234 - accuracy: 0.9907 - val_loss: 0.0077 - val_accuracy: 0.9969
#
# Epoch 00025: val_loss did not improve from 0.00199
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.0056 - val_accuracy: 0.9977
#
# Epoch 00026: val_loss did not improve from 0.00199
# Epoch 27/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0185 - val_accuracy: 0.9937
#
# Epoch 00027: val_loss did not improve from 0.00199
# Epoch 28/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0304 - accuracy: 0.9898 - val_loss: 0.6850 - val_accuracy: 0.8891
#
# Epoch 00028: val_loss did not improve from 0.00199
# Epoch 29/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0210 - accuracy: 0.9924 - val_loss: 0.0084 - val_accuracy: 0.9961
#
# Epoch 00029: val_loss did not improve from 0.00199
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 0.0071 - val_accuracy: 0.9977
#
# Epoch 00030: val_loss did not improve from 0.00199
# Epoch 31/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.0067 - val_accuracy: 0.9977
#
# Epoch 00031: val_loss did not improve from 0.00199
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0142 - accuracy: 0.9939 - val_loss: 0.0737 - val_accuracy: 0.9785
#
# Epoch 00032: val_loss did not improve from 0.00199
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0161 - accuracy: 0.9946 - val_loss: 0.0254 - val_accuracy: 0.9914
#
# Epoch 00033: val_loss did not improve from 0.00199
# Epoch 34/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.0079 - val_accuracy: 0.9977
#
# Epoch 00034: val_loss did not improve from 0.00199
# Epoch 35/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0151 - accuracy: 0.9940 - val_loss: 0.0076 - val_accuracy: 0.9977
#
# Epoch 00035: val_loss did not improve from 0.00199
# Epoch 36/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0164 - accuracy: 0.9943 - val_loss: 0.1658 - val_accuracy: 0.9566
#
# Epoch 00036: val_loss did not improve from 0.00199
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0195 - accuracy: 0.9931 - val_loss: 0.0205 - val_accuracy: 0.9937
#
# Epoch 00037: val_loss did not improve from 0.00199
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0221 - accuracy: 0.9919 - val_loss: 0.0209 - val_accuracy: 0.9906
#
# Epoch 00038: val_loss did not improve from 0.00199
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0127 - accuracy: 0.9949 - val_loss: 0.0161 - val_accuracy: 0.9926
#
# Epoch 00039: val_loss did not improve from 0.00199
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0132 - accuracy: 0.9950 - val_loss: 0.0233 - val_accuracy: 0.9937
#
# Epoch 00040: val_loss did not improve from 0.00199
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0153 - accuracy: 0.9948 - val_loss: 0.0121 - val_accuracy: 0.9945
#
# Epoch 00041: val_loss did not improve from 0.00199
# Epoch 42/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9956 - val_loss: 0.0041 - val_accuracy: 0.9973
#
# Epoch 00042: val_loss did not improve from 0.00199
# Epoch 43/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0035 - val_accuracy: 0.9977
#
# Epoch 00043: val_loss did not improve from 0.00199
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.2438 - val_accuracy: 0.9438
#
# Epoch 00044: val_loss did not improve from 0.00199
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0130 - accuracy: 0.9946 - val_loss: 0.0054 - val_accuracy: 0.9969
#
# Epoch 00045: val_loss did not improve from 0.00199
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0135 - accuracy: 0.9947 - val_loss: 0.0365 - val_accuracy: 0.9918
#
# Epoch 00046: val_loss did not improve from 0.00199
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 0.1362 - val_accuracy: 0.9648
#
# Epoch 00047: val_loss did not improve from 0.00199
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0117 - accuracy: 0.9954 - val_loss: 0.0263 - val_accuracy: 0.9898
#
# Epoch 00048: val_loss did not improve from 0.00199
# Epoch 49/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0126 - accuracy: 0.9954 - val_loss: 0.0249 - val_accuracy: 0.9930
#
# Epoch 00049: val_loss did not improve from 0.00199
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0103 - accuracy: 0.9958 - val_loss: 0.0072 - val_accuracy: 0.9980
#
# Epoch 00050: val_loss did not improve from 0.00199
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 0.9980
# Val Score:  [0.007183198817074299, 0.998046875]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
