# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **HIDDEN LAYER TEST -- USING ONLY 4 HIDDEN LAYER**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_65 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_66 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_67 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_68 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_69 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_70 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4475 - accuracy: 0.8674 - val_loss: 5.4938 - val_accuracy: 0.4273
#
# Epoch 00001: val_loss improved from inf to 5.49383, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1560 - accuracy: 0.9455 - val_loss: 0.3651 - val_accuracy: 0.8887
#
# Epoch 00002: val_loss improved from 5.49383 to 0.36508, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0917 - accuracy: 0.9694 - val_loss: 1.5005 - val_accuracy: 0.7375
#
# Epoch 00003: val_loss did not improve from 0.36508
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0750 - accuracy: 0.9747 - val_loss: 0.1632 - val_accuracy: 0.9344
#
# Epoch 00004: val_loss improved from 0.36508 to 0.16319, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0573 - accuracy: 0.9798 - val_loss: 0.3744 - val_accuracy: 0.9117
#
# Epoch 00005: val_loss did not improve from 0.16319
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0445 - accuracy: 0.9845 - val_loss: 0.1346 - val_accuracy: 0.9637
#
# Epoch 00006: val_loss improved from 0.16319 to 0.13465, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0477 - accuracy: 0.9842 - val_loss: 0.0453 - val_accuracy: 0.9844
#
# Epoch 00007: val_loss improved from 0.13465 to 0.04527, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0495 - accuracy: 0.9834 - val_loss: 0.1551 - val_accuracy: 0.9637
#
# Epoch 00008: val_loss did not improve from 0.04527
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0401 - accuracy: 0.9878 - val_loss: 0.9388 - val_accuracy: 0.8043
#
# Epoch 00009: val_loss did not improve from 0.04527
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0454 - accuracy: 0.9851 - val_loss: 0.0891 - val_accuracy: 0.9688
#
# Epoch 00010: val_loss did not improve from 0.04527
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0290 - accuracy: 0.9916 - val_loss: 0.0301 - val_accuracy: 0.9883
#
# Epoch 00011: val_loss improved from 0.04527 to 0.03014, saving model to model.h5
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0265 - accuracy: 0.9906 - val_loss: 0.1410 - val_accuracy: 0.9613
#
# Epoch 00012: val_loss did not improve from 0.03014
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0347 - accuracy: 0.9881 - val_loss: 1.1699 - val_accuracy: 0.7508
#
# Epoch 00013: val_loss did not improve from 0.03014
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0462 - accuracy: 0.9857 - val_loss: 0.0119 - val_accuracy: 0.9965
#
# Epoch 00014: val_loss improved from 0.03014 to 0.01193, saving model to model.h5
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0318 - accuracy: 0.9887 - val_loss: 0.1139 - val_accuracy: 0.9621
#
# Epoch 00015: val_loss did not improve from 0.01193
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0243 - accuracy: 0.9926 - val_loss: 0.8411 - val_accuracy: 0.8508
#
# Epoch 00016: val_loss did not improve from 0.01193
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0304 - accuracy: 0.9910 - val_loss: 0.0452 - val_accuracy: 0.9867
#
# Epoch 00017: val_loss did not improve from 0.01193
# Epoch 18/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0210 - accuracy: 0.9923 - val_loss: 1.3307 - val_accuracy: 0.8219
#
# Epoch 00018: val_loss did not improve from 0.01193
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0219 - accuracy: 0.9929 - val_loss: 0.4215 - val_accuracy: 0.9199
#
# Epoch 00019: val_loss did not improve from 0.01193
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0124 - accuracy: 0.9954 - val_loss: 0.1420 - val_accuracy: 0.9648
#
# Epoch 00020: val_loss did not improve from 0.01193
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0439 - accuracy: 0.9869 - val_loss: 0.0408 - val_accuracy: 0.9840
#
# Epoch 00021: val_loss did not improve from 0.01193
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0210 - accuracy: 0.9927 - val_loss: 0.0179 - val_accuracy: 0.9941
#
# Epoch 00022: val_loss did not improve from 0.01193
# Epoch 23/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0188 - accuracy: 0.9944 - val_loss: 0.0251 - val_accuracy: 0.9930
#
# Epoch 00023: val_loss did not improve from 0.01193
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.0808 - val_accuracy: 0.9711
#
# Epoch 00024: val_loss did not improve from 0.01193
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0225 - accuracy: 0.9929 - val_loss: 0.8067 - val_accuracy: 0.8363
#
# Epoch 00025: val_loss did not improve from 0.01193
# Epoch 26/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0334 - accuracy: 0.9912 - val_loss: 0.0190 - val_accuracy: 0.9941
#
# Epoch 00026: val_loss did not improve from 0.01193
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.4418 - val_accuracy: 0.9254
#
# Epoch 00027: val_loss did not improve from 0.01193
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0139 - accuracy: 0.9942 - val_loss: 0.0059 - val_accuracy: 0.9973
#
# Epoch 00028: val_loss improved from 0.01193 to 0.00593, saving model to model.h5
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0229 - accuracy: 0.9929 - val_loss: 0.0287 - val_accuracy: 0.9906
#
# Epoch 00029: val_loss did not improve from 0.00593
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0229 - accuracy: 0.9935 - val_loss: 0.2429 - val_accuracy: 0.9484
#
# Epoch 00030: val_loss did not improve from 0.00593
# Epoch 31/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.0378 - val_accuracy: 0.9941
#
# Epoch 00031: val_loss did not improve from 0.00593
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.0192 - val_accuracy: 0.9953
#
# Epoch 00032: val_loss did not improve from 0.00593
# Epoch 33/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0108 - val_accuracy: 0.9965
#
# Epoch 00033: val_loss did not improve from 0.00593
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 0.1695 - val_accuracy: 0.9523
#
# Epoch 00034: val_loss did not improve from 0.00593
# Epoch 35/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0306 - accuracy: 0.9921 - val_loss: 0.0115 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00593
# Epoch 36/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 0.0122 - val_accuracy: 0.9965
#
# Epoch 00036: val_loss did not improve from 0.00593
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 0.0401 - val_accuracy: 0.9852
#
# Epoch 00037: val_loss did not improve from 0.00593
# Epoch 38/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0100 - accuracy: 0.9961 - val_loss: 0.0953 - val_accuracy: 0.9664
#
# Epoch 00038: val_loss did not improve from 0.00593
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9955 - val_loss: 0.2729 - val_accuracy: 0.9453
#
# Epoch 00039: val_loss did not improve from 0.00593
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.0622 - val_accuracy: 0.9840
#
# Epoch 00040: val_loss did not improve from 0.00593
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.1094 - val_accuracy: 0.9676
#
# Epoch 00041: val_loss did not improve from 0.00593
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0220 - accuracy: 0.9945 - val_loss: 0.0711 - val_accuracy: 0.9816
#
# Epoch 00042: val_loss did not improve from 0.00593
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9951 - val_loss: 0.0035 - val_accuracy: 0.9984
#
# Epoch 00043: val_loss improved from 0.00593 to 0.00354, saving model to model.h5
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00044: val_loss improved from 0.00354 to 0.00201, saving model to model.h5
# Epoch 45/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0283 - val_accuracy: 0.9914
#
# Epoch 00045: val_loss did not improve from 0.00201
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00046: val_loss did not improve from 0.00201
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0104 - accuracy: 0.9970 - val_loss: 1.5917 - val_accuracy: 0.7988
#
# Epoch 00047: val_loss did not improve from 0.00201
# Epoch 48/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0164 - accuracy: 0.9952 - val_loss: 0.0849 - val_accuracy: 0.9758
#
# Epoch 00048: val_loss did not improve from 0.00201
# Epoch 49/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0238 - accuracy: 0.9929 - val_loss: 0.1735 - val_accuracy: 0.9402
#
# Epoch 00049: val_loss did not improve from 0.00201
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 0.0124 - val_accuracy: 0.9965
#
# Epoch 00050: val_loss did not improve from 0.00201
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0127 - accuracy: 0.9953 - val_loss: 0.0056 - val_accuracy: 0.9977
#
# Epoch 00051: val_loss did not improve from 0.00201
# Epoch 52/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0264 - val_accuracy: 0.9910
#
# Epoch 00052: val_loss did not improve from 0.00201
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9958 - val_loss: 0.1143 - val_accuracy: 0.9629
#
# Epoch 00053: val_loss did not improve from 0.00201
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0957 - val_accuracy: 0.9754
#
# Epoch 00054: val_loss did not improve from 0.00201
# Epoch 55/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0101 - accuracy: 0.9961 - val_loss: 0.0355 - val_accuracy: 0.9887
#
# Epoch 00055: val_loss did not improve from 0.00201
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0215 - accuracy: 0.9940 - val_loss: 0.6455 - val_accuracy: 0.9000
#
# Epoch 00056: val_loss did not improve from 0.00201
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.0048 - val_accuracy: 0.9977
#
# Epoch 00057: val_loss did not improve from 0.00201
# Epoch 58/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00058: val_loss did not improve from 0.00201
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.4263 - val_accuracy: 0.9113
#
# Epoch 00059: val_loss did not improve from 0.00201
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00060: val_loss did not improve from 0.00201
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0156 - accuracy: 0.9952 - val_loss: 8.2444 - val_accuracy: 0.5977
#
# Epoch 00061: val_loss did not improve from 0.00201
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.0064 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00201
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0050 - accuracy: 0.9977 - val_loss: 0.0137 - val_accuracy: 0.9937
#
# Epoch 00063: val_loss did not improve from 0.00201
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9967 - val_loss: 0.3222 - val_accuracy: 0.9254
#
# Epoch 00064: val_loss did not improve from 0.00201
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00065: val_loss did not improve from 0.00201
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00066: val_loss did not improve from 0.00201
# Epoch 67/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00067: val_loss did not improve from 0.00201
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0272 - val_accuracy: 0.9937
#
# Epoch 00068: val_loss did not improve from 0.00201
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0065 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00201
# Epoch 70/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0205 - accuracy: 0.9947 - val_loss: 0.6205 - val_accuracy: 0.8805
#
# Epoch 00070: val_loss did not improve from 0.00201
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0039 - val_accuracy: 0.9984
#
# Epoch 00071: val_loss did not improve from 0.00201
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00072: val_loss did not improve from 0.00201
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0080 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00201
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0088 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00201
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.0601 - val_accuracy: 0.9891
#
# Epoch 00075: val_loss did not improve from 0.00201
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.3001 - val_accuracy: 0.9262
#
# Epoch 00076: val_loss did not improve from 0.00201
# Epoch 77/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.6340 - val_accuracy: 0.8816
#
# Epoch 00077: val_loss did not improve from 0.00201
# Epoch 78/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.9883 - val_accuracy: 0.9102
#
# Epoch 00078: val_loss did not improve from 0.00201
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0079 - val_accuracy: 0.9973
#
# Epoch 00079: val_loss did not improve from 0.00201
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00080: val_loss did not improve from 0.00201
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00201
# Epoch 82/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.4573 - val_accuracy: 0.9461
#
# Epoch 00082: val_loss did not improve from 0.00201
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0106 - accuracy: 0.9957 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00083: val_loss did not improve from 0.00201
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.0865 - val_accuracy: 0.9879
#
# Epoch 00084: val_loss did not improve from 0.00201
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0050 - val_accuracy: 0.9984
#
# Epoch 00085: val_loss did not improve from 0.00201
# Epoch 86/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0066 - accuracy: 0.9970 - val_loss: 0.0060 - val_accuracy: 0.9973
#
# Epoch 00086: val_loss did not improve from 0.00201
# Epoch 87/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0094 - accuracy: 0.9965 - val_loss: 0.0830 - val_accuracy: 0.9734
#
# Epoch 00087: val_loss did not improve from 0.00201
# Epoch 88/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0042 - val_accuracy: 0.9977
#
# Epoch 00088: val_loss did not improve from 0.00201
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.0290 - val_accuracy: 0.9922
#
# Epoch 00089: val_loss did not improve from 0.00201
# Epoch 90/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.0049 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00201
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0372 - val_accuracy: 0.9906
#
# Epoch 00091: val_loss did not improve from 0.00201
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00092: val_loss did not improve from 0.00201
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00093: val_loss did not improve from 0.00201
# Epoch 94/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00094: val_loss did not improve from 0.00201
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0121 - val_accuracy: 0.9973
#
# Epoch 00095: val_loss did not improve from 0.00201
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0073 - val_accuracy: 0.9977
#
# Epoch 00096: val_loss did not improve from 0.00201
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9973 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00201
# Epoch 98/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0447 - val_accuracy: 0.9855
#
# Epoch 00098: val_loss did not improve from 0.00201
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0051 - accuracy: 0.9978 - val_loss: 0.0019 - val_accuracy: 0.9984
#
# Epoch 00099: val_loss improved from 0.00201 to 0.00191, saving model to model.h5
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00100: val_loss did not improve from 0.00191
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 0.9988
# Val Score:  [0.002454272238537669, 0.998828113079071]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4216 - accuracy: 0.8611 - val_loss: 2.9516 - val_accuracy: 0.5156
#
# Epoch 00001: val_loss did not improve from 0.00191
# Epoch 2/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1509 - accuracy: 0.9450 - val_loss: 0.6402 - val_accuracy: 0.8188
#
# Epoch 00002: val_loss did not improve from 0.00191
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0960 - accuracy: 0.9662 - val_loss: 0.3859 - val_accuracy: 0.8734
#
# Epoch 00003: val_loss did not improve from 0.00191
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0682 - accuracy: 0.9746 - val_loss: 4.0085 - val_accuracy: 0.6078
#
# Epoch 00004: val_loss did not improve from 0.00191
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0584 - accuracy: 0.9787 - val_loss: 0.4260 - val_accuracy: 0.8863
#
# Epoch 00005: val_loss did not improve from 0.00191
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0544 - accuracy: 0.9827 - val_loss: 0.0252 - val_accuracy: 0.9895
#
# Epoch 00006: val_loss did not improve from 0.00191
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0381 - accuracy: 0.9871 - val_loss: 0.1520 - val_accuracy: 0.9527
#
# Epoch 00007: val_loss did not improve from 0.00191
# Epoch 8/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0397 - accuracy: 0.9864 - val_loss: 0.0168 - val_accuracy: 0.9934
#
# Epoch 00008: val_loss did not improve from 0.00191
# Epoch 9/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0363 - accuracy: 0.9874 - val_loss: 0.0960 - val_accuracy: 0.9641
#
# Epoch 00009: val_loss did not improve from 0.00191
# Epoch 10/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0257 - accuracy: 0.9904 - val_loss: 0.0849 - val_accuracy: 0.9766
#
# Epoch 00010: val_loss did not improve from 0.00191
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0341 - accuracy: 0.9875 - val_loss: 0.0104 - val_accuracy: 0.9977
#
# Epoch 00011: val_loss did not improve from 0.00191
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0236 - accuracy: 0.9922 - val_loss: 0.0490 - val_accuracy: 0.9809
#
# Epoch 00012: val_loss did not improve from 0.00191
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0336 - accuracy: 0.9892 - val_loss: 0.0320 - val_accuracy: 0.9887
#
# Epoch 00013: val_loss did not improve from 0.00191
# Epoch 14/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0265 - accuracy: 0.9903 - val_loss: 0.0282 - val_accuracy: 0.9891
#
# Epoch 00014: val_loss did not improve from 0.00191
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0318 - accuracy: 0.9901 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00015: val_loss did not improve from 0.00191
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0334 - accuracy: 0.9888 - val_loss: 0.0337 - val_accuracy: 0.9906
#
# Epoch 00016: val_loss did not improve from 0.00191
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0318 - accuracy: 0.9893 - val_loss: 0.0166 - val_accuracy: 0.9937
#
# Epoch 00017: val_loss did not improve from 0.00191
# Epoch 18/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0291 - accuracy: 0.9904 - val_loss: 0.0066 - val_accuracy: 0.9977
#
# Epoch 00018: val_loss did not improve from 0.00191
# Epoch 19/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0193 - accuracy: 0.9939 - val_loss: 0.0195 - val_accuracy: 0.9945
#
# Epoch 00019: val_loss did not improve from 0.00191
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.0381 - val_accuracy: 0.9891
#
# Epoch 00020: val_loss did not improve from 0.00191
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0244 - accuracy: 0.9917 - val_loss: 0.0083 - val_accuracy: 0.9957
#
# Epoch 00021: val_loss did not improve from 0.00191
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0172 - accuracy: 0.9939 - val_loss: 0.0032 - val_accuracy: 0.9980
#
# Epoch 00022: val_loss did not improve from 0.00191
# Epoch 23/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.0197 - val_accuracy: 0.9922
#
# Epoch 00023: val_loss did not improve from 0.00191
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.0154 - val_accuracy: 0.9937
#
# Epoch 00024: val_loss did not improve from 0.00191
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.1532 - val_accuracy: 0.9527
#
# Epoch 00025: val_loss did not improve from 0.00191
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0304 - accuracy: 0.9911 - val_loss: 0.4755 - val_accuracy: 0.8820
#
# Epoch 00026: val_loss did not improve from 0.00191
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.0234 - val_accuracy: 0.9914
#
# Epoch 00027: val_loss did not improve from 0.00191
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0252 - accuracy: 0.9920 - val_loss: 0.0275 - val_accuracy: 0.9895
#
# Epoch 00028: val_loss did not improve from 0.00191
# Epoch 29/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 0.0381 - val_accuracy: 0.9910
#
# Epoch 00029: val_loss did not improve from 0.00191
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.0063 - val_accuracy: 0.9980
#
# Epoch 00030: val_loss did not improve from 0.00191
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.2080 - val_accuracy: 0.9430
#
# Epoch 00031: val_loss did not improve from 0.00191
# Epoch 32/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.0305 - val_accuracy: 0.9887
#
# Epoch 00032: val_loss did not improve from 0.00191
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9958 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00033: val_loss did not improve from 0.00191
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0160 - val_accuracy: 0.9957
#
# Epoch 00034: val_loss did not improve from 0.00191
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0072 - val_accuracy: 0.9984
#
# Epoch 00035: val_loss did not improve from 0.00191
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0336 - accuracy: 0.9893 - val_loss: 0.1342 - val_accuracy: 0.9594
#
# Epoch 00036: val_loss did not improve from 0.00191
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0191 - accuracy: 0.9931 - val_loss: 0.0422 - val_accuracy: 0.9891
#
# Epoch 00037: val_loss did not improve from 0.00191
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.1029 - val_accuracy: 0.9691
#
# Epoch 00038: val_loss did not improve from 0.00191
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00191
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0106 - val_accuracy: 0.9973
#
# Epoch 00040: val_loss did not improve from 0.00191
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0364 - val_accuracy: 0.9906
#
# Epoch 00041: val_loss did not improve from 0.00191
# Epoch 42/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0104 - accuracy: 0.9959 - val_loss: 0.0072 - val_accuracy: 0.9969
#
# Epoch 00042: val_loss did not improve from 0.00191
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0826 - val_accuracy: 0.9723
#
# Epoch 00043: val_loss did not improve from 0.00191
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0027 - val_accuracy: 0.9988
#
# Epoch 00044: val_loss did not improve from 0.00191
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.2055 - val_accuracy: 0.9652
#
# Epoch 00045: val_loss did not improve from 0.00191
# Epoch 46/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 0.1172 - val_accuracy: 0.9617
#
# Epoch 00046: val_loss did not improve from 0.00191
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0096 - accuracy: 0.9964 - val_loss: 0.3471 - val_accuracy: 0.9270
#
# Epoch 00047: val_loss did not improve from 0.00191
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.0062 - val_accuracy: 0.9984
#
# Epoch 00048: val_loss did not improve from 0.00191
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 0.1431 - val_accuracy: 0.9570
#
# Epoch 00049: val_loss did not improve from 0.00191
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0159 - accuracy: 0.9947 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00050: val_loss did not improve from 0.00191
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 0.0075 - val_accuracy: 0.9980
#
# Epoch 00051: val_loss did not improve from 0.00191
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0090 - val_accuracy: 0.9973
#
# Epoch 00052: val_loss did not improve from 0.00191
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.7331 - val_accuracy: 0.8766
#
# Epoch 00053: val_loss did not improve from 0.00191
# Epoch 54/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00054: val_loss did not improve from 0.00191
# Epoch 55/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0103 - accuracy: 0.9961 - val_loss: 0.0107 - val_accuracy: 0.9969
#
# Epoch 00055: val_loss did not improve from 0.00191
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0531 - val_accuracy: 0.9859
#
# Epoch 00056: val_loss did not improve from 0.00191
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.0298 - val_accuracy: 0.9922
#
# Epoch 00057: val_loss did not improve from 0.00191
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9963 - val_loss: 0.0046 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00191
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0165 - val_accuracy: 0.9961
#
# Epoch 00059: val_loss did not improve from 0.00191
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 0.0164 - val_accuracy: 0.9957
#
# Epoch 00060: val_loss did not improve from 0.00191
# Epoch 61/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.0605 - val_accuracy: 0.9867
#
# Epoch 00061: val_loss did not improve from 0.00191
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.9780 - val_accuracy: 0.8445
#
# Epoch 00062: val_loss did not improve from 0.00191
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.1438 - val_accuracy: 0.9676
#
# Epoch 00063: val_loss did not improve from 0.00191
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0133 - val_accuracy: 0.9973
#
# Epoch 00064: val_loss did not improve from 0.00191
# Epoch 65/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00065: val_loss did not improve from 0.00191
# Epoch 66/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0163 - val_accuracy: 0.9957
#
# Epoch 00066: val_loss did not improve from 0.00191
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00067: val_loss did not improve from 0.00191
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.1830 - val_accuracy: 0.9617
#
# Epoch 00068: val_loss did not improve from 0.00191
# Epoch 69/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0072 - val_accuracy: 0.9973
#
# Epoch 00069: val_loss did not improve from 0.00191
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0167 - accuracy: 0.9954 - val_loss: 1.6195 - val_accuracy: 0.7953
#
# Epoch 00070: val_loss did not improve from 0.00191
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9968 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00071: val_loss did not improve from 0.00191
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0073 - val_accuracy: 0.9961
#
# Epoch 00072: val_loss did not improve from 0.00191
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 0.0080 - val_accuracy: 0.9969
#
# Epoch 00073: val_loss did not improve from 0.00191
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.0153 - val_accuracy: 0.9984
#
# Epoch 00074: val_loss did not improve from 0.00191
# Epoch 75/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0065 - val_accuracy: 0.9965
#
# Epoch 00075: val_loss did not improve from 0.00191
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0048 - accuracy: 0.9978 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00076: val_loss did not improve from 0.00191
# Epoch 77/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00077: val_loss did not improve from 0.00191
# Epoch 78/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0045 - val_accuracy: 0.9984
#
# Epoch 00078: val_loss did not improve from 0.00191
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9971 - val_loss: 0.0061 - val_accuracy: 0.9973
#
# Epoch 00079: val_loss did not improve from 0.00191
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0095 - val_accuracy: 0.9957
#
# Epoch 00080: val_loss did not improve from 0.00191
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.0056 - val_accuracy: 0.9961
#
# Epoch 00081: val_loss did not improve from 0.00191
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.0164 - val_accuracy: 0.9949
#
# Epoch 00082: val_loss did not improve from 0.00191
# Epoch 83/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 1.1175 - val_accuracy: 0.8137
#
# Epoch 00083: val_loss did not improve from 0.00191
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0054 - val_accuracy: 0.9984
#
# Epoch 00084: val_loss did not improve from 0.00191
# Epoch 85/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0127 - val_accuracy: 0.9957
#
# Epoch 00085: val_loss did not improve from 0.00191
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00086: val_loss did not improve from 0.00191
# Epoch 87/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9967 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00191
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9972 - val_loss: 0.0079 - val_accuracy: 0.9965
#
# Epoch 00088: val_loss did not improve from 0.00191
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.2125 - val_accuracy: 0.9461
#
# Epoch 00089: val_loss did not improve from 0.00191
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.0262 - val_accuracy: 0.9957
#
# Epoch 00090: val_loss did not improve from 0.00191
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00191
# Epoch 92/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0055 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00191
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9964 - val_loss: 0.3909 - val_accuracy: 0.9285
#
# Epoch 00093: val_loss did not improve from 0.00191
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0165 - accuracy: 0.9945 - val_loss: 0.0042 - val_accuracy: 0.9984
#
# Epoch 00094: val_loss did not improve from 0.00191
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0052 - val_accuracy: 0.9969
#
# Epoch 00095: val_loss did not improve from 0.00191
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00096: val_loss did not improve from 0.00191
# Epoch 97/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0096 - val_accuracy: 0.9961
#
# Epoch 00097: val_loss did not improve from 0.00191
# Epoch 98/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9973 - val_loss: 0.0108 - val_accuracy: 0.9961
#
# Epoch 00098: val_loss did not improve from 0.00191
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0066 - accuracy: 0.9969 - val_loss: 0.0026 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00191
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00100: val_loss did not improve from 0.00191
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 0.9988
# Val Score:  [0.002108695451170206, 0.998828113079071]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4004 - accuracy: 0.8800 - val_loss: 4.2441 - val_accuracy: 0.4785
#
# Epoch 00001: val_loss did not improve from 0.00191
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1134 - accuracy: 0.9592 - val_loss: 0.4847 - val_accuracy: 0.8566
#
# Epoch 00002: val_loss did not improve from 0.00191
# Epoch 3/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0750 - accuracy: 0.9731 - val_loss: 0.1380 - val_accuracy: 0.9586
#
# Epoch 00003: val_loss did not improve from 0.00191
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0521 - accuracy: 0.9816 - val_loss: 0.1117 - val_accuracy: 0.9656
#
# Epoch 00004: val_loss did not improve from 0.00191
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0530 - accuracy: 0.9813 - val_loss: 0.0474 - val_accuracy: 0.9832
#
# Epoch 00005: val_loss did not improve from 0.00191
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0330 - accuracy: 0.9880 - val_loss: 0.2594 - val_accuracy: 0.9543
#
# Epoch 00006: val_loss did not improve from 0.00191
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0327 - accuracy: 0.9889 - val_loss: 1.2521 - val_accuracy: 0.7891
#
# Epoch 00007: val_loss did not improve from 0.00191
# Epoch 8/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0372 - accuracy: 0.9883 - val_loss: 0.0714 - val_accuracy: 0.9750
#
# Epoch 00008: val_loss did not improve from 0.00191
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0255 - accuracy: 0.9923 - val_loss: 0.3375 - val_accuracy: 0.9219
#
# Epoch 00009: val_loss did not improve from 0.00191
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0292 - accuracy: 0.9894 - val_loss: 0.0553 - val_accuracy: 0.9801
#
# Epoch 00010: val_loss did not improve from 0.00191
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.2811 - val_accuracy: 0.9250
#
# Epoch 00011: val_loss did not improve from 0.00191
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 0.0927 - val_accuracy: 0.9664
#
# Epoch 00012: val_loss did not improve from 0.00191
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0207 - accuracy: 0.9948 - val_loss: 0.1557 - val_accuracy: 0.9539
#
# Epoch 00013: val_loss did not improve from 0.00191
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0232 - accuracy: 0.9919 - val_loss: 1.4200 - val_accuracy: 0.6836
#
# Epoch 00014: val_loss did not improve from 0.00191
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0285 - accuracy: 0.9907 - val_loss: 0.1517 - val_accuracy: 0.9547
#
# Epoch 00015: val_loss did not improve from 0.00191
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0293 - accuracy: 0.9900 - val_loss: 0.0946 - val_accuracy: 0.9703
#
# Epoch 00016: val_loss did not improve from 0.00191
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0220 - accuracy: 0.9922 - val_loss: 0.0063 - val_accuracy: 0.9980
#
# Epoch 00017: val_loss did not improve from 0.00191
# Epoch 18/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0143 - accuracy: 0.9959 - val_loss: 0.0355 - val_accuracy: 0.9863
#
# Epoch 00018: val_loss did not improve from 0.00191
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0051 - val_accuracy: 0.9977
#
# Epoch 00019: val_loss did not improve from 0.00191
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0164 - accuracy: 0.9939 - val_loss: 0.0640 - val_accuracy: 0.9789
#
# Epoch 00020: val_loss did not improve from 0.00191
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0171 - accuracy: 0.9937 - val_loss: 0.4334 - val_accuracy: 0.8906
#
# Epoch 00021: val_loss did not improve from 0.00191
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0166 - accuracy: 0.9937 - val_loss: 0.0222 - val_accuracy: 0.9930
#
# Epoch 00022: val_loss did not improve from 0.00191
# Epoch 23/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.0517 - val_accuracy: 0.9836
#
# Epoch 00023: val_loss did not improve from 0.00191
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.2099 - val_accuracy: 0.9691
#
# Epoch 00024: val_loss did not improve from 0.00191
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.0434 - val_accuracy: 0.9887
#
# Epoch 00025: val_loss did not improve from 0.00191
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.0152 - val_accuracy: 0.9961
#
# Epoch 00026: val_loss did not improve from 0.00191
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.0282 - val_accuracy: 0.9891
#
# Epoch 00027: val_loss did not improve from 0.00191
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0226 - accuracy: 0.9935 - val_loss: 0.0476 - val_accuracy: 0.9859
#
# Epoch 00028: val_loss did not improve from 0.00191
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0138 - accuracy: 0.9949 - val_loss: 0.0662 - val_accuracy: 0.9812
#
# Epoch 00029: val_loss did not improve from 0.00191
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.0073 - val_accuracy: 0.9973
#
# Epoch 00030: val_loss did not improve from 0.00191
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0054 - val_accuracy: 0.9984
#
# Epoch 00031: val_loss did not improve from 0.00191
# Epoch 32/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0703 - val_accuracy: 0.9766
#
# Epoch 00032: val_loss did not improve from 0.00191
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0121 - accuracy: 0.9957 - val_loss: 0.6343 - val_accuracy: 0.8586
#
# Epoch 00033: val_loss did not improve from 0.00191
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0035 - val_accuracy: 0.9984
#
# Epoch 00034: val_loss did not improve from 0.00191
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.2512 - val_accuracy: 0.9184
#
# Epoch 00035: val_loss did not improve from 0.00191
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.3156 - val_accuracy: 0.9391
#
# Epoch 00036: val_loss did not improve from 0.00191
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0114 - accuracy: 0.9952 - val_loss: 0.0080 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss did not improve from 0.00191
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.0096 - val_accuracy: 0.9973
#
# Epoch 00038: val_loss did not improve from 0.00191
# Epoch 39/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0137 - accuracy: 0.9947 - val_loss: 0.1729 - val_accuracy: 0.9633
#
# Epoch 00039: val_loss did not improve from 0.00191
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0093 - accuracy: 0.9964 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00040: val_loss did not improve from 0.00191
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.0144 - val_accuracy: 0.9965
#
# Epoch 00041: val_loss did not improve from 0.00191
# Epoch 42/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00191
# Epoch 21/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0183 - accuracy: 0.9935 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00021: val_loss did not improve from 0.00191
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0101 - accuracy: 0.9959 - val_loss: 0.0446 - val_accuracy: 0.9840
#
# Epoch 00022: val_loss did not improve from 0.00191
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.0180 - val_accuracy: 0.9926
#
# Epoch 00023: val_loss did not improve from 0.00191
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9930 - val_loss: 0.1072 - val_accuracy: 0.9664
#
# Epoch 00024: val_loss did not improve from 0.00191
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.0797 - val_accuracy: 0.9766
#
# Epoch 00025: val_loss did not improve from 0.00191
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00026: val_loss did not improve from 0.00191
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0072 - val_accuracy: 0.9980
#
# Epoch 00027: val_loss did not improve from 0.00191
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0141 - val_accuracy: 0.9953
#
# Epoch 00028: val_loss did not improve from 0.00191
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0264 - accuracy: 0.9917 - val_loss: 0.1773 - val_accuracy: 0.9520
#
# Epoch 00029: val_loss did not improve from 0.00191
# Epoch 30/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00030: val_loss did not improve from 0.00191
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0090 - accuracy: 0.9967 - val_loss: 0.0137 - val_accuracy: 0.9949
#
# Epoch 00031: val_loss did not improve from 0.00191
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9945 - val_loss: 0.1247 - val_accuracy: 0.9715
#
# Epoch 00032: val_loss did not improve from 0.00191
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0151 - accuracy: 0.9953 - val_loss: 0.0091 - val_accuracy: 0.9965
#
# Epoch 00033: val_loss did not improve from 0.00191
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.9267 - val_accuracy: 0.8438
#
# Epoch 00034: val_loss did not improve from 0.00191
# Epoch 35/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00035: val_loss did not improve from 0.00191
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9975 - val_loss: 0.0090 - val_accuracy: 0.9969
#
# Epoch 00036: val_loss did not improve from 0.00191
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.0538 - val_accuracy: 0.9836
#
# Epoch 00037: val_loss did not improve from 0.00191
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9953 - val_loss: 0.0102 - val_accuracy: 0.9961
#
# Epoch 00038: val_loss did not improve from 0.00191
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0086 - val_accuracy: 0.9965
#
# Epoch 00039: val_loss did not improve from 0.00191
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0276 - val_accuracy: 0.9926
#
# Epoch 00040: val_loss did not improve from 0.00191
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0148 - accuracy: 0.9944 - val_loss: 0.0055 - val_accuracy: 0.9973
#
# Epoch 00041: val_loss did not improve from 0.00191
# Epoch 42/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0095 - accuracy: 0.9956 - val_loss: 0.0147 - val_accuracy: 0.9965
#
# Epoch 00042: val_loss did not improve from 0.00191
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00043: val_loss did not improve from 0.00191
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0094 - accuracy: 0.9959 - val_loss: 1.5796 - val_accuracy: 0.7633
#
# Epoch 00044: val_loss did not improve from 0.00191
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9964 - val_loss: 0.0047 - val_accuracy: 0.9977
#
# Epoch 00045: val_loss did not improve from 0.00191
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0139 - val_accuracy: 0.9934
#
# Epoch 00046: val_loss did not improve from 0.00191
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0060 - val_accuracy: 0.9969
#
# Epoch 00047: val_loss did not improve from 0.00191
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0033 - val_accuracy: 0.9977
#
# Epoch 00048: val_loss did not improve from 0.00191
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00049: val_loss did not improve from 0.00191
# Epoch 50/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0026 - val_accuracy: 0.9980
#
# Epoch 00050: val_loss did not improve from 0.00191
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.0404 - val_accuracy: 0.9887
#
# Epoch 00051: val_loss did not improve from 0.00191
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00052: val_loss did not improve from 0.00191
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00053: val_loss did not improve from 0.00191
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00054: val_loss did not improve from 0.00191
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 1.3305 - val_accuracy: 0.8176
#
# Epoch 00055: val_loss did not improve from 0.00191
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.0184 - val_accuracy: 0.9926
#
# Epoch 00056: val_loss did not improve from 0.00191
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00057: val_loss did not improve from 0.00191
# Epoch 58/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0145 - val_accuracy: 0.9949
#
# Epoch 00058: val_loss did not improve from 0.00191
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0027 - val_accuracy: 0.9988
#
# Epoch 00059: val_loss did not improve from 0.00191
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9971 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00060: val_loss did not improve from 0.00191
# Epoch 61/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0040 - accuracy: 0.9982 - val_loss: 0.0049 - val_accuracy: 0.9984
#
# Epoch 00061: val_loss did not improve from 0.00191
# Epoch 62/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9981 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00191
# Epoch 63/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0158 - accuracy: 0.9941 - val_loss: 0.0122 - val_accuracy: 0.9953
#
# Epoch 00063: val_loss did not improve from 0.00191
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0070 - val_accuracy: 0.9965
#
# Epoch 00064: val_loss did not improve from 0.00191
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0033 - val_accuracy: 0.9977
#
# Epoch 00065: val_loss did not improve from 0.00191
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0113 - val_accuracy: 0.9961
#
# Epoch 00066: val_loss did not improve from 0.00191
# Epoch 67/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0149 - val_accuracy: 0.9930
#
# Epoch 00067: val_loss did not improve from 0.00191
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0038 - val_accuracy: 0.9977
#
# Epoch 00068: val_loss did not improve from 0.00191
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0423 - val_accuracy: 0.9887
#
# Epoch 00069: val_loss did not improve from 0.00191
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0668 - val_accuracy: 0.9859
#
# Epoch 00070: val_loss did not improve from 0.00191
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0045 - val_accuracy: 0.9984
#
# Epoch 00071: val_loss did not improve from 0.00191
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00072: val_loss did not improve from 0.00191
# Epoch 73/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00073: val_loss did not improve from 0.00191
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.0053 - val_accuracy: 0.9988
#
# Epoch 00074: val_loss did not improve from 0.00191
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0065 - val_accuracy: 0.9977
#
# Epoch 00075: val_loss did not improve from 0.00191
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00191
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00077: val_loss did not improve from 0.00191
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00078: val_loss did not improve from 0.00191
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0293 - val_accuracy: 0.9898
#
# Epoch 00079: val_loss did not improve from 0.00191
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.0040 - val_accuracy: 0.9988
#
# Epoch 00080: val_loss did not improve from 0.00191
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0053 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00191
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00082: val_loss did not improve from 0.00191
# Epoch 83/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0075 - accuracy: 0.9970 - val_loss: 0.0086 - val_accuracy: 0.9965
#
# Epoch 00083: val_loss did not improve from 0.00191
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.0032 - val_accuracy: 0.9988
#
# Epoch 00084: val_loss did not improve from 0.00191
# Epoch 85/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0055 - val_accuracy: 0.9977
#
# Epoch 00085: val_loss did not improve from 0.00191
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 0.2406 - val_accuracy: 0.9398
#
# Epoch 00086: val_loss did not improve from 0.00191
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00191
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9974 - val_loss: 0.0422 - val_accuracy: 0.9832
#
# Epoch 00088: val_loss did not improve from 0.00191
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00089: val_loss did not improve from 0.00191
# Epoch 90/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00090: val_loss did not improve from 0.00191
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0205 - val_accuracy: 0.9922
#
# Epoch 00091: val_loss did not improve from 0.00191
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0217 - val_accuracy: 0.9914
#
# Epoch 00092: val_loss did not improve from 0.00191
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9965 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00093: val_loss did not improve from 0.00191
# Epoch 94/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0123 - val_accuracy: 0.9953
#
# Epoch 00094: val_loss did not improve from 0.00191
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0020 - val_accuracy: 0.9984
#
# Epoch 00095: val_loss did not improve from 0.00191
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00191
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.0074 - val_accuracy: 0.9957
#
# Epoch 00097: val_loss did not improve from 0.00191
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9973 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00191
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00099: val_loss did not improve from 0.00191
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.0691 - val_accuracy: 0.9797
#
# Epoch 00100: val_loss did not improve from 0.00191
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9797
# Val Score:  [0.06913963705301285, 0.979687511920929]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       1.00      1.00      1.00       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      1.00      1.00       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9987
# Test Accuracy: 99.87499713897705

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
