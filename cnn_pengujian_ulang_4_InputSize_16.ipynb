# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-4
BS = 32
default_image_size = tuple((16, 16))
image_size = 0
directory_root = "../input/riceleaf"
width=16
height=16
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 2022-08-07 12:03:29.685875: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:29.781824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:29.782621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:29.784257: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-07 12:03:29.784650: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:29.785401: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:29.786094: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:31.982304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:31.983234: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:31.984043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-07 12:03:31.985621: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 16, 16, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 16, 16, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 16, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 5, 5, 16)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 5, 32)          4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 5, 5, 32)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5, 5, 32)          128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 5, 5, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5, 5, 64)          256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 128)         73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 631,908
# Trainable params: 629,380
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# 2022-08-07 12:03:33.473959: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-08-07 12:03:35.337993: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 320/320 [==============================] - 9s 6ms/step - loss: 1.2665 - accuracy: 0.5666 - val_loss: 0.9247 - val_accuracy: 0.6156
#
# Epoch 00001: val_loss improved from inf to 0.92468, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.8905 - accuracy: 0.6815 - val_loss: 0.4162 - val_accuracy: 0.8383
#
# Epoch 00002: val_loss improved from 0.92468 to 0.41617, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.7332 - accuracy: 0.7292 - val_loss: 0.3349 - val_accuracy: 0.8742
#
# Epoch 00003: val_loss improved from 0.41617 to 0.33487, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.6091 - accuracy: 0.7754 - val_loss: 0.2579 - val_accuracy: 0.9121
#
# Epoch 00004: val_loss improved from 0.33487 to 0.25791, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.5291 - accuracy: 0.7999 - val_loss: 0.2893 - val_accuracy: 0.8773
#
# Epoch 00005: val_loss did not improve from 0.25791
# Epoch 6/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.4738 - accuracy: 0.8245 - val_loss: 0.2212 - val_accuracy: 0.9160
#
# Epoch 00006: val_loss improved from 0.25791 to 0.22123, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.4185 - accuracy: 0.8456 - val_loss: 0.2191 - val_accuracy: 0.9215
#
# Epoch 00007: val_loss improved from 0.22123 to 0.21910, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3825 - accuracy: 0.8565 - val_loss: 0.1685 - val_accuracy: 0.9434
#
# Epoch 00008: val_loss improved from 0.21910 to 0.16849, saving model to model.h5
# Epoch 9/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3535 - accuracy: 0.8659 - val_loss: 0.1663 - val_accuracy: 0.9402
#
# Epoch 00009: val_loss improved from 0.16849 to 0.16630, saving model to model.h5
# Epoch 10/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3419 - accuracy: 0.8681 - val_loss: 0.1567 - val_accuracy: 0.9434
#
# Epoch 00010: val_loss improved from 0.16630 to 0.15670, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3009 - accuracy: 0.8851 - val_loss: 0.1469 - val_accuracy: 0.9414
#
# Epoch 00011: val_loss improved from 0.15670 to 0.14686, saving model to model.h5
# Epoch 12/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2834 - accuracy: 0.8913 - val_loss: 0.1306 - val_accuracy: 0.9461
#
# Epoch 00012: val_loss improved from 0.14686 to 0.13056, saving model to model.h5
# Epoch 13/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2632 - accuracy: 0.9010 - val_loss: 0.1238 - val_accuracy: 0.9484
#
# Epoch 00013: val_loss improved from 0.13056 to 0.12382, saving model to model.h5
# Epoch 14/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2578 - accuracy: 0.9026 - val_loss: 0.0956 - val_accuracy: 0.9609
#
# Epoch 00014: val_loss improved from 0.12382 to 0.09556, saving model to model.h5
# Epoch 15/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2328 - accuracy: 0.9101 - val_loss: 0.1138 - val_accuracy: 0.9570
#
# Epoch 00015: val_loss did not improve from 0.09556
# Epoch 16/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2224 - accuracy: 0.9135 - val_loss: 0.0934 - val_accuracy: 0.9656
#
# Epoch 00016: val_loss improved from 0.09556 to 0.09342, saving model to model.h5
# Epoch 17/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2003 - accuracy: 0.9255 - val_loss: 0.0860 - val_accuracy: 0.9664
#
# Epoch 00017: val_loss improved from 0.09342 to 0.08599, saving model to model.h5
# Epoch 18/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1982 - accuracy: 0.9248 - val_loss: 0.0888 - val_accuracy: 0.9668
#
# Epoch 00018: val_loss did not improve from 0.08599
# Epoch 19/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1884 - accuracy: 0.9288 - val_loss: 0.0671 - val_accuracy: 0.9746
#
# Epoch 00019: val_loss improved from 0.08599 to 0.06713, saving model to model.h5
# Epoch 20/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1646 - accuracy: 0.9375 - val_loss: 0.0588 - val_accuracy: 0.9754
#
# Epoch 00020: val_loss improved from 0.06713 to 0.05878, saving model to model.h5
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1588 - accuracy: 0.9387 - val_loss: 0.0571 - val_accuracy: 0.9781
#
# Epoch 00021: val_loss improved from 0.05878 to 0.05708, saving model to model.h5
# Epoch 22/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1578 - accuracy: 0.9406 - val_loss: 0.0563 - val_accuracy: 0.9785
#
# Epoch 00022: val_loss improved from 0.05708 to 0.05631, saving model to model.h5
# Epoch 23/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1453 - accuracy: 0.9432 - val_loss: 0.0535 - val_accuracy: 0.9805
#
# Epoch 00023: val_loss improved from 0.05631 to 0.05351, saving model to model.h5
# Epoch 24/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1312 - accuracy: 0.9514 - val_loss: 0.0451 - val_accuracy: 0.9859
#
# Epoch 00024: val_loss improved from 0.05351 to 0.04509, saving model to model.h5
# Epoch 25/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1361 - accuracy: 0.9502 - val_loss: 0.0418 - val_accuracy: 0.9852
#
# Epoch 00025: val_loss improved from 0.04509 to 0.04180, saving model to model.h5
# Epoch 26/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1295 - accuracy: 0.9498 - val_loss: 0.0612 - val_accuracy: 0.9793
#
# Epoch 00026: val_loss did not improve from 0.04180
# Epoch 27/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1202 - accuracy: 0.9539 - val_loss: 0.0440 - val_accuracy: 0.9848
#
# Epoch 00027: val_loss did not improve from 0.04180
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1132 - accuracy: 0.9556 - val_loss: 0.0529 - val_accuracy: 0.9836
#
# Epoch 00028: val_loss did not improve from 0.04180
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1110 - accuracy: 0.9584 - val_loss: 0.0371 - val_accuracy: 0.9844
#
# Epoch 00029: val_loss improved from 0.04180 to 0.03711, saving model to model.h5
# Epoch 30/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1056 - accuracy: 0.9597 - val_loss: 0.0292 - val_accuracy: 0.9902
#
# Epoch 00030: val_loss improved from 0.03711 to 0.02919, saving model to model.h5
# Epoch 31/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1036 - accuracy: 0.9605 - val_loss: 0.0409 - val_accuracy: 0.9840
#
# Epoch 00031: val_loss did not improve from 0.02919
# Epoch 32/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0916 - accuracy: 0.9658 - val_loss: 0.0260 - val_accuracy: 0.9898
#
# Epoch 00032: val_loss improved from 0.02919 to 0.02595, saving model to model.h5
# Epoch 33/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0939 - accuracy: 0.9657 - val_loss: 0.0253 - val_accuracy: 0.9906
#
# Epoch 00033: val_loss improved from 0.02595 to 0.02526, saving model to model.h5
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0922 - accuracy: 0.9635 - val_loss: 0.0232 - val_accuracy: 0.9922
#
# Epoch 00034: val_loss improved from 0.02526 to 0.02321, saving model to model.h5
# Epoch 35/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0890 - accuracy: 0.9683 - val_loss: 0.0272 - val_accuracy: 0.9922
#
# Epoch 00035: val_loss did not improve from 0.02321
# Epoch 36/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0810 - accuracy: 0.9722 - val_loss: 0.0389 - val_accuracy: 0.9844
#
# Epoch 00036: val_loss did not improve from 0.02321
# Epoch 37/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0863 - accuracy: 0.9671 - val_loss: 0.0226 - val_accuracy: 0.9914
#
# Epoch 00037: val_loss improved from 0.02321 to 0.02255, saving model to model.h5
# Epoch 38/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0807 - accuracy: 0.9693 - val_loss: 0.0243 - val_accuracy: 0.9898
#
# Epoch 00038: val_loss did not improve from 0.02255
# Epoch 39/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0800 - accuracy: 0.9707 - val_loss: 0.0279 - val_accuracy: 0.9883
#
# Epoch 00039: val_loss did not improve from 0.02255
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0734 - accuracy: 0.9729 - val_loss: 0.0270 - val_accuracy: 0.9891
#
# Epoch 00040: val_loss did not improve from 0.02255
# Epoch 41/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0735 - accuracy: 0.9722 - val_loss: 0.0220 - val_accuracy: 0.9926
#
# Epoch 00041: val_loss improved from 0.02255 to 0.02199, saving model to model.h5
# Epoch 42/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0636 - accuracy: 0.9768 - val_loss: 0.0251 - val_accuracy: 0.9914
#
# Epoch 00042: val_loss did not improve from 0.02199
# Epoch 43/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0697 - accuracy: 0.9741 - val_loss: 0.0188 - val_accuracy: 0.9926
#
# Epoch 00043: val_loss improved from 0.02199 to 0.01875, saving model to model.h5
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0710 - accuracy: 0.9737 - val_loss: 0.0174 - val_accuracy: 0.9934
#
# Epoch 00044: val_loss improved from 0.01875 to 0.01737, saving model to model.h5
# Epoch 45/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0638 - accuracy: 0.9751 - val_loss: 0.0157 - val_accuracy: 0.9953
#
# Epoch 00045: val_loss improved from 0.01737 to 0.01572, saving model to model.h5
# Epoch 46/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0601 - accuracy: 0.9776 - val_loss: 0.0155 - val_accuracy: 0.9941
#
# Epoch 00046: val_loss improved from 0.01572 to 0.01547, saving model to model.h5
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0613 - accuracy: 0.9756 - val_loss: 0.0148 - val_accuracy: 0.9945
#
# Epoch 00047: val_loss improved from 0.01547 to 0.01485, saving model to model.h5
# Epoch 48/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0559 - accuracy: 0.9805 - val_loss: 0.0147 - val_accuracy: 0.9941
#
# Epoch 00048: val_loss improved from 0.01485 to 0.01471, saving model to model.h5
# Epoch 49/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0581 - accuracy: 0.9771 - val_loss: 0.0255 - val_accuracy: 0.9906
#
# Epoch 00049: val_loss did not improve from 0.01471
# Epoch 50/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0546 - accuracy: 0.9806 - val_loss: 0.0152 - val_accuracy: 0.9957
#
# Epoch 00050: val_loss did not improve from 0.01471
# Epoch 51/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0523 - accuracy: 0.9824 - val_loss: 0.0220 - val_accuracy: 0.9918
#
# Epoch 00051: val_loss did not improve from 0.01471
# Epoch 52/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0559 - accuracy: 0.9795 - val_loss: 0.0196 - val_accuracy: 0.9937
#
# Epoch 00052: val_loss did not improve from 0.01471
# Epoch 53/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0511 - accuracy: 0.9808 - val_loss: 0.0174 - val_accuracy: 0.9937
#
# Epoch 00053: val_loss did not improve from 0.01471
# Epoch 54/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0500 - accuracy: 0.9812 - val_loss: 0.0111 - val_accuracy: 0.9961
#
# Epoch 00054: val_loss improved from 0.01471 to 0.01107, saving model to model.h5
# Epoch 55/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0513 - accuracy: 0.9800 - val_loss: 0.0123 - val_accuracy: 0.9941
#
# Epoch 00055: val_loss did not improve from 0.01107
# Epoch 56/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0436 - accuracy: 0.9840 - val_loss: 0.0107 - val_accuracy: 0.9961
#
# Epoch 00056: val_loss improved from 0.01107 to 0.01067, saving model to model.h5
# Epoch 57/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0445 - accuracy: 0.9830 - val_loss: 0.0243 - val_accuracy: 0.9930
#
# Epoch 00057: val_loss did not improve from 0.01067
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0423 - accuracy: 0.9844 - val_loss: 0.0136 - val_accuracy: 0.9949
#
# Epoch 00058: val_loss did not improve from 0.01067
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0468 - accuracy: 0.9836 - val_loss: 0.0119 - val_accuracy: 0.9949
#
# Epoch 00059: val_loss did not improve from 0.01067
# Epoch 60/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0438 - accuracy: 0.9838 - val_loss: 0.0190 - val_accuracy: 0.9934
#
# Epoch 00060: val_loss did not improve from 0.01067
# Epoch 61/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0428 - accuracy: 0.9838 - val_loss: 0.0109 - val_accuracy: 0.9961
#
# Epoch 00061: val_loss did not improve from 0.01067
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0421 - accuracy: 0.9848 - val_loss: 0.0176 - val_accuracy: 0.9930
#
# Epoch 00062: val_loss did not improve from 0.01067
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0466 - accuracy: 0.9833 - val_loss: 0.0090 - val_accuracy: 0.9969
#
# Epoch 00063: val_loss improved from 0.01067 to 0.00902, saving model to model.h5
# Epoch 64/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0387 - accuracy: 0.9857 - val_loss: 0.0118 - val_accuracy: 0.9953
#
# Epoch 00064: val_loss did not improve from 0.00902
# Epoch 65/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0443 - accuracy: 0.9834 - val_loss: 0.0112 - val_accuracy: 0.9957
#
# Epoch 00065: val_loss did not improve from 0.00902
# Epoch 66/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0419 - accuracy: 0.9848 - val_loss: 0.0092 - val_accuracy: 0.9957
#
# Epoch 00066: val_loss did not improve from 0.00902
# Epoch 67/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0362 - accuracy: 0.9864 - val_loss: 0.0096 - val_accuracy: 0.9965
#
# Epoch 00067: val_loss did not improve from 0.00902
# Epoch 68/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0399 - accuracy: 0.9854 - val_loss: 0.0117 - val_accuracy: 0.9957
#
# Epoch 00068: val_loss did not improve from 0.00902
# Epoch 69/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0351 - accuracy: 0.9868 - val_loss: 0.0074 - val_accuracy: 0.9973
#
# Epoch 00069: val_loss improved from 0.00902 to 0.00742, saving model to model.h5
# Epoch 70/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0351 - accuracy: 0.9878 - val_loss: 0.0077 - val_accuracy: 0.9965
#
# Epoch 00070: val_loss did not improve from 0.00742
# Epoch 71/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0341 - accuracy: 0.9869 - val_loss: 0.0134 - val_accuracy: 0.9949
#
# Epoch 00071: val_loss did not improve from 0.00742
# Epoch 72/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0311 - accuracy: 0.9874 - val_loss: 0.0082 - val_accuracy: 0.9973
#
# Epoch 00072: val_loss did not improve from 0.00742
# Epoch 73/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0326 - accuracy: 0.9885 - val_loss: 0.0073 - val_accuracy: 0.9965
#
# Epoch 00073: val_loss improved from 0.00742 to 0.00730, saving model to model.h5
# Epoch 74/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0319 - accuracy: 0.9880 - val_loss: 0.0088 - val_accuracy: 0.9957
#
# Epoch 00074: val_loss did not improve from 0.00730
# Epoch 75/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0294 - accuracy: 0.9888 - val_loss: 0.0105 - val_accuracy: 0.9957
#
# Epoch 00075: val_loss did not improve from 0.00730
# Epoch 76/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0349 - accuracy: 0.9860 - val_loss: 0.0148 - val_accuracy: 0.9953
#
# Epoch 00076: val_loss did not improve from 0.00730
# Epoch 77/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0302 - accuracy: 0.9880 - val_loss: 0.0095 - val_accuracy: 0.9957
#
# Epoch 00077: val_loss did not improve from 0.00730
# Epoch 78/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0356 - accuracy: 0.9865 - val_loss: 0.0087 - val_accuracy: 0.9961
#
# Epoch 00078: val_loss did not improve from 0.00730
# Epoch 79/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0305 - accuracy: 0.9871 - val_loss: 0.0121 - val_accuracy: 0.9965
#
# Epoch 00079: val_loss did not improve from 0.00730
# Epoch 80/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0309 - accuracy: 0.9893 - val_loss: 0.0136 - val_accuracy: 0.9945
#
# Epoch 00080: val_loss did not improve from 0.00730
# Epoch 81/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0275 - accuracy: 0.9909 - val_loss: 0.0164 - val_accuracy: 0.9926
#
# Epoch 00081: val_loss did not improve from 0.00730
# Epoch 82/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0263 - accuracy: 0.9903 - val_loss: 0.0136 - val_accuracy: 0.9953
#
# Epoch 00082: val_loss did not improve from 0.00730
# Epoch 83/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0291 - accuracy: 0.9894 - val_loss: 0.0076 - val_accuracy: 0.9957
#
# Epoch 00083: val_loss did not improve from 0.00730
# Epoch 84/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0290 - accuracy: 0.9894 - val_loss: 0.0118 - val_accuracy: 0.9953
#
# Epoch 00084: val_loss did not improve from 0.00730
# Epoch 85/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0296 - accuracy: 0.9896 - val_loss: 0.0133 - val_accuracy: 0.9945
#
# Epoch 00085: val_loss did not improve from 0.00730
# Epoch 86/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0290 - accuracy: 0.9875 - val_loss: 0.0102 - val_accuracy: 0.9961
#
# Epoch 00086: val_loss did not improve from 0.00730
# Epoch 87/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0298 - accuracy: 0.9895 - val_loss: 0.0082 - val_accuracy: 0.9969
#
# Epoch 00087: val_loss did not improve from 0.00730
# Epoch 88/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0265 - accuracy: 0.9905 - val_loss: 0.0065 - val_accuracy: 0.9965
#
# Epoch 00088: val_loss improved from 0.00730 to 0.00647, saving model to model.h5
# Epoch 89/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0247 - accuracy: 0.9915 - val_loss: 0.0190 - val_accuracy: 0.9934
#
# Epoch 00089: val_loss did not improve from 0.00647
# Epoch 90/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0267 - accuracy: 0.9904 - val_loss: 0.0104 - val_accuracy: 0.9961
#
# Epoch 00090: val_loss did not improve from 0.00647
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0307 - accuracy: 0.9885 - val_loss: 0.0075 - val_accuracy: 0.9965
#
# Epoch 00091: val_loss did not improve from 0.00647
# Epoch 92/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0283 - accuracy: 0.9894 - val_loss: 0.0107 - val_accuracy: 0.9969
#
# Epoch 00092: val_loss did not improve from 0.00647
# Epoch 93/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0222 - accuracy: 0.9912 - val_loss: 0.0064 - val_accuracy: 0.9969
#
# Epoch 00093: val_loss improved from 0.00647 to 0.00640, saving model to model.h5
# Epoch 94/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.0092 - val_accuracy: 0.9969
#
# Epoch 00094: val_loss did not improve from 0.00640
# Epoch 95/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0235 - accuracy: 0.9917 - val_loss: 0.0087 - val_accuracy: 0.9969
#
# Epoch 00095: val_loss did not improve from 0.00640
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0233 - accuracy: 0.9910 - val_loss: 0.0105 - val_accuracy: 0.9961
#
# Epoch 00096: val_loss did not improve from 0.00640
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0219 - accuracy: 0.9912 - val_loss: 0.0091 - val_accuracy: 0.9961
#
# Epoch 00097: val_loss did not improve from 0.00640
# Epoch 98/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0238 - accuracy: 0.9905 - val_loss: 0.0084 - val_accuracy: 0.9969
#
# Epoch 00098: val_loss did not improve from 0.00640
# Epoch 99/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0227 - accuracy: 0.9913 - val_loss: 0.0104 - val_accuracy: 0.9953
#
# Epoch 00099: val_loss did not improve from 0.00640
# Epoch 100/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0182 - accuracy: 0.9928 - val_loss: 0.0134 - val_accuracy: 0.9957
#
# Epoch 00100: val_loss did not improve from 0.00640
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9957
# Val Score:  [0.013392115011811256, 0.9957031011581421]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 3s 6ms/step - loss: 0.9315 - accuracy: 0.6685 - val_loss: 1.0146 - val_accuracy: 0.4895
#
# Epoch 00001: val_loss did not improve from 0.00640
# Epoch 2/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.6606 - accuracy: 0.7389 - val_loss: 0.4143 - val_accuracy: 0.8227
#
# Epoch 00002: val_loss did not improve from 0.00640
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.5315 - accuracy: 0.7895 - val_loss: 0.3269 - val_accuracy: 0.8738
#
# Epoch 00003: val_loss did not improve from 0.00640
# Epoch 4/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.4491 - accuracy: 0.8238 - val_loss: 0.2624 - val_accuracy: 0.8977
#
# Epoch 00004: val_loss did not improve from 0.00640
# Epoch 5/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3843 - accuracy: 0.8516 - val_loss: 0.2083 - val_accuracy: 0.9156
#
# Epoch 00005: val_loss did not improve from 0.00640
# Epoch 6/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3436 - accuracy: 0.8687 - val_loss: 0.2003 - val_accuracy: 0.9191
#
# Epoch 00006: val_loss did not improve from 0.00640
# Epoch 7/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2998 - accuracy: 0.8825 - val_loss: 0.1430 - val_accuracy: 0.9500
#
# Epoch 00007: val_loss did not improve from 0.00640
# Epoch 8/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2741 - accuracy: 0.8935 - val_loss: 0.1488 - val_accuracy: 0.9453
#
# Epoch 00008: val_loss did not improve from 0.00640
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2661 - accuracy: 0.8972 - val_loss: 0.1550 - val_accuracy: 0.9277
#
# Epoch 00009: val_loss did not improve from 0.00640
# Epoch 10/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2327 - accuracy: 0.9094 - val_loss: 0.1215 - val_accuracy: 0.9535
#
# Epoch 00010: val_loss did not improve from 0.00640
# Epoch 11/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2159 - accuracy: 0.9176 - val_loss: 0.1115 - val_accuracy: 0.9598
#
# Epoch 00011: val_loss did not improve from 0.00640
# Epoch 12/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1971 - accuracy: 0.9225 - val_loss: 0.0908 - val_accuracy: 0.9688
#
# Epoch 00012: val_loss did not improve from 0.00640
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1881 - accuracy: 0.9279 - val_loss: 0.1304 - val_accuracy: 0.9430
#
# Epoch 00013: val_loss did not improve from 0.00640
# Epoch 14/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1743 - accuracy: 0.9314 - val_loss: 0.0953 - val_accuracy: 0.9641
#
# Epoch 00014: val_loss did not improve from 0.00640
# Epoch 15/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1676 - accuracy: 0.9348 - val_loss: 0.0770 - val_accuracy: 0.9688
#
# Epoch 00015: val_loss did not improve from 0.00640
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1557 - accuracy: 0.9419 - val_loss: 0.0822 - val_accuracy: 0.9680
#
# Epoch 00016: val_loss did not improve from 0.00640
# Epoch 17/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1587 - accuracy: 0.9409 - val_loss: 0.0732 - val_accuracy: 0.9727
#
# Epoch 00017: val_loss did not improve from 0.00640
# Epoch 18/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1473 - accuracy: 0.9433 - val_loss: 0.0601 - val_accuracy: 0.9777
#
# Epoch 00018: val_loss did not improve from 0.00640
# Epoch 19/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1344 - accuracy: 0.9487 - val_loss: 0.0561 - val_accuracy: 0.9793
#
# Epoch 00019: val_loss did not improve from 0.00640
# Epoch 20/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1228 - accuracy: 0.9533 - val_loss: 0.0625 - val_accuracy: 0.9770
#
# Epoch 00020: val_loss did not improve from 0.00640
# Epoch 21/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1315 - accuracy: 0.9494 - val_loss: 0.0429 - val_accuracy: 0.9824
#
# Epoch 00021: val_loss did not improve from 0.00640
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1217 - accuracy: 0.9551 - val_loss: 0.0610 - val_accuracy: 0.9793
#
# Epoch 00022: val_loss did not improve from 0.00640
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1114 - accuracy: 0.9593 - val_loss: 0.0408 - val_accuracy: 0.9840
#
# Epoch 00023: val_loss did not improve from 0.00640
# Epoch 24/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1081 - accuracy: 0.9603 - val_loss: 0.0370 - val_accuracy: 0.9859
#
# Epoch 00024: val_loss did not improve from 0.00640
# Epoch 25/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1033 - accuracy: 0.9618 - val_loss: 0.0418 - val_accuracy: 0.9848
#
# Epoch 00025: val_loss did not improve from 0.00640
# Epoch 26/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1037 - accuracy: 0.9621 - val_loss: 0.0342 - val_accuracy: 0.9863
#
# Epoch 00026: val_loss did not improve from 0.00640
# Epoch 27/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1008 - accuracy: 0.9621 - val_loss: 0.0326 - val_accuracy: 0.9871
#
# Epoch 00027: val_loss did not improve from 0.00640
# Epoch 28/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0911 - accuracy: 0.9669 - val_loss: 0.0611 - val_accuracy: 0.9809
#
# Epoch 00028: val_loss did not improve from 0.00640
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0878 - accuracy: 0.9676 - val_loss: 0.0379 - val_accuracy: 0.9871
#
# Epoch 00029: val_loss did not improve from 0.00640
# Epoch 30/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0838 - accuracy: 0.9683 - val_loss: 0.0269 - val_accuracy: 0.9902
#
# Epoch 00030: val_loss did not improve from 0.00640
# Epoch 31/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0851 - accuracy: 0.9687 - val_loss: 0.0359 - val_accuracy: 0.9879
#
# Epoch 00031: val_loss did not improve from 0.00640
# Epoch 32/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0701 - accuracy: 0.9746 - val_loss: 0.0251 - val_accuracy: 0.9906
#
# Epoch 00032: val_loss did not improve from 0.00640
# Epoch 33/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0728 - accuracy: 0.9727 - val_loss: 0.0275 - val_accuracy: 0.9914
#
# Epoch 00033: val_loss did not improve from 0.00640
# Epoch 34/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0760 - accuracy: 0.9722 - val_loss: 0.0303 - val_accuracy: 0.9902
#
# Epoch 00034: val_loss did not improve from 0.00640
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0626 - accuracy: 0.9770 - val_loss: 0.0307 - val_accuracy: 0.9906
#
# Epoch 00035: val_loss did not improve from 0.00640
# Epoch 36/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0671 - accuracy: 0.9754 - val_loss: 0.0218 - val_accuracy: 0.9914
#
# Epoch 00036: val_loss did not improve from 0.00640
# Epoch 37/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0751 - accuracy: 0.9745 - val_loss: 0.0312 - val_accuracy: 0.9887
#
# Epoch 00037: val_loss did not improve from 0.00640
# Epoch 38/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0607 - accuracy: 0.9778 - val_loss: 0.0288 - val_accuracy: 0.9891
#
# Epoch 00038: val_loss did not improve from 0.00640
# Epoch 39/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0694 - accuracy: 0.9743 - val_loss: 0.0228 - val_accuracy: 0.9918
#
# Epoch 00039: val_loss did not improve from 0.00640
# Epoch 40/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0600 - accuracy: 0.9771 - val_loss: 0.0215 - val_accuracy: 0.9914
#
# Epoch 00040: val_loss did not improve from 0.00640
# Epoch 41/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0601 - accuracy: 0.9779 - val_loss: 0.0324 - val_accuracy: 0.9895
#
# Epoch 00041: val_loss did not improve from 0.00640
# Epoch 42/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0587 - accuracy: 0.9784 - val_loss: 0.0208 - val_accuracy: 0.9918
#
# Epoch 00042: val_loss did not improve from 0.00640
# Epoch 43/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0530 - accuracy: 0.9812 - val_loss: 0.0254 - val_accuracy: 0.9906
#
# Epoch 00043: val_loss did not improve from 0.00640
# Epoch 44/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0488 - accuracy: 0.9820 - val_loss: 0.0221 - val_accuracy: 0.9930
#
# Epoch 00044: val_loss did not improve from 0.00640
# Epoch 45/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0579 - accuracy: 0.9785 - val_loss: 0.0200 - val_accuracy: 0.9906
#
# Epoch 00045: val_loss did not improve from 0.00640
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0459 - accuracy: 0.9838 - val_loss: 0.0188 - val_accuracy: 0.9937
#
# Epoch 00046: val_loss did not improve from 0.00640
# Epoch 47/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0466 - accuracy: 0.9831 - val_loss: 0.0164 - val_accuracy: 0.9934
#
# Epoch 00047: val_loss did not improve from 0.00640
# Epoch 48/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0512 - accuracy: 0.9811 - val_loss: 0.0114 - val_accuracy: 0.9957
#
# Epoch 00048: val_loss did not improve from 0.00640
# Epoch 49/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0439 - accuracy: 0.9848 - val_loss: 0.0208 - val_accuracy: 0.9926
#
# Epoch 00049: val_loss did not improve from 0.00640
# Epoch 50/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0512 - accuracy: 0.9810 - val_loss: 0.0122 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00640
# Epoch 51/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0434 - accuracy: 0.9840 - val_loss: 0.0121 - val_accuracy: 0.9941
#
# Epoch 00051: val_loss did not improve from 0.00640
# Epoch 52/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0475 - accuracy: 0.9820 - val_loss: 0.0113 - val_accuracy: 0.9953
#
# Epoch 00052: val_loss did not improve from 0.00640
# Epoch 53/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0400 - accuracy: 0.9849 - val_loss: 0.0130 - val_accuracy: 0.9937
#
# Epoch 00053: val_loss did not improve from 0.00640
# Epoch 54/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0401 - accuracy: 0.9859 - val_loss: 0.0183 - val_accuracy: 0.9926
#
# Epoch 00054: val_loss did not improve from 0.00640
# Epoch 55/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0354 - accuracy: 0.9864 - val_loss: 0.0157 - val_accuracy: 0.9930
#
# Epoch 00055: val_loss did not improve from 0.00640
# Epoch 56/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0393 - accuracy: 0.9860 - val_loss: 0.0154 - val_accuracy: 0.9937
#
# Epoch 00056: val_loss did not improve from 0.00640
# Epoch 57/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0356 - accuracy: 0.9874 - val_loss: 0.0115 - val_accuracy: 0.9953
#
# Epoch 00057: val_loss did not improve from 0.00640
# Epoch 58/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0353 - accuracy: 0.9865 - val_loss: 0.0127 - val_accuracy: 0.9957
#
# Epoch 00058: val_loss did not improve from 0.00640
# Epoch 59/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0370 - accuracy: 0.9854 - val_loss: 0.0230 - val_accuracy: 0.9918
#
# Epoch 00059: val_loss did not improve from 0.00640
# Epoch 60/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0351 - accuracy: 0.9871 - val_loss: 0.0086 - val_accuracy: 0.9973
#
# Epoch 00060: val_loss did not improve from 0.00640
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0349 - accuracy: 0.9861 - val_loss: 0.0144 - val_accuracy: 0.9953
#
# Epoch 00061: val_loss did not improve from 0.00640
# Epoch 62/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0345 - accuracy: 0.9892 - val_loss: 0.0139 - val_accuracy: 0.9945
#
# Epoch 00062: val_loss did not improve from 0.00640
# Epoch 63/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0327 - accuracy: 0.9880 - val_loss: 0.0090 - val_accuracy: 0.9965
#
# Epoch 00063: val_loss did not improve from 0.00640
# Epoch 64/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0321 - accuracy: 0.9889 - val_loss: 0.0079 - val_accuracy: 0.9965
#
# Epoch 00064: val_loss did not improve from 0.00640
# Epoch 65/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0288 - accuracy: 0.9899 - val_loss: 0.0087 - val_accuracy: 0.9961
#
# Epoch 00065: val_loss did not improve from 0.00640
# Epoch 66/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0298 - accuracy: 0.9884 - val_loss: 0.0082 - val_accuracy: 0.9973
#
# Epoch 00066: val_loss did not improve from 0.00640
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0292 - accuracy: 0.9886 - val_loss: 0.0162 - val_accuracy: 0.9945
#
# Epoch 00067: val_loss did not improve from 0.00640
# Epoch 68/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0331 - accuracy: 0.9886 - val_loss: 0.0103 - val_accuracy: 0.9969
#
# Epoch 00068: val_loss did not improve from 0.00640
# Epoch 69/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0301 - accuracy: 0.9898 - val_loss: 0.0122 - val_accuracy: 0.9941
#
# Epoch 00069: val_loss did not improve from 0.00640
# Epoch 70/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0266 - accuracy: 0.9905 - val_loss: 0.0101 - val_accuracy: 0.9957
#
# Epoch 00070: val_loss did not improve from 0.00640
# Epoch 71/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0325 - accuracy: 0.9870 - val_loss: 0.0089 - val_accuracy: 0.9957
#
# Epoch 00071: val_loss did not improve from 0.00640
# Epoch 72/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0297 - accuracy: 0.9894 - val_loss: 0.0111 - val_accuracy: 0.9945
#
# Epoch 00072: val_loss did not improve from 0.00640
# Epoch 73/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0231 - accuracy: 0.9910 - val_loss: 0.0070 - val_accuracy: 0.9973
#
# Epoch 00073: val_loss did not improve from 0.00640
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0283 - accuracy: 0.9900 - val_loss: 0.0084 - val_accuracy: 0.9957
#
# Epoch 00074: val_loss did not improve from 0.00640
# Epoch 75/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0254 - accuracy: 0.9909 - val_loss: 0.0076 - val_accuracy: 0.9965
#
# Epoch 00075: val_loss did not improve from 0.00640
# Epoch 76/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0309 - accuracy: 0.9885 - val_loss: 0.0098 - val_accuracy: 0.9961
#
# Epoch 00076: val_loss did not improve from 0.00640
# Epoch 77/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0275 - accuracy: 0.9893 - val_loss: 0.0073 - val_accuracy: 0.9965
#
# Epoch 00077: val_loss did not improve from 0.00640
# Epoch 78/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0215 - accuracy: 0.9919 - val_loss: 0.0112 - val_accuracy: 0.9953
#
# Epoch 00078: val_loss did not improve from 0.00640
# Epoch 79/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0234 - accuracy: 0.9909 - val_loss: 0.0079 - val_accuracy: 0.9969
#
# Epoch 00079: val_loss did not improve from 0.00640
# Epoch 80/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0247 - accuracy: 0.9904 - val_loss: 0.0095 - val_accuracy: 0.9965
#
# Epoch 00080: val_loss did not improve from 0.00640
# Epoch 81/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.0120 - val_accuracy: 0.9957
#
# Epoch 00081: val_loss did not improve from 0.00640
# Epoch 82/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0212 - accuracy: 0.9910 - val_loss: 0.0114 - val_accuracy: 0.9957
#
# Epoch 00082: val_loss did not improve from 0.00640
# Epoch 83/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0236 - accuracy: 0.9913 - val_loss: 0.0097 - val_accuracy: 0.9973
#
# Epoch 00083: val_loss did not improve from 0.00640
# Epoch 84/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0219 - accuracy: 0.9921 - val_loss: 0.0092 - val_accuracy: 0.9965
#
# Epoch 00084: val_loss did not improve from 0.00640
# Epoch 85/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0235 - accuracy: 0.9908 - val_loss: 0.0118 - val_accuracy: 0.9957
#
# Epoch 00085: val_loss did not improve from 0.00640
# Epoch 86/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0194 - accuracy: 0.9923 - val_loss: 0.0120 - val_accuracy: 0.9953
#
# Epoch 00086: val_loss did not improve from 0.00640
# Epoch 87/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0275 - accuracy: 0.9902 - val_loss: 0.0134 - val_accuracy: 0.9953
#
# Epoch 00087: val_loss did not improve from 0.00640
# Epoch 88/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0258 - accuracy: 0.9906 - val_loss: 0.0066 - val_accuracy: 0.9969
#
# Epoch 00088: val_loss did not improve from 0.00640
# Epoch 89/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0198 - accuracy: 0.9923 - val_loss: 0.0103 - val_accuracy: 0.9953
#
# Epoch 00089: val_loss did not improve from 0.00640
# Epoch 90/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.0080 - val_accuracy: 0.9965
#
# Epoch 00090: val_loss did not improve from 0.00640
# Epoch 91/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0271 - accuracy: 0.9899 - val_loss: 0.0073 - val_accuracy: 0.9973
#
# Epoch 00091: val_loss did not improve from 0.00640
# Epoch 92/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0220 - accuracy: 0.9917 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00640
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0190 - accuracy: 0.9919 - val_loss: 0.0120 - val_accuracy: 0.9949
#
# Epoch 00093: val_loss did not improve from 0.00640
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0217 - accuracy: 0.9912 - val_loss: 0.0084 - val_accuracy: 0.9961
#
# Epoch 00094: val_loss did not improve from 0.00640
# Epoch 95/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0169 - accuracy: 0.9926 - val_loss: 0.0140 - val_accuracy: 0.9949
#
# Epoch 00095: val_loss did not improve from 0.00640
# Epoch 96/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0190 - accuracy: 0.9929 - val_loss: 0.0100 - val_accuracy: 0.9973
#
# Epoch 00096: val_loss did not improve from 0.00640
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0213 - accuracy: 0.9927 - val_loss: 0.0069 - val_accuracy: 0.9973
#
# Epoch 00097: val_loss did not improve from 0.00640
# Epoch 98/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0177 - accuracy: 0.9936 - val_loss: 0.0095 - val_accuracy: 0.9961
#
# Epoch 00098: val_loss did not improve from 0.00640
# Epoch 99/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0188 - accuracy: 0.9926 - val_loss: 0.0070 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00640
# Epoch 100/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0177 - accuracy: 0.9926 - val_loss: 0.0085 - val_accuracy: 0.9961
#
# Epoch 00100: val_loss did not improve from 0.00640
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9961
# Val Score:  [0.008531661704182625, 0.99609375]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 3s 6ms/step - loss: 1.0352 - accuracy: 0.6429 - val_loss: 1.2342 - val_accuracy: 0.5594
#
# Epoch 00001: val_loss did not improve from 0.00640
# Epoch 2/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.6342 - accuracy: 0.7660 - val_loss: 0.5105 - val_accuracy: 0.7797
#
# Epoch 00002: val_loss did not improve from 0.00640
# Epoch 3/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.4908 - accuracy: 0.8120 - val_loss: 0.2886 - val_accuracy: 0.8887
#
# Epoch 00003: val_loss did not improve from 0.00640
# Epoch 4/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.4095 - accuracy: 0.8402 - val_loss: 0.3381 - val_accuracy: 0.8516
#
# Epoch 00004: val_loss did not improve from 0.00640
# Epoch 5/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3799 - accuracy: 0.8529 - val_loss: 0.2521 - val_accuracy: 0.8973
#
# Epoch 00005: val_loss did not improve from 0.00640
# Epoch 6/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3397 - accuracy: 0.8702 - val_loss: 0.2173 - val_accuracy: 0.9180
#
# Epoch 00006: val_loss did not improve from 0.00640
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3230 - accuracy: 0.8753 - val_loss: 0.2251 - val_accuracy: 0.9062
#
# Epoch 00007: val_loss did not improve from 0.00640
# Epoch 8/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2804 - accuracy: 0.8929 - val_loss: 0.1655 - val_accuracy: 0.9391
#
# Epoch 00008: val_loss did not improve from 0.00640
# Epoch 9/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2693 - accuracy: 0.8985 - val_loss: 0.1441 - val_accuracy: 0.9473
#
# Epoch 00009: val_loss did not improve from 0.00640
# Epoch 10/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2555 - accuracy: 0.9021 - val_loss: 0.1409 - val_accuracy: 0.9453
#
# Epoch 00010: val_loss did not improve from 0.00640
# Epoch 11/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2416 - accuracy: 0.9067 - val_loss: 0.1268 - val_accuracy: 0.9531
#
# Epoch 00011: val_loss did not improve from 0.00640
# Epoch 12/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2313 - accuracy: 0.9102 - val_loss: 0.1380 - val_accuracy: 0.9508
#
# Epoch 00012: val_loss did not improve from 0.00640
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2233 - accuracy: 0.9113 - val_loss: 0.1364 - val_accuracy: 0.9469
#
# Epoch 00013: val_loss did not improve from 0.00640
# Epoch 14/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1928 - accuracy: 0.9269 - val_loss: 0.0979 - val_accuracy: 0.9656
#
# Epoch 00014: val_loss did not improve from 0.00640
# Epoch 15/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1964 - accuracy: 0.9241 - val_loss: 0.0940 - val_accuracy: 0.9664
#
# Epoch 00015: val_loss did not improve from 0.00640
# Epoch 16/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1804 - accuracy: 0.9300 - val_loss: 0.0916 - val_accuracy: 0.9676
#
# Epoch 00016: val_loss did not improve from 0.00640
# Epoch 17/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1593 - accuracy: 0.9420 - val_loss: 0.0776 - val_accuracy: 0.9773
#
# Epoch 00017: val_loss did not improve from 0.00640
# Epoch 18/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1692 - accuracy: 0.9403 - val_loss: 0.0830 - val_accuracy: 0.9715
#
# Epoch 00018: val_loss did not improve from 0.00640
# Epoch 19/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1572 - accuracy: 0.9408 - val_loss: 0.0541 - val_accuracy: 0.9820
#
# Epoch 00019: val_loss did not improve from 0.00640
# Epoch 20/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1435 - accuracy: 0.9464 - val_loss: 0.0608 - val_accuracy: 0.9801
#
# Epoch 00020: val_loss did not improve from 0.00640
# Epoch 21/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1387 - accuracy: 0.9462 - val_loss: 0.0643 - val_accuracy: 0.9762
#
# Epoch 00021: val_loss did not improve from 0.00640
# Epoch 22/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1305 - accuracy: 0.9512 - val_loss: 0.0576 - val_accuracy: 0.9812
#
# Epoch 00022: val_loss did not improve from 0.00640
# Epoch 23/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1286 - accuracy: 0.9519 - val_loss: 0.0555 - val_accuracy: 0.9816
#
# Epoch 00023: val_loss did not improve from 0.00640
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1209 - accuracy: 0.9540 - val_loss: 0.0423 - val_accuracy: 0.9855
#
# Epoch 00024: val_loss did not improve from 0.00640
# Epoch 25/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1212 - accuracy: 0.9557 - val_loss: 0.0468 - val_accuracy: 0.9840
#
# Epoch 00025: val_loss did not improve from 0.00640
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1101 - accuracy: 0.9594 - val_loss: 0.0473 - val_accuracy: 0.9840
#
# Epoch 00026: val_loss did not improve from 0.00640
# Epoch 27/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1039 - accuracy: 0.9609 - val_loss: 0.0602 - val_accuracy: 0.9793
#
# Epoch 00027: val_loss did not improve from 0.00640
# Epoch 28/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1039 - accuracy: 0.9594 - val_loss: 0.0320 - val_accuracy: 0.9891
#
# Epoch 00028: val_loss did not improve from 0.00640
# Epoch 29/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0987 - accuracy: 0.9641 - val_loss: 0.0307 - val_accuracy: 0.9875
#
# Epoch 00029: val_loss did not improve from 0.00640
# Epoch 30/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0861 - accuracy: 0.9693 - val_loss: 0.0373 - val_accuracy: 0.9867
#
# Epoch 00030: val_loss did not improve from 0.00640
# Epoch 31/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0899 - accuracy: 0.9671 - val_loss: 0.0291 - val_accuracy: 0.9910
#
# Epoch 00031: val_loss did not improve from 0.00640
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0909 - accuracy: 0.9661 - val_loss: 0.0267 - val_accuracy: 0.9914
#
# Epoch 00032: val_loss did not improve from 0.00640
# Epoch 33/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0854 - accuracy: 0.9671 - val_loss: 0.0247 - val_accuracy: 0.9898
#
# Epoch 00033: val_loss did not improve from 0.00640
# Epoch 34/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0818 - accuracy: 0.9710 - val_loss: 0.0219 - val_accuracy: 0.9918
#
# Epoch 00034: val_loss did not improve from 0.00640
# Epoch 35/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0778 - accuracy: 0.9724 - val_loss: 0.0231 - val_accuracy: 0.9914
#
# Epoch 00035: val_loss did not improve from 0.00640
# Epoch 36/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00270
# Epoch 21/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1224 - accuracy: 0.9544 - val_loss: 0.0509 - val_accuracy: 0.9812
#
# Epoch 00021: val_loss did not improve from 0.00270
# Epoch 22/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1165 - accuracy: 0.9556 - val_loss: 0.0745 - val_accuracy: 0.9723
#
# Epoch 00022: val_loss did not improve from 0.00270
# Epoch 23/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1102 - accuracy: 0.9590 - val_loss: 0.0476 - val_accuracy: 0.9812
#
# Epoch 00023: val_loss did not improve from 0.00270
# Epoch 24/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1106 - accuracy: 0.9576 - val_loss: 0.0619 - val_accuracy: 0.9758
#
# Epoch 00024: val_loss did not improve from 0.00270
# Epoch 25/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0968 - accuracy: 0.9630 - val_loss: 0.0647 - val_accuracy: 0.9758
#
# Epoch 00025: val_loss did not improve from 0.00270
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0948 - accuracy: 0.9650 - val_loss: 0.0440 - val_accuracy: 0.9828
#
# Epoch 00026: val_loss did not improve from 0.00270
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0930 - accuracy: 0.9662 - val_loss: 0.0747 - val_accuracy: 0.9695
#
# Epoch 00027: val_loss did not improve from 0.00270
# Epoch 28/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0870 - accuracy: 0.9664 - val_loss: 0.0463 - val_accuracy: 0.9832
#
# Epoch 00028: val_loss did not improve from 0.00270
# Epoch 29/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0894 - accuracy: 0.9688 - val_loss: 0.0292 - val_accuracy: 0.9887
#
# Epoch 00029: val_loss did not improve from 0.00270
# Epoch 30/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0850 - accuracy: 0.9679 - val_loss: 0.0357 - val_accuracy: 0.9863
#
# Epoch 00030: val_loss did not improve from 0.00270
# Epoch 31/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0820 - accuracy: 0.9698 - val_loss: 0.0291 - val_accuracy: 0.9875
#
# Epoch 00031: val_loss did not improve from 0.00270
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0786 - accuracy: 0.9710 - val_loss: 0.0388 - val_accuracy: 0.9824
#
# Epoch 00032: val_loss did not improve from 0.00270
# Epoch 33/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0704 - accuracy: 0.9727 - val_loss: 0.0386 - val_accuracy: 0.9832
#
# Epoch 00033: val_loss did not improve from 0.00270
# Epoch 34/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0772 - accuracy: 0.9712 - val_loss: 0.0509 - val_accuracy: 0.9805
#
# Epoch 00034: val_loss did not improve from 0.00270
# Epoch 35/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0742 - accuracy: 0.9736 - val_loss: 0.0246 - val_accuracy: 0.9895
#
# Epoch 00035: val_loss did not improve from 0.00270
# Epoch 36/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0704 - accuracy: 0.9748 - val_loss: 0.0339 - val_accuracy: 0.9844
#
# Epoch 00036: val_loss did not improve from 0.00270
# Epoch 37/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0674 - accuracy: 0.9738 - val_loss: 0.0330 - val_accuracy: 0.9859
#
# Epoch 00037: val_loss did not improve from 0.00270
# Epoch 38/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0609 - accuracy: 0.9787 - val_loss: 0.0276 - val_accuracy: 0.9887
#
# Epoch 00038: val_loss did not improve from 0.00270
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0615 - accuracy: 0.9771 - val_loss: 0.0333 - val_accuracy: 0.9895
#
# Epoch 00039: val_loss did not improve from 0.00270
# Epoch 40/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0638 - accuracy: 0.9766 - val_loss: 0.0224 - val_accuracy: 0.9914
#
# Epoch 00040: val_loss did not improve from 0.00270
# Epoch 41/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0559 - accuracy: 0.9801 - val_loss: 0.0223 - val_accuracy: 0.9922
#
# Epoch 00041: val_loss did not improve from 0.00270
# Epoch 42/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0585 - accuracy: 0.9788 - val_loss: 0.0239 - val_accuracy: 0.9906
#
# Epoch 00042: val_loss did not improve from 0.00270
# Epoch 43/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0530 - accuracy: 0.9801 - val_loss: 0.0255 - val_accuracy: 0.9883
#
# Epoch 00043: val_loss did not improve from 0.00270
# Epoch 44/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0522 - accuracy: 0.9802 - val_loss: 0.0234 - val_accuracy: 0.9922
#
# Epoch 00044: val_loss did not improve from 0.00270
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0576 - accuracy: 0.9778 - val_loss: 0.0242 - val_accuracy: 0.9898
#
# Epoch 00045: val_loss did not improve from 0.00270
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0494 - accuracy: 0.9814 - val_loss: 0.0221 - val_accuracy: 0.9918
#
# Epoch 00046: val_loss did not improve from 0.00270
# Epoch 47/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0527 - accuracy: 0.9807 - val_loss: 0.0196 - val_accuracy: 0.9930
#
# Epoch 00047: val_loss did not improve from 0.00270
# Epoch 48/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0470 - accuracy: 0.9822 - val_loss: 0.0240 - val_accuracy: 0.9922
#
# Epoch 00048: val_loss did not improve from 0.00270
# Epoch 49/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0515 - accuracy: 0.9820 - val_loss: 0.0216 - val_accuracy: 0.9910
#
# Epoch 00049: val_loss did not improve from 0.00270
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0479 - accuracy: 0.9820 - val_loss: 0.0151 - val_accuracy: 0.9945
#
# Epoch 00050: val_loss did not improve from 0.00270
# Epoch 51/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0461 - accuracy: 0.9842 - val_loss: 0.0241 - val_accuracy: 0.9898
#
# Epoch 00051: val_loss did not improve from 0.00270
# Epoch 52/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0450 - accuracy: 0.9845 - val_loss: 0.0177 - val_accuracy: 0.9914
#
# Epoch 00052: val_loss did not improve from 0.00270
# Epoch 53/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0413 - accuracy: 0.9855 - val_loss: 0.0197 - val_accuracy: 0.9934
#
# Epoch 00053: val_loss did not improve from 0.00270
# Epoch 54/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0421 - accuracy: 0.9845 - val_loss: 0.0328 - val_accuracy: 0.9898
#
# Epoch 00054: val_loss did not improve from 0.00270
# Epoch 55/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0487 - accuracy: 0.9823 - val_loss: 0.0175 - val_accuracy: 0.9922
#
# Epoch 00055: val_loss did not improve from 0.00270
# Epoch 56/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0332 - accuracy: 0.9887 - val_loss: 0.0193 - val_accuracy: 0.9918
#
# Epoch 00056: val_loss did not improve from 0.00270
# Epoch 57/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0388 - accuracy: 0.9847 - val_loss: 0.0154 - val_accuracy: 0.9934
#
# Epoch 00057: val_loss did not improve from 0.00270
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0400 - accuracy: 0.9853 - val_loss: 0.0126 - val_accuracy: 0.9945
#
# Epoch 00058: val_loss did not improve from 0.00270
# Epoch 59/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0399 - accuracy: 0.9858 - val_loss: 0.0201 - val_accuracy: 0.9906
#
# Epoch 00059: val_loss did not improve from 0.00270
# Epoch 60/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0403 - accuracy: 0.9853 - val_loss: 0.0210 - val_accuracy: 0.9914
#
# Epoch 00060: val_loss did not improve from 0.00270
# Epoch 61/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0370 - accuracy: 0.9861 - val_loss: 0.0138 - val_accuracy: 0.9949
#
# Epoch 00061: val_loss did not improve from 0.00270
# Epoch 62/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0348 - accuracy: 0.9874 - val_loss: 0.0124 - val_accuracy: 0.9953
#
# Epoch 00062: val_loss did not improve from 0.00270
# Epoch 63/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0338 - accuracy: 0.9877 - val_loss: 0.0211 - val_accuracy: 0.9902
#
# Epoch 00063: val_loss did not improve from 0.00270
# Epoch 64/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0344 - accuracy: 0.9885 - val_loss: 0.0113 - val_accuracy: 0.9957
#
# Epoch 00064: val_loss did not improve from 0.00270
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0361 - accuracy: 0.9872 - val_loss: 0.0096 - val_accuracy: 0.9965
#
# Epoch 00065: val_loss did not improve from 0.00270
# Epoch 66/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0297 - accuracy: 0.9891 - val_loss: 0.0102 - val_accuracy: 0.9961
#
# Epoch 00066: val_loss did not improve from 0.00270
# Epoch 67/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0378 - accuracy: 0.9863 - val_loss: 0.0150 - val_accuracy: 0.9926
#
# Epoch 00067: val_loss did not improve from 0.00270
# Epoch 68/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0294 - accuracy: 0.9895 - val_loss: 0.0123 - val_accuracy: 0.9937
#
# Epoch 00068: val_loss did not improve from 0.00270
# Epoch 69/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0342 - accuracy: 0.9873 - val_loss: 0.0062 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00270
# Epoch 70/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0305 - accuracy: 0.9891 - val_loss: 0.0086 - val_accuracy: 0.9965
#
# Epoch 00070: val_loss did not improve from 0.00270
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0312 - accuracy: 0.9885 - val_loss: 0.0094 - val_accuracy: 0.9961
#
# Epoch 00071: val_loss did not improve from 0.00270
# Epoch 72/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0278 - accuracy: 0.9894 - val_loss: 0.0097 - val_accuracy: 0.9953
#
# Epoch 00072: val_loss did not improve from 0.00270
# Epoch 73/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0293 - accuracy: 0.9905 - val_loss: 0.0134 - val_accuracy: 0.9941
#
# Epoch 00073: val_loss did not improve from 0.00270
# Epoch 74/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0306 - accuracy: 0.9883 - val_loss: 0.0158 - val_accuracy: 0.9934
#
# Epoch 00074: val_loss did not improve from 0.00270
# Epoch 75/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0287 - accuracy: 0.9894 - val_loss: 0.0100 - val_accuracy: 0.9949
#
# Epoch 00075: val_loss did not improve from 0.00270
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0286 - accuracy: 0.9891 - val_loss: 0.0083 - val_accuracy: 0.9953
#
# Epoch 00076: val_loss did not improve from 0.00270
# Epoch 77/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0315 - accuracy: 0.9896 - val_loss: 0.0087 - val_accuracy: 0.9945
#
# Epoch 00077: val_loss did not improve from 0.00270
# Epoch 78/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0271 - accuracy: 0.9898 - val_loss: 0.0222 - val_accuracy: 0.9914
#
# Epoch 00078: val_loss did not improve from 0.00270
# Epoch 79/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0288 - accuracy: 0.9901 - val_loss: 0.0233 - val_accuracy: 0.9902
#
# Epoch 00079: val_loss did not improve from 0.00270
# Epoch 80/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0257 - accuracy: 0.9895 - val_loss: 0.0151 - val_accuracy: 0.9926
#
# Epoch 00080: val_loss did not improve from 0.00270
# Epoch 81/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0226 - accuracy: 0.9915 - val_loss: 0.0112 - val_accuracy: 0.9965
#
# Epoch 00081: val_loss did not improve from 0.00270
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0273 - accuracy: 0.9899 - val_loss: 0.0069 - val_accuracy: 0.9973
#
# Epoch 00082: val_loss did not improve from 0.00270
# Epoch 83/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0227 - accuracy: 0.9916 - val_loss: 0.0079 - val_accuracy: 0.9961
#
# Epoch 00083: val_loss did not improve from 0.00270
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0244 - accuracy: 0.9909 - val_loss: 0.0054 - val_accuracy: 0.9977
#
# Epoch 00084: val_loss did not improve from 0.00270
# Epoch 85/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0219 - accuracy: 0.9915 - val_loss: 0.0079 - val_accuracy: 0.9961
#
# Epoch 00085: val_loss did not improve from 0.00270
# Epoch 86/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0266 - accuracy: 0.9896 - val_loss: 0.0171 - val_accuracy: 0.9918
#
# Epoch 00086: val_loss did not improve from 0.00270
# Epoch 87/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0262 - accuracy: 0.9910 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00087: val_loss did not improve from 0.00270
# Epoch 88/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0240 - accuracy: 0.9920 - val_loss: 0.0073 - val_accuracy: 0.9965
#
# Epoch 00088: val_loss did not improve from 0.00270
# Epoch 89/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0268 - accuracy: 0.9901 - val_loss: 0.0132 - val_accuracy: 0.9941
#
# Epoch 00089: val_loss did not improve from 0.00270
# Epoch 90/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0208 - accuracy: 0.9923 - val_loss: 0.0063 - val_accuracy: 0.9969
#
# Epoch 00090: val_loss did not improve from 0.00270
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0217 - accuracy: 0.9925 - val_loss: 0.0086 - val_accuracy: 0.9973
#
# Epoch 00091: val_loss did not improve from 0.00270
# Epoch 92/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0230 - accuracy: 0.9918 - val_loss: 0.0097 - val_accuracy: 0.9965
#
# Epoch 00092: val_loss did not improve from 0.00270
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0209 - accuracy: 0.9921 - val_loss: 0.0092 - val_accuracy: 0.9965
#
# Epoch 00093: val_loss did not improve from 0.00270
# Epoch 94/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0228 - accuracy: 0.9916 - val_loss: 0.0073 - val_accuracy: 0.9965
#
# Epoch 00094: val_loss did not improve from 0.00270
# Epoch 95/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0248 - accuracy: 0.9904 - val_loss: 0.0101 - val_accuracy: 0.9949
#
# Epoch 00095: val_loss did not improve from 0.00270
# Epoch 96/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0195 - accuracy: 0.9926 - val_loss: 0.0088 - val_accuracy: 0.9957
#
# Epoch 00096: val_loss did not improve from 0.00270
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 0.0079 - val_accuracy: 0.9957
#
# Epoch 00097: val_loss did not improve from 0.00270
# Epoch 98/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0244 - accuracy: 0.9910 - val_loss: 0.0063 - val_accuracy: 0.9973
#
# Epoch 00098: val_loss did not improve from 0.00270
# Epoch 99/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.0051 - val_accuracy: 0.9969
#
# Epoch 00099: val_loss did not improve from 0.00270
# Epoch 100/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0178 - accuracy: 0.9928 - val_loss: 0.0057 - val_accuracy: 0.9973
#
# Epoch 00100: val_loss did not improve from 0.00270
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9973
# Val Score:  [0.005662008188664913, 0.997265636920929]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       1.00      0.99      1.00       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       0.99      1.00      1.00       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9981
# Test Accuracy: 99.81250166893005

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
