# %% [markdown]
# ## RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **EPOCHS 50 -- USING ADAM AND BEST RESULT OF HIDDEN LAYER(4) AND 0.001 LEARNING RATE**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_36 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_37 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_38 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_39 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_40 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_41 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.3617 - accuracy: 0.8939 - val_loss: 5.2189 - val_accuracy: 0.2598
#
# Epoch 00001: val_loss improved from inf to 5.21891, saving model to model.h5
# Epoch 2/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1328 - accuracy: 0.9569 - val_loss: 0.3081 - val_accuracy: 0.9102
#
# Epoch 00002: val_loss improved from 5.21891 to 0.30812, saving model to model.h5
# Epoch 3/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0923 - accuracy: 0.9703 - val_loss: 0.6545 - val_accuracy: 0.8570
#
# Epoch 00003: val_loss did not improve from 0.30812
# Epoch 4/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0755 - accuracy: 0.9741 - val_loss: 0.5491 - val_accuracy: 0.8574
#
# Epoch 00004: val_loss did not improve from 0.30812
# Epoch 5/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0547 - accuracy: 0.9821 - val_loss: 0.3035 - val_accuracy: 0.9035
#
# Epoch 00005: val_loss improved from 0.30812 to 0.30352, saving model to model.h5
# Epoch 6/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0561 - accuracy: 0.9810 - val_loss: 0.9192 - val_accuracy: 0.8246
#
# Epoch 00006: val_loss did not improve from 0.30352
# Epoch 7/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0485 - accuracy: 0.9838 - val_loss: 0.1081 - val_accuracy: 0.9711
#
# Epoch 00007: val_loss improved from 0.30352 to 0.10808, saving model to model.h5
# Epoch 8/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0380 - accuracy: 0.9888 - val_loss: 0.5169 - val_accuracy: 0.8613
#
# Epoch 00008: val_loss did not improve from 0.10808
# Epoch 9/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0365 - accuracy: 0.9884 - val_loss: 1.2124 - val_accuracy: 0.8082
#
# Epoch 00009: val_loss did not improve from 0.10808
# Epoch 10/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0308 - accuracy: 0.9906 - val_loss: 3.6094 - val_accuracy: 0.5133
#
# Epoch 00010: val_loss did not improve from 0.10808
# Epoch 11/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0433 - accuracy: 0.9866 - val_loss: 0.0122 - val_accuracy: 0.9957
#
# Epoch 00011: val_loss improved from 0.10808 to 0.01220, saving model to model.h5
# Epoch 12/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0417 - accuracy: 0.9880 - val_loss: 0.1077 - val_accuracy: 0.9816
#
# Epoch 00012: val_loss did not improve from 0.01220
# Epoch 13/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0408 - accuracy: 0.9871 - val_loss: 0.0146 - val_accuracy: 0.9953
#
# Epoch 00013: val_loss did not improve from 0.01220
# Epoch 14/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0301 - accuracy: 0.9909 - val_loss: 0.0335 - val_accuracy: 0.9895
#
# Epoch 00014: val_loss did not improve from 0.01220
# Epoch 15/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0270 - accuracy: 0.9919 - val_loss: 0.1833 - val_accuracy: 0.9398
#
# Epoch 00015: val_loss did not improve from 0.01220
# Epoch 16/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9936 - val_loss: 0.0796 - val_accuracy: 0.9695
#
# Epoch 00016: val_loss did not improve from 0.01220
# Epoch 17/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0320 - accuracy: 0.9905 - val_loss: 0.5682 - val_accuracy: 0.8320
#
# Epoch 00017: val_loss did not improve from 0.01220
# Epoch 18/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0193 - accuracy: 0.9927 - val_loss: 1.6512 - val_accuracy: 0.7676
#
# Epoch 00018: val_loss did not improve from 0.01220
# Epoch 19/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0264 - accuracy: 0.9912 - val_loss: 0.0383 - val_accuracy: 0.9922
#
# Epoch 00019: val_loss did not improve from 0.01220
# Epoch 20/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0238 - accuracy: 0.9924 - val_loss: 0.0256 - val_accuracy: 0.9906
#
# Epoch 00020: val_loss did not improve from 0.01220
# Epoch 21/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0123 - val_accuracy: 0.9977
#
# Epoch 00021: val_loss did not improve from 0.01220
# Epoch 22/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0250 - accuracy: 0.9925 - val_loss: 0.1671 - val_accuracy: 0.9523
#
# Epoch 00022: val_loss did not improve from 0.01220
# Epoch 23/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0265 - accuracy: 0.9926 - val_loss: 0.5595 - val_accuracy: 0.9055
#
# Epoch 00023: val_loss did not improve from 0.01220
# Epoch 24/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0210 - accuracy: 0.9933 - val_loss: 0.3859 - val_accuracy: 0.9148
#
# Epoch 00024: val_loss did not improve from 0.01220
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0215 - accuracy: 0.9932 - val_loss: 0.0075 - val_accuracy: 0.9969
#
# Epoch 00025: val_loss improved from 0.01220 to 0.00752, saving model to model.h5
# Epoch 26/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0167 - accuracy: 0.9947 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00026: val_loss improved from 0.00752 to 0.00443, saving model to model.h5
# Epoch 27/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0145 - accuracy: 0.9954 - val_loss: 0.1425 - val_accuracy: 0.9555
#
# Epoch 00027: val_loss did not improve from 0.00443
# Epoch 28/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0242 - accuracy: 0.9932 - val_loss: 0.2166 - val_accuracy: 0.9414
#
# Epoch 00028: val_loss did not improve from 0.00443
# Epoch 29/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.2436 - val_accuracy: 0.9324
#
# Epoch 00029: val_loss did not improve from 0.00443
# Epoch 30/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 1.5709 - val_accuracy: 0.7777
#
# Epoch 00030: val_loss did not improve from 0.00443
# Epoch 31/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0269 - accuracy: 0.9920 - val_loss: 0.0294 - val_accuracy: 0.9895
#
# Epoch 00031: val_loss did not improve from 0.00443
# Epoch 32/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.4247 - val_accuracy: 0.9145
#
# Epoch 00032: val_loss did not improve from 0.00443
# Epoch 33/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00033: val_loss improved from 0.00443 to 0.00265, saving model to model.h5
# Epoch 34/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0386 - val_accuracy: 0.9914
#
# Epoch 00034: val_loss did not improve from 0.00265
# Epoch 35/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0168 - accuracy: 0.9951 - val_loss: 0.0108 - val_accuracy: 0.9965
#
# Epoch 00035: val_loss did not improve from 0.00265
# Epoch 36/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 0.1591 - val_accuracy: 0.9480
#
# Epoch 00036: val_loss did not improve from 0.00265
# Epoch 37/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00037: val_loss did not improve from 0.00265
# Epoch 38/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.0262 - val_accuracy: 0.9914
#
# Epoch 00038: val_loss did not improve from 0.00265
# Epoch 39/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.0081 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00265
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0174 - accuracy: 0.9947 - val_loss: 0.2452 - val_accuracy: 0.9488
#
# Epoch 00040: val_loss did not improve from 0.00265
# Epoch 41/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 0.0199 - val_accuracy: 0.9934
#
# Epoch 00041: val_loss did not improve from 0.00265
# Epoch 42/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.4988 - val_accuracy: 0.9219
#
# Epoch 00042: val_loss did not improve from 0.00265
# Epoch 43/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0111 - accuracy: 0.9953 - val_loss: 0.0100 - val_accuracy: 0.9961
#
# Epoch 00043: val_loss did not improve from 0.00265
# Epoch 44/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0325 - val_accuracy: 0.9902
#
# Epoch 00044: val_loss did not improve from 0.00265
# Epoch 45/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0113 - accuracy: 0.9957 - val_loss: 0.0136 - val_accuracy: 0.9961
#
# Epoch 00045: val_loss did not improve from 0.00265
# Epoch 46/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.4525 - val_accuracy: 0.8973
#
# Epoch 00046: val_loss did not improve from 0.00265
# Epoch 47/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0047 - val_accuracy: 0.9984
#
# Epoch 00047: val_loss did not improve from 0.00265
# Epoch 48/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00048: val_loss did not improve from 0.00265
# Epoch 49/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9933 - val_loss: 0.1967 - val_accuracy: 0.9570
#
# Epoch 00049: val_loss did not improve from 0.00265
# Epoch 50/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00050: val_loss did not improve from 0.00265
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9973
# Val Score:  [0.0075573972426354885, 0.997265636920929]
# Training on Fold:  2
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4395 - accuracy: 0.8552 - val_loss: 2.3251 - val_accuracy: 0.4215
#
# Epoch 00001: val_loss did not improve from 0.00265
# Epoch 2/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1647 - accuracy: 0.9430 - val_loss: 0.2923 - val_accuracy: 0.8883
#
# Epoch 00002: val_loss did not improve from 0.00265
# Epoch 3/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1192 - accuracy: 0.9565 - val_loss: 2.4395 - val_accuracy: 0.5773
#
# Epoch 00003: val_loss did not improve from 0.00265
# Epoch 4/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0890 - accuracy: 0.9684 - val_loss: 0.4258 - val_accuracy: 0.8520
#
# Epoch 00004: val_loss did not improve from 0.00265
# Epoch 5/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0691 - accuracy: 0.9797 - val_loss: 0.3924 - val_accuracy: 0.9086
#
# Epoch 00005: val_loss did not improve from 0.00265
# Epoch 6/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0566 - accuracy: 0.9807 - val_loss: 0.0490 - val_accuracy: 0.9840
#
# Epoch 00006: val_loss did not improve from 0.00265
# Epoch 7/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0493 - accuracy: 0.9832 - val_loss: 0.0152 - val_accuracy: 0.9949
#
# Epoch 00007: val_loss did not improve from 0.00265
# Epoch 8/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0391 - accuracy: 0.9871 - val_loss: 0.0201 - val_accuracy: 0.9934
#
# Epoch 00008: val_loss did not improve from 0.00265
# Epoch 9/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0432 - accuracy: 0.9871 - val_loss: 0.1672 - val_accuracy: 0.9535
#
# Epoch 00009: val_loss did not improve from 0.00265
# Epoch 10/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0326 - accuracy: 0.9896 - val_loss: 0.0487 - val_accuracy: 0.9859
#
# Epoch 00010: val_loss did not improve from 0.00265
# Epoch 11/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0404 - accuracy: 0.9850 - val_loss: 0.0137 - val_accuracy: 0.9957
#
# Epoch 00011: val_loss did not improve from 0.00265
# Epoch 12/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0288 - accuracy: 0.9911 - val_loss: 0.0317 - val_accuracy: 0.9910
#
# Epoch 00012: val_loss did not improve from 0.00265
# Epoch 13/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0298 - val_accuracy: 0.9902
#
# Epoch 00013: val_loss did not improve from 0.00265
# Epoch 14/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0266 - accuracy: 0.9915 - val_loss: 0.0901 - val_accuracy: 0.9707
#
# Epoch 00014: val_loss did not improve from 0.00265
# Epoch 15/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0264 - accuracy: 0.9899 - val_loss: 0.0600 - val_accuracy: 0.9777
#
# Epoch 00015: val_loss did not improve from 0.00265
# Epoch 16/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9933 - val_loss: 0.0351 - val_accuracy: 0.9926
#
# Epoch 00016: val_loss did not improve from 0.00265
# Epoch 17/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0242 - accuracy: 0.9920 - val_loss: 0.1363 - val_accuracy: 0.9605
#
# Epoch 00017: val_loss did not improve from 0.00265
# Epoch 18/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0353 - accuracy: 0.9881 - val_loss: 0.0266 - val_accuracy: 0.9910
#
# Epoch 00018: val_loss did not improve from 0.00265
# Epoch 19/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0306 - accuracy: 0.9890 - val_loss: 0.0153 - val_accuracy: 0.9953
#
# Epoch 00019: val_loss did not improve from 0.00265
# Epoch 20/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.0262 - val_accuracy: 0.9883
#
# Epoch 00020: val_loss did not improve from 0.00265
# Epoch 21/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0155 - accuracy: 0.9941 - val_loss: 2.2595 - val_accuracy: 0.7691
#
# Epoch 00021: val_loss did not improve from 0.00265
# Epoch 22/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0253 - accuracy: 0.9910 - val_loss: 0.0180 - val_accuracy: 0.9949
#
# Epoch 00022: val_loss did not improve from 0.00265
# Epoch 23/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 0.0127 - val_accuracy: 0.9965
#
# Epoch 00023: val_loss did not improve from 0.00265
# Epoch 24/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0570 - val_accuracy: 0.9820
#
# Epoch 00024: val_loss did not improve from 0.00265
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.0075 - val_accuracy: 0.9973
#
# Epoch 00025: val_loss did not improve from 0.00265
# Epoch 26/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.0347 - val_accuracy: 0.9859
#
# Epoch 00026: val_loss did not improve from 0.00265
# Epoch 27/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0199 - accuracy: 0.9934 - val_loss: 0.0166 - val_accuracy: 0.9945
#
# Epoch 00027: val_loss did not improve from 0.00265
# Epoch 28/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0220 - accuracy: 0.9930 - val_loss: 0.0261 - val_accuracy: 0.9906
#
# Epoch 00028: val_loss did not improve from 0.00265
# Epoch 29/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.0099 - val_accuracy: 0.9965
#
# Epoch 00029: val_loss did not improve from 0.00265
# Epoch 30/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0183 - accuracy: 0.9929 - val_loss: 0.1039 - val_accuracy: 0.9762
#
# Epoch 00030: val_loss did not improve from 0.00265
# Epoch 31/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.5971 - val_accuracy: 0.8648
#
# Epoch 00031: val_loss did not improve from 0.00265
# Epoch 32/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.4650 - val_accuracy: 0.8809
#
# Epoch 00032: val_loss did not improve from 0.00265
# Epoch 33/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0176 - accuracy: 0.9936 - val_loss: 0.0277 - val_accuracy: 0.9937
#
# Epoch 00033: val_loss did not improve from 0.00265
# Epoch 34/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.0099 - val_accuracy: 0.9973
#
# Epoch 00034: val_loss did not improve from 0.00265
# Epoch 35/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0082 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00265
# Epoch 36/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.9937 - val_loss: 0.1310 - val_accuracy: 0.9621
#
# Epoch 00036: val_loss did not improve from 0.00265
# Epoch 37/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0459 - val_accuracy: 0.9852
#
# Epoch 00037: val_loss did not improve from 0.00265
# Epoch 38/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0125 - accuracy: 0.9953 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00038: val_loss did not improve from 0.00265
# Epoch 39/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0294 - val_accuracy: 0.9914
#
# Epoch 00039: val_loss did not improve from 0.00265
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 1.7531 - val_accuracy: 0.7145
#
# Epoch 00040: val_loss did not improve from 0.00265
# Epoch 41/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0811 - val_accuracy: 0.9820
#
# Epoch 00041: val_loss did not improve from 0.00265
# Epoch 42/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 0.0169 - val_accuracy: 0.9934
#
# Epoch 00042: val_loss did not improve from 0.00265
# Epoch 43/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0098 - accuracy: 0.9959 - val_loss: 0.0191 - val_accuracy: 0.9937
#
# Epoch 00043: val_loss did not improve from 0.00265
# Epoch 44/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0397 - val_accuracy: 0.9848
#
# Epoch 00044: val_loss did not improve from 0.00265
# Epoch 45/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0035 - val_accuracy: 0.9988
#
# Epoch 00045: val_loss did not improve from 0.00265
# Epoch 46/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0190 - accuracy: 0.9939 - val_loss: 0.0264 - val_accuracy: 0.9918
#
# Epoch 00046: val_loss did not improve from 0.00265
# Epoch 47/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9963 - val_loss: 0.3253 - val_accuracy: 0.9195
#
# Epoch 00047: val_loss did not improve from 0.00265
# Epoch 48/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0166 - val_accuracy: 0.9965
#
# Epoch 00048: val_loss did not improve from 0.00265
# Epoch 49/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0133 - accuracy: 0.9948 - val_loss: 0.0427 - val_accuracy: 0.9867
#
# Epoch 00049: val_loss did not improve from 0.00265
# Epoch 50/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.0188 - val_accuracy: 0.9965
#
# Epoch 00050: val_loss did not improve from 0.00265
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9965
# Val Score:  [0.01877467893064022, 0.9964843988418579]
# Training on Fold:  3
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4335 - accuracy: 0.8526 - val_loss: 6.6163 - val_accuracy: 0.4930
#
# Epoch 00001: val_loss did not improve from 0.00265
# Epoch 2/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1550 - accuracy: 0.9443 - val_loss: 0.1469 - val_accuracy: 0.9477
#
# Epoch 00002: val_loss did not improve from 0.00265
# Epoch 3/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1099 - accuracy: 0.9628 - val_loss: 0.1508 - val_accuracy: 0.9570
#
# Epoch 00003: val_loss did not improve from 0.00265
# Epoch 4/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0862 - accuracy: 0.9694 - val_loss: 0.0541 - val_accuracy: 0.9809
#
# Epoch 00004: val_loss did not improve from 0.00265
# Epoch 5/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0678 - accuracy: 0.9760 - val_loss: 0.0762 - val_accuracy: 0.9676
#
# Epoch 00005: val_loss did not improve from 0.00265
# Epoch 6/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0497 - accuracy: 0.9844 - val_loss: 0.0512 - val_accuracy: 0.9832
#
# Epoch 00006: val_loss did not improve from 0.00265
# Epoch 7/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0462 - accuracy: 0.9846 - val_loss: 0.0808 - val_accuracy: 0.9773
#
# Epoch 00007: val_loss did not improve from 0.00265
# Epoch 8/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0426 - accuracy: 0.9859 - val_loss: 0.0188 - val_accuracy: 0.9910
#
# Epoch 00008: val_loss did not improve from 0.00265
# Epoch 9/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0350 - accuracy: 0.9891 - val_loss: 0.0138 - val_accuracy: 0.9961
#
# Epoch 00009: val_loss did not improve from 0.00265
# Epoch 10/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0319 - accuracy: 0.9894 - val_loss: 0.0249 - val_accuracy: 0.9910
#
# Epoch 00010: val_loss did not improve from 0.00265
# Epoch 11/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0247 - accuracy: 0.9913 - val_loss: 0.0375 - val_accuracy: 0.9855
#
# Epoch 00011: val_loss did not improve from 0.00265
# Epoch 12/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0264 - accuracy: 0.9914 - val_loss: 0.0985 - val_accuracy: 0.9660
#
# Epoch 00012: val_loss did not improve from 0.00265
# Epoch 13/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0207 - accuracy: 0.9936 - val_loss: 0.3218 - val_accuracy: 0.9223
#
# Epoch 00013: val_loss did not improve from 0.00265
# Epoch 14/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0321 - accuracy: 0.9896 - val_loss: 0.0685 - val_accuracy: 0.9777
#
# Epoch 00014: val_loss did not improve from 0.00265
# Epoch 15/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0232 - accuracy: 0.9921 - val_loss: 0.2542 - val_accuracy: 0.9363
#
# Epoch 00015: val_loss did not improve from 0.00265
# Epoch 16/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0184 - accuracy: 0.9932 - val_loss: 0.0806 - val_accuracy: 0.9699
#
# Epoch 00016: val_loss did not improve from 0.00265
# Epoch 17/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0201 - accuracy: 0.9928 - val_loss: 0.0139 - val_accuracy: 0.9953
#
# Epoch 00017: val_loss did not improve from 0.00265
# Epoch 18/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0097 - val_accuracy: 0.9977
#
# Epoch 00018: val_loss did not improve from 0.00265
# Epoch 19/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0207 - accuracy: 0.9928 - val_loss: 0.0856 - val_accuracy: 0.9848
#
# Epoch 00019: val_loss did not improve from 0.00265
# Epoch 20/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0377 - accuracy: 0.9898 - val_loss: 0.0066 - val_accuracy: 0.9965
#
# Epoch 00020: val_loss did not improve from 0.00265
# Epoch 21/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0201 - accuracy: 0.9934 - val_loss: 0.0706 - val_accuracy: 0.9797
#
# Epoch 00021: val_loss did not improve from 0.00265
# Epoch 22/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.0097 - val_accuracy: 0.9973
#
# Epoch 00022: val_loss did not improve from 0.00265
# Epoch 23/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0138 - accuracy: 0.9952 - val_loss: 0.0172 - val_accuracy: 0.9949
#
# Epoch 00023: val_loss did not improve from 0.00265
# Epoch 24/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0180 - accuracy: 0.9951 - val_loss: 0.0382 - val_accuracy: 0.9859
#
# Epoch 00024: val_loss did not improve from 0.00265
# Epoch 25/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00025: val_loss did not improve from 0.00265
# Epoch 26/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0174 - accuracy: 0.9945 - val_loss: 0.0142 - val_accuracy: 0.9957
#
# Epoch 00026: val_loss did not improve from 0.00265
# Epoch 27/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00027: val_loss did not improve from 0.00265
# Epoch 28/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00028: val_loss did not improve from 0.00265
# Epoch 29/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.6126 - val_accuracy: 0.9191
#
# Epoch 00029: val_loss did not improve from 0.00265
# Epoch 30/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0188 - accuracy: 0.9935 - val_loss: 0.0054 - val_accuracy: 0.9980
#
# Epoch 00030: val_loss did not improve from 0.00265
# Epoch 31/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.0036 - val_accuracy: 0.9988
#
# Epoch 00031: val_loss did not improve from 0.00265
# Epoch 32/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00032: val_loss did not improve from 0.00265
# Epoch 33/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0213 - val_accuracy: 0.9945
#
# Epoch 00033: val_loss did not improve from 0.00265
# Epoch 34/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00034: val_loss did not improve from 0.00265
# Epoch 35/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0255 - accuracy: 0.9920 - val_loss: 0.0122 - val_accuracy: 0.9945
#
# Epoch 00035: val_loss did not improve from 0.00265
# Epoch 36/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.0114 - val_accuracy: 0.9969
#
# Epoch 00036: val_loss did not improve from 0.00265
# Epoch 37/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss did not improve from 0.00265
# Epoch 38/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00038: val_loss did not improve from 0.00265
# Epoch 39/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0266 - val_accuracy: 0.9914
#
# Epoch 00039: val_loss did not improve from 0.00265
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9950 - val_loss: 0.2809 - val_accuracy: 0.9293
#
# Epoch 00040: val_loss did not improve from 0.00265
# Epoch 41/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0124 - accuracy: 0.9954 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00041: val_loss did not improve from 0.00265
# Epoch 42/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00042: val_loss improved from 0.00265 to 0.00239, saving model to model.h5
# Epoch 43/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 6.2698 - val_accuracy: 0.4652
#
# Epoch 00043: val_loss did not improve from 0.00239
# Epoch 44/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.0208 - val_accuracy: 0.9914
#
# Epoch 00044: val_loss did not improve from 0.00239
# Epoch 45/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0238 - val_accuracy: 0.9914
#
# Epoch 00045: val_loss did not improve from 0.00239
# Epoch 46/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00046: val_loss improved from 0.00239 to 0.00222, saving model to model.h5
# Epoch 47/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0842 - val_accuracy: 0.9676
#
# Epoch 00047: val_loss did not improve from 0.00222
# Epoch 48/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.0077 - val_accuracy: 0.9961
#
# Epoch 00048: val_loss did not improve from 0.00222
# Epoch 49/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00049: val_loss did not improve from 0.00222
# Epoch 50/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0204 - val_accuracy: 0.9930
#
# Epoch 00050: val_loss did not improve from 0.00222
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9930
# Val Score:  [0.020447075366973877, 0.992968738079071]
# Training on Fold:  4
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.3552 - accuracy: 0.8856 - val_loss: 3.4674 - val_accuracy: 0.5418
#
# Epoch 00001: val_loss did not improve from 0.00222
# Epoch 2/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1100 - accuracy: 0.9601 - val_loss: 0.1051 - val_accuracy: 0.9563
#
# Epoch 00002: val_loss did not improve from 0.00222
# Epoch 3/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0778 - accuracy: 0.9730 - val_loss: 0.0879 - val_accuracy: 0.9652
#
# Epoch 00003: val_loss did not improve from 0.00222
# Epoch 4/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0670 - accuracy: 0.9770 - val_loss: 0.0615 - val_accuracy: 0.9770
#
# Epoch 00004: val_loss did not improve from 0.00222
# Epoch 5/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0443 - accuracy: 0.9842 - val_loss: 0.0310 - val_accuracy: 0.9887
#
# Epoch 00005: val_loss did not improve from 0.00222
# Epoch 6/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0319 - accuracy: 0.9888 - val_loss: 0.0539 - val_accuracy: 0.9871
#
# Epoch 00006: val_loss did not improve from 0.00222
# Epoch 7/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.0631 - val_accuracy: 0.9793
#
# Epoch 00007: val_loss did not improve from 0.00222
# Epoch 8/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0327 - accuracy: 0.9889 - val_loss: 0.3709 - val_accuracy: 0.9016
#
# Epoch 00008: val_loss did not improve from 0.00222
# Epoch 9/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0241 - accuracy: 0.9911 - val_loss: 0.2285 - val_accuracy: 0.9305
#
# Epoch 00009: val_loss did not improve from 0.00222
# Epoch 10/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.0070 - val_accuracy: 0.9977
#
# Epoch 00010: val_loss did not improve from 0.00222
# Epoch 11/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0499 - val_accuracy: 0.9828
#
# Epoch 00011: val_loss did not improve from 0.00222
# Epoch 12/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.2976 - val_accuracy: 0.9074
#
# Epoch 00012: val_loss did not improve from 0.00222
# Epoch 13/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0308 - accuracy: 0.9900 - val_loss: 0.0373 - val_accuracy: 0.9879
#
# Epoch 00013: val_loss did not improve from 0.00222
# Epoch 14/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.0256 - val_accuracy: 0.9918
#
# Epoch 00014: val_loss did not improve from 0.00222
# Epoch 15/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0155 - accuracy: 0.9939 - val_loss: 0.0531 - val_accuracy: 0.9855
#
# Epoch 00015: val_loss did not improve from 0.00222
# Epoch 16/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.0915 - val_accuracy: 0.9711
#
# Epoch 00016: val_loss did not improve from 0.00222
# Epoch 17/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0227 - accuracy: 0.9927 - val_loss: 0.1043 - val_accuracy: 0.9676
#
# Epoch 00017: val_loss did not improve from 0.00222
# Epoch 18/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0119 - accuracy: 0.9952 - val_loss: 0.0467 - val_accuracy: 0.9840
#
# Epoch 00018: val_loss did not improve from 0.00222
# Epoch 19/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0060 - val_accuracy: 0.9969
#
# Epoch 00019: val_loss did not improve from 0.00222
# Epoch 20/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0159 - accuracy: 0.9945 - val_loss: 0.0143 - val_accuracy: 0.9949
#
# Epoch 00020: val_loss did not improve from 0.00222
# Epoch 21/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0227 - accuracy: 0.9924 - val_loss: 0.1448 - val_accuracy: 0.9625
#
# Epoch 00021: val_loss did not improve from 0.00222
# Epoch 22/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.0103 - val_accuracy: 0.9965
#
# Epoch 00022: val_loss did not improve from 0.00222
# Epoch 23/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.0074 - val_accuracy: 0.9973
#
# Epoch 00023: val_loss did not improve from 0.00222
# Epoch 24/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9957 - val_loss: 0.0093 - val_accuracy: 0.9977
#
# Epoch 00024: val_loss did not improve from 0.00222
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9947 - val_loss: 0.0080 - val_accuracy: 0.9977
#
# Epoch 00025: val_loss did not improve from 0.00222
# Epoch 26/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9961 - val_loss: 0.0122 - val_accuracy: 0.9949
#
# Epoch 00026: val_loss did not improve from 0.00222
# Epoch 27/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0105 - accuracy: 0.9957 - val_loss: 0.0143 - val_accuracy: 0.9953
#
# Epoch 00027: val_loss did not improve from 0.00222
# Epoch 28/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0155 - accuracy: 0.9954 - val_loss: 0.0317 - val_accuracy: 0.9914
#
# Epoch 00028: val_loss did not improve from 0.00222
# Epoch 29/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.0103 - val_accuracy: 0.9957
#
# Epoch 00029: val_loss did not improve from 0.00222
# Epoch 30/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00030: val_loss did not improve from 0.00222
# Epoch 31/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0186 - accuracy: 0.9942 - val_loss: 0.0184 - val_accuracy: 0.9937
#
# Epoch 00031: val_loss did not improve from 0.00222
# Epoch 32/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.2354 - val_accuracy: 0.9324
#
# Epoch 00032: val_loss did not improve from 0.00222
# Epoch 33/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0053 - val_accuracy: 0.9977
#
# Epoch 00033: val_loss did not improve from 0.00222
# Epoch 34/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0045 - val_accuracy: 0.9984
#
# Epoch 00034: val_loss did not improve from 0.00222
# Epoch 35/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9969 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00035: val_loss did not improve from 0.00222
# Epoch 36/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0143 - accuracy: 0.9941 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00036: val_loss did not improve from 0.00222
# Epoch 37/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.0052 - val_accuracy: 0.9977
#
# Epoch 00037: val_loss did not improve from 0.00222
# Epoch 38/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00038: val_loss did not improve from 0.00222
# Epoch 39/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00039: val_loss did not improve from 0.00222
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9962 - val_loss: 0.0057 - val_accuracy: 0.9973
#
# Epoch 00040: val_loss did not improve from 0.00222
# Epoch 41/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0217 - accuracy: 0.9930 - val_loss: 0.0427 - val_accuracy: 0.9855
#
# Epoch 00041: val_loss did not improve from 0.00222
# Epoch 42/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.0136 - val_accuracy: 0.9949
#
# Epoch 00042: val_loss did not improve from 0.00222
# Epoch 43/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1040 - val_accuracy: 0.9734
#
# Epoch 00043: val_loss did not improve from 0.00222
# Epoch 44/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0091 - val_accuracy: 0.9965
#
# Epoch 00044: val_loss did not improve from 0.00222
# Epoch 45/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 0.0066 - val_accuracy: 0.9980
#
# Epoch 00045: val_loss did not improve from 0.00222
# Epoch 46/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0076 - accuracy: 0.9968 - val_loss: 0.0036 - val_accuracy: 0.9977
#
# Epoch 00046: val_loss did not improve from 0.00222
# Epoch 47/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.1128 - val_accuracy: 0.9668
#
# Epoch 00047: val_loss did not improve from 0.00222
# Epoch 48/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9969 - val_loss: 0.0565 - val_accuracy: 0.9855
#
# Epoch 00048: val_loss did not improve from 0.00222
# Epoch 49/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00049: val_loss did not improve from 0.00222
# Epoch 50/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0127 - accuracy: 0.9953 - val_loss: 0.0464 - val_accuracy: 0.9883
#
# Epoch 00050: val_loss did not improve from 0.00222
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0464 - accuracy: 0.9883
# Val Score:  [0.0464344248175621, 0.98828125]
# Training on Fold:  5
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4040 - accuracy: 0.8665 - val_loss: 3.8778 - val_accuracy: 0.4742
#
# Epoch 00001: val_loss did not improve from 0.00222
# Epoch 2/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1612 - accuracy: 0.9441 - val_loss: 0.3976 - val_accuracy: 0.8766
#
# Epoch 00002: val_loss did not improve from 0.00222
# Epoch 3/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0910 - accuracy: 0.9672 - val_loss: 0.1769 - val_accuracy: 0.9484
#
# Epoch 00003: val_loss did not improve from 0.00222
# Epoch 4/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0683 - accuracy: 0.9777 - val_loss: 0.0469 - val_accuracy: 0.9828
#
# Epoch 00004: val_loss did not improve from 0.00222
# Epoch 5/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0473 - accuracy: 0.9826 - val_loss: 0.0479 - val_accuracy: 0.9852
#
# Epoch 00005: val_loss did not improve from 0.00222
# Epoch 6/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0455 - accuracy: 0.9852 - val_loss: 0.0902 - val_accuracy: 0.9676
#
# Epoch 00006: val_loss did not improve from 0.00222
# Epoch 7/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0451 - accuracy: 0.9842 - val_loss: 0.0358 - val_accuracy: 0.9898
#
# Epoch 00007: val_loss did not improve from 0.00222
# Epoch 8/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0249 - accuracy: 0.9923 - val_loss: 0.0571 - val_accuracy: 0.9844
#
# Epoch 00008: val_loss did not improve from 0.00222
# Epoch 9/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0344 - accuracy: 0.9884 - val_loss: 0.2207 - val_accuracy: 0.9348
#
# Epoch 00009: val_loss did not improve from 0.00222
# Epoch 10/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9929 - val_loss: 0.1081 - val_accuracy: 0.9652
#
# Epoch 00010: val_loss did not improve from 0.00222
# Epoch 11/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0284 - accuracy: 0.9900 - val_loss: 0.0201 - val_accuracy: 0.9934
#
# Epoch 00011: val_loss did not improve from 0.00222
# Epoch 12/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0255 - accuracy: 0.9910 - val_loss: 0.0233 - val_accuracy: 0.9910
#
# Epoch 00012: val_loss did not improve from 0.00222
# Epoch 13/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.0856 - val_accuracy: 0.9707
#
# Epoch 00013: val_loss did not improve from 0.00222
# Epoch 14/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0276 - accuracy: 0.9913 - val_loss: 0.0203 - val_accuracy: 0.9914
#
# Epoch 00014: val_loss did not improve from 0.00222
# Epoch 15/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0188 - accuracy: 0.9936 - val_loss: 0.2498 - val_accuracy: 0.9312
#
# Epoch 00015: val_loss did not improve from 0.00222
# Epoch 16/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0237 - accuracy: 0.9921 - val_loss: 0.0460 - val_accuracy: 0.9891
#
# Epoch 00016: val_loss did not improve from 0.00222
# Epoch 17/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.0437 - val_accuracy: 0.9891
#
# Epoch 00017: val_loss did not improve from 0.00222
# Epoch 18/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0168 - accuracy: 0.9937 - val_loss: 0.1826 - val_accuracy: 0.9449
#
# Epoch 00018: val_loss did not improve from 0.00222
# Epoch 19/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0172 - accuracy: 0.9937 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00019: val_loss did not improve from 0.00222
# Epoch 20/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0216 - accuracy: 0.9927 - val_loss: 0.8502 - val_accuracy: 0.8453
#
# Epoch 00020: val_loss did not improve from 0.00222
# Epoch 21/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0217 - accuracy: 0.9924 - val_loss: 0.0196 - val_accuracy: 0.9945
#
# Epoch 00021: val_loss did not improve from 0.00222
# Epoch 22/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.1513 - val_accuracy: 0.9527
#
# Epoch 00022: val_loss did not improve from 0.00222
# Epoch 23/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0070 - val_accuracy: 0.9973
#
# Epoch 00023: val_loss did not improve from 0.00222
# Epoch 24/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 0.0206 - val_accuracy: 0.9961
#
# Epoch 00024: val_loss did not improve from 0.00222
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.0113 - val_accuracy: 0.9945
#
# Epoch 00025: val_loss did not improve from 0.00222
# Epoch 26/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.0221 - val_accuracy: 0.9918
#
# Epoch 00026: val_loss did not improve from 0.00222
# Epoch 27/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.0115 - val_accuracy: 0.9973
#
# Epoch 00027: val_loss did not improve from 0.00222
# Epoch 28/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.0889 - val_accuracy: 0.9793
#
# Epoch 00028: val_loss did not improve from 0.00222
# Epoch 29/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0120 - accuracy: 0.9956 - val_loss: 0.0228 - val_accuracy: 0.9922
#
# Epoch 00029: val_loss did not improve from 0.00222
# Epoch 30/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0137 - accuracy: 0.9947 - val_loss: 0.0599 - val_accuracy: 0.9824
#
# Epoch 00030: val_loss did not improve from 0.00222
# Epoch 31/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0245 - accuracy: 0.9928 - val_loss: 0.0162 - val_accuracy: 0.9957
#
# Epoch 00031: val_loss did not improve from 0.00222
# Epoch 32/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0090 - val_accuracy: 0.9961
#
# Epoch 00032: val_loss did not improve from 0.00222
# Epoch 33/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0171 - accuracy: 0.9943 - val_loss: 0.0229 - val_accuracy: 0.9941
#
# Epoch 00033: val_loss did not improve from 0.00222
# Epoch 34/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0122 - accuracy: 0.9952 - val_loss: 0.0111 - val_accuracy: 0.9965
#
# Epoch 00034: val_loss did not improve from 0.00222
# Epoch 35/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0116 - accuracy: 0.9960 - val_loss: 0.0137 - val_accuracy: 0.9953
#
# Epoch 00035: val_loss did not improve from 0.00222
# Epoch 36/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.1202 - val_accuracy: 0.9902
#
# Epoch 00036: val_loss did not improve from 0.00222
# Epoch 37/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 0.0141 - val_accuracy: 0.9945
#
# Epoch 00037: val_loss did not improve from 0.00222
# Epoch 38/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 0.0382 - val_accuracy: 0.9895
#
# Epoch 00038: val_loss did not improve from 0.00222
# Epoch 39/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00039: val_loss did not improve from 0.00222
# Epoch 40/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 0.0212 - val_accuracy: 0.9930
#
# Epoch 00040: val_loss did not improve from 0.00222
# Epoch 41/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9957 - val_loss: 0.0128 - val_accuracy: 0.9945
#
# Epoch 00041: val_loss did not improve from 0.00222
# Epoch 42/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.0112 - val_accuracy: 0.9961
#
# Epoch 00042: val_loss did not improve from 0.00222
# Epoch 43/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9960 - val_loss: 0.0198 - val_accuracy: 0.9953
#
# Epoch 00043: val_loss did not improve from 0.00222
# Epoch 44/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.0118 - val_accuracy: 0.9957
#
# Epoch 00044: val_loss did not improve from 0.00222
# Epoch 45/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 0.0028 - val_accuracy: 0.9980
#
# Epoch 00045: val_loss did not improve from 0.00222
# Epoch 46/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9970 - val_loss: 0.0094 - val_accuracy: 0.9977
#
# Epoch 00046: val_loss did not improve from 0.00222
# Epoch 47/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0141 - accuracy: 0.9946 - val_loss: 0.0059 - val_accuracy: 0.9973
#
# Epoch 00047: val_loss did not improve from 0.00222
# Epoch 48/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.1103 - val_accuracy: 0.9734
#
# Epoch 00048: val_loss did not improve from 0.00222
# Epoch 49/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 0.0113 - val_accuracy: 0.9957
#
# Epoch 00049: val_loss did not improve from 0.00222
# Epoch 50/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0090 - accuracy: 0.9967 - val_loss: 0.0050 - val_accuracy: 0.9984
#
# Epoch 00050: val_loss did not improve from 0.00222
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9984
# Val Score:  [0.004981671459972858, 0.9984375238418579]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       1.00      1.00      1.00       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      1.00      1.00       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9987
# Test Accuracy: 99.87499713897705

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
