# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 75
INIT_LR = 1e-4
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_120 (Conv2D)          (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_180 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_150 (Bat (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_181 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_151 (Bat (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_182 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_152 (Bat (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_183 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_153 (Bat (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_60 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_184 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_154 (Bat (None, 1024)              4096
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_61 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_185 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/75
# 320/320 [==============================] - 4s 9ms/step - loss: 0.5326 - accuracy: 0.8221 - val_loss: 2.9224 - val_accuracy: 0.4902
#
# Epoch 00001: val_loss improved from inf to 2.92236, saving model to model.h5
# Epoch 2/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2487 - accuracy: 0.9102 - val_loss: 0.5745 - val_accuracy: 0.8121
#
# Epoch 00002: val_loss improved from 2.92236 to 0.57446, saving model to model.h5
# Epoch 3/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1806 - accuracy: 0.9343 - val_loss: 0.9453 - val_accuracy: 0.7711
#
# Epoch 00003: val_loss did not improve from 0.57446
# Epoch 4/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1241 - accuracy: 0.9561 - val_loss: 0.8842 - val_accuracy: 0.8039
#
# Epoch 00004: val_loss did not improve from 0.57446
# Epoch 5/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1098 - accuracy: 0.9598 - val_loss: 0.4054 - val_accuracy: 0.8898
#
# Epoch 00005: val_loss improved from 0.57446 to 0.40545, saving model to model.h5
# Epoch 6/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0816 - accuracy: 0.9720 - val_loss: 0.2828 - val_accuracy: 0.9219
#
# Epoch 00006: val_loss improved from 0.40545 to 0.28280, saving model to model.h5
# Epoch 7/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0665 - accuracy: 0.9767 - val_loss: 0.4232 - val_accuracy: 0.8914
#
# Epoch 00007: val_loss did not improve from 0.28280
# Epoch 8/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0628 - accuracy: 0.9798 - val_loss: 0.4635 - val_accuracy: 0.8863
#
# Epoch 00008: val_loss did not improve from 0.28280
# Epoch 9/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0593 - accuracy: 0.9818 - val_loss: 0.5287 - val_accuracy: 0.8813
#
# Epoch 00009: val_loss did not improve from 0.28280
# Epoch 10/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0600 - accuracy: 0.9810 - val_loss: 0.3526 - val_accuracy: 0.9020
#
# Epoch 00010: val_loss did not improve from 0.28280
# Epoch 11/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0476 - accuracy: 0.9829 - val_loss: 0.1680 - val_accuracy: 0.9461
#
# Epoch 00011: val_loss improved from 0.28280 to 0.16800, saving model to model.h5
# Epoch 12/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0454 - accuracy: 0.9839 - val_loss: 0.2053 - val_accuracy: 0.9367
#
# Epoch 00012: val_loss did not improve from 0.16800
# Epoch 13/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0297 - accuracy: 0.9893 - val_loss: 0.2339 - val_accuracy: 0.9391
#
# Epoch 00013: val_loss did not improve from 0.16800
# Epoch 14/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0315 - accuracy: 0.9888 - val_loss: 0.3089 - val_accuracy: 0.9238
#
# Epoch 00014: val_loss did not improve from 0.16800
# Epoch 15/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0341 - accuracy: 0.9887 - val_loss: 0.1172 - val_accuracy: 0.9660
#
# Epoch 00015: val_loss improved from 0.16800 to 0.11724, saving model to model.h5
# Epoch 16/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.1313 - val_accuracy: 0.9609
#
# Epoch 00016: val_loss did not improve from 0.11724
# Epoch 17/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0255 - accuracy: 0.9917 - val_loss: 0.0784 - val_accuracy: 0.9762
#
# Epoch 00017: val_loss improved from 0.11724 to 0.07843, saving model to model.h5
# Epoch 18/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0277 - accuracy: 0.9897 - val_loss: 0.4164 - val_accuracy: 0.9020
#
# Epoch 00018: val_loss did not improve from 0.07843
# Epoch 19/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0275 - accuracy: 0.9907 - val_loss: 0.0818 - val_accuracy: 0.9762
#
# Epoch 00019: val_loss did not improve from 0.07843
# Epoch 20/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.2117 - val_accuracy: 0.9457
#
# Epoch 00020: val_loss did not improve from 0.07843
# Epoch 21/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.0543 - val_accuracy: 0.9828
#
# Epoch 00021: val_loss improved from 0.07843 to 0.05432, saving model to model.h5
# Epoch 22/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0206 - accuracy: 0.9923 - val_loss: 0.0681 - val_accuracy: 0.9781
#
# Epoch 00022: val_loss did not improve from 0.05432
# Epoch 23/75
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.0643 - val_accuracy: 0.9816
#
# Epoch 00023: val_loss did not improve from 0.05432
# Epoch 24/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0218 - accuracy: 0.9930 - val_loss: 0.0308 - val_accuracy: 0.9910
#
# Epoch 00024: val_loss improved from 0.05432 to 0.03078, saving model to model.h5
# Epoch 25/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.0451 - val_accuracy: 0.9824
#
# Epoch 00025: val_loss did not improve from 0.03078
# Epoch 26/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0162 - accuracy: 0.9942 - val_loss: 0.0447 - val_accuracy: 0.9875
#
# Epoch 00026: val_loss did not improve from 0.03078
# Epoch 27/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0144 - accuracy: 0.9952 - val_loss: 0.0733 - val_accuracy: 0.9785
#
# Epoch 00027: val_loss did not improve from 0.03078
# Epoch 28/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.0459 - val_accuracy: 0.9852
#
# Epoch 00028: val_loss did not improve from 0.03078
# Epoch 29/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0466 - val_accuracy: 0.9887
#
# Epoch 00029: val_loss did not improve from 0.03078
# Epoch 30/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.0266 - val_accuracy: 0.9918
#
# Epoch 00030: val_loss improved from 0.03078 to 0.02661, saving model to model.h5
# Epoch 31/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0188 - val_accuracy: 0.9945
#
# Epoch 00031: val_loss improved from 0.02661 to 0.01877, saving model to model.h5
# Epoch 32/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.0426 - val_accuracy: 0.9887
#
# Epoch 00032: val_loss did not improve from 0.01877
# Epoch 33/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0148 - accuracy: 0.9942 - val_loss: 0.0103 - val_accuracy: 0.9969
#
# Epoch 00033: val_loss improved from 0.01877 to 0.01032, saving model to model.h5
# Epoch 34/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0128 - accuracy: 0.9945 - val_loss: 0.0415 - val_accuracy: 0.9875
#
# Epoch 00034: val_loss did not improve from 0.01032
# Epoch 35/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0433 - val_accuracy: 0.9871
#
# Epoch 00035: val_loss did not improve from 0.01032
# Epoch 36/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0129 - accuracy: 0.9944 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00036: val_loss improved from 0.01032 to 0.00818, saving model to model.h5
# Epoch 37/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 0.0456 - val_accuracy: 0.9855
#
# Epoch 00037: val_loss did not improve from 0.00818
# Epoch 38/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0132 - accuracy: 0.9952 - val_loss: 0.0474 - val_accuracy: 0.9844
#
# Epoch 00038: val_loss did not improve from 0.00818
# Epoch 39/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0327 - val_accuracy: 0.9895
#
# Epoch 00039: val_loss did not improve from 0.00818
# Epoch 40/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0104 - accuracy: 0.9958 - val_loss: 0.1524 - val_accuracy: 0.9633
#
# Epoch 00040: val_loss did not improve from 0.00818
# Epoch 41/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.0234 - val_accuracy: 0.9898
#
# Epoch 00041: val_loss did not improve from 0.00818
# Epoch 42/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 0.0139 - val_accuracy: 0.9961
#
# Epoch 00042: val_loss did not improve from 0.00818
# Epoch 43/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00043: val_loss improved from 0.00818 to 0.00603, saving model to model.h5
# Epoch 44/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0098 - accuracy: 0.9959 - val_loss: 0.0193 - val_accuracy: 0.9934
#
# Epoch 00044: val_loss did not improve from 0.00603
# Epoch 45/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0129 - val_accuracy: 0.9961
#
# Epoch 00045: val_loss did not improve from 0.00603
# Epoch 46/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9952 - val_loss: 0.0249 - val_accuracy: 0.9941
#
# Epoch 00046: val_loss did not improve from 0.00603
# Epoch 47/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.0159 - val_accuracy: 0.9957
#
# Epoch 00047: val_loss did not improve from 0.00603
# Epoch 48/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0169 - val_accuracy: 0.9945
#
# Epoch 00048: val_loss did not improve from 0.00603
# Epoch 49/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0174 - val_accuracy: 0.9953
#
# Epoch 00049: val_loss did not improve from 0.00603
# Epoch 50/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0108 - accuracy: 0.9957 - val_loss: 0.0123 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00603
# Epoch 51/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0106 - val_accuracy: 0.9973
#
# Epoch 00051: val_loss did not improve from 0.00603
# Epoch 52/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0054 - val_accuracy: 0.9973
#
# Epoch 00052: val_loss improved from 0.00603 to 0.00537, saving model to model.h5
# Epoch 53/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.0646 - val_accuracy: 0.9863
#
# Epoch 00053: val_loss did not improve from 0.00537
# Epoch 54/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0192 - val_accuracy: 0.9957
#
# Epoch 00054: val_loss did not improve from 0.00537
# Epoch 55/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0130 - accuracy: 0.9944 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00055: val_loss improved from 0.00537 to 0.00277, saving model to model.h5
# Epoch 56/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.0978 - val_accuracy: 0.9797
#
# Epoch 00056: val_loss did not improve from 0.00277
# Epoch 57/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 0.0131 - val_accuracy: 0.9945
#
# Epoch 00057: val_loss did not improve from 0.00277
# Epoch 58/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0086 - accuracy: 0.9967 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00058: val_loss did not improve from 0.00277
# Epoch 59/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9965 - val_loss: 0.0187 - val_accuracy: 0.9945
#
# Epoch 00059: val_loss did not improve from 0.00277
# Epoch 60/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.1174 - val_accuracy: 0.9730
#
# Epoch 00060: val_loss did not improve from 0.00277
# Epoch 61/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9966 - val_loss: 0.0115 - val_accuracy: 0.9965
#
# Epoch 00061: val_loss did not improve from 0.00277
# Epoch 62/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.0272 - val_accuracy: 0.9922
#
# Epoch 00062: val_loss did not improve from 0.00277
# Epoch 63/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.0188 - val_accuracy: 0.9953
#
# Epoch 00063: val_loss did not improve from 0.00277
# Epoch 64/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0377 - val_accuracy: 0.9902
#
# Epoch 00064: val_loss did not improve from 0.00277
# Epoch 65/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.1713 - val_accuracy: 0.9605
#
# Epoch 00065: val_loss did not improve from 0.00277
# Epoch 66/75
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0064 - accuracy: 0.9970 - val_loss: 0.0181 - val_accuracy: 0.9957
#
# Epoch 00066: val_loss did not improve from 0.00277
# Epoch 67/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9975 - val_loss: 0.0152 - val_accuracy: 0.9973
#
# Epoch 00067: val_loss did not improve from 0.00277
# Epoch 68/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9956 - val_loss: 0.0144 - val_accuracy: 0.9961
#
# Epoch 00068: val_loss did not improve from 0.00277
# Epoch 69/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0253 - val_accuracy: 0.9961
#
# Epoch 00069: val_loss did not improve from 0.00277
# Epoch 70/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0093 - accuracy: 0.9964 - val_loss: 0.0194 - val_accuracy: 0.9934
#
# Epoch 00070: val_loss did not improve from 0.00277
# Epoch 71/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9967 - val_loss: 0.0057 - val_accuracy: 0.9969
#
# Epoch 00071: val_loss did not improve from 0.00277
# Epoch 72/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9972 - val_loss: 0.0130 - val_accuracy: 0.9961
#
# Epoch 00072: val_loss did not improve from 0.00277
# Epoch 73/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0070 - accuracy: 0.9969 - val_loss: 0.0101 - val_accuracy: 0.9965
#
# Epoch 00073: val_loss did not improve from 0.00277
# Epoch 74/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00074: val_loss did not improve from 0.00277
# Epoch 75/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0079 - accuracy: 0.9968 - val_loss: 0.0348 - val_accuracy: 0.9914
#
# Epoch 00075: val_loss did not improve from 0.00277
# 80/80 [==============================] - 1s 6ms/step - loss: 0.0348 - accuracy: 0.9914
# Val Score:  [0.03475366160273552, 0.991406261920929]
# Training on Fold:  2
# Epoch 1/75
# 320/320 [==============================] - 4s 9ms/step - loss: 0.3843 - accuracy: 0.8792 - val_loss: 5.7224 - val_accuracy: 0.3395
#
# Epoch 00001: val_loss did not improve from 0.00277
# Epoch 2/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1489 - accuracy: 0.9514 - val_loss: 1.2783 - val_accuracy: 0.7105
#
# Epoch 00002: val_loss did not improve from 0.00277
# Epoch 3/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0982 - accuracy: 0.9671 - val_loss: 0.4973 - val_accuracy: 0.8664
#
# Epoch 00003: val_loss did not improve from 0.00277
# Epoch 4/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0822 - accuracy: 0.9726 - val_loss: 0.1831 - val_accuracy: 0.9574
#
# Epoch 00004: val_loss did not improve from 0.00277
# Epoch 5/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0624 - accuracy: 0.9801 - val_loss: 0.7397 - val_accuracy: 0.8344
#
# Epoch 00005: val_loss did not improve from 0.00277
# Epoch 6/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0587 - accuracy: 0.9810 - val_loss: 0.0747 - val_accuracy: 0.9828
#
# Epoch 00006: val_loss did not improve from 0.00277
# Epoch 7/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0486 - accuracy: 0.9847 - val_loss: 0.4208 - val_accuracy: 0.9180
#
# Epoch 00007: val_loss did not improve from 0.00277
# Epoch 8/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0504 - accuracy: 0.9855 - val_loss: 0.2754 - val_accuracy: 0.9418
#
# Epoch 00008: val_loss did not improve from 0.00277
# Epoch 9/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0414 - accuracy: 0.9867 - val_loss: 0.0637 - val_accuracy: 0.9805
#
# Epoch 00009: val_loss did not improve from 0.00277
# Epoch 10/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0341 - accuracy: 0.9896 - val_loss: 0.1393 - val_accuracy: 0.9609
#
# Epoch 00010: val_loss did not improve from 0.00277
# Epoch 11/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0358 - accuracy: 0.9893 - val_loss: 0.1009 - val_accuracy: 0.9730
#
# Epoch 00011: val_loss did not improve from 0.00277
# Epoch 12/75
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 0.3367 - val_accuracy: 0.9262
#
# Epoch 00012: val_loss did not improve from 0.00277
# Epoch 13/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0340 - accuracy: 0.9912 - val_loss: 0.2670 - val_accuracy: 0.9395
#
# Epoch 00013: val_loss did not improve from 0.00277
# Epoch 14/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0238 - accuracy: 0.9935 - val_loss: 0.2260 - val_accuracy: 0.9367
#
# Epoch 00014: val_loss did not improve from 0.00277
# Epoch 15/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0271 - accuracy: 0.9913 - val_loss: 0.0734 - val_accuracy: 0.9797
#
# Epoch 00015: val_loss did not improve from 0.00277
# Epoch 16/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0282 - accuracy: 0.9912 - val_loss: 0.0495 - val_accuracy: 0.9867
#
# Epoch 00016: val_loss did not improve from 0.00277
# Epoch 17/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0210 - accuracy: 0.9933 - val_loss: 0.0906 - val_accuracy: 0.9738
#
# Epoch 00017: val_loss did not improve from 0.00277
# Epoch 18/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0770 - val_accuracy: 0.9746
#
# Epoch 00018: val_loss did not improve from 0.00277
# Epoch 19/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0202 - accuracy: 0.9946 - val_loss: 0.0605 - val_accuracy: 0.9828
#
# Epoch 00019: val_loss did not improve from 0.00277
# Epoch 20/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0194 - accuracy: 0.9939 - val_loss: 0.1156 - val_accuracy: 0.9656
#
# Epoch 00020: val_loss did not improve from 0.00277
# Epoch 21/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0221 - accuracy: 0.9949 - val_loss: 0.0434 - val_accuracy: 0.9887
#
# Epoch 00021: val_loss did not improve from 0.00277
# Epoch 22/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 0.0485 - val_accuracy: 0.9875
#
# Epoch 00022: val_loss did not improve from 0.00277
# Epoch 23/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 0.0226 - val_accuracy: 0.9930
#
# Epoch 00023: val_loss did not improve from 0.00277
# Epoch 24/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0166 - accuracy: 0.9939 - val_loss: 0.0452 - val_accuracy: 0.9898
#
# Epoch 00024: val_loss did not improve from 0.00277
# Epoch 25/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.1900 - val_accuracy: 0.9543
#
# Epoch 00025: val_loss did not improve from 0.00277
# Epoch 26/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0187 - accuracy: 0.9946 - val_loss: 0.0897 - val_accuracy: 0.9859
#
# Epoch 00026: val_loss did not improve from 0.00277
# Epoch 27/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9952 - val_loss: 0.0290 - val_accuracy: 0.9910
#
# Epoch 00027: val_loss did not improve from 0.00277
# Epoch 28/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.1575 - val_accuracy: 0.9625
#
# Epoch 00028: val_loss did not improve from 0.00277
# Epoch 29/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9949 - val_loss: 0.2145 - val_accuracy: 0.9551
#
# Epoch 00029: val_loss did not improve from 0.00277
# Epoch 30/75
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.0214 - val_accuracy: 0.9930
#
# Epoch 00030: val_loss did not improve from 0.00277
# Epoch 31/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9956 - val_loss: 0.0172 - val_accuracy: 0.9953
#
# Epoch 00031: val_loss did not improve from 0.00277
# Epoch 32/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9951 - val_loss: 0.0788 - val_accuracy: 0.9805
#
# Epoch 00032: val_loss did not improve from 0.00277
# Epoch 33/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9964 - val_loss: 0.0424 - val_accuracy: 0.9906
#
# Epoch 00033: val_loss did not improve from 0.00277
# Epoch 34/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 0.0671 - val_accuracy: 0.9855
#
# Epoch 00034: val_loss did not improve from 0.00277
# Epoch 35/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 0.1233 - val_accuracy: 0.9703
#
# Epoch 00035: val_loss did not improve from 0.00277
# Epoch 36/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.0178 - val_accuracy: 0.9953
#
# Epoch 00036: val_loss did not improve from 0.00277
# Epoch 37/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0131 - accuracy: 0.9944 - val_loss: 0.0690 - val_accuracy: 0.9871
#
# Epoch 00037: val_loss did not improve from 0.00277
# Epoch 38/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0352 - val_accuracy: 0.9895
#
# Epoch 00038: val_loss did not improve from 0.00277
# Epoch 39/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0086 - accuracy: 0.9967 - val_loss: 0.0249 - val_accuracy: 0.9914
#
# Epoch 00039: val_loss did not improve from 0.00277
# Epoch 40/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0295 - val_accuracy: 0.9914
#
# Epoch 00040: val_loss did not improve from 0.00277
# Epoch 41/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.0254 - val_accuracy: 0.9914
#
# Epoch 00041: val_loss did not improve from 0.00277
# Epoch 42/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9957 - val_loss: 0.0085 - val_accuracy: 0.9965
#
# Epoch 00042: val_loss did not improve from 0.00277
# Epoch 43/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0086 - accuracy: 0.9960 - val_loss: 0.0109 - val_accuracy: 0.9953
#
# Epoch 00043: val_loss did not improve from 0.00277
# Epoch 44/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0132 - val_accuracy: 0.9957
#
# Epoch 00044: val_loss did not improve from 0.00277
# Epoch 45/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0131 - val_accuracy: 0.9953
#
# Epoch 00045: val_loss did not improve from 0.00277
# Epoch 46/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.0087 - val_accuracy: 0.9973
#
# Epoch 00046: val_loss did not improve from 0.00277
# Epoch 47/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0134 - val_accuracy: 0.9953
#
# Epoch 00047: val_loss did not improve from 0.00277
# Epoch 48/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.0103 - val_accuracy: 0.9977
#
# Epoch 00048: val_loss did not improve from 0.00277
# Epoch 49/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0132 - val_accuracy: 0.9953
#
# Epoch 00049: val_loss did not improve from 0.00277
# Epoch 50/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0092 - accuracy: 0.9963 - val_loss: 0.0147 - val_accuracy: 0.9953
#
# Epoch 00050: val_loss did not improve from 0.00277
# Epoch 51/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9961 - val_loss: 0.0166 - val_accuracy: 0.9945
#
# Epoch 00051: val_loss did not improve from 0.00277
# Epoch 52/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.0233 - val_accuracy: 0.9941
#
# Epoch 00052: val_loss did not improve from 0.00277
# Epoch 53/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.0151 - val_accuracy: 0.9969
#
# Epoch 00053: val_loss did not improve from 0.00277
# Epoch 54/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9963 - val_loss: 0.0312 - val_accuracy: 0.9930
#
# Epoch 00054: val_loss did not improve from 0.00277
# Epoch 55/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0085 - val_accuracy: 0.9969
#
# Epoch 00055: val_loss did not improve from 0.00277
# Epoch 56/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0051 - accuracy: 0.9976 - val_loss: 0.0113 - val_accuracy: 0.9957
#
# Epoch 00056: val_loss did not improve from 0.00277
# Epoch 57/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0162 - val_accuracy: 0.9937
#
# Epoch 00057: val_loss did not improve from 0.00277
# Epoch 58/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.0139 - val_accuracy: 0.9957
#
# Epoch 00058: val_loss did not improve from 0.00277
# Epoch 59/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.0114 - val_accuracy: 0.9957
#
# Epoch 00059: val_loss did not improve from 0.00277
# Epoch 60/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9964 - val_loss: 0.0149 - val_accuracy: 0.9957
#
# Epoch 00060: val_loss did not improve from 0.00277
# Epoch 61/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9971 - val_loss: 0.0179 - val_accuracy: 0.9949
#
# Epoch 00061: val_loss did not improve from 0.00277
# Epoch 62/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0097 - val_accuracy: 0.9977
#
# Epoch 00062: val_loss did not improve from 0.00277
# Epoch 63/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9967 - val_loss: 0.1148 - val_accuracy: 0.9750
#
# Epoch 00063: val_loss did not improve from 0.00277
# Epoch 64/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0111 - val_accuracy: 0.9949
#
# Epoch 00064: val_loss did not improve from 0.00277
# Epoch 65/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 0.0219 - val_accuracy: 0.9934
#
# Epoch 00065: val_loss did not improve from 0.00277
# Epoch 66/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.3739 - val_accuracy: 0.9152
#
# Epoch 00066: val_loss did not improve from 0.00277
# Epoch 67/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0072 - val_accuracy: 0.9969
#
# Epoch 00067: val_loss did not improve from 0.00277
# Epoch 68/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 0.0168 - val_accuracy: 0.9953
#
# Epoch 00068: val_loss did not improve from 0.00277
# Epoch 69/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 0.0393 - val_accuracy: 0.9891
#
# Epoch 00069: val_loss did not improve from 0.00277
# Epoch 70/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.0150 - val_accuracy: 0.9961
#
# Epoch 00070: val_loss did not improve from 0.00277
# Epoch 71/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.0252 - val_accuracy: 0.9941
#
# Epoch 00071: val_loss did not improve from 0.00277
# Epoch 72/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9970 - val_loss: 0.0179 - val_accuracy: 0.9937
#
# Epoch 00072: val_loss did not improve from 0.00277
# Epoch 73/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.0058 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00277
# Epoch 74/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9972 - val_loss: 0.0125 - val_accuracy: 0.9953
#
# Epoch 00074: val_loss did not improve from 0.00277
# Epoch 75/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0038 - accuracy: 0.9983 - val_loss: 0.0133 - val_accuracy: 0.9953
#
# Epoch 00075: val_loss did not improve from 0.00277
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9953
# Val Score:  [0.013270655646920204, 0.995312511920929]
# Training on Fold:  3
# Epoch 1/75
# 320/320 [==============================] - 4s 9ms/step - loss: 0.3868 - accuracy: 0.8791 - val_loss: 2.9967 - val_accuracy: 0.6090
#
# Epoch 00001: val_loss did not improve from 0.00277
# Epoch 2/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1489 - accuracy: 0.9483 - val_loss: 1.2164 - val_accuracy: 0.7500
#
# Epoch 00002: val_loss did not improve from 0.00277
# Epoch 3/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1086 - accuracy: 0.9601 - val_loss: 0.7759 - val_accuracy: 0.8047
#
# Epoch 00003: val_loss did not improve from 0.00277
# Epoch 4/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0794 - accuracy: 0.9729 - val_loss: 0.3905 - val_accuracy: 0.8875
#
# Epoch 00004: val_loss did not improve from 0.00277
# Epoch 5/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0577 - accuracy: 0.9797 - val_loss: 0.4129 - val_accuracy: 0.8867
#
# Epoch 00005: val_loss did not improve from 0.00277
# Epoch 6/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0618 - accuracy: 0.9791 - val_loss: 0.1636 - val_accuracy: 0.9414
#
# Epoch 00006: val_loss did not improve from 0.00277
# Epoch 7/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0458 - accuracy: 0.9852 - val_loss: 0.1244 - val_accuracy: 0.9574
#
# Epoch 00007: val_loss did not improve from 0.00277
# Epoch 8/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0408 - accuracy: 0.9849 - val_loss: 0.0646 - val_accuracy: 0.9750
#
# Epoch 00008: val_loss did not improve from 0.00277
# Epoch 9/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0318 - accuracy: 0.9880 - val_loss: 0.2445 - val_accuracy: 0.9348
#
# Epoch 00009: val_loss did not improve from 0.00277
# Epoch 10/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0256 - accuracy: 0.9897 - val_loss: 0.1244 - val_accuracy: 0.9590
#
# Epoch 00010: val_loss did not improve from 0.00277
# Epoch 11/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0242 - accuracy: 0.9911 - val_loss: 0.2060 - val_accuracy: 0.9438
#
# Epoch 00011: val_loss did not improve from 0.00277
# Epoch 12/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0264 - accuracy: 0.9901 - val_loss: 0.0763 - val_accuracy: 0.9742
#
# Epoch 00012: val_loss did not improve from 0.00277
# Epoch 13/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0208 - accuracy: 0.9935 - val_loss: 0.0994 - val_accuracy: 0.9660
#
# Epoch 00013: val_loss did not improve from 0.00277
# Epoch 14/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0262 - accuracy: 0.9906 - val_loss: 0.1765 - val_accuracy: 0.9430
#
# Epoch 00014: val_loss did not improve from 0.00277
# Epoch 15/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0196 - accuracy: 0.9932 - val_loss: 0.0651 - val_accuracy: 0.9770
#
# Epoch 00015: val_loss did not improve from 0.00277
# Epoch 16/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0226 - accuracy: 0.9925 - val_loss: 0.2879 - val_accuracy: 0.9367
#
# Epoch 00016: val_loss did not improve from 0.00277
# Epoch 17/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.1309 - val_accuracy: 0.9582
#
# Epoch 00017: val_loss did not improve from 0.00277
# Epoch 18/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0153 - accuracy: 0.9936 - val_loss: 0.0534 - val_accuracy: 0.9832
#
# Epoch 00018: val_loss did not improve from 0.00277
# Epoch 19/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0167 - accuracy: 0.9938 - val_loss: 0.0575 - val_accuracy: 0.9824
#
# Epoch 00019: val_loss did not improve from 0.00277
# Epoch 20/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0147 - accuracy: 0.9938 - val_loss: 0.0593 - val_accuracy: 0.9816
#
# Epoch 00020: val_loss did not improve from 0.00277
# Epoch 21/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.1888 - val_accuracy: 0.9523
#
# Epoch 00021: val_loss did not improve from 0.00277
# Epoch 22/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0805 - val_accuracy: 0.9777
#
# Epoch 00022: val_loss did not improve from 0.00277
# Epoch 23/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.0350 - val_accuracy: 0.9891
#
# Epoch 00023: val_loss did not improve from 0.00277
# Epoch 24/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 0.0408 - val_accuracy: 0.9848
#
# Epoch 00024: val_loss did not improve from 0.00277
# Epoch 25/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.0123 - val_accuracy: 0.9957
#
# Epoch 00025: val_loss did not improve from 0.00277
# Epoch 26/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 0.0297 - val_accuracy: 0.9883
#
# Epoch 00026: val_loss did not improve from 0.00277
# Epoch 27/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.0108 - val_accuracy: 0.9957
#
# Epoch 00027: val_loss did not improve from 0.00277
# Epoch 28/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9950 - val_loss: 0.0272 - val_accuracy: 0.9910
#
# Epoch 00028: val_loss did not improve from 0.00277
# Epoch 29/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 0.1231 - val_accuracy: 0.9691
#
# Epoch 00029: val_loss did not improve from 0.00277
# Epoch 30/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0107 - accuracy: 0.9958 - val_loss: 0.0232 - val_accuracy: 0.9941
#
# Epoch 00030: val_loss did not improve from 0.00277
# Epoch 31/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9961 - val_loss: 0.0237 - val_accuracy: 0.9898
#
# Epoch 00031: val_loss did not improve from 0.00277
# Epoch 32/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9958 - val_loss: 0.0124 - val_accuracy: 0.9949
#
# Epoch 00032: val_loss did not improve from 0.00277
# Epoch 33/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9967 - val_loss: 0.0454 - val_accuracy: 0.9883
#
# Epoch 00033: val_loss did not improve from 0.00277
# Epoch 34/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0498 - val_accuracy: 0.9812
#
# Epoch 00034: val_loss did not improve from 0.00277
# Epoch 35/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9972 - val_loss: 0.0247 - val_accuracy: 0.9926
#
# Epoch 00035: val_loss did not improve from 0.00277
# Epoch 36/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0303 - val_accuracy: 0.9930
#
# Epoch 00036: val_loss did not improve from 0.00277
# Epoch 37/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.0035 - val_accuracy: 0.9984
#
# Epoch 00037: val_loss did not improve from 0.00277
# Epoch 38/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.0253 - val_accuracy: 0.9887
#
# Epoch 00038: val_loss did not improve from 0.00277
# Epoch 39/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9964 - val_loss: 0.0471 - val_accuracy: 0.9852
#
# Epoch 00039: val_loss did not improve from 0.00277
# Epoch 40/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0538 - val_accuracy: 0.9848
#
# Epoch 00040: val_loss did not improve from 0.00277
# Epoch 41/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 0.0374 - val_accuracy: 0.9930
#
# Epoch 00041: val_loss did not improve from 0.00277
# Epoch 42/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0258 - val_accuracy: 0.9973
#
# Epoch 00042: val_loss did not improve from 0.00277
# Epoch 43/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0220 - val_accuracy: 0.9949
#
# Epoch 00043: val_loss did not improve from 0.00277
# Epoch 44/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.0806 - val_accuracy: 0.9809
#
# Epoch 00044: val_loss did not improve from 0.00277
# Epoch 45/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.0324 - val_accuracy: 0.9922
#
# Epoch 00045: val_loss did not improve from 0.00277
# Epoch 46/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9960 - val_loss: 0.0325 - val_accuracy: 0.9969
#
# Epoch 00046: val_loss did not improve from 0.00277
# Epoch 47/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9965 - val_loss: 0.0277 - val_accuracy: 0.9945
#
# Epoch 00047: val_loss did not improve from 0.00277
# Epoch 48/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0448 - val_accuracy: 0.9918
#
# Epoch 00048: val_loss did not improve from 0.00277
# Epoch 49/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9965 - val_loss: 0.0282 - val_accuracy: 0.9945
#
# Epoch 00049: val_loss did not improve from 0.00277
# Epoch 50/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0245 - val_accuracy: 0.9965
#
# Epoch 00050: val_loss did not improve from 0.00277
# Epoch 51/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9975 - val_loss: 0.0716 - val_accuracy: 0.9945
#
# Epoch 00051: val_loss did not improve from 0.00277
# Epoch 52/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.0530 - val_accuracy: 0.9937
#
# Epoch 00052: val_loss did not improve from 0.00277
# Epoch 53/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.0490 - val_accuracy: 0.9941
#
# Epoch 00053: val_loss did not improve from 0.00277
# Epoch 54/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0179 - val_accuracy: 0.9969
#
# Epoch 00054: val_loss did not improve from 0.00277
# Epoch 55/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.0230 - val_accuracy: 0.9922
#
# Epoch 00055: val_loss did not improve from 0.00277
# Epoch 56/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9973 - val_loss: 0.0082 - val_accuracy: 0.9969
#
# Epoch 00056: val_loss did not improve from 0.00277
# Epoch 57/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9964 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00057: val_loss did not improve from 0.00277
# Epoch 58/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0278 - val_accuracy: 0.9957
#
# Epoch 00058: val_loss did not improve from 0.00277
# Epoch 59/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9970 - val_loss: 0.0378 - val_accuracy: 0.9969
#
# Epoch 00059: val_loss did not improve from 0.00277
# Epoch 60/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0282 - val_accuracy: 0.9961
#
# Epoch 00060: val_loss did not improve from 0.00277
# Epoch 61/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9972 - val_loss: 0.0195 - val_accuracy: 0.9973
#
# Epoch 00061: val_loss did not improve from 0.00277
# Epoch 62/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0375 - val_accuracy: 0.9961
#
# Epoch 00062: val_loss did not improve from 0.00277
# Epoch 63/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0787 - val_accuracy: 0.9887
#
# Epoch 00063: val_loss did not improve from 0.00277
# Epoch 64/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9980 - val_loss: 0.0418 - val_accuracy: 0.9957
#
# Epoch 00064: val_loss did not improve from 0.00277
# Epoch 65/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0240 - val_accuracy: 0.9957
#
# Epoch 00065: val_loss did not improve from 0.00277
# Epoch 66/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0061 - accuracy: 0.9973 - val_loss: 0.0287 - val_accuracy: 0.9957
#
# Epoch 00066: val_loss did not improve from 0.00277
# Epoch 67/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0295 - val_accuracy: 0.9957
#
# Epoch 00067: val_loss did not improve from 0.00277
# Epoch 68/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0232 - val_accuracy: 0.9961
#
# Epoch 00068: val_loss did not improve from 0.00277
# Epoch 69/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0216 - val_accuracy: 0.9961
#
# Epoch 00069: val_loss did not improve from 0.00277
# Epoch 70/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0248 - val_accuracy: 0.9945
#
# Epoch 00070: val_loss did not improve from 0.00277
# Epoch 71/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0050 - accuracy: 0.9973 - val_loss: 0.0313 - val_accuracy: 0.9957
#
# Epoch 00071: val_loss did not improve from 0.00277
# Epoch 72/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.0206 - val_accuracy: 0.9945
#
# Epoch 00072: val_loss did not improve from 0.00277
# Epoch 73/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9969 - val_loss: 0.0122 - val_accuracy: 0.9977
#
# Epoch 00073: val_loss did not improve from 0.00277
# Epoch 74/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.0297 - val_accuracy: 0.9965
#
# Epoch 00074: val_loss did not improve from 0.00277
# Epoch 75/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9967 - val_loss: 0.0684 - val_accuracy: 0.9965
#
# Epoch 00075: val_loss did not improve from 0.00277
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0684 - accuracy: 0.9965
# Val Score:  [0.06842799484729767, 0.9964843988418579]
# Training on Fold:  4
# Epoch 1/75
# 320/320 [==============================] - 4s 10ms/step - loss: 0.4133 - accuracy: 0.8661 - val_loss: 3.5825 - val_accuracy: 0.4023
#
# Epoch 00001: val_loss did not improve from 0.00277
# Epoch 2/75
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1548 - accuracy: 0.9438 - val_loss: 0.9535 - val_accuracy: 0.7590
#
# Epoch 00002: val_loss did not improve from 0.00277
# Epoch 3/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1179 - accuracy: 0.9581 - val_loss: 0.4457 - val_accuracy: 0.8598
#
# Epoch 00003: val_loss did not improve from 0.00277
# Epoch 4/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0836 - accuracy: 0.9692 - val_loss: 0.3367 - val_accuracy: 0.9000
#
# Epoch 00004: val_loss did not improve from 0.00277
# Epoch 5/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0641 - accuracy: 0.9792 - val_loss: 0.2546 - val_accuracy: 0.9145
#
# Epoch 00005: val_loss did not improve from 0.00277
# Epoch 6/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0527 - accuracy: 0.9834 - val_loss: 0.3583 - val_accuracy: 0.9051
#
# Epoch 00006: val_loss did not improve from 0.00277
# Epoch 7/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0469 - accuracy: 0.9857 - val_loss: 0.2319 - val_accuracy: 0.9289
#
# Epoch 00007: val_loss did not improve from 0.00277
# Epoch 8/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0482 - accuracy: 0.9844 - val_loss: 0.3647 - val_accuracy: 0.9094
#
# Epoch 00008: val_loss did not improve from 0.00277
# Epoch 9/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0397 - accuracy: 0.9886 - val_loss: 0.1549 - val_accuracy: 0.9543
#
# Epoch 00009: val_loss did not improve from 0.00277
# Epoch 10/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.1544 - val_accuracy: 0.9566
#
# Epoch 00010: val_loss did not improve from 0.00277
# Epoch 11/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0321 - accuracy: 0.9897 - val_loss: 0.1684 - val_accuracy: 0.9520
#
# Epoch 00011: val_loss did not improve from 0.00277
# Epoch 12/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0260 - accuracy: 0.9908 - val_loss: 0.1407 - val_accuracy: 0.9641
#
# Epoch 00012: val_loss did not improve from 0.00277
# Epoch 13/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0202 - accuracy: 0.9937 - val_loss: 0.2570 - val_accuracy: 0.9484
#
# Epoch 00013: val_loss did not improve from 0.00277
# Epoch 14/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0277 - accuracy: 0.9917 - val_loss: 0.2442 - val_accuracy: 0.9434
#
# Epoch 00014: val_loss did not improve from 0.00277
# Epoch 15/75
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 0.0888 - val_accuracy: 0.9738
#
# Epoch 00015: val_loss did not improve from 0.00277
# Epoch 16/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0485 - val_accuracy: 0.9855
#
# Epoch 00016: val_loss did not improve from 0.00277
# Epoch 17/75
# ...
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0035 - val_accuracy: 0.9984
#
# Epoch 00071: val_loss did not improve from 0.00254
# Epoch 72/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.1260 - val_accuracy: 0.9703
#
# Epoch 00072: val_loss did not improve from 0.00254
# Epoch 73/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0069 - val_accuracy: 0.9977
#
# Epoch 00073: val_loss did not improve from 0.00254
# Epoch 74/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 0.0054 - val_accuracy: 0.9980
#
# Epoch 00074: val_loss did not improve from 0.00254
# Epoch 75/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0044 - accuracy: 0.9976 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00075: val_loss did not improve from 0.00254
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9980
# Val Score:  [0.005551367998123169, 0.998046875]
# Training on Fold:  5
# Epoch 1/75
# 320/320 [==============================] - 5s 9ms/step - loss: 0.3462 - accuracy: 0.8915 - val_loss: 10.7373 - val_accuracy: 0.2648
#
# Epoch 00001: val_loss did not improve from 0.00254
# Epoch 2/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1230 - accuracy: 0.9563 - val_loss: 1.7595 - val_accuracy: 0.6820
#
# Epoch 00002: val_loss did not improve from 0.00254
# Epoch 3/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0959 - accuracy: 0.9687 - val_loss: 0.6326 - val_accuracy: 0.8398
#
# Epoch 00003: val_loss did not improve from 0.00254
# Epoch 4/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0674 - accuracy: 0.9766 - val_loss: 0.5833 - val_accuracy: 0.8387
#
# Epoch 00004: val_loss did not improve from 0.00254
# Epoch 5/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0611 - accuracy: 0.9801 - val_loss: 0.2550 - val_accuracy: 0.9215
#
# Epoch 00005: val_loss did not improve from 0.00254
# Epoch 6/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0445 - accuracy: 0.9867 - val_loss: 0.0823 - val_accuracy: 0.9746
#
# Epoch 00006: val_loss did not improve from 0.00254
# Epoch 7/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0466 - accuracy: 0.9843 - val_loss: 0.1279 - val_accuracy: 0.9563
#
# Epoch 00007: val_loss did not improve from 0.00254
# Epoch 8/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0442 - accuracy: 0.9867 - val_loss: 0.1859 - val_accuracy: 0.9371
#
# Epoch 00008: val_loss did not improve from 0.00254
# Epoch 9/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0350 - accuracy: 0.9908 - val_loss: 0.0955 - val_accuracy: 0.9730
#
# Epoch 00009: val_loss did not improve from 0.00254
# Epoch 10/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0303 - accuracy: 0.9897 - val_loss: 0.0977 - val_accuracy: 0.9680
#
# Epoch 00010: val_loss did not improve from 0.00254
# Epoch 11/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0310 - accuracy: 0.9894 - val_loss: 0.0524 - val_accuracy: 0.9820
#
# Epoch 00011: val_loss did not improve from 0.00254
# Epoch 12/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0296 - accuracy: 0.9910 - val_loss: 0.0537 - val_accuracy: 0.9828
#
# Epoch 00012: val_loss did not improve from 0.00254
# Epoch 13/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0739 - val_accuracy: 0.9742
#
# Epoch 00013: val_loss did not improve from 0.00254
# Epoch 14/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.0353 - val_accuracy: 0.9859
#
# Epoch 00014: val_loss did not improve from 0.00254
# Epoch 15/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0262 - accuracy: 0.9906 - val_loss: 0.0698 - val_accuracy: 0.9750
#
# Epoch 00015: val_loss did not improve from 0.00254
# Epoch 16/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 0.0208 - val_accuracy: 0.9922
#
# Epoch 00016: val_loss did not improve from 0.00254
# Epoch 17/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0177 - accuracy: 0.9942 - val_loss: 0.0192 - val_accuracy: 0.9953
#
# Epoch 00017: val_loss did not improve from 0.00254
# Epoch 18/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0174 - accuracy: 0.9935 - val_loss: 0.0345 - val_accuracy: 0.9895
#
# Epoch 00018: val_loss did not improve from 0.00254
# Epoch 19/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9950 - val_loss: 0.0298 - val_accuracy: 0.9906
#
# Epoch 00019: val_loss did not improve from 0.00254
# Epoch 20/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0192 - accuracy: 0.9934 - val_loss: 0.0296 - val_accuracy: 0.9914
#
# Epoch 00020: val_loss did not improve from 0.00254
# Epoch 21/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9955 - val_loss: 0.0247 - val_accuracy: 0.9926
#
# Epoch 00021: val_loss did not improve from 0.00254
# Epoch 22/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9942 - val_loss: 0.0367 - val_accuracy: 0.9867
#
# Epoch 00022: val_loss did not improve from 0.00254
# Epoch 23/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0241 - val_accuracy: 0.9934
#
# Epoch 00023: val_loss did not improve from 0.00254
# Epoch 24/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0510 - val_accuracy: 0.9879
#
# Epoch 00024: val_loss did not improve from 0.00254
# Epoch 25/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0125 - accuracy: 0.9954 - val_loss: 0.0155 - val_accuracy: 0.9953
#
# Epoch 00025: val_loss did not improve from 0.00254
# Epoch 26/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0100 - accuracy: 0.9962 - val_loss: 0.0122 - val_accuracy: 0.9965
#
# Epoch 00026: val_loss did not improve from 0.00254
# Epoch 27/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.0544 - val_accuracy: 0.9836
#
# Epoch 00027: val_loss did not improve from 0.00254
# Epoch 28/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0132 - accuracy: 0.9950 - val_loss: 0.0120 - val_accuracy: 0.9961
#
# Epoch 00028: val_loss did not improve from 0.00254
# Epoch 29/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0178 - val_accuracy: 0.9953
#
# Epoch 00029: val_loss did not improve from 0.00254
# Epoch 30/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9970 - val_loss: 0.0242 - val_accuracy: 0.9934
#
# Epoch 00030: val_loss did not improve from 0.00254
# Epoch 31/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9951 - val_loss: 0.0295 - val_accuracy: 0.9941
#
# Epoch 00031: val_loss did not improve from 0.00254
# Epoch 32/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0299 - val_accuracy: 0.9906
#
# Epoch 00032: val_loss did not improve from 0.00254
# Epoch 33/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.0197 - val_accuracy: 0.9961
#
# Epoch 00033: val_loss did not improve from 0.00254
# Epoch 34/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9967 - val_loss: 0.0182 - val_accuracy: 0.9953
#
# Epoch 00034: val_loss did not improve from 0.00254
# Epoch 35/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0135 - accuracy: 0.9950 - val_loss: 0.3964 - val_accuracy: 0.9102
#
# Epoch 00035: val_loss did not improve from 0.00254
# Epoch 36/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0125 - val_accuracy: 0.9969
#
# Epoch 00036: val_loss did not improve from 0.00254
# Epoch 37/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0223 - val_accuracy: 0.9961
#
# Epoch 00037: val_loss did not improve from 0.00254
# Epoch 38/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0154 - val_accuracy: 0.9953
#
# Epoch 00038: val_loss did not improve from 0.00254
# Epoch 39/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9960 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00039: val_loss did not improve from 0.00254
# Epoch 40/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9963 - val_loss: 0.0739 - val_accuracy: 0.9797
#
# Epoch 00040: val_loss did not improve from 0.00254
# Epoch 41/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0072 - val_accuracy: 0.9973
#
# Epoch 00041: val_loss did not improve from 0.00254
# Epoch 42/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0351 - val_accuracy: 0.9918
#
# Epoch 00042: val_loss did not improve from 0.00254
# Epoch 43/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0542 - val_accuracy: 0.9949
#
# Epoch 00043: val_loss did not improve from 0.00254
# Epoch 44/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0133 - accuracy: 0.9951 - val_loss: 0.0253 - val_accuracy: 0.9937
#
# Epoch 00044: val_loss did not improve from 0.00254
# Epoch 45/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0174 - val_accuracy: 0.9961
#
# Epoch 00045: val_loss did not improve from 0.00254
# Epoch 46/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0164 - val_accuracy: 0.9953
#
# Epoch 00046: val_loss did not improve from 0.00254
# Epoch 47/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9965 - val_loss: 0.0697 - val_accuracy: 0.9809
#
# Epoch 00047: val_loss did not improve from 0.00254
# Epoch 48/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9962 - val_loss: 0.0179 - val_accuracy: 0.9961
#
# Epoch 00048: val_loss did not improve from 0.00254
# Epoch 49/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0075 - accuracy: 0.9967 - val_loss: 0.0068 - val_accuracy: 0.9973
#
# Epoch 00049: val_loss did not improve from 0.00254
# Epoch 50/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.0080 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00254
# Epoch 51/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9962 - val_loss: 0.0040 - val_accuracy: 0.9984
#
# Epoch 00051: val_loss did not improve from 0.00254
# Epoch 52/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0039 - val_accuracy: 0.9973
#
# Epoch 00052: val_loss did not improve from 0.00254
# Epoch 53/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00053: val_loss did not improve from 0.00254
# Epoch 54/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0097 - val_accuracy: 0.9961
#
# Epoch 00054: val_loss did not improve from 0.00254
# Epoch 55/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.0205 - val_accuracy: 0.9957
#
# Epoch 00055: val_loss did not improve from 0.00254
# Epoch 56/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.0282 - val_accuracy: 0.9918
#
# Epoch 00056: val_loss did not improve from 0.00254
# Epoch 57/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.0091 - val_accuracy: 0.9980
#
# Epoch 00057: val_loss did not improve from 0.00254
# Epoch 58/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0107 - val_accuracy: 0.9969
#
# Epoch 00058: val_loss did not improve from 0.00254
# Epoch 59/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00059: val_loss did not improve from 0.00254
# Epoch 60/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0088 - val_accuracy: 0.9973
#
# Epoch 00060: val_loss did not improve from 0.00254
# Epoch 61/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0095 - val_accuracy: 0.9965
#
# Epoch 00061: val_loss did not improve from 0.00254
# Epoch 62/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0047 - accuracy: 0.9977 - val_loss: 0.0133 - val_accuracy: 0.9977
#
# Epoch 00062: val_loss did not improve from 0.00254
# Epoch 63/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0050 - accuracy: 0.9976 - val_loss: 0.0131 - val_accuracy: 0.9980
#
# Epoch 00063: val_loss did not improve from 0.00254
# Epoch 64/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0047 - accuracy: 0.9981 - val_loss: 0.0163 - val_accuracy: 0.9965
#
# Epoch 00064: val_loss did not improve from 0.00254
# Epoch 65/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9967 - val_loss: 0.0072 - val_accuracy: 0.9977
#
# Epoch 00065: val_loss did not improve from 0.00254
# Epoch 66/75
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9972 - val_loss: 0.0046 - val_accuracy: 0.9977
#
# Epoch 00066: val_loss did not improve from 0.00254
# Epoch 67/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0060 - val_accuracy: 0.9988
#
# Epoch 00067: val_loss did not improve from 0.00254
# Epoch 68/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9970 - val_loss: 0.0083 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00254
# Epoch 69/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9972 - val_loss: 0.0104 - val_accuracy: 0.9984
#
# Epoch 00069: val_loss did not improve from 0.00254
# Epoch 70/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00070: val_loss improved from 0.00254 to 0.00237, saving model to model.h5
# Epoch 71/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9970 - val_loss: 0.0028 - val_accuracy: 0.9988
#
# Epoch 00071: val_loss did not improve from 0.00237
# Epoch 72/75
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.0433 - val_accuracy: 0.9879
#
# Epoch 00072: val_loss did not improve from 0.00237
# Epoch 73/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0130 - val_accuracy: 0.9957
#
# Epoch 00073: val_loss did not improve from 0.00237
# Epoch 74/75
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00074: val_loss did not improve from 0.00237
# Epoch 75/75
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9971 - val_loss: 0.0199 - val_accuracy: 0.9969
#
# Epoch 00075: val_loss did not improve from 0.00237
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9969
# Val Score:  [0.019910268485546112, 0.996874988079071]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 0.9959
# Test Accuracy: 99.59375262260437

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
