# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-2
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_36 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_37 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_38 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_39 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_40 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_41 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.7169 - accuracy: 0.8052 - val_loss: 2.4141 - val_accuracy: 0.7094
#
# Epoch 00001: val_loss improved from inf to 2.41409, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.3370 - accuracy: 0.8943 - val_loss: 0.7430 - val_accuracy: 0.8066
#
# Epoch 00002: val_loss improved from 2.41409 to 0.74296, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2164 - accuracy: 0.9320 - val_loss: 4.3496 - val_accuracy: 0.5715
#
# Epoch 00003: val_loss did not improve from 0.74296
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1529 - accuracy: 0.9499 - val_loss: 0.2682 - val_accuracy: 0.9383
#
# Epoch 00004: val_loss improved from 0.74296 to 0.26816, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1268 - accuracy: 0.9588 - val_loss: 0.1953 - val_accuracy: 0.9602
#
# Epoch 00005: val_loss improved from 0.26816 to 0.19529, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1276 - accuracy: 0.9607 - val_loss: 0.1128 - val_accuracy: 0.9648
#
# Epoch 00006: val_loss improved from 0.19529 to 0.11276, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0817 - accuracy: 0.9738 - val_loss: 0.3094 - val_accuracy: 0.9227
#
# Epoch 00007: val_loss did not improve from 0.11276
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0901 - accuracy: 0.9737 - val_loss: 0.1104 - val_accuracy: 0.9637
#
# Epoch 00008: val_loss improved from 0.11276 to 0.11044, saving model to model.h5
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1078 - accuracy: 0.9683 - val_loss: 0.0284 - val_accuracy: 0.9891
#
# Epoch 00009: val_loss improved from 0.11044 to 0.02841, saving model to model.h5
# Epoch 10/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0667 - accuracy: 0.9792 - val_loss: 0.7732 - val_accuracy: 0.8297
#
# Epoch 00010: val_loss did not improve from 0.02841
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1036 - accuracy: 0.9729 - val_loss: 2.3020 - val_accuracy: 0.7125
#
# Epoch 00011: val_loss did not improve from 0.02841
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0773 - accuracy: 0.9788 - val_loss: 8.5618 - val_accuracy: 0.3191
#
# Epoch 00012: val_loss did not improve from 0.02841
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1677 - accuracy: 0.9602 - val_loss: 0.1583 - val_accuracy: 0.9477
#
# Epoch 00013: val_loss did not improve from 0.02841
# Epoch 14/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0722 - accuracy: 0.9807 - val_loss: 0.1016 - val_accuracy: 0.9715
#
# Epoch 00014: val_loss did not improve from 0.02841
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0442 - accuracy: 0.9870 - val_loss: 0.0363 - val_accuracy: 0.9887
#
# Epoch 00015: val_loss did not improve from 0.02841
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0562 - accuracy: 0.9825 - val_loss: 0.0840 - val_accuracy: 0.9766
#
# Epoch 00016: val_loss did not improve from 0.02841
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0507 - accuracy: 0.9858 - val_loss: 0.0156 - val_accuracy: 0.9945
#
# Epoch 00017: val_loss improved from 0.02841 to 0.01557, saving model to model.h5
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0486 - accuracy: 0.9856 - val_loss: 0.0483 - val_accuracy: 0.9887
#
# Epoch 00018: val_loss did not improve from 0.01557
# Epoch 19/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0381 - accuracy: 0.9897 - val_loss: 0.3070 - val_accuracy: 0.9352
#
# Epoch 00019: val_loss did not improve from 0.01557
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0478 - accuracy: 0.9861 - val_loss: 0.0665 - val_accuracy: 0.9801
#
# Epoch 00020: val_loss did not improve from 0.01557
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0521 - accuracy: 0.9857 - val_loss: 0.0134 - val_accuracy: 0.9965
#
# Epoch 00021: val_loss improved from 0.01557 to 0.01338, saving model to model.h5
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0314 - accuracy: 0.9909 - val_loss: 0.0149 - val_accuracy: 0.9937
#
# Epoch 00022: val_loss did not improve from 0.01338
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0533 - accuracy: 0.9864 - val_loss: 0.0398 - val_accuracy: 0.9883
#
# Epoch 00023: val_loss did not improve from 0.01338
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0756 - accuracy: 0.9826 - val_loss: 20.1774 - val_accuracy: 0.4473
#
# Epoch 00024: val_loss did not improve from 0.01338
# Epoch 25/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0587 - accuracy: 0.9856 - val_loss: 0.0282 - val_accuracy: 0.9949
#
# Epoch 00025: val_loss did not improve from 0.01338
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0525 - accuracy: 0.9872 - val_loss: 0.0291 - val_accuracy: 0.9902
#
# Epoch 00026: val_loss did not improve from 0.01338
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.0336 - val_accuracy: 0.9918
#
# Epoch 00027: val_loss did not improve from 0.01338
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0220 - accuracy: 0.9933 - val_loss: 0.0048 - val_accuracy: 0.9984
#
# Epoch 00028: val_loss improved from 0.01338 to 0.00481, saving model to model.h5
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0182 - accuracy: 0.9957 - val_loss: 0.0217 - val_accuracy: 0.9945
#
# Epoch 00029: val_loss did not improve from 0.00481
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0373 - accuracy: 0.9907 - val_loss: 0.0525 - val_accuracy: 0.9895
#
# Epoch 00030: val_loss did not improve from 0.00481
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0445 - accuracy: 0.9889 - val_loss: 0.1570 - val_accuracy: 0.9789
#
# Epoch 00031: val_loss did not improve from 0.00481
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0309 - accuracy: 0.9915 - val_loss: 0.0232 - val_accuracy: 0.9977
#
# Epoch 00032: val_loss did not improve from 0.00481
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0283 - accuracy: 0.9934 - val_loss: 0.1278 - val_accuracy: 0.9660
#
# Epoch 00033: val_loss did not improve from 0.00481
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0307 - accuracy: 0.9918 - val_loss: 0.0108 - val_accuracy: 0.9984
#
# Epoch 00034: val_loss did not improve from 0.00481
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0260 - accuracy: 0.9934 - val_loss: 0.0067 - val_accuracy: 0.9977
#
# Epoch 00035: val_loss did not improve from 0.00481
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0320 - accuracy: 0.9933 - val_loss: 0.0630 - val_accuracy: 0.9891
#
# Epoch 00036: val_loss did not improve from 0.00481
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0544 - accuracy: 0.9879 - val_loss: 0.2255 - val_accuracy: 0.9609
#
# Epoch 00037: val_loss did not improve from 0.00481
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0270 - accuracy: 0.9931 - val_loss: 0.0193 - val_accuracy: 0.9965
#
# Epoch 00038: val_loss did not improve from 0.00481
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0254 - accuracy: 0.9943 - val_loss: 0.1020 - val_accuracy: 0.9879
#
# Epoch 00039: val_loss did not improve from 0.00481
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0169 - accuracy: 0.9952 - val_loss: 0.0201 - val_accuracy: 0.9961
#
# Epoch 00040: val_loss did not improve from 0.00481
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0445 - accuracy: 0.9913 - val_loss: 0.0243 - val_accuracy: 0.9949
#
# Epoch 00041: val_loss did not improve from 0.00481
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0184 - accuracy: 0.9946 - val_loss: 0.0088 - val_accuracy: 0.9973
#
# Epoch 00042: val_loss did not improve from 0.00481
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0234 - accuracy: 0.9932 - val_loss: 0.0193 - val_accuracy: 0.9934
#
# Epoch 00043: val_loss did not improve from 0.00481
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0146 - accuracy: 0.9960 - val_loss: 0.0951 - val_accuracy: 0.9809
#
# Epoch 00044: val_loss did not improve from 0.00481
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9944 - val_loss: 0.0266 - val_accuracy: 0.9934
#
# Epoch 00045: val_loss did not improve from 0.00481
# Epoch 46/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0200 - accuracy: 0.9951 - val_loss: 0.0201 - val_accuracy: 0.9969
#
# Epoch 00046: val_loss did not improve from 0.00481
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0172 - accuracy: 0.9951 - val_loss: 0.0106 - val_accuracy: 0.9965
#
# Epoch 00047: val_loss did not improve from 0.00481
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0317 - accuracy: 0.9925 - val_loss: 0.6537 - val_accuracy: 0.8941
#
# Epoch 00048: val_loss did not improve from 0.00481
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0186 - accuracy: 0.9954 - val_loss: 0.0215 - val_accuracy: 0.9973
#
# Epoch 00049: val_loss did not improve from 0.00481
# Epoch 50/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0294 - accuracy: 0.9937 - val_loss: 0.0177 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00481
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00051: val_loss improved from 0.00481 to 0.00390, saving model to model.h5
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0215 - accuracy: 0.9947 - val_loss: 0.3015 - val_accuracy: 0.9578
#
# Epoch 00052: val_loss did not improve from 0.00390
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0182 - accuracy: 0.9955 - val_loss: 0.0050 - val_accuracy: 0.9984
#
# Epoch 00053: val_loss did not improve from 0.00390
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0210 - val_accuracy: 0.9937
#
# Epoch 00054: val_loss did not improve from 0.00390
# Epoch 55/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0168 - accuracy: 0.9951 - val_loss: 0.0090 - val_accuracy: 0.9961
#
# Epoch 00055: val_loss did not improve from 0.00390
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0148 - accuracy: 0.9962 - val_loss: 0.0106 - val_accuracy: 0.9980
#
# Epoch 00056: val_loss did not improve from 0.00390
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 0.0085 - val_accuracy: 0.9977
#
# Epoch 00057: val_loss did not improve from 0.00390
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0193 - accuracy: 0.9949 - val_loss: 0.0322 - val_accuracy: 0.9922
#
# Epoch 00058: val_loss did not improve from 0.00390
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0338 - accuracy: 0.9922 - val_loss: 0.0091 - val_accuracy: 0.9977
#
# Epoch 00059: val_loss did not improve from 0.00390
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0411 - val_accuracy: 0.9898
#
# Epoch 00060: val_loss did not improve from 0.00390
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0201 - accuracy: 0.9945 - val_loss: 0.0180 - val_accuracy: 0.9969
#
# Epoch 00061: val_loss did not improve from 0.00390
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9963 - val_loss: 0.0134 - val_accuracy: 0.9961
#
# Epoch 00062: val_loss did not improve from 0.00390
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0698 - val_accuracy: 0.9898
#
# Epoch 00063: val_loss did not improve from 0.00390
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.0511 - val_accuracy: 0.9887
#
# Epoch 00064: val_loss did not improve from 0.00390
# Epoch 65/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0167 - accuracy: 0.9962 - val_loss: 0.0252 - val_accuracy: 0.9957
#
# Epoch 00065: val_loss did not improve from 0.00390
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.4058 - val_accuracy: 0.9453
#
# Epoch 00066: val_loss did not improve from 0.00390
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 0.4634 - val_accuracy: 0.9285
#
# Epoch 00067: val_loss did not improve from 0.00390
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0236 - accuracy: 0.9940 - val_loss: 0.0159 - val_accuracy: 0.9973
#
# Epoch 00068: val_loss did not improve from 0.00390
# Epoch 69/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0133 - accuracy: 0.9967 - val_loss: 0.0036 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss improved from 0.00390 to 0.00361, saving model to model.h5
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0202 - accuracy: 0.9948 - val_loss: 0.0528 - val_accuracy: 0.9926
#
# Epoch 00070: val_loss did not improve from 0.00361
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0165 - accuracy: 0.9964 - val_loss: 0.0597 - val_accuracy: 0.9859
#
# Epoch 00071: val_loss did not improve from 0.00361
# Epoch 72/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.0099 - val_accuracy: 0.9973
#
# Epoch 00072: val_loss did not improve from 0.00361
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0174 - accuracy: 0.9958 - val_loss: 0.0101 - val_accuracy: 0.9965
#
# Epoch 00073: val_loss did not improve from 0.00361
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00074: val_loss did not improve from 0.00361
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0177 - accuracy: 0.9958 - val_loss: 0.2870 - val_accuracy: 0.9449
#
# Epoch 00075: val_loss did not improve from 0.00361
# Epoch 76/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss improved from 0.00361 to 0.00299, saving model to model.h5
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.0062 - val_accuracy: 0.9980
#
# Epoch 00077: val_loss did not improve from 0.00299
# Epoch 78/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0159 - val_accuracy: 0.9969
#
# Epoch 00078: val_loss did not improve from 0.00299
# Epoch 79/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.0597 - val_accuracy: 0.9898
#
# Epoch 00079: val_loss did not improve from 0.00299
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.0177 - val_accuracy: 0.9969
#
# Epoch 00080: val_loss did not improve from 0.00299
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0229 - val_accuracy: 0.9961
#
# Epoch 00081: val_loss did not improve from 0.00299
# Epoch 82/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0139 - val_accuracy: 0.9965
#
# Epoch 00082: val_loss did not improve from 0.00299
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0259 - val_accuracy: 0.9957
#
# Epoch 00083: val_loss did not improve from 0.00299
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0122 - accuracy: 0.9973 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00084: val_loss did not improve from 0.00299
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0109 - accuracy: 0.9973 - val_loss: 0.0260 - val_accuracy: 0.9961
#
# Epoch 00085: val_loss did not improve from 0.00299
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.0263 - val_accuracy: 0.9965
#
# Epoch 00086: val_loss did not improve from 0.00299
# Epoch 87/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.0226 - val_accuracy: 0.9965
#
# Epoch 00087: val_loss did not improve from 0.00299
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0082 - val_accuracy: 0.9973
#
# Epoch 00088: val_loss did not improve from 0.00299
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.0306 - val_accuracy: 0.9957
#
# Epoch 00089: val_loss did not improve from 0.00299
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 0.0229 - val_accuracy: 0.9949
#
# Epoch 00090: val_loss did not improve from 0.00299
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 0.0192 - val_accuracy: 0.9969
#
# Epoch 00091: val_loss did not improve from 0.00299
# Epoch 92/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0183 - accuracy: 0.9950 - val_loss: 0.0158 - val_accuracy: 0.9973
#
# Epoch 00092: val_loss did not improve from 0.00299
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0117 - val_accuracy: 0.9969
#
# Epoch 00093: val_loss did not improve from 0.00299
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0154 - accuracy: 0.9964 - val_loss: 0.0357 - val_accuracy: 0.9957
#
# Epoch 00094: val_loss did not improve from 0.00299
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0142 - val_accuracy: 0.9965
#
# Epoch 00095: val_loss did not improve from 0.00299
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0088 - val_accuracy: 0.9973
#
# Epoch 00096: val_loss did not improve from 0.00299
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.0048 - val_accuracy: 0.9984
#
# Epoch 00097: val_loss did not improve from 0.00299
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0134 - val_accuracy: 0.9965
#
# Epoch 00098: val_loss did not improve from 0.00299
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0055 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00299
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.9899 - val_accuracy: 0.8727
#
# Epoch 00100: val_loss did not improve from 0.00299
# 80/80 [==============================] - 0s 3ms/step - loss: 0.9899 - accuracy: 0.8727
# Val Score:  [0.9898756146430969, 0.8726562261581421]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.6981 - accuracy: 0.8201 - val_loss: 1.6332 - val_accuracy: 0.7207
#
# Epoch 00001: val_loss did not improve from 0.00299
# Epoch 2/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.3302 - accuracy: 0.8949 - val_loss: 0.1322 - val_accuracy: 0.9512
#
# Epoch 00002: val_loss did not improve from 0.00299
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1995 - accuracy: 0.9313 - val_loss: 0.3412 - val_accuracy: 0.9027
#
# Epoch 00003: val_loss did not improve from 0.00299
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1399 - accuracy: 0.9528 - val_loss: 1.8279 - val_accuracy: 0.7141
#
# Epoch 00004: val_loss did not improve from 0.00299
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1162 - accuracy: 0.9621 - val_loss: 0.1607 - val_accuracy: 0.9328
#
# Epoch 00005: val_loss did not improve from 0.00299
# Epoch 6/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1330 - accuracy: 0.9567 - val_loss: 0.1092 - val_accuracy: 0.9535
#
# Epoch 00006: val_loss did not improve from 0.00299
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0920 - accuracy: 0.9706 - val_loss: 0.1915 - val_accuracy: 0.9469
#
# Epoch 00007: val_loss did not improve from 0.00299
# Epoch 8/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0729 - accuracy: 0.9758 - val_loss: 0.0838 - val_accuracy: 0.9699
#
# Epoch 00008: val_loss did not improve from 0.00299
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0591 - accuracy: 0.9797 - val_loss: 0.0132 - val_accuracy: 0.9973
#
# Epoch 00009: val_loss did not improve from 0.00299
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0525 - accuracy: 0.9827 - val_loss: 0.0116 - val_accuracy: 0.9965
#
# Epoch 00010: val_loss did not improve from 0.00299
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0569 - accuracy: 0.9826 - val_loss: 1.0659 - val_accuracy: 0.8266
#
# Epoch 00011: val_loss did not improve from 0.00299
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0355 - accuracy: 0.9882 - val_loss: 0.5492 - val_accuracy: 0.9012
#
# Epoch 00012: val_loss did not improve from 0.00299
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0406 - accuracy: 0.9864 - val_loss: 0.2649 - val_accuracy: 0.9484
#
# Epoch 00013: val_loss did not improve from 0.00299
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0469 - accuracy: 0.9854 - val_loss: 0.1051 - val_accuracy: 0.9730
#
# Epoch 00014: val_loss did not improve from 0.00299
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0535 - accuracy: 0.9825 - val_loss: 0.2691 - val_accuracy: 0.9133
#
# Epoch 00015: val_loss did not improve from 0.00299
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0452 - accuracy: 0.9854 - val_loss: 0.1902 - val_accuracy: 0.9434
#
# Epoch 00016: val_loss did not improve from 0.00299
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.0492 - val_accuracy: 0.9812
#
# Epoch 00017: val_loss did not improve from 0.00299
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0335 - accuracy: 0.9902 - val_loss: 0.4831 - val_accuracy: 0.8953
#
# Epoch 00018: val_loss did not improve from 0.00299
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0320 - accuracy: 0.9900 - val_loss: 0.0667 - val_accuracy: 0.9793
#
# Epoch 00019: val_loss did not improve from 0.00299
# Epoch 20/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0354 - accuracy: 0.9891 - val_loss: 0.3280 - val_accuracy: 0.9199
#
# Epoch 00020: val_loss did not improve from 0.00299
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0355 - accuracy: 0.9889 - val_loss: 0.0308 - val_accuracy: 0.9902
#
# Epoch 00021: val_loss did not improve from 0.00299
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0296 - accuracy: 0.9902 - val_loss: 0.3576 - val_accuracy: 0.9109
#
# Epoch 00022: val_loss did not improve from 0.00299
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0345 - accuracy: 0.9894 - val_loss: 0.2908 - val_accuracy: 0.9430
#
# Epoch 00023: val_loss did not improve from 0.00299
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0462 - accuracy: 0.9861 - val_loss: 0.4326 - val_accuracy: 0.9043
#
# Epoch 00024: val_loss did not improve from 0.00299
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.2167 - val_accuracy: 0.9535
#
# Epoch 00025: val_loss did not improve from 0.00299
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0270 - accuracy: 0.9924 - val_loss: 0.0431 - val_accuracy: 0.9887
#
# Epoch 00026: val_loss did not improve from 0.00299
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0410 - accuracy: 0.9890 - val_loss: 0.0259 - val_accuracy: 0.9910
#
# Epoch 00027: val_loss did not improve from 0.00299
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0325 - accuracy: 0.9903 - val_loss: 0.0225 - val_accuracy: 0.9926
#
# Epoch 00028: val_loss did not improve from 0.00299
# Epoch 29/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0325 - accuracy: 0.9906 - val_loss: 0.0699 - val_accuracy: 0.9812
#
# Epoch 00029: val_loss did not improve from 0.00299
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0309 - accuracy: 0.9915 - val_loss: 1.6090 - val_accuracy: 0.7992
#
# Epoch 00030: val_loss did not improve from 0.00299
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 0.0091 - val_accuracy: 0.9977
#
# Epoch 00031: val_loss did not improve from 0.00299
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.0327 - val_accuracy: 0.9914
#
# Epoch 00032: val_loss did not improve from 0.00299
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.2379 - val_accuracy: 0.9473
#
# Epoch 00033: val_loss did not improve from 0.00299
# Epoch 34/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0256 - accuracy: 0.9929 - val_loss: 0.0637 - val_accuracy: 0.9828
#
# Epoch 00034: val_loss did not improve from 0.00299
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0194 - accuracy: 0.9938 - val_loss: 0.0041 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00299
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.0169 - val_accuracy: 0.9953
#
# Epoch 00036: val_loss did not improve from 0.00299
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0146 - accuracy: 0.9947 - val_loss: 0.0194 - val_accuracy: 0.9941
#
# Epoch 00037: val_loss did not improve from 0.00299
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.0202 - val_accuracy: 0.9930
#
# Epoch 00038: val_loss did not improve from 0.00299
# Epoch 39/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.6961 - val_accuracy: 0.9008
#
# Epoch 00039: val_loss did not improve from 0.00299
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0203 - accuracy: 0.9940 - val_loss: 0.6666 - val_accuracy: 0.8828
#
# Epoch 00040: val_loss did not improve from 0.00299
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0317 - accuracy: 0.9915 - val_loss: 2.5519 - val_accuracy: 0.8164
#
# Epoch 00041: val_loss did not improve from 0.00299
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9927 - val_loss: 0.0238 - val_accuracy: 0.9930
#
# Epoch 00042: val_loss did not improve from 0.00299
# Epoch 43/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0285 - accuracy: 0.9925 - val_loss: 0.0112 - val_accuracy: 0.9965
#
# Epoch 00043: val_loss did not improve from 0.00299
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.0214 - val_accuracy: 0.9937
#
# Epoch 00044: val_loss did not improve from 0.00299
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.0078 - val_accuracy: 0.9977
#
# Epoch 00045: val_loss did not improve from 0.00299
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00046: val_loss did not improve from 0.00299
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0193 - accuracy: 0.9940 - val_loss: 0.0482 - val_accuracy: 0.9824
#
# Epoch 00047: val_loss did not improve from 0.00299
# Epoch 48/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0298 - accuracy: 0.9922 - val_loss: 0.0309 - val_accuracy: 0.9898
#
# Epoch 00048: val_loss did not improve from 0.00299
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9942 - val_loss: 1.3417 - val_accuracy: 0.8340
#
# Epoch 00049: val_loss did not improve from 0.00299
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0138 - accuracy: 0.9953 - val_loss: 0.3502 - val_accuracy: 0.9703
#
# Epoch 00050: val_loss did not improve from 0.00299
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0234 - accuracy: 0.9924 - val_loss: 0.1180 - val_accuracy: 0.9750
#
# Epoch 00051: val_loss did not improve from 0.00299
# Epoch 52/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0497 - val_accuracy: 0.9859
#
# Epoch 00052: val_loss did not improve from 0.00299
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0246 - accuracy: 0.9933 - val_loss: 1.8060 - val_accuracy: 0.7945
#
# Epoch 00053: val_loss did not improve from 0.00299
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0222 - accuracy: 0.9938 - val_loss: 0.0318 - val_accuracy: 0.9898
#
# Epoch 00054: val_loss did not improve from 0.00299
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.2517 - val_accuracy: 0.9500
#
# Epoch 00055: val_loss did not improve from 0.00299
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0171 - accuracy: 0.9954 - val_loss: 0.1878 - val_accuracy: 0.9602
#
# Epoch 00056: val_loss did not improve from 0.00299
# Epoch 57/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00057: val_loss did not improve from 0.00299
# Epoch 58/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.0099 - val_accuracy: 0.9973
#
# Epoch 00058: val_loss did not improve from 0.00299
# Epoch 59/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.0173 - val_accuracy: 0.9930
#
# Epoch 00059: val_loss did not improve from 0.00299
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0684 - val_accuracy: 0.9848
#
# Epoch 00060: val_loss did not improve from 0.00299
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.8327 - val_accuracy: 0.9004
#
# Epoch 00061: val_loss did not improve from 0.00299
# Epoch 62/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 1.6790 - val_accuracy: 0.8504
#
# Epoch 00062: val_loss did not improve from 0.00299
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0384 - accuracy: 0.9909 - val_loss: 0.0069 - val_accuracy: 0.9973
#
# Epoch 00063: val_loss did not improve from 0.00299
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0127 - accuracy: 0.9952 - val_loss: 0.0199 - val_accuracy: 0.9969
#
# Epoch 00064: val_loss did not improve from 0.00299
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.0444 - val_accuracy: 0.9879
#
# Epoch 00065: val_loss did not improve from 0.00299
# Epoch 66/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00066: val_loss did not improve from 0.00299
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0174 - accuracy: 0.9944 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00067: val_loss did not improve from 0.00299
# Epoch 68/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00068: val_loss improved from 0.00299 to 0.00263, saving model to model.h5
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0163 - accuracy: 0.9952 - val_loss: 0.0177 - val_accuracy: 0.9949
#
# Epoch 00069: val_loss did not improve from 0.00263
# Epoch 70/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0206 - accuracy: 0.9944 - val_loss: 0.1953 - val_accuracy: 0.9832
#
# Epoch 00070: val_loss did not improve from 0.00263
# Epoch 71/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0148 - accuracy: 0.9962 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00071: val_loss improved from 0.00263 to 0.00228, saving model to model.h5
# Epoch 72/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.0049 - val_accuracy: 0.9980
#
# Epoch 00072: val_loss did not improve from 0.00228
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0044 - val_accuracy: 0.9973
#
# Epoch 00073: val_loss did not improve from 0.00228
# Epoch 74/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0160 - accuracy: 0.9943 - val_loss: 0.1143 - val_accuracy: 0.9926
#
# Epoch 00074: val_loss did not improve from 0.00228
# Epoch 75/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.1586 - val_accuracy: 0.9953
#
# Epoch 00075: val_loss did not improve from 0.00228
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00228
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.0260 - val_accuracy: 0.9953
#
# Epoch 00077: val_loss did not improve from 0.00228
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0955 - val_accuracy: 0.9730
#
# Epoch 00078: val_loss did not improve from 0.00228
# Epoch 79/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00079: val_loss did not improve from 0.00228
# Epoch 80/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.0311 - val_accuracy: 0.9914
#
# Epoch 00080: val_loss did not improve from 0.00228
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 1.6002 - val_accuracy: 0.9008
#
# Epoch 00081: val_loss did not improve from 0.00228
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.0114 - val_accuracy: 0.9961
#
# Epoch 00082: val_loss did not improve from 0.00228
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.0108 - val_accuracy: 0.9961
#
# Epoch 00083: val_loss did not improve from 0.00228
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00084: val_loss did not improve from 0.00228
# Epoch 85/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0183 - val_accuracy: 0.9941
#
# Epoch 00085: val_loss did not improve from 0.00228
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0055 - val_accuracy: 0.9977
#
# Epoch 00086: val_loss did not improve from 0.00228
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9963 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00087: val_loss did not improve from 0.00228
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0178 - accuracy: 0.9964 - val_loss: 0.3570 - val_accuracy: 0.9789
#
# Epoch 00088: val_loss did not improve from 0.00228
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0421 - accuracy: 0.9916 - val_loss: 0.0065 - val_accuracy: 0.9984
#
# Epoch 00089: val_loss did not improve from 0.00228
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9959 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00228
# Epoch 91/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0101 - val_accuracy: 0.9973
#
# Epoch 00091: val_loss did not improve from 0.00228
# Epoch 92/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.0069 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00228
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.0198 - val_accuracy: 0.9937
#
# Epoch 00093: val_loss did not improve from 0.00228
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.0056 - val_accuracy: 0.9984
#
# Epoch 00094: val_loss did not improve from 0.00228
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00095: val_loss did not improve from 0.00228
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9967 - val_loss: 0.0636 - val_accuracy: 0.9840
#
# Epoch 00096: val_loss did not improve from 0.00228
# Epoch 97/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.0130 - val_accuracy: 0.9961
#
# Epoch 00097: val_loss did not improve from 0.00228
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0118 - accuracy: 0.9973 - val_loss: 0.0093 - val_accuracy: 0.9965
#
# Epoch 00098: val_loss did not improve from 0.00228
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.0482 - val_accuracy: 0.9926
#
# Epoch 00099: val_loss did not improve from 0.00228
# Epoch 100/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00100: val_loss did not improve from 0.00228
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 0.9984
# Val Score:  [0.0029617343097925186, 0.9984375238418579]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.5008 - accuracy: 0.8430 - val_loss: 0.8187 - val_accuracy: 0.7117
#
# Epoch 00001: val_loss did not improve from 0.00228
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1767 - accuracy: 0.9374 - val_loss: 0.3319 - val_accuracy: 0.8734
#
# Epoch 00002: val_loss did not improve from 0.00228
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1243 - accuracy: 0.9567 - val_loss: 0.4254 - val_accuracy: 0.8574
#
# Epoch 00003: val_loss did not improve from 0.00228
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0907 - accuracy: 0.9678 - val_loss: 0.1678 - val_accuracy: 0.9461
#
# Epoch 00004: val_loss did not improve from 0.00228
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0714 - accuracy: 0.9759 - val_loss: 0.3628 - val_accuracy: 0.8891
#
# Epoch 00005: val_loss did not improve from 0.00228
# Epoch 6/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0697 - accuracy: 0.9785 - val_loss: 0.0388 - val_accuracy: 0.9887
#
# Epoch 00006: val_loss did not improve from 0.00228
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0464 - accuracy: 0.9866 - val_loss: 0.0881 - val_accuracy: 0.9715
#
# Epoch 00007: val_loss did not improve from 0.00228
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0440 - accuracy: 0.9850 - val_loss: 0.0943 - val_accuracy: 0.9719
#
# Epoch 00008: val_loss did not improve from 0.00228
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0404 - accuracy: 0.9877 - val_loss: 0.0325 - val_accuracy: 0.9867
#
# Epoch 00009: val_loss did not improve from 0.00228
# Epoch 10/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0386 - accuracy: 0.9885 - val_loss: 0.0157 - val_accuracy: 0.9961
#
# Epoch 00010: val_loss did not improve from 0.00228
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0577 - accuracy: 0.9831 - val_loss: 0.0203 - val_accuracy: 0.9937
#
# Epoch 00011: val_loss did not improve from 0.00228
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.0242 - val_accuracy: 0.9969
#
# Epoch 00012: val_loss did not improve from 0.00228
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0617 - accuracy: 0.9821 - val_loss: 0.2723 - val_accuracy: 0.9324
#
# Epoch 00013: val_loss did not improve from 0.00228
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0524 - accuracy: 0.9833 - val_loss: 0.1036 - val_accuracy: 0.9652
#
# Epoch 00014: val_loss did not improve from 0.00228
# Epoch 15/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0329 - accuracy: 0.9906 - val_loss: 0.0841 - val_accuracy: 0.9785
#
# Epoch 00015: val_loss did not improve from 0.00228
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0262 - accuracy: 0.9921 - val_loss: 0.0066 - val_accuracy: 0.9969
#
# Epoch 00016: val_loss did not improve from 0.00228
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0322 - accuracy: 0.9897 - val_loss: 0.1551 - val_accuracy: 0.9473
#
# Epoch 00017: val_loss did not improve from 0.00228
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0258 - accuracy: 0.9925 - val_loss: 0.0257 - val_accuracy: 0.9910
#
# Epoch 00018: val_loss did not improve from 0.00228
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0525 - accuracy: 0.9849 - val_loss: 0.0992 - val_accuracy: 0.9746
#
# Epoch 00019: val_loss did not improve from 0.00228
# Epoch 20/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0362 - accuracy: 0.9895 - val_loss: 0.0643 - val_accuracy: 0.9828
#
# Epoch 00020: val_loss did not improve from 0.00228
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0285 - accuracy: 0.9912 - val_loss: 0.5001 - val_accuracy: 0.8918
#
# Epoch 00021: val_loss did not improve from 0.00228
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0237 - accuracy: 0.9927 - val_loss: 0.0102 - val_accuracy: 0.9969
#
# Epoch 00022: val_loss did not improve from 0.00228
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0279 - accuracy: 0.9916 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00023: val_loss did not improve from 0.00228
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 0.0388 - val_accuracy: 0.9887
#
# Epoch 00024: val_loss did not improve from 0.00228
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.0310 - val_accuracy: 0.9918
#
# Epoch 00025: val_loss did not improve from 0.00228
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0163 - accuracy: 0.9944 - val_loss: 0.0111 - val_accuracy: 0.9953
#
# Epoch 00026: val_loss did not improve from 0.00228
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0278 - accuracy: 0.9928 - val_loss: 0.0076 - val_accuracy: 0.9969
#
# Epoch 00027: val_loss did not improve from 0.00228
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.0254 - val_accuracy: 0.9922
#
# Epoch 00028: val_loss did not improve from 0.00228
# Epoch 29/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0167 - accuracy: 0.9935 - val_loss: 0.0369 - val_accuracy: 0.9898
#
# Epoch 00029: val_loss did not improve from 0.00228
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0259 - accuracy: 0.9915 - val_loss: 0.0105 - val_accuracy: 0.9961
#
# Epoch 00030: val_loss did not improve from 0.00228
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.1488 - val_accuracy: 0.9555
#
# Epoch 00031: val_loss did not improve from 0.00228
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0349 - accuracy: 0.9907 - val_loss: 0.2557 - val_accuracy: 0.9496
#
# Epoch 00032: val_loss did not improve from 0.00228
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0261 - accuracy: 0.9928 - val_loss: 0.0081 - val_accuracy: 0.9977
#
# Epoch 00033: val_loss did not improve from 0.00228
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0136 - accuracy: 0.9959 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00034: val_loss did not improve from 0.00228
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0079 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00228
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0182 - val_accuracy: 0.9957
#
# Epoch 00036: val_loss did not improve from 0.00228
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.0163 - val_accuracy: 0.9953
#
# Epoch 00037: val_loss did not improve from 0.00228
# Epoch 38/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0384 - accuracy: 0.9895 - val_loss: 0.1861 - val_accuracy: 0.9539
#
# Epoch 00038: val_loss did not improve from 0.00228
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0112 - val_accuracy: 0.9965
#
# Epoch 00039: val_loss did not improve from 0.00228
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.0299 - val_accuracy: 0.9906
#
# Epoch 00040: val_loss did not improve from 0.00228
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9944 - val_loss: 0.0276 - val_accuracy: 0.9906
#
# ...
#
# Epoch 00020: val_loss did not improve from 0.00225
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.2238 - val_accuracy: 0.9383
#
# Epoch 00021: val_loss did not improve from 0.00225
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0209 - accuracy: 0.9923 - val_loss: 0.0205 - val_accuracy: 0.9918
#
# Epoch 00022: val_loss did not improve from 0.00225
# Epoch 23/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0236 - accuracy: 0.9914 - val_loss: 0.0610 - val_accuracy: 0.9797
#
# Epoch 00023: val_loss did not improve from 0.00225
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0165 - accuracy: 0.9933 - val_loss: 0.0106 - val_accuracy: 0.9945
#
# Epoch 00024: val_loss did not improve from 0.00225
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00025: val_loss did not improve from 0.00225
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0116 - accuracy: 0.9958 - val_loss: 0.0234 - val_accuracy: 0.9953
#
# Epoch 00026: val_loss did not improve from 0.00225
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.4402 - val_accuracy: 0.8988
#
# Epoch 00027: val_loss did not improve from 0.00225
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0243 - accuracy: 0.9920 - val_loss: 0.1197 - val_accuracy: 0.9563
#
# Epoch 00028: val_loss did not improve from 0.00225
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00029: val_loss did not improve from 0.00225
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.1617 - val_accuracy: 0.9555
#
# Epoch 00030: val_loss did not improve from 0.00225
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.1124 - val_accuracy: 0.9695
#
# Epoch 00031: val_loss did not improve from 0.00225
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0184 - accuracy: 0.9940 - val_loss: 0.0158 - val_accuracy: 0.9965
#
# Epoch 00032: val_loss did not improve from 0.00225
# Epoch 33/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0241 - accuracy: 0.9930 - val_loss: 0.0610 - val_accuracy: 0.9863
#
# Epoch 00033: val_loss did not improve from 0.00225
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.0316 - val_accuracy: 0.9902
#
# Epoch 00034: val_loss did not improve from 0.00225
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.5828 - val_accuracy: 0.8805
#
# Epoch 00035: val_loss did not improve from 0.00225
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9941 - val_loss: 0.0491 - val_accuracy: 0.9855
#
# Epoch 00036: val_loss did not improve from 0.00225
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0118 - accuracy: 0.9954 - val_loss: 0.0222 - val_accuracy: 0.9941
#
# Epoch 00037: val_loss did not improve from 0.00225
# Epoch 38/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0085 - val_accuracy: 0.9969
#
# Epoch 00038: val_loss did not improve from 0.00225
# Epoch 39/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.0080 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00225
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.0430 - val_accuracy: 0.9906
#
# Epoch 00040: val_loss did not improve from 0.00225
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0100 - val_accuracy: 0.9965
#
# Epoch 00041: val_loss did not improve from 0.00225
# Epoch 42/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.0385 - val_accuracy: 0.9891
#
# Epoch 00042: val_loss did not improve from 0.00225
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9948 - val_loss: 0.0119 - val_accuracy: 0.9945
#
# Epoch 00043: val_loss did not improve from 0.00225
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9952 - val_loss: 0.0129 - val_accuracy: 0.9969
#
# Epoch 00044: val_loss did not improve from 0.00225
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9968 - val_loss: 0.0201 - val_accuracy: 0.9965
#
# Epoch 00045: val_loss did not improve from 0.00225
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 0.0073 - val_accuracy: 0.9973
#
# Epoch 00046: val_loss did not improve from 0.00225
# Epoch 47/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 1.7969 - val_accuracy: 0.8074
#
# Epoch 00047: val_loss did not improve from 0.00225
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.9955 - val_loss: 0.4707 - val_accuracy: 0.8820
#
# Epoch 00048: val_loss did not improve from 0.00225
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0116 - accuracy: 0.9946 - val_loss: 0.0474 - val_accuracy: 0.9828
#
# Epoch 00049: val_loss did not improve from 0.00225
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9949 - val_loss: 0.0147 - val_accuracy: 0.9957
#
# Epoch 00050: val_loss did not improve from 0.00225
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0047 - val_accuracy: 0.9984
#
# Epoch 00051: val_loss did not improve from 0.00225
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0161 - val_accuracy: 0.9945
#
# Epoch 00052: val_loss did not improve from 0.00225
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.0118 - val_accuracy: 0.9969
#
# Epoch 00053: val_loss did not improve from 0.00225
# Epoch 54/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.2944 - val_accuracy: 0.9312
#
# Epoch 00054: val_loss did not improve from 0.00225
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.4470 - val_accuracy: 0.8949
#
# Epoch 00055: val_loss did not improve from 0.00225
# Epoch 56/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0217 - accuracy: 0.9939 - val_loss: 0.1292 - val_accuracy: 0.9730
#
# Epoch 00056: val_loss did not improve from 0.00225
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9954 - val_loss: 0.0058 - val_accuracy: 0.9965
#
# Epoch 00057: val_loss did not improve from 0.00225
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00058: val_loss did not improve from 0.00225
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0097 - val_accuracy: 0.9969
#
# Epoch 00059: val_loss did not improve from 0.00225
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00060: val_loss did not improve from 0.00225
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0240 - val_accuracy: 0.9926
#
# Epoch 00061: val_loss did not improve from 0.00225
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 0.0128 - val_accuracy: 0.9965
#
# Epoch 00062: val_loss did not improve from 0.00225
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9965 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00063: val_loss did not improve from 0.00225
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00064: val_loss did not improve from 0.00225
# Epoch 65/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9961 - val_loss: 0.0044 - val_accuracy: 0.9977
#
# Epoch 00065: val_loss did not improve from 0.00225
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0043 - val_accuracy: 0.9977
#
# Epoch 00066: val_loss did not improve from 0.00225
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0043 - accuracy: 0.9979 - val_loss: 0.0118 - val_accuracy: 0.9969
#
# Epoch 00067: val_loss did not improve from 0.00225
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0109 - val_accuracy: 0.9973
#
# Epoch 00068: val_loss did not improve from 0.00225
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.1368 - val_accuracy: 0.9754
#
# Epoch 00069: val_loss did not improve from 0.00225
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0161 - accuracy: 0.9955 - val_loss: 0.0141 - val_accuracy: 0.9953
#
# Epoch 00070: val_loss did not improve from 0.00225
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0111 - val_accuracy: 0.9949
#
# Epoch 00071: val_loss did not improve from 0.00225
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0079 - val_accuracy: 0.9977
#
# Epoch 00072: val_loss did not improve from 0.00225
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0207 - val_accuracy: 0.9902
#
# Epoch 00073: val_loss did not improve from 0.00225
# Epoch 74/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0102 - accuracy: 0.9960 - val_loss: 0.0258 - val_accuracy: 0.9949
#
# Epoch 00074: val_loss did not improve from 0.00225
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.8464 - val_accuracy: 0.8195
#
# Epoch 00075: val_loss did not improve from 0.00225
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 0.0070 - val_accuracy: 0.9977
#
# Epoch 00076: val_loss did not improve from 0.00225
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9970 - val_loss: 0.0068 - val_accuracy: 0.9973
#
# Epoch 00077: val_loss did not improve from 0.00225
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0129 - val_accuracy: 0.9977
#
# Epoch 00078: val_loss did not improve from 0.00225
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0105 - val_accuracy: 0.9969
#
# Epoch 00079: val_loss did not improve from 0.00225
# Epoch 80/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0352 - val_accuracy: 0.9891
#
# Epoch 00080: val_loss did not improve from 0.00225
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.0785 - val_accuracy: 0.9887
#
# Epoch 00081: val_loss did not improve from 0.00225
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0202 - val_accuracy: 0.9937
#
# Epoch 00082: val_loss did not improve from 0.00225
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.0351 - val_accuracy: 0.9930
#
# Epoch 00083: val_loss did not improve from 0.00225
# Epoch 84/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0086 - accuracy: 0.9966 - val_loss: 0.0121 - val_accuracy: 0.9969
#
# Epoch 00084: val_loss did not improve from 0.00225
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0053 - val_accuracy: 0.9973
#
# Epoch 00085: val_loss did not improve from 0.00225
# Epoch 86/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0051 - accuracy: 0.9974 - val_loss: 0.0086 - val_accuracy: 0.9969
#
# Epoch 00086: val_loss did not improve from 0.00225
# Epoch 87/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00225
# Epoch 88/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9972 - val_loss: 0.0059 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00225
# Epoch 89/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0359 - val_accuracy: 0.9891
#
# Epoch 00089: val_loss did not improve from 0.00225
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9964 - val_loss: 0.0137 - val_accuracy: 0.9965
#
# Epoch 00090: val_loss did not improve from 0.00225
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0374 - val_accuracy: 0.9937
#
# Epoch 00091: val_loss did not improve from 0.00225
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9972 - val_loss: 0.0090 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00225
# Epoch 93/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0176 - val_accuracy: 0.9965
#
# Epoch 00093: val_loss did not improve from 0.00225
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00225
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9971 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00095: val_loss did not improve from 0.00225
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0099 - accuracy: 0.9957 - val_loss: 0.0198 - val_accuracy: 0.9953
#
# Epoch 00096: val_loss did not improve from 0.00225
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0178 - val_accuracy: 0.9945
#
# Epoch 00097: val_loss did not improve from 0.00225
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.0072 - val_accuracy: 0.9969
#
# Epoch 00098: val_loss did not improve from 0.00225
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0084 - val_accuracy: 0.9965
#
# Epoch 00099: val_loss did not improve from 0.00225
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0195 - val_accuracy: 0.9937
#
# Epoch 00100: val_loss did not improve from 0.00225
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 0.9937
# Val Score:  [0.01951717399060726, 0.9937499761581421]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9962
# Test Accuracy: 99.62499737739563

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
