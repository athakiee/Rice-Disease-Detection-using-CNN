# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 25
INIT_LR = 1e-4
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_144 (Conv2D)          (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_216 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_180 (Bat (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_145 (Conv2D)          (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_217 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_181 (Bat (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_218 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_182 (Bat (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_109 (Dropout)        (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_147 (Conv2D)          (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_219 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_183 (Bat (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_72 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_220 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_184 (Bat (None, 1024)              4096
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_73 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_221 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/25
# 320/320 [==============================] - 4s 9ms/step - loss: 0.5278 - accuracy: 0.8313 - val_loss: 5.7672 - val_accuracy: 0.3281
#
# Epoch 00001: val_loss improved from inf to 5.76720, saving model to model.h5
# Epoch 2/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2228 - accuracy: 0.9214 - val_loss: 1.9854 - val_accuracy: 0.6898
#
# Epoch 00002: val_loss improved from 5.76720 to 1.98537, saving model to model.h5
# Epoch 3/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1402 - accuracy: 0.9502 - val_loss: 1.0327 - val_accuracy: 0.7727
#
# Epoch 00003: val_loss improved from 1.98537 to 1.03267, saving model to model.h5
# Epoch 4/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1137 - accuracy: 0.9601 - val_loss: 0.9011 - val_accuracy: 0.7910
#
# Epoch 00004: val_loss improved from 1.03267 to 0.90106, saving model to model.h5
# Epoch 5/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0945 - accuracy: 0.9687 - val_loss: 1.0094 - val_accuracy: 0.7836
#
# Epoch 00005: val_loss did not improve from 0.90106
# Epoch 6/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0748 - accuracy: 0.9764 - val_loss: 0.7760 - val_accuracy: 0.8125
#
# Epoch 00006: val_loss improved from 0.90106 to 0.77600, saving model to model.h5
# Epoch 7/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0665 - accuracy: 0.9765 - val_loss: 0.4751 - val_accuracy: 0.8785
#
# Epoch 00007: val_loss improved from 0.77600 to 0.47514, saving model to model.h5
# Epoch 8/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0555 - accuracy: 0.9817 - val_loss: 0.8115 - val_accuracy: 0.8273
#
# Epoch 00008: val_loss did not improve from 0.47514
# Epoch 9/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0564 - accuracy: 0.9828 - val_loss: 1.1699 - val_accuracy: 0.8098
#
# Epoch 00009: val_loss did not improve from 0.47514
# Epoch 10/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0511 - accuracy: 0.9854 - val_loss: 0.7046 - val_accuracy: 0.8363
#
# Epoch 00010: val_loss did not improve from 0.47514
# Epoch 11/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0443 - accuracy: 0.9861 - val_loss: 0.4895 - val_accuracy: 0.8840
#
# Epoch 00011: val_loss did not improve from 0.47514
# Epoch 12/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0452 - accuracy: 0.9859 - val_loss: 0.2880 - val_accuracy: 0.9195
#
# Epoch 00012: val_loss improved from 0.47514 to 0.28799, saving model to model.h5
# Epoch 13/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0353 - accuracy: 0.9879 - val_loss: 0.8630 - val_accuracy: 0.8215
#
# Epoch 00013: val_loss did not improve from 0.28799
# Epoch 14/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0306 - accuracy: 0.9904 - val_loss: 0.5762 - val_accuracy: 0.8730
#
# Epoch 00014: val_loss did not improve from 0.28799
# Epoch 15/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0292 - accuracy: 0.9915 - val_loss: 0.6952 - val_accuracy: 0.8395
#
# Epoch 00015: val_loss did not improve from 0.28799
# Epoch 16/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0350 - accuracy: 0.9896 - val_loss: 0.3809 - val_accuracy: 0.8953
#
# Epoch 00016: val_loss did not improve from 0.28799
# Epoch 17/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0353 - accuracy: 0.9886 - val_loss: 0.4182 - val_accuracy: 0.9062
#
# Epoch 00017: val_loss did not improve from 0.28799
# Epoch 18/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0326 - accuracy: 0.9901 - val_loss: 0.8401 - val_accuracy: 0.8652
#
# Epoch 00018: val_loss did not improve from 0.28799
# Epoch 19/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0306 - accuracy: 0.9903 - val_loss: 0.2729 - val_accuracy: 0.9340
#
# Epoch 00019: val_loss improved from 0.28799 to 0.27292, saving model to model.h5
# Epoch 20/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0242 - accuracy: 0.9926 - val_loss: 0.3970 - val_accuracy: 0.9141
#
# Epoch 00020: val_loss did not improve from 0.27292
# Epoch 21/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0215 - accuracy: 0.9939 - val_loss: 0.3829 - val_accuracy: 0.9137
#
# Epoch 00021: val_loss did not improve from 0.27292
# Epoch 22/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0246 - accuracy: 0.9928 - val_loss: 0.2388 - val_accuracy: 0.9422
#
# Epoch 00022: val_loss improved from 0.27292 to 0.23876, saving model to model.h5
# Epoch 23/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0218 - accuracy: 0.9921 - val_loss: 0.2432 - val_accuracy: 0.9355
#
# Epoch 00023: val_loss did not improve from 0.23876
# Epoch 24/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0195 - accuracy: 0.9945 - val_loss: 0.1526 - val_accuracy: 0.9625
#
# Epoch 00024: val_loss improved from 0.23876 to 0.15260, saving model to model.h5
# Epoch 25/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0187 - accuracy: 0.9946 - val_loss: 0.1433 - val_accuracy: 0.9637
#
# Epoch 00025: val_loss improved from 0.15260 to 0.14331, saving model to model.h5
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1433 - accuracy: 0.9637
# Val Score:  [0.14330704510211945, 0.963671863079071]
# Training on Fold:  2
# Epoch 1/25
# 320/320 [==============================] - 4s 9ms/step - loss: 0.3386 - accuracy: 0.8905 - val_loss: 7.8864 - val_accuracy: 0.4922
#
# Epoch 00001: val_loss did not improve from 0.14331
# Epoch 2/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1314 - accuracy: 0.9559 - val_loss: 1.5513 - val_accuracy: 0.6730
#
# Epoch 00002: val_loss did not improve from 0.14331
# Epoch 3/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0818 - accuracy: 0.9736 - val_loss: 0.3830 - val_accuracy: 0.8863
#
# Epoch 00003: val_loss did not improve from 0.14331
# Epoch 4/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0642 - accuracy: 0.9777 - val_loss: 0.2512 - val_accuracy: 0.9238
#
# Epoch 00004: val_loss did not improve from 0.14331
# Epoch 5/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0551 - accuracy: 0.9831 - val_loss: 0.3478 - val_accuracy: 0.8895
#
# Epoch 00005: val_loss did not improve from 0.14331
# Epoch 6/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0444 - accuracy: 0.9865 - val_loss: 0.4753 - val_accuracy: 0.8797
#
# Epoch 00006: val_loss did not improve from 0.14331
# Epoch 7/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0396 - accuracy: 0.9883 - val_loss: 0.2561 - val_accuracy: 0.9270
#
# Epoch 00007: val_loss did not improve from 0.14331
# Epoch 8/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0363 - accuracy: 0.9878 - val_loss: 0.3941 - val_accuracy: 0.9105
#
# Epoch 00008: val_loss did not improve from 0.14331
# Epoch 9/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.3612 - val_accuracy: 0.9062
#
# Epoch 00009: val_loss did not improve from 0.14331
# Epoch 10/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0290 - accuracy: 0.9909 - val_loss: 0.1891 - val_accuracy: 0.9520
#
# Epoch 00010: val_loss did not improve from 0.14331
# Epoch 11/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0237 - accuracy: 0.9921 - val_loss: 0.2944 - val_accuracy: 0.9250
#
# Epoch 00011: val_loss did not improve from 0.14331
# Epoch 12/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0193 - accuracy: 0.9949 - val_loss: 0.1358 - val_accuracy: 0.9605
#
# Epoch 00012: val_loss improved from 0.14331 to 0.13578, saving model to model.h5
# Epoch 13/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.0977 - val_accuracy: 0.9703
#
# Epoch 00013: val_loss improved from 0.13578 to 0.09771, saving model to model.h5
# Epoch 14/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0167 - accuracy: 0.9953 - val_loss: 0.1136 - val_accuracy: 0.9719
#
# Epoch 00014: val_loss did not improve from 0.09771
# Epoch 15/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0174 - accuracy: 0.9944 - val_loss: 0.1474 - val_accuracy: 0.9547
#
# Epoch 00015: val_loss did not improve from 0.09771
# Epoch 16/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.0329 - val_accuracy: 0.9883
#
# Epoch 00016: val_loss improved from 0.09771 to 0.03291, saving model to model.h5
# Epoch 17/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0231 - accuracy: 0.9927 - val_loss: 0.1383 - val_accuracy: 0.9582
#
# Epoch 00017: val_loss did not improve from 0.03291
# Epoch 18/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0252 - accuracy: 0.9931 - val_loss: 0.0577 - val_accuracy: 0.9785
#
# Epoch 00018: val_loss did not improve from 0.03291
# Epoch 19/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.0861 - val_accuracy: 0.9742
#
# Epoch 00019: val_loss did not improve from 0.03291
# Epoch 20/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0288 - val_accuracy: 0.9887
#
# Epoch 00020: val_loss improved from 0.03291 to 0.02878, saving model to model.h5
# Epoch 21/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.0513 - val_accuracy: 0.9855
#
# Epoch 00021: val_loss did not improve from 0.02878
# Epoch 22/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0150 - accuracy: 0.9954 - val_loss: 0.0274 - val_accuracy: 0.9926
#
# Epoch 00022: val_loss improved from 0.02878 to 0.02738, saving model to model.h5
# Epoch 23/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0123 - accuracy: 0.9963 - val_loss: 0.0832 - val_accuracy: 0.9762
#
# Epoch 00023: val_loss did not improve from 0.02738
# Epoch 24/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.0723 - val_accuracy: 0.9805
#
# Epoch 00024: val_loss did not improve from 0.02738
# Epoch 25/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0172 - val_accuracy: 0.9949
#
# Epoch 00025: val_loss improved from 0.02738 to 0.01717, saving model to model.h5
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 0.9949
# Val Score:  [0.01716584526002407, 0.994921863079071]
# Training on Fold:  3
# Epoch 1/25
# 320/320 [==============================] - 4s 9ms/step - loss: 0.3717 - accuracy: 0.8854 - val_loss: 4.6269 - val_accuracy: 0.5223
#
# Epoch 00001: val_loss did not improve from 0.01717
# Epoch 2/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1411 - accuracy: 0.9490 - val_loss: 1.1016 - val_accuracy: 0.7586
#
# Epoch 00002: val_loss did not improve from 0.01717
# Epoch 3/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0982 - accuracy: 0.9664 - val_loss: 0.4354 - val_accuracy: 0.8762
#
# Epoch 00003: val_loss did not improve from 0.01717
# Epoch 4/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0728 - accuracy: 0.9736 - val_loss: 0.2837 - val_accuracy: 0.9242
#
# Epoch 00004: val_loss did not improve from 0.01717
# Epoch 5/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0557 - accuracy: 0.9810 - val_loss: 0.2061 - val_accuracy: 0.9410
#
# Epoch 00005: val_loss did not improve from 0.01717
# Epoch 6/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0599 - accuracy: 0.9812 - val_loss: 0.2197 - val_accuracy: 0.9371
#
# Epoch 00006: val_loss did not improve from 0.01717
# Epoch 7/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0463 - accuracy: 0.9842 - val_loss: 0.0814 - val_accuracy: 0.9762
#
# Epoch 00007: val_loss did not improve from 0.01717
# Epoch 8/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0398 - accuracy: 0.9881 - val_loss: 0.1179 - val_accuracy: 0.9676
#
# Epoch 00008: val_loss did not improve from 0.01717
# Epoch 9/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0388 - accuracy: 0.9874 - val_loss: 0.2801 - val_accuracy: 0.9207
#
# Epoch 00009: val_loss did not improve from 0.01717
# Epoch 10/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0337 - accuracy: 0.9897 - val_loss: 0.1826 - val_accuracy: 0.9559
#
# Epoch 00010: val_loss did not improve from 0.01717
# Epoch 11/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0349 - accuracy: 0.9890 - val_loss: 0.0942 - val_accuracy: 0.9809
#
# Epoch 00011: val_loss did not improve from 0.01717
# Epoch 12/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0274 - accuracy: 0.9914 - val_loss: 0.0575 - val_accuracy: 0.9859
#
# Epoch 00012: val_loss did not improve from 0.01717
# Epoch 13/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0317 - accuracy: 0.9897 - val_loss: 0.0990 - val_accuracy: 0.9777
#
# Epoch 00013: val_loss did not improve from 0.01717
# Epoch 14/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0239 - accuracy: 0.9923 - val_loss: 0.0399 - val_accuracy: 0.9898
#
# Epoch 00014: val_loss did not improve from 0.01717
# Epoch 15/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.0642 - val_accuracy: 0.9902
#
# Epoch 00015: val_loss did not improve from 0.01717
# Epoch 16/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0222 - accuracy: 0.9921 - val_loss: 0.0451 - val_accuracy: 0.9918
#
# Epoch 00016: val_loss did not improve from 0.01717
# Epoch 17/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0227 - accuracy: 0.9919 - val_loss: 0.0443 - val_accuracy: 0.9914
#
# Epoch 00017: val_loss did not improve from 0.01717
# Epoch 18/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0186 - accuracy: 0.9936 - val_loss: 0.0122 - val_accuracy: 0.9961
#
# Epoch 00018: val_loss improved from 0.01717 to 0.01217, saving model to model.h5
# Epoch 19/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.0275 - val_accuracy: 0.9930
#
# Epoch 00019: val_loss did not improve from 0.01217
# Epoch 20/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 0.0275 - val_accuracy: 0.9945
#
# Epoch 00020: val_loss did not improve from 0.01217
# Epoch 21/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.0661 - val_accuracy: 0.9828
#
# Epoch 00021: val_loss did not improve from 0.01217
# Epoch 22/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0167 - accuracy: 0.9943 - val_loss: 0.0406 - val_accuracy: 0.9926
#
# Epoch 00022: val_loss did not improve from 0.01217
# Epoch 23/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.0177 - val_accuracy: 0.9961
#
# Epoch 00023: val_loss did not improve from 0.01217
# Epoch 24/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9947 - val_loss: 0.0641 - val_accuracy: 0.9801
#
# Epoch 00024: val_loss did not improve from 0.01217
# Epoch 25/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0138 - accuracy: 0.9953 - val_loss: 0.0045 - val_accuracy: 0.9973
#
# Epoch 00025: val_loss improved from 0.01217 to 0.00451, saving model to model.h5
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9973
# Val Score:  [0.004514061380177736, 0.997265636920929]
# Training on Fold:  4
# Epoch 1/25
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4020 - accuracy: 0.8794 - val_loss: 6.8204 - val_accuracy: 0.4660
#
# Epoch 00001: val_loss did not improve from 0.00451
# Epoch 2/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1339 - accuracy: 0.9507 - val_loss: 0.9355 - val_accuracy: 0.7770
#
# Epoch 00002: val_loss did not improve from 0.00451
# Epoch 3/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1084 - accuracy: 0.9636 - val_loss: 0.1682 - val_accuracy: 0.9410
#
# Epoch 00003: val_loss did not improve from 0.00451
# Epoch 4/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0822 - accuracy: 0.9707 - val_loss: 0.2493 - val_accuracy: 0.9180
#
# Epoch 00004: val_loss did not improve from 0.00451
# Epoch 5/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0652 - accuracy: 0.9775 - val_loss: 0.1506 - val_accuracy: 0.9512
#
# Epoch 00005: val_loss did not improve from 0.00451
# Epoch 6/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0479 - accuracy: 0.9835 - val_loss: 0.2075 - val_accuracy: 0.9395
#
# Epoch 00006: val_loss did not improve from 0.00451
# Epoch 7/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0486 - accuracy: 0.9839 - val_loss: 0.1427 - val_accuracy: 0.9594
#
# Epoch 00007: val_loss did not improve from 0.00451
# Epoch 8/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0378 - accuracy: 0.9885 - val_loss: 0.1194 - val_accuracy: 0.9664
#
# Epoch 00008: val_loss did not improve from 0.00451
# Epoch 9/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0439 - accuracy: 0.9858 - val_loss: 0.1753 - val_accuracy: 0.9496
#
# Epoch 00009: val_loss did not improve from 0.00451
# Epoch 10/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0314 - accuracy: 0.9893 - val_loss: 0.1257 - val_accuracy: 0.9656
#
# Epoch 00010: val_loss did not improve from 0.00451
# Epoch 11/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0325 - accuracy: 0.9896 - val_loss: 0.0951 - val_accuracy: 0.9766
#
# Epoch 00011: val_loss did not improve from 0.00451
# Epoch 12/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0289 - accuracy: 0.9897 - val_loss: 0.1015 - val_accuracy: 0.9754
#
# Epoch 00012: val_loss did not improve from 0.00451
# Epoch 13/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0226 - accuracy: 0.9926 - val_loss: 0.0882 - val_accuracy: 0.9812
#
# Epoch 00013: val_loss did not improve from 0.00451
# Epoch 14/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0223 - accuracy: 0.9930 - val_loss: 0.1137 - val_accuracy: 0.9746
#
# Epoch 00014: val_loss did not improve from 0.00451
# Epoch 15/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0224 - accuracy: 0.9938 - val_loss: 0.0489 - val_accuracy: 0.9879
#
# Epoch 00015: val_loss did not improve from 0.00451
# Epoch 16/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.0883 - val_accuracy: 0.9867
#
# Epoch 00016: val_loss did not improve from 0.00451
# Epoch 17/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0198 - accuracy: 0.9941 - val_loss: 0.0479 - val_accuracy: 0.9926
#
# Epoch 00017: val_loss did not improve from 0.00451
# Epoch 18/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0157 - accuracy: 0.9947 - val_loss: 0.0807 - val_accuracy: 0.9793
#
# Epoch 00018: val_loss did not improve from 0.00451
# Epoch 19/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0202 - accuracy: 0.9941 - val_loss: 0.0761 - val_accuracy: 0.9871
#
# Epoch 00019: val_loss did not improve from 0.00451
# Epoch 20/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0159 - accuracy: 0.9935 - val_loss: 0.0668 - val_accuracy: 0.9949
#
# Epoch 00020: val_loss did not improve from 0.00451
# Epoch 21/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0160 - accuracy: 0.9938 - val_loss: 0.0439 - val_accuracy: 0.9906
#
# Epoch 00021: val_loss did not improve from 0.00451
# Epoch 22/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0292 - val_accuracy: 0.9949
#
# Epoch 00022: val_loss did not improve from 0.00451
# Epoch 23/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0490 - val_accuracy: 0.9941
#
# Epoch 00023: val_loss did not improve from 0.00451
# Epoch 24/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9945 - val_loss: 0.0420 - val_accuracy: 0.9934
#
# Epoch 00024: val_loss did not improve from 0.00451
# Epoch 25/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.0510 - val_accuracy: 0.9930
#
# Epoch 00025: val_loss did not improve from 0.00451
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9930
# Val Score:  [0.05101324990391731, 0.992968738079071]
# Training on Fold:  5
# Epoch 1/25
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4083 - accuracy: 0.8724 - val_loss: 5.9459 - val_accuracy: 0.5047
#
# Epoch 00001: val_loss did not improve from 0.00451
# Epoch 2/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1488 - accuracy: 0.9457 - val_loss: 1.6665 - val_accuracy: 0.6898
#
# Epoch 00002: val_loss did not improve from 0.00451
# Epoch 3/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1047 - accuracy: 0.9619 - val_loss: 0.9504 - val_accuracy: 0.7891
#
# Epoch 00003: val_loss did not improve from 0.00451
# Epoch 4/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0741 - accuracy: 0.9771 - val_loss: 0.8732 - val_accuracy: 0.8219
#
# Epoch 00004: val_loss did not improve from 0.00451
# Epoch 5/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0692 - accuracy: 0.9759 - val_loss: 0.8173 - val_accuracy: 0.8195
#
# Epoch 00005: val_loss did not improve from 0.00451
# Epoch 6/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0599 - accuracy: 0.9801 - val_loss: 0.6283 - val_accuracy: 0.8586
#
# Epoch 00006: val_loss did not improve from 0.00451
# Epoch 7/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0420 - accuracy: 0.9857 - val_loss: 0.5840 - val_accuracy: 0.8680
#
# Epoch 00007: val_loss did not improve from 0.00451
# Epoch 8/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0366 - accuracy: 0.9882 - val_loss: 0.6689 - val_accuracy: 0.8707
#
# Epoch 00008: val_loss did not improve from 0.00451
# Epoch 9/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0414 - accuracy: 0.9871 - val_loss: 0.4939 - val_accuracy: 0.8844
#
# Epoch 00009: val_loss did not improve from 0.00451
# Epoch 10/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0300 - accuracy: 0.9901 - val_loss: 0.4623 - val_accuracy: 0.8855
#
# Epoch 00010: val_loss did not improve from 0.00451
# Epoch 11/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0324 - accuracy: 0.9895 - val_loss: 0.3715 - val_accuracy: 0.9031
#
# Epoch 00011: val_loss did not improve from 0.00451
# Epoch 12/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0294 - accuracy: 0.9913 - val_loss: 0.1444 - val_accuracy: 0.9629
#
# Epoch 00012: val_loss did not improve from 0.00451
# Epoch 13/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0263 - accuracy: 0.9928 - val_loss: 0.1862 - val_accuracy: 0.9531
#
# Epoch 00013: val_loss did not improve from 0.00451
# Epoch 14/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0226 - accuracy: 0.9935 - val_loss: 0.2790 - val_accuracy: 0.9262
#
# Epoch 00014: val_loss did not improve from 0.00451
# Epoch 15/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0237 - accuracy: 0.9932 - val_loss: 0.2339 - val_accuracy: 0.9391
#
# Epoch 00015: val_loss did not improve from 0.00451
# Epoch 16/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0188 - accuracy: 0.9938 - val_loss: 0.3349 - val_accuracy: 0.9148
#
# Epoch 00016: val_loss did not improve from 0.00451
# Epoch 17/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9943 - val_loss: 0.1694 - val_accuracy: 0.9527
#
# Epoch 00017: val_loss did not improve from 0.00451
# Epoch 18/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.1953 - val_accuracy: 0.9457
#
# Epoch 00018: val_loss did not improve from 0.00451
# Epoch 19/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.1368 - val_accuracy: 0.9602
#
# Epoch 00019: val_loss did not improve from 0.00451
# Epoch 20/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0234 - accuracy: 0.9931 - val_loss: 0.2749 - val_accuracy: 0.9336
#
# Epoch 00020: val_loss did not improve from 0.00451
# Epoch 21/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0195 - accuracy: 0.9949 - val_loss: 0.3274 - val_accuracy: 0.9117
#
# Epoch 00021: val_loss did not improve from 0.00451
# Epoch 22/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0181 - accuracy: 0.9945 - val_loss: 0.0600 - val_accuracy: 0.9820
#
# Epoch 00022: val_loss did not improve from 0.00451
# Epoch 23/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.1676 - val_accuracy: 0.9516
#
# Epoch 00023: val_loss did not improve from 0.00451
# Epoch 24/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.0560 - val_accuracy: 0.9820
#
# Epoch 00024: val_loss did not improve from 0.00451
# Epoch 25/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.1137 - val_accuracy: 0.9699
#
# Epoch 00025: val_loss did not improve from 0.00451
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1137 - accuracy: 0.9699
# Val Score:  [0.11370216310024261, 0.969921886920929]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9962
# Test Accuracy: 99.62499737739563

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
