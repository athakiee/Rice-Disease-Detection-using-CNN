# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **HIDDEN LAYER TEST -- USING ONLY 3 HIDDEN LAYER**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
#model.add(Conv2D(128, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_35 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_36 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_37 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              6554624
# _________________________________________________________________
# activation_38 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_39 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 6,586,852
# Trainable params: 6,584,580
# Non-trainable params: 2,272
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.3775 - accuracy: 0.8747 - val_loss: 3.5633 - val_accuracy: 0.6238
#
# Epoch 00001: val_loss improved from inf to 3.56327, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1440 - accuracy: 0.9502 - val_loss: 1.3505 - val_accuracy: 0.7711
#
# Epoch 00002: val_loss improved from 3.56327 to 1.35049, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1105 - accuracy: 0.9606 - val_loss: 0.2959 - val_accuracy: 0.9004
#
# Epoch 00003: val_loss improved from 1.35049 to 0.29586, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0791 - accuracy: 0.9741 - val_loss: 0.4672 - val_accuracy: 0.8359
#
# Epoch 00004: val_loss did not improve from 0.29586
# Epoch 5/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0783 - accuracy: 0.9743 - val_loss: 0.1823 - val_accuracy: 0.9395
#
# Epoch 00005: val_loss improved from 0.29586 to 0.18232, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0679 - accuracy: 0.9776 - val_loss: 0.1181 - val_accuracy: 0.9602
#
# Epoch 00006: val_loss improved from 0.18232 to 0.11812, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0467 - accuracy: 0.9850 - val_loss: 0.0295 - val_accuracy: 0.9895
#
# Epoch 00007: val_loss improved from 0.11812 to 0.02952, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0589 - accuracy: 0.9812 - val_loss: 0.0721 - val_accuracy: 0.9879
#
# Epoch 00008: val_loss did not improve from 0.02952
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0449 - accuracy: 0.9858 - val_loss: 1.9296 - val_accuracy: 0.7047
#
# Epoch 00009: val_loss did not improve from 0.02952
# Epoch 10/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0425 - accuracy: 0.9871 - val_loss: 0.0237 - val_accuracy: 0.9914
#
# Epoch 00010: val_loss improved from 0.02952 to 0.02372, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0484 - accuracy: 0.9859 - val_loss: 0.0689 - val_accuracy: 0.9805
#
# Epoch 00011: val_loss did not improve from 0.02372
# Epoch 12/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0604 - accuracy: 0.9814 - val_loss: 0.0813 - val_accuracy: 0.9793
#
# Epoch 00012: val_loss did not improve from 0.02372
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0484 - accuracy: 0.9850 - val_loss: 2.5838 - val_accuracy: 0.5984
#
# Epoch 00013: val_loss did not improve from 0.02372
# Epoch 14/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0463 - accuracy: 0.9865 - val_loss: 0.2437 - val_accuracy: 0.9348
#
# Epoch 00014: val_loss did not improve from 0.02372
# Epoch 15/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0373 - accuracy: 0.9878 - val_loss: 0.0292 - val_accuracy: 0.9941
#
# Epoch 00015: val_loss did not improve from 0.02372
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0309 - accuracy: 0.9897 - val_loss: 0.0285 - val_accuracy: 0.9941
#
# Epoch 00016: val_loss did not improve from 0.02372
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0265 - accuracy: 0.9924 - val_loss: 0.0517 - val_accuracy: 0.9832
#
# Epoch 00017: val_loss did not improve from 0.02372
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0320 - accuracy: 0.9917 - val_loss: 0.0344 - val_accuracy: 0.9887
#
# Epoch 00018: val_loss did not improve from 0.02372
# Epoch 19/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0399 - accuracy: 0.9895 - val_loss: 0.1281 - val_accuracy: 0.9613
#
# Epoch 00019: val_loss did not improve from 0.02372
# Epoch 20/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0328 - accuracy: 0.9899 - val_loss: 0.0119 - val_accuracy: 0.9969
#
# Epoch 00020: val_loss improved from 0.02372 to 0.01194, saving model to model.h5
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0292 - accuracy: 0.9917 - val_loss: 1.6921 - val_accuracy: 0.6914
#
# Epoch 00021: val_loss did not improve from 0.01194
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0425 - accuracy: 0.9884 - val_loss: 0.0152 - val_accuracy: 0.9949
#
# Epoch 00022: val_loss did not improve from 0.01194
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0363 - accuracy: 0.9892 - val_loss: 0.0265 - val_accuracy: 0.9961
#
# Epoch 00023: val_loss did not improve from 0.01194
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.0061 - val_accuracy: 0.9988
#
# Epoch 00024: val_loss improved from 0.01194 to 0.00611, saving model to model.h5
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0239 - accuracy: 0.9929 - val_loss: 0.1115 - val_accuracy: 0.9680
#
# Epoch 00025: val_loss did not improve from 0.00611
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0304 - accuracy: 0.9915 - val_loss: 0.0266 - val_accuracy: 0.9902
#
# Epoch 00026: val_loss did not improve from 0.00611
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0261 - accuracy: 0.9923 - val_loss: 1.7593 - val_accuracy: 0.6910
#
# Epoch 00027: val_loss did not improve from 0.00611
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0270 - accuracy: 0.9936 - val_loss: 0.0188 - val_accuracy: 0.9961
#
# Epoch 00028: val_loss did not improve from 0.00611
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0330 - accuracy: 0.9918 - val_loss: 0.0279 - val_accuracy: 0.9926
#
# Epoch 00029: val_loss did not improve from 0.00611
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.2229 - val_accuracy: 0.9426
#
# Epoch 00030: val_loss did not improve from 0.00611
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0259 - accuracy: 0.9930 - val_loss: 0.3922 - val_accuracy: 0.9187
#
# Epoch 00031: val_loss did not improve from 0.00611
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0213 - accuracy: 0.9940 - val_loss: 0.0131 - val_accuracy: 0.9977
#
# Epoch 00032: val_loss did not improve from 0.00611
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0197 - accuracy: 0.9943 - val_loss: 0.0219 - val_accuracy: 0.9949
#
# Epoch 00033: val_loss did not improve from 0.00611
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0243 - accuracy: 0.9929 - val_loss: 0.0407 - val_accuracy: 0.9891
#
# Epoch 00034: val_loss did not improve from 0.00611
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.1403 - val_accuracy: 0.9531
#
# Epoch 00035: val_loss did not improve from 0.00611
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0167 - accuracy: 0.9963 - val_loss: 0.0404 - val_accuracy: 0.9922
#
# Epoch 00036: val_loss did not improve from 0.00611
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0220 - accuracy: 0.9935 - val_loss: 0.0243 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss did not improve from 0.00611
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0237 - accuracy: 0.9946 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00038: val_loss did not improve from 0.00611
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9949 - val_loss: 0.2297 - val_accuracy: 0.9473
#
# Epoch 00039: val_loss did not improve from 0.00611
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0233 - accuracy: 0.9942 - val_loss: 0.0379 - val_accuracy: 0.9902
#
# Epoch 00040: val_loss did not improve from 0.00611
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0360 - accuracy: 0.9917 - val_loss: 0.0597 - val_accuracy: 0.9859
#
# Epoch 00041: val_loss did not improve from 0.00611
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0247 - accuracy: 0.9924 - val_loss: 0.0107 - val_accuracy: 0.9965
#
# Epoch 00042: val_loss did not improve from 0.00611
# Epoch 43/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0202 - accuracy: 0.9949 - val_loss: 0.0048 - val_accuracy: 0.9969
#
# Epoch 00043: val_loss improved from 0.00611 to 0.00481, saving model to model.h5
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.0138 - val_accuracy: 0.9965
#
# Epoch 00044: val_loss did not improve from 0.00481
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 0.0083 - val_accuracy: 0.9973
#
# Epoch 00045: val_loss did not improve from 0.00481
# Epoch 46/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.0223 - val_accuracy: 0.9969
#
# Epoch 00046: val_loss did not improve from 0.00481
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0049 - val_accuracy: 0.9980
#
# Epoch 00047: val_loss did not improve from 0.00481
# Epoch 48/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0766 - val_accuracy: 0.9969
#
# Epoch 00048: val_loss did not improve from 0.00481
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0158 - accuracy: 0.9956 - val_loss: 0.0315 - val_accuracy: 0.9937
#
# Epoch 00049: val_loss did not improve from 0.00481
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0221 - accuracy: 0.9939 - val_loss: 0.1644 - val_accuracy: 0.9605
#
# Epoch 00050: val_loss did not improve from 0.00481
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 0.0433 - val_accuracy: 0.9949
#
# Epoch 00051: val_loss did not improve from 0.00481
# Epoch 52/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.0166 - val_accuracy: 0.9961
#
# Epoch 00052: val_loss did not improve from 0.00481
# Epoch 53/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.0248 - val_accuracy: 0.9930
#
# Epoch 00053: val_loss did not improve from 0.00481
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0296 - val_accuracy: 0.9934
#
# Epoch 00054: val_loss did not improve from 0.00481
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.0047 - val_accuracy: 0.9984
#
# Epoch 00055: val_loss improved from 0.00481 to 0.00471, saving model to model.h5
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0090 - val_accuracy: 0.9977
#
# Epoch 00056: val_loss did not improve from 0.00471
# Epoch 57/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.2093 - val_accuracy: 0.9457
#
# Epoch 00057: val_loss did not improve from 0.00471
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00058: val_loss did not improve from 0.00471
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 0.0095 - val_accuracy: 0.9973
#
# Epoch 00059: val_loss did not improve from 0.00471
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.0077 - val_accuracy: 0.9977
#
# Epoch 00060: val_loss did not improve from 0.00471
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0152 - accuracy: 0.9955 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00061: val_loss improved from 0.00471 to 0.00397, saving model to model.h5
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0218 - val_accuracy: 0.9965
#
# Epoch 00062: val_loss did not improve from 0.00397
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.0537 - val_accuracy: 0.9805
#
# Epoch 00063: val_loss did not improve from 0.00397
# Epoch 64/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.2925 - val_accuracy: 0.9242
#
# Epoch 00064: val_loss did not improve from 0.00397
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0298 - val_accuracy: 0.9941
#
# Epoch 00065: val_loss did not improve from 0.00397
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.0082 - val_accuracy: 0.9969
#
# Epoch 00066: val_loss did not improve from 0.00397
# Epoch 67/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0240 - accuracy: 0.9937 - val_loss: 0.0086 - val_accuracy: 0.9977
#
# Epoch 00067: val_loss did not improve from 0.00397
# Epoch 68/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0128 - accuracy: 0.9961 - val_loss: 0.0105 - val_accuracy: 0.9957
#
# Epoch 00068: val_loss did not improve from 0.00397
# Epoch 69/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.0120 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00397
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9960 - val_loss: 0.0133 - val_accuracy: 0.9965
#
# Epoch 00070: val_loss did not improve from 0.00397
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9957 - val_loss: 0.1235 - val_accuracy: 0.9723
#
# Epoch 00071: val_loss did not improve from 0.00397
# Epoch 72/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.0182 - val_accuracy: 0.9973
#
# Epoch 00072: val_loss did not improve from 0.00397
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0253 - val_accuracy: 0.9949
#
# Epoch 00073: val_loss did not improve from 0.00397
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.0325 - val_accuracy: 0.9863
#
# Epoch 00074: val_loss did not improve from 0.00397
# Epoch 75/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0169 - val_accuracy: 0.9941
#
# Epoch 00075: val_loss did not improve from 0.00397
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9970 - val_loss: 0.0362 - val_accuracy: 0.9875
#
# Epoch 00076: val_loss did not improve from 0.00397
# Epoch 77/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0053 - val_accuracy: 0.9977
#
# Epoch 00077: val_loss did not improve from 0.00397
# Epoch 78/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.0182 - val_accuracy: 0.9941
#
# Epoch 00078: val_loss did not improve from 0.00397
# Epoch 79/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 0.0150 - val_accuracy: 0.9961
#
# Epoch 00079: val_loss did not improve from 0.00397
# Epoch 80/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0050 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00397
# Epoch 81/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0051 - val_accuracy: 0.9984
#
# Epoch 00081: val_loss did not improve from 0.00397
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0047 - val_accuracy: 0.9977
#
# Epoch 00082: val_loss did not improve from 0.00397
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00083: val_loss improved from 0.00397 to 0.00211, saving model to model.h5
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.7834 - val_accuracy: 0.8703
#
# Epoch 00084: val_loss did not improve from 0.00211
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00085: val_loss did not improve from 0.00211
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0167 - val_accuracy: 0.9953
#
# Epoch 00086: val_loss did not improve from 0.00211
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 0.0045 - val_accuracy: 0.9988
#
# Epoch 00087: val_loss did not improve from 0.00211
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 0.0625 - val_accuracy: 0.9957
#
# Epoch 00088: val_loss did not improve from 0.00211
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.0843 - val_accuracy: 0.9750
#
# Epoch 00089: val_loss did not improve from 0.00211
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.0157 - val_accuracy: 0.9926
#
# Epoch 00090: val_loss did not improve from 0.00211
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00211
# Epoch 92/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.0035 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00211
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.0470 - val_accuracy: 0.9863
#
# Epoch 00093: val_loss did not improve from 0.00211
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9953 - val_loss: 0.0083 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00211
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0910 - val_accuracy: 0.9691
#
# Epoch 00095: val_loss did not improve from 0.00211
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0183 - val_accuracy: 0.9969
#
# Epoch 00096: val_loss did not improve from 0.00211
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0064 - accuracy: 0.9971 - val_loss: 0.0132 - val_accuracy: 0.9977
#
# Epoch 00097: val_loss did not improve from 0.00211
# Epoch 98/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.0075 - val_accuracy: 0.9973
#
# Epoch 00098: val_loss did not improve from 0.00211
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9970 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00211
# Epoch 100/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00211
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9980
# Val Score:  [0.005735710728913546, 0.998046875]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.5019 - accuracy: 0.8417 - val_loss: 1.6683 - val_accuracy: 0.6062
#
# Epoch 00001: val_loss did not improve from 0.00211
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1927 - accuracy: 0.9312 - val_loss: 0.1891 - val_accuracy: 0.9277
#
# Epoch 00002: val_loss did not improve from 0.00211
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1139 - accuracy: 0.9575 - val_loss: 0.1213 - val_accuracy: 0.9473
#
# Epoch 00003: val_loss did not improve from 0.00211
# Epoch 4/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0956 - accuracy: 0.9691 - val_loss: 0.1362 - val_accuracy: 0.9570
#
# Epoch 00004: val_loss did not improve from 0.00211
# Epoch 5/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0690 - accuracy: 0.9756 - val_loss: 0.1424 - val_accuracy: 0.9516
#
# Epoch 00005: val_loss did not improve from 0.00211
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0566 - accuracy: 0.9812 - val_loss: 0.0594 - val_accuracy: 0.9766
#
# Epoch 00006: val_loss did not improve from 0.00211
# Epoch 7/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0622 - accuracy: 0.9797 - val_loss: 0.0247 - val_accuracy: 0.9937
#
# Epoch 00007: val_loss did not improve from 0.00211
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0477 - accuracy: 0.9862 - val_loss: 0.0866 - val_accuracy: 0.9660
#
# Epoch 00008: val_loss did not improve from 0.00211
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0364 - accuracy: 0.9882 - val_loss: 0.0834 - val_accuracy: 0.9930
#
# Epoch 00009: val_loss did not improve from 0.00211
# Epoch 10/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0651 - accuracy: 0.9806 - val_loss: 0.0141 - val_accuracy: 0.9953
#
# Epoch 00010: val_loss did not improve from 0.00211
# Epoch 11/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0426 - accuracy: 0.9868 - val_loss: 0.0239 - val_accuracy: 0.9953
#
# Epoch 00011: val_loss did not improve from 0.00211
# Epoch 12/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0316 - accuracy: 0.9903 - val_loss: 0.0192 - val_accuracy: 0.9969
#
# Epoch 00012: val_loss did not improve from 0.00211
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0276 - accuracy: 0.9899 - val_loss: 0.0233 - val_accuracy: 0.9937
#
# Epoch 00013: val_loss did not improve from 0.00211
# Epoch 14/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0344 - accuracy: 0.9903 - val_loss: 0.0155 - val_accuracy: 0.9957
#
# Epoch 00014: val_loss did not improve from 0.00211
# Epoch 15/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0247 - accuracy: 0.9916 - val_loss: 0.0284 - val_accuracy: 0.9910
#
# Epoch 00015: val_loss did not improve from 0.00211
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0333 - accuracy: 0.9887 - val_loss: 0.0635 - val_accuracy: 0.9859
#
# Epoch 00016: val_loss did not improve from 0.00211
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0318 - accuracy: 0.9899 - val_loss: 0.0100 - val_accuracy: 0.9965
#
# Epoch 00017: val_loss did not improve from 0.00211
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0241 - accuracy: 0.9931 - val_loss: 0.1290 - val_accuracy: 0.9590
#
# Epoch 00018: val_loss did not improve from 0.00211
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 0.0096 - val_accuracy: 0.9961
#
# Epoch 00019: val_loss did not improve from 0.00211
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.0155 - val_accuracy: 0.9957
#
# Epoch 00020: val_loss did not improve from 0.00211
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0265 - accuracy: 0.9934 - val_loss: 0.0431 - val_accuracy: 0.9910
#
# Epoch 00021: val_loss did not improve from 0.00211
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0216 - accuracy: 0.9933 - val_loss: 0.0179 - val_accuracy: 0.9926
#
# Epoch 00022: val_loss did not improve from 0.00211
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0178 - accuracy: 0.9946 - val_loss: 0.0229 - val_accuracy: 0.9961
#
# Epoch 00023: val_loss did not improve from 0.00211
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0352 - accuracy: 0.9896 - val_loss: 0.0258 - val_accuracy: 0.9949
#
# Epoch 00024: val_loss did not improve from 0.00211
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.0076 - val_accuracy: 0.9980
#
# Epoch 00025: val_loss did not improve from 0.00211
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 0.0573 - val_accuracy: 0.9824
#
# Epoch 00026: val_loss did not improve from 0.00211
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.0149 - val_accuracy: 0.9965
#
# Epoch 00027: val_loss did not improve from 0.00211
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.0257 - val_accuracy: 0.9918
#
# Epoch 00028: val_loss did not improve from 0.00211
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 0.1539 - val_accuracy: 0.9520
#
# Epoch 00029: val_loss did not improve from 0.00211
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.0138 - val_accuracy: 0.9961
#
# Epoch 00030: val_loss did not improve from 0.00211
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.0251 - val_accuracy: 0.9922
#
# Epoch 00031: val_loss did not improve from 0.00211
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0297 - accuracy: 0.9906 - val_loss: 0.0083 - val_accuracy: 0.9969
#
# Epoch 00032: val_loss did not improve from 0.00211
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00033: val_loss did not improve from 0.00211
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.0085 - val_accuracy: 0.9973
#
# Epoch 00034: val_loss did not improve from 0.00211
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0160 - accuracy: 0.9943 - val_loss: 0.0654 - val_accuracy: 0.9801
#
# Epoch 00035: val_loss did not improve from 0.00211
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0201 - accuracy: 0.9940 - val_loss: 0.0376 - val_accuracy: 0.9863
#
# Epoch 00036: val_loss did not improve from 0.00211
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0070 - val_accuracy: 0.9984
#
# Epoch 00037: val_loss did not improve from 0.00211
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0058 - val_accuracy: 0.9984
#
# Epoch 00038: val_loss did not improve from 0.00211
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00039: val_loss did not improve from 0.00211
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0217 - accuracy: 0.9933 - val_loss: 0.0095 - val_accuracy: 0.9984
#
# Epoch 00040: val_loss did not improve from 0.00211
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9962 - val_loss: 0.0483 - val_accuracy: 0.9863
#
# Epoch 00041: val_loss did not improve from 0.00211
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0077 - val_accuracy: 0.9977
#
# Epoch 00042: val_loss did not improve from 0.00211
# Epoch 43/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0123 - val_accuracy: 0.9961
#
# Epoch 00043: val_loss did not improve from 0.00211
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.0103 - val_accuracy: 0.9977
#
# Epoch 00044: val_loss did not improve from 0.00211
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.0235 - val_accuracy: 0.9937
#
# Epoch 00045: val_loss did not improve from 0.00211
# Epoch 46/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0283 - val_accuracy: 0.9922
#
# Epoch 00046: val_loss did not improve from 0.00211
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0167 - accuracy: 0.9940 - val_loss: 0.0265 - val_accuracy: 0.9922
#
# Epoch 00047: val_loss did not improve from 0.00211
# Epoch 48/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0228 - val_accuracy: 0.9918
#
# Epoch 00048: val_loss did not improve from 0.00211
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.0337 - val_accuracy: 0.9914
#
# Epoch 00049: val_loss did not improve from 0.00211
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00050: val_loss did not improve from 0.00211
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00051: val_loss did not improve from 0.00211
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0055 - val_accuracy: 0.9977
#
# Epoch 00052: val_loss did not improve from 0.00211
# Epoch 53/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0332 - val_accuracy: 0.9906
#
# Epoch 00053: val_loss did not improve from 0.00211
# Epoch 54/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0107 - val_accuracy: 0.9949
#
# Epoch 00054: val_loss did not improve from 0.00211
# Epoch 55/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0238 - val_accuracy: 0.9922
#
# Epoch 00055: val_loss did not improve from 0.00211
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.0203 - val_accuracy: 0.9918
#
# Epoch 00056: val_loss did not improve from 0.00211
# Epoch 57/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0119 - accuracy: 0.9953 - val_loss: 0.0142 - val_accuracy: 0.9953
#
# Epoch 00057: val_loss did not improve from 0.00211
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.0092 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00211
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0945 - val_accuracy: 0.9758
#
# Epoch 00059: val_loss did not improve from 0.00211
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.0048 - val_accuracy: 0.9977
#
# Epoch 00060: val_loss did not improve from 0.00211
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 0.0119 - val_accuracy: 0.9961
#
# Epoch 00061: val_loss did not improve from 0.00211
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0069 - val_accuracy: 0.9973
#
# Epoch 00062: val_loss did not improve from 0.00211
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00063: val_loss did not improve from 0.00211
# Epoch 64/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9965 - val_loss: 0.0139 - val_accuracy: 0.9957
#
# Epoch 00064: val_loss did not improve from 0.00211
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.1190 - val_accuracy: 0.9746
#
# Epoch 00065: val_loss did not improve from 0.00211
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0135 - val_accuracy: 0.9953
#
# Epoch 00066: val_loss did not improve from 0.00211
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0055 - val_accuracy: 0.9980
#
# Epoch 00067: val_loss did not improve from 0.00211
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.0347 - val_accuracy: 0.9906
#
# Epoch 00068: val_loss did not improve from 0.00211
# Epoch 69/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0125 - accuracy: 0.9954 - val_loss: 0.0091 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00211
# Epoch 70/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00211
# Epoch 71/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.0090 - val_accuracy: 0.9969
#
# Epoch 00071: val_loss did not improve from 0.00211
# Epoch 72/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00072: val_loss did not improve from 0.00211
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0081 - accuracy: 0.9966 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00073: val_loss did not improve from 0.00211
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0127 - accuracy: 0.9955 - val_loss: 0.0088 - val_accuracy: 0.9977
#
# Epoch 00074: val_loss did not improve from 0.00211
# Epoch 75/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00211
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0080 - accuracy: 0.9963 - val_loss: 0.0108 - val_accuracy: 0.9961
#
# Epoch 00076: val_loss did not improve from 0.00211
# Epoch 77/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0021 - val_accuracy: 0.9984
#
# Epoch 00077: val_loss improved from 0.00211 to 0.00207, saving model to model.h5
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00078: val_loss did not improve from 0.00207
# Epoch 79/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0318 - val_accuracy: 0.9914
#
# Epoch 00079: val_loss did not improve from 0.00207
# Epoch 80/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0091 - accuracy: 0.9962 - val_loss: 0.1043 - val_accuracy: 0.9695
#
# Epoch 00080: val_loss did not improve from 0.00207
# Epoch 81/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00081: val_loss did not improve from 0.00207
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0122 - val_accuracy: 0.9973
#
# Epoch 00082: val_loss did not improve from 0.00207
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.0060 - val_accuracy: 0.9973
#
# Epoch 00083: val_loss did not improve from 0.00207
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9960 - val_loss: 0.0293 - val_accuracy: 0.9926
#
# Epoch 00084: val_loss did not improve from 0.00207
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.0142 - val_accuracy: 0.9969
#
# Epoch 00085: val_loss did not improve from 0.00207
# Epoch 86/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.0098 - val_accuracy: 0.9973
#
# Epoch 00086: val_loss did not improve from 0.00207
# Epoch 87/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0187 - val_accuracy: 0.9969
#
# Epoch 00087: val_loss did not improve from 0.00207
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0333 - val_accuracy: 0.9930
#
# Epoch 00088: val_loss did not improve from 0.00207
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0244 - val_accuracy: 0.9937
#
# Epoch 00089: val_loss did not improve from 0.00207
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00090: val_loss did not improve from 0.00207
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0061 - accuracy: 0.9973 - val_loss: 0.0031 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00207
# Epoch 92/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0338 - val_accuracy: 0.9926
#
# Epoch 00092: val_loss did not improve from 0.00207
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0086 - val_accuracy: 0.9969
#
# Epoch 00093: val_loss did not improve from 0.00207
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00094: val_loss did not improve from 0.00207
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00095: val_loss did not improve from 0.00207
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0413 - val_accuracy: 0.9840
#
# Epoch 00096: val_loss did not improve from 0.00207
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0040 - val_accuracy: 0.9973
#
# Epoch 00097: val_loss did not improve from 0.00207
# Epoch 98/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00207
# Epoch 99/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00099: val_loss did not improve from 0.00207
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9968 - val_loss: 0.0040 - val_accuracy: 0.9969
#
# Epoch 00100: val_loss did not improve from 0.00207
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.9969
# Val Score:  [0.004001484718173742, 0.996874988079071]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.5278 - accuracy: 0.8187 - val_loss: 9.7747 - val_accuracy: 0.4488
#
# Epoch 00001: val_loss did not improve from 0.00207
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2120 - accuracy: 0.9179 - val_loss: 0.7620 - val_accuracy: 0.7781
#
# Epoch 00002: val_loss did not improve from 0.00207
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1375 - accuracy: 0.9521 - val_loss: 0.2409 - val_accuracy: 0.9164
#
# Epoch 00003: val_loss did not improve from 0.00207
# Epoch 4/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1112 - accuracy: 0.9611 - val_loss: 0.1037 - val_accuracy: 0.9652
#
# Epoch 00004: val_loss did not improve from 0.00207
# Epoch 5/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0962 - accuracy: 0.9656 - val_loss: 0.5121 - val_accuracy: 0.8711
#
# Epoch 00005: val_loss did not improve from 0.00207
# Epoch 6/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0864 - accuracy: 0.9723 - val_loss: 1.3491 - val_accuracy: 0.7117
#
# Epoch 00006: val_loss did not improve from 0.00207
# Epoch 7/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0653 - accuracy: 0.9796 - val_loss: 0.0469 - val_accuracy: 0.9816
#
# Epoch 00007: val_loss did not improve from 0.00207
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0518 - accuracy: 0.9834 - val_loss: 0.0566 - val_accuracy: 0.9852
#
# Epoch 00008: val_loss did not improve from 0.00207
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0458 - accuracy: 0.9840 - val_loss: 0.0216 - val_accuracy: 0.9941
#
# Epoch 00009: val_loss did not improve from 0.00207
# Epoch 10/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0353 - accuracy: 0.9885 - val_loss: 0.0261 - val_accuracy: 0.9926
#
# Epoch 00010: val_loss did not improve from 0.00207
# Epoch 11/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0523 - accuracy: 0.9853 - val_loss: 0.0792 - val_accuracy: 0.9867
#
# Epoch 00011: val_loss did not improve from 0.00207
# Epoch 12/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0772 - accuracy: 0.9763 - val_loss: 0.0248 - val_accuracy: 0.9867
#
# Epoch 00012: val_loss did not improve from 0.00207
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0380 - accuracy: 0.9884 - val_loss: 0.0431 - val_accuracy: 0.9867
#
# Epoch 00013: val_loss did not improve from 0.00207
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0379 - accuracy: 0.9867 - val_loss: 0.0186 - val_accuracy: 0.9930
#
# Epoch 00014: val_loss did not improve from 0.00207
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0335 - accuracy: 0.9889 - val_loss: 0.0618 - val_accuracy: 0.9828
#
# Epoch 00015: val_loss did not improve from 0.00207
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0318 - accuracy: 0.9897 - val_loss: 0.0606 - val_accuracy: 0.9805
#
# Epoch 00016: val_loss did not improve from 0.00207
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0266 - accuracy: 0.9913 - val_loss: 0.0540 - val_accuracy: 0.9820
#
# Epoch 00017: val_loss did not improve from 0.00207
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0333 - accuracy: 0.9890 - val_loss: 0.0520 - val_accuracy: 0.9840
#
# Epoch 00018: val_loss did not improve from 0.00207
# Epoch 19/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0307 - accuracy: 0.9897 - val_loss: 0.0076 - val_accuracy: 0.9965
#
# Epoch 00019: val_loss did not improve from 0.00207
# Epoch 20/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.9927 - val_loss: 0.0508 - val_accuracy: 0.9859
#
# Epoch 00020: val_loss did not improve from 0.00207
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 0.3287 - val_accuracy: 0.9250
#
# Epoch 00021: val_loss did not improve from 0.00207
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0194 - accuracy: 0.9934 - val_loss: 0.0136 - val_accuracy: 0.9961
#
# Epoch 00022: val_loss did not improve from 0.00207
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.0988 - val_accuracy: 0.9762
#
# Epoch 00023: val_loss did not improve from 0.00207
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.0048 - val_accuracy: 0.9984
#
# Epoch 00024: val_loss did not improve from 0.00207
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.9939 - val_loss: 0.5342 - val_accuracy: 0.8805
#
# Epoch 00025: val_loss did not improve from 0.00207
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0202 - accuracy: 0.9923 - val_loss: 0.0107 - val_accuracy: 0.9961
#
# Epoch 00026: val_loss did not improve from 0.00207
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0334 - accuracy: 0.9900 - val_loss: 0.1050 - val_accuracy: 0.9730
#
# Epoch 00027: val_loss did not improve from 0.00207
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0225 - val_accuracy: 0.9941
#
# Epoch 00028: val_loss did not improve from 0.00207
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.0221 - val_accuracy: 0.9930
#
# Epoch 00029: val_loss did not improve from 0.00207
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0170 - accuracy: 0.9941 - val_loss: 0.1986 - val_accuracy: 0.9586
#
# Epoch 00030: val_loss did not improve from 0.00207
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0244 - accuracy: 0.9911 - val_loss: 0.0092 - val_accuracy: 0.9969
#
# Epoch 00031: val_loss did not improve from 0.00207
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0330 - accuracy: 0.9911 - val_loss: 1.4312 - val_accuracy: 0.7340
#
# Epoch 00032: val_loss did not improve from 0.00207
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0325 - accuracy: 0.9898 - val_loss: 0.0080 - val_accuracy: 0.9973
#
# Epoch 00033: val_loss did not improve from 0.00207
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0212 - accuracy: 0.9930 - val_loss: 0.0145 - val_accuracy: 0.9957
#
# Epoch 00034: val_loss did not improve from 0.00207
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0138 - accuracy: 0.9946 - val_loss: 0.0161 - val_accuracy: 0.9953
#
# Epoch 00035: val_loss did not improve from 0.00207
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0155 - accuracy: 0.9942 - val_loss: 0.2062 - val_accuracy: 0.9453
#
# Epoch 00036: val_loss did not improve from 0.00207
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0460 - accuracy: 0.9864 - val_loss: 0.0137 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss did not improve from 0.00207
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0199 - accuracy: 0.9925 - val_loss: 0.0327 - val_accuracy: 0.9902
#
# Epoch 00038: val_loss did not improve from 0.00207
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.0094 - val_accuracy: 0.9973
#
# Epoch 00039: val_loss did not improve from 0.00207
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9958 - val_loss: 0.0101 - val_accuracy: 0.9977
#
# Epoch 00040: val_loss did not improve from 0.00207
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.0219 - val_accuracy: 0.9930
#
# Epoch 00041: val_loss did not improve from 0.00207
# Epoch 42/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00199
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0219 - accuracy: 0.9933 - val_loss: 0.3471 - val_accuracy: 0.9137
#
# Epoch 00021: val_loss did not improve from 0.00199
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0300 - accuracy: 0.9914 - val_loss: 0.0228 - val_accuracy: 0.9930
#
# Epoch 00022: val_loss did not improve from 0.00199
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0145 - val_accuracy: 0.9934
#
# Epoch 00023: val_loss did not improve from 0.00199
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.3855 - val_accuracy: 0.9422
#
# Epoch 00024: val_loss did not improve from 0.00199
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0217 - accuracy: 0.9942 - val_loss: 0.0140 - val_accuracy: 0.9941
#
# Epoch 00025: val_loss did not improve from 0.00199
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0189 - accuracy: 0.9950 - val_loss: 0.0201 - val_accuracy: 0.9953
#
# Epoch 00026: val_loss did not improve from 0.00199
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.0322 - val_accuracy: 0.9887
#
# Epoch 00027: val_loss did not improve from 0.00199
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0168 - accuracy: 0.9952 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00028: val_loss did not improve from 0.00199
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.0134 - val_accuracy: 0.9973
#
# Epoch 00029: val_loss did not improve from 0.00199
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.4960 - val_accuracy: 0.9008
#
# Epoch 00030: val_loss did not improve from 0.00199
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0172 - accuracy: 0.9951 - val_loss: 0.1688 - val_accuracy: 0.9555
#
# Epoch 00031: val_loss did not improve from 0.00199
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0157 - accuracy: 0.9947 - val_loss: 0.0096 - val_accuracy: 0.9969
#
# Epoch 00032: val_loss did not improve from 0.00199
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0182 - accuracy: 0.9955 - val_loss: 0.0093 - val_accuracy: 0.9984
#
# Epoch 00033: val_loss did not improve from 0.00199
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0159 - val_accuracy: 0.9973
#
# Epoch 00034: val_loss did not improve from 0.00199
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0131 - accuracy: 0.9962 - val_loss: 0.0593 - val_accuracy: 0.9855
#
# Epoch 00035: val_loss did not improve from 0.00199
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0173 - accuracy: 0.9952 - val_loss: 4.6966 - val_accuracy: 0.6574
#
# Epoch 00036: val_loss did not improve from 0.00199
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.1214 - val_accuracy: 0.9680
#
# Epoch 00037: val_loss did not improve from 0.00199
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.2355 - val_accuracy: 0.9465
#
# Epoch 00038: val_loss did not improve from 0.00199
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0128 - val_accuracy: 0.9980
#
# Epoch 00039: val_loss did not improve from 0.00199
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0166 - val_accuracy: 0.9953
#
# Epoch 00040: val_loss did not improve from 0.00199
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0159 - accuracy: 0.9948 - val_loss: 0.0365 - val_accuracy: 0.9871
#
# Epoch 00041: val_loss did not improve from 0.00199
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0175 - accuracy: 0.9942 - val_loss: 0.0993 - val_accuracy: 0.9746
#
# Epoch 00042: val_loss did not improve from 0.00199
# Epoch 43/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9964 - val_loss: 0.1211 - val_accuracy: 0.9559
#
# Epoch 00043: val_loss did not improve from 0.00199
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0232 - accuracy: 0.9951 - val_loss: 0.2766 - val_accuracy: 0.9297
#
# Epoch 00044: val_loss did not improve from 0.00199
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0229 - accuracy: 0.9968 - val_loss: 0.0082 - val_accuracy: 0.9977
#
# Epoch 00045: val_loss did not improve from 0.00199
# Epoch 46/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0188 - accuracy: 0.9954 - val_loss: 0.0541 - val_accuracy: 0.9863
#
# Epoch 00046: val_loss did not improve from 0.00199
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0202 - accuracy: 0.9967 - val_loss: 0.0407 - val_accuracy: 0.9867
#
# Epoch 00047: val_loss did not improve from 0.00199
# Epoch 48/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0156 - accuracy: 0.9971 - val_loss: 0.0273 - val_accuracy: 0.9961
#
# Epoch 00048: val_loss did not improve from 0.00199
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0186 - accuracy: 0.9960 - val_loss: 0.3946 - val_accuracy: 0.9203
#
# Epoch 00049: val_loss did not improve from 0.00199
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0131 - accuracy: 0.9966 - val_loss: 0.0466 - val_accuracy: 0.9871
#
# Epoch 00050: val_loss did not improve from 0.00199
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0549 - val_accuracy: 0.9840
#
# Epoch 00051: val_loss did not improve from 0.00199
# Epoch 52/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0169 - accuracy: 0.9962 - val_loss: 0.0144 - val_accuracy: 0.9965
#
# Epoch 00052: val_loss did not improve from 0.00199
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0146 - accuracy: 0.9964 - val_loss: 0.0406 - val_accuracy: 0.9840
#
# Epoch 00053: val_loss did not improve from 0.00199
# Epoch 54/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0110 - accuracy: 0.9973 - val_loss: 0.0487 - val_accuracy: 0.9848
#
# Epoch 00054: val_loss did not improve from 0.00199
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9970 - val_loss: 0.0415 - val_accuracy: 0.9875
#
# Epoch 00055: val_loss did not improve from 0.00199
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0128 - accuracy: 0.9961 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00056: val_loss did not improve from 0.00199
# Epoch 57/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0133 - accuracy: 0.9952 - val_loss: 0.0157 - val_accuracy: 0.9961
#
# Epoch 00057: val_loss did not improve from 0.00199
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.0076 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00199
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 0.0078 - val_accuracy: 0.9977
#
# Epoch 00059: val_loss did not improve from 0.00199
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.0853 - val_accuracy: 0.9777
#
# Epoch 00060: val_loss did not improve from 0.00199
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.0073 - val_accuracy: 0.9973
#
# Epoch 00061: val_loss did not improve from 0.00199
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0081 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00199
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00063: val_loss did not improve from 0.00199
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9961 - val_loss: 3.4436 - val_accuracy: 0.6234
#
# Epoch 00064: val_loss did not improve from 0.00199
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.0029 - val_accuracy: 0.9988
#
# Epoch 00065: val_loss did not improve from 0.00199
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9964 - val_loss: 0.0623 - val_accuracy: 0.9840
#
# Epoch 00066: val_loss did not improve from 0.00199
# Epoch 67/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0092 - val_accuracy: 0.9977
#
# Epoch 00067: val_loss did not improve from 0.00199
# Epoch 68/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00068: val_loss did not improve from 0.00199
# Epoch 69/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0141 - val_accuracy: 0.9937
#
# Epoch 00069: val_loss did not improve from 0.00199
# Epoch 70/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0101 - val_accuracy: 0.9949
#
# Epoch 00070: val_loss did not improve from 0.00199
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0105 - accuracy: 0.9960 - val_loss: 0.0098 - val_accuracy: 0.9973
#
# Epoch 00071: val_loss did not improve from 0.00199
# Epoch 72/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.0703 - val_accuracy: 0.9770
#
# Epoch 00072: val_loss did not improve from 0.00199
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0151 - val_accuracy: 0.9953
#
# Epoch 00073: val_loss did not improve from 0.00199
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0083 - val_accuracy: 0.9961
#
# Epoch 00074: val_loss did not improve from 0.00199
# Epoch 75/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0133 - val_accuracy: 0.9957
#
# Epoch 00075: val_loss did not improve from 0.00199
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 0.0046 - val_accuracy: 0.9980
#
# Epoch 00076: val_loss did not improve from 0.00199
# Epoch 77/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0079 - accuracy: 0.9965 - val_loss: 0.0085 - val_accuracy: 0.9969
#
# Epoch 00077: val_loss did not improve from 0.00199
# Epoch 78/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0166 - accuracy: 0.9964 - val_loss: 0.0263 - val_accuracy: 0.9945
#
# Epoch 00078: val_loss did not improve from 0.00199
# Epoch 79/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0189 - accuracy: 0.9976 - val_loss: 0.0034 - val_accuracy: 0.9988
#
# Epoch 00079: val_loss did not improve from 0.00199
# Epoch 80/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0144 - accuracy: 0.9959 - val_loss: 0.0376 - val_accuracy: 0.9867
#
# Epoch 00080: val_loss did not improve from 0.00199
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0062 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00199
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0105 - val_accuracy: 0.9949
#
# Epoch 00082: val_loss did not improve from 0.00199
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0083 - val_accuracy: 0.9973
#
# Epoch 00083: val_loss did not improve from 0.00199
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0031 - val_accuracy: 0.9980
#
# Epoch 00084: val_loss did not improve from 0.00199
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0067 - accuracy: 0.9970 - val_loss: 0.0055 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00199
# Epoch 86/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.1555 - val_accuracy: 0.9547
#
# Epoch 00086: val_loss did not improve from 0.00199
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0052 - val_accuracy: 0.9973
#
# Epoch 00087: val_loss did not improve from 0.00199
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0054 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00199
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.0202 - val_accuracy: 0.9937
#
# Epoch 00089: val_loss did not improve from 0.00199
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9956 - val_loss: 0.0063 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00199
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00199
# Epoch 92/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00092: val_loss did not improve from 0.00199
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0190 - val_accuracy: 0.9945
#
# Epoch 00093: val_loss did not improve from 0.00199
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0094 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00199
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0068 - accuracy: 0.9973 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00095: val_loss improved from 0.00199 to 0.00198, saving model to model.h5
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0308 - val_accuracy: 0.9906
#
# Epoch 00096: val_loss did not improve from 0.00198
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00198
# Epoch 98/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0035 - val_accuracy: 0.9984
#
# Epoch 00098: val_loss did not improve from 0.00198
# Epoch 99/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00198
# Epoch 100/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0123 - val_accuracy: 0.9949
#
# Epoch 00100: val_loss did not improve from 0.00198
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9949
# Val Score:  [0.012318853288888931, 0.994921863079071]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
