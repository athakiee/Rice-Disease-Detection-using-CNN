# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 50
INIT_LR = 1e-4
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_96 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_144 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_120 (Bat (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_97 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_145 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_121 (Bat (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_146 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_122 (Bat (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_147 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_123 (Bat (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_48 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_148 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_124 (Bat (None, 1024)              4096
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_149 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/50
# 320/320 [==============================] - 4s 10ms/step - loss: 0.4630 - accuracy: 0.8412 - val_loss: 3.8025 - val_accuracy: 0.5270
#
# Epoch 00001: val_loss improved from inf to 3.80247, saving model to model.h5
# Epoch 2/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1732 - accuracy: 0.9395 - val_loss: 1.6029 - val_accuracy: 0.7070
#
# Epoch 00002: val_loss improved from 3.80247 to 1.60291, saving model to model.h5
# Epoch 3/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1185 - accuracy: 0.9572 - val_loss: 0.6635 - val_accuracy: 0.8500
#
# Epoch 00003: val_loss improved from 1.60291 to 0.66347, saving model to model.h5
# Epoch 4/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0851 - accuracy: 0.9719 - val_loss: 0.3172 - val_accuracy: 0.9062
#
# Epoch 00004: val_loss improved from 0.66347 to 0.31721, saving model to model.h5
# Epoch 5/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0791 - accuracy: 0.9749 - val_loss: 0.4891 - val_accuracy: 0.8777
#
# Epoch 00005: val_loss did not improve from 0.31721
# Epoch 6/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0621 - accuracy: 0.9802 - val_loss: 0.2689 - val_accuracy: 0.9258
#
# Epoch 00006: val_loss improved from 0.31721 to 0.26888, saving model to model.h5
# Epoch 7/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0543 - accuracy: 0.9814 - val_loss: 0.4897 - val_accuracy: 0.8855
#
# Epoch 00007: val_loss did not improve from 0.26888
# Epoch 8/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0476 - accuracy: 0.9838 - val_loss: 0.1880 - val_accuracy: 0.9375
#
# Epoch 00008: val_loss improved from 0.26888 to 0.18802, saving model to model.h5
# Epoch 9/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0399 - accuracy: 0.9881 - val_loss: 0.2039 - val_accuracy: 0.9363
#
# Epoch 00009: val_loss did not improve from 0.18802
# Epoch 10/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0357 - accuracy: 0.9887 - val_loss: 0.3555 - val_accuracy: 0.9168
#
# Epoch 00010: val_loss did not improve from 0.18802
# Epoch 11/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0356 - accuracy: 0.9890 - val_loss: 0.0998 - val_accuracy: 0.9664
#
# Epoch 00011: val_loss improved from 0.18802 to 0.09977, saving model to model.h5
# Epoch 12/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0372 - accuracy: 0.9889 - val_loss: 0.0681 - val_accuracy: 0.9773
#
# Epoch 00012: val_loss improved from 0.09977 to 0.06814, saving model to model.h5
# Epoch 13/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0299 - accuracy: 0.9908 - val_loss: 0.0895 - val_accuracy: 0.9758
#
# Epoch 00013: val_loss did not improve from 0.06814
# Epoch 14/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0301 - accuracy: 0.9893 - val_loss: 0.2969 - val_accuracy: 0.9250
#
# Epoch 00014: val_loss did not improve from 0.06814
# Epoch 15/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0234 - accuracy: 0.9921 - val_loss: 0.1938 - val_accuracy: 0.9488
#
# Epoch 00015: val_loss did not improve from 0.06814
# Epoch 16/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0203 - accuracy: 0.9935 - val_loss: 0.1513 - val_accuracy: 0.9621
#
# Epoch 00016: val_loss did not improve from 0.06814
# Epoch 17/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0255 - accuracy: 0.9910 - val_loss: 0.1780 - val_accuracy: 0.9539
#
# Epoch 00017: val_loss did not improve from 0.06814
# Epoch 18/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.0820 - val_accuracy: 0.9809
#
# Epoch 00018: val_loss did not improve from 0.06814
# Epoch 19/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0236 - accuracy: 0.9924 - val_loss: 0.0647 - val_accuracy: 0.9824
#
# Epoch 00019: val_loss improved from 0.06814 to 0.06466, saving model to model.h5
# Epoch 20/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 0.0611 - val_accuracy: 0.9781
#
# Epoch 00020: val_loss improved from 0.06466 to 0.06112, saving model to model.h5
# Epoch 21/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0220 - accuracy: 0.9921 - val_loss: 0.2315 - val_accuracy: 0.9359
#
# Epoch 00021: val_loss did not improve from 0.06112
# Epoch 22/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.2080 - val_accuracy: 0.9453
#
# Epoch 00022: val_loss did not improve from 0.06112
# Epoch 23/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0162 - accuracy: 0.9942 - val_loss: 0.0537 - val_accuracy: 0.9871
#
# Epoch 00023: val_loss improved from 0.06112 to 0.05374, saving model to model.h5
# Epoch 24/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.0563 - val_accuracy: 0.9848
#
# Epoch 00024: val_loss did not improve from 0.05374
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 0.0271 - val_accuracy: 0.9914
#
# Epoch 00025: val_loss improved from 0.05374 to 0.02714, saving model to model.h5
# Epoch 26/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.0281 - val_accuracy: 0.9898
#
# Epoch 00026: val_loss did not improve from 0.02714
# Epoch 27/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.0197 - val_accuracy: 0.9969
#
# Epoch 00027: val_loss improved from 0.02714 to 0.01967, saving model to model.h5
# Epoch 28/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0144 - accuracy: 0.9948 - val_loss: 0.0453 - val_accuracy: 0.9863
#
# Epoch 00028: val_loss did not improve from 0.01967
# Epoch 29/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9949 - val_loss: 0.0507 - val_accuracy: 0.9863
#
# Epoch 00029: val_loss did not improve from 0.01967
# Epoch 30/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 0.0565 - val_accuracy: 0.9852
#
# Epoch 00030: val_loss did not improve from 0.01967
# Epoch 31/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.0386 - val_accuracy: 0.9883
#
# Epoch 00031: val_loss did not improve from 0.01967
# Epoch 32/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9957 - val_loss: 0.0321 - val_accuracy: 0.9937
#
# Epoch 00032: val_loss did not improve from 0.01967
# Epoch 33/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.2554 - val_accuracy: 0.9289
#
# Epoch 00033: val_loss did not improve from 0.01967
# Epoch 34/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9964 - val_loss: 0.0154 - val_accuracy: 0.9949
#
# Epoch 00034: val_loss improved from 0.01967 to 0.01542, saving model to model.h5
# Epoch 35/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0086 - accuracy: 0.9960 - val_loss: 0.0265 - val_accuracy: 0.9922
#
# Epoch 00035: val_loss did not improve from 0.01542
# Epoch 36/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0448 - val_accuracy: 0.9863
#
# Epoch 00036: val_loss did not improve from 0.01542
# Epoch 37/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 0.0108 - val_accuracy: 0.9941
#
# Epoch 00037: val_loss improved from 0.01542 to 0.01084, saving model to model.h5
# Epoch 38/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0337 - val_accuracy: 0.9926
#
# Epoch 00038: val_loss did not improve from 0.01084
# Epoch 39/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0175 - val_accuracy: 0.9934
#
# Epoch 00039: val_loss did not improve from 0.01084
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0058 - val_accuracy: 0.9980
#
# Epoch 00040: val_loss improved from 0.01084 to 0.00575, saving model to model.h5
# Epoch 41/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.0083 - val_accuracy: 0.9973
#
# Epoch 00041: val_loss did not improve from 0.00575
# Epoch 42/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0271 - val_accuracy: 0.9961
#
# Epoch 00042: val_loss did not improve from 0.00575
# Epoch 43/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0103 - accuracy: 0.9960 - val_loss: 0.0159 - val_accuracy: 0.9969
#
# Epoch 00043: val_loss did not improve from 0.00575
# Epoch 44/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0502 - val_accuracy: 0.9871
#
# Epoch 00044: val_loss did not improve from 0.00575
# Epoch 45/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0094 - val_accuracy: 0.9965
#
# Epoch 00045: val_loss did not improve from 0.00575
# Epoch 46/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.0677 - val_accuracy: 0.9793
#
# Epoch 00046: val_loss did not improve from 0.00575
# Epoch 47/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0100 - val_accuracy: 0.9969
#
# Epoch 00047: val_loss did not improve from 0.00575
# Epoch 48/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.0086 - val_accuracy: 0.9973
#
# Epoch 00048: val_loss did not improve from 0.00575
# Epoch 49/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0152 - val_accuracy: 0.9977
#
# Epoch 00049: val_loss did not improve from 0.00575
# Epoch 50/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.0272 - val_accuracy: 0.9957
#
# Epoch 00050: val_loss did not improve from 0.00575
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9957
# Val Score:  [0.02717835083603859, 0.9957031011581421]
# Training on Fold:  2
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4544 - accuracy: 0.8460 - val_loss: 6.7287 - val_accuracy: 0.4648
#
# Epoch 00001: val_loss did not improve from 0.00575
# Epoch 2/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2073 - accuracy: 0.9245 - val_loss: 2.3485 - val_accuracy: 0.6313
#
# Epoch 00002: val_loss did not improve from 0.00575
# Epoch 3/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1328 - accuracy: 0.9499 - val_loss: 1.4304 - val_accuracy: 0.7195
#
# Epoch 00003: val_loss did not improve from 0.00575
# Epoch 4/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0991 - accuracy: 0.9644 - val_loss: 0.9699 - val_accuracy: 0.7824
#
# Epoch 00004: val_loss did not improve from 0.00575
# Epoch 5/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0775 - accuracy: 0.9731 - val_loss: 0.9923 - val_accuracy: 0.7941
#
# Epoch 00005: val_loss did not improve from 0.00575
# Epoch 6/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0664 - accuracy: 0.9780 - val_loss: 1.3429 - val_accuracy: 0.7684
#
# Epoch 00006: val_loss did not improve from 0.00575
# Epoch 7/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0591 - accuracy: 0.9787 - val_loss: 0.7687 - val_accuracy: 0.8301
#
# Epoch 00007: val_loss did not improve from 0.00575
# Epoch 8/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0429 - accuracy: 0.9866 - val_loss: 0.7227 - val_accuracy: 0.8375
#
# Epoch 00008: val_loss did not improve from 0.00575
# Epoch 9/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0382 - accuracy: 0.9883 - val_loss: 0.6735 - val_accuracy: 0.8480
#
# Epoch 00009: val_loss did not improve from 0.00575
# Epoch 10/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0334 - accuracy: 0.9883 - val_loss: 0.9274 - val_accuracy: 0.8242
#
# Epoch 00010: val_loss did not improve from 0.00575
# Epoch 11/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0429 - accuracy: 0.9871 - val_loss: 0.7292 - val_accuracy: 0.8535
#
# Epoch 00011: val_loss did not improve from 0.00575
# Epoch 12/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0260 - accuracy: 0.9905 - val_loss: 0.6136 - val_accuracy: 0.8590
#
# Epoch 00012: val_loss did not improve from 0.00575
# Epoch 13/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0306 - accuracy: 0.9896 - val_loss: 0.3186 - val_accuracy: 0.9164
#
# Epoch 00013: val_loss did not improve from 0.00575
# Epoch 14/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0254 - accuracy: 0.9915 - val_loss: 0.4637 - val_accuracy: 0.8867
#
# Epoch 00014: val_loss did not improve from 0.00575
# Epoch 15/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0313 - accuracy: 0.9897 - val_loss: 0.5725 - val_accuracy: 0.8773
#
# Epoch 00015: val_loss did not improve from 0.00575
# Epoch 16/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0243 - accuracy: 0.9926 - val_loss: 0.4718 - val_accuracy: 0.8875
#
# Epoch 00016: val_loss did not improve from 0.00575
# Epoch 17/50
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0224 - accuracy: 0.9934 - val_loss: 0.3305 - val_accuracy: 0.9266
#
# Epoch 00017: val_loss did not improve from 0.00575
# Epoch 18/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 0.3411 - val_accuracy: 0.9098
#
# Epoch 00018: val_loss did not improve from 0.00575
# Epoch 19/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9938 - val_loss: 0.1880 - val_accuracy: 0.9480
#
# Epoch 00019: val_loss did not improve from 0.00575
# Epoch 20/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0222 - accuracy: 0.9919 - val_loss: 0.0838 - val_accuracy: 0.9703
#
# Epoch 00020: val_loss did not improve from 0.00575
# Epoch 21/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0147 - accuracy: 0.9941 - val_loss: 0.1705 - val_accuracy: 0.9504
#
# Epoch 00021: val_loss did not improve from 0.00575
# Epoch 22/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.2096 - val_accuracy: 0.9426
#
# Epoch 00022: val_loss did not improve from 0.00575
# Epoch 23/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.9940 - val_loss: 0.1164 - val_accuracy: 0.9695
#
# Epoch 00023: val_loss did not improve from 0.00575
# Epoch 24/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.1889 - val_accuracy: 0.9461
#
# Epoch 00024: val_loss did not improve from 0.00575
# Epoch 25/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.2829 - val_accuracy: 0.9445
#
# Epoch 00025: val_loss did not improve from 0.00575
# Epoch 26/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.1726 - val_accuracy: 0.9543
#
# Epoch 00026: val_loss did not improve from 0.00575
# Epoch 27/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.1187 - val_accuracy: 0.9629
#
# Epoch 00027: val_loss did not improve from 0.00575
# Epoch 28/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.0717 - val_accuracy: 0.9805
#
# Epoch 00028: val_loss did not improve from 0.00575
# Epoch 29/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0153 - accuracy: 0.9944 - val_loss: 0.0738 - val_accuracy: 0.9797
#
# Epoch 00029: val_loss did not improve from 0.00575
# Epoch 30/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0103 - accuracy: 0.9958 - val_loss: 0.1138 - val_accuracy: 0.9691
#
# Epoch 00030: val_loss did not improve from 0.00575
# Epoch 31/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0502 - val_accuracy: 0.9883
#
# Epoch 00031: val_loss did not improve from 0.00575
# Epoch 32/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0499 - val_accuracy: 0.9863
#
# Epoch 00032: val_loss did not improve from 0.00575
# Epoch 33/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0364 - val_accuracy: 0.9930
#
# Epoch 00033: val_loss did not improve from 0.00575
# Epoch 34/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.1773 - val_accuracy: 0.9555
#
# Epoch 00034: val_loss did not improve from 0.00575
# Epoch 35/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0775 - val_accuracy: 0.9855
#
# Epoch 00035: val_loss did not improve from 0.00575
# Epoch 36/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0647 - val_accuracy: 0.9852
#
# Epoch 00036: val_loss did not improve from 0.00575
# Epoch 37/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 0.0853 - val_accuracy: 0.9801
#
# Epoch 00037: val_loss did not improve from 0.00575
# Epoch 38/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.1764 - val_accuracy: 0.9574
#
# Epoch 00038: val_loss did not improve from 0.00575
# Epoch 39/50
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0113 - accuracy: 0.9956 - val_loss: 0.0757 - val_accuracy: 0.9805
#
# Epoch 00039: val_loss did not improve from 0.00575
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0096 - accuracy: 0.9964 - val_loss: 0.0433 - val_accuracy: 0.9895
#
# Epoch 00040: val_loss did not improve from 0.00575
# Epoch 41/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0349 - val_accuracy: 0.9906
#
# Epoch 00041: val_loss did not improve from 0.00575
# Epoch 42/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0512 - val_accuracy: 0.9828
#
# Epoch 00042: val_loss did not improve from 0.00575
# Epoch 43/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0567 - val_accuracy: 0.9871
#
# Epoch 00043: val_loss did not improve from 0.00575
# Epoch 44/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9966 - val_loss: 0.0484 - val_accuracy: 0.9875
#
# Epoch 00044: val_loss did not improve from 0.00575
# Epoch 45/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.0251 - val_accuracy: 0.9934
#
# Epoch 00045: val_loss did not improve from 0.00575
# Epoch 46/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9959 - val_loss: 0.2061 - val_accuracy: 0.9656
#
# Epoch 00046: val_loss did not improve from 0.00575
# Epoch 47/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.0356 - val_accuracy: 0.9906
#
# Epoch 00047: val_loss did not improve from 0.00575
# Epoch 48/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9971 - val_loss: 0.0413 - val_accuracy: 0.9926
#
# Epoch 00048: val_loss did not improve from 0.00575
# Epoch 49/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0604 - val_accuracy: 0.9840
#
# Epoch 00049: val_loss did not improve from 0.00575
# Epoch 50/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0095 - accuracy: 0.9962 - val_loss: 0.1388 - val_accuracy: 0.9641
#
# Epoch 00050: val_loss did not improve from 0.00575
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1388 - accuracy: 0.9641
# Val Score:  [0.13879987597465515, 0.964062511920929]
# Training on Fold:  3
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4591 - accuracy: 0.8610 - val_loss: 7.1708 - val_accuracy: 0.4902
#
# Epoch 00001: val_loss did not improve from 0.00575
# Epoch 2/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1774 - accuracy: 0.9363 - val_loss: 2.6442 - val_accuracy: 0.6215
#
# Epoch 00002: val_loss did not improve from 0.00575
# Epoch 3/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1247 - accuracy: 0.9555 - val_loss: 1.3798 - val_accuracy: 0.7539
#
# Epoch 00003: val_loss did not improve from 0.00575
# Epoch 4/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1025 - accuracy: 0.9649 - val_loss: 1.4352 - val_accuracy: 0.7414
#
# Epoch 00004: val_loss did not improve from 0.00575
# Epoch 5/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0789 - accuracy: 0.9720 - val_loss: 1.6067 - val_accuracy: 0.7527
#
# Epoch 00005: val_loss did not improve from 0.00575
# Epoch 6/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0639 - accuracy: 0.9783 - val_loss: 0.5828 - val_accuracy: 0.8598
#
# Epoch 00006: val_loss did not improve from 0.00575
# Epoch 7/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0555 - accuracy: 0.9805 - val_loss: 1.0453 - val_accuracy: 0.7852
#
# Epoch 00007: val_loss did not improve from 0.00575
# Epoch 8/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0512 - accuracy: 0.9819 - val_loss: 0.7314 - val_accuracy: 0.8289
#
# Epoch 00008: val_loss did not improve from 0.00575
# Epoch 9/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0467 - accuracy: 0.9851 - val_loss: 0.6696 - val_accuracy: 0.8508
#
# Epoch 00009: val_loss did not improve from 0.00575
# Epoch 10/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0386 - accuracy: 0.9872 - val_loss: 0.9045 - val_accuracy: 0.8313
#
# Epoch 00010: val_loss did not improve from 0.00575
# Epoch 11/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0350 - accuracy: 0.9892 - val_loss: 0.4479 - val_accuracy: 0.8918
#
# Epoch 00011: val_loss did not improve from 0.00575
# Epoch 12/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0388 - accuracy: 0.9862 - val_loss: 0.4051 - val_accuracy: 0.9148
#
# Epoch 00012: val_loss did not improve from 0.00575
# Epoch 13/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0299 - accuracy: 0.9896 - val_loss: 0.9363 - val_accuracy: 0.8375
#
# Epoch 00013: val_loss did not improve from 0.00575
# Epoch 14/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0270 - accuracy: 0.9896 - val_loss: 0.3966 - val_accuracy: 0.9133
#
# Epoch 00014: val_loss did not improve from 0.00575
# Epoch 15/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0292 - accuracy: 0.9893 - val_loss: 0.8248 - val_accuracy: 0.8543
#
# Epoch 00015: val_loss did not improve from 0.00575
# Epoch 16/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0262 - accuracy: 0.9916 - val_loss: 0.5026 - val_accuracy: 0.8762
#
# Epoch 00016: val_loss did not improve from 0.00575
# Epoch 17/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0189 - accuracy: 0.9933 - val_loss: 0.3918 - val_accuracy: 0.9113
#
# Epoch 00017: val_loss did not improve from 0.00575
# Epoch 18/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0195 - accuracy: 0.9932 - val_loss: 0.3707 - val_accuracy: 0.9156
#
# Epoch 00018: val_loss did not improve from 0.00575
# Epoch 19/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.1920 - val_accuracy: 0.9457
#
# Epoch 00019: val_loss did not improve from 0.00575
# Epoch 20/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0170 - accuracy: 0.9938 - val_loss: 0.6983 - val_accuracy: 0.8750
#
# Epoch 00020: val_loss did not improve from 0.00575
# Epoch 21/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0173 - accuracy: 0.9930 - val_loss: 0.1600 - val_accuracy: 0.9605
#
# Epoch 00021: val_loss did not improve from 0.00575
# Epoch 22/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.4745 - val_accuracy: 0.9012
#
# Epoch 00022: val_loss did not improve from 0.00575
# Epoch 23/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9941 - val_loss: 0.3928 - val_accuracy: 0.9098
#
# Epoch 00023: val_loss did not improve from 0.00575
# Epoch 24/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 0.1465 - val_accuracy: 0.9617
#
# Epoch 00024: val_loss did not improve from 0.00575
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0121 - accuracy: 0.9953 - val_loss: 0.1412 - val_accuracy: 0.9656
#
# Epoch 00025: val_loss did not improve from 0.00575
# Epoch 26/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0186 - accuracy: 0.9932 - val_loss: 0.0988 - val_accuracy: 0.9734
#
# Epoch 00026: val_loss did not improve from 0.00575
# Epoch 27/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.5185 - val_accuracy: 0.8898
#
# Epoch 00027: val_loss did not improve from 0.00575
# Epoch 28/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0146 - accuracy: 0.9948 - val_loss: 0.1379 - val_accuracy: 0.9617
#
# Epoch 00028: val_loss did not improve from 0.00575
# Epoch 29/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.2918 - val_accuracy: 0.9336
#
# Epoch 00029: val_loss did not improve from 0.00575
# Epoch 30/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0117 - accuracy: 0.9951 - val_loss: 0.0844 - val_accuracy: 0.9777
#
# Epoch 00030: val_loss did not improve from 0.00575
# Epoch 31/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.0955 - val_accuracy: 0.9746
#
# Epoch 00031: val_loss did not improve from 0.00575
# Epoch 32/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9950 - val_loss: 0.1069 - val_accuracy: 0.9762
#
# Epoch 00032: val_loss did not improve from 0.00575
# Epoch 33/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0397 - val_accuracy: 0.9883
#
# Epoch 00033: val_loss did not improve from 0.00575
# Epoch 34/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0867 - val_accuracy: 0.9762
#
# Epoch 00034: val_loss did not improve from 0.00575
# Epoch 35/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.1371 - val_accuracy: 0.9656
#
# Epoch 00035: val_loss did not improve from 0.00575
# Epoch 36/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0135 - accuracy: 0.9949 - val_loss: 0.0896 - val_accuracy: 0.9746
#
# Epoch 00036: val_loss did not improve from 0.00575
# Epoch 37/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.0209 - val_accuracy: 0.9945
#
# Epoch 00037: val_loss did not improve from 0.00575
# Epoch 38/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9961 - val_loss: 0.0536 - val_accuracy: 0.9879
#
# Epoch 00038: val_loss did not improve from 0.00575
# Epoch 39/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9956 - val_loss: 0.5270 - val_accuracy: 0.8871
#
# Epoch 00039: val_loss did not improve from 0.00575
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0942 - val_accuracy: 0.9750
#
# Epoch 00040: val_loss did not improve from 0.00575
# Epoch 41/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0135 - accuracy: 0.9947 - val_loss: 0.0220 - val_accuracy: 0.9922
#
# Epoch 00041: val_loss did not improve from 0.00575
# Epoch 42/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0269 - val_accuracy: 0.9934
#
# Epoch 00042: val_loss did not improve from 0.00575
# Epoch 43/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0701 - val_accuracy: 0.9762
#
# Epoch 00043: val_loss did not improve from 0.00575
# Epoch 44/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0673 - val_accuracy: 0.9855
#
# Epoch 00044: val_loss did not improve from 0.00575
# Epoch 45/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9960 - val_loss: 0.0713 - val_accuracy: 0.9801
#
# Epoch 00045: val_loss did not improve from 0.00575
# Epoch 46/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9971 - val_loss: 0.0335 - val_accuracy: 0.9902
#
# Epoch 00046: val_loss did not improve from 0.00575
# Epoch 47/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0470 - val_accuracy: 0.9871
#
# Epoch 00047: val_loss did not improve from 0.00575
# Epoch 48/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0105 - accuracy: 0.9958 - val_loss: 0.0153 - val_accuracy: 0.9945
#
# Epoch 00048: val_loss did not improve from 0.00575
# Epoch 49/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.1087 - val_accuracy: 0.9762
#
# Epoch 00049: val_loss did not improve from 0.00575
# Epoch 50/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0099 - accuracy: 0.9959 - val_loss: 0.0706 - val_accuracy: 0.9809
#
# Epoch 00050: val_loss did not improve from 0.00575
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0706 - accuracy: 0.9809
# Val Score:  [0.07063424587249756, 0.9808593988418579]
# Training on Fold:  4
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.3593 - accuracy: 0.8827 - val_loss: 5.9027 - val_accuracy: 0.4930
#
# Epoch 00001: val_loss did not improve from 0.00575
# Epoch 2/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1274 - accuracy: 0.9538 - val_loss: 1.0788 - val_accuracy: 0.7730
#
# Epoch 00002: val_loss did not improve from 0.00575
# Epoch 3/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0847 - accuracy: 0.9708 - val_loss: 0.5922 - val_accuracy: 0.8363
#
# Epoch 00003: val_loss did not improve from 0.00575
# Epoch 4/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0647 - accuracy: 0.9793 - val_loss: 0.4690 - val_accuracy: 0.8707
#
# Epoch 00004: val_loss did not improve from 0.00575
# Epoch 5/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0474 - accuracy: 0.9846 - val_loss: 0.4405 - val_accuracy: 0.8793
#
# Epoch 00005: val_loss did not improve from 0.00575
# Epoch 6/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0474 - accuracy: 0.9844 - val_loss: 0.3607 - val_accuracy: 0.8922
#
# Epoch 00006: val_loss did not improve from 0.00575
# Epoch 7/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0465 - accuracy: 0.9855 - val_loss: 0.3213 - val_accuracy: 0.9070
#
# Epoch 00007: val_loss did not improve from 0.00575
# Epoch 8/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0374 - accuracy: 0.9867 - val_loss: 0.3379 - val_accuracy: 0.9016
#
# Epoch 00008: val_loss did not improve from 0.00575
# Epoch 9/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0360 - accuracy: 0.9891 - val_loss: 0.1388 - val_accuracy: 0.9531
#
# Epoch 00009: val_loss did not improve from 0.00575
# Epoch 10/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0319 - accuracy: 0.9903 - val_loss: 0.1032 - val_accuracy: 0.9660
#
# Epoch 00010: val_loss did not improve from 0.00575
# Epoch 11/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0303 - accuracy: 0.9900 - val_loss: 0.1424 - val_accuracy: 0.9539
#
# Epoch 00011: val_loss did not improve from 0.00575
# Epoch 12/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0275 - accuracy: 0.9916 - val_loss: 0.0839 - val_accuracy: 0.9773
#
# Epoch 00012: val_loss did not improve from 0.00575
# Epoch 13/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0235 - accuracy: 0.9926 - val_loss: 0.1161 - val_accuracy: 0.9680
#
# Epoch 00013: val_loss did not improve from 0.00575
# Epoch 14/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0164 - accuracy: 0.9954 - val_loss: 0.0332 - val_accuracy: 0.9887
#
# Epoch 00014: val_loss did not improve from 0.00575
# Epoch 15/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9930 - val_loss: 0.0866 - val_accuracy: 0.9781
#
# Epoch 00015: val_loss did not improve from 0.00575
# Epoch 16/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.0299 - val_accuracy: 0.9875
#
# Epoch 00016: val_loss did not improve from 0.00575
# Epoch 17/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0219 - accuracy: 0.9933 - val_loss: 0.0684 - val_accuracy: 0.9816
#
# Epoch 00017: val_loss did not improve from 0.00575
# Epoch 18/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0690 - val_accuracy: 0.9797
#
# Epoch 00018: val_loss did not improve from 0.00575
# Epoch 19/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0590 - val_accuracy: 0.9832
#
# Epoch 00019: val_loss did not improve from 0.00575
# Epoch 20/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0160 - accuracy: 0.9942 - val_loss: 0.0213 - val_accuracy: 0.9910
#
# Epoch 00020: val_loss did not improve from 0.00575
# Epoch 21/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0163 - accuracy: 0.9936 - val_loss: 0.0303 - val_accuracy: 0.9914
#
# Epoch 00021: val_loss did not improve from 0.00575
# Epoch 22/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.0143 - val_accuracy: 0.9961
#
# Epoch 00022: val_loss did not improve from 0.00575
# Epoch 23/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.0410 - val_accuracy: 0.9891
#
# Epoch 00023: val_loss did not improve from 0.00575
# Epoch 24/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0157 - accuracy: 0.9942 - val_loss: 0.0317 - val_accuracy: 0.9914
#
# Epoch 00024: val_loss did not improve from 0.00575
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0151 - accuracy: 0.9948 - val_loss: 0.0106 - val_accuracy: 0.9957
#
# Epoch 00025: val_loss did not improve from 0.00575
# Epoch 26/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0189 - val_accuracy: 0.9953
#
# Epoch 00026: val_loss did not improve from 0.00575
# Epoch 27/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.0224 - val_accuracy: 0.9910
#
# Epoch 00027: val_loss did not improve from 0.00575
# Epoch 28/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.0464 - val_accuracy: 0.9895
#
# Epoch 00028: val_loss did not improve from 0.00575
# Epoch 29/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 0.0354 - val_accuracy: 0.9906
#
# Epoch 00029: val_loss did not improve from 0.00575
# Epoch 30/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0148 - val_accuracy: 0.9961
#
# Epoch 00030: val_loss did not improve from 0.00575
# Epoch 31/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.0241 - val_accuracy: 0.9953
#
# Epoch 00031: val_loss did not improve from 0.00575
# Epoch 32/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0101 - accuracy: 0.9961 - val_loss: 0.0256 - val_accuracy: 0.9910
#
# Epoch 00032: val_loss did not improve from 0.00575
# Epoch 33/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.0101 - val_accuracy: 0.9965
#
# Epoch 00033: val_loss did not improve from 0.00575
# Epoch 34/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.1952 - val_accuracy: 0.9605
#
# Epoch 00034: val_loss did not improve from 0.00575
# Epoch 35/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0194 - val_accuracy: 0.9937
#
# Epoch 00035: val_loss did not improve from 0.00575
# Epoch 36/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.0097 - val_accuracy: 0.9961
#
# Epoch 00036: val_loss did not improve from 0.00575
# Epoch 37/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0068 - accuracy: 0.9973 - val_loss: 0.0144 - val_accuracy: 0.9953
#
# Epoch 00037: val_loss did not improve from 0.00575
# Epoch 38/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.0171 - val_accuracy: 0.9957
#
# Epoch 00038: val_loss did not improve from 0.00575
# Epoch 39/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0118 - val_accuracy: 0.9969
#
# Epoch 00039: val_loss did not improve from 0.00575
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9970 - val_loss: 0.0280 - val_accuracy: 0.9945
#
# Epoch 00040: val_loss did not improve from 0.00575
# Epoch 41/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0112 - val_accuracy: 0.9965
#
# Epoch 00041: val_loss did not improve from 0.00575
# Epoch 42/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0250 - val_accuracy: 0.9969
#
# Epoch 00042: val_loss did not improve from 0.00575
# Epoch 43/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0137 - val_accuracy: 0.9969
#
# Epoch 00043: val_loss did not improve from 0.00575
# Epoch 44/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 0.0179 - val_accuracy: 0.9945
#
# Epoch 00044: val_loss did not improve from 0.00575
# Epoch 45/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0123 - val_accuracy: 0.9965
#
# Epoch 00045: val_loss did not improve from 0.00575
# Epoch 46/50
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0087 - accuracy: 0.9964 - val_loss: 0.0111 - val_accuracy: 0.9961
#
# Epoch 00046: val_loss did not improve from 0.00575
# Epoch 47/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9970 - val_loss: 0.0170 - val_accuracy: 0.9969
#
# Epoch 00047: val_loss did not improve from 0.00575
# Epoch 48/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0327 - val_accuracy: 0.9957
#
# Epoch 00048: val_loss did not improve from 0.00575
# Epoch 49/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0536 - val_accuracy: 0.9898
#
# Epoch 00049: val_loss did not improve from 0.00575
# Epoch 50/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00050: val_loss did not improve from 0.00575
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9969
# Val Score:  [0.008884540759027004, 0.996874988079071]
# Training on Fold:  5
# Epoch 1/50
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4089 - accuracy: 0.8696 - val_loss: 4.8749 - val_accuracy: 0.3691
#
# Epoch 00001: val_loss did not improve from 0.00575
# Epoch 2/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1453 - accuracy: 0.9473 - val_loss: 1.0205 - val_accuracy: 0.7531
#
# Epoch 00002: val_loss did not improve from 0.00575
# Epoch 3/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0935 - accuracy: 0.9686 - val_loss: 0.2520 - val_accuracy: 0.9207
#
# Epoch 00003: val_loss did not improve from 0.00575
# Epoch 4/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0640 - accuracy: 0.9783 - val_loss: 0.4741 - val_accuracy: 0.8852
#
# Epoch 00004: val_loss did not improve from 0.00575
# Epoch 5/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0564 - accuracy: 0.9790 - val_loss: 0.3586 - val_accuracy: 0.9051
#
# Epoch 00005: val_loss did not improve from 0.00575
# Epoch 6/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0504 - accuracy: 0.9831 - val_loss: 0.4086 - val_accuracy: 0.9047
#
# Epoch 00006: val_loss did not improve from 0.00575
# Epoch 7/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0510 - accuracy: 0.9844 - val_loss: 0.1478 - val_accuracy: 0.9543
#
# Epoch 00007: val_loss did not improve from 0.00575
# Epoch 8/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0366 - accuracy: 0.9879 - val_loss: 0.1808 - val_accuracy: 0.9438
#
# Epoch 00008: val_loss did not improve from 0.00575
# Epoch 9/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0326 - accuracy: 0.9893 - val_loss: 0.2545 - val_accuracy: 0.9332
#
# Epoch 00009: val_loss did not improve from 0.00575
# Epoch 10/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0361 - accuracy: 0.9880 - val_loss: 0.0587 - val_accuracy: 0.9773
#
# Epoch 00010: val_loss did not improve from 0.00575
# Epoch 11/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0293 - accuracy: 0.9904 - val_loss: 0.1938 - val_accuracy: 0.9461
#
# Epoch 00011: val_loss did not improve from 0.00575
# Epoch 12/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0271 - accuracy: 0.9913 - val_loss: 0.1372 - val_accuracy: 0.9652
#
# Epoch 00012: val_loss did not improve from 0.00575
# Epoch 13/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0281 - accuracy: 0.9923 - val_loss: 0.1253 - val_accuracy: 0.9648
#
# Epoch 00013: val_loss did not improve from 0.00575
# Epoch 14/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 0.1722 - val_accuracy: 0.9527
#
# Epoch 00014: val_loss did not improve from 0.00575
# Epoch 15/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.2724 - val_accuracy: 0.9531
#
# Epoch 00015: val_loss did not improve from 0.00575
# Epoch 16/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0177 - accuracy: 0.9952 - val_loss: 0.2716 - val_accuracy: 0.9344
#
# Epoch 00016: val_loss did not improve from 0.00575
# Epoch 17/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0171 - accuracy: 0.9957 - val_loss: 0.0353 - val_accuracy: 0.9871
#
# Epoch 00017: val_loss did not improve from 0.00575
# Epoch 18/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.0296 - val_accuracy: 0.9906
#
# Epoch 00018: val_loss did not improve from 0.00575
# Epoch 19/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.1233 - val_accuracy: 0.9641
#
# Epoch 00019: val_loss did not improve from 0.00575
# Epoch 20/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 0.0560 - val_accuracy: 0.9863
#
# Epoch 00020: val_loss did not improve from 0.00575
# Epoch 21/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0161 - accuracy: 0.9946 - val_loss: 0.0694 - val_accuracy: 0.9754
#
# Epoch 00021: val_loss did not improve from 0.00575
# Epoch 22/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.0670 - val_accuracy: 0.9809
#
# Epoch 00022: val_loss did not improve from 0.00575
# Epoch 23/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0177 - accuracy: 0.9944 - val_loss: 0.0602 - val_accuracy: 0.9816
#
# Epoch 00023: val_loss did not improve from 0.00575
# Epoch 24/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0121 - accuracy: 0.9951 - val_loss: 0.0363 - val_accuracy: 0.9875
#
# Epoch 00024: val_loss did not improve from 0.00575
# Epoch 25/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.0729 - val_accuracy: 0.9789
#
# Epoch 00025: val_loss did not improve from 0.00575
# Epoch 26/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9946 - val_loss: 0.0363 - val_accuracy: 0.9891
#
# Epoch 00026: val_loss did not improve from 0.00575
# Epoch 27/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0219 - val_accuracy: 0.9918
#
# Epoch 00027: val_loss did not improve from 0.00575
# Epoch 28/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0342 - val_accuracy: 0.9887
#
# Epoch 00028: val_loss did not improve from 0.00575
# Epoch 29/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0849 - val_accuracy: 0.9793
#
# Epoch 00029: val_loss did not improve from 0.00575
# Epoch 30/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0104 - val_accuracy: 0.9980
#
# Epoch 00030: val_loss did not improve from 0.00575
# Epoch 31/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0574 - val_accuracy: 0.9844
#
# Epoch 00031: val_loss did not improve from 0.00575
# Epoch 32/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00032: val_loss did not improve from 0.00575
# Epoch 33/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9958 - val_loss: 0.0357 - val_accuracy: 0.9906
#
# Epoch 00033: val_loss did not improve from 0.00575
# Epoch 34/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0127 - val_accuracy: 0.9957
#
# Epoch 00034: val_loss did not improve from 0.00575
# Epoch 35/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0499 - val_accuracy: 0.9875
#
# Epoch 00035: val_loss did not improve from 0.00575
# Epoch 36/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0094 - accuracy: 0.9965 - val_loss: 0.0126 - val_accuracy: 0.9973
#
# Epoch 00036: val_loss did not improve from 0.00575
# Epoch 37/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9964 - val_loss: 0.0169 - val_accuracy: 0.9957
#
# Epoch 00037: val_loss did not improve from 0.00575
# Epoch 38/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0169 - val_accuracy: 0.9949
#
# Epoch 00038: val_loss did not improve from 0.00575
# Epoch 39/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9954 - val_loss: 0.0211 - val_accuracy: 0.9957
#
# Epoch 00039: val_loss did not improve from 0.00575
# Epoch 40/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9966 - val_loss: 0.0054 - val_accuracy: 0.9984
#
# Epoch 00040: val_loss improved from 0.00575 to 0.00539, saving model to model.h5
# Epoch 41/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0116 - val_accuracy: 0.9969
#
# Epoch 00041: val_loss did not improve from 0.00539
# Epoch 42/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0696 - val_accuracy: 0.9871
#
# Epoch 00042: val_loss did not improve from 0.00539
# Epoch 43/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.1281 - val_accuracy: 0.9785
#
# Epoch 00043: val_loss did not improve from 0.00539
# Epoch 44/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9968 - val_loss: 0.0129 - val_accuracy: 0.9969
#
# Epoch 00044: val_loss did not improve from 0.00539
# Epoch 45/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0879 - val_accuracy: 0.9867
#
# Epoch 00045: val_loss did not improve from 0.00539
# Epoch 46/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0106 - accuracy: 0.9959 - val_loss: 0.0153 - val_accuracy: 0.9949
#
# Epoch 00046: val_loss did not improve from 0.00539
# Epoch 47/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0142 - val_accuracy: 0.9961
#
# Epoch 00047: val_loss did not improve from 0.00539
# Epoch 48/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0253 - val_accuracy: 0.9945
#
# Epoch 00048: val_loss did not improve from 0.00539
# Epoch 49/50
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0070 - val_accuracy: 0.9980
#
# Epoch 00049: val_loss did not improve from 0.00539
# Epoch 50/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0093 - val_accuracy: 0.9969
#
# Epoch 00050: val_loss did not improve from 0.00539
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.9969
# Val Score:  [0.009291899390518665, 0.996874988079071]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.98      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 3ms/step - loss: 0.0088 - accuracy: 0.9956
# Test Accuracy: 99.56250190734863

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
