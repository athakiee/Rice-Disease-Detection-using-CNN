# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_36 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_37 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_38 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_39 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_40 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_41 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = RMSprop(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 5s 11ms/step - loss: 0.4596 - accuracy: 0.8632 - val_loss: 8.5189 - val_accuracy: 0.3602
#
# Epoch 00001: val_loss improved from inf to 8.51887, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.1701 - accuracy: 0.9436 - val_loss: 1.2383 - val_accuracy: 0.6707
#
# Epoch 00002: val_loss improved from 8.51887 to 1.23833, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0920 - accuracy: 0.9689 - val_loss: 0.9786 - val_accuracy: 0.7766
#
# Epoch 00003: val_loss improved from 1.23833 to 0.97862, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0690 - accuracy: 0.9776 - val_loss: 1.0095 - val_accuracy: 0.8422
#
# Epoch 00004: val_loss did not improve from 0.97862
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0618 - accuracy: 0.9821 - val_loss: 0.1730 - val_accuracy: 0.9469
#
# Epoch 00005: val_loss improved from 0.97862 to 0.17299, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0443 - accuracy: 0.9873 - val_loss: 0.1660 - val_accuracy: 0.9473
#
# Epoch 00006: val_loss improved from 0.17299 to 0.16596, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0479 - accuracy: 0.9878 - val_loss: 1.9655 - val_accuracy: 0.6914
#
# Epoch 00007: val_loss did not improve from 0.16596
# Epoch 8/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0378 - accuracy: 0.9891 - val_loss: 0.2359 - val_accuracy: 0.9418
#
# Epoch 00008: val_loss did not improve from 0.16596
# Epoch 9/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0313 - accuracy: 0.9902 - val_loss: 0.1349 - val_accuracy: 0.9609
#
# Epoch 00009: val_loss improved from 0.16596 to 0.13486, saving model to model.h5
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0319 - accuracy: 0.9920 - val_loss: 0.0309 - val_accuracy: 0.9926
#
# Epoch 00010: val_loss improved from 0.13486 to 0.03089, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0362 - accuracy: 0.9896 - val_loss: 0.8395 - val_accuracy: 0.7898
#
# Epoch 00011: val_loss did not improve from 0.03089
# Epoch 12/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0361 - accuracy: 0.9903 - val_loss: 0.1474 - val_accuracy: 0.9688
#
# Epoch 00012: val_loss did not improve from 0.03089
# Epoch 13/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0302 - accuracy: 0.9911 - val_loss: 0.0342 - val_accuracy: 0.9910
#
# Epoch 00013: val_loss did not improve from 0.03089
# Epoch 14/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0234 - accuracy: 0.9931 - val_loss: 0.3773 - val_accuracy: 0.9129
#
# Epoch 00014: val_loss did not improve from 0.03089
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0246 - accuracy: 0.9939 - val_loss: 2.6342 - val_accuracy: 0.8188
#
# Epoch 00015: val_loss did not improve from 0.03089
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0201 - accuracy: 0.9952 - val_loss: 0.8368 - val_accuracy: 0.8520
#
# Epoch 00016: val_loss did not improve from 0.03089
# Epoch 17/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0233 - accuracy: 0.9935 - val_loss: 0.0201 - val_accuracy: 0.9930
#
# Epoch 00017: val_loss improved from 0.03089 to 0.02006, saving model to model.h5
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0236 - accuracy: 0.9937 - val_loss: 1.7816 - val_accuracy: 0.8316
#
# Epoch 00018: val_loss did not improve from 0.02006
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0303 - accuracy: 0.9925 - val_loss: 0.2377 - val_accuracy: 0.9520
#
# Epoch 00019: val_loss did not improve from 0.02006
# Epoch 20/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0199 - accuracy: 0.9943 - val_loss: 0.1077 - val_accuracy: 0.9688
#
# Epoch 00020: val_loss did not improve from 0.02006
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0213 - accuracy: 0.9942 - val_loss: 0.0552 - val_accuracy: 0.9809
#
# Epoch 00021: val_loss did not improve from 0.02006
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0156 - accuracy: 0.9970 - val_loss: 0.1616 - val_accuracy: 0.9617
#
# Epoch 00022: val_loss did not improve from 0.02006
# Epoch 23/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0186 - accuracy: 0.9955 - val_loss: 1.0702 - val_accuracy: 0.7895
#
# Epoch 00023: val_loss did not improve from 0.02006
# Epoch 24/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0231 - accuracy: 0.9939 - val_loss: 0.0364 - val_accuracy: 0.9910
#
# Epoch 00024: val_loss did not improve from 0.02006
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0217 - accuracy: 0.9943 - val_loss: 0.0360 - val_accuracy: 0.9906
#
# Epoch 00025: val_loss did not improve from 0.02006
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0174 - accuracy: 0.9949 - val_loss: 3.2605 - val_accuracy: 0.6957
#
# Epoch 00026: val_loss did not improve from 0.02006
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0234 - accuracy: 0.9945 - val_loss: 0.0122 - val_accuracy: 0.9965
#
# Epoch 00027: val_loss improved from 0.02006 to 0.01223, saving model to model.h5
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0157 - accuracy: 0.9961 - val_loss: 0.8976 - val_accuracy: 0.8617
#
# Epoch 00028: val_loss did not improve from 0.01223
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 2.1734 - val_accuracy: 0.6254
#
# Epoch 00029: val_loss did not improve from 0.01223
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0285 - accuracy: 0.9946 - val_loss: 1.4341 - val_accuracy: 0.8496
#
# Epoch 00030: val_loss did not improve from 0.01223
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0182 - accuracy: 0.9952 - val_loss: 0.0166 - val_accuracy: 0.9961
#
# Epoch 00031: val_loss did not improve from 0.01223
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0191 - accuracy: 0.9958 - val_loss: 0.2375 - val_accuracy: 0.9434
#
# Epoch 00032: val_loss did not improve from 0.01223
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0167 - accuracy: 0.9958 - val_loss: 0.0133 - val_accuracy: 0.9969
#
# Epoch 00033: val_loss did not improve from 0.01223
# Epoch 34/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 1.8388 - val_accuracy: 0.8035
#
# Epoch 00034: val_loss did not improve from 0.01223
# Epoch 35/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0158 - accuracy: 0.9960 - val_loss: 0.0245 - val_accuracy: 0.9930
#
# Epoch 00035: val_loss did not improve from 0.01223
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0172 - accuracy: 0.9958 - val_loss: 2.6661 - val_accuracy: 0.7496
#
# Epoch 00036: val_loss did not improve from 0.01223
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0193 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9961
#
# Epoch 00037: val_loss did not improve from 0.01223
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0141 - accuracy: 0.9965 - val_loss: 0.3990 - val_accuracy: 0.9258
#
# Epoch 00038: val_loss did not improve from 0.01223
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0150 - accuracy: 0.9959 - val_loss: 0.2579 - val_accuracy: 0.9371
#
# Epoch 00039: val_loss did not improve from 0.01223
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0132 - accuracy: 0.9966 - val_loss: 0.5539 - val_accuracy: 0.9215
#
# Epoch 00040: val_loss did not improve from 0.01223
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0188 - accuracy: 0.9953 - val_loss: 0.2508 - val_accuracy: 0.9398
#
# Epoch 00041: val_loss did not improve from 0.01223
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0224 - accuracy: 0.9943 - val_loss: 0.0361 - val_accuracy: 0.9922
#
# Epoch 00042: val_loss did not improve from 0.01223
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0180 - accuracy: 0.9957 - val_loss: 0.0205 - val_accuracy: 0.9945
#
# Epoch 00043: val_loss did not improve from 0.01223
# Epoch 44/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0168 - accuracy: 0.9956 - val_loss: 0.0665 - val_accuracy: 0.9828
#
# Epoch 00044: val_loss did not improve from 0.01223
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0184 - accuracy: 0.9961 - val_loss: 0.0944 - val_accuracy: 0.9848
#
# Epoch 00045: val_loss did not improve from 0.01223
# Epoch 46/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0184 - accuracy: 0.9956 - val_loss: 0.0190 - val_accuracy: 0.9937
#
# Epoch 00046: val_loss did not improve from 0.01223
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 0.0146 - val_accuracy: 0.9965
#
# Epoch 00047: val_loss did not improve from 0.01223
# Epoch 48/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0107 - accuracy: 0.9971 - val_loss: 0.0137 - val_accuracy: 0.9957
#
# Epoch 00048: val_loss did not improve from 0.01223
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9968 - val_loss: 0.1800 - val_accuracy: 0.9500
#
# Epoch 00049: val_loss did not improve from 0.01223
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0147 - accuracy: 0.9962 - val_loss: 0.0611 - val_accuracy: 0.9785
#
# Epoch 00050: val_loss did not improve from 0.01223
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.0531 - val_accuracy: 0.9875
#
# Epoch 00051: val_loss did not improve from 0.01223
# Epoch 52/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0173 - accuracy: 0.9957 - val_loss: 0.0092 - val_accuracy: 0.9977
#
# Epoch 00052: val_loss improved from 0.01223 to 0.00918, saving model to model.h5
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.0278 - val_accuracy: 0.9953
#
# Epoch 00053: val_loss did not improve from 0.00918
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0948 - val_accuracy: 0.9820
#
# Epoch 00054: val_loss did not improve from 0.00918
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0185 - accuracy: 0.9953 - val_loss: 3.3825 - val_accuracy: 0.8031
#
# Epoch 00055: val_loss did not improve from 0.00918
# Epoch 56/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 1.1240 - val_accuracy: 0.8902
#
# Epoch 00056: val_loss did not improve from 0.00918
# Epoch 57/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0165 - accuracy: 0.9965 - val_loss: 0.0218 - val_accuracy: 0.9949
#
# Epoch 00057: val_loss did not improve from 0.00918
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.0530 - val_accuracy: 0.9875
#
# Epoch 00058: val_loss did not improve from 0.00918
# Epoch 59/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9961 - val_loss: 0.0021 - val_accuracy: 0.9984
#
# Epoch 00059: val_loss improved from 0.00918 to 0.00206, saving model to model.h5
# Epoch 60/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.1438 - val_accuracy: 0.9703
#
# Epoch 00060: val_loss did not improve from 0.00206
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0194 - accuracy: 0.9955 - val_loss: 0.0154 - val_accuracy: 0.9965
#
# Epoch 00061: val_loss did not improve from 0.00206
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0151 - accuracy: 0.9959 - val_loss: 0.0144 - val_accuracy: 0.9969
#
# Epoch 00062: val_loss did not improve from 0.00206
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0189 - accuracy: 0.9955 - val_loss: 0.0066 - val_accuracy: 0.9980
#
# Epoch 00063: val_loss did not improve from 0.00206
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0172 - val_accuracy: 0.9945
#
# Epoch 00064: val_loss did not improve from 0.00206
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0188 - accuracy: 0.9964 - val_loss: 0.6708 - val_accuracy: 0.8582
#
# Epoch 00065: val_loss did not improve from 0.00206
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0156 - accuracy: 0.9962 - val_loss: 0.7266 - val_accuracy: 0.9082
#
# Epoch 00066: val_loss did not improve from 0.00206
# Epoch 67/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0161 - accuracy: 0.9961 - val_loss: 0.4679 - val_accuracy: 0.9098
#
# Epoch 00067: val_loss did not improve from 0.00206
# Epoch 68/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0149 - accuracy: 0.9959 - val_loss: 0.0050 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00206
# Epoch 69/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00069: val_loss did not improve from 0.00206
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.0375 - val_accuracy: 0.9902
#
# Epoch 00070: val_loss did not improve from 0.00206
# Epoch 71/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9973 - val_loss: 0.0078 - val_accuracy: 0.9977
#
# Epoch 00071: val_loss did not improve from 0.00206
# Epoch 72/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0163 - accuracy: 0.9949 - val_loss: 1.6555 - val_accuracy: 0.8270
#
# Epoch 00072: val_loss did not improve from 0.00206
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0143 - accuracy: 0.9968 - val_loss: 0.7412 - val_accuracy: 0.9059
#
# Epoch 00073: val_loss did not improve from 0.00206
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0890 - val_accuracy: 0.9785
#
# Epoch 00074: val_loss did not improve from 0.00206
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.1376 - val_accuracy: 0.9809
#
# Epoch 00075: val_loss did not improve from 0.00206
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00206
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9968 - val_loss: 0.1715 - val_accuracy: 0.9695
#
# Epoch 00077: val_loss did not improve from 0.00206
# Epoch 78/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0631 - val_accuracy: 0.9895
#
# Epoch 00078: val_loss did not improve from 0.00206
# Epoch 79/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0185 - accuracy: 0.9952 - val_loss: 0.0137 - val_accuracy: 0.9973
#
# Epoch 00079: val_loss did not improve from 0.00206
# Epoch 80/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.0032 - val_accuracy: 0.9977
#
# Epoch 00080: val_loss did not improve from 0.00206
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0169 - accuracy: 0.9959 - val_loss: 0.0126 - val_accuracy: 0.9953
#
# Epoch 00081: val_loss did not improve from 0.00206
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.1488 - val_accuracy: 0.9742
#
# Epoch 00082: val_loss did not improve from 0.00206
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.0256 - val_accuracy: 0.9910
#
# Epoch 00083: val_loss did not improve from 0.00206
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9973 - val_loss: 0.1007 - val_accuracy: 0.9762
#
# Epoch 00084: val_loss did not improve from 0.00206
# Epoch 85/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9971 - val_loss: 0.0194 - val_accuracy: 0.9937
#
# Epoch 00085: val_loss did not improve from 0.00206
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0149 - accuracy: 0.9962 - val_loss: 0.0086 - val_accuracy: 0.9961
#
# Epoch 00086: val_loss did not improve from 0.00206
# Epoch 87/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0136 - accuracy: 0.9970 - val_loss: 0.0029 - val_accuracy: 0.9988
#
# Epoch 00087: val_loss did not improve from 0.00206
# Epoch 88/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9972 - val_loss: 0.0266 - val_accuracy: 0.9984
#
# Epoch 00088: val_loss did not improve from 0.00206
# Epoch 89/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0141 - accuracy: 0.9970 - val_loss: 0.0102 - val_accuracy: 0.9973
#
# Epoch 00089: val_loss did not improve from 0.00206
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.0271 - val_accuracy: 0.9937
#
# Epoch 00090: val_loss did not improve from 0.00206
# Epoch 91/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0139 - accuracy: 0.9966 - val_loss: 0.0530 - val_accuracy: 0.9863
#
# Epoch 00091: val_loss did not improve from 0.00206
# Epoch 92/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.0095 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00206
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 3.0795 - val_accuracy: 0.8031
#
# Epoch 00093: val_loss did not improve from 0.00206
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0157 - accuracy: 0.9965 - val_loss: 0.0920 - val_accuracy: 0.9785
#
# Epoch 00094: val_loss did not improve from 0.00206
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0149 - accuracy: 0.9968 - val_loss: 0.0084 - val_accuracy: 0.9973
#
# Epoch 00095: val_loss did not improve from 0.00206
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0118 - accuracy: 0.9969 - val_loss: 3.4780 - val_accuracy: 0.8316
#
# Epoch 00096: val_loss did not improve from 0.00206
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0133 - accuracy: 0.9964 - val_loss: 0.0386 - val_accuracy: 0.9902
#
# Epoch 00097: val_loss did not improve from 0.00206
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0145 - accuracy: 0.9963 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00098: val_loss did not improve from 0.00206
# Epoch 99/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00206
# Epoch 100/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0152 - accuracy: 0.9963 - val_loss: 0.0046 - val_accuracy: 0.9984
#
# Epoch 00100: val_loss did not improve from 0.00206
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9984
# Val Score:  [0.004626963287591934, 0.9984375238418579]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 5s 12ms/step - loss: 0.3980 - accuracy: 0.8872 - val_loss: 3.2819 - val_accuracy: 0.5852
#
# Epoch 00001: val_loss did not improve from 0.00206
# Epoch 2/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1377 - accuracy: 0.9546 - val_loss: 0.0790 - val_accuracy: 0.9711
#
# Epoch 00002: val_loss did not improve from 0.00206
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0980 - accuracy: 0.9702 - val_loss: 0.1071 - val_accuracy: 0.9617
#
# Epoch 00003: val_loss did not improve from 0.00206
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0625 - accuracy: 0.9810 - val_loss: 0.1618 - val_accuracy: 0.9512
#
# Epoch 00004: val_loss did not improve from 0.00206
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0467 - accuracy: 0.9857 - val_loss: 0.0315 - val_accuracy: 0.9895
#
# Epoch 00005: val_loss did not improve from 0.00206
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0417 - accuracy: 0.9883 - val_loss: 0.9338 - val_accuracy: 0.8254
#
# Epoch 00006: val_loss did not improve from 0.00206
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0409 - accuracy: 0.9899 - val_loss: 0.0315 - val_accuracy: 0.9875
#
# Epoch 00007: val_loss did not improve from 0.00206
# Epoch 8/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0370 - accuracy: 0.9912 - val_loss: 0.3534 - val_accuracy: 0.9203
#
# Epoch 00008: val_loss did not improve from 0.00206
# Epoch 9/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0341 - accuracy: 0.9908 - val_loss: 0.1227 - val_accuracy: 0.9699
#
# Epoch 00009: val_loss did not improve from 0.00206
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0302 - accuracy: 0.9927 - val_loss: 0.0754 - val_accuracy: 0.9723
#
# Epoch 00010: val_loss did not improve from 0.00206
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0248 - accuracy: 0.9934 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00011: val_loss did not improve from 0.00206
# Epoch 12/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0277 - accuracy: 0.9927 - val_loss: 1.3377 - val_accuracy: 0.8441
#
# Epoch 00012: val_loss did not improve from 0.00206
# Epoch 13/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0294 - accuracy: 0.9935 - val_loss: 0.0154 - val_accuracy: 0.9980
#
# Epoch 00013: val_loss did not improve from 0.00206
# Epoch 14/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0306 - accuracy: 0.9926 - val_loss: 0.0280 - val_accuracy: 0.9945
#
# Epoch 00014: val_loss did not improve from 0.00206
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0204 - accuracy: 0.9949 - val_loss: 3.6816 - val_accuracy: 0.6777
#
# Epoch 00015: val_loss did not improve from 0.00206
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0199 - accuracy: 0.9949 - val_loss: 0.1371 - val_accuracy: 0.9656
#
# Epoch 00016: val_loss did not improve from 0.00206
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0202 - accuracy: 0.9944 - val_loss: 0.3412 - val_accuracy: 0.9051
#
# Epoch 00017: val_loss did not improve from 0.00206
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0709 - val_accuracy: 0.9863
#
# Epoch 00018: val_loss did not improve from 0.00206
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0190 - accuracy: 0.9949 - val_loss: 0.0086 - val_accuracy: 0.9980
#
# Epoch 00019: val_loss did not improve from 0.00206
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0209 - accuracy: 0.9949 - val_loss: 0.0115 - val_accuracy: 0.9965
#
# Epoch 00020: val_loss did not improve from 0.00206
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.0557 - val_accuracy: 0.9859
#
# Epoch 00021: val_loss did not improve from 0.00206
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0186 - accuracy: 0.9954 - val_loss: 0.0058 - val_accuracy: 0.9980
#
# Epoch 00022: val_loss did not improve from 0.00206
# Epoch 23/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0214 - accuracy: 0.9953 - val_loss: 0.0068 - val_accuracy: 0.9969
#
# Epoch 00023: val_loss did not improve from 0.00206
# Epoch 24/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.0080 - val_accuracy: 0.9984
#
# Epoch 00024: val_loss did not improve from 0.00206
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0152 - accuracy: 0.9964 - val_loss: 0.0110 - val_accuracy: 0.9980
#
# Epoch 00025: val_loss did not improve from 0.00206
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0247 - accuracy: 0.9945 - val_loss: 0.0038 - val_accuracy: 0.9977
#
# Epoch 00026: val_loss did not improve from 0.00206
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.6977 - val_accuracy: 0.9000
#
# Epoch 00027: val_loss did not improve from 0.00206
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0174 - accuracy: 0.9956 - val_loss: 0.5403 - val_accuracy: 0.9109
#
# Epoch 00028: val_loss did not improve from 0.00206
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.0107 - val_accuracy: 0.9969
#
# Epoch 00029: val_loss did not improve from 0.00206
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0238 - accuracy: 0.9940 - val_loss: 0.0419 - val_accuracy: 0.9914
#
# Epoch 00030: val_loss did not improve from 0.00206
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0167 - accuracy: 0.9951 - val_loss: 0.0239 - val_accuracy: 0.9941
#
# Epoch 00031: val_loss did not improve from 0.00206
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.0085 - val_accuracy: 0.9969
#
# Epoch 00032: val_loss did not improve from 0.00206
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0224 - accuracy: 0.9952 - val_loss: 0.9619 - val_accuracy: 0.8301
#
# Epoch 00033: val_loss did not improve from 0.00206
# Epoch 34/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0190 - accuracy: 0.9957 - val_loss: 0.0104 - val_accuracy: 0.9984
#
# Epoch 00034: val_loss did not improve from 0.00206
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9967 - val_loss: 0.2401 - val_accuracy: 0.9547
#
# Epoch 00035: val_loss did not improve from 0.00206
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9958 - val_loss: 0.1352 - val_accuracy: 0.9695
#
# Epoch 00036: val_loss did not improve from 0.00206
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.2970 - val_accuracy: 0.9207
#
# Epoch 00037: val_loss did not improve from 0.00206
# Epoch 38/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0179 - accuracy: 0.9951 - val_loss: 0.0818 - val_accuracy: 0.9805
#
# Epoch 00038: val_loss did not improve from 0.00206
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0175 - accuracy: 0.9952 - val_loss: 0.0366 - val_accuracy: 0.9898
#
# Epoch 00039: val_loss did not improve from 0.00206
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0155 - accuracy: 0.9958 - val_loss: 0.0125 - val_accuracy: 0.9973
#
# Epoch 00040: val_loss did not improve from 0.00206
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0196 - accuracy: 0.9951 - val_loss: 3.2597 - val_accuracy: 0.6926
#
# Epoch 00041: val_loss did not improve from 0.00206
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.1615 - val_accuracy: 0.9605
#
# Epoch 00042: val_loss did not improve from 0.00206
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.1156 - val_accuracy: 0.9660
#
# Epoch 00043: val_loss did not improve from 0.00206
# Epoch 44/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 0.2354 - val_accuracy: 0.9594
#
# Epoch 00044: val_loss did not improve from 0.00206
# Epoch 45/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0141 - accuracy: 0.9960 - val_loss: 0.0104 - val_accuracy: 0.9969
#
# Epoch 00045: val_loss did not improve from 0.00206
# Epoch 46/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 0.0860 - val_accuracy: 0.9797
#
# Epoch 00046: val_loss did not improve from 0.00206
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0152 - accuracy: 0.9964 - val_loss: 0.0098 - val_accuracy: 0.9977
#
# Epoch 00047: val_loss did not improve from 0.00206
# Epoch 48/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0169 - accuracy: 0.9963 - val_loss: 0.0297 - val_accuracy: 0.9906
#
# Epoch 00048: val_loss did not improve from 0.00206
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0137 - accuracy: 0.9965 - val_loss: 0.2303 - val_accuracy: 0.9539
#
# Epoch 00049: val_loss did not improve from 0.00206
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0144 - accuracy: 0.9964 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00050: val_loss did not improve from 0.00206
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0199 - accuracy: 0.9957 - val_loss: 5.4965 - val_accuracy: 0.7117
#
# Epoch 00051: val_loss did not improve from 0.00206
# Epoch 52/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0137 - accuracy: 0.9965 - val_loss: 0.0615 - val_accuracy: 0.9828
#
# Epoch 00052: val_loss did not improve from 0.00206
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0163 - accuracy: 0.9960 - val_loss: 0.5466 - val_accuracy: 0.9145
#
# Epoch 00053: val_loss did not improve from 0.00206
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0192 - accuracy: 0.9955 - val_loss: 4.5579 - val_accuracy: 0.7238
#
# Epoch 00054: val_loss did not improve from 0.00206
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 1.5936 - val_accuracy: 0.7781
#
# Epoch 00055: val_loss did not improve from 0.00206
# Epoch 56/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0154 - accuracy: 0.9962 - val_loss: 1.0025 - val_accuracy: 0.8832
#
# Epoch 00056: val_loss did not improve from 0.00206
# Epoch 57/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0121 - accuracy: 0.9974 - val_loss: 0.1443 - val_accuracy: 0.9746
#
# Epoch 00057: val_loss did not improve from 0.00206
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 4.6613 - val_accuracy: 0.8574
#
# Epoch 00058: val_loss did not improve from 0.00206
# Epoch 59/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9970 - val_loss: 0.1662 - val_accuracy: 0.9703
#
# Epoch 00059: val_loss did not improve from 0.00206
# Epoch 60/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0133 - accuracy: 0.9967 - val_loss: 0.0095 - val_accuracy: 0.9980
#
# Epoch 00060: val_loss did not improve from 0.00206
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 0.2900 - val_accuracy: 0.9547
#
# Epoch 00061: val_loss did not improve from 0.00206
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0105 - accuracy: 0.9974 - val_loss: 0.7795 - val_accuracy: 0.8977
#
# Epoch 00062: val_loss did not improve from 0.00206
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0154 - val_accuracy: 0.9957
#
# Epoch 00063: val_loss did not improve from 0.00206
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0258 - val_accuracy: 0.9949
#
# Epoch 00064: val_loss did not improve from 0.00206
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0144 - accuracy: 0.9970 - val_loss: 1.8662 - val_accuracy: 0.8305
#
# Epoch 00065: val_loss did not improve from 0.00206
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0110 - accuracy: 0.9974 - val_loss: 0.0296 - val_accuracy: 0.9961
#
# Epoch 00066: val_loss did not improve from 0.00206
# Epoch 67/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.1256 - val_accuracy: 0.9738
#
# Epoch 00067: val_loss did not improve from 0.00206
# Epoch 68/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.0098 - val_accuracy: 0.9961
#
# Epoch 00068: val_loss did not improve from 0.00206
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0126 - accuracy: 0.9969 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00069: val_loss did not improve from 0.00206
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 0.4350 - val_accuracy: 0.9066
#
# Epoch 00070: val_loss did not improve from 0.00206
# Epoch 71/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.0158 - val_accuracy: 0.9957
#
# Epoch 00071: val_loss did not improve from 0.00206
# Epoch 72/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.1291 - val_accuracy: 0.9809
#
# Epoch 00072: val_loss did not improve from 0.00206
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.1838 - val_accuracy: 0.9387
#
# Epoch 00073: val_loss did not improve from 0.00206
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0135 - accuracy: 0.9965 - val_loss: 0.0215 - val_accuracy: 0.9941
#
# Epoch 00074: val_loss did not improve from 0.00206
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0133 - accuracy: 0.9968 - val_loss: 0.0066 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00206
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0138 - accuracy: 0.9969 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00076: val_loss did not improve from 0.00206
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.0288 - val_accuracy: 0.9937
#
# Epoch 00077: val_loss did not improve from 0.00206
# Epoch 78/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00078: val_loss improved from 0.00206 to 0.00197, saving model to model.h5
# Epoch 79/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0068 - val_accuracy: 0.9965
#
# Epoch 00079: val_loss did not improve from 0.00197
# Epoch 80/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.0078 - val_accuracy: 0.9980
#
# Epoch 00080: val_loss did not improve from 0.00197
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.6519 - val_accuracy: 0.9086
#
# Epoch 00081: val_loss did not improve from 0.00197
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.0052 - val_accuracy: 0.9984
#
# Epoch 00082: val_loss did not improve from 0.00197
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9973 - val_loss: 1.4696 - val_accuracy: 0.8500
#
# Epoch 00083: val_loss did not improve from 0.00197
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 0.2700 - val_accuracy: 0.9527
#
# Epoch 00084: val_loss did not improve from 0.00197
# Epoch 85/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00197
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 0.0250 - val_accuracy: 0.9902
#
# Epoch 00086: val_loss did not improve from 0.00197
# Epoch 87/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.1336 - val_accuracy: 0.9816
#
# Epoch 00087: val_loss did not improve from 0.00197
# Epoch 88/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.4108 - val_accuracy: 0.9395
#
# Epoch 00088: val_loss did not improve from 0.00197
# Epoch 89/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.2359 - val_accuracy: 0.9660
#
# Epoch 00089: val_loss did not improve from 0.00197
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.3371 - val_accuracy: 0.9164
#
# Epoch 00090: val_loss did not improve from 0.00197
# Epoch 91/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.2045 - val_accuracy: 0.9805
#
# Epoch 00091: val_loss did not improve from 0.00197
# Epoch 92/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0303 - val_accuracy: 0.9949
#
# Epoch 00092: val_loss did not improve from 0.00197
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.1739 - val_accuracy: 0.9707
#
# Epoch 00093: val_loss did not improve from 0.00197
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00094: val_loss did not improve from 0.00197
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.1810 - val_accuracy: 0.9660
#
# Epoch 00095: val_loss did not improve from 0.00197
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.4193 - val_accuracy: 0.9566
#
# Epoch 00096: val_loss did not improve from 0.00197
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0132 - accuracy: 0.9964 - val_loss: 0.0434 - val_accuracy: 0.9863
#
# Epoch 00097: val_loss did not improve from 0.00197
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0152 - val_accuracy: 0.9957
#
# Epoch 00098: val_loss did not improve from 0.00197
# Epoch 99/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0091 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00197
# Epoch 100/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00100: val_loss did not improve from 0.00197
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 0.9988
# Val Score:  [0.002491903956979513, 0.998828113079071]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 6s 11ms/step - loss: 0.4768 - accuracy: 0.8465 - val_loss: 12.4108 - val_accuracy: 0.2875
#
# Epoch 00001: val_loss did not improve from 0.00197
# Epoch 2/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.1705 - accuracy: 0.9433 - val_loss: 1.4111 - val_accuracy: 0.7773
#
# Epoch 00002: val_loss did not improve from 0.00197
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1157 - accuracy: 0.9616 - val_loss: 0.1632 - val_accuracy: 0.9516
#
# Epoch 00003: val_loss did not improve from 0.00197
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0842 - accuracy: 0.9717 - val_loss: 0.0634 - val_accuracy: 0.9863
#
# Epoch 00004: val_loss did not improve from 0.00197
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0566 - accuracy: 0.9813 - val_loss: 0.0325 - val_accuracy: 0.9887
#
# Epoch 00005: val_loss did not improve from 0.00197
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0516 - accuracy: 0.9835 - val_loss: 0.2140 - val_accuracy: 0.9559
#
# Epoch 00006: val_loss did not improve from 0.00197
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0414 - accuracy: 0.9879 - val_loss: 0.0917 - val_accuracy: 0.9730
#
# Epoch 00007: val_loss did not improve from 0.00197
# Epoch 8/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0359 - accuracy: 0.9887 - val_loss: 0.0716 - val_accuracy: 0.9832
#
# Epoch 00008: val_loss did not improve from 0.00197
# Epoch 9/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0370 - accuracy: 0.9888 - val_loss: 0.0491 - val_accuracy: 0.9887
#
# Epoch 00009: val_loss did not improve from 0.00197
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0316 - accuracy: 0.9901 - val_loss: 0.1349 - val_accuracy: 0.9672
#
# Epoch 00010: val_loss did not improve from 0.00197
# Epoch 11/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0254 - accuracy: 0.9923 - val_loss: 0.0683 - val_accuracy: 0.9777
#
# Epoch 00011: val_loss did not improve from 0.00197
# Epoch 12/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 0.4197 - val_accuracy: 0.9273
#
# Epoch 00012: val_loss did not improve from 0.00197
# Epoch 13/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0266 - accuracy: 0.9928 - val_loss: 0.0240 - val_accuracy: 0.9930
#
# Epoch 00013: val_loss did not improve from 0.00197
# Epoch 14/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.0827 - val_accuracy: 0.9762
#
# Epoch 00014: val_loss did not improve from 0.00197
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0249 - accuracy: 0.9937 - val_loss: 0.0276 - val_accuracy: 0.9941
#
# Epoch 00015: val_loss did not improve from 0.00197
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0227 - accuracy: 0.9946 - val_loss: 0.0440 - val_accuracy: 0.9926
#
# Epoch 00016: val_loss did not improve from 0.00197
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0240 - accuracy: 0.9927 - val_loss: 0.0132 - val_accuracy: 0.9953
#
# Epoch 00017: val_loss did not improve from 0.00197
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0161 - accuracy: 0.9946 - val_loss: 0.0655 - val_accuracy: 0.9812
#
# Epoch 00018: val_loss did not improve from 0.00197
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0166 - accuracy: 0.9956 - val_loss: 0.0501 - val_accuracy: 0.9906
#
# Epoch 00019: val_loss did not improve from 0.00197
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0213 - accuracy: 0.9945 - val_loss: 0.0657 - val_accuracy: 0.9828
#
# Epoch 00020: val_loss did not improve from 0.00197
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0210 - accuracy: 0.9955 - val_loss: 0.1318 - val_accuracy: 0.9754
#
# Epoch 00021: val_loss did not improve from 0.00197
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0166 - accuracy: 0.9962 - val_loss: 0.9078 - val_accuracy: 0.8594
#
# Epoch 00022: val_loss did not improve from 0.00197
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0174 - accuracy: 0.9954 - val_loss: 0.0072 - val_accuracy: 0.9973
#
# Epoch 00023: val_loss did not improve from 0.00197
# Epoch 24/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0176 - accuracy: 0.9956 - val_loss: 0.0311 - val_accuracy: 0.9941
#
# Epoch 00024: val_loss did not improve from 0.00197
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.1012 - val_accuracy: 0.9910
#
# Epoch 00025: val_loss did not improve from 0.00197
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0177 - accuracy: 0.9948 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00026: val_loss did not improve from 0.00197
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.0160 - val_accuracy: 0.9973
#
# Epoch 00027: val_loss did not improve from 0.00197
# Epoch 28/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.4394 - val_accuracy: 0.9086
#
# Epoch 00028: val_loss did not improve from 0.00197
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0133 - accuracy: 0.9952 - val_loss: 0.0328 - val_accuracy: 0.9926
#
# Epoch 00029: val_loss did not improve from 0.00197
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.2874 - val_accuracy: 0.9551
#
# Epoch 00030: val_loss did not improve from 0.00197
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0191 - accuracy: 0.9961 - val_loss: 0.0370 - val_accuracy: 0.9914
#
# Epoch 00031: val_loss did not improve from 0.00197
# Epoch 32/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0140 - accuracy: 0.9962 - val_loss: 0.6926 - val_accuracy: 0.8824
#
# Epoch 00032: val_loss did not improve from 0.00197
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 0.0981 - val_accuracy: 0.9762
#
# Epoch 00033: val_loss did not improve from 0.00197
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0323 - val_accuracy: 0.9926
#
# Epoch 00034: val_loss did not improve from 0.00197
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9960 - val_loss: 0.0294 - val_accuracy: 0.9953
#
# Epoch 00035: val_loss did not improve from 0.00197
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0346 - val_accuracy: 0.9930
#
# Epoch 00036: val_loss did not improve from 0.00197
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0216 - accuracy: 0.9950 - val_loss: 0.0280 - val_accuracy: 0.9941
#
# Epoch 00037: val_loss did not improve from 0.00197
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0202 - accuracy: 0.9947 - val_loss: 0.0347 - val_accuracy: 0.9969
#
# Epoch 00038: val_loss did not improve from 0.00197
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.0719 - val_accuracy: 0.9828
#
# Epoch 00039: val_loss did not improve from 0.00197
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0142 - accuracy: 0.9960 - val_loss: 1.5399 - val_accuracy: 0.8051
#
# Epoch 00040: val_loss did not improve from 0.00197
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0142 - accuracy: 0.9964 - val_loss: 0.0131 - val_accuracy: 0.9965
#
# Epoch 00041: val_loss did not improve from 0.00197
# Epoch 42/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00193
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0163 - accuracy: 0.9959 - val_loss: 0.0400 - val_accuracy: 0.9871
#
# Epoch 00021: val_loss did not improve from 0.00193
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.0367 - val_accuracy: 0.9891
#
# Epoch 00022: val_loss did not improve from 0.00193
# Epoch 23/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0154 - accuracy: 0.9965 - val_loss: 0.0140 - val_accuracy: 0.9957
#
# Epoch 00023: val_loss did not improve from 0.00193
# Epoch 24/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0159 - accuracy: 0.9960 - val_loss: 0.0670 - val_accuracy: 0.9828
#
# Epoch 00024: val_loss did not improve from 0.00193
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.3244 - val_accuracy: 0.9563
#
# Epoch 00025: val_loss did not improve from 0.00193
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.0339 - val_accuracy: 0.9930
#
# Epoch 00026: val_loss did not improve from 0.00193
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0150 - accuracy: 0.9958 - val_loss: 0.1051 - val_accuracy: 0.9660
#
# Epoch 00027: val_loss did not improve from 0.00193
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.0083 - val_accuracy: 0.9965
#
# Epoch 00028: val_loss did not improve from 0.00193
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0150 - accuracy: 0.9961 - val_loss: 0.0083 - val_accuracy: 0.9969
#
# Epoch 00029: val_loss did not improve from 0.00193
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0108 - accuracy: 0.9961 - val_loss: 0.0904 - val_accuracy: 0.9719
#
# Epoch 00030: val_loss did not improve from 0.00193
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 0.0568 - val_accuracy: 0.9848
#
# Epoch 00031: val_loss did not improve from 0.00193
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 0.0057 - val_accuracy: 0.9984
#
# Epoch 00032: val_loss did not improve from 0.00193
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0079 - val_accuracy: 0.9977
#
# Epoch 00033: val_loss did not improve from 0.00193
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.5791 - val_accuracy: 0.9145
#
# Epoch 00034: val_loss did not improve from 0.00193
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.0091 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00193
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9964 - val_loss: 0.9293 - val_accuracy: 0.8871
#
# Epoch 00036: val_loss did not improve from 0.00193
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0149 - val_accuracy: 0.9945
#
# Epoch 00037: val_loss did not improve from 0.00193
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0951 - val_accuracy: 0.9801
#
# Epoch 00038: val_loss did not improve from 0.00193
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00039: val_loss did not improve from 0.00193
# Epoch 40/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0083 - val_accuracy: 0.9980
#
# Epoch 00040: val_loss did not improve from 0.00193
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 0.0161 - val_accuracy: 0.9957
#
# Epoch 00041: val_loss did not improve from 0.00193
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0104 - val_accuracy: 0.9969
#
# Epoch 00042: val_loss did not improve from 0.00193
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 2.2774 - val_accuracy: 0.7648
#
# Epoch 00043: val_loss did not improve from 0.00193
# Epoch 44/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.0044 - val_accuracy: 0.9977
#
# Epoch 00044: val_loss did not improve from 0.00193
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.0051 - val_accuracy: 0.9988
#
# Epoch 00045: val_loss did not improve from 0.00193
# Epoch 46/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.1723 - val_accuracy: 0.9590
#
# Epoch 00046: val_loss did not improve from 0.00193
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0251 - val_accuracy: 0.9957
#
# Epoch 00047: val_loss did not improve from 0.00193
# Epoch 48/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0084 - val_accuracy: 0.9965
#
# Epoch 00048: val_loss did not improve from 0.00193
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0124 - val_accuracy: 0.9980
#
# Epoch 00049: val_loss did not improve from 0.00193
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0102 - accuracy: 0.9971 - val_loss: 0.0201 - val_accuracy: 0.9922
#
# Epoch 00050: val_loss did not improve from 0.00193
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0152 - val_accuracy: 0.9945
#
# Epoch 00051: val_loss did not improve from 0.00193
# Epoch 52/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0768 - val_accuracy: 0.9832
#
# Epoch 00052: val_loss did not improve from 0.00193
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0143 - accuracy: 0.9964 - val_loss: 0.0093 - val_accuracy: 0.9969
#
# Epoch 00053: val_loss did not improve from 0.00193
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.1549 - val_accuracy: 0.9652
#
# Epoch 00054: val_loss did not improve from 0.00193
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.0280 - val_accuracy: 0.9965
#
# Epoch 00055: val_loss did not improve from 0.00193
# Epoch 56/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0286 - val_accuracy: 0.9949
#
# Epoch 00056: val_loss did not improve from 0.00193
# Epoch 57/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0687 - val_accuracy: 0.9887
#
# Epoch 00057: val_loss did not improve from 0.00193
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0028 - val_accuracy: 0.9988
#
# Epoch 00058: val_loss did not improve from 0.00193
# Epoch 59/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0123 - accuracy: 0.9969 - val_loss: 0.0030 - val_accuracy: 0.9988
#
# Epoch 00059: val_loss did not improve from 0.00193
# Epoch 60/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.0090 - val_accuracy: 0.9961
#
# Epoch 00060: val_loss did not improve from 0.00193
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.0153 - val_accuracy: 0.9969
#
# Epoch 00061: val_loss did not improve from 0.00193
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0055 - val_accuracy: 0.9977
#
# Epoch 00062: val_loss did not improve from 0.00193
# Epoch 63/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0066 - val_accuracy: 0.9973
#
# Epoch 00063: val_loss did not improve from 0.00193
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.0073 - val_accuracy: 0.9980
#
# Epoch 00064: val_loss did not improve from 0.00193
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.0110 - val_accuracy: 0.9977
#
# Epoch 00065: val_loss did not improve from 0.00193
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0132 - accuracy: 0.9972 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00066: val_loss did not improve from 0.00193
# Epoch 67/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0089 - accuracy: 0.9978 - val_loss: 0.0064 - val_accuracy: 0.9973
#
# Epoch 00067: val_loss did not improve from 0.00193
# Epoch 68/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00193
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.0200 - val_accuracy: 0.9949
#
# Epoch 00069: val_loss did not improve from 0.00193
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 1.2448 - val_accuracy: 0.9082
#
# Epoch 00070: val_loss did not improve from 0.00193
# Epoch 71/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0220 - val_accuracy: 0.9941
#
# Epoch 00071: val_loss did not improve from 0.00193
# Epoch 72/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0240 - val_accuracy: 0.9969
#
# Epoch 00072: val_loss did not improve from 0.00193
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0137 - accuracy: 0.9962 - val_loss: 0.2467 - val_accuracy: 0.9453
#
# Epoch 00073: val_loss did not improve from 0.00193
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.0200 - val_accuracy: 0.9914
#
# Epoch 00074: val_loss did not improve from 0.00193
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 3.3413 - val_accuracy: 0.7441
#
# Epoch 00075: val_loss did not improve from 0.00193
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.0021 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00193
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0101 - val_accuracy: 0.9984
#
# Epoch 00077: val_loss did not improve from 0.00193
# Epoch 78/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00078: val_loss did not improve from 0.00193
# Epoch 79/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00079: val_loss did not improve from 0.00193
# Epoch 80/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0636 - val_accuracy: 0.9859
#
# Epoch 00080: val_loss did not improve from 0.00193
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.4746 - val_accuracy: 0.9227
#
# Epoch 00081: val_loss did not improve from 0.00193
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 3.7120 - val_accuracy: 0.7547
#
# Epoch 00082: val_loss did not improve from 0.00193
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9970 - val_loss: 0.0148 - val_accuracy: 0.9961
#
# Epoch 00083: val_loss did not improve from 0.00193
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0535 - val_accuracy: 0.9852
#
# Epoch 00084: val_loss did not improve from 0.00193
# Epoch 85/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.0062 - val_accuracy: 0.9984
#
# Epoch 00085: val_loss did not improve from 0.00193
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.0074 - val_accuracy: 0.9969
#
# Epoch 00086: val_loss did not improve from 0.00193
# Epoch 87/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0146 - val_accuracy: 0.9969
#
# Epoch 00087: val_loss did not improve from 0.00193
# Epoch 88/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.0066 - val_accuracy: 0.9984
#
# Epoch 00088: val_loss did not improve from 0.00193
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9966 - val_loss: 0.0235 - val_accuracy: 0.9937
#
# Epoch 00089: val_loss did not improve from 0.00193
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.0102 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00193
# Epoch 91/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0131 - val_accuracy: 0.9973
#
# Epoch 00091: val_loss did not improve from 0.00193
# Epoch 92/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9965 - val_loss: 0.0095 - val_accuracy: 0.9984
#
# Epoch 00092: val_loss did not improve from 0.00193
# Epoch 93/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0098 - accuracy: 0.9972 - val_loss: 0.0174 - val_accuracy: 0.9969
#
# Epoch 00093: val_loss did not improve from 0.00193
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 0.0232 - val_accuracy: 0.9949
#
# Epoch 00094: val_loss did not improve from 0.00193
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0027 - val_accuracy: 0.9988
#
# Epoch 00095: val_loss did not improve from 0.00193
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.2470 - val_accuracy: 0.9457
#
# Epoch 00096: val_loss did not improve from 0.00193
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0087 - val_accuracy: 0.9973
#
# Epoch 00097: val_loss did not improve from 0.00193
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00098: val_loss did not improve from 0.00193
# Epoch 99/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.0117 - val_accuracy: 0.9969
#
# Epoch 00099: val_loss did not improve from 0.00193
# Epoch 100/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0049 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00193
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.9980
# Val Score:  [0.0048551009967923164, 0.998046875]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 4ms/step - loss: 0.0042 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
