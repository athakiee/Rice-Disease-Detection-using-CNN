# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **HIDDEN LAYER TEST -- USING ONLY 4 HIDDEN LAYER**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 2022-08-04 01:01:58.168287: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:01:58.285744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:01:58.286549: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:01:58.287914: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-04 01:01:58.288246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:01:58.288982: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:01:58.289635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:02:00.711923: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:02:00.712813: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:02:00.713531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 01:02:00.715014: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# 2022-08-04 01:02:04.262632: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-08-04 01:02:06.021132: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 320/320 [==============================] - 11s 10ms/step - loss: 0.4359 - accuracy: 0.8624 - val_loss: 3.4139 - val_accuracy: 0.5020
#
# Epoch 00001: val_loss improved from inf to 3.41386, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1636 - accuracy: 0.9438 - val_loss: 0.6120 - val_accuracy: 0.8211
#
# Epoch 00002: val_loss improved from 3.41386 to 0.61204, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1118 - accuracy: 0.9614 - val_loss: 1.5409 - val_accuracy: 0.6754
#
# Epoch 00003: val_loss did not improve from 0.61204
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1015 - accuracy: 0.9656 - val_loss: 0.2189 - val_accuracy: 0.9516
#
# Epoch 00004: val_loss improved from 0.61204 to 0.21891, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0643 - accuracy: 0.9776 - val_loss: 0.0226 - val_accuracy: 0.9910
#
# Epoch 00005: val_loss improved from 0.21891 to 0.02260, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0705 - accuracy: 0.9754 - val_loss: 0.1306 - val_accuracy: 0.9566
#
# Epoch 00006: val_loss did not improve from 0.02260
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0538 - accuracy: 0.9826 - val_loss: 0.0566 - val_accuracy: 0.9793
#
# Epoch 00007: val_loss did not improve from 0.02260
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0548 - accuracy: 0.9826 - val_loss: 0.8893 - val_accuracy: 0.8082
#
# Epoch 00008: val_loss did not improve from 0.02260
# Epoch 9/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0459 - accuracy: 0.9847 - val_loss: 0.4034 - val_accuracy: 0.9156
#
# Epoch 00009: val_loss did not improve from 0.02260
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0327 - accuracy: 0.9897 - val_loss: 2.8609 - val_accuracy: 0.6715
#
# Epoch 00010: val_loss did not improve from 0.02260
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0421 - accuracy: 0.9862 - val_loss: 0.4430 - val_accuracy: 0.9156
#
# Epoch 00011: val_loss did not improve from 0.02260
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0415 - accuracy: 0.9862 - val_loss: 0.1849 - val_accuracy: 0.9320
#
# Epoch 00012: val_loss did not improve from 0.02260
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0313 - accuracy: 0.9890 - val_loss: 0.9757 - val_accuracy: 0.8371
#
# Epoch 00013: val_loss did not improve from 0.02260
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0363 - accuracy: 0.9882 - val_loss: 0.1373 - val_accuracy: 0.9621
#
# Epoch 00014: val_loss did not improve from 0.02260
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.1884 - val_accuracy: 0.9547
#
# Epoch 00015: val_loss did not improve from 0.02260
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0264 - accuracy: 0.9914 - val_loss: 0.2100 - val_accuracy: 0.9570
#
# Epoch 00016: val_loss did not improve from 0.02260
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0219 - accuracy: 0.9938 - val_loss: 1.5824 - val_accuracy: 0.7953
#
# Epoch 00017: val_loss did not improve from 0.02260
# Epoch 18/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0157 - accuracy: 0.9942 - val_loss: 0.0543 - val_accuracy: 0.9820
#
# Epoch 00018: val_loss did not improve from 0.02260
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0273 - accuracy: 0.9922 - val_loss: 0.0146 - val_accuracy: 0.9949
#
# Epoch 00019: val_loss improved from 0.02260 to 0.01457, saving model to model.h5
# Epoch 20/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0287 - accuracy: 0.9899 - val_loss: 0.0051 - val_accuracy: 0.9973
#
# Epoch 00020: val_loss improved from 0.01457 to 0.00515, saving model to model.h5
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00021: val_loss did not improve from 0.00515
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0244 - accuracy: 0.9928 - val_loss: 0.0274 - val_accuracy: 0.9898
#
# Epoch 00022: val_loss did not improve from 0.00515
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0254 - accuracy: 0.9921 - val_loss: 0.0637 - val_accuracy: 0.9793
#
# Epoch 00023: val_loss did not improve from 0.00515
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0377 - accuracy: 0.9891 - val_loss: 0.2700 - val_accuracy: 0.9375
#
# Epoch 00024: val_loss did not improve from 0.00515
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0284 - accuracy: 0.9910 - val_loss: 0.0567 - val_accuracy: 0.9832
#
# Epoch 00025: val_loss did not improve from 0.00515
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.1211 - val_accuracy: 0.9676
#
# Epoch 00026: val_loss did not improve from 0.00515
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.0323 - val_accuracy: 0.9918
#
# Epoch 00027: val_loss did not improve from 0.00515
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0214 - accuracy: 0.9931 - val_loss: 0.0112 - val_accuracy: 0.9969
#
# Epoch 00028: val_loss did not improve from 0.00515
# Epoch 29/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0156 - accuracy: 0.9952 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00029: val_loss improved from 0.00515 to 0.00387, saving model to model.h5
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00030: val_loss improved from 0.00387 to 0.00373, saving model to model.h5
# Epoch 31/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00031: val_loss did not improve from 0.00373
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9932 - val_loss: 0.0402 - val_accuracy: 0.9895
#
# Epoch 00032: val_loss did not improve from 0.00373
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0186 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9969
#
# Epoch 00033: val_loss did not improve from 0.00373
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.1418 - val_accuracy: 0.9641
#
# Epoch 00034: val_loss did not improve from 0.00373
# Epoch 35/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.2449 - val_accuracy: 0.9453
#
# Epoch 00035: val_loss did not improve from 0.00373
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0184 - accuracy: 0.9928 - val_loss: 0.0302 - val_accuracy: 0.9910
#
# Epoch 00036: val_loss did not improve from 0.00373
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0177 - accuracy: 0.9944 - val_loss: 1.9654 - val_accuracy: 0.7812
#
# Epoch 00037: val_loss did not improve from 0.00373
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.2171 - val_accuracy: 0.9484
#
# Epoch 00038: val_loss did not improve from 0.00373
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0172 - accuracy: 0.9946 - val_loss: 0.5615 - val_accuracy: 0.8891
#
# Epoch 00039: val_loss did not improve from 0.00373
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0177 - accuracy: 0.9940 - val_loss: 0.4077 - val_accuracy: 0.9227
#
# Epoch 00040: val_loss did not improve from 0.00373
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9943 - val_loss: 0.0765 - val_accuracy: 0.9848
#
# Epoch 00041: val_loss did not improve from 0.00373
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0240 - accuracy: 0.9929 - val_loss: 0.0792 - val_accuracy: 0.9789
#
# Epoch 00042: val_loss did not improve from 0.00373
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0131 - val_accuracy: 0.9969
#
# Epoch 00043: val_loss did not improve from 0.00373
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0134 - accuracy: 0.9954 - val_loss: 0.0103 - val_accuracy: 0.9973
#
# Epoch 00044: val_loss did not improve from 0.00373
# Epoch 45/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0070 - val_accuracy: 0.9980
#
# Epoch 00045: val_loss did not improve from 0.00373
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0100 - val_accuracy: 0.9973
#
# Epoch 00046: val_loss did not improve from 0.00373
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0187 - accuracy: 0.9947 - val_loss: 0.4930 - val_accuracy: 0.8891
#
# Epoch 00047: val_loss did not improve from 0.00373
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0079 - val_accuracy: 0.9980
#
# Epoch 00048: val_loss did not improve from 0.00373
# Epoch 49/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0154 - accuracy: 0.9956 - val_loss: 0.0161 - val_accuracy: 0.9945
#
# Epoch 00049: val_loss did not improve from 0.00373
# Epoch 50/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0146 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00373
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0457 - accuracy: 0.9882 - val_loss: 0.1833 - val_accuracy: 0.9598
#
# Epoch 00051: val_loss did not improve from 0.00373
# Epoch 52/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0179 - accuracy: 0.9948 - val_loss: 0.0046 - val_accuracy: 0.9977
#
# Epoch 00052: val_loss did not improve from 0.00373
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.0221 - val_accuracy: 0.9961
#
# Epoch 00053: val_loss did not improve from 0.00373
# Epoch 54/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.0057 - val_accuracy: 0.9977
#
# Epoch 00054: val_loss did not improve from 0.00373
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0057 - val_accuracy: 0.9973
#
# Epoch 00055: val_loss did not improve from 0.00373
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00056: val_loss improved from 0.00373 to 0.00244, saving model to model.h5
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0684 - val_accuracy: 0.9871
#
# Epoch 00057: val_loss did not improve from 0.00244
# Epoch 58/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.0066 - val_accuracy: 0.9984
#
# Epoch 00058: val_loss did not improve from 0.00244
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0111 - val_accuracy: 0.9961
#
# Epoch 00059: val_loss did not improve from 0.00244
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.0186 - val_accuracy: 0.9949
#
# Epoch 00060: val_loss did not improve from 0.00244
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.4967 - val_accuracy: 0.9062
#
# Epoch 00061: val_loss did not improve from 0.00244
# Epoch 62/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.3711 - val_accuracy: 0.9215
#
# Epoch 00062: val_loss did not improve from 0.00244
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0216 - accuracy: 0.9943 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00063: val_loss did not improve from 0.00244
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0056 - val_accuracy: 0.9969
#
# Epoch 00064: val_loss did not improve from 0.00244
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0078 - val_accuracy: 0.9965
#
# Epoch 00065: val_loss did not improve from 0.00244
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.1016 - val_accuracy: 0.9812
#
# Epoch 00066: val_loss did not improve from 0.00244
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0099 - accuracy: 0.9956 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00067: val_loss did not improve from 0.00244
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0142 - val_accuracy: 0.9961
#
# Epoch 00068: val_loss did not improve from 0.00244
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 0.0236 - val_accuracy: 0.9965
#
# Epoch 00069: val_loss did not improve from 0.00244
# Epoch 70/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0158 - accuracy: 0.9954 - val_loss: 0.0294 - val_accuracy: 0.9898
#
# Epoch 00070: val_loss did not improve from 0.00244
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.0075 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00244
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.0080 - val_accuracy: 0.9969
#
# Epoch 00072: val_loss did not improve from 0.00244
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.0134 - val_accuracy: 0.9953
#
# Epoch 00073: val_loss did not improve from 0.00244
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0134 - val_accuracy: 0.9965
#
# Epoch 00074: val_loss did not improve from 0.00244
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0820 - val_accuracy: 0.9758
#
# Epoch 00075: val_loss did not improve from 0.00244
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0094 - accuracy: 0.9965 - val_loss: 0.0277 - val_accuracy: 0.9918
#
# Epoch 00076: val_loss did not improve from 0.00244
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.0140 - val_accuracy: 0.9969
#
# Epoch 00077: val_loss did not improve from 0.00244
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0150 - val_accuracy: 0.9973
#
# Epoch 00078: val_loss did not improve from 0.00244
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.9362 - val_accuracy: 0.8664
#
# Epoch 00079: val_loss did not improve from 0.00244
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.0082 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00244
# Epoch 81/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0054 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00244
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0076 - val_accuracy: 0.9984
#
# Epoch 00082: val_loss did not improve from 0.00244
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0077 - val_accuracy: 0.9980
#
# Epoch 00083: val_loss did not improve from 0.00244
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9970 - val_loss: 0.0081 - val_accuracy: 0.9980
#
# Epoch 00084: val_loss did not improve from 0.00244
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00244
# Epoch 86/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00086: val_loss did not improve from 0.00244
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.0303 - val_accuracy: 0.9949
#
# Epoch 00087: val_loss did not improve from 0.00244
# Epoch 88/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9976 - val_loss: 0.0179 - val_accuracy: 0.9973
#
# Epoch 00088: val_loss did not improve from 0.00244
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0190 - val_accuracy: 0.9973
#
# Epoch 00089: val_loss did not improve from 0.00244
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0079 - accuracy: 0.9968 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00244
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.1541 - val_accuracy: 0.9617
#
# Epoch 00091: val_loss did not improve from 0.00244
# Epoch 92/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.1408 - val_accuracy: 0.9723
#
# Epoch 00092: val_loss did not improve from 0.00244
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.2114 - val_accuracy: 0.9449
#
# Epoch 00093: val_loss did not improve from 0.00244
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0252 - val_accuracy: 0.9906
#
# Epoch 00094: val_loss did not improve from 0.00244
# Epoch 95/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.0019 - val_accuracy: 0.9984
#
# Epoch 00095: val_loss improved from 0.00244 to 0.00193, saving model to model.h5
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00096: val_loss did not improve from 0.00193
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0043 - accuracy: 0.9981 - val_loss: 0.0079 - val_accuracy: 0.9969
#
# Epoch 00097: val_loss did not improve from 0.00193
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.0038 - val_accuracy: 0.9984
#
# Epoch 00098: val_loss did not improve from 0.00193
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0066 - val_accuracy: 0.9977
#
# Epoch 00099: val_loss did not improve from 0.00193
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.0179 - val_accuracy: 0.9977
#
# Epoch 00100: val_loss did not improve from 0.00193
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9977
# Val Score:  [0.017910709604620934, 0.9976562261581421]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4489 - accuracy: 0.8489 - val_loss: 2.0219 - val_accuracy: 0.5813
#
# Epoch 00001: val_loss did not improve from 0.00193
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1605 - accuracy: 0.9387 - val_loss: 0.7672 - val_accuracy: 0.7930
#
# Epoch 00002: val_loss did not improve from 0.00193
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1089 - accuracy: 0.9612 - val_loss: 0.0741 - val_accuracy: 0.9691
#
# Epoch 00003: val_loss did not improve from 0.00193
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0725 - accuracy: 0.9757 - val_loss: 0.0414 - val_accuracy: 0.9883
#
# Epoch 00004: val_loss did not improve from 0.00193
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0783 - accuracy: 0.9735 - val_loss: 0.0526 - val_accuracy: 0.9816
#
# Epoch 00005: val_loss did not improve from 0.00193
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0436 - accuracy: 0.9853 - val_loss: 0.0189 - val_accuracy: 0.9957
#
# Epoch 00006: val_loss did not improve from 0.00193
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0481 - accuracy: 0.9843 - val_loss: 0.0311 - val_accuracy: 0.9902
#
# Epoch 00007: val_loss did not improve from 0.00193
# Epoch 8/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0371 - accuracy: 0.9877 - val_loss: 0.0117 - val_accuracy: 0.9949
#
# Epoch 00008: val_loss did not improve from 0.00193
# Epoch 9/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0396 - accuracy: 0.9863 - val_loss: 0.0170 - val_accuracy: 0.9949
#
# Epoch 00009: val_loss did not improve from 0.00193
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0262 - accuracy: 0.9917 - val_loss: 0.2247 - val_accuracy: 0.9332
#
# Epoch 00010: val_loss did not improve from 0.00193
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 0.0209 - val_accuracy: 0.9922
#
# Epoch 00011: val_loss did not improve from 0.00193
# Epoch 12/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.1018 - val_accuracy: 0.9676
#
# Epoch 00012: val_loss did not improve from 0.00193
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0261 - accuracy: 0.9906 - val_loss: 0.0295 - val_accuracy: 0.9898
#
# Epoch 00013: val_loss did not improve from 0.00193
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0330 - accuracy: 0.9896 - val_loss: 0.1316 - val_accuracy: 0.9551
#
# Epoch 00014: val_loss did not improve from 0.00193
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.0137 - val_accuracy: 0.9937
#
# Epoch 00015: val_loss did not improve from 0.00193
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0298 - accuracy: 0.9899 - val_loss: 0.0353 - val_accuracy: 0.9879
#
# Epoch 00016: val_loss did not improve from 0.00193
# Epoch 17/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0296 - accuracy: 0.9890 - val_loss: 0.0443 - val_accuracy: 0.9855
#
# Epoch 00017: val_loss did not improve from 0.00193
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.3487 - val_accuracy: 0.9223
#
# Epoch 00018: val_loss did not improve from 0.00193
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0259 - accuracy: 0.9912 - val_loss: 0.0168 - val_accuracy: 0.9953
#
# Epoch 00019: val_loss did not improve from 0.00193
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.0129 - val_accuracy: 0.9949
#
# Epoch 00020: val_loss did not improve from 0.00193
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9957 - val_loss: 0.0416 - val_accuracy: 0.9957
#
# Epoch 00021: val_loss did not improve from 0.00193
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.0426 - val_accuracy: 0.9863
#
# Epoch 00022: val_loss did not improve from 0.00193
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0058 - val_accuracy: 0.9973
#
# Epoch 00023: val_loss did not improve from 0.00193
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0246 - accuracy: 0.9932 - val_loss: 0.0073 - val_accuracy: 0.9973
#
# Epoch 00024: val_loss did not improve from 0.00193
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 0.2089 - val_accuracy: 0.9453
#
# Epoch 00025: val_loss did not improve from 0.00193
# Epoch 26/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0228 - accuracy: 0.9933 - val_loss: 0.0051 - val_accuracy: 0.9973
#
# Epoch 00026: val_loss did not improve from 0.00193
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0101 - accuracy: 0.9958 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00027: val_loss did not improve from 0.00193
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 0.0129 - val_accuracy: 0.9937
#
# Epoch 00028: val_loss did not improve from 0.00193
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0260 - accuracy: 0.9922 - val_loss: 0.0113 - val_accuracy: 0.9961
#
# Epoch 00029: val_loss did not improve from 0.00193
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.0066 - val_accuracy: 0.9977
#
# Epoch 00030: val_loss did not improve from 0.00193
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0138 - accuracy: 0.9952 - val_loss: 0.0083 - val_accuracy: 0.9969
#
# Epoch 00031: val_loss did not improve from 0.00193
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.5980 - val_accuracy: 0.8664
#
# Epoch 00032: val_loss did not improve from 0.00193
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0193 - accuracy: 0.9928 - val_loss: 0.0081 - val_accuracy: 0.9973
#
# Epoch 00033: val_loss did not improve from 0.00193
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00034: val_loss did not improve from 0.00193
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0098 - val_accuracy: 0.9961
#
# Epoch 00035: val_loss did not improve from 0.00193
# Epoch 36/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0204 - accuracy: 0.9931 - val_loss: 0.0138 - val_accuracy: 0.9934
#
# Epoch 00036: val_loss did not improve from 0.00193
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0183 - accuracy: 0.9935 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00037: val_loss did not improve from 0.00193
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0916 - val_accuracy: 0.9688
#
# Epoch 00038: val_loss did not improve from 0.00193
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0122 - accuracy: 0.9953 - val_loss: 0.0139 - val_accuracy: 0.9953
#
# Epoch 00039: val_loss did not improve from 0.00193
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0075 - val_accuracy: 0.9980
#
# Epoch 00040: val_loss did not improve from 0.00193
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9965 - val_loss: 0.0101 - val_accuracy: 0.9973
#
# Epoch 00041: val_loss did not improve from 0.00193
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.0115 - val_accuracy: 0.9965
#
# Epoch 00042: val_loss did not improve from 0.00193
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00043: val_loss did not improve from 0.00193
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0680 - val_accuracy: 0.9781
#
# Epoch 00044: val_loss did not improve from 0.00193
# Epoch 45/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.0795 - val_accuracy: 0.9770
#
# Epoch 00045: val_loss did not improve from 0.00193
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00046: val_loss did not improve from 0.00193
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0052 - val_accuracy: 0.9973
#
# Epoch 00047: val_loss did not improve from 0.00193
# Epoch 48/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0132 - accuracy: 0.9962 - val_loss: 0.0337 - val_accuracy: 0.9953
#
# Epoch 00048: val_loss did not improve from 0.00193
# Epoch 49/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0237 - accuracy: 0.9933 - val_loss: 0.0080 - val_accuracy: 0.9973
#
# Epoch 00049: val_loss did not improve from 0.00193
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0119 - val_accuracy: 0.9965
#
# Epoch 00050: val_loss did not improve from 0.00193
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.0069 - val_accuracy: 0.9961
#
# Epoch 00051: val_loss did not improve from 0.00193
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0080 - val_accuracy: 0.9957
#
# Epoch 00052: val_loss did not improve from 0.00193
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0393 - val_accuracy: 0.9871
#
# Epoch 00053: val_loss did not improve from 0.00193
# Epoch 54/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0185 - accuracy: 0.9942 - val_loss: 0.0083 - val_accuracy: 0.9977
#
# Epoch 00054: val_loss did not improve from 0.00193
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.0881 - val_accuracy: 0.9730
#
# Epoch 00055: val_loss did not improve from 0.00193
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0196 - val_accuracy: 0.9957
#
# Epoch 00056: val_loss did not improve from 0.00193
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00057: val_loss did not improve from 0.00193
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0081 - accuracy: 0.9966 - val_loss: 0.0054 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00193
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9958 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00059: val_loss did not improve from 0.00193
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.0099 - val_accuracy: 0.9969
#
# Epoch 00060: val_loss did not improve from 0.00193
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0093 - val_accuracy: 0.9977
#
# Epoch 00061: val_loss did not improve from 0.00193
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 0.0046 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00193
# Epoch 63/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0127 - val_accuracy: 0.9965
#
# Epoch 00063: val_loss did not improve from 0.00193
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00064: val_loss did not improve from 0.00193
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00065: val_loss did not improve from 0.00193
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00066: val_loss did not improve from 0.00193
# Epoch 67/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9950 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00067: val_loss did not improve from 0.00193
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00068: val_loss did not improve from 0.00193
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.9148 - val_accuracy: 0.8383
#
# Epoch 00069: val_loss did not improve from 0.00193
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0154 - val_accuracy: 0.9949
#
# Epoch 00070: val_loss did not improve from 0.00193
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00193
# Epoch 72/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0179 - val_accuracy: 0.9957
#
# Epoch 00072: val_loss did not improve from 0.00193
# Epoch 73/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0054 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00193
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9959 - val_loss: 0.2050 - val_accuracy: 0.9602
#
# Epoch 00074: val_loss did not improve from 0.00193
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00193
# Epoch 76/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9962 - val_loss: 0.0084 - val_accuracy: 0.9980
#
# Epoch 00076: val_loss did not improve from 0.00193
# Epoch 77/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00077: val_loss did not improve from 0.00193
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.0026 - val_accuracy: 0.9980
#
# Epoch 00078: val_loss did not improve from 0.00193
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.0051 - val_accuracy: 0.9973
#
# Epoch 00079: val_loss did not improve from 0.00193
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00193
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.0040 - val_accuracy: 0.9984
#
# Epoch 00081: val_loss did not improve from 0.00193
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.0161 - val_accuracy: 0.9937
#
# Epoch 00082: val_loss did not improve from 0.00193
# Epoch 83/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0159 - accuracy: 0.9952 - val_loss: 0.0031 - val_accuracy: 0.9988
#
# Epoch 00083: val_loss did not improve from 0.00193
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0079 - val_accuracy: 0.9965
#
# Epoch 00084: val_loss did not improve from 0.00193
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.0046 - val_accuracy: 0.9973
#
# Epoch 00085: val_loss did not improve from 0.00193
# Epoch 86/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00086: val_loss did not improve from 0.00193
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0050 - accuracy: 0.9977 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00087: val_loss did not improve from 0.00193
# Epoch 88/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00193
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0287 - val_accuracy: 0.9906
#
# Epoch 00089: val_loss did not improve from 0.00193
# Epoch 90/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0087 - accuracy: 0.9963 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00193
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9960 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00193
# Epoch 92/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0127 - accuracy: 0.9954 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00092: val_loss did not improve from 0.00193
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0072 - accuracy: 0.9968 - val_loss: 0.0113 - val_accuracy: 0.9965
#
# Epoch 00093: val_loss did not improve from 0.00193
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0035 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00193
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0046 - accuracy: 0.9979 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00095: val_loss did not improve from 0.00193
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00096: val_loss did not improve from 0.00193
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00097: val_loss did not improve from 0.00193
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00193
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9963 - val_loss: 0.0075 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00193
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 2.2096 - val_accuracy: 0.7652
#
# Epoch 00100: val_loss did not improve from 0.00193
# 80/80 [==============================] - 0s 3ms/step - loss: 2.2096 - accuracy: 0.7652
# Val Score:  [2.2095656394958496, 0.7652343511581421]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4305 - accuracy: 0.8642 - val_loss: 3.4022 - val_accuracy: 0.4773
#
# Epoch 00001: val_loss did not improve from 0.00193
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1433 - accuracy: 0.9492 - val_loss: 1.0600 - val_accuracy: 0.7082
#
# Epoch 00002: val_loss did not improve from 0.00193
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0993 - accuracy: 0.9651 - val_loss: 0.0668 - val_accuracy: 0.9762
#
# Epoch 00003: val_loss did not improve from 0.00193
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0626 - accuracy: 0.9788 - val_loss: 0.4527 - val_accuracy: 0.8617
#
# Epoch 00004: val_loss did not improve from 0.00193
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0624 - accuracy: 0.9791 - val_loss: 0.2213 - val_accuracy: 0.9141
#
# Epoch 00005: val_loss did not improve from 0.00193
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0467 - accuracy: 0.9836 - val_loss: 0.0428 - val_accuracy: 0.9840
#
# Epoch 00006: val_loss did not improve from 0.00193
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0390 - accuracy: 0.9859 - val_loss: 4.2384 - val_accuracy: 0.6824
#
# Epoch 00007: val_loss did not improve from 0.00193
# Epoch 8/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0374 - accuracy: 0.9877 - val_loss: 0.0420 - val_accuracy: 0.9820
#
# Epoch 00008: val_loss did not improve from 0.00193
# Epoch 9/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0273 - accuracy: 0.9897 - val_loss: 0.0168 - val_accuracy: 0.9937
#
# Epoch 00009: val_loss did not improve from 0.00193
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0244 - accuracy: 0.9920 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00010: val_loss did not improve from 0.00193
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9914 - val_loss: 0.0640 - val_accuracy: 0.9766
#
# Epoch 00011: val_loss did not improve from 0.00193
# Epoch 12/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0382 - accuracy: 0.9889 - val_loss: 0.0162 - val_accuracy: 0.9930
#
# Epoch 00012: val_loss did not improve from 0.00193
# Epoch 13/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.0129 - val_accuracy: 0.9957
#
# Epoch 00013: val_loss did not improve from 0.00193
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0247 - accuracy: 0.9918 - val_loss: 0.2684 - val_accuracy: 0.9312
#
# Epoch 00014: val_loss did not improve from 0.00193
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0469 - val_accuracy: 0.9855
#
# Epoch 00015: val_loss did not improve from 0.00193
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.0176 - val_accuracy: 0.9945
#
# Epoch 00016: val_loss did not improve from 0.00193
# Epoch 17/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 0.0071 - val_accuracy: 0.9961
#
# Epoch 00017: val_loss did not improve from 0.00193
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0297 - accuracy: 0.9899 - val_loss: 5.7941 - val_accuracy: 0.6941
#
# Epoch 00018: val_loss did not improve from 0.00193
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0188 - accuracy: 0.9943 - val_loss: 0.0176 - val_accuracy: 0.9953
#
# Epoch 00019: val_loss did not improve from 0.00193
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.2955 - val_accuracy: 0.9242
#
# Epoch 00020: val_loss did not improve from 0.00193
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0086 - val_accuracy: 0.9973
#
# Epoch 00021: val_loss did not improve from 0.00193
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.0129 - val_accuracy: 0.9941
#
# Epoch 00022: val_loss did not improve from 0.00193
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 0.0759 - val_accuracy: 0.9785
#
# Epoch 00023: val_loss did not improve from 0.00193
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0159 - accuracy: 0.9933 - val_loss: 0.2406 - val_accuracy: 0.9410
#
# Epoch 00024: val_loss did not improve from 0.00193
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0174 - accuracy: 0.9940 - val_loss: 0.0514 - val_accuracy: 0.9824
#
# Epoch 00025: val_loss did not improve from 0.00193
# Epoch 26/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9957 - val_loss: 0.9070 - val_accuracy: 0.7895
#
# Epoch 00026: val_loss did not improve from 0.00193
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.0227 - val_accuracy: 0.9949
#
# Epoch 00027: val_loss did not improve from 0.00193
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.0096 - val_accuracy: 0.9949
#
# Epoch 00028: val_loss did not improve from 0.00193
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.0206 - val_accuracy: 0.9941
#
# Epoch 00029: val_loss did not improve from 0.00193
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00030: val_loss did not improve from 0.00193
# Epoch 31/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0123 - accuracy: 0.9954 - val_loss: 0.0122 - val_accuracy: 0.9957
#
# Epoch 00031: val_loss did not improve from 0.00193
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00032: val_loss did not improve from 0.00193
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.1588 - val_accuracy: 0.9551
#
# Epoch 00033: val_loss did not improve from 0.00193
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.0236 - val_accuracy: 0.9922
#
# Epoch 00034: val_loss did not improve from 0.00193
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9953 - val_loss: 0.0106 - val_accuracy: 0.9949
#
# Epoch 00035: val_loss did not improve from 0.00193
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0126 - accuracy: 0.9956 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00036: val_loss did not improve from 0.00193
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0125 - val_accuracy: 0.9957
#
# Epoch 00037: val_loss did not improve from 0.00193
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9933 - val_loss: 0.1314 - val_accuracy: 0.9559
#
# Epoch 00038: val_loss did not improve from 0.00193
# Epoch 39/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0133 - accuracy: 0.9952 - val_loss: 0.0296 - val_accuracy: 0.9906
#
# Epoch 00039: val_loss did not improve from 0.00193
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9965 - val_loss: 0.0111 - val_accuracy: 0.9965
#
# Epoch 00040: val_loss did not improve from 0.00193
# Epoch 41/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00193
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0108 - val_accuracy: 0.9953
#
# Epoch 00021: val_loss did not improve from 0.00193
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.0186 - val_accuracy: 0.9934
#
# Epoch 00022: val_loss did not improve from 0.00193
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9931 - val_loss: 0.1029 - val_accuracy: 0.9688
#
# Epoch 00023: val_loss did not improve from 0.00193
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0194 - accuracy: 0.9925 - val_loss: 0.0059 - val_accuracy: 0.9980
#
# Epoch 00024: val_loss did not improve from 0.00193
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0188 - accuracy: 0.9938 - val_loss: 0.0194 - val_accuracy: 0.9930
#
# Epoch 00025: val_loss did not improve from 0.00193
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.0308 - val_accuracy: 0.9883
#
# Epoch 00026: val_loss did not improve from 0.00193
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.0174 - val_accuracy: 0.9930
#
# Epoch 00027: val_loss did not improve from 0.00193
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.0112 - val_accuracy: 0.9945
#
# Epoch 00028: val_loss did not improve from 0.00193
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0120 - accuracy: 0.9953 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00029: val_loss did not improve from 0.00193
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0315 - val_accuracy: 0.9930
#
# Epoch 00030: val_loss did not improve from 0.00193
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.0720 - val_accuracy: 0.9824
#
# Epoch 00031: val_loss did not improve from 0.00193
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9954 - val_loss: 0.0123 - val_accuracy: 0.9941
#
# Epoch 00032: val_loss did not improve from 0.00193
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0278 - val_accuracy: 0.9887
#
# Epoch 00033: val_loss did not improve from 0.00193
# Epoch 34/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0221 - accuracy: 0.9946 - val_loss: 0.5364 - val_accuracy: 0.8969
#
# Epoch 00034: val_loss did not improve from 0.00193
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00035: val_loss did not improve from 0.00193
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.0702 - val_accuracy: 0.9715
#
# Epoch 00036: val_loss did not improve from 0.00193
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9961 - val_loss: 0.0428 - val_accuracy: 0.9906
#
# Epoch 00037: val_loss did not improve from 0.00193
# Epoch 38/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9956 - val_loss: 0.0083 - val_accuracy: 0.9977
#
# Epoch 00038: val_loss did not improve from 0.00193
# Epoch 39/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0140 - accuracy: 0.9949 - val_loss: 0.0323 - val_accuracy: 0.9957
#
# Epoch 00039: val_loss did not improve from 0.00193
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9960 - val_loss: 0.0045 - val_accuracy: 0.9984
#
# Epoch 00040: val_loss did not improve from 0.00193
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0134 - accuracy: 0.9949 - val_loss: 0.0059 - val_accuracy: 0.9961
#
# Epoch 00041: val_loss did not improve from 0.00193
# Epoch 42/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.0047 - val_accuracy: 0.9977
#
# Epoch 00042: val_loss did not improve from 0.00193
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9961 - val_loss: 0.1028 - val_accuracy: 0.9680
#
# Epoch 00043: val_loss did not improve from 0.00193
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9963 - val_loss: 0.0115 - val_accuracy: 0.9961
#
# Epoch 00044: val_loss did not improve from 0.00193
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00045: val_loss did not improve from 0.00193
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0095 - accuracy: 0.9964 - val_loss: 0.0126 - val_accuracy: 0.9977
#
# Epoch 00046: val_loss did not improve from 0.00193
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0134 - accuracy: 0.9949 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00047: val_loss did not improve from 0.00193
# Epoch 48/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0116 - accuracy: 0.9953 - val_loss: 0.0147 - val_accuracy: 0.9961
#
# Epoch 00048: val_loss did not improve from 0.00193
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00049: val_loss did not improve from 0.00193
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0298 - val_accuracy: 0.9914
#
# Epoch 00050: val_loss did not improve from 0.00193
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.0070 - val_accuracy: 0.9961
#
# Epoch 00051: val_loss did not improve from 0.00193
# Epoch 52/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9971 - val_loss: 0.0058 - val_accuracy: 0.9977
#
# Epoch 00052: val_loss did not improve from 0.00193
# Epoch 53/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.2662 - val_accuracy: 0.9574
#
# Epoch 00053: val_loss did not improve from 0.00193
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0128 - accuracy: 0.9949 - val_loss: 0.0329 - val_accuracy: 0.9965
#
# Epoch 00054: val_loss did not improve from 0.00193
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00055: val_loss did not improve from 0.00193
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9969 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00056: val_loss did not improve from 0.00193
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0136 - val_accuracy: 0.9977
#
# Epoch 00057: val_loss did not improve from 0.00193
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.2258 - val_accuracy: 0.9469
#
# Epoch 00058: val_loss did not improve from 0.00193
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00059: val_loss did not improve from 0.00193
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.1789 - val_accuracy: 0.9480
#
# Epoch 00060: val_loss did not improve from 0.00193
# Epoch 61/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0103 - val_accuracy: 0.9969
#
# Epoch 00061: val_loss did not improve from 0.00193
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 1.7713 - val_accuracy: 0.8039
#
# Epoch 00062: val_loss did not improve from 0.00193
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00063: val_loss did not improve from 0.00193
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0118 - accuracy: 0.9954 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00064: val_loss did not improve from 0.00193
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0162 - val_accuracy: 0.9973
#
# Epoch 00065: val_loss did not improve from 0.00193
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00066: val_loss did not improve from 0.00193
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0493 - val_accuracy: 0.9816
#
# Epoch 00067: val_loss did not improve from 0.00193
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 0.0329 - val_accuracy: 0.9977
#
# Epoch 00068: val_loss did not improve from 0.00193
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00069: val_loss did not improve from 0.00193
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 0.0075 - val_accuracy: 0.9973
#
# Epoch 00070: val_loss did not improve from 0.00193
# Epoch 71/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0054 - val_accuracy: 0.9977
#
# Epoch 00071: val_loss did not improve from 0.00193
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9955 - val_loss: 0.0408 - val_accuracy: 0.9852
#
# Epoch 00072: val_loss did not improve from 0.00193
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0110 - accuracy: 0.9956 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00193
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0598 - val_accuracy: 0.9754
#
# Epoch 00074: val_loss did not improve from 0.00193
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00193
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 0.0662 - val_accuracy: 0.9930
#
# Epoch 00076: val_loss did not improve from 0.00193
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00077: val_loss did not improve from 0.00193
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.2097 - val_accuracy: 0.9359
#
# Epoch 00078: val_loss did not improve from 0.00193
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00193
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0088 - val_accuracy: 0.9973
#
# Epoch 00080: val_loss did not improve from 0.00193
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0362 - val_accuracy: 0.9961
#
# Epoch 00081: val_loss did not improve from 0.00193
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9965 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00082: val_loss did not improve from 0.00193
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 0.0021 - val_accuracy: 0.9984
#
# Epoch 00083: val_loss did not improve from 0.00193
# Epoch 84/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.0067 - val_accuracy: 0.9977
#
# Epoch 00084: val_loss did not improve from 0.00193
# Epoch 85/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.0038 - val_accuracy: 0.9973
#
# Epoch 00085: val_loss did not improve from 0.00193
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9972 - val_loss: 0.0301 - val_accuracy: 0.9965
#
# Epoch 00086: val_loss did not improve from 0.00193
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0363 - val_accuracy: 0.9957
#
# Epoch 00087: val_loss did not improve from 0.00193
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00193
# Epoch 89/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00089: val_loss did not improve from 0.00193
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.1686 - val_accuracy: 0.9492
#
# Epoch 00090: val_loss did not improve from 0.00193
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.0050 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00193
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.1335 - val_accuracy: 0.9922
#
# Epoch 00092: val_loss did not improve from 0.00193
# Epoch 93/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9980 - val_loss: 0.0038 - val_accuracy: 0.9984
#
# Epoch 00093: val_loss did not improve from 0.00193
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0046 - accuracy: 0.9979 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00094: val_loss did not improve from 0.00193
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0092 - accuracy: 0.9963 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00095: val_loss did not improve from 0.00193
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00096: val_loss did not improve from 0.00193
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9973 - val_loss: 0.0110 - val_accuracy: 0.9969
#
# Epoch 00097: val_loss did not improve from 0.00193
# Epoch 98/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00098: val_loss did not improve from 0.00193
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.0227 - val_accuracy: 0.9953
#
# Epoch 00099: val_loss did not improve from 0.00193
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.0055 - val_accuracy: 0.9973
#
# Epoch 00100: val_loss did not improve from 0.00193
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9973
# Val Score:  [0.0055422717705369, 0.997265636920929]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       1.00      1.00      1.00       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      1.00      1.00       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 0.9984
# Test Accuracy: 99.84375238418579

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
