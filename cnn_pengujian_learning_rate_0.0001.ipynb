# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **LEARNING RATE TEST 0.0001 -- USING ADAM AND BEST RESULT OF HIDDEN LAYER(4)**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-4
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_48 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_72 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_73 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_74 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_75 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_76 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_77 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.5198 - accuracy: 0.8253 - val_loss: 4.6502 - val_accuracy: 0.3234
#
# Epoch 00001: val_loss improved from inf to 4.65024, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.2254 - accuracy: 0.9209 - val_loss: 1.5219 - val_accuracy: 0.6805
#
# Epoch 00002: val_loss improved from 4.65024 to 1.52190, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1609 - accuracy: 0.9441 - val_loss: 0.6610 - val_accuracy: 0.8242
#
# Epoch 00003: val_loss improved from 1.52190 to 0.66105, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1219 - accuracy: 0.9574 - val_loss: 0.3512 - val_accuracy: 0.8844
#
# Epoch 00004: val_loss improved from 0.66105 to 0.35125, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0998 - accuracy: 0.9646 - val_loss: 0.3188 - val_accuracy: 0.8934
#
# Epoch 00005: val_loss improved from 0.35125 to 0.31882, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0793 - accuracy: 0.9737 - val_loss: 0.2535 - val_accuracy: 0.9199
#
# Epoch 00006: val_loss improved from 0.31882 to 0.25352, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0761 - accuracy: 0.9747 - val_loss: 0.3510 - val_accuracy: 0.8941
#
# Epoch 00007: val_loss did not improve from 0.25352
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0625 - accuracy: 0.9797 - val_loss: 0.3174 - val_accuracy: 0.9113
#
# Epoch 00008: val_loss did not improve from 0.25352
# Epoch 9/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.5210 - val_accuracy: 0.8930
#
# Epoch 00009: val_loss did not improve from 0.25352
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0553 - accuracy: 0.9823 - val_loss: 0.1778 - val_accuracy: 0.9551
#
# Epoch 00010: val_loss improved from 0.25352 to 0.17778, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0440 - accuracy: 0.9859 - val_loss: 0.2283 - val_accuracy: 0.9320
#
# Epoch 00011: val_loss did not improve from 0.17778
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0447 - accuracy: 0.9856 - val_loss: 0.3056 - val_accuracy: 0.9219
#
# Epoch 00012: val_loss did not improve from 0.17778
# Epoch 13/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0342 - accuracy: 0.9905 - val_loss: 0.2064 - val_accuracy: 0.9453
#
# Epoch 00013: val_loss did not improve from 0.17778
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0406 - accuracy: 0.9866 - val_loss: 0.1679 - val_accuracy: 0.9508
#
# Epoch 00014: val_loss improved from 0.17778 to 0.16788, saving model to model.h5
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0374 - accuracy: 0.9886 - val_loss: 0.0733 - val_accuracy: 0.9770
#
# Epoch 00015: val_loss improved from 0.16788 to 0.07328, saving model to model.h5
# Epoch 16/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0253 - accuracy: 0.9928 - val_loss: 0.4693 - val_accuracy: 0.8945
#
# Epoch 00016: val_loss did not improve from 0.07328
# Epoch 17/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0325 - accuracy: 0.9897 - val_loss: 0.2996 - val_accuracy: 0.9195
#
# Epoch 00017: val_loss did not improve from 0.07328
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.3663 - val_accuracy: 0.9223
#
# Epoch 00018: val_loss did not improve from 0.07328
# Epoch 19/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0284 - accuracy: 0.9911 - val_loss: 0.1690 - val_accuracy: 0.9527
#
# Epoch 00019: val_loss did not improve from 0.07328
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0249 - accuracy: 0.9921 - val_loss: 0.0702 - val_accuracy: 0.9789
#
# Epoch 00020: val_loss improved from 0.07328 to 0.07024, saving model to model.h5
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0213 - accuracy: 0.9922 - val_loss: 0.2255 - val_accuracy: 0.9406
#
# Epoch 00021: val_loss did not improve from 0.07024
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.0707 - val_accuracy: 0.9797
#
# Epoch 00022: val_loss did not improve from 0.07024
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.2638 - val_accuracy: 0.9363
#
# Epoch 00023: val_loss did not improve from 0.07024
# Epoch 24/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.2149 - val_accuracy: 0.9535
#
# Epoch 00024: val_loss did not improve from 0.07024
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0170 - accuracy: 0.9939 - val_loss: 0.2806 - val_accuracy: 0.9406
#
# Epoch 00025: val_loss did not improve from 0.07024
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0239 - accuracy: 0.9913 - val_loss: 0.0684 - val_accuracy: 0.9848
#
# Epoch 00026: val_loss improved from 0.07024 to 0.06845, saving model to model.h5
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0170 - accuracy: 0.9941 - val_loss: 0.2184 - val_accuracy: 0.9488
#
# Epoch 00027: val_loss did not improve from 0.06845
# Epoch 28/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 0.1681 - val_accuracy: 0.9613
#
# Epoch 00028: val_loss did not improve from 0.06845
# Epoch 29/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0159 - accuracy: 0.9939 - val_loss: 0.0962 - val_accuracy: 0.9727
#
# Epoch 00029: val_loss did not improve from 0.06845
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9952 - val_loss: 0.0429 - val_accuracy: 0.9902
#
# Epoch 00030: val_loss improved from 0.06845 to 0.04286, saving model to model.h5
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9941 - val_loss: 0.0423 - val_accuracy: 0.9906
#
# Epoch 00031: val_loss improved from 0.04286 to 0.04229, saving model to model.h5
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 0.0480 - val_accuracy: 0.9883
#
# Epoch 00032: val_loss did not improve from 0.04229
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0112 - accuracy: 0.9955 - val_loss: 0.0873 - val_accuracy: 0.9836
#
# Epoch 00033: val_loss did not improve from 0.04229
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.1504 - val_accuracy: 0.9641
#
# Epoch 00034: val_loss did not improve from 0.04229
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0881 - val_accuracy: 0.9793
#
# Epoch 00035: val_loss did not improve from 0.04229
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 1.3116 - val_accuracy: 0.8297
#
# Epoch 00036: val_loss did not improve from 0.04229
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.0470 - val_accuracy: 0.9848
#
# Epoch 00037: val_loss did not improve from 0.04229
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 0.0435 - val_accuracy: 0.9875
#
# Epoch 00038: val_loss did not improve from 0.04229
# Epoch 39/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.0282 - val_accuracy: 0.9937
#
# Epoch 00039: val_loss improved from 0.04229 to 0.02820, saving model to model.h5
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0443 - val_accuracy: 0.9859
#
# Epoch 00040: val_loss did not improve from 0.02820
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0295 - val_accuracy: 0.9934
#
# Epoch 00041: val_loss did not improve from 0.02820
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9957 - val_loss: 0.0514 - val_accuracy: 0.9891
#
# Epoch 00042: val_loss did not improve from 0.02820
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.0647 - val_accuracy: 0.9828
#
# Epoch 00043: val_loss did not improve from 0.02820
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0526 - val_accuracy: 0.9902
#
# Epoch 00044: val_loss did not improve from 0.02820
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.0969 - val_accuracy: 0.9797
#
# Epoch 00045: val_loss did not improve from 0.02820
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0109 - accuracy: 0.9957 - val_loss: 0.1026 - val_accuracy: 0.9766
#
# Epoch 00046: val_loss did not improve from 0.02820
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0110 - accuracy: 0.9955 - val_loss: 0.1117 - val_accuracy: 0.9734
#
# Epoch 00047: val_loss did not improve from 0.02820
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0524 - val_accuracy: 0.9891
#
# Epoch 00048: val_loss did not improve from 0.02820
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0096 - accuracy: 0.9959 - val_loss: 0.0590 - val_accuracy: 0.9867
#
# Epoch 00049: val_loss did not improve from 0.02820
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0260 - val_accuracy: 0.9945
#
# Epoch 00050: val_loss improved from 0.02820 to 0.02599, saving model to model.h5
# Epoch 51/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.1579 - val_accuracy: 0.9582
#
# Epoch 00051: val_loss did not improve from 0.02599
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0229 - val_accuracy: 0.9949
#
# Epoch 00052: val_loss improved from 0.02599 to 0.02291, saving model to model.h5
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.0259 - val_accuracy: 0.9949
#
# Epoch 00053: val_loss did not improve from 0.02291
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.0815 - val_accuracy: 0.9832
#
# Epoch 00054: val_loss did not improve from 0.02291
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0124 - accuracy: 0.9948 - val_loss: 0.0243 - val_accuracy: 0.9957
#
# Epoch 00055: val_loss did not improve from 0.02291
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0077 - accuracy: 0.9966 - val_loss: 0.0355 - val_accuracy: 0.9941
#
# Epoch 00056: val_loss did not improve from 0.02291
# Epoch 57/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0354 - val_accuracy: 0.9949
#
# Epoch 00057: val_loss did not improve from 0.02291
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0069 - accuracy: 0.9970 - val_loss: 0.0185 - val_accuracy: 0.9953
#
# Epoch 00058: val_loss improved from 0.02291 to 0.01853, saving model to model.h5
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.0519 - val_accuracy: 0.9906
#
# Epoch 00059: val_loss did not improve from 0.01853
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.0874 - val_accuracy: 0.9797
#
# Epoch 00060: val_loss did not improve from 0.01853
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0431 - val_accuracy: 0.9902
#
# Epoch 00061: val_loss did not improve from 0.01853
# Epoch 62/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0071 - accuracy: 0.9966 - val_loss: 0.0267 - val_accuracy: 0.9957
#
# Epoch 00062: val_loss did not improve from 0.01853
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0556 - val_accuracy: 0.9836
#
# Epoch 00063: val_loss did not improve from 0.01853
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9973 - val_loss: 0.0224 - val_accuracy: 0.9949
#
# Epoch 00064: val_loss did not improve from 0.01853
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0098 - accuracy: 0.9962 - val_loss: 0.6480 - val_accuracy: 0.9187
#
# Epoch 00065: val_loss did not improve from 0.01853
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0128 - val_accuracy: 0.9969
#
# Epoch 00066: val_loss improved from 0.01853 to 0.01279, saving model to model.h5
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0127 - val_accuracy: 0.9965
#
# Epoch 00067: val_loss improved from 0.01279 to 0.01273, saving model to model.h5
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 0.0120 - val_accuracy: 0.9965
#
# Epoch 00068: val_loss improved from 0.01273 to 0.01199, saving model to model.h5
# Epoch 69/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0431 - val_accuracy: 0.9879
#
# Epoch 00069: val_loss did not improve from 0.01199
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.0149 - val_accuracy: 0.9961
#
# Epoch 00070: val_loss did not improve from 0.01199
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0459 - val_accuracy: 0.9879
#
# Epoch 00071: val_loss did not improve from 0.01199
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0754 - val_accuracy: 0.9836
#
# Epoch 00072: val_loss did not improve from 0.01199
# Epoch 73/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 0.1213 - val_accuracy: 0.9754
#
# Epoch 00073: val_loss did not improve from 0.01199
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.0312 - val_accuracy: 0.9949
#
# Epoch 00074: val_loss did not improve from 0.01199
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0052 - accuracy: 0.9975 - val_loss: 0.0198 - val_accuracy: 0.9965
#
# Epoch 00075: val_loss did not improve from 0.01199
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0075 - accuracy: 0.9966 - val_loss: 0.0250 - val_accuracy: 0.9930
#
# Epoch 00076: val_loss did not improve from 0.01199
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0073 - accuracy: 0.9962 - val_loss: 0.0314 - val_accuracy: 0.9918
#
# Epoch 00077: val_loss did not improve from 0.01199
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.0390 - val_accuracy: 0.9930
#
# Epoch 00078: val_loss did not improve from 0.01199
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0105 - accuracy: 0.9959 - val_loss: 0.0274 - val_accuracy: 0.9895
#
# Epoch 00079: val_loss did not improve from 0.01199
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.0150 - val_accuracy: 0.9969
#
# Epoch 00080: val_loss did not improve from 0.01199
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0054 - accuracy: 0.9973 - val_loss: 0.0097 - val_accuracy: 0.9977
#
# Epoch 00081: val_loss improved from 0.01199 to 0.00970, saving model to model.h5
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0162 - val_accuracy: 0.9977
#
# Epoch 00082: val_loss did not improve from 0.00970
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0067 - val_accuracy: 0.9980
#
# Epoch 00083: val_loss improved from 0.00970 to 0.00669, saving model to model.h5
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.0402 - val_accuracy: 0.9937
#
# Epoch 00084: val_loss did not improve from 0.00669
# Epoch 85/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0060 - accuracy: 0.9974 - val_loss: 0.0119 - val_accuracy: 0.9977
#
# Epoch 00085: val_loss did not improve from 0.00669
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0062 - accuracy: 0.9971 - val_loss: 0.0108 - val_accuracy: 0.9969
#
# Epoch 00086: val_loss did not improve from 0.00669
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0043 - accuracy: 0.9978 - val_loss: 0.0451 - val_accuracy: 0.9977
#
# Epoch 00087: val_loss did not improve from 0.00669
# Epoch 88/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0245 - val_accuracy: 0.9957
#
# Epoch 00088: val_loss did not improve from 0.00669
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0325 - val_accuracy: 0.9910
#
# Epoch 00089: val_loss did not improve from 0.00669
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0406 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00669
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0056 - accuracy: 0.9976 - val_loss: 0.0227 - val_accuracy: 0.9969
#
# Epoch 00091: val_loss did not improve from 0.00669
# Epoch 92/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.0164 - val_accuracy: 0.9965
#
# Epoch 00092: val_loss did not improve from 0.00669
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0047 - accuracy: 0.9978 - val_loss: 0.0308 - val_accuracy: 0.9965
#
# Epoch 00093: val_loss did not improve from 0.00669
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9978 - val_loss: 0.0564 - val_accuracy: 0.9941
#
# Epoch 00094: val_loss did not improve from 0.00669
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9961 - val_loss: 0.1890 - val_accuracy: 0.9660
#
# Epoch 00095: val_loss did not improve from 0.00669
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0473 - val_accuracy: 0.9965
#
# Epoch 00096: val_loss did not improve from 0.00669
# Epoch 97/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0042 - accuracy: 0.9981 - val_loss: 0.0668 - val_accuracy: 0.9965
#
# Epoch 00097: val_loss did not improve from 0.00669
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9974 - val_loss: 0.0203 - val_accuracy: 0.9953
#
# Epoch 00098: val_loss did not improve from 0.00669
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0393 - val_accuracy: 0.9965
#
# Epoch 00099: val_loss did not improve from 0.00669
# Epoch 100/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.0257 - val_accuracy: 0.9965
#
# Epoch 00100: val_loss did not improve from 0.00669
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9965
# Val Score:  [0.025698695331811905, 0.9964843988418579]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.3820 - accuracy: 0.8803 - val_loss: 5.1407 - val_accuracy: 0.3297
#
# Epoch 00001: val_loss did not improve from 0.00669
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1181 - accuracy: 0.9563 - val_loss: 1.1697 - val_accuracy: 0.7508
#
# Epoch 00002: val_loss did not improve from 0.00669
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0841 - accuracy: 0.9705 - val_loss: 0.2756 - val_accuracy: 0.9062
#
# Epoch 00003: val_loss did not improve from 0.00669
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0663 - accuracy: 0.9770 - val_loss: 0.2370 - val_accuracy: 0.9230
#
# Epoch 00004: val_loss did not improve from 0.00669
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0565 - accuracy: 0.9794 - val_loss: 0.0889 - val_accuracy: 0.9660
#
# Epoch 00005: val_loss did not improve from 0.00669
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0436 - accuracy: 0.9860 - val_loss: 0.0793 - val_accuracy: 0.9738
#
# Epoch 00006: val_loss did not improve from 0.00669
# Epoch 7/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0382 - accuracy: 0.9863 - val_loss: 0.1021 - val_accuracy: 0.9652
#
# Epoch 00007: val_loss did not improve from 0.00669
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0339 - accuracy: 0.9884 - val_loss: 0.0781 - val_accuracy: 0.9742
#
# Epoch 00008: val_loss did not improve from 0.00669
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0310 - accuracy: 0.9892 - val_loss: 0.0487 - val_accuracy: 0.9836
#
# Epoch 00009: val_loss did not improve from 0.00669
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0263 - accuracy: 0.9918 - val_loss: 0.1222 - val_accuracy: 0.9637
#
# Epoch 00010: val_loss did not improve from 0.00669
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0288 - accuracy: 0.9901 - val_loss: 0.0760 - val_accuracy: 0.9793
#
# Epoch 00011: val_loss did not improve from 0.00669
# Epoch 12/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.0369 - val_accuracy: 0.9883
#
# Epoch 00012: val_loss did not improve from 0.00669
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0228 - accuracy: 0.9919 - val_loss: 0.1054 - val_accuracy: 0.9695
#
# Epoch 00013: val_loss did not improve from 0.00669
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0196 - accuracy: 0.9929 - val_loss: 0.0599 - val_accuracy: 0.9812
#
# Epoch 00014: val_loss did not improve from 0.00669
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0200 - accuracy: 0.9939 - val_loss: 0.0594 - val_accuracy: 0.9805
#
# Epoch 00015: val_loss did not improve from 0.00669
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0605 - val_accuracy: 0.9766
#
# Epoch 00016: val_loss did not improve from 0.00669
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0162 - accuracy: 0.9951 - val_loss: 0.0653 - val_accuracy: 0.9816
#
# Epoch 00017: val_loss did not improve from 0.00669
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0129 - accuracy: 0.9951 - val_loss: 0.0333 - val_accuracy: 0.9914
#
# Epoch 00018: val_loss did not improve from 0.00669
# Epoch 19/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0402 - val_accuracy: 0.9879
#
# Epoch 00019: val_loss did not improve from 0.00669
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.0276 - val_accuracy: 0.9906
#
# Epoch 00020: val_loss did not improve from 0.00669
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.0245 - val_accuracy: 0.9937
#
# Epoch 00021: val_loss did not improve from 0.00669
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0139 - accuracy: 0.9952 - val_loss: 0.0276 - val_accuracy: 0.9922
#
# Epoch 00022: val_loss did not improve from 0.00669
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.0162 - val_accuracy: 0.9957
#
# Epoch 00023: val_loss did not improve from 0.00669
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.1456 - val_accuracy: 0.9535
#
# Epoch 00024: val_loss did not improve from 0.00669
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0109 - accuracy: 0.9957 - val_loss: 0.0376 - val_accuracy: 0.9898
#
# Epoch 00025: val_loss did not improve from 0.00669
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0156 - accuracy: 0.9942 - val_loss: 0.0241 - val_accuracy: 0.9926
#
# Epoch 00026: val_loss did not improve from 0.00669
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0267 - val_accuracy: 0.9945
#
# Epoch 00027: val_loss did not improve from 0.00669
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0126 - accuracy: 0.9956 - val_loss: 0.0306 - val_accuracy: 0.9918
#
# Epoch 00028: val_loss did not improve from 0.00669
# Epoch 29/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.0120 - val_accuracy: 0.9969
#
# Epoch 00029: val_loss did not improve from 0.00669
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0106 - accuracy: 0.9951 - val_loss: 0.0096 - val_accuracy: 0.9969
#
# Epoch 00030: val_loss did not improve from 0.00669
# Epoch 31/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.0321 - val_accuracy: 0.9922
#
# Epoch 00031: val_loss did not improve from 0.00669
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9964 - val_loss: 0.0149 - val_accuracy: 0.9965
#
# Epoch 00032: val_loss did not improve from 0.00669
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0241 - val_accuracy: 0.9941
#
# Epoch 00033: val_loss did not improve from 0.00669
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00034: val_loss improved from 0.00669 to 0.00564, saving model to model.h5
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9963 - val_loss: 0.0172 - val_accuracy: 0.9977
#
# Epoch 00035: val_loss did not improve from 0.00564
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0154 - val_accuracy: 0.9980
#
# Epoch 00036: val_loss did not improve from 0.00564
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0254 - val_accuracy: 0.9957
#
# Epoch 00037: val_loss did not improve from 0.00564
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0246 - val_accuracy: 0.9934
#
# Epoch 00038: val_loss did not improve from 0.00564
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.0124 - val_accuracy: 0.9957
#
# Epoch 00039: val_loss did not improve from 0.00564
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.0127 - val_accuracy: 0.9957
#
# Epoch 00040: val_loss did not improve from 0.00564
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.0082 - val_accuracy: 0.9969
#
# Epoch 00041: val_loss did not improve from 0.00564
# Epoch 42/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0157 - val_accuracy: 0.9961
#
# Epoch 00042: val_loss did not improve from 0.00564
# Epoch 43/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00043: val_loss improved from 0.00564 to 0.00408, saving model to model.h5
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9973 - val_loss: 0.0163 - val_accuracy: 0.9965
#
# Epoch 00044: val_loss did not improve from 0.00408
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 0.0182 - val_accuracy: 0.9941
#
# Epoch 00045: val_loss did not improve from 0.00408
# Epoch 46/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0093 - accuracy: 0.9962 - val_loss: 0.0087 - val_accuracy: 0.9969
#
# Epoch 00046: val_loss did not improve from 0.00408
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0073 - val_accuracy: 0.9969
#
# Epoch 00047: val_loss did not improve from 0.00408
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00048: val_loss did not improve from 0.00408
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.0109 - val_accuracy: 0.9973
#
# Epoch 00049: val_loss did not improve from 0.00408
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0059 - accuracy: 0.9974 - val_loss: 0.0205 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00408
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0061 - accuracy: 0.9972 - val_loss: 0.0110 - val_accuracy: 0.9969
#
# Epoch 00051: val_loss did not improve from 0.00408
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0050 - accuracy: 0.9980 - val_loss: 0.0224 - val_accuracy: 0.9945
#
# Epoch 00052: val_loss did not improve from 0.00408
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.0232 - val_accuracy: 0.9961
#
# Epoch 00053: val_loss did not improve from 0.00408
# Epoch 54/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0104 - accuracy: 0.9958 - val_loss: 0.0252 - val_accuracy: 0.9941
#
# Epoch 00054: val_loss did not improve from 0.00408
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0071 - accuracy: 0.9966 - val_loss: 0.0155 - val_accuracy: 0.9969
#
# Epoch 00055: val_loss did not improve from 0.00408
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0187 - val_accuracy: 0.9969
#
# Epoch 00056: val_loss did not improve from 0.00408
# Epoch 57/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9969 - val_loss: 0.0152 - val_accuracy: 0.9953
#
# Epoch 00057: val_loss did not improve from 0.00408
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0064 - accuracy: 0.9971 - val_loss: 0.0423 - val_accuracy: 0.9906
#
# Epoch 00058: val_loss did not improve from 0.00408
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9969 - val_loss: 0.0223 - val_accuracy: 0.9961
#
# Epoch 00059: val_loss did not improve from 0.00408
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0053 - accuracy: 0.9979 - val_loss: 0.0153 - val_accuracy: 0.9973
#
# Epoch 00060: val_loss did not improve from 0.00408
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0052 - accuracy: 0.9976 - val_loss: 0.0113 - val_accuracy: 0.9977
#
# Epoch 00061: val_loss did not improve from 0.00408
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0051 - accuracy: 0.9976 - val_loss: 0.0238 - val_accuracy: 0.9969
#
# Epoch 00062: val_loss did not improve from 0.00408
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0059 - accuracy: 0.9974 - val_loss: 0.0158 - val_accuracy: 0.9957
#
# Epoch 00063: val_loss did not improve from 0.00408
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.0138 - val_accuracy: 0.9965
#
# Epoch 00064: val_loss did not improve from 0.00408
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.0151 - val_accuracy: 0.9977
#
# Epoch 00065: val_loss did not improve from 0.00408
# Epoch 66/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.0109 - val_accuracy: 0.9961
#
# Epoch 00066: val_loss did not improve from 0.00408
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9974 - val_loss: 0.0183 - val_accuracy: 0.9957
#
# Epoch 00067: val_loss did not improve from 0.00408
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9975 - val_loss: 0.0267 - val_accuracy: 0.9949
#
# Epoch 00068: val_loss did not improve from 0.00408
# Epoch 69/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 0.0064 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00408
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 0.0086 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00408
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0209 - val_accuracy: 0.9937
#
# Epoch 00071: val_loss did not improve from 0.00408
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.0100 - val_accuracy: 0.9973
#
# Epoch 00072: val_loss did not improve from 0.00408
# Epoch 73/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0050 - val_accuracy: 0.9973
#
# Epoch 00073: val_loss did not improve from 0.00408
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0237 - val_accuracy: 0.9937
#
# Epoch 00074: val_loss did not improve from 0.00408
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9971 - val_loss: 0.0631 - val_accuracy: 0.9926
#
# Epoch 00075: val_loss did not improve from 0.00408
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0221 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00408
# Epoch 77/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9973 - val_loss: 0.0078 - val_accuracy: 0.9988
#
# Epoch 00077: val_loss did not improve from 0.00408
# Epoch 78/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0051 - accuracy: 0.9974 - val_loss: 0.0080 - val_accuracy: 0.9980
#
# Epoch 00078: val_loss did not improve from 0.00408
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0371 - val_accuracy: 0.9957
#
# Epoch 00079: val_loss did not improve from 0.00408
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0056 - accuracy: 0.9975 - val_loss: 0.0538 - val_accuracy: 0.9914
#
# Epoch 00080: val_loss did not improve from 0.00408
# Epoch 81/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.0366 - val_accuracy: 0.9973
#
# Epoch 00081: val_loss did not improve from 0.00408
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0061 - accuracy: 0.9973 - val_loss: 0.0155 - val_accuracy: 0.9980
#
# Epoch 00082: val_loss did not improve from 0.00408
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0095 - val_accuracy: 0.9961
#
# Epoch 00083: val_loss did not improve from 0.00408
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0258 - val_accuracy: 0.9969
#
# Epoch 00084: val_loss did not improve from 0.00408
# Epoch 85/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0042 - accuracy: 0.9979 - val_loss: 0.0229 - val_accuracy: 0.9957
#
# Epoch 00085: val_loss did not improve from 0.00408
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 0.0146 - val_accuracy: 0.9977
#
# Epoch 00086: val_loss did not improve from 0.00408
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0059 - val_accuracy: 0.9984
#
# Epoch 00087: val_loss did not improve from 0.00408
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.0100 - val_accuracy: 0.9984
#
# Epoch 00088: val_loss did not improve from 0.00408
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0054 - accuracy: 0.9973 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00089: val_loss improved from 0.00408 to 0.00266, saving model to model.h5
# Epoch 90/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0050 - accuracy: 0.9977 - val_loss: 0.0229 - val_accuracy: 0.9941
#
# Epoch 00090: val_loss did not improve from 0.00266
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9972 - val_loss: 0.0264 - val_accuracy: 0.9941
#
# Epoch 00091: val_loss did not improve from 0.00266
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0490 - val_accuracy: 0.9855
#
# Epoch 00092: val_loss did not improve from 0.00266
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.0575 - val_accuracy: 0.9973
#
# Epoch 00093: val_loss did not improve from 0.00266
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9973 - val_loss: 0.0341 - val_accuracy: 0.9969
#
# Epoch 00094: val_loss did not improve from 0.00266
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0145 - val_accuracy: 0.9980
#
# Epoch 00095: val_loss did not improve from 0.00266
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0050 - accuracy: 0.9977 - val_loss: 0.0038 - val_accuracy: 0.9984
#
# Epoch 00096: val_loss did not improve from 0.00266
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.0063 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00266
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0047 - accuracy: 0.9975 - val_loss: 0.0080 - val_accuracy: 0.9973
#
# Epoch 00098: val_loss did not improve from 0.00266
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00266
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0047 - accuracy: 0.9977 - val_loss: 0.0100 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00266
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9980
# Val Score:  [0.009979448281228542, 0.998046875]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 5s 10ms/step - loss: 0.3923 - accuracy: 0.8732 - val_loss: 5.2137 - val_accuracy: 0.4930
#
# Epoch 00001: val_loss did not improve from 0.00266
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1478 - accuracy: 0.9477 - val_loss: 1.7859 - val_accuracy: 0.6828
#
# Epoch 00002: val_loss did not improve from 0.00266
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1051 - accuracy: 0.9626 - val_loss: 0.3146 - val_accuracy: 0.9031
#
# Epoch 00003: val_loss did not improve from 0.00266
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0775 - accuracy: 0.9740 - val_loss: 0.6581 - val_accuracy: 0.8348
#
# Epoch 00004: val_loss did not improve from 0.00266
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0668 - accuracy: 0.9767 - val_loss: 0.1097 - val_accuracy: 0.9617
#
# Epoch 00005: val_loss did not improve from 0.00266
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0626 - accuracy: 0.9801 - val_loss: 0.4939 - val_accuracy: 0.8707
#
# Epoch 00006: val_loss did not improve from 0.00266
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0417 - accuracy: 0.9845 - val_loss: 0.1859 - val_accuracy: 0.9418
#
# Epoch 00007: val_loss did not improve from 0.00266
# Epoch 8/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0428 - accuracy: 0.9867 - val_loss: 0.2737 - val_accuracy: 0.9219
#
# Epoch 00008: val_loss did not improve from 0.00266
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0405 - accuracy: 0.9869 - val_loss: 0.0966 - val_accuracy: 0.9707
#
# Epoch 00009: val_loss did not improve from 0.00266
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0401 - accuracy: 0.9869 - val_loss: 0.1952 - val_accuracy: 0.9488
#
# Epoch 00010: val_loss did not improve from 0.00266
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0319 - accuracy: 0.9896 - val_loss: 0.0718 - val_accuracy: 0.9816
#
# Epoch 00011: val_loss did not improve from 0.00266
# Epoch 12/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0295 - accuracy: 0.9907 - val_loss: 0.3785 - val_accuracy: 0.9160
#
# Epoch 00012: val_loss did not improve from 0.00266
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0332 - accuracy: 0.9897 - val_loss: 0.0602 - val_accuracy: 0.9836
#
# Epoch 00013: val_loss did not improve from 0.00266
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0230 - accuracy: 0.9934 - val_loss: 0.0399 - val_accuracy: 0.9883
#
# Epoch 00014: val_loss did not improve from 0.00266
# Epoch 15/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0266 - accuracy: 0.9926 - val_loss: 0.0176 - val_accuracy: 0.9941
#
# Epoch 00015: val_loss did not improve from 0.00266
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0241 - accuracy: 0.9924 - val_loss: 0.0366 - val_accuracy: 0.9906
#
# Epoch 00016: val_loss did not improve from 0.00266
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0234 - accuracy: 0.9939 - val_loss: 0.0982 - val_accuracy: 0.9715
#
# Epoch 00017: val_loss did not improve from 0.00266
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0219 - accuracy: 0.9935 - val_loss: 0.0142 - val_accuracy: 0.9949
#
# Epoch 00018: val_loss did not improve from 0.00266
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0218 - accuracy: 0.9936 - val_loss: 0.0248 - val_accuracy: 0.9926
#
# Epoch 00019: val_loss did not improve from 0.00266
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0192 - accuracy: 0.9938 - val_loss: 0.0098 - val_accuracy: 0.9949
#
# Epoch 00020: val_loss did not improve from 0.00266
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0212 - accuracy: 0.9932 - val_loss: 0.0137 - val_accuracy: 0.9953
#
# Epoch 00021: val_loss did not improve from 0.00266
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.0116 - val_accuracy: 0.9957
#
# Epoch 00022: val_loss did not improve from 0.00266
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00023: val_loss did not improve from 0.00266
# Epoch 24/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.0181 - val_accuracy: 0.9957
#
# Epoch 00024: val_loss did not improve from 0.00266
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0135 - accuracy: 0.9953 - val_loss: 0.0099 - val_accuracy: 0.9965
#
# Epoch 00025: val_loss did not improve from 0.00266
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0189 - accuracy: 0.9940 - val_loss: 0.4807 - val_accuracy: 0.8969
#
# Epoch 00026: val_loss did not improve from 0.00266
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.0063 - val_accuracy: 0.9980
#
# Epoch 00027: val_loss did not improve from 0.00266
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.0093 - val_accuracy: 0.9961
#
# Epoch 00028: val_loss did not improve from 0.00266
# Epoch 29/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.0039 - val_accuracy: 0.9984
#
# Epoch 00029: val_loss did not improve from 0.00266
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0059 - val_accuracy: 0.9973
#
# Epoch 00030: val_loss did not improve from 0.00266
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00031: val_loss did not improve from 0.00266
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9960 - val_loss: 0.0058 - val_accuracy: 0.9980
#
# Epoch 00032: val_loss did not improve from 0.00266
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0111 - accuracy: 0.9956 - val_loss: 0.0733 - val_accuracy: 0.9871
#
# Epoch 00033: val_loss did not improve from 0.00266
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.0110 - val_accuracy: 0.9969
#
# Epoch 00034: val_loss did not improve from 0.00266
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00035: val_loss did not improve from 0.00266
# Epoch 36/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0098 - accuracy: 0.9961 - val_loss: 0.0036 - val_accuracy: 0.9973
#
# Epoch 00036: val_loss did not improve from 0.00266
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0225 - val_accuracy: 0.9930
#
# Epoch 00037: val_loss did not improve from 0.00266
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.0251 - val_accuracy: 0.9910
#
# Epoch 00038: val_loss did not improve from 0.00266
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0134 - accuracy: 0.9947 - val_loss: 0.0076 - val_accuracy: 0.9957
#
# Epoch 00039: val_loss did not improve from 0.00266
# Epoch 40/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00197
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0190 - accuracy: 0.9945 - val_loss: 0.7691 - val_accuracy: 0.8914
#
# Epoch 00021: val_loss did not improve from 0.00197
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0167 - accuracy: 0.9947 - val_loss: 0.1852 - val_accuracy: 0.9578
#
# Epoch 00022: val_loss did not improve from 0.00197
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0197 - accuracy: 0.9941 - val_loss: 0.2147 - val_accuracy: 0.9637
#
# Epoch 00023: val_loss did not improve from 0.00197
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 0.1687 - val_accuracy: 0.9809
#
# Epoch 00024: val_loss did not improve from 0.00197
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.1827 - val_accuracy: 0.9711
#
# Epoch 00025: val_loss did not improve from 0.00197
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.0896 - val_accuracy: 0.9770
#
# Epoch 00026: val_loss did not improve from 0.00197
# Epoch 27/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.0239 - val_accuracy: 0.9922
#
# Epoch 00027: val_loss did not improve from 0.00197
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0115 - accuracy: 0.9972 - val_loss: 0.0219 - val_accuracy: 0.9937
#
# Epoch 00028: val_loss did not improve from 0.00197
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.0810 - val_accuracy: 0.9805
#
# Epoch 00029: val_loss did not improve from 0.00197
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.0895 - val_accuracy: 0.9758
#
# Epoch 00030: val_loss did not improve from 0.00197
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0210 - val_accuracy: 0.9934
#
# Epoch 00031: val_loss did not improve from 0.00197
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.0477 - val_accuracy: 0.9867
#
# Epoch 00032: val_loss did not improve from 0.00197
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.3200 - val_accuracy: 0.9301
#
# Epoch 00033: val_loss did not improve from 0.00197
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0417 - val_accuracy: 0.9902
#
# Epoch 00034: val_loss did not improve from 0.00197
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9968 - val_loss: 0.0999 - val_accuracy: 0.9773
#
# Epoch 00035: val_loss did not improve from 0.00197
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0708 - val_accuracy: 0.9832
#
# Epoch 00036: val_loss did not improve from 0.00197
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.0407 - val_accuracy: 0.9883
#
# Epoch 00037: val_loss did not improve from 0.00197
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0462 - val_accuracy: 0.9875
#
# Epoch 00038: val_loss did not improve from 0.00197
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.3158 - val_accuracy: 0.9348
#
# Epoch 00039: val_loss did not improve from 0.00197
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.0208 - val_accuracy: 0.9930
#
# Epoch 00040: val_loss did not improve from 0.00197
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0191 - val_accuracy: 0.9945
#
# Epoch 00041: val_loss did not improve from 0.00197
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.0321 - val_accuracy: 0.9902
#
# Epoch 00042: val_loss did not improve from 0.00197
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0099 - accuracy: 0.9961 - val_loss: 0.0593 - val_accuracy: 0.9820
#
# Epoch 00043: val_loss did not improve from 0.00197
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0234 - val_accuracy: 0.9937
#
# Epoch 00044: val_loss did not improve from 0.00197
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.0578 - val_accuracy: 0.9828
#
# Epoch 00045: val_loss did not improve from 0.00197
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.0224 - val_accuracy: 0.9945
#
# Epoch 00046: val_loss did not improve from 0.00197
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0280 - val_accuracy: 0.9910
#
# Epoch 00047: val_loss did not improve from 0.00197
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0103 - val_accuracy: 0.9961
#
# Epoch 00048: val_loss did not improve from 0.00197
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0116 - val_accuracy: 0.9969
#
# Epoch 00049: val_loss did not improve from 0.00197
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.0183 - val_accuracy: 0.9957
#
# Epoch 00050: val_loss did not improve from 0.00197
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.0178 - val_accuracy: 0.9961
#
# Epoch 00051: val_loss did not improve from 0.00197
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0137 - val_accuracy: 0.9961
#
# Epoch 00052: val_loss did not improve from 0.00197
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0080 - accuracy: 0.9959 - val_loss: 0.0251 - val_accuracy: 0.9930
#
# Epoch 00053: val_loss did not improve from 0.00197
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0151 - val_accuracy: 0.9953
#
# Epoch 00054: val_loss did not improve from 0.00197
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0112 - accuracy: 0.9956 - val_loss: 0.0659 - val_accuracy: 0.9801
#
# Epoch 00055: val_loss did not improve from 0.00197
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.0518 - val_accuracy: 0.9902
#
# Epoch 00056: val_loss did not improve from 0.00197
# Epoch 57/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.0221 - val_accuracy: 0.9957
#
# Epoch 00057: val_loss did not improve from 0.00197
# Epoch 58/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9976 - val_loss: 0.0076 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00197
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0542 - val_accuracy: 0.9848
#
# Epoch 00059: val_loss did not improve from 0.00197
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0048 - accuracy: 0.9980 - val_loss: 0.0192 - val_accuracy: 0.9961
#
# Epoch 00060: val_loss did not improve from 0.00197
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0049 - accuracy: 0.9977 - val_loss: 0.0181 - val_accuracy: 0.9965
#
# Epoch 00061: val_loss did not improve from 0.00197
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9973 - val_loss: 0.0197 - val_accuracy: 0.9949
#
# Epoch 00062: val_loss did not improve from 0.00197
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 0.0441 - val_accuracy: 0.9918
#
# Epoch 00063: val_loss did not improve from 0.00197
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0165 - val_accuracy: 0.9965
#
# Epoch 00064: val_loss did not improve from 0.00197
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0081 - accuracy: 0.9966 - val_loss: 0.0383 - val_accuracy: 0.9883
#
# Epoch 00065: val_loss did not improve from 0.00197
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0143 - val_accuracy: 0.9953
#
# Epoch 00066: val_loss did not improve from 0.00197
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0046 - accuracy: 0.9980 - val_loss: 0.0192 - val_accuracy: 0.9965
#
# Epoch 00067: val_loss did not improve from 0.00197
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.0324 - val_accuracy: 0.9973
#
# Epoch 00068: val_loss did not improve from 0.00197
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0059 - accuracy: 0.9972 - val_loss: 0.0060 - val_accuracy: 0.9973
#
# Epoch 00069: val_loss did not improve from 0.00197
# Epoch 70/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0073 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00197
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.0045 - val_accuracy: 0.9984
#
# Epoch 00071: val_loss did not improve from 0.00197
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.0095 - val_accuracy: 0.9961
#
# Epoch 00072: val_loss did not improve from 0.00197
# Epoch 73/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.0090 - val_accuracy: 0.9977
#
# Epoch 00073: val_loss did not improve from 0.00197
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0105 - accuracy: 0.9959 - val_loss: 0.0153 - val_accuracy: 0.9969
#
# Epoch 00074: val_loss did not improve from 0.00197
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00075: val_loss did not improve from 0.00197
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0040 - accuracy: 0.9979 - val_loss: 0.0166 - val_accuracy: 0.9953
#
# Epoch 00076: val_loss did not improve from 0.00197
# Epoch 77/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9969 - val_loss: 0.0126 - val_accuracy: 0.9973
#
# Epoch 00077: val_loss did not improve from 0.00197
# Epoch 78/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0074 - accuracy: 0.9967 - val_loss: 0.0318 - val_accuracy: 0.9914
#
# Epoch 00078: val_loss did not improve from 0.00197
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0101 - accuracy: 0.9958 - val_loss: 0.0122 - val_accuracy: 0.9965
#
# Epoch 00079: val_loss did not improve from 0.00197
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.0193 - val_accuracy: 0.9969
#
# Epoch 00080: val_loss did not improve from 0.00197
# Epoch 81/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0050 - accuracy: 0.9977 - val_loss: 0.0583 - val_accuracy: 0.9859
#
# Epoch 00081: val_loss did not improve from 0.00197
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.0169 - val_accuracy: 0.9953
#
# Epoch 00082: val_loss did not improve from 0.00197
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0048 - accuracy: 0.9980 - val_loss: 0.0151 - val_accuracy: 0.9961
#
# Epoch 00083: val_loss did not improve from 0.00197
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.0202 - val_accuracy: 0.9965
#
# Epoch 00084: val_loss did not improve from 0.00197
# Epoch 85/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.0146 - val_accuracy: 0.9961
#
# Epoch 00085: val_loss did not improve from 0.00197
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.0063 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00197
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0049 - accuracy: 0.9977 - val_loss: 0.0401 - val_accuracy: 0.9902
#
# Epoch 00087: val_loss did not improve from 0.00197
# Epoch 88/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.0084 - val_accuracy: 0.9977
#
# Epoch 00088: val_loss did not improve from 0.00197
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0054 - accuracy: 0.9973 - val_loss: 0.0159 - val_accuracy: 0.9961
#
# Epoch 00089: val_loss did not improve from 0.00197
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0037 - accuracy: 0.9981 - val_loss: 0.0113 - val_accuracy: 0.9965
#
# Epoch 00090: val_loss did not improve from 0.00197
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0043 - accuracy: 0.9981 - val_loss: 0.0277 - val_accuracy: 0.9934
#
# Epoch 00091: val_loss did not improve from 0.00197
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9972 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00092: val_loss did not improve from 0.00197
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0049 - accuracy: 0.9977 - val_loss: 0.0477 - val_accuracy: 0.9926
#
# Epoch 00093: val_loss did not improve from 0.00197
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0039 - accuracy: 0.9982 - val_loss: 0.0105 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00197
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0106 - val_accuracy: 0.9969
#
# Epoch 00095: val_loss did not improve from 0.00197
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9966 - val_loss: 0.0094 - val_accuracy: 0.9977
#
# Epoch 00096: val_loss did not improve from 0.00197
# Epoch 97/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0053 - accuracy: 0.9979 - val_loss: 0.0201 - val_accuracy: 0.9953
#
# Epoch 00097: val_loss did not improve from 0.00197
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0124 - val_accuracy: 0.9969
#
# Epoch 00098: val_loss did not improve from 0.00197
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00197
# Epoch 100/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.0074 - val_accuracy: 0.9969
#
# Epoch 00100: val_loss did not improve from 0.00197
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9969
# Val Score:  [0.007382119540125132, 0.996874988079071]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       1.00      1.00      1.00       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      1.00      1.00       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 0.9981
# Test Accuracy: 99.81250166893005

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
