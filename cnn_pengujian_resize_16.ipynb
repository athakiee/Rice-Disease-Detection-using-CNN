# %% [raw]
# ## RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **RESIZE 16 -- USING ADAM AND BEST RESULT OF HIDDEN LAYER(4) AND 0.001 LEARNING RATE, 50 EPOCHS**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((16, 16))
image_size = 0
directory_root = "../input/riceleaf"
width=16
height=16
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_121 (Conv2D)          (None, 16, 16, 16)        448
# _________________________________________________________________
# activation_180 (Activation)  (None, 16, 16, 16)        0
# _________________________________________________________________
# batch_normalization_150 (Bat (None, 16, 16, 16)        64
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 5, 5, 16)          0
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 5, 5, 32)          4640
# _________________________________________________________________
# activation_181 (Activation)  (None, 5, 5, 32)          0
# _________________________________________________________________
# batch_normalization_151 (Bat (None, 5, 5, 32)          128
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 5, 5, 64)          18496
# _________________________________________________________________
# activation_182 (Activation)  (None, 5, 5, 64)          0
# _________________________________________________________________
# batch_normalization_152 (Bat (None, 5, 5, 64)          256
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 2, 2, 128)         73856
# _________________________________________________________________
# activation_183 (Activation)  (None, 2, 2, 128)         0
# _________________________________________________________________
# batch_normalization_153 (Bat (None, 2, 2, 128)         512
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# activation_184 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_154 (Bat (None, 1024)              4096
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_61 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_185 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 631,908
# Trainable params: 629,380
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/50
# 320/320 [==============================] - 3s 6ms/step - loss: 0.7865 - accuracy: 0.7287 - val_loss: 0.5657 - val_accuracy: 0.7816
#
# Epoch 00001: val_loss improved from inf to 0.56572, saving model to model.h5
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3430 - accuracy: 0.8658 - val_loss: 0.2791 - val_accuracy: 0.8734
#
# Epoch 00002: val_loss improved from 0.56572 to 0.27906, saving model to model.h5
# Epoch 3/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2475 - accuracy: 0.9058 - val_loss: 0.2016 - val_accuracy: 0.9105
#
# Epoch 00003: val_loss improved from 0.27906 to 0.20160, saving model to model.h5
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2062 - accuracy: 0.9225 - val_loss: 0.1215 - val_accuracy: 0.9480
#
# Epoch 00004: val_loss improved from 0.20160 to 0.12145, saving model to model.h5
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1739 - accuracy: 0.9334 - val_loss: 0.0617 - val_accuracy: 0.9723
#
# Epoch 00005: val_loss improved from 0.12145 to 0.06172, saving model to model.h5
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1549 - accuracy: 0.9431 - val_loss: 0.2044 - val_accuracy: 0.9281
#
# Epoch 00006: val_loss did not improve from 0.06172
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1306 - accuracy: 0.9521 - val_loss: 0.6531 - val_accuracy: 0.8387
#
# Epoch 00007: val_loss did not improve from 0.06172
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1198 - accuracy: 0.9578 - val_loss: 0.2124 - val_accuracy: 0.9297
#
# Epoch 00008: val_loss did not improve from 0.06172
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1277 - accuracy: 0.9558 - val_loss: 0.2391 - val_accuracy: 0.9156
#
# Epoch 00009: val_loss did not improve from 0.06172
# Epoch 10/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1093 - accuracy: 0.9590 - val_loss: 0.1354 - val_accuracy: 0.9563
#
# Epoch 00010: val_loss did not improve from 0.06172
# Epoch 11/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1056 - accuracy: 0.9612 - val_loss: 0.1574 - val_accuracy: 0.9391
#
# Epoch 00011: val_loss did not improve from 0.06172
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0946 - accuracy: 0.9657 - val_loss: 0.1298 - val_accuracy: 0.9438
#
# Epoch 00012: val_loss did not improve from 0.06172
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0743 - accuracy: 0.9724 - val_loss: 0.1596 - val_accuracy: 0.9480
#
# Epoch 00013: val_loss did not improve from 0.06172
# Epoch 14/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0918 - accuracy: 0.9694 - val_loss: 0.0783 - val_accuracy: 0.9699
#
# Epoch 00014: val_loss did not improve from 0.06172
# Epoch 15/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0780 - accuracy: 0.9726 - val_loss: 0.4540 - val_accuracy: 0.8535
#
# Epoch 00015: val_loss did not improve from 0.06172
# Epoch 16/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0713 - accuracy: 0.9736 - val_loss: 0.1893 - val_accuracy: 0.9328
#
# Epoch 00016: val_loss did not improve from 0.06172
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0718 - accuracy: 0.9747 - val_loss: 0.2954 - val_accuracy: 0.9164
#
# Epoch 00017: val_loss did not improve from 0.06172
# Epoch 18/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0669 - accuracy: 0.9768 - val_loss: 0.3650 - val_accuracy: 0.8863
#
# Epoch 00018: val_loss did not improve from 0.06172
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0684 - accuracy: 0.9763 - val_loss: 0.0284 - val_accuracy: 0.9902
#
# Epoch 00019: val_loss improved from 0.06172 to 0.02835, saving model to model.h5
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0519 - accuracy: 0.9817 - val_loss: 0.2438 - val_accuracy: 0.9305
#
# Epoch 00020: val_loss did not improve from 0.02835
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0588 - accuracy: 0.9795 - val_loss: 0.3478 - val_accuracy: 0.9098
#
# Epoch 00021: val_loss did not improve from 0.02835
# Epoch 22/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0604 - accuracy: 0.9797 - val_loss: 0.0177 - val_accuracy: 0.9930
#
# Epoch 00022: val_loss improved from 0.02835 to 0.01768, saving model to model.h5
# Epoch 23/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0575 - accuracy: 0.9800 - val_loss: 0.5066 - val_accuracy: 0.8551
#
# Epoch 00023: val_loss did not improve from 0.01768
# Epoch 24/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0518 - accuracy: 0.9823 - val_loss: 0.0533 - val_accuracy: 0.9793
#
# Epoch 00024: val_loss did not improve from 0.01768
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0487 - accuracy: 0.9814 - val_loss: 0.0248 - val_accuracy: 0.9922
#
# Epoch 00025: val_loss did not improve from 0.01768
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0532 - accuracy: 0.9817 - val_loss: 0.3624 - val_accuracy: 0.8980
#
# Epoch 00026: val_loss did not improve from 0.01768
# Epoch 27/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0535 - accuracy: 0.9812 - val_loss: 0.1402 - val_accuracy: 0.9539
#
# Epoch 00027: val_loss did not improve from 0.01768
# Epoch 28/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0533 - accuracy: 0.9812 - val_loss: 0.0477 - val_accuracy: 0.9832
#
# Epoch 00028: val_loss did not improve from 0.01768
# Epoch 29/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0463 - accuracy: 0.9842 - val_loss: 0.0285 - val_accuracy: 0.9895
#
# Epoch 00029: val_loss did not improve from 0.01768
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0487 - accuracy: 0.9833 - val_loss: 0.0363 - val_accuracy: 0.9871
#
# Epoch 00030: val_loss did not improve from 0.01768
# Epoch 31/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0505 - accuracy: 0.9827 - val_loss: 0.0444 - val_accuracy: 0.9859
#
# Epoch 00031: val_loss did not improve from 0.01768
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0315 - accuracy: 0.9890 - val_loss: 0.0219 - val_accuracy: 0.9906
#
# Epoch 00032: val_loss did not improve from 0.01768
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0465 - accuracy: 0.9839 - val_loss: 0.0095 - val_accuracy: 0.9969
#
# Epoch 00033: val_loss improved from 0.01768 to 0.00954, saving model to model.h5
# Epoch 34/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0385 - accuracy: 0.9869 - val_loss: 0.0713 - val_accuracy: 0.9738
#
# Epoch 00034: val_loss did not improve from 0.00954
# Epoch 35/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0429 - accuracy: 0.9843 - val_loss: 0.0613 - val_accuracy: 0.9797
#
# Epoch 00035: val_loss did not improve from 0.00954
# Epoch 36/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0461 - accuracy: 0.9840 - val_loss: 0.0143 - val_accuracy: 0.9953
#
# Epoch 00036: val_loss did not improve from 0.00954
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0395 - accuracy: 0.9879 - val_loss: 0.0152 - val_accuracy: 0.9957
#
# Epoch 00037: val_loss did not improve from 0.00954
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0359 - accuracy: 0.9876 - val_loss: 0.0578 - val_accuracy: 0.9766
#
# Epoch 00038: val_loss did not improve from 0.00954
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0285 - accuracy: 0.9890 - val_loss: 0.0137 - val_accuracy: 0.9953
#
# Epoch 00039: val_loss did not improve from 0.00954
# Epoch 40/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0374 - accuracy: 0.9872 - val_loss: 0.0122 - val_accuracy: 0.9949
#
# Epoch 00040: val_loss did not improve from 0.00954
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0362 - accuracy: 0.9884 - val_loss: 0.0344 - val_accuracy: 0.9906
#
# Epoch 00041: val_loss did not improve from 0.00954
# Epoch 42/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0298 - accuracy: 0.9900 - val_loss: 0.0317 - val_accuracy: 0.9918
#
# Epoch 00042: val_loss did not improve from 0.00954
# Epoch 43/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0416 - accuracy: 0.9862 - val_loss: 0.0569 - val_accuracy: 0.9816
#
# Epoch 00043: val_loss did not improve from 0.00954
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0309 - accuracy: 0.9893 - val_loss: 0.0099 - val_accuracy: 0.9961
#
# Epoch 00044: val_loss did not improve from 0.00954
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0222 - accuracy: 0.9915 - val_loss: 0.0167 - val_accuracy: 0.9937
#
# Epoch 00045: val_loss did not improve from 0.00954
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0401 - accuracy: 0.9865 - val_loss: 0.0782 - val_accuracy: 0.9680
#
# Epoch 00046: val_loss did not improve from 0.00954
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0299 - accuracy: 0.9896 - val_loss: 0.0832 - val_accuracy: 0.9758
#
# Epoch 00047: val_loss did not improve from 0.00954
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0385 - accuracy: 0.9877 - val_loss: 0.0325 - val_accuracy: 0.9871
#
# Epoch 00048: val_loss did not improve from 0.00954
# Epoch 49/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0270 - accuracy: 0.9900 - val_loss: 0.0158 - val_accuracy: 0.9945
#
# Epoch 00049: val_loss did not improve from 0.00954
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0363 - accuracy: 0.9870 - val_loss: 0.3114 - val_accuracy: 0.9254
#
# Epoch 00050: val_loss did not improve from 0.00954
# 80/80 [==============================] - 0s 2ms/step - loss: 0.3114 - accuracy: 0.9254
# Val Score:  [0.31138187646865845, 0.9253906011581421]
# Training on Fold:  2
# Epoch 1/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.7014 - accuracy: 0.7591 - val_loss: 0.9908 - val_accuracy: 0.5875
#
# Epoch 00001: val_loss did not improve from 0.00954
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3117 - accuracy: 0.8829 - val_loss: 0.1441 - val_accuracy: 0.9527
#
# Epoch 00002: val_loss did not improve from 0.00954
# Epoch 3/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2304 - accuracy: 0.9131 - val_loss: 0.1028 - val_accuracy: 0.9629
#
# Epoch 00003: val_loss did not improve from 0.00954
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1804 - accuracy: 0.9323 - val_loss: 0.2680 - val_accuracy: 0.9051
#
# Epoch 00004: val_loss did not improve from 0.00954
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1525 - accuracy: 0.9416 - val_loss: 0.0515 - val_accuracy: 0.9785
#
# Epoch 00005: val_loss did not improve from 0.00954
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1329 - accuracy: 0.9528 - val_loss: 0.0518 - val_accuracy: 0.9824
#
# Epoch 00006: val_loss did not improve from 0.00954
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1390 - accuracy: 0.9510 - val_loss: 0.1056 - val_accuracy: 0.9664
#
# Epoch 00007: val_loss did not improve from 0.00954
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1231 - accuracy: 0.9554 - val_loss: 0.0481 - val_accuracy: 0.9840
#
# Epoch 00008: val_loss did not improve from 0.00954
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1028 - accuracy: 0.9626 - val_loss: 0.6370 - val_accuracy: 0.8313
#
# Epoch 00009: val_loss did not improve from 0.00954
# Epoch 10/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1039 - accuracy: 0.9638 - val_loss: 0.2403 - val_accuracy: 0.9242
#
# Epoch 00010: val_loss did not improve from 0.00954
# Epoch 11/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0970 - accuracy: 0.9646 - val_loss: 0.0394 - val_accuracy: 0.9820
#
# Epoch 00011: val_loss did not improve from 0.00954
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0853 - accuracy: 0.9703 - val_loss: 0.2792 - val_accuracy: 0.9152
#
# Epoch 00012: val_loss did not improve from 0.00954
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0789 - accuracy: 0.9719 - val_loss: 0.0863 - val_accuracy: 0.9738
#
# Epoch 00013: val_loss did not improve from 0.00954
# Epoch 14/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0774 - accuracy: 0.9731 - val_loss: 0.0547 - val_accuracy: 0.9820
#
# Epoch 00014: val_loss did not improve from 0.00954
# Epoch 15/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0656 - accuracy: 0.9771 - val_loss: 0.0257 - val_accuracy: 0.9930
#
# Epoch 00015: val_loss did not improve from 0.00954
# Epoch 16/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0731 - accuracy: 0.9730 - val_loss: 0.0398 - val_accuracy: 0.9914
#
# Epoch 00016: val_loss did not improve from 0.00954
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0630 - accuracy: 0.9782 - val_loss: 0.0214 - val_accuracy: 0.9926
#
# Epoch 00017: val_loss did not improve from 0.00954
# Epoch 18/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0669 - accuracy: 0.9774 - val_loss: 0.0241 - val_accuracy: 0.9914
#
# Epoch 00018: val_loss did not improve from 0.00954
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0500 - accuracy: 0.9821 - val_loss: 0.0677 - val_accuracy: 0.9781
#
# Epoch 00019: val_loss did not improve from 0.00954
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0611 - accuracy: 0.9803 - val_loss: 0.0918 - val_accuracy: 0.9719
#
# Epoch 00020: val_loss did not improve from 0.00954
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0546 - accuracy: 0.9825 - val_loss: 0.0154 - val_accuracy: 0.9937
#
# Epoch 00021: val_loss did not improve from 0.00954
# Epoch 22/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0530 - accuracy: 0.9825 - val_loss: 0.0445 - val_accuracy: 0.9828
#
# Epoch 00022: val_loss did not improve from 0.00954
# Epoch 23/50
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0462 - accuracy: 0.9838 - val_loss: 0.0231 - val_accuracy: 0.9918
#
# Epoch 00023: val_loss did not improve from 0.00954
# Epoch 24/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0512 - accuracy: 0.9834 - val_loss: 0.0590 - val_accuracy: 0.9793
#
# Epoch 00024: val_loss did not improve from 0.00954
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0496 - accuracy: 0.9834 - val_loss: 0.0180 - val_accuracy: 0.9926
#
# Epoch 00025: val_loss did not improve from 0.00954
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0590 - accuracy: 0.9796 - val_loss: 0.0358 - val_accuracy: 0.9898
#
# Epoch 00026: val_loss did not improve from 0.00954
# Epoch 27/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0496 - accuracy: 0.9831 - val_loss: 0.0281 - val_accuracy: 0.9906
#
# Epoch 00027: val_loss did not improve from 0.00954
# Epoch 28/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0419 - accuracy: 0.9871 - val_loss: 0.1009 - val_accuracy: 0.9625
#
# Epoch 00028: val_loss did not improve from 0.00954
# Epoch 29/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0401 - accuracy: 0.9862 - val_loss: 0.0275 - val_accuracy: 0.9898
#
# Epoch 00029: val_loss did not improve from 0.00954
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0451 - accuracy: 0.9849 - val_loss: 0.0750 - val_accuracy: 0.9738
#
# Epoch 00030: val_loss did not improve from 0.00954
# Epoch 31/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0556 - accuracy: 0.9815 - val_loss: 0.0180 - val_accuracy: 0.9926
#
# Epoch 00031: val_loss did not improve from 0.00954
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0338 - accuracy: 0.9877 - val_loss: 0.0272 - val_accuracy: 0.9895
#
# Epoch 00032: val_loss did not improve from 0.00954
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0315 - accuracy: 0.9887 - val_loss: 0.0162 - val_accuracy: 0.9934
#
# Epoch 00033: val_loss did not improve from 0.00954
# Epoch 34/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0284 - accuracy: 0.9890 - val_loss: 0.0124 - val_accuracy: 0.9945
#
# Epoch 00034: val_loss did not improve from 0.00954
# Epoch 35/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0292 - accuracy: 0.9898 - val_loss: 0.1844 - val_accuracy: 0.9836
#
# Epoch 00035: val_loss did not improve from 0.00954
# Epoch 36/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0379 - accuracy: 0.9871 - val_loss: 0.0462 - val_accuracy: 0.9875
#
# Epoch 00036: val_loss did not improve from 0.00954
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0317 - accuracy: 0.9890 - val_loss: 0.0073 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss improved from 0.00954 to 0.00730, saving model to model.h5
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0416 - accuracy: 0.9851 - val_loss: 0.0098 - val_accuracy: 0.9961
#
# Epoch 00038: val_loss did not improve from 0.00730
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0317 - accuracy: 0.9890 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss improved from 0.00730 to 0.00488, saving model to model.h5
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0384 - accuracy: 0.9873 - val_loss: 0.0418 - val_accuracy: 0.9844
#
# Epoch 00040: val_loss did not improve from 0.00488
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0322 - accuracy: 0.9891 - val_loss: 0.0666 - val_accuracy: 0.9789
#
# Epoch 00041: val_loss did not improve from 0.00488
# Epoch 42/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0301 - accuracy: 0.9888 - val_loss: 0.0120 - val_accuracy: 0.9957
#
# Epoch 00042: val_loss did not improve from 0.00488
# Epoch 43/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0296 - accuracy: 0.9895 - val_loss: 0.0068 - val_accuracy: 0.9973
#
# Epoch 00043: val_loss did not improve from 0.00488
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0268 - accuracy: 0.9921 - val_loss: 0.0057 - val_accuracy: 0.9973
#
# Epoch 00044: val_loss did not improve from 0.00488
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0267 - accuracy: 0.9901 - val_loss: 0.0352 - val_accuracy: 0.9895
#
# Epoch 00045: val_loss did not improve from 0.00488
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0374 - accuracy: 0.9861 - val_loss: 0.0304 - val_accuracy: 0.9891
#
# Epoch 00046: val_loss did not improve from 0.00488
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0246 - accuracy: 0.9907 - val_loss: 0.0108 - val_accuracy: 0.9953
#
# Epoch 00047: val_loss did not improve from 0.00488
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0300 - accuracy: 0.9899 - val_loss: 0.0203 - val_accuracy: 0.9930
#
# Epoch 00048: val_loss did not improve from 0.00488
# Epoch 49/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0318 - accuracy: 0.9895 - val_loss: 0.0131 - val_accuracy: 0.9957
#
# Epoch 00049: val_loss did not improve from 0.00488
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0277 - accuracy: 0.9900 - val_loss: 0.0047 - val_accuracy: 0.9973
#
# Epoch 00050: val_loss improved from 0.00488 to 0.00467, saving model to model.h5
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 0.9973
# Val Score:  [0.00466760341078043, 0.997265636920929]
# Training on Fold:  3
# Epoch 1/50
# 320/320 [==============================] - 3s 6ms/step - loss: 0.6608 - accuracy: 0.7606 - val_loss: 1.4145 - val_accuracy: 0.5406
#
# Epoch 00001: val_loss did not improve from 0.00467
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2994 - accuracy: 0.8846 - val_loss: 0.4770 - val_accuracy: 0.8371
#
# Epoch 00002: val_loss did not improve from 0.00467
# Epoch 3/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2248 - accuracy: 0.9149 - val_loss: 0.0961 - val_accuracy: 0.9641
#
# Epoch 00003: val_loss did not improve from 0.00467
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1872 - accuracy: 0.9261 - val_loss: 0.1096 - val_accuracy: 0.9547
#
# Epoch 00004: val_loss did not improve from 0.00467
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1590 - accuracy: 0.9412 - val_loss: 0.0845 - val_accuracy: 0.9688
#
# Epoch 00005: val_loss did not improve from 0.00467
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1516 - accuracy: 0.9454 - val_loss: 0.0861 - val_accuracy: 0.9684
#
# Epoch 00006: val_loss did not improve from 0.00467
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1241 - accuracy: 0.9529 - val_loss: 0.0688 - val_accuracy: 0.9727
#
# Epoch 00007: val_loss did not improve from 0.00467
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1253 - accuracy: 0.9561 - val_loss: 0.0456 - val_accuracy: 0.9812
#
# Epoch 00008: val_loss did not improve from 0.00467
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1116 - accuracy: 0.9593 - val_loss: 0.0410 - val_accuracy: 0.9852
#
# Epoch 00009: val_loss did not improve from 0.00467
# Epoch 10/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0916 - accuracy: 0.9672 - val_loss: 0.0856 - val_accuracy: 0.9641
#
# Epoch 00010: val_loss did not improve from 0.00467
# Epoch 11/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0879 - accuracy: 0.9678 - val_loss: 0.0382 - val_accuracy: 0.9871
#
# Epoch 00011: val_loss did not improve from 0.00467
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0880 - accuracy: 0.9669 - val_loss: 0.0319 - val_accuracy: 0.9918
#
# Epoch 00012: val_loss did not improve from 0.00467
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0739 - accuracy: 0.9734 - val_loss: 0.0366 - val_accuracy: 0.9836
#
# Epoch 00013: val_loss did not improve from 0.00467
# Epoch 14/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0702 - accuracy: 0.9730 - val_loss: 0.0495 - val_accuracy: 0.9793
#
# Epoch 00014: val_loss did not improve from 0.00467
# Epoch 15/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0774 - accuracy: 0.9734 - val_loss: 0.0342 - val_accuracy: 0.9836
#
# Epoch 00015: val_loss did not improve from 0.00467
# Epoch 16/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0698 - accuracy: 0.9732 - val_loss: 0.0480 - val_accuracy: 0.9820
#
# Epoch 00016: val_loss did not improve from 0.00467
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0700 - accuracy: 0.9740 - val_loss: 0.0353 - val_accuracy: 0.9863
#
# Epoch 00017: val_loss did not improve from 0.00467
# Epoch 18/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0651 - accuracy: 0.9775 - val_loss: 0.0812 - val_accuracy: 0.9711
#
# Epoch 00018: val_loss did not improve from 0.00467
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0664 - accuracy: 0.9753 - val_loss: 0.0216 - val_accuracy: 0.9902
#
# Epoch 00019: val_loss did not improve from 0.00467
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0557 - accuracy: 0.9802 - val_loss: 0.0167 - val_accuracy: 0.9937
#
# Epoch 00020: val_loss did not improve from 0.00467
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0597 - accuracy: 0.9792 - val_loss: 0.0321 - val_accuracy: 0.9895
#
# Epoch 00021: val_loss did not improve from 0.00467
# Epoch 22/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0446 - accuracy: 0.9844 - val_loss: 0.0154 - val_accuracy: 0.9945
#
# Epoch 00022: val_loss did not improve from 0.00467
# Epoch 23/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0505 - accuracy: 0.9815 - val_loss: 0.0276 - val_accuracy: 0.9887
#
# Epoch 00023: val_loss did not improve from 0.00467
# Epoch 24/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0529 - accuracy: 0.9802 - val_loss: 0.1324 - val_accuracy: 0.9523
#
# Epoch 00024: val_loss did not improve from 0.00467
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0533 - accuracy: 0.9819 - val_loss: 0.0335 - val_accuracy: 0.9871
#
# Epoch 00025: val_loss did not improve from 0.00467
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0484 - accuracy: 0.9835 - val_loss: 0.0144 - val_accuracy: 0.9957
#
# Epoch 00026: val_loss did not improve from 0.00467
# Epoch 27/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0398 - accuracy: 0.9859 - val_loss: 0.0170 - val_accuracy: 0.9937
#
# Epoch 00027: val_loss did not improve from 0.00467
# Epoch 28/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0458 - accuracy: 0.9836 - val_loss: 0.0118 - val_accuracy: 0.9945
#
# Epoch 00028: val_loss did not improve from 0.00467
# Epoch 29/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0447 - accuracy: 0.9838 - val_loss: 0.1201 - val_accuracy: 0.9625
#
# Epoch 00029: val_loss did not improve from 0.00467
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0495 - accuracy: 0.9842 - val_loss: 0.0266 - val_accuracy: 0.9902
#
# Epoch 00030: val_loss did not improve from 0.00467
# Epoch 31/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0414 - accuracy: 0.9857 - val_loss: 0.0361 - val_accuracy: 0.9863
#
# Epoch 00031: val_loss did not improve from 0.00467
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0391 - accuracy: 0.9871 - val_loss: 0.0210 - val_accuracy: 0.9922
#
# Epoch 00032: val_loss did not improve from 0.00467
# Epoch 33/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0385 - accuracy: 0.9871 - val_loss: 0.0117 - val_accuracy: 0.9949
#
# Epoch 00033: val_loss did not improve from 0.00467
# Epoch 34/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0421 - accuracy: 0.9853 - val_loss: 0.0156 - val_accuracy: 0.9941
#
# Epoch 00034: val_loss did not improve from 0.00467
# Epoch 35/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0354 - accuracy: 0.9865 - val_loss: 0.0312 - val_accuracy: 0.9898
#
# Epoch 00035: val_loss did not improve from 0.00467
# Epoch 36/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0344 - accuracy: 0.9879 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00036: val_loss improved from 0.00467 to 0.00411, saving model to model.h5
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0361 - accuracy: 0.9872 - val_loss: 0.0397 - val_accuracy: 0.9859
#
# Epoch 00037: val_loss did not improve from 0.00411
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0368 - accuracy: 0.9869 - val_loss: 0.0809 - val_accuracy: 0.9770
#
# Epoch 00038: val_loss did not improve from 0.00411
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0395 - accuracy: 0.9852 - val_loss: 0.0165 - val_accuracy: 0.9953
#
# Epoch 00039: val_loss did not improve from 0.00411
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0298 - accuracy: 0.9881 - val_loss: 0.0110 - val_accuracy: 0.9969
#
# Epoch 00040: val_loss did not improve from 0.00411
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0398 - accuracy: 0.9867 - val_loss: 0.0103 - val_accuracy: 0.9953
#
# Epoch 00041: val_loss did not improve from 0.00411
# Epoch 42/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0345 - accuracy: 0.9879 - val_loss: 0.0061 - val_accuracy: 0.9973
#
# Epoch 00042: val_loss did not improve from 0.00411
# Epoch 43/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0263 - accuracy: 0.9896 - val_loss: 0.0167 - val_accuracy: 0.9941
#
# Epoch 00043: val_loss did not improve from 0.00411
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0319 - accuracy: 0.9904 - val_loss: 0.0125 - val_accuracy: 0.9961
#
# Epoch 00044: val_loss did not improve from 0.00411
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0372 - accuracy: 0.9865 - val_loss: 0.0068 - val_accuracy: 0.9973
#
# Epoch 00045: val_loss did not improve from 0.00411
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0301 - accuracy: 0.9890 - val_loss: 0.0059 - val_accuracy: 0.9973
#
# Epoch 00046: val_loss did not improve from 0.00411
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0314 - accuracy: 0.9881 - val_loss: 0.0075 - val_accuracy: 0.9969
#
# Epoch 00047: val_loss did not improve from 0.00411
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0277 - accuracy: 0.9899 - val_loss: 0.0253 - val_accuracy: 0.9930
#
# Epoch 00048: val_loss did not improve from 0.00411
# Epoch 49/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0288 - accuracy: 0.9890 - val_loss: 0.0303 - val_accuracy: 0.9891
#
# Epoch 00049: val_loss did not improve from 0.00411
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0267 - accuracy: 0.9907 - val_loss: 0.0363 - val_accuracy: 0.9840
#
# Epoch 00050: val_loss did not improve from 0.00411
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9840
# Val Score:  [0.03625042364001274, 0.9839843511581421]
# Training on Fold:  4
# Epoch 1/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.6676 - accuracy: 0.7616 - val_loss: 1.0779 - val_accuracy: 0.5129
#
# Epoch 00001: val_loss did not improve from 0.00411
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3334 - accuracy: 0.8711 - val_loss: 0.1706 - val_accuracy: 0.9336
#
# Epoch 00002: val_loss did not improve from 0.00411
# Epoch 3/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2505 - accuracy: 0.9051 - val_loss: 0.2214 - val_accuracy: 0.9062
#
# Epoch 00003: val_loss did not improve from 0.00411
# Epoch 4/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2022 - accuracy: 0.9204 - val_loss: 0.1698 - val_accuracy: 0.9363
#
# Epoch 00004: val_loss did not improve from 0.00411
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1676 - accuracy: 0.9381 - val_loss: 0.0869 - val_accuracy: 0.9703
#
# Epoch 00005: val_loss did not improve from 0.00411
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1409 - accuracy: 0.9485 - val_loss: 0.1004 - val_accuracy: 0.9695
#
# Epoch 00006: val_loss did not improve from 0.00411
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1312 - accuracy: 0.9520 - val_loss: 0.0745 - val_accuracy: 0.9711
#
# Epoch 00007: val_loss did not improve from 0.00411
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1124 - accuracy: 0.9584 - val_loss: 0.0489 - val_accuracy: 0.9824
#
# Epoch 00008: val_loss did not improve from 0.00411
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1088 - accuracy: 0.9595 - val_loss: 0.1025 - val_accuracy: 0.9602
#
# Epoch 00009: val_loss did not improve from 0.00411
# Epoch 10/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0998 - accuracy: 0.9640 - val_loss: 0.0264 - val_accuracy: 0.9902
#
# Epoch 00010: val_loss did not improve from 0.00411
# Epoch 11/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0867 - accuracy: 0.9691 - val_loss: 0.0320 - val_accuracy: 0.9898
#
# Epoch 00011: val_loss did not improve from 0.00411
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0849 - accuracy: 0.9704 - val_loss: 0.0417 - val_accuracy: 0.9844
#
# Epoch 00012: val_loss did not improve from 0.00411
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0732 - accuracy: 0.9740 - val_loss: 0.0296 - val_accuracy: 0.9891
#
# Epoch 00013: val_loss did not improve from 0.00411
# Epoch 14/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0732 - accuracy: 0.9740 - val_loss: 0.0380 - val_accuracy: 0.9859
#
# Epoch 00014: val_loss did not improve from 0.00411
# Epoch 15/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0612 - accuracy: 0.9789 - val_loss: 0.0180 - val_accuracy: 0.9930
#
# Epoch 00015: val_loss did not improve from 0.00411
# Epoch 16/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0666 - accuracy: 0.9760 - val_loss: 0.0157 - val_accuracy: 0.9937
#
# Epoch 00016: val_loss did not improve from 0.00411
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0629 - accuracy: 0.9771 - val_loss: 0.0508 - val_accuracy: 0.9816
#
# Epoch 00017: val_loss did not improve from 0.00411
# Epoch 18/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0620 - accuracy: 0.9781 - val_loss: 0.0420 - val_accuracy: 0.9887
#
# Epoch 00018: val_loss did not improve from 0.00411
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0586 - accuracy: 0.9782 - val_loss: 0.0158 - val_accuracy: 0.9961
#
# Epoch 00019: val_loss did not improve from 0.00411
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0491 - accuracy: 0.9819 - val_loss: 0.0106 - val_accuracy: 0.9965
#
# Epoch 00020: val_loss did not improve from 0.00411
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0514 - accuracy: 0.9831 - val_loss: 0.0158 - val_accuracy: 0.9937
#
# Epoch 00021: val_loss did not improve from 0.00411
# Epoch 22/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0502 - accuracy: 0.9816 - val_loss: 0.0226 - val_accuracy: 0.9930
#
# Epoch 00022: val_loss did not improve from 0.00411
# Epoch 23/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0462 - accuracy: 0.9828 - val_loss: 0.0094 - val_accuracy: 0.9965
#
# Epoch 00023: val_loss did not improve from 0.00411
# Epoch 24/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0503 - accuracy: 0.9849 - val_loss: 0.0286 - val_accuracy: 0.9902
#
# Epoch 00024: val_loss did not improve from 0.00411
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0389 - accuracy: 0.9865 - val_loss: 0.0293 - val_accuracy: 0.9867
#
# Epoch 00025: val_loss did not improve from 0.00411
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0349 - accuracy: 0.9869 - val_loss: 0.0142 - val_accuracy: 0.9941
#
# Epoch 00026: val_loss did not improve from 0.00411
# Epoch 27/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0474 - accuracy: 0.9828 - val_loss: 0.0137 - val_accuracy: 0.9934
#
# Epoch 00027: val_loss did not improve from 0.00411
# Epoch 28/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0405 - accuracy: 0.9850 - val_loss: 0.0202 - val_accuracy: 0.9930
#
# Epoch 00028: val_loss did not improve from 0.00411
# Epoch 29/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0441 - accuracy: 0.9850 - val_loss: 0.0341 - val_accuracy: 0.9859
#
# Epoch 00029: val_loss did not improve from 0.00411
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0433 - accuracy: 0.9843 - val_loss: 0.0114 - val_accuracy: 0.9965
#
# Epoch 00030: val_loss did not improve from 0.00411
# Epoch 31/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0406 - accuracy: 0.9855 - val_loss: 0.0169 - val_accuracy: 0.9949
#
# Epoch 00031: val_loss did not improve from 0.00411
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0405 - accuracy: 0.9854 - val_loss: 0.0107 - val_accuracy: 0.9957
#
# Epoch 00032: val_loss did not improve from 0.00411
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0380 - accuracy: 0.9868 - val_loss: 0.0141 - val_accuracy: 0.9941
#
# Epoch 00033: val_loss did not improve from 0.00411
# Epoch 34/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0415 - accuracy: 0.9861 - val_loss: 0.0283 - val_accuracy: 0.9906
#
# Epoch 00034: val_loss did not improve from 0.00411
# Epoch 35/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0463 - accuracy: 0.9838 - val_loss: 0.0071 - val_accuracy: 0.9969
#
# Epoch 00035: val_loss did not improve from 0.00411
# Epoch 36/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.0096 - val_accuracy: 0.9961
#
# Epoch 00036: val_loss did not improve from 0.00411
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.0082 - val_accuracy: 0.9957
#
# Epoch 00037: val_loss did not improve from 0.00411
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0303 - accuracy: 0.9898 - val_loss: 0.0119 - val_accuracy: 0.9957
#
# Epoch 00038: val_loss did not improve from 0.00411
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0372 - accuracy: 0.9876 - val_loss: 0.0199 - val_accuracy: 0.9937
#
# Epoch 00039: val_loss did not improve from 0.00411
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0276 - accuracy: 0.9896 - val_loss: 0.0076 - val_accuracy: 0.9969
#
# Epoch 00040: val_loss did not improve from 0.00411
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0288 - accuracy: 0.9905 - val_loss: 0.0144 - val_accuracy: 0.9949
#
# Epoch 00041: val_loss did not improve from 0.00411
# Epoch 42/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0294 - accuracy: 0.9896 - val_loss: 0.0152 - val_accuracy: 0.9961
#
# Epoch 00042: val_loss did not improve from 0.00411
# Epoch 43/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0304 - accuracy: 0.9901 - val_loss: 0.0057 - val_accuracy: 0.9977
#
# Epoch 00043: val_loss did not improve from 0.00411
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0330 - accuracy: 0.9882 - val_loss: 0.0146 - val_accuracy: 0.9953
#
# Epoch 00044: val_loss did not improve from 0.00411
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0257 - accuracy: 0.9919 - val_loss: 0.0075 - val_accuracy: 0.9969
#
# Epoch 00045: val_loss did not improve from 0.00411
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0318 - accuracy: 0.9887 - val_loss: 0.0371 - val_accuracy: 0.9871
#
# Epoch 00046: val_loss did not improve from 0.00411
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0247 - accuracy: 0.9914 - val_loss: 0.0121 - val_accuracy: 0.9941
#
# Epoch 00047: val_loss did not improve from 0.00411
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0251 - accuracy: 0.9899 - val_loss: 0.0099 - val_accuracy: 0.9957
#
# Epoch 00048: val_loss did not improve from 0.00411
# Epoch 49/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0210 - accuracy: 0.9933 - val_loss: 0.0083 - val_accuracy: 0.9957
#
# Epoch 00049: val_loss did not improve from 0.00411
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0294 - accuracy: 0.9891 - val_loss: 0.0050 - val_accuracy: 0.9980
#
# Epoch 00050: val_loss did not improve from 0.00411
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 0.9980
# Val Score:  [0.005021425895392895, 0.998046875]
# Training on Fold:  5
# Epoch 1/50
# 320/320 [==============================] - 3s 6ms/step - loss: 0.6459 - accuracy: 0.7897 - val_loss: 0.5250 - val_accuracy: 0.7934
#
# Epoch 00001: val_loss did not improve from 0.00411
# Epoch 2/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.3224 - accuracy: 0.8757 - val_loss: 0.2309 - val_accuracy: 0.9070
#
# Epoch 00002: val_loss did not improve from 0.00411
# Epoch 3/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2480 - accuracy: 0.9014 - val_loss: 0.1501 - val_accuracy: 0.9348
#
# Epoch 00003: val_loss did not improve from 0.00411
# Epoch 4/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2043 - accuracy: 0.9218 - val_loss: 0.1588 - val_accuracy: 0.9348
#
# Epoch 00004: val_loss did not improve from 0.00411
# Epoch 5/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1920 - accuracy: 0.9263 - val_loss: 0.0884 - val_accuracy: 0.9676
#
# Epoch 00005: val_loss did not improve from 0.00411
# Epoch 6/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1527 - accuracy: 0.9426 - val_loss: 0.0882 - val_accuracy: 0.9680
#
# Epoch 00006: val_loss did not improve from 0.00411
# Epoch 7/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1356 - accuracy: 0.9477 - val_loss: 0.1012 - val_accuracy: 0.9590
#
# Epoch 00007: val_loss did not improve from 0.00411
# Epoch 8/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1354 - accuracy: 0.9490 - val_loss: 0.1180 - val_accuracy: 0.9559
#
# Epoch 00008: val_loss did not improve from 0.00411
# Epoch 9/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1182 - accuracy: 0.9572 - val_loss: 0.0382 - val_accuracy: 0.9891
#
# Epoch 00009: val_loss did not improve from 0.00411
# Epoch 10/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1036 - accuracy: 0.9612 - val_loss: 0.0463 - val_accuracy: 0.9832
#
# Epoch 00010: val_loss did not improve from 0.00411
# Epoch 11/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1025 - accuracy: 0.9604 - val_loss: 0.0519 - val_accuracy: 0.9789
#
# Epoch 00011: val_loss did not improve from 0.00411
# Epoch 12/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0951 - accuracy: 0.9650 - val_loss: 0.0744 - val_accuracy: 0.9727
#
# Epoch 00012: val_loss did not improve from 0.00411
# Epoch 13/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0825 - accuracy: 0.9710 - val_loss: 0.0465 - val_accuracy: 0.9844
#
# Epoch 00013: val_loss did not improve from 0.00411
# Epoch 14/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0762 - accuracy: 0.9717 - val_loss: 0.0341 - val_accuracy: 0.9875
#
# Epoch 00014: val_loss did not improve from 0.00411
# Epoch 15/50
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0729 - accuracy: 0.9739 - val_loss: 0.0341 - val_accuracy: 0.9879
#
# Epoch 00015: val_loss did not improve from 0.00411
# Epoch 16/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0736 - accuracy: 0.9749 - val_loss: 0.0268 - val_accuracy: 0.9895
#
# Epoch 00016: val_loss did not improve from 0.00411
# Epoch 17/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0718 - accuracy: 0.9764 - val_loss: 0.0233 - val_accuracy: 0.9895
#
# Epoch 00017: val_loss did not improve from 0.00411
# Epoch 18/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0633 - accuracy: 0.9777 - val_loss: 0.0209 - val_accuracy: 0.9906
#
# Epoch 00018: val_loss did not improve from 0.00411
# Epoch 19/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0652 - accuracy: 0.9762 - val_loss: 0.0325 - val_accuracy: 0.9883
#
# Epoch 00019: val_loss did not improve from 0.00411
# Epoch 20/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0568 - accuracy: 0.9797 - val_loss: 0.0326 - val_accuracy: 0.9895
#
# Epoch 00020: val_loss did not improve from 0.00411
# Epoch 21/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0564 - accuracy: 0.9799 - val_loss: 0.0225 - val_accuracy: 0.9910
#
# Epoch 00021: val_loss did not improve from 0.00411
# Epoch 22/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0579 - accuracy: 0.9799 - val_loss: 0.0188 - val_accuracy: 0.9934
#
# Epoch 00022: val_loss did not improve from 0.00411
# Epoch 23/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0458 - accuracy: 0.9836 - val_loss: 0.0830 - val_accuracy: 0.9754
#
# Epoch 00023: val_loss did not improve from 0.00411
# Epoch 24/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0482 - accuracy: 0.9837 - val_loss: 0.0156 - val_accuracy: 0.9941
#
# Epoch 00024: val_loss did not improve from 0.00411
# Epoch 25/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0524 - accuracy: 0.9825 - val_loss: 0.0287 - val_accuracy: 0.9910
#
# Epoch 00025: val_loss did not improve from 0.00411
# Epoch 26/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0471 - accuracy: 0.9843 - val_loss: 0.0590 - val_accuracy: 0.9773
#
# Epoch 00026: val_loss did not improve from 0.00411
# Epoch 27/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0382 - accuracy: 0.9866 - val_loss: 0.0087 - val_accuracy: 0.9969
#
# Epoch 00027: val_loss did not improve from 0.00411
# Epoch 28/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0476 - accuracy: 0.9831 - val_loss: 0.0196 - val_accuracy: 0.9918
#
# Epoch 00028: val_loss did not improve from 0.00411
# Epoch 29/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0446 - accuracy: 0.9840 - val_loss: 0.0225 - val_accuracy: 0.9895
#
# Epoch 00029: val_loss did not improve from 0.00411
# Epoch 30/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0407 - accuracy: 0.9859 - val_loss: 0.0442 - val_accuracy: 0.9836
#
# Epoch 00030: val_loss did not improve from 0.00411
# Epoch 31/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0452 - accuracy: 0.9842 - val_loss: 0.0264 - val_accuracy: 0.9891
#
# Epoch 00031: val_loss did not improve from 0.00411
# Epoch 32/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0388 - accuracy: 0.9874 - val_loss: 0.0073 - val_accuracy: 0.9957
#
# Epoch 00032: val_loss did not improve from 0.00411
# Epoch 33/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0375 - accuracy: 0.9865 - val_loss: 0.0153 - val_accuracy: 0.9961
#
# Epoch 00033: val_loss did not improve from 0.00411
# Epoch 34/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0325 - accuracy: 0.9888 - val_loss: 0.0181 - val_accuracy: 0.9945
#
# Epoch 00034: val_loss did not improve from 0.00411
# Epoch 35/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0423 - accuracy: 0.9865 - val_loss: 0.0235 - val_accuracy: 0.9926
#
# Epoch 00035: val_loss did not improve from 0.00411
# Epoch 36/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0313 - accuracy: 0.9894 - val_loss: 0.0100 - val_accuracy: 0.9973
#
# Epoch 00036: val_loss did not improve from 0.00411
# Epoch 37/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0303 - accuracy: 0.9896 - val_loss: 0.0171 - val_accuracy: 0.9926
#
# Epoch 00037: val_loss did not improve from 0.00411
# Epoch 38/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0371 - accuracy: 0.9871 - val_loss: 0.0074 - val_accuracy: 0.9973
#
# Epoch 00038: val_loss did not improve from 0.00411
# Epoch 39/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0286 - accuracy: 0.9896 - val_loss: 0.0059 - val_accuracy: 0.9965
#
# Epoch 00039: val_loss did not improve from 0.00411
# Epoch 40/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0316 - accuracy: 0.9879 - val_loss: 0.0189 - val_accuracy: 0.9918
#
# Epoch 00040: val_loss did not improve from 0.00411
# Epoch 41/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0330 - accuracy: 0.9884 - val_loss: 0.0094 - val_accuracy: 0.9973
#
# Epoch 00041: val_loss did not improve from 0.00411
# Epoch 42/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0256 - accuracy: 0.9904 - val_loss: 0.0241 - val_accuracy: 0.9918
#
# Epoch 00042: val_loss did not improve from 0.00411
# Epoch 43/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0406 - accuracy: 0.9864 - val_loss: 0.0198 - val_accuracy: 0.9949
#
# Epoch 00043: val_loss did not improve from 0.00411
# Epoch 44/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0256 - accuracy: 0.9903 - val_loss: 0.0050 - val_accuracy: 0.9980
#
# Epoch 00044: val_loss did not improve from 0.00411
# Epoch 45/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0374 - accuracy: 0.9868 - val_loss: 0.3303 - val_accuracy: 0.8980
#
# Epoch 00045: val_loss did not improve from 0.00411
# Epoch 46/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0318 - accuracy: 0.9890 - val_loss: 0.0085 - val_accuracy: 0.9969
#
# Epoch 00046: val_loss did not improve from 0.00411
# Epoch 47/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0273 - accuracy: 0.9910 - val_loss: 0.0108 - val_accuracy: 0.9957
#
# Epoch 00047: val_loss did not improve from 0.00411
# Epoch 48/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0211 - accuracy: 0.9921 - val_loss: 0.0090 - val_accuracy: 0.9965
#
# Epoch 00048: val_loss did not improve from 0.00411
# Epoch 49/50
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0317 - accuracy: 0.9896 - val_loss: 0.0087 - val_accuracy: 0.9957
#
# Epoch 00049: val_loss did not improve from 0.00411
# Epoch 50/50
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.0253 - val_accuracy: 0.9895
#
# Epoch 00050: val_loss did not improve from 0.00411
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9895
# Val Score:  [0.025332976132631302, 0.989453136920929]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9959
# Test Accuracy: 99.59375262260437

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
