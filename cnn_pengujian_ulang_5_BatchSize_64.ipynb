# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-4
BS = 64
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_36 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_37 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_38 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_39 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_40 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_41 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 160/160 [==============================] - 3s 15ms/step - loss: 0.4792 - accuracy: 0.8448 - val_loss: 4.0138 - val_accuracy: 0.2516
#
# Epoch 00001: val_loss improved from inf to 4.01376, saving model to model.h5
# Epoch 2/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.1705 - accuracy: 0.9400 - val_loss: 4.6938 - val_accuracy: 0.3492
#
# Epoch 00002: val_loss did not improve from 4.01376
# Epoch 3/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.1185 - accuracy: 0.9585 - val_loss: 3.3852 - val_accuracy: 0.6395
#
# Epoch 00003: val_loss improved from 4.01376 to 3.38516, saving model to model.h5
# Epoch 4/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0799 - accuracy: 0.9733 - val_loss: 0.7076 - val_accuracy: 0.8313
#
# Epoch 00004: val_loss improved from 3.38516 to 0.70761, saving model to model.h5
# Epoch 5/100
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0707 - accuracy: 0.9773 - val_loss: 0.3235 - val_accuracy: 0.9066
#
# Epoch 00005: val_loss improved from 0.70761 to 0.32350, saving model to model.h5
# Epoch 6/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0611 - accuracy: 0.9805 - val_loss: 0.4478 - val_accuracy: 0.8992
#
# Epoch 00006: val_loss did not improve from 0.32350
# Epoch 7/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0461 - accuracy: 0.9839 - val_loss: 0.1667 - val_accuracy: 0.9480
#
# Epoch 00007: val_loss improved from 0.32350 to 0.16667, saving model to model.h5
# Epoch 8/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0423 - accuracy: 0.9865 - val_loss: 0.2454 - val_accuracy: 0.9301
#
# Epoch 00008: val_loss did not improve from 0.16667
# Epoch 9/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0368 - accuracy: 0.9890 - val_loss: 0.1801 - val_accuracy: 0.9457
#
# Epoch 00009: val_loss did not improve from 0.16667
# Epoch 10/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0279 - accuracy: 0.9919 - val_loss: 0.2514 - val_accuracy: 0.9336
#
# Epoch 00010: val_loss did not improve from 0.16667
# Epoch 11/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0398 - accuracy: 0.9898 - val_loss: 0.2822 - val_accuracy: 0.9301
#
# Epoch 00011: val_loss did not improve from 0.16667
# Epoch 12/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0305 - accuracy: 0.9906 - val_loss: 0.2865 - val_accuracy: 0.9348
#
# Epoch 00012: val_loss did not improve from 0.16667
# Epoch 13/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0309 - accuracy: 0.9919 - val_loss: 0.1350 - val_accuracy: 0.9617
#
# Epoch 00013: val_loss improved from 0.16667 to 0.13503, saving model to model.h5
# Epoch 14/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0240 - accuracy: 0.9926 - val_loss: 0.1882 - val_accuracy: 0.9445
#
# Epoch 00014: val_loss did not improve from 0.13503
# Epoch 15/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0226 - accuracy: 0.9933 - val_loss: 0.1607 - val_accuracy: 0.9543
#
# Epoch 00015: val_loss did not improve from 0.13503
# Epoch 16/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0213 - accuracy: 0.9943 - val_loss: 0.0597 - val_accuracy: 0.9820
#
# Epoch 00016: val_loss improved from 0.13503 to 0.05971, saving model to model.h5
# Epoch 17/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.1646 - val_accuracy: 0.9570
#
# Epoch 00017: val_loss did not improve from 0.05971
# Epoch 18/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0186 - accuracy: 0.9942 - val_loss: 0.2738 - val_accuracy: 0.9406
#
# Epoch 00018: val_loss did not improve from 0.05971
# Epoch 19/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.1626 - val_accuracy: 0.9570
#
# Epoch 00019: val_loss did not improve from 0.05971
# Epoch 20/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 0.1110 - val_accuracy: 0.9676
#
# Epoch 00020: val_loss did not improve from 0.05971
# Epoch 21/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0221 - accuracy: 0.9928 - val_loss: 0.2272 - val_accuracy: 0.9438
#
# Epoch 00021: val_loss did not improve from 0.05971
# Epoch 22/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0174 - accuracy: 0.9938 - val_loss: 0.3146 - val_accuracy: 0.9309
#
# Epoch 00022: val_loss did not improve from 0.05971
# Epoch 23/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0135 - accuracy: 0.9948 - val_loss: 0.1115 - val_accuracy: 0.9660
#
# Epoch 00023: val_loss did not improve from 0.05971
# Epoch 24/100
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.0876 - val_accuracy: 0.9727
#
# Epoch 00024: val_loss did not improve from 0.05971
# Epoch 25/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0459 - val_accuracy: 0.9863
#
# Epoch 00025: val_loss improved from 0.05971 to 0.04589, saving model to model.h5
# Epoch 26/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0198 - accuracy: 0.9935 - val_loss: 0.0457 - val_accuracy: 0.9848
#
# Epoch 00026: val_loss improved from 0.04589 to 0.04565, saving model to model.h5
# Epoch 27/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0478 - val_accuracy: 0.9855
#
# Epoch 00027: val_loss did not improve from 0.04565
# Epoch 28/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0517 - val_accuracy: 0.9820
#
# Epoch 00028: val_loss did not improve from 0.04565
# Epoch 29/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.0265 - val_accuracy: 0.9918
#
# Epoch 00029: val_loss improved from 0.04565 to 0.02653, saving model to model.h5
# Epoch 30/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.0445 - val_accuracy: 0.9855
#
# Epoch 00030: val_loss did not improve from 0.02653
# Epoch 31/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.2509 - val_accuracy: 0.9453
#
# Epoch 00031: val_loss did not improve from 0.02653
# Epoch 32/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0631 - val_accuracy: 0.9777
#
# Epoch 00032: val_loss did not improve from 0.02653
# Epoch 33/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 0.0224 - val_accuracy: 0.9930
#
# Epoch 00033: val_loss improved from 0.02653 to 0.02240, saving model to model.h5
# Epoch 34/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0273 - val_accuracy: 0.9918
#
# Epoch 00034: val_loss did not improve from 0.02240
# Epoch 35/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0126 - accuracy: 0.9950 - val_loss: 0.0464 - val_accuracy: 0.9906
#
# Epoch 00035: val_loss did not improve from 0.02240
# Epoch 36/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.3226 - val_accuracy: 0.9383
#
# Epoch 00036: val_loss did not improve from 0.02240
# Epoch 37/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0179 - val_accuracy: 0.9941
#
# Epoch 00037: val_loss improved from 0.02240 to 0.01788, saving model to model.h5
# Epoch 38/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 0.0269 - val_accuracy: 0.9922
#
# Epoch 00038: val_loss did not improve from 0.01788
# Epoch 39/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0103 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss improved from 0.01788 to 0.01030, saving model to model.h5
# Epoch 40/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.0266 - val_accuracy: 0.9914
#
# Epoch 00040: val_loss did not improve from 0.01030
# Epoch 41/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0111 - accuracy: 0.9956 - val_loss: 0.0172 - val_accuracy: 0.9961
#
# Epoch 00041: val_loss did not improve from 0.01030
# Epoch 42/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0072 - accuracy: 0.9968 - val_loss: 0.0151 - val_accuracy: 0.9965
#
# Epoch 00042: val_loss did not improve from 0.01030
# Epoch 43/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 0.0283 - val_accuracy: 0.9918
#
# Epoch 00043: val_loss did not improve from 0.01030
# Epoch 44/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0217 - val_accuracy: 0.9934
#
# Epoch 00044: val_loss did not improve from 0.01030
# Epoch 45/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.0388 - val_accuracy: 0.9887
#
# Epoch 00045: val_loss did not improve from 0.01030
# Epoch 46/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 0.0185 - val_accuracy: 0.9934
#
# Epoch 00046: val_loss did not improve from 0.01030
# Epoch 47/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.0310 - val_accuracy: 0.9898
#
# Epoch 00047: val_loss did not improve from 0.01030
# Epoch 48/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.0469 - val_accuracy: 0.9863
#
# Epoch 00048: val_loss did not improve from 0.01030
# Epoch 49/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0125 - val_accuracy: 0.9965
#
# Epoch 00049: val_loss did not improve from 0.01030
# Epoch 50/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0081 - accuracy: 0.9966 - val_loss: 0.0195 - val_accuracy: 0.9953
#
# Epoch 00050: val_loss did not improve from 0.01030
# Epoch 51/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0083 - accuracy: 0.9965 - val_loss: 0.0157 - val_accuracy: 0.9949
#
# Epoch 00051: val_loss did not improve from 0.01030
# Epoch 52/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0070 - accuracy: 0.9968 - val_loss: 0.0276 - val_accuracy: 0.9930
#
# Epoch 00052: val_loss did not improve from 0.01030
# Epoch 53/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.0095 - val_accuracy: 0.9977
#
# Epoch 00053: val_loss improved from 0.01030 to 0.00946, saving model to model.h5
# Epoch 54/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0096 - accuracy: 0.9964 - val_loss: 0.0139 - val_accuracy: 0.9977
#
# Epoch 00054: val_loss did not improve from 0.00946
# Epoch 55/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 0.0289 - val_accuracy: 0.9945
#
# Epoch 00055: val_loss did not improve from 0.00946
# Epoch 56/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 0.0277 - val_accuracy: 0.9922
#
# Epoch 00056: val_loss did not improve from 0.00946
# Epoch 57/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9972 - val_loss: 0.0214 - val_accuracy: 0.9945
#
# Epoch 00057: val_loss did not improve from 0.00946
# Epoch 58/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0102 - val_accuracy: 0.9973
#
# Epoch 00058: val_loss did not improve from 0.00946
# Epoch 59/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9968 - val_loss: 0.0203 - val_accuracy: 0.9930
#
# Epoch 00059: val_loss did not improve from 0.00946
# Epoch 60/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0188 - val_accuracy: 0.9953
#
# Epoch 00060: val_loss did not improve from 0.00946
# Epoch 61/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0162 - val_accuracy: 0.9957
#
# Epoch 00061: val_loss did not improve from 0.00946
# Epoch 62/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0334 - val_accuracy: 0.9922
#
# Epoch 00062: val_loss did not improve from 0.00946
# Epoch 63/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0038 - accuracy: 0.9982 - val_loss: 0.0119 - val_accuracy: 0.9965
#
# Epoch 00063: val_loss did not improve from 0.00946
# Epoch 64/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0076 - val_accuracy: 0.9977
#
# Epoch 00064: val_loss improved from 0.00946 to 0.00764, saving model to model.h5
# Epoch 65/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.1060 - val_accuracy: 0.9750
#
# Epoch 00065: val_loss did not improve from 0.00764
# Epoch 66/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0042 - accuracy: 0.9981 - val_loss: 0.0105 - val_accuracy: 0.9977
#
# Epoch 00066: val_loss did not improve from 0.00764
# Epoch 67/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0096 - val_accuracy: 0.9980
#
# Epoch 00067: val_loss did not improve from 0.00764
# Epoch 68/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.0088 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00764
# Epoch 69/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.0120 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00764
# Epoch 70/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0055 - accuracy: 0.9978 - val_loss: 0.0093 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00764
# Epoch 71/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0070 - accuracy: 0.9968 - val_loss: 0.0789 - val_accuracy: 0.9801
#
# Epoch 00071: val_loss did not improve from 0.00764
# Epoch 72/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 0.0100 - val_accuracy: 0.9957
#
# Epoch 00072: val_loss did not improve from 0.00764
# Epoch 73/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0056 - accuracy: 0.9975 - val_loss: 0.0092 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00764
# Epoch 74/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0048 - accuracy: 0.9980 - val_loss: 0.0104 - val_accuracy: 0.9977
#
# Epoch 00074: val_loss did not improve from 0.00764
# Epoch 75/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.0137 - val_accuracy: 0.9977
#
# Epoch 00075: val_loss did not improve from 0.00764
# Epoch 76/100
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.0382 - val_accuracy: 0.9969
#
# Epoch 00076: val_loss did not improve from 0.00764
# Epoch 77/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0050 - accuracy: 0.9977 - val_loss: 0.0119 - val_accuracy: 0.9969
#
# Epoch 00077: val_loss did not improve from 0.00764
# Epoch 78/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0074 - val_accuracy: 0.9977
#
# Epoch 00078: val_loss improved from 0.00764 to 0.00741, saving model to model.h5
# Epoch 79/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0435 - val_accuracy: 0.9914
#
# Epoch 00079: val_loss did not improve from 0.00741
# Epoch 80/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0053 - accuracy: 0.9971 - val_loss: 0.0116 - val_accuracy: 0.9965
#
# Epoch 00080: val_loss did not improve from 0.00741
# Epoch 81/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0064 - accuracy: 0.9969 - val_loss: 0.0097 - val_accuracy: 0.9969
#
# Epoch 00081: val_loss did not improve from 0.00741
# Epoch 82/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0043 - accuracy: 0.9978 - val_loss: 0.0107 - val_accuracy: 0.9973
#
# Epoch 00082: val_loss did not improve from 0.00741
# Epoch 83/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0051 - accuracy: 0.9976 - val_loss: 0.0984 - val_accuracy: 0.9785
#
# Epoch 00083: val_loss did not improve from 0.00741
# Epoch 84/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0096 - accuracy: 0.9959 - val_loss: 0.1086 - val_accuracy: 0.9754
#
# Epoch 00084: val_loss did not improve from 0.00741
# Epoch 85/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9971 - val_loss: 0.0083 - val_accuracy: 0.9977
#
# Epoch 00085: val_loss did not improve from 0.00741
# Epoch 86/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0057 - accuracy: 0.9968 - val_loss: 0.0149 - val_accuracy: 0.9961
#
# Epoch 00086: val_loss did not improve from 0.00741
# Epoch 87/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0054 - accuracy: 0.9976 - val_loss: 0.0088 - val_accuracy: 0.9977
#
# Epoch 00087: val_loss did not improve from 0.00741
# Epoch 88/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0062 - accuracy: 0.9970 - val_loss: 0.0172 - val_accuracy: 0.9969
#
# Epoch 00088: val_loss did not improve from 0.00741
# Epoch 89/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.0151 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00741
# Epoch 90/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0051 - accuracy: 0.9974 - val_loss: 0.0091 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00741
# Epoch 91/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0037 - accuracy: 0.9981 - val_loss: 0.0106 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00741
# Epoch 92/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.0090 - val_accuracy: 0.9984
#
# Epoch 00092: val_loss did not improve from 0.00741
# Epoch 93/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0047 - accuracy: 0.9977 - val_loss: 0.0125 - val_accuracy: 0.9969
#
# Epoch 00093: val_loss did not improve from 0.00741
# Epoch 94/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0725 - val_accuracy: 0.9848
#
# Epoch 00094: val_loss did not improve from 0.00741
# Epoch 95/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0060 - accuracy: 0.9974 - val_loss: 0.0112 - val_accuracy: 0.9984
#
# Epoch 00095: val_loss did not improve from 0.00741
# Epoch 96/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0041 - accuracy: 0.9979 - val_loss: 0.0138 - val_accuracy: 0.9973
#
# Epoch 00096: val_loss did not improve from 0.00741
# Epoch 97/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0041 - accuracy: 0.9979 - val_loss: 0.0117 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00741
# Epoch 98/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0042 - accuracy: 0.9979 - val_loss: 0.0110 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00741
# Epoch 99/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0040 - accuracy: 0.9982 - val_loss: 0.0078 - val_accuracy: 0.9977
#
# Epoch 00099: val_loss did not improve from 0.00741
# Epoch 100/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0040 - accuracy: 0.9976 - val_loss: 0.0226 - val_accuracy: 0.9961
#
# Epoch 00100: val_loss did not improve from 0.00741
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9961
# Val Score:  [0.02264058217406273, 0.99609375]
# Training on Fold:  2
# Epoch 1/100
# 160/160 [==============================] - 3s 13ms/step - loss: 0.3497 - accuracy: 0.8940 - val_loss: 9.4012 - val_accuracy: 0.2406
#
# Epoch 00001: val_loss did not improve from 0.00741
# Epoch 2/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0928 - accuracy: 0.9688 - val_loss: 8.2176 - val_accuracy: 0.4301
#
# Epoch 00002: val_loss did not improve from 0.00741
# Epoch 3/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0624 - accuracy: 0.9786 - val_loss: 3.8936 - val_accuracy: 0.6473
#
# Epoch 00003: val_loss did not improve from 0.00741
# Epoch 4/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0621 - accuracy: 0.9825 - val_loss: 1.1836 - val_accuracy: 0.8004
#
# Epoch 00004: val_loss did not improve from 0.00741
# Epoch 5/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0477 - accuracy: 0.9857 - val_loss: 0.5232 - val_accuracy: 0.8766
#
# Epoch 00005: val_loss did not improve from 0.00741
# Epoch 6/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0333 - accuracy: 0.9896 - val_loss: 0.5666 - val_accuracy: 0.8898
#
# Epoch 00006: val_loss did not improve from 0.00741
# Epoch 7/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.2657 - val_accuracy: 0.9371
#
# Epoch 00007: val_loss did not improve from 0.00741
# Epoch 8/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0273 - accuracy: 0.9929 - val_loss: 0.6905 - val_accuracy: 0.8938
#
# Epoch 00008: val_loss did not improve from 0.00741
# Epoch 9/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0290 - accuracy: 0.9912 - val_loss: 0.0701 - val_accuracy: 0.9805
#
# Epoch 00009: val_loss did not improve from 0.00741
# Epoch 10/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0213 - accuracy: 0.9914 - val_loss: 0.1283 - val_accuracy: 0.9641
#
# Epoch 00010: val_loss did not improve from 0.00741
# Epoch 11/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.3795 - val_accuracy: 0.9203
#
# Epoch 00011: val_loss did not improve from 0.00741
# Epoch 12/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0244 - accuracy: 0.9917 - val_loss: 0.1107 - val_accuracy: 0.9695
#
# Epoch 00012: val_loss did not improve from 0.00741
# Epoch 13/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0198 - accuracy: 0.9924 - val_loss: 0.2624 - val_accuracy: 0.9426
#
# Epoch 00013: val_loss did not improve from 0.00741
# Epoch 14/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 0.3562 - val_accuracy: 0.9234
#
# Epoch 00014: val_loss did not improve from 0.00741
# Epoch 15/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 0.4657 - val_accuracy: 0.9086
#
# Epoch 00015: val_loss did not improve from 0.00741
# Epoch 16/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0102 - accuracy: 0.9959 - val_loss: 0.2705 - val_accuracy: 0.9398
#
# Epoch 00016: val_loss did not improve from 0.00741
# Epoch 17/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.4437 - val_accuracy: 0.9187
#
# Epoch 00017: val_loss did not improve from 0.00741
# Epoch 18/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0145 - accuracy: 0.9949 - val_loss: 0.0669 - val_accuracy: 0.9840
#
# Epoch 00018: val_loss did not improve from 0.00741
# Epoch 19/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0150 - accuracy: 0.9946 - val_loss: 0.4089 - val_accuracy: 0.9184
#
# Epoch 00019: val_loss did not improve from 0.00741
# Epoch 20/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.1612 - val_accuracy: 0.9605
#
# Epoch 00020: val_loss did not improve from 0.00741
# Epoch 21/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0967 - val_accuracy: 0.9738
#
# Epoch 00021: val_loss did not improve from 0.00741
# Epoch 22/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 0.1537 - val_accuracy: 0.9605
#
# Epoch 00022: val_loss did not improve from 0.00741
# Epoch 23/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0121 - accuracy: 0.9952 - val_loss: 0.0349 - val_accuracy: 0.9898
#
# Epoch 00023: val_loss did not improve from 0.00741
# Epoch 24/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0093 - accuracy: 0.9960 - val_loss: 0.0753 - val_accuracy: 0.9820
#
# Epoch 00024: val_loss did not improve from 0.00741
# Epoch 25/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0865 - val_accuracy: 0.9789
#
# Epoch 00025: val_loss did not improve from 0.00741
# Epoch 26/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0082 - accuracy: 0.9957 - val_loss: 0.0706 - val_accuracy: 0.9832
#
# Epoch 00026: val_loss did not improve from 0.00741
# Epoch 27/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0090 - accuracy: 0.9960 - val_loss: 0.0676 - val_accuracy: 0.9840
#
# Epoch 00027: val_loss did not improve from 0.00741
# Epoch 28/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0089 - accuracy: 0.9965 - val_loss: 0.0934 - val_accuracy: 0.9758
#
# Epoch 00028: val_loss did not improve from 0.00741
# Epoch 29/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0096 - accuracy: 0.9957 - val_loss: 0.1006 - val_accuracy: 0.9734
#
# Epoch 00029: val_loss did not improve from 0.00741
# Epoch 30/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0074 - accuracy: 0.9970 - val_loss: 0.0702 - val_accuracy: 0.9773
#
# Epoch 00030: val_loss did not improve from 0.00741
# Epoch 31/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 0.1033 - val_accuracy: 0.9746
#
# Epoch 00031: val_loss did not improve from 0.00741
# Epoch 32/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0969 - val_accuracy: 0.9805
#
# Epoch 00032: val_loss did not improve from 0.00741
# Epoch 33/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.1417 - val_accuracy: 0.9723
#
# Epoch 00033: val_loss did not improve from 0.00741
# Epoch 34/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.2161 - val_accuracy: 0.9535
#
# Epoch 00034: val_loss did not improve from 0.00741
# Epoch 35/100
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 0.1769 - val_accuracy: 0.9637
#
# Epoch 00035: val_loss did not improve from 0.00741
# Epoch 36/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 0.0435 - val_accuracy: 0.9914
#
# Epoch 00036: val_loss did not improve from 0.00741
# Epoch 37/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0082 - accuracy: 0.9959 - val_loss: 0.2026 - val_accuracy: 0.9555
#
# Epoch 00037: val_loss did not improve from 0.00741
# Epoch 38/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.1386 - val_accuracy: 0.9633
#
# Epoch 00038: val_loss did not improve from 0.00741
# Epoch 39/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0352 - val_accuracy: 0.9918
#
# Epoch 00039: val_loss did not improve from 0.00741
# Epoch 40/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.0339 - val_accuracy: 0.9926
#
# Epoch 00040: val_loss did not improve from 0.00741
# Epoch 41/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0596 - val_accuracy: 0.9891
#
# Epoch 00041: val_loss did not improve from 0.00741
# Epoch 42/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9972 - val_loss: 0.0481 - val_accuracy: 0.9902
#
# Epoch 00042: val_loss did not improve from 0.00741
# Epoch 43/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0053 - accuracy: 0.9979 - val_loss: 0.0374 - val_accuracy: 0.9914
#
# Epoch 00043: val_loss did not improve from 0.00741
# Epoch 44/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0126 - accuracy: 0.9948 - val_loss: 0.0290 - val_accuracy: 0.9922
#
# Epoch 00044: val_loss did not improve from 0.00741
# Epoch 45/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0074 - accuracy: 0.9967 - val_loss: 0.0444 - val_accuracy: 0.9863
#
# Epoch 00045: val_loss did not improve from 0.00741
# Epoch 46/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0060 - accuracy: 0.9970 - val_loss: 0.0267 - val_accuracy: 0.9902
#
# Epoch 00046: val_loss did not improve from 0.00741
# Epoch 47/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0347 - val_accuracy: 0.9914
#
# Epoch 00047: val_loss did not improve from 0.00741
# Epoch 48/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0079 - accuracy: 0.9961 - val_loss: 0.0942 - val_accuracy: 0.9812
#
# Epoch 00048: val_loss did not improve from 0.00741
# Epoch 49/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0080 - accuracy: 0.9970 - val_loss: 0.0204 - val_accuracy: 0.9937
#
# Epoch 00049: val_loss did not improve from 0.00741
# Epoch 50/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0073 - accuracy: 0.9965 - val_loss: 0.0246 - val_accuracy: 0.9937
#
# Epoch 00050: val_loss did not improve from 0.00741
# Epoch 51/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0454 - val_accuracy: 0.9871
#
# Epoch 00051: val_loss did not improve from 0.00741
# Epoch 52/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.1056 - val_accuracy: 0.9762
#
# Epoch 00052: val_loss did not improve from 0.00741
# Epoch 53/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0074 - accuracy: 0.9963 - val_loss: 0.0181 - val_accuracy: 0.9953
#
# Epoch 00053: val_loss did not improve from 0.00741
# Epoch 54/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.0330 - val_accuracy: 0.9937
#
# Epoch 00054: val_loss did not improve from 0.00741
# Epoch 55/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.0281 - val_accuracy: 0.9961
#
# Epoch 00055: val_loss did not improve from 0.00741
# Epoch 56/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0075 - accuracy: 0.9967 - val_loss: 0.0544 - val_accuracy: 0.9914
#
# Epoch 00056: val_loss did not improve from 0.00741
# Epoch 57/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0238 - val_accuracy: 0.9953
#
# Epoch 00057: val_loss did not improve from 0.00741
# Epoch 58/100
# 160/160 [==============================] - 2s 13ms/step - loss: 0.0045 - accuracy: 0.9978 - val_loss: 0.0378 - val_accuracy: 0.9930
#
# Epoch 00058: val_loss did not improve from 0.00741
# Epoch 59/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0046 - accuracy: 0.9975 - val_loss: 0.0471 - val_accuracy: 0.9930
#
# Epoch 00059: val_loss did not improve from 0.00741
# Epoch 60/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0047 - accuracy: 0.9977 - val_loss: 0.0376 - val_accuracy: 0.9961
#
# Epoch 00060: val_loss did not improve from 0.00741
# Epoch 61/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 0.0498 - val_accuracy: 0.9953
#
# Epoch 00061: val_loss did not improve from 0.00741
# Epoch 62/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0073 - accuracy: 0.9960 - val_loss: 0.0338 - val_accuracy: 0.9969
#
# Epoch 00062: val_loss did not improve from 0.00741
# Epoch 63/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0389 - val_accuracy: 0.9973
#
# Epoch 00063: val_loss did not improve from 0.00741
# Epoch 64/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0452 - val_accuracy: 0.9887
#
# Epoch 00064: val_loss did not improve from 0.00741
# Epoch 65/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0302 - val_accuracy: 0.9914
#
# Epoch 00065: val_loss did not improve from 0.00741
# Epoch 66/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0046 - accuracy: 0.9978 - val_loss: 0.0064 - val_accuracy: 0.9977
#
# Epoch 00066: val_loss improved from 0.00741 to 0.00635, saving model to model.h5
# Epoch 67/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9963 - val_loss: 0.0365 - val_accuracy: 0.9906
#
# Epoch 00067: val_loss did not improve from 0.00635
# Epoch 68/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0045 - accuracy: 0.9974 - val_loss: 0.0103 - val_accuracy: 0.9977
#
# Epoch 00068: val_loss did not improve from 0.00635
# Epoch 69/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0057 - accuracy: 0.9971 - val_loss: 0.0136 - val_accuracy: 0.9965
#
# Epoch 00069: val_loss did not improve from 0.00635
# Epoch 70/100
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.0122 - val_accuracy: 0.9969
#
# Epoch 00070: val_loss did not improve from 0.00635
# Epoch 71/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 0.0116 - val_accuracy: 0.9961
#
# Epoch 00071: val_loss did not improve from 0.00635
# Epoch 72/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.0195 - val_accuracy: 0.9922
#
# Epoch 00072: val_loss did not improve from 0.00635
# Epoch 73/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0054 - accuracy: 0.9974 - val_loss: 0.0694 - val_accuracy: 0.9816
#
# Epoch 00073: val_loss did not improve from 0.00635
# Epoch 74/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0202 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00635
# Epoch 75/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0038 - accuracy: 0.9979 - val_loss: 0.0182 - val_accuracy: 0.9957
#
# Epoch 00075: val_loss did not improve from 0.00635
# Epoch 76/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.0364 - val_accuracy: 0.9961
#
# Epoch 00076: val_loss did not improve from 0.00635
# Epoch 77/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0363 - val_accuracy: 0.9941
#
# Epoch 00077: val_loss did not improve from 0.00635
# Epoch 78/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0046 - accuracy: 0.9977 - val_loss: 0.0354 - val_accuracy: 0.9977
#
# Epoch 00078: val_loss did not improve from 0.00635
# Epoch 79/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0055 - accuracy: 0.9975 - val_loss: 0.0351 - val_accuracy: 0.9934
#
# Epoch 00079: val_loss did not improve from 0.00635
# Epoch 80/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0061 - accuracy: 0.9969 - val_loss: 0.0904 - val_accuracy: 0.9844
#
# Epoch 00080: val_loss did not improve from 0.00635
# Epoch 81/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0322 - val_accuracy: 0.9973
#
# Epoch 00081: val_loss did not improve from 0.00635
# Epoch 82/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0044 - accuracy: 0.9979 - val_loss: 0.0681 - val_accuracy: 0.9926
#
# Epoch 00082: val_loss did not improve from 0.00635
# Epoch 83/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0061 - accuracy: 0.9974 - val_loss: 0.0361 - val_accuracy: 0.9949
#
# Epoch 00083: val_loss did not improve from 0.00635
# Epoch 84/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.0345 - val_accuracy: 0.9957
#
# Epoch 00084: val_loss did not improve from 0.00635
# Epoch 85/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0331 - val_accuracy: 0.9945
#
# Epoch 00085: val_loss did not improve from 0.00635
# Epoch 86/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.0149 - val_accuracy: 0.9961
#
# Epoch 00086: val_loss did not improve from 0.00635
# Epoch 87/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.0637 - val_accuracy: 0.9945
#
# Epoch 00087: val_loss did not improve from 0.00635
# Epoch 88/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0042 - accuracy: 0.9979 - val_loss: 0.0499 - val_accuracy: 0.9945
#
# Epoch 00088: val_loss did not improve from 0.00635
# Epoch 89/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0087 - val_accuracy: 0.9969
#
# Epoch 00089: val_loss did not improve from 0.00635
# Epoch 90/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0038 - accuracy: 0.9979 - val_loss: 0.0195 - val_accuracy: 0.9969
#
# Epoch 00090: val_loss did not improve from 0.00635
# Epoch 91/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9969 - val_loss: 0.0119 - val_accuracy: 0.9953
#
# Epoch 00091: val_loss did not improve from 0.00635
# Epoch 92/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.0083 - val_accuracy: 0.9961
#
# Epoch 00092: val_loss did not improve from 0.00635
# Epoch 93/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0055 - accuracy: 0.9974 - val_loss: 0.0215 - val_accuracy: 0.9965
#
# Epoch 00093: val_loss did not improve from 0.00635
# Epoch 94/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0034 - accuracy: 0.9982 - val_loss: 0.0462 - val_accuracy: 0.9969
#
# Epoch 00094: val_loss did not improve from 0.00635
# Epoch 95/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0049 - accuracy: 0.9974 - val_loss: 0.0580 - val_accuracy: 0.9937
#
# Epoch 00095: val_loss did not improve from 0.00635
# Epoch 96/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0046 - accuracy: 0.9976 - val_loss: 0.0558 - val_accuracy: 0.9965
#
# Epoch 00096: val_loss did not improve from 0.00635
# Epoch 97/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0042 - accuracy: 0.9977 - val_loss: 0.0224 - val_accuracy: 0.9965
#
# Epoch 00097: val_loss did not improve from 0.00635
# Epoch 98/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.0609 - val_accuracy: 0.9895
#
# Epoch 00098: val_loss did not improve from 0.00635
# Epoch 99/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0044 - accuracy: 0.9975 - val_loss: 0.0434 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00635
# Epoch 100/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0045 - accuracy: 0.9976 - val_loss: 0.0400 - val_accuracy: 0.9973
#
# Epoch 00100: val_loss did not improve from 0.00635
# 80/80 [==============================] - 1s 4ms/step - loss: 0.0400 - accuracy: 0.9973
# Val Score:  [0.039966173470020294, 0.997265636920929]
# Training on Fold:  3
# Epoch 1/100
# 160/160 [==============================] - 3s 13ms/step - loss: 0.3960 - accuracy: 0.8739 - val_loss: 1.8376 - val_accuracy: 0.3660
#
# Epoch 00001: val_loss did not improve from 0.00635
# Epoch 2/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.1268 - accuracy: 0.9551 - val_loss: 4.4572 - val_accuracy: 0.5125
#
# Epoch 00002: val_loss did not improve from 0.00635
# Epoch 3/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0942 - accuracy: 0.9707 - val_loss: 3.1311 - val_accuracy: 0.5348
#
# Epoch 00003: val_loss did not improve from 0.00635
# Epoch 4/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0614 - accuracy: 0.9791 - val_loss: 1.6382 - val_accuracy: 0.7258
#
# Epoch 00004: val_loss did not improve from 0.00635
# Epoch 5/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0639 - accuracy: 0.9797 - val_loss: 0.7423 - val_accuracy: 0.8441
#
# Epoch 00005: val_loss did not improve from 0.00635
# Epoch 6/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0478 - accuracy: 0.9840 - val_loss: 0.7093 - val_accuracy: 0.8480
#
# Epoch 00006: val_loss did not improve from 0.00635
# Epoch 7/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0383 - accuracy: 0.9895 - val_loss: 0.3353 - val_accuracy: 0.9102
#
# Epoch 00007: val_loss did not improve from 0.00635
# Epoch 8/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0338 - accuracy: 0.9911 - val_loss: 0.4238 - val_accuracy: 0.8957
#
# Epoch 00008: val_loss did not improve from 0.00635
# Epoch 9/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0240 - accuracy: 0.9916 - val_loss: 0.1405 - val_accuracy: 0.9527
#
# Epoch 00009: val_loss did not improve from 0.00635
# Epoch 10/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0265 - accuracy: 0.9916 - val_loss: 0.1009 - val_accuracy: 0.9684
#
# Epoch 00010: val_loss did not improve from 0.00635
# Epoch 11/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.2023 - val_accuracy: 0.9438
#
# Epoch 00011: val_loss did not improve from 0.00635
# Epoch 12/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0168 - accuracy: 0.9944 - val_loss: 0.0536 - val_accuracy: 0.9809
#
# Epoch 00012: val_loss did not improve from 0.00635
# Epoch 13/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0173 - accuracy: 0.9938 - val_loss: 0.1143 - val_accuracy: 0.9617
#
# Epoch 00013: val_loss did not improve from 0.00635
# Epoch 14/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.0705 - val_accuracy: 0.9758
#
# Epoch 00014: val_loss did not improve from 0.00635
# Epoch 15/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0155 - accuracy: 0.9942 - val_loss: 0.1142 - val_accuracy: 0.9641
#
# Epoch 00015: val_loss did not improve from 0.00635
# Epoch 16/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0957 - val_accuracy: 0.9730
#
# Epoch 00016: val_loss did not improve from 0.00635
# Epoch 17/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.1050 - val_accuracy: 0.9676
#
# Epoch 00017: val_loss did not improve from 0.00635
# Epoch 18/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0171 - accuracy: 0.9937 - val_loss: 0.1509 - val_accuracy: 0.9594
#
# Epoch 00018: val_loss did not improve from 0.00635
# Epoch 19/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.0719 - val_accuracy: 0.9793
#
# Epoch 00019: val_loss did not improve from 0.00635
# Epoch 20/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 0.0746 - val_accuracy: 0.9754
#
# Epoch 00020: val_loss did not improve from 0.00635
# Epoch 21/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 0.0373 - val_accuracy: 0.9887
#
# Epoch 00021: val_loss did not improve from 0.00635
# Epoch 22/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.1949 - val_accuracy: 0.9527
#
# Epoch 00022: val_loss did not improve from 0.00635
# Epoch 23/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0321 - val_accuracy: 0.9910
#
# Epoch 00023: val_loss did not improve from 0.00635
# Epoch 24/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0555 - val_accuracy: 0.9852
#
# Epoch 00024: val_loss did not improve from 0.00635
# Epoch 25/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0092 - accuracy: 0.9963 - val_loss: 0.0317 - val_accuracy: 0.9875
#
# Epoch 00025: val_loss did not improve from 0.00635
# Epoch 26/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.0416 - val_accuracy: 0.9859
#
# Epoch 00026: val_loss did not improve from 0.00635
# Epoch 27/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0499 - val_accuracy: 0.9832
#
# Epoch 00027: val_loss did not improve from 0.00635
# Epoch 28/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0345 - val_accuracy: 0.9898
#
# Epoch 00028: val_loss did not improve from 0.00635
# Epoch 29/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0086 - accuracy: 0.9967 - val_loss: 0.0669 - val_accuracy: 0.9785
#
# Epoch 00029: val_loss did not improve from 0.00635
# Epoch 30/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0083 - accuracy: 0.9964 - val_loss: 0.0381 - val_accuracy: 0.9883
#
# Epoch 00030: val_loss did not improve from 0.00635
# Epoch 31/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.0522 - val_accuracy: 0.9816
#
# Epoch 00031: val_loss did not improve from 0.00635
# Epoch 32/100
# 160/160 [==============================] - 2s 12ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0541 - val_accuracy: 0.9840
#
# Epoch 00032: val_loss did not improve from 0.00635
# Epoch 33/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0114 - accuracy: 0.9955 - val_loss: 0.0464 - val_accuracy: 0.9844
#
# Epoch 00033: val_loss did not improve from 0.00635
# Epoch 34/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0270 - val_accuracy: 0.9937
#
# Epoch 00034: val_loss did not improve from 0.00635
# Epoch 35/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0071 - accuracy: 0.9967 - val_loss: 0.0431 - val_accuracy: 0.9902
#
# Epoch 00035: val_loss did not improve from 0.00635
# Epoch 36/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.0253 - val_accuracy: 0.9926
#
# Epoch 00036: val_loss did not improve from 0.00635
# Epoch 37/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0089 - accuracy: 0.9964 - val_loss: 0.0255 - val_accuracy: 0.9941
#
# Epoch 00037: val_loss did not improve from 0.00635
# Epoch 38/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0085 - accuracy: 0.9968 - val_loss: 0.0389 - val_accuracy: 0.9855
#
# Epoch 00038: val_loss did not improve from 0.00635
# Epoch 39/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0357 - val_accuracy: 0.9926
#
# Epoch 00039: val_loss did not improve from 0.00635
# Epoch 40/100
# ...
#
# Epoch 00021: val_loss did not improve from 0.00401
# Epoch 22/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.1407 - val_accuracy: 0.9570
#
# Epoch 00022: val_loss did not improve from 0.00401
# Epoch 23/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0116 - accuracy: 0.9954 - val_loss: 0.2745 - val_accuracy: 0.9387
#
# Epoch 00023: val_loss did not improve from 0.00401
# Epoch 24/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0525 - val_accuracy: 0.9844
#
# Epoch 00024: val_loss did not improve from 0.00401
# Epoch 25/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.1502 - val_accuracy: 0.9613
#
# Epoch 00025: val_loss did not improve from 0.00401
# Epoch 26/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0104 - accuracy: 0.9960 - val_loss: 0.0710 - val_accuracy: 0.9809
#
# Epoch 00026: val_loss did not improve from 0.00401
# Epoch 27/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.2174 - val_accuracy: 0.9434
#
# Epoch 00027: val_loss did not improve from 0.00401
# Epoch 28/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0088 - accuracy: 0.9960 - val_loss: 0.0310 - val_accuracy: 0.9895
#
# Epoch 00028: val_loss did not improve from 0.00401
# Epoch 29/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0100 - accuracy: 0.9962 - val_loss: 0.0860 - val_accuracy: 0.9762
#
# Epoch 00029: val_loss did not improve from 0.00401
# Epoch 30/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.1009 - val_accuracy: 0.9711
#
# Epoch 00030: val_loss did not improve from 0.00401
# Epoch 31/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0765 - val_accuracy: 0.9777
#
# Epoch 00031: val_loss did not improve from 0.00401
# Epoch 32/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0086 - accuracy: 0.9964 - val_loss: 0.1419 - val_accuracy: 0.9613
#
# Epoch 00032: val_loss did not improve from 0.00401
# Epoch 33/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0776 - val_accuracy: 0.9766
#
# Epoch 00033: val_loss did not improve from 0.00401
# Epoch 34/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.1024 - val_accuracy: 0.9754
#
# Epoch 00034: val_loss did not improve from 0.00401
# Epoch 35/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0074 - accuracy: 0.9967 - val_loss: 0.1001 - val_accuracy: 0.9746
#
# Epoch 00035: val_loss did not improve from 0.00401
# Epoch 36/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0089 - accuracy: 0.9963 - val_loss: 0.0369 - val_accuracy: 0.9898
#
# Epoch 00036: val_loss did not improve from 0.00401
# Epoch 37/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0069 - accuracy: 0.9970 - val_loss: 0.1224 - val_accuracy: 0.9680
#
# Epoch 00037: val_loss did not improve from 0.00401
# Epoch 38/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0089 - accuracy: 0.9965 - val_loss: 0.0633 - val_accuracy: 0.9848
#
# Epoch 00038: val_loss did not improve from 0.00401
# Epoch 39/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0471 - val_accuracy: 0.9891
#
# Epoch 00039: val_loss did not improve from 0.00401
# Epoch 40/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0079 - accuracy: 0.9966 - val_loss: 0.1128 - val_accuracy: 0.9793
#
# Epoch 00040: val_loss did not improve from 0.00401
# Epoch 41/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0074 - accuracy: 0.9966 - val_loss: 0.0212 - val_accuracy: 0.9957
#
# Epoch 00041: val_loss did not improve from 0.00401
# Epoch 42/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0049 - accuracy: 0.9976 - val_loss: 0.0239 - val_accuracy: 0.9926
#
# Epoch 00042: val_loss did not improve from 0.00401
# Epoch 43/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0202 - val_accuracy: 0.9941
#
# Epoch 00043: val_loss did not improve from 0.00401
# Epoch 44/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0076 - accuracy: 0.9963 - val_loss: 0.0993 - val_accuracy: 0.9777
#
# Epoch 00044: val_loss did not improve from 0.00401
# Epoch 45/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.0826 - val_accuracy: 0.9832
#
# Epoch 00045: val_loss did not improve from 0.00401
# Epoch 46/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0048 - accuracy: 0.9980 - val_loss: 0.0245 - val_accuracy: 0.9945
#
# Epoch 00046: val_loss did not improve from 0.00401
# Epoch 47/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.0378 - val_accuracy: 0.9926
#
# Epoch 00047: val_loss did not improve from 0.00401
# Epoch 48/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0510 - val_accuracy: 0.9926
#
# Epoch 00048: val_loss did not improve from 0.00401
# Epoch 49/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0047 - accuracy: 0.9978 - val_loss: 0.0317 - val_accuracy: 0.9910
#
# Epoch 00049: val_loss did not improve from 0.00401
# Epoch 50/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0051 - accuracy: 0.9975 - val_loss: 0.0307 - val_accuracy: 0.9937
#
# Epoch 00050: val_loss did not improve from 0.00401
# Epoch 51/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0576 - val_accuracy: 0.9855
#
# Epoch 00051: val_loss did not improve from 0.00401
# Epoch 52/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.0159 - val_accuracy: 0.9957
#
# Epoch 00052: val_loss did not improve from 0.00401
# Epoch 53/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0084 - accuracy: 0.9962 - val_loss: 0.0183 - val_accuracy: 0.9957
#
# Epoch 00053: val_loss did not improve from 0.00401
# Epoch 54/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0658 - val_accuracy: 0.9824
#
# Epoch 00054: val_loss did not improve from 0.00401
# Epoch 55/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0066 - accuracy: 0.9972 - val_loss: 0.0284 - val_accuracy: 0.9937
#
# Epoch 00055: val_loss did not improve from 0.00401
# Epoch 56/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0053 - accuracy: 0.9976 - val_loss: 0.0275 - val_accuracy: 0.9945
#
# Epoch 00056: val_loss did not improve from 0.00401
# Epoch 57/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0043 - accuracy: 0.9979 - val_loss: 0.0237 - val_accuracy: 0.9941
#
# Epoch 00057: val_loss did not improve from 0.00401
# Epoch 58/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0061 - accuracy: 0.9970 - val_loss: 0.0607 - val_accuracy: 0.9832
#
# Epoch 00058: val_loss did not improve from 0.00401
# Epoch 59/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0057 - accuracy: 0.9973 - val_loss: 0.0120 - val_accuracy: 0.9969
#
# Epoch 00059: val_loss did not improve from 0.00401
# Epoch 60/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0059 - accuracy: 0.9971 - val_loss: 0.0362 - val_accuracy: 0.9937
#
# Epoch 00060: val_loss did not improve from 0.00401
# Epoch 61/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0076 - accuracy: 0.9964 - val_loss: 0.0240 - val_accuracy: 0.9926
#
# Epoch 00061: val_loss did not improve from 0.00401
# Epoch 62/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0047 - accuracy: 0.9979 - val_loss: 0.0105 - val_accuracy: 0.9969
#
# Epoch 00062: val_loss did not improve from 0.00401
# Epoch 63/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0062 - accuracy: 0.9963 - val_loss: 0.0117 - val_accuracy: 0.9973
#
# Epoch 00063: val_loss did not improve from 0.00401
# Epoch 64/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0076 - accuracy: 0.9968 - val_loss: 0.1442 - val_accuracy: 0.9750
#
# Epoch 00064: val_loss did not improve from 0.00401
# Epoch 65/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.0091 - val_accuracy: 0.9969
#
# Epoch 00065: val_loss did not improve from 0.00401
# Epoch 66/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 0.0142 - val_accuracy: 0.9965
#
# Epoch 00066: val_loss did not improve from 0.00401
# Epoch 67/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 0.0125 - val_accuracy: 0.9961
#
# Epoch 00067: val_loss did not improve from 0.00401
# Epoch 68/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0054 - accuracy: 0.9976 - val_loss: 0.0122 - val_accuracy: 0.9973
#
# Epoch 00068: val_loss did not improve from 0.00401
# Epoch 69/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0042 - accuracy: 0.9982 - val_loss: 0.0084 - val_accuracy: 0.9980
#
# Epoch 00069: val_loss did not improve from 0.00401
# Epoch 70/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0037 - accuracy: 0.9983 - val_loss: 0.0112 - val_accuracy: 0.9973
#
# Epoch 00070: val_loss did not improve from 0.00401
# Epoch 71/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0045 - accuracy: 0.9976 - val_loss: 0.0088 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00401
# Epoch 72/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0080 - accuracy: 0.9967 - val_loss: 0.1119 - val_accuracy: 0.9840
#
# Epoch 00072: val_loss did not improve from 0.00401
# Epoch 73/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 0.0173 - val_accuracy: 0.9957
#
# Epoch 00073: val_loss did not improve from 0.00401
# Epoch 74/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.0149 - val_accuracy: 0.9965
#
# Epoch 00074: val_loss did not improve from 0.00401
# Epoch 75/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0058 - accuracy: 0.9972 - val_loss: 0.0203 - val_accuracy: 0.9949
#
# Epoch 00075: val_loss did not improve from 0.00401
# Epoch 76/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0051 - accuracy: 0.9975 - val_loss: 0.0114 - val_accuracy: 0.9977
#
# Epoch 00076: val_loss did not improve from 0.00401
# Epoch 77/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.0254 - val_accuracy: 0.9930
#
# Epoch 00077: val_loss did not improve from 0.00401
# Epoch 78/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0046 - accuracy: 0.9975 - val_loss: 0.0127 - val_accuracy: 0.9969
#
# Epoch 00078: val_loss did not improve from 0.00401
# Epoch 79/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0065 - accuracy: 0.9970 - val_loss: 0.0112 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00401
# Epoch 80/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0051 - accuracy: 0.9974 - val_loss: 0.0934 - val_accuracy: 0.9801
#
# Epoch 00080: val_loss did not improve from 0.00401
# Epoch 81/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0052 - accuracy: 0.9973 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00081: val_loss improved from 0.00401 to 0.00238, saving model to model.h5
# Epoch 82/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.0108 - val_accuracy: 0.9973
#
# Epoch 00082: val_loss did not improve from 0.00238
# Epoch 83/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.0097 - val_accuracy: 0.9980
#
# Epoch 00083: val_loss did not improve from 0.00238
# Epoch 84/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0114 - val_accuracy: 0.9977
#
# Epoch 00084: val_loss did not improve from 0.00238
# Epoch 85/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0036 - accuracy: 0.9980 - val_loss: 0.0141 - val_accuracy: 0.9973
#
# Epoch 00085: val_loss did not improve from 0.00238
# Epoch 86/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0047 - accuracy: 0.9978 - val_loss: 0.0177 - val_accuracy: 0.9953
#
# Epoch 00086: val_loss did not improve from 0.00238
# Epoch 87/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0039 - accuracy: 0.9977 - val_loss: 0.0070 - val_accuracy: 0.9977
#
# Epoch 00087: val_loss did not improve from 0.00238
# Epoch 88/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0040 - accuracy: 0.9981 - val_loss: 0.0082 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00238
# Epoch 89/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0157 - val_accuracy: 0.9969
#
# Epoch 00089: val_loss did not improve from 0.00238
# Epoch 90/100
# 160/160 [==============================] - 2s 11ms/step - loss: 0.0041 - accuracy: 0.9977 - val_loss: 0.0099 - val_accuracy: 0.9977
#
# Epoch 00090: val_loss did not improve from 0.00238
# Epoch 91/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0035 - accuracy: 0.9978 - val_loss: 0.0087 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00238
# Epoch 92/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0047 - accuracy: 0.9976 - val_loss: 0.0258 - val_accuracy: 0.9953
#
# Epoch 00092: val_loss did not improve from 0.00238
# Epoch 93/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0037 - accuracy: 0.9979 - val_loss: 0.0064 - val_accuracy: 0.9977
#
# Epoch 00093: val_loss did not improve from 0.00238
# Epoch 94/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0356 - val_accuracy: 0.9910
#
# Epoch 00094: val_loss did not improve from 0.00238
# Epoch 95/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0047 - accuracy: 0.9981 - val_loss: 0.0173 - val_accuracy: 0.9953
#
# Epoch 00095: val_loss did not improve from 0.00238
# Epoch 96/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0051 - accuracy: 0.9977 - val_loss: 0.0190 - val_accuracy: 0.9961
#
# Epoch 00096: val_loss did not improve from 0.00238
# Epoch 97/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0062 - accuracy: 0.9970 - val_loss: 0.0222 - val_accuracy: 0.9941
#
# Epoch 00097: val_loss did not improve from 0.00238
# Epoch 98/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 0.0102 - val_accuracy: 0.9973
#
# Epoch 00098: val_loss did not improve from 0.00238
# Epoch 99/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0049 - accuracy: 0.9973 - val_loss: 0.0117 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00238
# Epoch 100/100
# 160/160 [==============================] - 2s 10ms/step - loss: 0.0042 - accuracy: 0.9977 - val_loss: 0.0356 - val_accuracy: 0.9918
#
# Epoch 00100: val_loss did not improve from 0.00238
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0356 - accuracy: 0.9918
# Val Score:  [0.035579126328229904, 0.9917968511581421]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 3ms/step - loss: 0.0081 - accuracy: 0.9959
# Test Accuracy: 99.59375262260437

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
