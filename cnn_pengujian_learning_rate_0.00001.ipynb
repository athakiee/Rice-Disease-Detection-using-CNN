# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **LEARNING RATE TEST 0.00001 -- USING ADAM AND BEST RESULT OF HIDDEN LAYER(4)**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-5
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_72 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_108 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_109 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_91 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_110 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_92 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_111 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_93 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_36 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_112 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_37 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_113 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.9829 - accuracy: 0.6550 - val_loss: 1.5193 - val_accuracy: 0.4605
#
# Epoch 00001: val_loss improved from inf to 1.51926, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.5195 - accuracy: 0.8139 - val_loss: 0.3918 - val_accuracy: 0.8477
#
# Epoch 00002: val_loss improved from 1.51926 to 0.39182, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.3948 - accuracy: 0.8572 - val_loss: 0.2400 - val_accuracy: 0.9082
#
# Epoch 00003: val_loss improved from 0.39182 to 0.24004, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.3171 - accuracy: 0.8878 - val_loss: 0.2038 - val_accuracy: 0.9234
#
# Epoch 00004: val_loss improved from 0.24004 to 0.20383, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2628 - accuracy: 0.9050 - val_loss: 0.1692 - val_accuracy: 0.9371
#
# Epoch 00005: val_loss improved from 0.20383 to 0.16920, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.2247 - accuracy: 0.9192 - val_loss: 0.1449 - val_accuracy: 0.9395
#
# Epoch 00006: val_loss improved from 0.16920 to 0.14490, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2007 - accuracy: 0.9281 - val_loss: 0.1283 - val_accuracy: 0.9508
#
# Epoch 00007: val_loss improved from 0.14490 to 0.12827, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1829 - accuracy: 0.9330 - val_loss: 0.1313 - val_accuracy: 0.9516
#
# Epoch 00008: val_loss did not improve from 0.12827
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1610 - accuracy: 0.9423 - val_loss: 0.1472 - val_accuracy: 0.9391
#
# Epoch 00009: val_loss did not improve from 0.12827
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1410 - accuracy: 0.9482 - val_loss: 0.1742 - val_accuracy: 0.9312
#
# Epoch 00010: val_loss did not improve from 0.12827
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1285 - accuracy: 0.9527 - val_loss: 0.1847 - val_accuracy: 0.9285
#
# Epoch 00011: val_loss did not improve from 0.12827
# Epoch 12/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.1236 - accuracy: 0.9552 - val_loss: 0.0944 - val_accuracy: 0.9668
#
# Epoch 00012: val_loss improved from 0.12827 to 0.09439, saving model to model.h5
# Epoch 13/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1132 - accuracy: 0.9585 - val_loss: 0.1111 - val_accuracy: 0.9609
#
# Epoch 00013: val_loss did not improve from 0.09439
# Epoch 14/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1040 - accuracy: 0.9622 - val_loss: 0.1510 - val_accuracy: 0.9465
#
# Epoch 00014: val_loss did not improve from 0.09439
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0971 - accuracy: 0.9657 - val_loss: 0.1214 - val_accuracy: 0.9574
#
# Epoch 00015: val_loss did not improve from 0.09439
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0865 - accuracy: 0.9673 - val_loss: 0.1268 - val_accuracy: 0.9539
#
# Epoch 00016: val_loss did not improve from 0.09439
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0826 - accuracy: 0.9691 - val_loss: 0.1534 - val_accuracy: 0.9484
#
# Epoch 00017: val_loss did not improve from 0.09439
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0704 - accuracy: 0.9755 - val_loss: 0.1348 - val_accuracy: 0.9496
#
# Epoch 00018: val_loss did not improve from 0.09439
# Epoch 19/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0786 - accuracy: 0.9723 - val_loss: 0.1028 - val_accuracy: 0.9648
#
# Epoch 00019: val_loss did not improve from 0.09439
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0685 - accuracy: 0.9769 - val_loss: 0.1144 - val_accuracy: 0.9602
#
# Epoch 00020: val_loss did not improve from 0.09439
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0652 - accuracy: 0.9778 - val_loss: 0.0972 - val_accuracy: 0.9648
#
# Epoch 00021: val_loss did not improve from 0.09439
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0620 - accuracy: 0.9794 - val_loss: 0.0883 - val_accuracy: 0.9684
#
# Epoch 00022: val_loss improved from 0.09439 to 0.08831, saving model to model.h5
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0541 - accuracy: 0.9798 - val_loss: 0.1601 - val_accuracy: 0.9465
#
# Epoch 00023: val_loss did not improve from 0.08831
# Epoch 24/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0568 - accuracy: 0.9797 - val_loss: 0.1358 - val_accuracy: 0.9547
#
# Epoch 00024: val_loss did not improve from 0.08831
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0543 - accuracy: 0.9802 - val_loss: 0.0867 - val_accuracy: 0.9691
#
# Epoch 00025: val_loss improved from 0.08831 to 0.08666, saving model to model.h5
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0498 - accuracy: 0.9835 - val_loss: 0.1289 - val_accuracy: 0.9539
#
# Epoch 00026: val_loss did not improve from 0.08666
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0503 - accuracy: 0.9814 - val_loss: 0.0952 - val_accuracy: 0.9652
#
# Epoch 00027: val_loss did not improve from 0.08666
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0461 - accuracy: 0.9847 - val_loss: 0.1352 - val_accuracy: 0.9563
#
# Epoch 00028: val_loss did not improve from 0.08666
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0458 - accuracy: 0.9860 - val_loss: 0.0736 - val_accuracy: 0.9750
#
# Epoch 00029: val_loss improved from 0.08666 to 0.07359, saving model to model.h5
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0446 - accuracy: 0.9852 - val_loss: 0.0954 - val_accuracy: 0.9668
#
# Epoch 00030: val_loss did not improve from 0.07359
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0389 - accuracy: 0.9856 - val_loss: 0.0744 - val_accuracy: 0.9715
#
# Epoch 00031: val_loss did not improve from 0.07359
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0393 - accuracy: 0.9864 - val_loss: 0.0882 - val_accuracy: 0.9719
#
# Epoch 00032: val_loss did not improve from 0.07359
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0442 - accuracy: 0.9857 - val_loss: 0.0996 - val_accuracy: 0.9664
#
# Epoch 00033: val_loss did not improve from 0.07359
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0381 - accuracy: 0.9874 - val_loss: 0.0666 - val_accuracy: 0.9758
#
# Epoch 00034: val_loss improved from 0.07359 to 0.06659, saving model to model.h5
# Epoch 35/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0371 - accuracy: 0.9872 - val_loss: 0.0675 - val_accuracy: 0.9777
#
# Epoch 00035: val_loss did not improve from 0.06659
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0334 - accuracy: 0.9893 - val_loss: 0.0656 - val_accuracy: 0.9754
#
# Epoch 00036: val_loss improved from 0.06659 to 0.06562, saving model to model.h5
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.0488 - val_accuracy: 0.9816
#
# Epoch 00037: val_loss improved from 0.06562 to 0.04881, saving model to model.h5
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0329 - accuracy: 0.9900 - val_loss: 0.0574 - val_accuracy: 0.9781
#
# Epoch 00038: val_loss did not improve from 0.04881
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0309 - accuracy: 0.9908 - val_loss: 0.0623 - val_accuracy: 0.9746
#
# Epoch 00039: val_loss did not improve from 0.04881
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0259 - accuracy: 0.9909 - val_loss: 0.0464 - val_accuracy: 0.9820
#
# Epoch 00040: val_loss improved from 0.04881 to 0.04644, saving model to model.h5
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0278 - accuracy: 0.9910 - val_loss: 0.0454 - val_accuracy: 0.9832
#
# Epoch 00041: val_loss improved from 0.04644 to 0.04537, saving model to model.h5
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0294 - accuracy: 0.9903 - val_loss: 0.0717 - val_accuracy: 0.9762
#
# Epoch 00042: val_loss did not improve from 0.04537
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0300 - accuracy: 0.9901 - val_loss: 0.0493 - val_accuracy: 0.9809
#
# Epoch 00043: val_loss did not improve from 0.04537
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0285 - accuracy: 0.9922 - val_loss: 0.0630 - val_accuracy: 0.9777
#
# Epoch 00044: val_loss did not improve from 0.04537
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0264 - accuracy: 0.9912 - val_loss: 0.0387 - val_accuracy: 0.9852
#
# Epoch 00045: val_loss improved from 0.04537 to 0.03871, saving model to model.h5
# Epoch 46/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0235 - accuracy: 0.9917 - val_loss: 0.0660 - val_accuracy: 0.9750
#
# Epoch 00046: val_loss did not improve from 0.03871
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0217 - accuracy: 0.9928 - val_loss: 0.0666 - val_accuracy: 0.9750
#
# Epoch 00047: val_loss did not improve from 0.03871
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 0.0622 - val_accuracy: 0.9785
#
# Epoch 00048: val_loss did not improve from 0.03871
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0209 - accuracy: 0.9942 - val_loss: 0.0493 - val_accuracy: 0.9828
#
# Epoch 00049: val_loss did not improve from 0.03871
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0218 - accuracy: 0.9931 - val_loss: 0.0449 - val_accuracy: 0.9824
#
# Epoch 00050: val_loss did not improve from 0.03871
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0215 - accuracy: 0.9921 - val_loss: 0.0743 - val_accuracy: 0.9730
#
# Epoch 00051: val_loss did not improve from 0.03871
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0274 - accuracy: 0.9901 - val_loss: 0.0610 - val_accuracy: 0.9789
#
# Epoch 00052: val_loss did not improve from 0.03871
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0541 - val_accuracy: 0.9812
#
# Epoch 00053: val_loss did not improve from 0.03871
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0206 - accuracy: 0.9943 - val_loss: 0.0651 - val_accuracy: 0.9793
#
# Epoch 00054: val_loss did not improve from 0.03871
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0216 - accuracy: 0.9940 - val_loss: 0.0371 - val_accuracy: 0.9867
#
# Epoch 00055: val_loss improved from 0.03871 to 0.03711, saving model to model.h5
# Epoch 56/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0215 - accuracy: 0.9936 - val_loss: 0.0619 - val_accuracy: 0.9777
#
# Epoch 00056: val_loss did not improve from 0.03711
# Epoch 57/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0177 - accuracy: 0.9942 - val_loss: 0.0532 - val_accuracy: 0.9801
#
# Epoch 00057: val_loss did not improve from 0.03711
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0202 - accuracy: 0.9929 - val_loss: 0.0558 - val_accuracy: 0.9797
#
# Epoch 00058: val_loss did not improve from 0.03711
# Epoch 59/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0208 - accuracy: 0.9937 - val_loss: 0.0340 - val_accuracy: 0.9887
#
# Epoch 00059: val_loss improved from 0.03711 to 0.03401, saving model to model.h5
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.0504 - val_accuracy: 0.9820
#
# Epoch 00060: val_loss did not improve from 0.03401
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.0379 - val_accuracy: 0.9867
#
# Epoch 00061: val_loss did not improve from 0.03401
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0188 - accuracy: 0.9936 - val_loss: 0.0603 - val_accuracy: 0.9793
#
# Epoch 00062: val_loss did not improve from 0.03401
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0193 - accuracy: 0.9934 - val_loss: 0.0483 - val_accuracy: 0.9844
#
# Epoch 00063: val_loss did not improve from 0.03401
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0166 - accuracy: 0.9955 - val_loss: 0.0655 - val_accuracy: 0.9801
#
# Epoch 00064: val_loss did not improve from 0.03401
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0516 - val_accuracy: 0.9832
#
# Epoch 00065: val_loss did not improve from 0.03401
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.0418 - val_accuracy: 0.9836
#
# Epoch 00066: val_loss did not improve from 0.03401
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.0278 - val_accuracy: 0.9898
#
# Epoch 00067: val_loss improved from 0.03401 to 0.02783, saving model to model.h5
# Epoch 68/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.0354 - val_accuracy: 0.9875
#
# Epoch 00068: val_loss did not improve from 0.02783
# Epoch 69/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0354 - val_accuracy: 0.9895
#
# Epoch 00069: val_loss did not improve from 0.02783
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.0346 - val_accuracy: 0.9871
#
# Epoch 00070: val_loss did not improve from 0.02783
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.0242 - val_accuracy: 0.9906
#
# Epoch 00071: val_loss improved from 0.02783 to 0.02425, saving model to model.h5
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0321 - val_accuracy: 0.9879
#
# Epoch 00072: val_loss did not improve from 0.02425
# Epoch 73/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.0697 - val_accuracy: 0.9777
#
# Epoch 00073: val_loss did not improve from 0.02425
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0231 - val_accuracy: 0.9930
#
# Epoch 00074: val_loss improved from 0.02425 to 0.02311, saving model to model.h5
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.0190 - val_accuracy: 0.9926
#
# Epoch 00075: val_loss improved from 0.02311 to 0.01896, saving model to model.h5
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 0.0350 - val_accuracy: 0.9875
#
# Epoch 00076: val_loss did not improve from 0.01896
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.0391 - val_accuracy: 0.9863
#
# Epoch 00077: val_loss did not improve from 0.01896
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0194 - val_accuracy: 0.9941
#
# Epoch 00078: val_loss did not improve from 0.01896
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0389 - val_accuracy: 0.9863
#
# Epoch 00079: val_loss did not improve from 0.01896
# Epoch 80/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0163 - accuracy: 0.9941 - val_loss: 0.0403 - val_accuracy: 0.9855
#
# Epoch 00080: val_loss did not improve from 0.01896
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.0268 - val_accuracy: 0.9902
#
# Epoch 00081: val_loss did not improve from 0.01896
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.0258 - val_accuracy: 0.9918
#
# Epoch 00082: val_loss did not improve from 0.01896
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.0224 - val_accuracy: 0.9922
#
# Epoch 00083: val_loss did not improve from 0.01896
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.0300 - val_accuracy: 0.9898
#
# Epoch 00084: val_loss did not improve from 0.01896
# Epoch 85/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0346 - val_accuracy: 0.9891
#
# Epoch 00085: val_loss did not improve from 0.01896
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.0245 - val_accuracy: 0.9914
#
# Epoch 00086: val_loss did not improve from 0.01896
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 0.0190 - val_accuracy: 0.9922
#
# Epoch 00087: val_loss did not improve from 0.01896
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.0533 - val_accuracy: 0.9824
#
# Epoch 00088: val_loss did not improve from 0.01896
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0224 - val_accuracy: 0.9914
#
# Epoch 00089: val_loss did not improve from 0.01896
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.0206 - val_accuracy: 0.9918
#
# Epoch 00090: val_loss did not improve from 0.01896
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.0188 - val_accuracy: 0.9922
#
# Epoch 00091: val_loss improved from 0.01896 to 0.01884, saving model to model.h5
# Epoch 92/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.0189 - val_accuracy: 0.9918
#
# Epoch 00092: val_loss did not improve from 0.01884
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.0292 - val_accuracy: 0.9895
#
# Epoch 00093: val_loss did not improve from 0.01884
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0276 - val_accuracy: 0.9902
#
# Epoch 00094: val_loss did not improve from 0.01884
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.0238 - val_accuracy: 0.9922
#
# Epoch 00095: val_loss did not improve from 0.01884
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0220 - val_accuracy: 0.9930
#
# Epoch 00096: val_loss did not improve from 0.01884
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0278 - val_accuracy: 0.9922
#
# Epoch 00097: val_loss did not improve from 0.01884
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0173 - val_accuracy: 0.9945
#
# Epoch 00098: val_loss improved from 0.01884 to 0.01734, saving model to model.h5
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.0346 - val_accuracy: 0.9879
#
# Epoch 00099: val_loss did not improve from 0.01734
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.0202 - val_accuracy: 0.9930
#
# Epoch 00100: val_loss did not improve from 0.01734
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9930
# Val Score:  [0.0201649758964777, 0.992968738079071]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.7309 - accuracy: 0.7523 - val_loss: 4.7320 - val_accuracy: 0.4715
#
# Epoch 00001: val_loss did not improve from 0.01734
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.4160 - accuracy: 0.8475 - val_loss: 0.9201 - val_accuracy: 0.7063
#
# Epoch 00002: val_loss did not improve from 0.01734
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.3381 - accuracy: 0.8815 - val_loss: 0.6525 - val_accuracy: 0.8051
#
# Epoch 00003: val_loss did not improve from 0.01734
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.2901 - accuracy: 0.8963 - val_loss: 0.6475 - val_accuracy: 0.8102
#
# Epoch 00004: val_loss did not improve from 0.01734
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.2435 - accuracy: 0.9102 - val_loss: 0.5609 - val_accuracy: 0.8387
#
# Epoch 00005: val_loss did not improve from 0.01734
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2249 - accuracy: 0.9187 - val_loss: 0.3915 - val_accuracy: 0.8758
#
# Epoch 00006: val_loss did not improve from 0.01734
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2008 - accuracy: 0.9271 - val_loss: 0.3915 - val_accuracy: 0.8758
#
# Epoch 00007: val_loss did not improve from 0.01734
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1873 - accuracy: 0.9344 - val_loss: 0.4537 - val_accuracy: 0.8652
#
# Epoch 00008: val_loss did not improve from 0.01734
# Epoch 9/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1740 - accuracy: 0.9361 - val_loss: 0.4537 - val_accuracy: 0.8680
#
# Epoch 00009: val_loss did not improve from 0.01734
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1466 - accuracy: 0.9468 - val_loss: 0.4595 - val_accuracy: 0.8707
#
# Epoch 00010: val_loss did not improve from 0.01734
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1484 - accuracy: 0.9464 - val_loss: 0.4333 - val_accuracy: 0.8699
#
# Epoch 00011: val_loss did not improve from 0.01734
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1356 - accuracy: 0.9489 - val_loss: 0.3458 - val_accuracy: 0.8914
#
# Epoch 00012: val_loss did not improve from 0.01734
# Epoch 13/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1344 - accuracy: 0.9523 - val_loss: 0.3958 - val_accuracy: 0.8801
#
# Epoch 00013: val_loss did not improve from 0.01734
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1135 - accuracy: 0.9587 - val_loss: 0.4193 - val_accuracy: 0.8773
#
# Epoch 00014: val_loss did not improve from 0.01734
# Epoch 15/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1107 - accuracy: 0.9604 - val_loss: 0.3792 - val_accuracy: 0.8836
#
# Epoch 00015: val_loss did not improve from 0.01734
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1096 - accuracy: 0.9601 - val_loss: 0.3361 - val_accuracy: 0.8961
#
# Epoch 00016: val_loss did not improve from 0.01734
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0956 - accuracy: 0.9649 - val_loss: 0.3949 - val_accuracy: 0.8793
#
# Epoch 00017: val_loss did not improve from 0.01734
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0867 - accuracy: 0.9679 - val_loss: 0.3854 - val_accuracy: 0.8855
#
# Epoch 00018: val_loss did not improve from 0.01734
# Epoch 19/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0962 - accuracy: 0.9649 - val_loss: 0.3701 - val_accuracy: 0.8945
#
# Epoch 00019: val_loss did not improve from 0.01734
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0836 - accuracy: 0.9711 - val_loss: 0.3458 - val_accuracy: 0.8926
#
# Epoch 00020: val_loss did not improve from 0.01734
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0788 - accuracy: 0.9703 - val_loss: 0.4261 - val_accuracy: 0.8840
#
# Epoch 00021: val_loss did not improve from 0.01734
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0866 - accuracy: 0.9682 - val_loss: 0.3612 - val_accuracy: 0.8984
#
# Epoch 00022: val_loss did not improve from 0.01734
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0728 - accuracy: 0.9748 - val_loss: 0.3229 - val_accuracy: 0.8965
#
# Epoch 00023: val_loss did not improve from 0.01734
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0648 - accuracy: 0.9751 - val_loss: 0.3771 - val_accuracy: 0.8883
#
# Epoch 00024: val_loss did not improve from 0.01734
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0706 - accuracy: 0.9751 - val_loss: 0.3616 - val_accuracy: 0.8879
#
# Epoch 00025: val_loss did not improve from 0.01734
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0644 - accuracy: 0.9751 - val_loss: 0.3421 - val_accuracy: 0.8934
#
# Epoch 00026: val_loss did not improve from 0.01734
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0612 - accuracy: 0.9777 - val_loss: 0.3431 - val_accuracy: 0.8957
#
# Epoch 00027: val_loss did not improve from 0.01734
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0673 - accuracy: 0.9761 - val_loss: 0.3299 - val_accuracy: 0.8980
#
# Epoch 00028: val_loss did not improve from 0.01734
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0523 - accuracy: 0.9809 - val_loss: 0.2726 - val_accuracy: 0.9184
#
# Epoch 00029: val_loss did not improve from 0.01734
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0533 - accuracy: 0.9819 - val_loss: 0.3479 - val_accuracy: 0.8953
#
# Epoch 00030: val_loss did not improve from 0.01734
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0517 - accuracy: 0.9815 - val_loss: 0.3971 - val_accuracy: 0.8852
#
# Epoch 00031: val_loss did not improve from 0.01734
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0569 - accuracy: 0.9807 - val_loss: 0.3750 - val_accuracy: 0.8930
#
# Epoch 00032: val_loss did not improve from 0.01734
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0466 - accuracy: 0.9844 - val_loss: 0.2789 - val_accuracy: 0.9148
#
# Epoch 00033: val_loss did not improve from 0.01734
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0511 - accuracy: 0.9812 - val_loss: 0.3216 - val_accuracy: 0.9078
#
# Epoch 00034: val_loss did not improve from 0.01734
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0440 - accuracy: 0.9853 - val_loss: 0.2641 - val_accuracy: 0.9223
#
# Epoch 00035: val_loss did not improve from 0.01734
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0484 - accuracy: 0.9836 - val_loss: 0.2221 - val_accuracy: 0.9328
#
# Epoch 00036: val_loss did not improve from 0.01734
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0428 - accuracy: 0.9847 - val_loss: 0.2635 - val_accuracy: 0.9199
#
# Epoch 00037: val_loss did not improve from 0.01734
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0413 - accuracy: 0.9853 - val_loss: 0.3461 - val_accuracy: 0.8980
#
# Epoch 00038: val_loss did not improve from 0.01734
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0474 - accuracy: 0.9843 - val_loss: 0.4123 - val_accuracy: 0.8844
#
# Epoch 00039: val_loss did not improve from 0.01734
# Epoch 40/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0376 - accuracy: 0.9866 - val_loss: 0.2229 - val_accuracy: 0.9336
#
# Epoch 00040: val_loss did not improve from 0.01734
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0390 - accuracy: 0.9872 - val_loss: 0.3393 - val_accuracy: 0.9059
#
# Epoch 00041: val_loss did not improve from 0.01734
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0375 - accuracy: 0.9875 - val_loss: 0.3563 - val_accuracy: 0.8988
#
# Epoch 00042: val_loss did not improve from 0.01734
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0392 - accuracy: 0.9856 - val_loss: 0.3180 - val_accuracy: 0.9078
#
# Epoch 00043: val_loss did not improve from 0.01734
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0342 - accuracy: 0.9884 - val_loss: 0.2565 - val_accuracy: 0.9250
#
# Epoch 00044: val_loss did not improve from 0.01734
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0314 - accuracy: 0.9892 - val_loss: 0.2974 - val_accuracy: 0.9129
#
# Epoch 00045: val_loss did not improve from 0.01734
# Epoch 46/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0347 - accuracy: 0.9883 - val_loss: 0.3101 - val_accuracy: 0.9102
#
# Epoch 00046: val_loss did not improve from 0.01734
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0342 - accuracy: 0.9891 - val_loss: 0.3138 - val_accuracy: 0.9102
#
# Epoch 00047: val_loss did not improve from 0.01734
# Epoch 48/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0297 - accuracy: 0.9902 - val_loss: 0.3045 - val_accuracy: 0.9109
#
# Epoch 00048: val_loss did not improve from 0.01734
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0336 - accuracy: 0.9890 - val_loss: 0.2698 - val_accuracy: 0.9215
#
# Epoch 00049: val_loss did not improve from 0.01734
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0282 - accuracy: 0.9909 - val_loss: 0.2543 - val_accuracy: 0.9281
#
# Epoch 00050: val_loss did not improve from 0.01734
# Epoch 51/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0292 - accuracy: 0.9897 - val_loss: 0.2188 - val_accuracy: 0.9340
#
# Epoch 00051: val_loss did not improve from 0.01734
# Epoch 52/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0300 - accuracy: 0.9897 - val_loss: 0.1933 - val_accuracy: 0.9414
#
# Epoch 00052: val_loss did not improve from 0.01734
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0300 - accuracy: 0.9906 - val_loss: 0.2284 - val_accuracy: 0.9340
#
# Epoch 00053: val_loss did not improve from 0.01734
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0257 - accuracy: 0.9908 - val_loss: 0.2301 - val_accuracy: 0.9293
#
# Epoch 00054: val_loss did not improve from 0.01734
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0281 - accuracy: 0.9901 - val_loss: 0.2118 - val_accuracy: 0.9355
#
# Epoch 00055: val_loss did not improve from 0.01734
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0282 - accuracy: 0.9913 - val_loss: 0.2363 - val_accuracy: 0.9309
#
# Epoch 00056: val_loss did not improve from 0.01734
# Epoch 57/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0262 - accuracy: 0.9913 - val_loss: 0.3304 - val_accuracy: 0.9102
#
# Epoch 00057: val_loss did not improve from 0.01734
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.2266 - val_accuracy: 0.9320
#
# Epoch 00058: val_loss did not improve from 0.01734
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0230 - accuracy: 0.9922 - val_loss: 0.2624 - val_accuracy: 0.9262
#
# Epoch 00059: val_loss did not improve from 0.01734
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0218 - accuracy: 0.9933 - val_loss: 0.2156 - val_accuracy: 0.9359
#
# Epoch 00060: val_loss did not improve from 0.01734
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0228 - accuracy: 0.9920 - val_loss: 0.1110 - val_accuracy: 0.9664
#
# Epoch 00061: val_loss did not improve from 0.01734
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0280 - accuracy: 0.9918 - val_loss: 0.1418 - val_accuracy: 0.9547
#
# Epoch 00062: val_loss did not improve from 0.01734
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 0.2213 - val_accuracy: 0.9363
#
# Epoch 00063: val_loss did not improve from 0.01734
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0199 - accuracy: 0.9924 - val_loss: 0.2349 - val_accuracy: 0.9328
#
# Epoch 00064: val_loss did not improve from 0.01734
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0231 - accuracy: 0.9926 - val_loss: 0.1991 - val_accuracy: 0.9395
#
# Epoch 00065: val_loss did not improve from 0.01734
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0170 - accuracy: 0.9937 - val_loss: 0.1973 - val_accuracy: 0.9371
#
# Epoch 00066: val_loss did not improve from 0.01734
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0220 - accuracy: 0.9933 - val_loss: 0.1778 - val_accuracy: 0.9488
#
# Epoch 00067: val_loss did not improve from 0.01734
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0209 - accuracy: 0.9934 - val_loss: 0.1828 - val_accuracy: 0.9496
#
# Epoch 00068: val_loss did not improve from 0.01734
# Epoch 69/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0192 - accuracy: 0.9931 - val_loss: 0.1283 - val_accuracy: 0.9605
#
# Epoch 00069: val_loss did not improve from 0.01734
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 0.1351 - val_accuracy: 0.9602
#
# Epoch 00070: val_loss did not improve from 0.01734
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.1525 - val_accuracy: 0.9598
#
# Epoch 00071: val_loss did not improve from 0.01734
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.1532 - val_accuracy: 0.9570
#
# Epoch 00072: val_loss did not improve from 0.01734
# Epoch 73/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 0.2563 - val_accuracy: 0.9305
#
# Epoch 00073: val_loss did not improve from 0.01734
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.1275 - val_accuracy: 0.9602
#
# Epoch 00074: val_loss did not improve from 0.01734
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.1479 - val_accuracy: 0.9566
#
# Epoch 00075: val_loss did not improve from 0.01734
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.1966 - val_accuracy: 0.9434
#
# Epoch 00076: val_loss did not improve from 0.01734
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0168 - accuracy: 0.9935 - val_loss: 0.2014 - val_accuracy: 0.9453
#
# Epoch 00077: val_loss did not improve from 0.01734
# Epoch 78/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0158 - accuracy: 0.9939 - val_loss: 0.2040 - val_accuracy: 0.9480
#
# Epoch 00078: val_loss did not improve from 0.01734
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.2330 - val_accuracy: 0.9375
#
# Epoch 00079: val_loss did not improve from 0.01734
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0156 - accuracy: 0.9949 - val_loss: 0.1594 - val_accuracy: 0.9563
#
# Epoch 00080: val_loss did not improve from 0.01734
# Epoch 81/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0159 - accuracy: 0.9955 - val_loss: 0.1158 - val_accuracy: 0.9672
#
# Epoch 00081: val_loss did not improve from 0.01734
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.1184 - val_accuracy: 0.9652
#
# Epoch 00082: val_loss did not improve from 0.01734
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.1162 - val_accuracy: 0.9645
#
# Epoch 00083: val_loss did not improve from 0.01734
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.1036 - val_accuracy: 0.9680
#
# Epoch 00084: val_loss did not improve from 0.01734
# Epoch 85/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0145 - accuracy: 0.9951 - val_loss: 0.0906 - val_accuracy: 0.9734
#
# Epoch 00085: val_loss did not improve from 0.01734
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.1040 - val_accuracy: 0.9652
#
# Epoch 00086: val_loss did not improve from 0.01734
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.1890 - val_accuracy: 0.9496
#
# Epoch 00087: val_loss did not improve from 0.01734
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 0.0924 - val_accuracy: 0.9699
#
# Epoch 00088: val_loss did not improve from 0.01734
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.1201 - val_accuracy: 0.9625
#
# Epoch 00089: val_loss did not improve from 0.01734
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.1112 - val_accuracy: 0.9680
#
# Epoch 00090: val_loss did not improve from 0.01734
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0126 - accuracy: 0.9952 - val_loss: 0.1632 - val_accuracy: 0.9543
#
# Epoch 00091: val_loss did not improve from 0.01734
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.1187 - val_accuracy: 0.9645
#
# Epoch 00092: val_loss did not improve from 0.01734
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.1782 - val_accuracy: 0.9500
#
# Epoch 00093: val_loss did not improve from 0.01734
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.1839 - val_accuracy: 0.9496
#
# Epoch 00094: val_loss did not improve from 0.01734
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.1923 - val_accuracy: 0.9504
#
# Epoch 00095: val_loss did not improve from 0.01734
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.1414 - val_accuracy: 0.9609
#
# Epoch 00096: val_loss did not improve from 0.01734
# Epoch 97/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.1204 - val_accuracy: 0.9660
#
# Epoch 00097: val_loss did not improve from 0.01734
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.1515 - val_accuracy: 0.9582
#
# Epoch 00098: val_loss did not improve from 0.01734
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.1596 - val_accuracy: 0.9547
#
# Epoch 00099: val_loss did not improve from 0.01734
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.1337 - val_accuracy: 0.9621
#
# Epoch 00100: val_loss did not improve from 0.01734
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1337 - accuracy: 0.9621
# Val Score:  [0.133681982755661, 0.962109386920929]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.6610 - accuracy: 0.7768 - val_loss: 3.8215 - val_accuracy: 0.4258
#
# Epoch 00001: val_loss did not improve from 0.01734
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.3938 - accuracy: 0.8615 - val_loss: 0.9986 - val_accuracy: 0.7063
#
# Epoch 00002: val_loss did not improve from 0.01734
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.3095 - accuracy: 0.8863 - val_loss: 0.4506 - val_accuracy: 0.8687
#
# Epoch 00003: val_loss did not improve from 0.01734
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2514 - accuracy: 0.9057 - val_loss: 0.5221 - val_accuracy: 0.8500
#
# Epoch 00004: val_loss did not improve from 0.01734
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.2178 - accuracy: 0.9222 - val_loss: 0.4160 - val_accuracy: 0.8762
#
# Epoch 00005: val_loss did not improve from 0.01734
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1965 - accuracy: 0.9289 - val_loss: 0.3902 - val_accuracy: 0.8816
#
# Epoch 00006: val_loss did not improve from 0.01734
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1839 - accuracy: 0.9333 - val_loss: 0.5094 - val_accuracy: 0.8684
#
# Epoch 00007: val_loss did not improve from 0.01734
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1514 - accuracy: 0.9438 - val_loss: 0.4248 - val_accuracy: 0.8828
#
# Epoch 00008: val_loss did not improve from 0.01734
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1382 - accuracy: 0.9508 - val_loss: 0.4462 - val_accuracy: 0.8871
#
# Epoch 00009: val_loss did not improve from 0.01734
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1315 - accuracy: 0.9531 - val_loss: 0.3455 - val_accuracy: 0.8988
#
# Epoch 00010: val_loss did not improve from 0.01734
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1101 - accuracy: 0.9587 - val_loss: 0.2442 - val_accuracy: 0.9187
#
# Epoch 00011: val_loss did not improve from 0.01734
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1157 - accuracy: 0.9581 - val_loss: 0.3382 - val_accuracy: 0.9059
#
# Epoch 00012: val_loss did not improve from 0.01734
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1002 - accuracy: 0.9649 - val_loss: 0.3318 - val_accuracy: 0.8992
#
# Epoch 00013: val_loss did not improve from 0.01734
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0953 - accuracy: 0.9677 - val_loss: 0.3262 - val_accuracy: 0.9051
#
# Epoch 00014: val_loss did not improve from 0.01734
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0904 - accuracy: 0.9677 - val_loss: 0.3640 - val_accuracy: 0.8992
#
# Epoch 00015: val_loss did not improve from 0.01734
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0908 - accuracy: 0.9671 - val_loss: 0.2551 - val_accuracy: 0.9184
#
# Epoch 00016: val_loss did not improve from 0.01734
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0812 - accuracy: 0.9696 - val_loss: 0.1825 - val_accuracy: 0.9445
#
# Epoch 00017: val_loss did not improve from 0.01734
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0751 - accuracy: 0.9730 - val_loss: 0.2065 - val_accuracy: 0.9352
#
# Epoch 00018: val_loss did not improve from 0.01734
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0759 - accuracy: 0.9736 - val_loss: 0.2172 - val_accuracy: 0.9336
#
# Epoch 00019: val_loss did not improve from 0.01734
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0741 - accuracy: 0.9730 - val_loss: 0.2123 - val_accuracy: 0.9367
#
# Epoch 00020: val_loss did not improve from 0.01734
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0691 - accuracy: 0.9759 - val_loss: 0.1383 - val_accuracy: 0.9555
#
# Epoch 00021: val_loss did not improve from 0.01734
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0576 - accuracy: 0.9804 - val_loss: 0.1472 - val_accuracy: 0.9563
#
# Epoch 00022: val_loss did not improve from 0.01734
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0534 - accuracy: 0.9804 - val_loss: 0.1554 - val_accuracy: 0.9523
#
# Epoch 00023: val_loss did not improve from 0.01734
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0537 - accuracy: 0.9803 - val_loss: 0.1602 - val_accuracy: 0.9457
#
# Epoch 00024: val_loss did not improve from 0.01734
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0512 - accuracy: 0.9820 - val_loss: 0.1330 - val_accuracy: 0.9555
#
# Epoch 00025: val_loss did not improve from 0.01734
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0514 - accuracy: 0.9831 - val_loss: 0.1209 - val_accuracy: 0.9613
#
# Epoch 00026: val_loss did not improve from 0.01734
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0412 - accuracy: 0.9845 - val_loss: 0.1080 - val_accuracy: 0.9660
#
# Epoch 00027: val_loss did not improve from 0.01734
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0441 - accuracy: 0.9853 - val_loss: 0.0992 - val_accuracy: 0.9699
#
# Epoch 00028: val_loss did not improve from 0.01734
# Epoch 29/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0488 - accuracy: 0.9838 - val_loss: 0.1164 - val_accuracy: 0.9602
#
# Epoch 00029: val_loss did not improve from 0.01734
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0387 - accuracy: 0.9867 - val_loss: 0.1093 - val_accuracy: 0.9625
#
# Epoch 00030: val_loss did not improve from 0.01734
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0385 - accuracy: 0.9872 - val_loss: 0.1000 - val_accuracy: 0.9684
#
# Epoch 00031: val_loss did not improve from 0.01734
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0378 - accuracy: 0.9873 - val_loss: 0.1174 - val_accuracy: 0.9621
#
# Epoch 00032: val_loss did not improve from 0.01734
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0373 - accuracy: 0.9865 - val_loss: 0.0829 - val_accuracy: 0.9746
#
# Epoch 00033: val_loss did not improve from 0.01734
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0325 - accuracy: 0.9890 - val_loss: 0.0766 - val_accuracy: 0.9730
#
# Epoch 00034: val_loss did not improve from 0.01734
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0296 - accuracy: 0.9908 - val_loss: 0.0884 - val_accuracy: 0.9711
#
# Epoch 00035: val_loss did not improve from 0.01734
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0267 - accuracy: 0.9909 - val_loss: 0.0649 - val_accuracy: 0.9777
#
# Epoch 00036: val_loss did not improve from 0.01734
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0300 - accuracy: 0.9896 - val_loss: 0.0773 - val_accuracy: 0.9734
#
# Epoch 00037: val_loss did not improve from 0.01734
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0275 - accuracy: 0.9901 - val_loss: 0.1024 - val_accuracy: 0.9648
#
# Epoch 00038: val_loss did not improve from 0.01734
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0334 - accuracy: 0.9896 - val_loss: 0.0582 - val_accuracy: 0.9809
#
# Epoch 00039: val_loss did not improve from 0.01734
# Epoch 40/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00996
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0789 - accuracy: 0.9719 - val_loss: 0.3200 - val_accuracy: 0.9008
#
# Epoch 00021: val_loss did not improve from 0.00996
# Epoch 22/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0674 - accuracy: 0.9767 - val_loss: 0.3053 - val_accuracy: 0.8945
#
# Epoch 00022: val_loss did not improve from 0.00996
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0615 - accuracy: 0.9777 - val_loss: 0.3006 - val_accuracy: 0.8977
#
# Epoch 00023: val_loss did not improve from 0.00996
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0631 - accuracy: 0.9801 - val_loss: 0.4396 - val_accuracy: 0.8637
#
# Epoch 00024: val_loss did not improve from 0.00996
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0621 - accuracy: 0.9781 - val_loss: 0.2786 - val_accuracy: 0.9047
#
# Epoch 00025: val_loss did not improve from 0.00996
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0578 - accuracy: 0.9803 - val_loss: 0.2945 - val_accuracy: 0.9102
#
# Epoch 00026: val_loss did not improve from 0.00996
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0590 - accuracy: 0.9798 - val_loss: 0.3668 - val_accuracy: 0.8949
#
# Epoch 00027: val_loss did not improve from 0.00996
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0539 - accuracy: 0.9833 - val_loss: 0.3181 - val_accuracy: 0.8996
#
# Epoch 00028: val_loss did not improve from 0.00996
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0500 - accuracy: 0.9835 - val_loss: 0.3654 - val_accuracy: 0.8852
#
# Epoch 00029: val_loss did not improve from 0.00996
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0523 - accuracy: 0.9826 - val_loss: 0.4094 - val_accuracy: 0.8910
#
# Epoch 00030: val_loss did not improve from 0.00996
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0489 - accuracy: 0.9845 - val_loss: 0.2853 - val_accuracy: 0.9121
#
# Epoch 00031: val_loss did not improve from 0.00996
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0458 - accuracy: 0.9845 - val_loss: 0.3152 - val_accuracy: 0.9082
#
# Epoch 00032: val_loss did not improve from 0.00996
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0405 - accuracy: 0.9866 - val_loss: 0.3412 - val_accuracy: 0.9117
#
# Epoch 00033: val_loss did not improve from 0.00996
# Epoch 34/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0420 - accuracy: 0.9862 - val_loss: 0.3109 - val_accuracy: 0.9133
#
# Epoch 00034: val_loss did not improve from 0.00996
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0434 - accuracy: 0.9857 - val_loss: 0.3995 - val_accuracy: 0.8922
#
# Epoch 00035: val_loss did not improve from 0.00996
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0367 - accuracy: 0.9882 - val_loss: 0.2529 - val_accuracy: 0.9262
#
# Epoch 00036: val_loss did not improve from 0.00996
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0369 - accuracy: 0.9869 - val_loss: 0.2949 - val_accuracy: 0.9133
#
# Epoch 00037: val_loss did not improve from 0.00996
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0359 - accuracy: 0.9866 - val_loss: 0.3974 - val_accuracy: 0.9020
#
# Epoch 00038: val_loss did not improve from 0.00996
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0371 - accuracy: 0.9882 - val_loss: 0.3285 - val_accuracy: 0.9133
#
# Epoch 00039: val_loss did not improve from 0.00996
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0342 - accuracy: 0.9876 - val_loss: 0.4672 - val_accuracy: 0.8813
#
# Epoch 00040: val_loss did not improve from 0.00996
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0344 - accuracy: 0.9882 - val_loss: 0.3602 - val_accuracy: 0.9094
#
# Epoch 00041: val_loss did not improve from 0.00996
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0331 - accuracy: 0.9894 - val_loss: 0.4004 - val_accuracy: 0.8898
#
# Epoch 00042: val_loss did not improve from 0.00996
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0304 - accuracy: 0.9897 - val_loss: 0.3604 - val_accuracy: 0.9008
#
# Epoch 00043: val_loss did not improve from 0.00996
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0315 - accuracy: 0.9903 - val_loss: 0.4104 - val_accuracy: 0.8957
#
# Epoch 00044: val_loss did not improve from 0.00996
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0275 - accuracy: 0.9900 - val_loss: 0.2975 - val_accuracy: 0.9156
#
# Epoch 00045: val_loss did not improve from 0.00996
# Epoch 46/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.3490 - val_accuracy: 0.9129
#
# Epoch 00046: val_loss did not improve from 0.00996
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0303 - accuracy: 0.9904 - val_loss: 0.3713 - val_accuracy: 0.9102
#
# Epoch 00047: val_loss did not improve from 0.00996
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0241 - accuracy: 0.9923 - val_loss: 0.3988 - val_accuracy: 0.9000
#
# Epoch 00048: val_loss did not improve from 0.00996
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0228 - accuracy: 0.9929 - val_loss: 0.2812 - val_accuracy: 0.9242
#
# Epoch 00049: val_loss did not improve from 0.00996
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.4053 - val_accuracy: 0.9016
#
# Epoch 00050: val_loss did not improve from 0.00996
# Epoch 51/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0229 - accuracy: 0.9919 - val_loss: 0.3768 - val_accuracy: 0.9082
#
# Epoch 00051: val_loss did not improve from 0.00996
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0193 - accuracy: 0.9932 - val_loss: 0.3202 - val_accuracy: 0.9109
#
# Epoch 00052: val_loss did not improve from 0.00996
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 0.4200 - val_accuracy: 0.8918
#
# Epoch 00053: val_loss did not improve from 0.00996
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0257 - accuracy: 0.9920 - val_loss: 0.2529 - val_accuracy: 0.9297
#
# Epoch 00054: val_loss did not improve from 0.00996
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0223 - accuracy: 0.9927 - val_loss: 0.2486 - val_accuracy: 0.9336
#
# Epoch 00055: val_loss did not improve from 0.00996
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0211 - accuracy: 0.9924 - val_loss: 0.2854 - val_accuracy: 0.9266
#
# Epoch 00056: val_loss did not improve from 0.00996
# Epoch 57/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0202 - accuracy: 0.9942 - val_loss: 0.2793 - val_accuracy: 0.9312
#
# Epoch 00057: val_loss did not improve from 0.00996
# Epoch 58/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0202 - accuracy: 0.9933 - val_loss: 0.2941 - val_accuracy: 0.9258
#
# Epoch 00058: val_loss did not improve from 0.00996
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0211 - accuracy: 0.9924 - val_loss: 0.2909 - val_accuracy: 0.9266
#
# Epoch 00059: val_loss did not improve from 0.00996
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 0.2694 - val_accuracy: 0.9293
#
# Epoch 00060: val_loss did not improve from 0.00996
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0234 - accuracy: 0.9929 - val_loss: 0.4388 - val_accuracy: 0.9035
#
# Epoch 00061: val_loss did not improve from 0.00996
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.2384 - val_accuracy: 0.9387
#
# Epoch 00062: val_loss did not improve from 0.00996
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.2274 - val_accuracy: 0.9422
#
# Epoch 00063: val_loss did not improve from 0.00996
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.1580 - val_accuracy: 0.9555
#
# Epoch 00064: val_loss did not improve from 0.00996
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 0.2998 - val_accuracy: 0.9316
#
# Epoch 00065: val_loss did not improve from 0.00996
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.1831 - val_accuracy: 0.9500
#
# Epoch 00066: val_loss did not improve from 0.00996
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.2311 - val_accuracy: 0.9379
#
# Epoch 00067: val_loss did not improve from 0.00996
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.2018 - val_accuracy: 0.9480
#
# Epoch 00068: val_loss did not improve from 0.00996
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.1835 - val_accuracy: 0.9547
#
# Epoch 00069: val_loss did not improve from 0.00996
# Epoch 70/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.2776 - val_accuracy: 0.9328
#
# Epoch 00070: val_loss did not improve from 0.00996
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.2432 - val_accuracy: 0.9383
#
# Epoch 00071: val_loss did not improve from 0.00996
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.2082 - val_accuracy: 0.9457
#
# Epoch 00072: val_loss did not improve from 0.00996
# Epoch 73/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.1962 - val_accuracy: 0.9496
#
# Epoch 00073: val_loss did not improve from 0.00996
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 0.2047 - val_accuracy: 0.9441
#
# Epoch 00074: val_loss did not improve from 0.00996
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.1830 - val_accuracy: 0.9516
#
# Epoch 00075: val_loss did not improve from 0.00996
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.3512 - val_accuracy: 0.9195
#
# Epoch 00076: val_loss did not improve from 0.00996
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0178 - accuracy: 0.9951 - val_loss: 0.2274 - val_accuracy: 0.9434
#
# Epoch 00077: val_loss did not improve from 0.00996
# Epoch 78/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 0.2337 - val_accuracy: 0.9434
#
# Epoch 00078: val_loss did not improve from 0.00996
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.2202 - val_accuracy: 0.9430
#
# Epoch 00079: val_loss did not improve from 0.00996
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 0.1730 - val_accuracy: 0.9578
#
# Epoch 00080: val_loss did not improve from 0.00996
# Epoch 81/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0167 - accuracy: 0.9947 - val_loss: 0.2236 - val_accuracy: 0.9449
#
# Epoch 00081: val_loss did not improve from 0.00996
# Epoch 82/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0144 - accuracy: 0.9948 - val_loss: 0.1253 - val_accuracy: 0.9645
#
# Epoch 00082: val_loss did not improve from 0.00996
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0122 - accuracy: 0.9957 - val_loss: 0.2334 - val_accuracy: 0.9375
#
# Epoch 00083: val_loss did not improve from 0.00996
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.1256 - val_accuracy: 0.9680
#
# Epoch 00084: val_loss did not improve from 0.00996
# Epoch 85/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 0.1576 - val_accuracy: 0.9594
#
# Epoch 00085: val_loss did not improve from 0.00996
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.2647 - val_accuracy: 0.9367
#
# Epoch 00086: val_loss did not improve from 0.00996
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.1417 - val_accuracy: 0.9660
#
# Epoch 00087: val_loss did not improve from 0.00996
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.1569 - val_accuracy: 0.9551
#
# Epoch 00088: val_loss did not improve from 0.00996
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.1585 - val_accuracy: 0.9559
#
# Epoch 00089: val_loss did not improve from 0.00996
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.2062 - val_accuracy: 0.9480
#
# Epoch 00090: val_loss did not improve from 0.00996
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.1532 - val_accuracy: 0.9598
#
# Epoch 00091: val_loss did not improve from 0.00996
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.2297 - val_accuracy: 0.9461
#
# Epoch 00092: val_loss did not improve from 0.00996
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.1908 - val_accuracy: 0.9496
#
# Epoch 00093: val_loss did not improve from 0.00996
# Epoch 94/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.1950 - val_accuracy: 0.9527
#
# Epoch 00094: val_loss did not improve from 0.00996
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.1841 - val_accuracy: 0.9523
#
# Epoch 00095: val_loss did not improve from 0.00996
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.1816 - val_accuracy: 0.9516
#
# Epoch 00096: val_loss did not improve from 0.00996
# Epoch 97/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.1691 - val_accuracy: 0.9547
#
# Epoch 00097: val_loss did not improve from 0.00996
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.1616 - val_accuracy: 0.9590
#
# Epoch 00098: val_loss did not improve from 0.00996
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.1797 - val_accuracy: 0.9574
#
# Epoch 00099: val_loss did not improve from 0.00996
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 0.1425 - val_accuracy: 0.9609
#
# Epoch 00100: val_loss did not improve from 0.00996
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1425 - accuracy: 0.9609
# Val Score:  [0.14251534640789032, 0.9609375]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.98      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.98      0.99       737
#
#              accuracy                           0.99      3200
#             macro avg       0.99      0.99      0.99      3200
#          weighted avg       0.99      0.99      0.99      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 4ms/step - loss: 0.0099 - accuracy: 0.9947
# Test Accuracy: 99.46874976158142

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
