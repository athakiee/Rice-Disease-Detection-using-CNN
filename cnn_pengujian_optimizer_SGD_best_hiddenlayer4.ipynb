# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **OPTIMIZER TEST -- USING SGD AND BEST RESULT OF HIDDEN LAYER(4)**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 2022-07-09 07:26:19.023703: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:19.141849: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:19.142933: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:19.145145: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-09 07:26:19.145467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:19.146196: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:19.146875: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:21.235235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:21.236256: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:21.236971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 07:26:21.238192: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = SGD(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# 2022-07-09 07:26:24.352868: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-07-09 07:26:25.921542: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 320/320 [==============================] - 10s 9ms/step - loss: 0.9106 - accuracy: 0.6854 - val_loss: 2.0736 - val_accuracy: 0.4820
#
# Epoch 00001: val_loss improved from inf to 2.07358, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.4685 - accuracy: 0.8265 - val_loss: 0.3871 - val_accuracy: 0.8465
#
# Epoch 00002: val_loss improved from 2.07358 to 0.38707, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3457 - accuracy: 0.8725 - val_loss: 0.4320 - val_accuracy: 0.8445
#
# Epoch 00003: val_loss did not improve from 0.38707
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2692 - accuracy: 0.8997 - val_loss: 0.5157 - val_accuracy: 0.8348
#
# Epoch 00004: val_loss did not improve from 0.38707
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2187 - accuracy: 0.9203 - val_loss: 0.1906 - val_accuracy: 0.9223
#
# Epoch 00005: val_loss improved from 0.38707 to 0.19064, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1861 - accuracy: 0.9292 - val_loss: 0.3574 - val_accuracy: 0.8664
#
# Epoch 00006: val_loss did not improve from 0.19064
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1735 - accuracy: 0.9383 - val_loss: 0.1366 - val_accuracy: 0.9512
#
# Epoch 00007: val_loss improved from 0.19064 to 0.13663, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1517 - accuracy: 0.9446 - val_loss: 0.2914 - val_accuracy: 0.8992
#
# Epoch 00008: val_loss did not improve from 0.13663
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1414 - accuracy: 0.9487 - val_loss: 0.2313 - val_accuracy: 0.9172
#
# Epoch 00009: val_loss did not improve from 0.13663
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1374 - accuracy: 0.9485 - val_loss: 0.1104 - val_accuracy: 0.9563
#
# Epoch 00010: val_loss improved from 0.13663 to 0.11043, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1191 - accuracy: 0.9550 - val_loss: 0.2846 - val_accuracy: 0.8914
#
# Epoch 00011: val_loss did not improve from 0.11043
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1082 - accuracy: 0.9621 - val_loss: 0.1575 - val_accuracy: 0.9438
#
# Epoch 00012: val_loss did not improve from 0.11043
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1140 - accuracy: 0.9583 - val_loss: 0.1602 - val_accuracy: 0.9441
#
# Epoch 00013: val_loss did not improve from 0.11043
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0951 - accuracy: 0.9667 - val_loss: 0.1988 - val_accuracy: 0.9305
#
# Epoch 00014: val_loss did not improve from 0.11043
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0882 - accuracy: 0.9681 - val_loss: 0.0722 - val_accuracy: 0.9758
#
# Epoch 00015: val_loss improved from 0.11043 to 0.07220, saving model to model.h5
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0856 - accuracy: 0.9683 - val_loss: 0.1422 - val_accuracy: 0.9473
#
# Epoch 00016: val_loss did not improve from 0.07220
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0859 - accuracy: 0.9679 - val_loss: 0.1055 - val_accuracy: 0.9598
#
# Epoch 00017: val_loss did not improve from 0.07220
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0796 - accuracy: 0.9708 - val_loss: 0.2821 - val_accuracy: 0.9102
#
# Epoch 00018: val_loss did not improve from 0.07220
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0733 - accuracy: 0.9734 - val_loss: 0.1172 - val_accuracy: 0.9570
#
# Epoch 00019: val_loss did not improve from 0.07220
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0737 - accuracy: 0.9742 - val_loss: 0.1219 - val_accuracy: 0.9598
#
# Epoch 00020: val_loss did not improve from 0.07220
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0682 - accuracy: 0.9745 - val_loss: 0.1436 - val_accuracy: 0.9457
#
# Epoch 00021: val_loss did not improve from 0.07220
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0673 - accuracy: 0.9744 - val_loss: 0.1123 - val_accuracy: 0.9633
#
# Epoch 00022: val_loss did not improve from 0.07220
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0700 - accuracy: 0.9743 - val_loss: 0.0845 - val_accuracy: 0.9727
#
# Epoch 00023: val_loss did not improve from 0.07220
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0548 - accuracy: 0.9811 - val_loss: 0.1079 - val_accuracy: 0.9609
#
# Epoch 00024: val_loss did not improve from 0.07220
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0656 - accuracy: 0.9764 - val_loss: 0.1130 - val_accuracy: 0.9582
#
# Epoch 00025: val_loss did not improve from 0.07220
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0548 - accuracy: 0.9818 - val_loss: 0.2233 - val_accuracy: 0.9242
#
# Epoch 00026: val_loss did not improve from 0.07220
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0551 - accuracy: 0.9811 - val_loss: 0.0853 - val_accuracy: 0.9703
#
# Epoch 00027: val_loss did not improve from 0.07220
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0597 - accuracy: 0.9796 - val_loss: 0.1189 - val_accuracy: 0.9563
#
# Epoch 00028: val_loss did not improve from 0.07220
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0557 - accuracy: 0.9804 - val_loss: 0.0772 - val_accuracy: 0.9727
#
# Epoch 00029: val_loss did not improve from 0.07220
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0454 - accuracy: 0.9847 - val_loss: 0.0763 - val_accuracy: 0.9719
#
# Epoch 00030: val_loss did not improve from 0.07220
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0492 - accuracy: 0.9830 - val_loss: 0.1523 - val_accuracy: 0.9438
#
# Epoch 00031: val_loss did not improve from 0.07220
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0500 - accuracy: 0.9821 - val_loss: 0.1489 - val_accuracy: 0.9492
#
# Epoch 00032: val_loss did not improve from 0.07220
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0519 - accuracy: 0.9819 - val_loss: 0.4753 - val_accuracy: 0.8504
#
# Epoch 00033: val_loss did not improve from 0.07220
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0491 - accuracy: 0.9835 - val_loss: 0.0566 - val_accuracy: 0.9812
#
# Epoch 00034: val_loss improved from 0.07220 to 0.05659, saving model to model.h5
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0453 - accuracy: 0.9843 - val_loss: 0.1148 - val_accuracy: 0.9629
#
# Epoch 00035: val_loss did not improve from 0.05659
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0472 - accuracy: 0.9837 - val_loss: 0.0967 - val_accuracy: 0.9648
#
# Epoch 00036: val_loss did not improve from 0.05659
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0535 - accuracy: 0.9801 - val_loss: 0.0556 - val_accuracy: 0.9781
#
# Epoch 00037: val_loss improved from 0.05659 to 0.05558, saving model to model.h5
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0403 - accuracy: 0.9862 - val_loss: 0.0547 - val_accuracy: 0.9801
#
# Epoch 00038: val_loss improved from 0.05558 to 0.05471, saving model to model.h5
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0438 - accuracy: 0.9838 - val_loss: 0.0391 - val_accuracy: 0.9871
#
# Epoch 00039: val_loss improved from 0.05471 to 0.03915, saving model to model.h5
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0409 - accuracy: 0.9857 - val_loss: 0.4258 - val_accuracy: 0.8828
#
# Epoch 00040: val_loss did not improve from 0.03915
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0391 - accuracy: 0.9849 - val_loss: 0.0591 - val_accuracy: 0.9812
#
# Epoch 00041: val_loss did not improve from 0.03915
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0422 - accuracy: 0.9851 - val_loss: 0.0858 - val_accuracy: 0.9723
#
# Epoch 00042: val_loss did not improve from 0.03915
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0406 - accuracy: 0.9869 - val_loss: 0.1112 - val_accuracy: 0.9656
#
# Epoch 00043: val_loss did not improve from 0.03915
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0348 - accuracy: 0.9882 - val_loss: 0.0583 - val_accuracy: 0.9812
#
# Epoch 00044: val_loss did not improve from 0.03915
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0365 - accuracy: 0.9875 - val_loss: 0.1436 - val_accuracy: 0.9453
#
# Epoch 00045: val_loss did not improve from 0.03915
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0331 - accuracy: 0.9891 - val_loss: 0.1038 - val_accuracy: 0.9629
#
# Epoch 00046: val_loss did not improve from 0.03915
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9879 - val_loss: 0.0911 - val_accuracy: 0.9699
#
# Epoch 00047: val_loss did not improve from 0.03915
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0286 - accuracy: 0.9904 - val_loss: 0.0829 - val_accuracy: 0.9695
#
# Epoch 00048: val_loss did not improve from 0.03915
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0335 - accuracy: 0.9882 - val_loss: 0.1046 - val_accuracy: 0.9629
#
# Epoch 00049: val_loss did not improve from 0.03915
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0327 - accuracy: 0.9889 - val_loss: 0.0672 - val_accuracy: 0.9742
#
# Epoch 00050: val_loss did not improve from 0.03915
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.3549 - val_accuracy: 0.9105
#
# Epoch 00051: val_loss did not improve from 0.03915
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0359 - accuracy: 0.9863 - val_loss: 0.0721 - val_accuracy: 0.9742
#
# Epoch 00052: val_loss did not improve from 0.03915
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0377 - accuracy: 0.9868 - val_loss: 0.0741 - val_accuracy: 0.9742
#
# Epoch 00053: val_loss did not improve from 0.03915
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0357 - accuracy: 0.9877 - val_loss: 0.1200 - val_accuracy: 0.9609
#
# Epoch 00054: val_loss did not improve from 0.03915
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0329 - accuracy: 0.9881 - val_loss: 0.1311 - val_accuracy: 0.9582
#
# Epoch 00055: val_loss did not improve from 0.03915
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0298 - accuracy: 0.9896 - val_loss: 0.0330 - val_accuracy: 0.9871
#
# Epoch 00056: val_loss improved from 0.03915 to 0.03297, saving model to model.h5
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0296 - accuracy: 0.9885 - val_loss: 0.0375 - val_accuracy: 0.9875
#
# Epoch 00057: val_loss did not improve from 0.03297
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 0.0366 - val_accuracy: 0.9902
#
# Epoch 00058: val_loss did not improve from 0.03297
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0290 - accuracy: 0.9894 - val_loss: 0.1245 - val_accuracy: 0.9531
#
# Epoch 00059: val_loss did not improve from 0.03297
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0265 - accuracy: 0.9911 - val_loss: 0.0484 - val_accuracy: 0.9852
#
# Epoch 00060: val_loss did not improve from 0.03297
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0261 - accuracy: 0.9907 - val_loss: 0.0592 - val_accuracy: 0.9816
#
# Epoch 00061: val_loss did not improve from 0.03297
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0310 - accuracy: 0.9891 - val_loss: 0.1671 - val_accuracy: 0.9422
#
# Epoch 00062: val_loss did not improve from 0.03297
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.0400 - val_accuracy: 0.9879
#
# Epoch 00063: val_loss did not improve from 0.03297
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0273 - accuracy: 0.9915 - val_loss: 0.0592 - val_accuracy: 0.9797
#
# Epoch 00064: val_loss did not improve from 0.03297
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0281 - accuracy: 0.9908 - val_loss: 0.0819 - val_accuracy: 0.9684
#
# Epoch 00065: val_loss did not improve from 0.03297
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0251 - accuracy: 0.9910 - val_loss: 0.0674 - val_accuracy: 0.9770
#
# Epoch 00066: val_loss did not improve from 0.03297
# Epoch 67/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0241 - accuracy: 0.9912 - val_loss: 0.0599 - val_accuracy: 0.9770
#
# Epoch 00067: val_loss did not improve from 0.03297
# Epoch 68/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0220 - accuracy: 0.9925 - val_loss: 0.0753 - val_accuracy: 0.9711
#
# Epoch 00068: val_loss did not improve from 0.03297
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0254 - accuracy: 0.9911 - val_loss: 0.1133 - val_accuracy: 0.9602
#
# Epoch 00069: val_loss did not improve from 0.03297
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.0324 - val_accuracy: 0.9879
#
# Epoch 00070: val_loss improved from 0.03297 to 0.03238, saving model to model.h5
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0225 - accuracy: 0.9922 - val_loss: 0.0949 - val_accuracy: 0.9656
#
# Epoch 00071: val_loss did not improve from 0.03238
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0196 - accuracy: 0.9932 - val_loss: 0.0259 - val_accuracy: 0.9906
#
# Epoch 00072: val_loss improved from 0.03238 to 0.02592, saving model to model.h5
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0269 - accuracy: 0.9907 - val_loss: 0.0870 - val_accuracy: 0.9668
#
# Epoch 00073: val_loss did not improve from 0.02592
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.0339 - val_accuracy: 0.9871
#
# Epoch 00074: val_loss did not improve from 0.02592
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.0369 - val_accuracy: 0.9863
#
# Epoch 00075: val_loss did not improve from 0.02592
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0234 - accuracy: 0.9920 - val_loss: 0.0625 - val_accuracy: 0.9762
#
# Epoch 00076: val_loss did not improve from 0.02592
# Epoch 77/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0220 - accuracy: 0.9928 - val_loss: 0.0296 - val_accuracy: 0.9895
#
# Epoch 00077: val_loss did not improve from 0.02592
# Epoch 78/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0226 - accuracy: 0.9916 - val_loss: 0.0738 - val_accuracy: 0.9746
#
# Epoch 00078: val_loss did not improve from 0.02592
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.0512 - val_accuracy: 0.9824
#
# Epoch 00079: val_loss did not improve from 0.02592
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0216 - accuracy: 0.9920 - val_loss: 0.0255 - val_accuracy: 0.9922
#
# Epoch 00080: val_loss improved from 0.02592 to 0.02551, saving model to model.h5
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0219 - accuracy: 0.9921 - val_loss: 0.0459 - val_accuracy: 0.9824
#
# Epoch 00081: val_loss did not improve from 0.02551
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0216 - accuracy: 0.9924 - val_loss: 0.0305 - val_accuracy: 0.9895
#
# Epoch 00082: val_loss did not improve from 0.02551
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0202 - accuracy: 0.9933 - val_loss: 0.0385 - val_accuracy: 0.9871
#
# Epoch 00083: val_loss did not improve from 0.02551
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0224 - accuracy: 0.9920 - val_loss: 0.0358 - val_accuracy: 0.9863
#
# Epoch 00084: val_loss did not improve from 0.02551
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.0343 - val_accuracy: 0.9875
#
# Epoch 00085: val_loss did not improve from 0.02551
# Epoch 86/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.0262 - val_accuracy: 0.9906
#
# Epoch 00086: val_loss did not improve from 0.02551
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0232 - accuracy: 0.9921 - val_loss: 0.4316 - val_accuracy: 0.8695
#
# Epoch 00087: val_loss did not improve from 0.02551
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 0.0238 - val_accuracy: 0.9906
#
# Epoch 00088: val_loss improved from 0.02551 to 0.02376, saving model to model.h5
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.0354 - val_accuracy: 0.9879
#
# Epoch 00089: val_loss did not improve from 0.02376
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0257 - accuracy: 0.9913 - val_loss: 0.0971 - val_accuracy: 0.9629
#
# Epoch 00090: val_loss did not improve from 0.02376
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0312 - val_accuracy: 0.9883
#
# Epoch 00091: val_loss did not improve from 0.02376
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9924 - val_loss: 0.0238 - val_accuracy: 0.9914
#
# Epoch 00092: val_loss improved from 0.02376 to 0.02376, saving model to model.h5
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.0824 - val_accuracy: 0.9711
#
# Epoch 00093: val_loss did not improve from 0.02376
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0173 - accuracy: 0.9931 - val_loss: 0.0310 - val_accuracy: 0.9883
#
# Epoch 00094: val_loss did not improve from 0.02376
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0197 - accuracy: 0.9928 - val_loss: 0.0484 - val_accuracy: 0.9816
#
# Epoch 00095: val_loss did not improve from 0.02376
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0370 - val_accuracy: 0.9879
#
# Epoch 00096: val_loss did not improve from 0.02376
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 0.0190 - val_accuracy: 0.9934
#
# Epoch 00097: val_loss improved from 0.02376 to 0.01903, saving model to model.h5
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0182 - accuracy: 0.9932 - val_loss: 0.0450 - val_accuracy: 0.9848
#
# Epoch 00098: val_loss did not improve from 0.01903
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0171 - accuracy: 0.9943 - val_loss: 0.0316 - val_accuracy: 0.9867
#
# Epoch 00099: val_loss did not improve from 0.01903
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0186 - accuracy: 0.9928 - val_loss: 0.0596 - val_accuracy: 0.9766
#
# Epoch 00100: val_loss did not improve from 0.01903
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9766
# Val Score:  [0.05962986499071121, 0.9765625]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.9562 - accuracy: 0.6740 - val_loss: 1.2887 - val_accuracy: 0.4879
#
# Epoch 00001: val_loss did not improve from 0.01903
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.5123 - accuracy: 0.8230 - val_loss: 0.2441 - val_accuracy: 0.9121
#
# Epoch 00002: val_loss did not improve from 0.01903
# Epoch 3/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.3923 - accuracy: 0.8586 - val_loss: 0.2699 - val_accuracy: 0.8941
#
# Epoch 00003: val_loss did not improve from 0.01903
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3252 - accuracy: 0.8796 - val_loss: 0.1762 - val_accuracy: 0.9363
#
# Epoch 00004: val_loss did not improve from 0.01903
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2812 - accuracy: 0.8995 - val_loss: 0.1491 - val_accuracy: 0.9449
#
# Epoch 00005: val_loss did not improve from 0.01903
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2370 - accuracy: 0.9141 - val_loss: 0.1229 - val_accuracy: 0.9570
#
# Epoch 00006: val_loss did not improve from 0.01903
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2185 - accuracy: 0.9174 - val_loss: 0.1136 - val_accuracy: 0.9621
#
# Epoch 00007: val_loss did not improve from 0.01903
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2049 - accuracy: 0.9266 - val_loss: 0.0984 - val_accuracy: 0.9645
#
# Epoch 00008: val_loss did not improve from 0.01903
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1796 - accuracy: 0.9350 - val_loss: 0.2604 - val_accuracy: 0.8930
#
# Epoch 00009: val_loss did not improve from 0.01903
# Epoch 10/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1798 - accuracy: 0.9298 - val_loss: 0.1170 - val_accuracy: 0.9598
#
# Epoch 00010: val_loss did not improve from 0.01903
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1457 - accuracy: 0.9455 - val_loss: 0.1058 - val_accuracy: 0.9629
#
# Epoch 00011: val_loss did not improve from 0.01903
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1400 - accuracy: 0.9465 - val_loss: 0.0962 - val_accuracy: 0.9656
#
# Epoch 00012: val_loss did not improve from 0.01903
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1313 - accuracy: 0.9516 - val_loss: 0.0959 - val_accuracy: 0.9645
#
# Epoch 00013: val_loss did not improve from 0.01903
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1216 - accuracy: 0.9537 - val_loss: 0.1045 - val_accuracy: 0.9605
#
# Epoch 00014: val_loss did not improve from 0.01903
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1164 - accuracy: 0.9562 - val_loss: 0.2320 - val_accuracy: 0.9160
#
# Epoch 00015: val_loss did not improve from 0.01903
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1201 - accuracy: 0.9547 - val_loss: 0.0954 - val_accuracy: 0.9605
#
# Epoch 00016: val_loss did not improve from 0.01903
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1028 - accuracy: 0.9619 - val_loss: 0.0785 - val_accuracy: 0.9703
#
# Epoch 00017: val_loss did not improve from 0.01903
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1095 - accuracy: 0.9585 - val_loss: 0.1486 - val_accuracy: 0.9488
#
# Epoch 00018: val_loss did not improve from 0.01903
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0990 - accuracy: 0.9625 - val_loss: 0.0717 - val_accuracy: 0.9715
#
# Epoch 00019: val_loss did not improve from 0.01903
# Epoch 20/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0889 - accuracy: 0.9667 - val_loss: 0.0767 - val_accuracy: 0.9699
#
# Epoch 00020: val_loss did not improve from 0.01903
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0808 - accuracy: 0.9697 - val_loss: 0.1190 - val_accuracy: 0.9551
#
# Epoch 00021: val_loss did not improve from 0.01903
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0830 - accuracy: 0.9688 - val_loss: 0.2210 - val_accuracy: 0.9238
#
# Epoch 00022: val_loss did not improve from 0.01903
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0781 - accuracy: 0.9719 - val_loss: 0.0940 - val_accuracy: 0.9625
#
# Epoch 00023: val_loss did not improve from 0.01903
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0760 - accuracy: 0.9726 - val_loss: 0.0933 - val_accuracy: 0.9625
#
# Epoch 00024: val_loss did not improve from 0.01903
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0795 - accuracy: 0.9721 - val_loss: 0.0908 - val_accuracy: 0.9676
#
# Epoch 00025: val_loss did not improve from 0.01903
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0915 - accuracy: 0.9674 - val_loss: 0.1334 - val_accuracy: 0.9512
#
# Epoch 00026: val_loss did not improve from 0.01903
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0760 - accuracy: 0.9724 - val_loss: 0.0642 - val_accuracy: 0.9762
#
# Epoch 00027: val_loss did not improve from 0.01903
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0711 - accuracy: 0.9763 - val_loss: 0.3854 - val_accuracy: 0.8820
#
# Epoch 00028: val_loss did not improve from 0.01903
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0665 - accuracy: 0.9765 - val_loss: 0.1070 - val_accuracy: 0.9637
#
# Epoch 00029: val_loss did not improve from 0.01903
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0684 - accuracy: 0.9754 - val_loss: 0.0535 - val_accuracy: 0.9836
#
# Epoch 00030: val_loss did not improve from 0.01903
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0648 - accuracy: 0.9767 - val_loss: 0.0643 - val_accuracy: 0.9785
#
# Epoch 00031: val_loss did not improve from 0.01903
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0667 - accuracy: 0.9741 - val_loss: 0.0378 - val_accuracy: 0.9848
#
# Epoch 00032: val_loss did not improve from 0.01903
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0641 - accuracy: 0.9777 - val_loss: 0.1456 - val_accuracy: 0.9504
#
# Epoch 00033: val_loss did not improve from 0.01903
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0617 - accuracy: 0.9776 - val_loss: 0.0730 - val_accuracy: 0.9746
#
# Epoch 00034: val_loss did not improve from 0.01903
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0610 - accuracy: 0.9789 - val_loss: 0.1294 - val_accuracy: 0.9559
#
# Epoch 00035: val_loss did not improve from 0.01903
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0600 - accuracy: 0.9795 - val_loss: 0.2471 - val_accuracy: 0.9148
#
# Epoch 00036: val_loss did not improve from 0.01903
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0652 - accuracy: 0.9781 - val_loss: 0.0912 - val_accuracy: 0.9668
#
# Epoch 00037: val_loss did not improve from 0.01903
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0532 - accuracy: 0.9813 - val_loss: 0.0777 - val_accuracy: 0.9719
#
# Epoch 00038: val_loss did not improve from 0.01903
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0570 - accuracy: 0.9794 - val_loss: 0.0262 - val_accuracy: 0.9887
#
# Epoch 00039: val_loss did not improve from 0.01903
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0564 - accuracy: 0.9790 - val_loss: 0.2130 - val_accuracy: 0.9266
#
# Epoch 00040: val_loss did not improve from 0.01903
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0525 - accuracy: 0.9801 - val_loss: 0.1151 - val_accuracy: 0.9586
#
# Epoch 00041: val_loss did not improve from 0.01903
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0529 - accuracy: 0.9809 - val_loss: 0.0381 - val_accuracy: 0.9848
#
# Epoch 00042: val_loss did not improve from 0.01903
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0492 - accuracy: 0.9832 - val_loss: 0.1183 - val_accuracy: 0.9574
#
# Epoch 00043: val_loss did not improve from 0.01903
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0483 - accuracy: 0.9831 - val_loss: 0.2518 - val_accuracy: 0.9133
#
# Epoch 00044: val_loss did not improve from 0.01903
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0501 - accuracy: 0.9821 - val_loss: 0.1066 - val_accuracy: 0.9617
#
# Epoch 00045: val_loss did not improve from 0.01903
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0436 - accuracy: 0.9851 - val_loss: 0.1348 - val_accuracy: 0.9527
#
# Epoch 00046: val_loss did not improve from 0.01903
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0484 - accuracy: 0.9826 - val_loss: 0.1012 - val_accuracy: 0.9660
#
# Epoch 00047: val_loss did not improve from 0.01903
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0467 - accuracy: 0.9849 - val_loss: 0.0542 - val_accuracy: 0.9766
#
# Epoch 00048: val_loss did not improve from 0.01903
# Epoch 49/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0447 - accuracy: 0.9847 - val_loss: 0.0649 - val_accuracy: 0.9719
#
# Epoch 00049: val_loss did not improve from 0.01903
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0405 - accuracy: 0.9854 - val_loss: 0.1888 - val_accuracy: 0.9391
#
# Epoch 00050: val_loss did not improve from 0.01903
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0401 - accuracy: 0.9865 - val_loss: 0.0385 - val_accuracy: 0.9844
#
# Epoch 00051: val_loss did not improve from 0.01903
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0414 - accuracy: 0.9845 - val_loss: 0.2244 - val_accuracy: 0.9289
#
# Epoch 00052: val_loss did not improve from 0.01903
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0464 - accuracy: 0.9843 - val_loss: 0.0844 - val_accuracy: 0.9684
#
# Epoch 00053: val_loss did not improve from 0.01903
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0366 - accuracy: 0.9880 - val_loss: 0.0576 - val_accuracy: 0.9742
#
# Epoch 00054: val_loss did not improve from 0.01903
# Epoch 55/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0372 - accuracy: 0.9870 - val_loss: 0.0629 - val_accuracy: 0.9754
#
# Epoch 00055: val_loss did not improve from 0.01903
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0419 - accuracy: 0.9847 - val_loss: 0.0388 - val_accuracy: 0.9852
#
# Epoch 00056: val_loss did not improve from 0.01903
# Epoch 57/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0342 - accuracy: 0.9883 - val_loss: 0.0661 - val_accuracy: 0.9742
#
# Epoch 00057: val_loss did not improve from 0.01903
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0433 - accuracy: 0.9856 - val_loss: 0.0983 - val_accuracy: 0.9641
#
# Epoch 00058: val_loss did not improve from 0.01903
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0373 - accuracy: 0.9875 - val_loss: 0.1233 - val_accuracy: 0.9551
#
# Epoch 00059: val_loss did not improve from 0.01903
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0338 - accuracy: 0.9866 - val_loss: 0.0229 - val_accuracy: 0.9922
#
# Epoch 00060: val_loss did not improve from 0.01903
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0367 - accuracy: 0.9862 - val_loss: 0.0540 - val_accuracy: 0.9770
#
# Epoch 00061: val_loss did not improve from 0.01903
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0391 - accuracy: 0.9860 - val_loss: 0.0223 - val_accuracy: 0.9914
#
# Epoch 00062: val_loss did not improve from 0.01903
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0332 - accuracy: 0.9876 - val_loss: 0.0568 - val_accuracy: 0.9781
#
# Epoch 00063: val_loss did not improve from 0.01903
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0342 - accuracy: 0.9880 - val_loss: 0.0713 - val_accuracy: 0.9734
#
# Epoch 00064: val_loss did not improve from 0.01903
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0321 - accuracy: 0.9892 - val_loss: 0.0147 - val_accuracy: 0.9949
#
# Epoch 00065: val_loss improved from 0.01903 to 0.01475, saving model to model.h5
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0318 - accuracy: 0.9882 - val_loss: 0.0481 - val_accuracy: 0.9820
#
# Epoch 00066: val_loss did not improve from 0.01475
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0303 - accuracy: 0.9886 - val_loss: 0.0340 - val_accuracy: 0.9863
#
# Epoch 00067: val_loss did not improve from 0.01475
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0341 - accuracy: 0.9890 - val_loss: 0.0426 - val_accuracy: 0.9824
#
# Epoch 00068: val_loss did not improve from 0.01475
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0334 - accuracy: 0.9872 - val_loss: 0.0362 - val_accuracy: 0.9863
#
# Epoch 00069: val_loss did not improve from 0.01475
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0313 - accuracy: 0.9899 - val_loss: 0.0555 - val_accuracy: 0.9762
#
# Epoch 00070: val_loss did not improve from 0.01475
# Epoch 71/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0260 - accuracy: 0.9908 - val_loss: 0.0371 - val_accuracy: 0.9840
#
# Epoch 00071: val_loss did not improve from 0.01475
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.0246 - val_accuracy: 0.9898
#
# Epoch 00072: val_loss did not improve from 0.01475
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0284 - accuracy: 0.9908 - val_loss: 0.0437 - val_accuracy: 0.9816
#
# Epoch 00073: val_loss did not improve from 0.01475
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0319 - accuracy: 0.9901 - val_loss: 0.1121 - val_accuracy: 0.9566
#
# Epoch 00074: val_loss did not improve from 0.01475
# Epoch 75/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0303 - accuracy: 0.9896 - val_loss: 0.0300 - val_accuracy: 0.9887
#
# Epoch 00075: val_loss did not improve from 0.01475
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0314 - accuracy: 0.9892 - val_loss: 0.0393 - val_accuracy: 0.9852
#
# Epoch 00076: val_loss did not improve from 0.01475
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0326 - accuracy: 0.9885 - val_loss: 0.0387 - val_accuracy: 0.9844
#
# Epoch 00077: val_loss did not improve from 0.01475
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0284 - accuracy: 0.9902 - val_loss: 0.1256 - val_accuracy: 0.9539
#
# Epoch 00078: val_loss did not improve from 0.01475
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0250 - accuracy: 0.9908 - val_loss: 0.0213 - val_accuracy: 0.9914
#
# Epoch 00079: val_loss did not improve from 0.01475
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0278 - accuracy: 0.9911 - val_loss: 0.0367 - val_accuracy: 0.9863
#
# Epoch 00080: val_loss did not improve from 0.01475
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0302 - accuracy: 0.9884 - val_loss: 0.0635 - val_accuracy: 0.9758
#
# Epoch 00081: val_loss did not improve from 0.01475
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0251 - accuracy: 0.9914 - val_loss: 0.0363 - val_accuracy: 0.9852
#
# Epoch 00082: val_loss did not improve from 0.01475
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0317 - accuracy: 0.9895 - val_loss: 0.0195 - val_accuracy: 0.9926
#
# Epoch 00083: val_loss did not improve from 0.01475
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0251 - accuracy: 0.9916 - val_loss: 0.0300 - val_accuracy: 0.9887
#
# Epoch 00084: val_loss did not improve from 0.01475
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.0541 - val_accuracy: 0.9781
#
# Epoch 00085: val_loss did not improve from 0.01475
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0294 - accuracy: 0.9903 - val_loss: 0.0098 - val_accuracy: 0.9961
#
# Epoch 00086: val_loss improved from 0.01475 to 0.00979, saving model to model.h5
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0267 - accuracy: 0.9914 - val_loss: 0.0534 - val_accuracy: 0.9781
#
# Epoch 00087: val_loss did not improve from 0.00979
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0252 - accuracy: 0.9911 - val_loss: 0.0357 - val_accuracy: 0.9875
#
# Epoch 00088: val_loss did not improve from 0.00979
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0269 - accuracy: 0.9906 - val_loss: 0.0174 - val_accuracy: 0.9937
#
# Epoch 00089: val_loss did not improve from 0.00979
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0247 - accuracy: 0.9911 - val_loss: 0.0141 - val_accuracy: 0.9934
#
# Epoch 00090: val_loss did not improve from 0.00979
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.0859 - val_accuracy: 0.9660
#
# Epoch 00091: val_loss did not improve from 0.00979
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.0267 - val_accuracy: 0.9906
#
# Epoch 00092: val_loss did not improve from 0.00979
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0247 - accuracy: 0.9923 - val_loss: 0.0452 - val_accuracy: 0.9828
#
# Epoch 00093: val_loss did not improve from 0.00979
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0242 - accuracy: 0.9916 - val_loss: 0.0438 - val_accuracy: 0.9816
#
# Epoch 00094: val_loss did not improve from 0.00979
# Epoch 95/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.0236 - val_accuracy: 0.9914
#
# Epoch 00095: val_loss did not improve from 0.00979
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0219 - accuracy: 0.9930 - val_loss: 0.0405 - val_accuracy: 0.9836
#
# Epoch 00096: val_loss did not improve from 0.00979
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 0.0339 - val_accuracy: 0.9855
#
# Epoch 00097: val_loss did not improve from 0.00979
# Epoch 98/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 0.0660 - val_accuracy: 0.9730
#
# Epoch 00098: val_loss did not improve from 0.00979
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0210 - accuracy: 0.9926 - val_loss: 0.0712 - val_accuracy: 0.9727
#
# Epoch 00099: val_loss did not improve from 0.00979
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0244 - accuracy: 0.9912 - val_loss: 0.0303 - val_accuracy: 0.9895
#
# Epoch 00100: val_loss did not improve from 0.00979
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 0.9895
# Val Score:  [0.030267879366874695, 0.989453136920929]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 3s 8ms/step - loss: 1.0336 - accuracy: 0.6472 - val_loss: 2.7543 - val_accuracy: 0.3309
#
# Epoch 00001: val_loss did not improve from 0.00979
# Epoch 2/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.5582 - accuracy: 0.8006 - val_loss: 0.8396 - val_accuracy: 0.6992
#
# Epoch 00002: val_loss did not improve from 0.00979
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.4347 - accuracy: 0.8498 - val_loss: 0.4563 - val_accuracy: 0.8242
#
# Epoch 00003: val_loss did not improve from 0.00979
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3582 - accuracy: 0.8722 - val_loss: 0.5151 - val_accuracy: 0.8000
#
# Epoch 00004: val_loss did not improve from 0.00979
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3029 - accuracy: 0.8865 - val_loss: 0.2931 - val_accuracy: 0.8941
#
# Epoch 00005: val_loss did not improve from 0.00979
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2858 - accuracy: 0.8938 - val_loss: 0.2767 - val_accuracy: 0.8953
#
# Epoch 00006: val_loss did not improve from 0.00979
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2409 - accuracy: 0.9077 - val_loss: 0.3689 - val_accuracy: 0.8570
#
# Epoch 00007: val_loss did not improve from 0.00979
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2276 - accuracy: 0.9156 - val_loss: 0.1960 - val_accuracy: 0.9305
#
# Epoch 00008: val_loss did not improve from 0.00979
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2184 - accuracy: 0.9194 - val_loss: 0.2561 - val_accuracy: 0.9090
#
# Epoch 00009: val_loss did not improve from 0.00979
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1902 - accuracy: 0.9304 - val_loss: 0.1957 - val_accuracy: 0.9332
#
# Epoch 00010: val_loss did not improve from 0.00979
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1734 - accuracy: 0.9349 - val_loss: 0.3488 - val_accuracy: 0.8719
#
# Epoch 00011: val_loss did not improve from 0.00979
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1708 - accuracy: 0.9359 - val_loss: 0.3149 - val_accuracy: 0.8793
#
# Epoch 00012: val_loss did not improve from 0.00979
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1605 - accuracy: 0.9381 - val_loss: 0.2177 - val_accuracy: 0.9152
#
# Epoch 00013: val_loss did not improve from 0.00979
# Epoch 14/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1474 - accuracy: 0.9462 - val_loss: 0.3222 - val_accuracy: 0.8813
#
# Epoch 00014: val_loss did not improve from 0.00979
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1465 - accuracy: 0.9449 - val_loss: 0.1814 - val_accuracy: 0.9348
#
# Epoch 00015: val_loss did not improve from 0.00979
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1364 - accuracy: 0.9490 - val_loss: 0.3101 - val_accuracy: 0.8895
#
# Epoch 00016: val_loss did not improve from 0.00979
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1288 - accuracy: 0.9529 - val_loss: 0.2264 - val_accuracy: 0.9184
#
# Epoch 00017: val_loss did not improve from 0.00979
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1276 - accuracy: 0.9520 - val_loss: 0.0957 - val_accuracy: 0.9699
#
# Epoch 00018: val_loss did not improve from 0.00979
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1208 - accuracy: 0.9536 - val_loss: 0.1796 - val_accuracy: 0.9305
#
# Epoch 00019: val_loss did not improve from 0.00979
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1084 - accuracy: 0.9597 - val_loss: 0.2968 - val_accuracy: 0.8910
#
# Epoch 00020: val_loss did not improve from 0.00979
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1070 - accuracy: 0.9623 - val_loss: 0.1749 - val_accuracy: 0.9371
#
# Epoch 00021: val_loss did not improve from 0.00979
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1068 - accuracy: 0.9607 - val_loss: 0.1920 - val_accuracy: 0.9301
#
# Epoch 00022: val_loss did not improve from 0.00979
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1013 - accuracy: 0.9632 - val_loss: 0.1366 - val_accuracy: 0.9508
#
# Epoch 00023: val_loss did not improve from 0.00979
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0904 - accuracy: 0.9662 - val_loss: 0.1507 - val_accuracy: 0.9422
#
# Epoch 00024: val_loss did not improve from 0.00979
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0935 - accuracy: 0.9667 - val_loss: 0.2317 - val_accuracy: 0.9195
#
# Epoch 00025: val_loss did not improve from 0.00979
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0865 - accuracy: 0.9678 - val_loss: 0.1114 - val_accuracy: 0.9559
#
# Epoch 00026: val_loss did not improve from 0.00979
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0864 - accuracy: 0.9687 - val_loss: 0.1758 - val_accuracy: 0.9398
#
# Epoch 00027: val_loss did not improve from 0.00979
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0842 - accuracy: 0.9681 - val_loss: 0.1229 - val_accuracy: 0.9516
#
# Epoch 00028: val_loss did not improve from 0.00979
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0861 - accuracy: 0.9688 - val_loss: 0.2169 - val_accuracy: 0.9234
#
# Epoch 00029: val_loss did not improve from 0.00979
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0795 - accuracy: 0.9712 - val_loss: 0.1282 - val_accuracy: 0.9563
#
# Epoch 00030: val_loss did not improve from 0.00979
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0761 - accuracy: 0.9716 - val_loss: 0.2388 - val_accuracy: 0.9113
#
# Epoch 00031: val_loss did not improve from 0.00979
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0749 - accuracy: 0.9731 - val_loss: 0.1260 - val_accuracy: 0.9492
#
# Epoch 00032: val_loss did not improve from 0.00979
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0778 - accuracy: 0.9723 - val_loss: 0.1904 - val_accuracy: 0.9297
#
# Epoch 00033: val_loss did not improve from 0.00979
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0703 - accuracy: 0.9759 - val_loss: 0.1546 - val_accuracy: 0.9422
#
# Epoch 00034: val_loss did not improve from 0.00979
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0764 - accuracy: 0.9727 - val_loss: 0.1822 - val_accuracy: 0.9363
#
# Epoch 00035: val_loss did not improve from 0.00979
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0673 - accuracy: 0.9765 - val_loss: 0.1261 - val_accuracy: 0.9523
#
# Epoch 00036: val_loss did not improve from 0.00979
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0645 - accuracy: 0.9761 - val_loss: 0.1654 - val_accuracy: 0.9418
#
# Epoch 00037: val_loss did not improve from 0.00979
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0631 - accuracy: 0.9787 - val_loss: 0.2240 - val_accuracy: 0.9266
#
# Epoch 00038: val_loss did not improve from 0.00979
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0627 - accuracy: 0.9770 - val_loss: 0.1268 - val_accuracy: 0.9535
#
# Epoch 00039: val_loss did not improve from 0.00979
# Epoch 40/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00979
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1463 - accuracy: 0.9474 - val_loss: 0.2736 - val_accuracy: 0.9109
#
# Epoch 00021: val_loss did not improve from 0.00979
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1546 - accuracy: 0.9415 - val_loss: 0.2015 - val_accuracy: 0.9305
#
# Epoch 00022: val_loss did not improve from 0.00979
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1328 - accuracy: 0.9503 - val_loss: 0.2391 - val_accuracy: 0.9055
#
# Epoch 00023: val_loss did not improve from 0.00979
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1310 - accuracy: 0.9492 - val_loss: 0.2161 - val_accuracy: 0.9234
#
# Epoch 00024: val_loss did not improve from 0.00979
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1259 - accuracy: 0.9523 - val_loss: 0.2215 - val_accuracy: 0.9250
#
# Epoch 00025: val_loss did not improve from 0.00979
# Epoch 26/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1356 - accuracy: 0.9506 - val_loss: 0.2522 - val_accuracy: 0.9082
#
# Epoch 00026: val_loss did not improve from 0.00979
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1218 - accuracy: 0.9544 - val_loss: 0.4789 - val_accuracy: 0.8672
#
# Epoch 00027: val_loss did not improve from 0.00979
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1258 - accuracy: 0.9555 - val_loss: 0.3315 - val_accuracy: 0.9004
#
# Epoch 00028: val_loss did not improve from 0.00979
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1156 - accuracy: 0.9567 - val_loss: 0.4425 - val_accuracy: 0.8738
#
# Epoch 00029: val_loss did not improve from 0.00979
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1067 - accuracy: 0.9605 - val_loss: 0.4101 - val_accuracy: 0.8789
#
# Epoch 00030: val_loss did not improve from 0.00979
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1069 - accuracy: 0.9608 - val_loss: 0.2422 - val_accuracy: 0.9176
#
# Epoch 00031: val_loss did not improve from 0.00979
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0975 - accuracy: 0.9649 - val_loss: 0.2699 - val_accuracy: 0.9141
#
# Epoch 00032: val_loss did not improve from 0.00979
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0998 - accuracy: 0.9646 - val_loss: 0.2695 - val_accuracy: 0.9137
#
# Epoch 00033: val_loss did not improve from 0.00979
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0949 - accuracy: 0.9635 - val_loss: 0.1375 - val_accuracy: 0.9512
#
# Epoch 00034: val_loss did not improve from 0.00979
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0965 - accuracy: 0.9636 - val_loss: 0.4433 - val_accuracy: 0.8734
#
# Epoch 00035: val_loss did not improve from 0.00979
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0891 - accuracy: 0.9681 - val_loss: 0.2716 - val_accuracy: 0.9109
#
# Epoch 00036: val_loss did not improve from 0.00979
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0962 - accuracy: 0.9658 - val_loss: 0.1529 - val_accuracy: 0.9445
#
# Epoch 00037: val_loss did not improve from 0.00979
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0896 - accuracy: 0.9681 - val_loss: 0.1814 - val_accuracy: 0.9391
#
# Epoch 00038: val_loss did not improve from 0.00979
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0903 - accuracy: 0.9658 - val_loss: 0.1707 - val_accuracy: 0.9398
#
# Epoch 00039: val_loss did not improve from 0.00979
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0870 - accuracy: 0.9692 - val_loss: 0.2654 - val_accuracy: 0.9133
#
# Epoch 00040: val_loss did not improve from 0.00979
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0854 - accuracy: 0.9674 - val_loss: 0.1235 - val_accuracy: 0.9566
#
# Epoch 00041: val_loss did not improve from 0.00979
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0858 - accuracy: 0.9685 - val_loss: 0.3249 - val_accuracy: 0.8938
#
# Epoch 00042: val_loss did not improve from 0.00979
# Epoch 43/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0833 - accuracy: 0.9699 - val_loss: 0.2767 - val_accuracy: 0.9117
#
# Epoch 00043: val_loss did not improve from 0.00979
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0770 - accuracy: 0.9723 - val_loss: 0.2694 - val_accuracy: 0.9176
#
# Epoch 00044: val_loss did not improve from 0.00979
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0815 - accuracy: 0.9709 - val_loss: 0.1283 - val_accuracy: 0.9520
#
# Epoch 00045: val_loss did not improve from 0.00979
# Epoch 46/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0759 - accuracy: 0.9735 - val_loss: 0.2495 - val_accuracy: 0.9258
#
# Epoch 00046: val_loss did not improve from 0.00979
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0745 - accuracy: 0.9713 - val_loss: 0.2020 - val_accuracy: 0.9348
#
# Epoch 00047: val_loss did not improve from 0.00979
# Epoch 48/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0694 - accuracy: 0.9749 - val_loss: 0.2155 - val_accuracy: 0.9293
#
# Epoch 00048: val_loss did not improve from 0.00979
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0759 - accuracy: 0.9729 - val_loss: 0.1414 - val_accuracy: 0.9465
#
# Epoch 00049: val_loss did not improve from 0.00979
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0630 - accuracy: 0.9779 - val_loss: 0.2389 - val_accuracy: 0.9207
#
# Epoch 00050: val_loss did not improve from 0.00979
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0633 - accuracy: 0.9762 - val_loss: 0.2099 - val_accuracy: 0.9297
#
# Epoch 00051: val_loss did not improve from 0.00979
# Epoch 52/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0641 - accuracy: 0.9751 - val_loss: 0.0802 - val_accuracy: 0.9711
#
# Epoch 00052: val_loss did not improve from 0.00979
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0646 - accuracy: 0.9767 - val_loss: 0.2764 - val_accuracy: 0.9195
#
# Epoch 00053: val_loss did not improve from 0.00979
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0676 - accuracy: 0.9763 - val_loss: 0.1241 - val_accuracy: 0.9559
#
# Epoch 00054: val_loss did not improve from 0.00979
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0650 - accuracy: 0.9774 - val_loss: 0.1612 - val_accuracy: 0.9441
#
# Epoch 00055: val_loss did not improve from 0.00979
# Epoch 56/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0668 - accuracy: 0.9767 - val_loss: 0.2191 - val_accuracy: 0.9320
#
# Epoch 00056: val_loss did not improve from 0.00979
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0588 - accuracy: 0.9772 - val_loss: 0.0446 - val_accuracy: 0.9832
#
# Epoch 00057: val_loss did not improve from 0.00979
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0617 - accuracy: 0.9791 - val_loss: 0.1860 - val_accuracy: 0.9422
#
# Epoch 00058: val_loss did not improve from 0.00979
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0587 - accuracy: 0.9780 - val_loss: 0.0887 - val_accuracy: 0.9684
#
# Epoch 00059: val_loss did not improve from 0.00979
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0629 - accuracy: 0.9770 - val_loss: 0.1833 - val_accuracy: 0.9305
#
# Epoch 00060: val_loss did not improve from 0.00979
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0588 - accuracy: 0.9782 - val_loss: 0.1066 - val_accuracy: 0.9605
#
# Epoch 00061: val_loss did not improve from 0.00979
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0597 - accuracy: 0.9780 - val_loss: 0.2111 - val_accuracy: 0.9297
#
# Epoch 00062: val_loss did not improve from 0.00979
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0594 - accuracy: 0.9791 - val_loss: 0.0849 - val_accuracy: 0.9703
#
# Epoch 00063: val_loss did not improve from 0.00979
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0598 - accuracy: 0.9791 - val_loss: 0.1199 - val_accuracy: 0.9586
#
# Epoch 00064: val_loss did not improve from 0.00979
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0600 - accuracy: 0.9795 - val_loss: 0.1599 - val_accuracy: 0.9453
#
# Epoch 00065: val_loss did not improve from 0.00979
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0521 - accuracy: 0.9808 - val_loss: 0.1804 - val_accuracy: 0.9406
#
# Epoch 00066: val_loss did not improve from 0.00979
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0525 - accuracy: 0.9819 - val_loss: 0.0851 - val_accuracy: 0.9680
#
# Epoch 00067: val_loss did not improve from 0.00979
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0533 - accuracy: 0.9803 - val_loss: 0.1543 - val_accuracy: 0.9480
#
# Epoch 00068: val_loss did not improve from 0.00979
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0522 - accuracy: 0.9809 - val_loss: 0.1757 - val_accuracy: 0.9434
#
# Epoch 00069: val_loss did not improve from 0.00979
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0478 - accuracy: 0.9822 - val_loss: 0.1128 - val_accuracy: 0.9602
#
# Epoch 00070: val_loss did not improve from 0.00979
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0511 - accuracy: 0.9809 - val_loss: 0.1560 - val_accuracy: 0.9430
#
# Epoch 00071: val_loss did not improve from 0.00979
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0543 - accuracy: 0.9804 - val_loss: 0.1199 - val_accuracy: 0.9543
#
# Epoch 00072: val_loss did not improve from 0.00979
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0471 - accuracy: 0.9837 - val_loss: 0.2002 - val_accuracy: 0.9371
#
# Epoch 00073: val_loss did not improve from 0.00979
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0501 - accuracy: 0.9831 - val_loss: 0.2051 - val_accuracy: 0.9297
#
# Epoch 00074: val_loss did not improve from 0.00979
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0435 - accuracy: 0.9839 - val_loss: 0.2465 - val_accuracy: 0.9129
#
# Epoch 00075: val_loss did not improve from 0.00979
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0506 - accuracy: 0.9813 - val_loss: 0.0869 - val_accuracy: 0.9684
#
# Epoch 00076: val_loss did not improve from 0.00979
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0487 - accuracy: 0.9837 - val_loss: 0.1577 - val_accuracy: 0.9461
#
# Epoch 00077: val_loss did not improve from 0.00979
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0495 - accuracy: 0.9814 - val_loss: 0.1554 - val_accuracy: 0.9477
#
# Epoch 00078: val_loss did not improve from 0.00979
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0410 - accuracy: 0.9855 - val_loss: 0.0987 - val_accuracy: 0.9645
#
# Epoch 00079: val_loss did not improve from 0.00979
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0467 - accuracy: 0.9828 - val_loss: 0.0717 - val_accuracy: 0.9738
#
# Epoch 00080: val_loss did not improve from 0.00979
# Epoch 81/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0431 - accuracy: 0.9851 - val_loss: 0.2349 - val_accuracy: 0.9270
#
# Epoch 00081: val_loss did not improve from 0.00979
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0394 - accuracy: 0.9860 - val_loss: 0.1556 - val_accuracy: 0.9465
#
# Epoch 00082: val_loss did not improve from 0.00979
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0420 - accuracy: 0.9848 - val_loss: 0.0718 - val_accuracy: 0.9727
#
# Epoch 00083: val_loss did not improve from 0.00979
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0495 - accuracy: 0.9834 - val_loss: 0.0958 - val_accuracy: 0.9637
#
# Epoch 00084: val_loss did not improve from 0.00979
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0393 - accuracy: 0.9864 - val_loss: 0.1752 - val_accuracy: 0.9430
#
# Epoch 00085: val_loss did not improve from 0.00979
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0389 - accuracy: 0.9862 - val_loss: 0.1856 - val_accuracy: 0.9418
#
# Epoch 00086: val_loss did not improve from 0.00979
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0446 - accuracy: 0.9853 - val_loss: 0.0861 - val_accuracy: 0.9680
#
# Epoch 00087: val_loss did not improve from 0.00979
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0423 - accuracy: 0.9851 - val_loss: 0.1298 - val_accuracy: 0.9531
#
# Epoch 00088: val_loss did not improve from 0.00979
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0374 - accuracy: 0.9867 - val_loss: 0.0803 - val_accuracy: 0.9688
#
# Epoch 00089: val_loss did not improve from 0.00979
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0427 - accuracy: 0.9847 - val_loss: 0.0638 - val_accuracy: 0.9754
#
# Epoch 00090: val_loss did not improve from 0.00979
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0353 - accuracy: 0.9879 - val_loss: 0.1184 - val_accuracy: 0.9574
#
# Epoch 00091: val_loss did not improve from 0.00979
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0390 - accuracy: 0.9858 - val_loss: 0.2280 - val_accuracy: 0.9352
#
# Epoch 00092: val_loss did not improve from 0.00979
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0405 - accuracy: 0.9853 - val_loss: 0.0421 - val_accuracy: 0.9840
#
# Epoch 00093: val_loss did not improve from 0.00979
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0359 - accuracy: 0.9878 - val_loss: 0.2085 - val_accuracy: 0.9371
#
# Epoch 00094: val_loss did not improve from 0.00979
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0407 - accuracy: 0.9846 - val_loss: 0.0977 - val_accuracy: 0.9633
#
# Epoch 00095: val_loss did not improve from 0.00979
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0353 - accuracy: 0.9874 - val_loss: 0.0882 - val_accuracy: 0.9664
#
# Epoch 00096: val_loss did not improve from 0.00979
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0391 - accuracy: 0.9866 - val_loss: 0.1416 - val_accuracy: 0.9523
#
# Epoch 00097: val_loss did not improve from 0.00979
# Epoch 98/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0376 - accuracy: 0.9884 - val_loss: 0.1037 - val_accuracy: 0.9621
#
# Epoch 00098: val_loss did not improve from 0.00979
# Epoch 99/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0406 - accuracy: 0.9858 - val_loss: 0.1244 - val_accuracy: 0.9535
#
# Epoch 00099: val_loss did not improve from 0.00979
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0383 - accuracy: 0.9860 - val_loss: 0.0814 - val_accuracy: 0.9676
#
# Epoch 00100: val_loss did not improve from 0.00979
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9676
# Val Score:  [0.08143581449985504, 0.967578113079071]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      0.99      0.99       859
#            Brown spot       0.97      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.98      0.99       737
#
#              accuracy                           0.99      3200
#             macro avg       0.99      0.99      0.99      3200
#          weighted avg       0.99      0.99      0.99      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9931
# Test Accuracy: 99.31250214576721

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
