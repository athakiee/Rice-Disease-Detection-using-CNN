# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 2022-08-04 02:58:13.596255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:13.704675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:13.705400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:13.706846: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-04 02:58:13.707203: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:13.708146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:13.708885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:15.905903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:15.906772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:15.907450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 02:58:15.909032: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = SGD(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# 2022-08-04 02:58:19.261010: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-08-04 02:58:20.931797: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 320/320 [==============================] - 10s 8ms/step - loss: 0.9053 - accuracy: 0.6885 - val_loss: 2.7650 - val_accuracy: 0.4918
#
# Epoch 00001: val_loss improved from inf to 2.76498, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.4754 - accuracy: 0.8294 - val_loss: 0.6978 - val_accuracy: 0.7621
#
# Epoch 00002: val_loss improved from 2.76498 to 0.69777, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3553 - accuracy: 0.8692 - val_loss: 0.6521 - val_accuracy: 0.7859
#
# Epoch 00003: val_loss improved from 0.69777 to 0.65208, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2575 - accuracy: 0.9042 - val_loss: 0.2594 - val_accuracy: 0.9004
#
# Epoch 00004: val_loss improved from 0.65208 to 0.25942, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2176 - accuracy: 0.9167 - val_loss: 0.1807 - val_accuracy: 0.9281
#
# Epoch 00005: val_loss improved from 0.25942 to 0.18070, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1888 - accuracy: 0.9299 - val_loss: 0.3371 - val_accuracy: 0.8879
#
# Epoch 00006: val_loss did not improve from 0.18070
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1648 - accuracy: 0.9388 - val_loss: 0.2170 - val_accuracy: 0.9211
#
# Epoch 00007: val_loss did not improve from 0.18070
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1416 - accuracy: 0.9493 - val_loss: 0.2982 - val_accuracy: 0.8793
#
# Epoch 00008: val_loss did not improve from 0.18070
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1373 - accuracy: 0.9507 - val_loss: 0.4133 - val_accuracy: 0.8754
#
# Epoch 00009: val_loss did not improve from 0.18070
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1192 - accuracy: 0.9527 - val_loss: 0.2539 - val_accuracy: 0.9062
#
# Epoch 00010: val_loss did not improve from 0.18070
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1084 - accuracy: 0.9606 - val_loss: 0.3216 - val_accuracy: 0.9012
#
# Epoch 00011: val_loss did not improve from 0.18070
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1080 - accuracy: 0.9604 - val_loss: 0.2144 - val_accuracy: 0.9184
#
# Epoch 00012: val_loss did not improve from 0.18070
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0948 - accuracy: 0.9648 - val_loss: 0.1217 - val_accuracy: 0.9512
#
# Epoch 00013: val_loss improved from 0.18070 to 0.12169, saving model to model.h5
# Epoch 14/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0903 - accuracy: 0.9687 - val_loss: 0.1905 - val_accuracy: 0.9379
#
# Epoch 00014: val_loss did not improve from 0.12169
# Epoch 15/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0837 - accuracy: 0.9714 - val_loss: 0.3369 - val_accuracy: 0.9031
#
# Epoch 00015: val_loss did not improve from 0.12169
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0713 - accuracy: 0.9742 - val_loss: 0.4365 - val_accuracy: 0.8641
#
# Epoch 00016: val_loss did not improve from 0.12169
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0776 - accuracy: 0.9715 - val_loss: 0.2336 - val_accuracy: 0.9270
#
# Epoch 00017: val_loss did not improve from 0.12169
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0726 - accuracy: 0.9725 - val_loss: 0.2082 - val_accuracy: 0.9371
#
# Epoch 00018: val_loss did not improve from 0.12169
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0709 - accuracy: 0.9752 - val_loss: 0.2561 - val_accuracy: 0.9246
#
# Epoch 00019: val_loss did not improve from 0.12169
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0691 - accuracy: 0.9765 - val_loss: 0.0724 - val_accuracy: 0.9715
#
# Epoch 00020: val_loss improved from 0.12169 to 0.07244, saving model to model.h5
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0581 - accuracy: 0.9799 - val_loss: 0.2514 - val_accuracy: 0.9230
#
# Epoch 00021: val_loss did not improve from 0.07244
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0536 - accuracy: 0.9813 - val_loss: 0.1814 - val_accuracy: 0.9387
#
# Epoch 00022: val_loss did not improve from 0.07244
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0603 - accuracy: 0.9808 - val_loss: 0.1838 - val_accuracy: 0.9375
#
# Epoch 00023: val_loss did not improve from 0.07244
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0582 - accuracy: 0.9809 - val_loss: 0.1837 - val_accuracy: 0.9422
#
# Epoch 00024: val_loss did not improve from 0.07244
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0564 - accuracy: 0.9808 - val_loss: 0.0675 - val_accuracy: 0.9723
#
# Epoch 00025: val_loss improved from 0.07244 to 0.06746, saving model to model.h5
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0551 - accuracy: 0.9809 - val_loss: 0.2526 - val_accuracy: 0.9238
#
# Epoch 00026: val_loss did not improve from 0.06746
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.0858 - val_accuracy: 0.9652
#
# Epoch 00027: val_loss did not improve from 0.06746
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0513 - accuracy: 0.9813 - val_loss: 0.1587 - val_accuracy: 0.9465
#
# Epoch 00028: val_loss did not improve from 0.06746
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0444 - accuracy: 0.9855 - val_loss: 0.1582 - val_accuracy: 0.9445
#
# Epoch 00029: val_loss did not improve from 0.06746
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0476 - accuracy: 0.9843 - val_loss: 0.3354 - val_accuracy: 0.9027
#
# Epoch 00030: val_loss did not improve from 0.06746
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0418 - accuracy: 0.9857 - val_loss: 0.0688 - val_accuracy: 0.9746
#
# Epoch 00031: val_loss did not improve from 0.06746
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0437 - accuracy: 0.9849 - val_loss: 0.1780 - val_accuracy: 0.9395
#
# Epoch 00032: val_loss did not improve from 0.06746
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0469 - accuracy: 0.9835 - val_loss: 0.1555 - val_accuracy: 0.9477
#
# Epoch 00033: val_loss did not improve from 0.06746
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0429 - accuracy: 0.9858 - val_loss: 0.1338 - val_accuracy: 0.9516
#
# Epoch 00034: val_loss did not improve from 0.06746
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0378 - accuracy: 0.9875 - val_loss: 0.1292 - val_accuracy: 0.9527
#
# Epoch 00035: val_loss did not improve from 0.06746
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0343 - accuracy: 0.9894 - val_loss: 0.0600 - val_accuracy: 0.9750
#
# Epoch 00036: val_loss improved from 0.06746 to 0.05999, saving model to model.h5
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0391 - accuracy: 0.9855 - val_loss: 0.2602 - val_accuracy: 0.9250
#
# Epoch 00037: val_loss did not improve from 0.05999
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0371 - accuracy: 0.9875 - val_loss: 0.1751 - val_accuracy: 0.9379
#
# Epoch 00038: val_loss did not improve from 0.05999
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0352 - accuracy: 0.9885 - val_loss: 0.0702 - val_accuracy: 0.9711
#
# Epoch 00039: val_loss did not improve from 0.05999
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0405 - accuracy: 0.9857 - val_loss: 0.1194 - val_accuracy: 0.9586
#
# Epoch 00040: val_loss did not improve from 0.05999
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0351 - accuracy: 0.9882 - val_loss: 0.0378 - val_accuracy: 0.9859
#
# Epoch 00041: val_loss improved from 0.05999 to 0.03785, saving model to model.h5
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 0.1086 - val_accuracy: 0.9598
#
# Epoch 00042: val_loss did not improve from 0.03785
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.0929 - val_accuracy: 0.9633
#
# Epoch 00043: val_loss did not improve from 0.03785
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0341 - accuracy: 0.9881 - val_loss: 0.1138 - val_accuracy: 0.9574
#
# Epoch 00044: val_loss did not improve from 0.03785
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0304 - accuracy: 0.9906 - val_loss: 0.1258 - val_accuracy: 0.9512
#
# Epoch 00045: val_loss did not improve from 0.03785
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 0.2681 - val_accuracy: 0.9215
#
# Epoch 00046: val_loss did not improve from 0.03785
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0308 - accuracy: 0.9899 - val_loss: 0.0874 - val_accuracy: 0.9656
#
# Epoch 00047: val_loss did not improve from 0.03785
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0306 - accuracy: 0.9903 - val_loss: 0.2225 - val_accuracy: 0.9355
#
# Epoch 00048: val_loss did not improve from 0.03785
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0297 - accuracy: 0.9904 - val_loss: 0.0313 - val_accuracy: 0.9887
#
# Epoch 00049: val_loss improved from 0.03785 to 0.03127, saving model to model.h5
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0284 - accuracy: 0.9914 - val_loss: 0.0170 - val_accuracy: 0.9930
#
# Epoch 00050: val_loss improved from 0.03127 to 0.01699, saving model to model.h5
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0307 - accuracy: 0.9899 - val_loss: 0.0370 - val_accuracy: 0.9855
#
# Epoch 00051: val_loss did not improve from 0.01699
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0279 - accuracy: 0.9905 - val_loss: 0.2702 - val_accuracy: 0.9230
#
# Epoch 00052: val_loss did not improve from 0.01699
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0302 - accuracy: 0.9902 - val_loss: 0.1044 - val_accuracy: 0.9594
#
# Epoch 00053: val_loss did not improve from 0.01699
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0260 - accuracy: 0.9911 - val_loss: 0.0984 - val_accuracy: 0.9617
#
# Epoch 00054: val_loss did not improve from 0.01699
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0234 - accuracy: 0.9931 - val_loss: 0.0744 - val_accuracy: 0.9699
#
# Epoch 00055: val_loss did not improve from 0.01699
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0256 - accuracy: 0.9920 - val_loss: 0.0537 - val_accuracy: 0.9777
#
# Epoch 00056: val_loss did not improve from 0.01699
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0755 - val_accuracy: 0.9727
#
# Epoch 00057: val_loss did not improve from 0.01699
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0268 - accuracy: 0.9905 - val_loss: 0.0195 - val_accuracy: 0.9930
#
# Epoch 00058: val_loss did not improve from 0.01699
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0236 - accuracy: 0.9924 - val_loss: 0.0390 - val_accuracy: 0.9832
#
# Epoch 00059: val_loss did not improve from 0.01699
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0235 - accuracy: 0.9921 - val_loss: 0.0515 - val_accuracy: 0.9793
#
# Epoch 00060: val_loss did not improve from 0.01699
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.0653 - val_accuracy: 0.9738
#
# Epoch 00061: val_loss did not improve from 0.01699
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0293 - accuracy: 0.9907 - val_loss: 0.0433 - val_accuracy: 0.9816
#
# Epoch 00062: val_loss did not improve from 0.01699
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0254 - accuracy: 0.9923 - val_loss: 0.1200 - val_accuracy: 0.9563
#
# Epoch 00063: val_loss did not improve from 0.01699
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0232 - accuracy: 0.9912 - val_loss: 0.0284 - val_accuracy: 0.9879
#
# Epoch 00064: val_loss did not improve from 0.01699
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0257 - accuracy: 0.9916 - val_loss: 0.1038 - val_accuracy: 0.9602
#
# Epoch 00065: val_loss did not improve from 0.01699
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9924 - val_loss: 0.0580 - val_accuracy: 0.9770
#
# Epoch 00066: val_loss did not improve from 0.01699
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0234 - accuracy: 0.9933 - val_loss: 0.0385 - val_accuracy: 0.9832
#
# Epoch 00067: val_loss did not improve from 0.01699
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9912 - val_loss: 0.0159 - val_accuracy: 0.9926
#
# Epoch 00068: val_loss improved from 0.01699 to 0.01590, saving model to model.h5
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0223 - accuracy: 0.9927 - val_loss: 0.0853 - val_accuracy: 0.9711
#
# Epoch 00069: val_loss did not improve from 0.01590
# Epoch 70/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0254 - accuracy: 0.9920 - val_loss: 0.0795 - val_accuracy: 0.9660
#
# Epoch 00070: val_loss did not improve from 0.01590
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 0.0323 - val_accuracy: 0.9883
#
# Epoch 00071: val_loss did not improve from 0.01590
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0196 - accuracy: 0.9920 - val_loss: 0.0454 - val_accuracy: 0.9840
#
# Epoch 00072: val_loss did not improve from 0.01590
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9920 - val_loss: 0.1044 - val_accuracy: 0.9652
#
# Epoch 00073: val_loss did not improve from 0.01590
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.0294 - val_accuracy: 0.9895
#
# Epoch 00074: val_loss did not improve from 0.01590
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0211 - accuracy: 0.9925 - val_loss: 0.1492 - val_accuracy: 0.9512
#
# Epoch 00075: val_loss did not improve from 0.01590
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0214 - accuracy: 0.9926 - val_loss: 0.0372 - val_accuracy: 0.9844
#
# Epoch 00076: val_loss did not improve from 0.01590
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0197 - accuracy: 0.9922 - val_loss: 0.1149 - val_accuracy: 0.9598
#
# Epoch 00077: val_loss did not improve from 0.01590
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 0.0246 - val_accuracy: 0.9926
#
# Epoch 00078: val_loss did not improve from 0.01590
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9928 - val_loss: 0.1684 - val_accuracy: 0.9453
#
# Epoch 00079: val_loss did not improve from 0.01590
# Epoch 80/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.0401 - val_accuracy: 0.9836
#
# Epoch 00080: val_loss did not improve from 0.01590
# Epoch 81/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 0.0893 - val_accuracy: 0.9691
#
# Epoch 00081: val_loss did not improve from 0.01590
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.0379 - val_accuracy: 0.9852
#
# Epoch 00082: val_loss did not improve from 0.01590
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.0376 - val_accuracy: 0.9855
#
# Epoch 00083: val_loss did not improve from 0.01590
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.0493 - val_accuracy: 0.9797
#
# Epoch 00084: val_loss did not improve from 0.01590
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0201 - val_accuracy: 0.9926
#
# Epoch 00085: val_loss did not improve from 0.01590
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0160 - accuracy: 0.9941 - val_loss: 0.0301 - val_accuracy: 0.9895
#
# Epoch 00086: val_loss did not improve from 0.01590
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.0283 - val_accuracy: 0.9895
#
# Epoch 00087: val_loss did not improve from 0.01590
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0193 - accuracy: 0.9932 - val_loss: 0.0631 - val_accuracy: 0.9727
#
# Epoch 00088: val_loss did not improve from 0.01590
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.0320 - val_accuracy: 0.9898
#
# Epoch 00089: val_loss did not improve from 0.01590
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0170 - accuracy: 0.9939 - val_loss: 0.0638 - val_accuracy: 0.9746
#
# Epoch 00090: val_loss did not improve from 0.01590
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9942 - val_loss: 0.0168 - val_accuracy: 0.9918
#
# Epoch 00091: val_loss did not improve from 0.01590
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0172 - accuracy: 0.9940 - val_loss: 0.0231 - val_accuracy: 0.9914
#
# Epoch 00092: val_loss did not improve from 0.01590
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.2202 - val_accuracy: 0.9332
#
# Epoch 00093: val_loss did not improve from 0.01590
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9936 - val_loss: 0.0177 - val_accuracy: 0.9930
#
# Epoch 00094: val_loss did not improve from 0.01590
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0181 - accuracy: 0.9935 - val_loss: 0.0099 - val_accuracy: 0.9949
#
# Epoch 00095: val_loss improved from 0.01590 to 0.00989, saving model to model.h5
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0192 - accuracy: 0.9936 - val_loss: 0.1741 - val_accuracy: 0.9496
#
# Epoch 00096: val_loss did not improve from 0.00989
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0179 - accuracy: 0.9935 - val_loss: 0.0493 - val_accuracy: 0.9801
#
# Epoch 00097: val_loss did not improve from 0.00989
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0457 - val_accuracy: 0.9832
#
# Epoch 00098: val_loss did not improve from 0.00989
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0200 - accuracy: 0.9934 - val_loss: 0.0355 - val_accuracy: 0.9855
#
# Epoch 00099: val_loss did not improve from 0.00989
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.0515 - val_accuracy: 0.9801
#
# Epoch 00100: val_loss did not improve from 0.00989
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0515 - accuracy: 0.9801
# Val Score:  [0.051508981734514236, 0.9800781011581421]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.9762 - accuracy: 0.6632 - val_loss: 1.6163 - val_accuracy: 0.4871
#
# Epoch 00001: val_loss did not improve from 0.00989
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.5498 - accuracy: 0.7981 - val_loss: 0.4978 - val_accuracy: 0.8020
#
# Epoch 00002: val_loss did not improve from 0.00989
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.4178 - accuracy: 0.8447 - val_loss: 0.5619 - val_accuracy: 0.8102
#
# Epoch 00003: val_loss did not improve from 0.00989
# Epoch 4/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.3321 - accuracy: 0.8804 - val_loss: 0.3890 - val_accuracy: 0.8547
#
# Epoch 00004: val_loss did not improve from 0.00989
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2775 - accuracy: 0.8975 - val_loss: 0.3879 - val_accuracy: 0.8492
#
# Epoch 00005: val_loss did not improve from 0.00989
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2246 - accuracy: 0.9157 - val_loss: 0.5627 - val_accuracy: 0.8207
#
# Epoch 00006: val_loss did not improve from 0.00989
# Epoch 7/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2023 - accuracy: 0.9229 - val_loss: 0.7598 - val_accuracy: 0.7742
#
# Epoch 00007: val_loss did not improve from 0.00989
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1839 - accuracy: 0.9285 - val_loss: 0.5852 - val_accuracy: 0.8160
#
# Epoch 00008: val_loss did not improve from 0.00989
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1752 - accuracy: 0.9356 - val_loss: 0.2693 - val_accuracy: 0.8961
#
# Epoch 00009: val_loss did not improve from 0.00989
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1597 - accuracy: 0.9395 - val_loss: 0.4989 - val_accuracy: 0.8328
#
# Epoch 00010: val_loss did not improve from 0.00989
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1432 - accuracy: 0.9490 - val_loss: 0.3878 - val_accuracy: 0.8559
#
# Epoch 00011: val_loss did not improve from 0.00989
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1376 - accuracy: 0.9477 - val_loss: 0.2980 - val_accuracy: 0.8879
#
# Epoch 00012: val_loss did not improve from 0.00989
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1207 - accuracy: 0.9549 - val_loss: 0.3632 - val_accuracy: 0.8676
#
# Epoch 00013: val_loss did not improve from 0.00989
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1179 - accuracy: 0.9561 - val_loss: 0.3628 - val_accuracy: 0.8711
#
# Epoch 00014: val_loss did not improve from 0.00989
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1146 - accuracy: 0.9588 - val_loss: 0.3286 - val_accuracy: 0.8875
#
# Epoch 00015: val_loss did not improve from 0.00989
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1077 - accuracy: 0.9622 - val_loss: 0.2447 - val_accuracy: 0.9082
#
# Epoch 00016: val_loss did not improve from 0.00989
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1021 - accuracy: 0.9632 - val_loss: 0.2262 - val_accuracy: 0.9184
#
# Epoch 00017: val_loss did not improve from 0.00989
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0981 - accuracy: 0.9637 - val_loss: 0.3351 - val_accuracy: 0.8793
#
# Epoch 00018: val_loss did not improve from 0.00989
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0969 - accuracy: 0.9634 - val_loss: 0.1977 - val_accuracy: 0.9277
#
# Epoch 00019: val_loss did not improve from 0.00989
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0858 - accuracy: 0.9702 - val_loss: 0.3256 - val_accuracy: 0.8938
#
# Epoch 00020: val_loss did not improve from 0.00989
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0901 - accuracy: 0.9684 - val_loss: 0.2494 - val_accuracy: 0.9027
#
# Epoch 00021: val_loss did not improve from 0.00989
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0835 - accuracy: 0.9712 - val_loss: 0.2347 - val_accuracy: 0.9133
#
# Epoch 00022: val_loss did not improve from 0.00989
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0856 - accuracy: 0.9691 - val_loss: 0.4646 - val_accuracy: 0.8586
#
# Epoch 00023: val_loss did not improve from 0.00989
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0751 - accuracy: 0.9729 - val_loss: 0.4202 - val_accuracy: 0.8609
#
# Epoch 00024: val_loss did not improve from 0.00989
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0776 - accuracy: 0.9738 - val_loss: 0.2606 - val_accuracy: 0.9062
#
# Epoch 00025: val_loss did not improve from 0.00989
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0721 - accuracy: 0.9749 - val_loss: 0.1895 - val_accuracy: 0.9246
#
# Epoch 00026: val_loss did not improve from 0.00989
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0740 - accuracy: 0.9748 - val_loss: 0.2614 - val_accuracy: 0.9059
#
# Epoch 00027: val_loss did not improve from 0.00989
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0750 - accuracy: 0.9746 - val_loss: 0.1795 - val_accuracy: 0.9316
#
# Epoch 00028: val_loss did not improve from 0.00989
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0678 - accuracy: 0.9772 - val_loss: 0.1482 - val_accuracy: 0.9402
#
# Epoch 00029: val_loss did not improve from 0.00989
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0675 - accuracy: 0.9752 - val_loss: 0.2098 - val_accuracy: 0.9215
#
# Epoch 00030: val_loss did not improve from 0.00989
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0595 - accuracy: 0.9794 - val_loss: 0.1394 - val_accuracy: 0.9457
#
# Epoch 00031: val_loss did not improve from 0.00989
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0622 - accuracy: 0.9780 - val_loss: 0.2741 - val_accuracy: 0.9086
#
# Epoch 00032: val_loss did not improve from 0.00989
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0636 - accuracy: 0.9780 - val_loss: 0.1890 - val_accuracy: 0.9285
#
# Epoch 00033: val_loss did not improve from 0.00989
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0612 - accuracy: 0.9783 - val_loss: 0.2017 - val_accuracy: 0.9227
#
# Epoch 00034: val_loss did not improve from 0.00989
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0669 - accuracy: 0.9783 - val_loss: 0.2279 - val_accuracy: 0.9195
#
# Epoch 00035: val_loss did not improve from 0.00989
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0605 - accuracy: 0.9785 - val_loss: 0.1568 - val_accuracy: 0.9367
#
# Epoch 00036: val_loss did not improve from 0.00989
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0542 - accuracy: 0.9807 - val_loss: 0.1572 - val_accuracy: 0.9371
#
# Epoch 00037: val_loss did not improve from 0.00989
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0556 - accuracy: 0.9811 - val_loss: 0.3512 - val_accuracy: 0.8855
#
# Epoch 00038: val_loss did not improve from 0.00989
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0517 - accuracy: 0.9826 - val_loss: 0.1330 - val_accuracy: 0.9449
#
# Epoch 00039: val_loss did not improve from 0.00989
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0569 - accuracy: 0.9802 - val_loss: 0.2569 - val_accuracy: 0.9148
#
# Epoch 00040: val_loss did not improve from 0.00989
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0495 - accuracy: 0.9825 - val_loss: 0.2629 - val_accuracy: 0.9066
#
# Epoch 00041: val_loss did not improve from 0.00989
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0565 - accuracy: 0.9814 - val_loss: 0.1790 - val_accuracy: 0.9297
#
# Epoch 00042: val_loss did not improve from 0.00989
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0442 - accuracy: 0.9852 - val_loss: 0.1952 - val_accuracy: 0.9277
#
# Epoch 00043: val_loss did not improve from 0.00989
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0467 - accuracy: 0.9842 - val_loss: 0.1867 - val_accuracy: 0.9324
#
# Epoch 00044: val_loss did not improve from 0.00989
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0430 - accuracy: 0.9842 - val_loss: 0.2484 - val_accuracy: 0.9164
#
# Epoch 00045: val_loss did not improve from 0.00989
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0461 - accuracy: 0.9830 - val_loss: 0.1686 - val_accuracy: 0.9371
#
# Epoch 00046: val_loss did not improve from 0.00989
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0484 - accuracy: 0.9832 - val_loss: 0.1739 - val_accuracy: 0.9371
#
# Epoch 00047: val_loss did not improve from 0.00989
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0426 - accuracy: 0.9850 - val_loss: 0.1421 - val_accuracy: 0.9492
#
# Epoch 00048: val_loss did not improve from 0.00989
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0433 - accuracy: 0.9849 - val_loss: 0.1390 - val_accuracy: 0.9473
#
# Epoch 00049: val_loss did not improve from 0.00989
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0438 - accuracy: 0.9854 - val_loss: 0.3073 - val_accuracy: 0.9078
#
# Epoch 00050: val_loss did not improve from 0.00989
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0409 - accuracy: 0.9844 - val_loss: 0.1656 - val_accuracy: 0.9391
#
# Epoch 00051: val_loss did not improve from 0.00989
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0413 - accuracy: 0.9850 - val_loss: 0.1731 - val_accuracy: 0.9371
#
# Epoch 00052: val_loss did not improve from 0.00989
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0398 - accuracy: 0.9849 - val_loss: 0.1838 - val_accuracy: 0.9320
#
# Epoch 00053: val_loss did not improve from 0.00989
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0429 - accuracy: 0.9855 - val_loss: 0.1826 - val_accuracy: 0.9340
#
# Epoch 00054: val_loss did not improve from 0.00989
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0436 - accuracy: 0.9854 - val_loss: 0.1834 - val_accuracy: 0.9359
#
# Epoch 00055: val_loss did not improve from 0.00989
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0376 - accuracy: 0.9862 - val_loss: 0.1485 - val_accuracy: 0.9465
#
# Epoch 00056: val_loss did not improve from 0.00989
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0427 - accuracy: 0.9858 - val_loss: 0.2222 - val_accuracy: 0.9262
#
# Epoch 00057: val_loss did not improve from 0.00989
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0339 - accuracy: 0.9888 - val_loss: 0.1815 - val_accuracy: 0.9395
#
# Epoch 00058: val_loss did not improve from 0.00989
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0431 - accuracy: 0.9848 - val_loss: 0.2379 - val_accuracy: 0.9207
#
# Epoch 00059: val_loss did not improve from 0.00989
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0361 - accuracy: 0.9873 - val_loss: 0.1539 - val_accuracy: 0.9395
#
# Epoch 00060: val_loss did not improve from 0.00989
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 0.1542 - val_accuracy: 0.9434
#
# Epoch 00061: val_loss did not improve from 0.00989
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0373 - accuracy: 0.9864 - val_loss: 0.1933 - val_accuracy: 0.9238
#
# Epoch 00062: val_loss did not improve from 0.00989
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0325 - accuracy: 0.9889 - val_loss: 0.1563 - val_accuracy: 0.9469
#
# Epoch 00063: val_loss did not improve from 0.00989
# Epoch 64/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0313 - accuracy: 0.9897 - val_loss: 0.1779 - val_accuracy: 0.9363
#
# Epoch 00064: val_loss did not improve from 0.00989
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0316 - accuracy: 0.9897 - val_loss: 0.1166 - val_accuracy: 0.9559
#
# Epoch 00065: val_loss did not improve from 0.00989
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0339 - accuracy: 0.9881 - val_loss: 0.1237 - val_accuracy: 0.9539
#
# Epoch 00066: val_loss did not improve from 0.00989
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0305 - accuracy: 0.9916 - val_loss: 0.1248 - val_accuracy: 0.9531
#
# Epoch 00067: val_loss did not improve from 0.00989
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0323 - accuracy: 0.9888 - val_loss: 0.1300 - val_accuracy: 0.9512
#
# Epoch 00068: val_loss did not improve from 0.00989
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0327 - accuracy: 0.9887 - val_loss: 0.1218 - val_accuracy: 0.9563
#
# Epoch 00069: val_loss did not improve from 0.00989
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0306 - accuracy: 0.9892 - val_loss: 0.1618 - val_accuracy: 0.9441
#
# Epoch 00070: val_loss did not improve from 0.00989
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0317 - accuracy: 0.9885 - val_loss: 0.2442 - val_accuracy: 0.9230
#
# Epoch 00071: val_loss did not improve from 0.00989
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0309 - accuracy: 0.9900 - val_loss: 0.1522 - val_accuracy: 0.9441
#
# Epoch 00072: val_loss did not improve from 0.00989
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0310 - accuracy: 0.9891 - val_loss: 0.1058 - val_accuracy: 0.9621
#
# Epoch 00073: val_loss did not improve from 0.00989
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0290 - accuracy: 0.9895 - val_loss: 0.2063 - val_accuracy: 0.9324
#
# Epoch 00074: val_loss did not improve from 0.00989
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0335 - accuracy: 0.9884 - val_loss: 0.2309 - val_accuracy: 0.9254
#
# Epoch 00075: val_loss did not improve from 0.00989
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0294 - accuracy: 0.9890 - val_loss: 0.0782 - val_accuracy: 0.9758
#
# Epoch 00076: val_loss did not improve from 0.00989
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0245 - accuracy: 0.9913 - val_loss: 0.2378 - val_accuracy: 0.9258
#
# Epoch 00077: val_loss did not improve from 0.00989
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0303 - accuracy: 0.9893 - val_loss: 0.2251 - val_accuracy: 0.9297
#
# Epoch 00078: val_loss did not improve from 0.00989
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 0.0825 - val_accuracy: 0.9730
#
# Epoch 00079: val_loss did not improve from 0.00989
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0264 - accuracy: 0.9907 - val_loss: 0.1731 - val_accuracy: 0.9320
#
# Epoch 00080: val_loss did not improve from 0.00989
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0285 - accuracy: 0.9901 - val_loss: 0.2234 - val_accuracy: 0.9277
#
# Epoch 00081: val_loss did not improve from 0.00989
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0266 - accuracy: 0.9911 - val_loss: 0.1161 - val_accuracy: 0.9563
#
# Epoch 00082: val_loss did not improve from 0.00989
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0278 - accuracy: 0.9909 - val_loss: 0.1936 - val_accuracy: 0.9328
#
# Epoch 00083: val_loss did not improve from 0.00989
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0265 - accuracy: 0.9903 - val_loss: 0.0821 - val_accuracy: 0.9691
#
# Epoch 00084: val_loss did not improve from 0.00989
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0275 - accuracy: 0.9903 - val_loss: 0.1103 - val_accuracy: 0.9645
#
# Epoch 00085: val_loss did not improve from 0.00989
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0267 - accuracy: 0.9899 - val_loss: 0.1228 - val_accuracy: 0.9555
#
# Epoch 00086: val_loss did not improve from 0.00989
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0245 - accuracy: 0.9926 - val_loss: 0.1662 - val_accuracy: 0.9445
#
# Epoch 00087: val_loss did not improve from 0.00989
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0251 - accuracy: 0.9914 - val_loss: 0.0952 - val_accuracy: 0.9641
#
# Epoch 00088: val_loss did not improve from 0.00989
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0236 - accuracy: 0.9915 - val_loss: 0.1126 - val_accuracy: 0.9566
#
# Epoch 00089: val_loss did not improve from 0.00989
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0261 - accuracy: 0.9907 - val_loss: 0.0994 - val_accuracy: 0.9609
#
# Epoch 00090: val_loss did not improve from 0.00989
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0297 - accuracy: 0.9893 - val_loss: 0.1974 - val_accuracy: 0.9332
#
# Epoch 00091: val_loss did not improve from 0.00989
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0249 - accuracy: 0.9912 - val_loss: 0.0719 - val_accuracy: 0.9754
#
# Epoch 00092: val_loss did not improve from 0.00989
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0243 - accuracy: 0.9922 - val_loss: 0.1375 - val_accuracy: 0.9484
#
# Epoch 00093: val_loss did not improve from 0.00989
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0267 - accuracy: 0.9907 - val_loss: 0.1088 - val_accuracy: 0.9598
#
# Epoch 00094: val_loss did not improve from 0.00989
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 0.0800 - val_accuracy: 0.9695
#
# Epoch 00095: val_loss did not improve from 0.00989
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0243 - accuracy: 0.9915 - val_loss: 0.1027 - val_accuracy: 0.9609
#
# Epoch 00096: val_loss did not improve from 0.00989
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0222 - accuracy: 0.9930 - val_loss: 0.0670 - val_accuracy: 0.9781
#
# Epoch 00097: val_loss did not improve from 0.00989
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0210 - accuracy: 0.9924 - val_loss: 0.1618 - val_accuracy: 0.9418
#
# Epoch 00098: val_loss did not improve from 0.00989
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.0978 - val_accuracy: 0.9613
#
# Epoch 00099: val_loss did not improve from 0.00989
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.1946 - val_accuracy: 0.9352
#
# Epoch 00100: val_loss did not improve from 0.00989
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1946 - accuracy: 0.9352
# Val Score:  [0.194586843252182, 0.9351562261581421]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.8985 - accuracy: 0.6867 - val_loss: 1.4462 - val_accuracy: 0.5250
#
# Epoch 00001: val_loss did not improve from 0.00989
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.4836 - accuracy: 0.8269 - val_loss: 0.3096 - val_accuracy: 0.8820
#
# Epoch 00002: val_loss did not improve from 0.00989
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3740 - accuracy: 0.8646 - val_loss: 0.2212 - val_accuracy: 0.9117
#
# Epoch 00003: val_loss did not improve from 0.00989
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3115 - accuracy: 0.8888 - val_loss: 0.2833 - val_accuracy: 0.9023
#
# Epoch 00004: val_loss did not improve from 0.00989
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2767 - accuracy: 0.8962 - val_loss: 0.2371 - val_accuracy: 0.8957
#
# Epoch 00005: val_loss did not improve from 0.00989
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2499 - accuracy: 0.9072 - val_loss: 0.2437 - val_accuracy: 0.8996
#
# Epoch 00006: val_loss did not improve from 0.00989
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2177 - accuracy: 0.9202 - val_loss: 0.3245 - val_accuracy: 0.8789
#
# Epoch 00007: val_loss did not improve from 0.00989
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1973 - accuracy: 0.9265 - val_loss: 0.3524 - val_accuracy: 0.8848
#
# Epoch 00008: val_loss did not improve from 0.00989
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1924 - accuracy: 0.9272 - val_loss: 0.3498 - val_accuracy: 0.8828
#
# Epoch 00009: val_loss did not improve from 0.00989
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1749 - accuracy: 0.9371 - val_loss: 0.2585 - val_accuracy: 0.9059
#
# Epoch 00010: val_loss did not improve from 0.00989
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1658 - accuracy: 0.9363 - val_loss: 0.2887 - val_accuracy: 0.8824
#
# Epoch 00011: val_loss did not improve from 0.00989
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1452 - accuracy: 0.9465 - val_loss: 0.1605 - val_accuracy: 0.9418
#
# Epoch 00012: val_loss did not improve from 0.00989
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1437 - accuracy: 0.9462 - val_loss: 0.1599 - val_accuracy: 0.9398
#
# Epoch 00013: val_loss did not improve from 0.00989
# Epoch 14/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1273 - accuracy: 0.9517 - val_loss: 0.3741 - val_accuracy: 0.8828
#
# Epoch 00014: val_loss did not improve from 0.00989
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1245 - accuracy: 0.9529 - val_loss: 0.1873 - val_accuracy: 0.9328
#
# Epoch 00015: val_loss did not improve from 0.00989
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1231 - accuracy: 0.9539 - val_loss: 0.1678 - val_accuracy: 0.9395
#
# Epoch 00016: val_loss did not improve from 0.00989
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1151 - accuracy: 0.9563 - val_loss: 0.1788 - val_accuracy: 0.9332
#
# Epoch 00017: val_loss did not improve from 0.00989
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1076 - accuracy: 0.9618 - val_loss: 0.3742 - val_accuracy: 0.8734
#
# Epoch 00018: val_loss did not improve from 0.00989
# Epoch 19/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1134 - accuracy: 0.9597 - val_loss: 0.2752 - val_accuracy: 0.9051
#
# Epoch 00019: val_loss did not improve from 0.00989
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1066 - accuracy: 0.9591 - val_loss: 0.3187 - val_accuracy: 0.8887
#
# Epoch 00020: val_loss did not improve from 0.00989
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0943 - accuracy: 0.9670 - val_loss: 0.2078 - val_accuracy: 0.9199
#
# Epoch 00021: val_loss did not improve from 0.00989
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0921 - accuracy: 0.9670 - val_loss: 0.1782 - val_accuracy: 0.9371
#
# Epoch 00022: val_loss did not improve from 0.00989
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0942 - accuracy: 0.9650 - val_loss: 0.1455 - val_accuracy: 0.9465
#
# Epoch 00023: val_loss did not improve from 0.00989
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0877 - accuracy: 0.9672 - val_loss: 0.2958 - val_accuracy: 0.9105
#
# Epoch 00024: val_loss did not improve from 0.00989
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0905 - accuracy: 0.9665 - val_loss: 0.2146 - val_accuracy: 0.9273
#
# Epoch 00025: val_loss did not improve from 0.00989
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0812 - accuracy: 0.9697 - val_loss: 0.1536 - val_accuracy: 0.9457
#
# Epoch 00026: val_loss did not improve from 0.00989
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0842 - accuracy: 0.9701 - val_loss: 0.2958 - val_accuracy: 0.9031
#
# Epoch 00027: val_loss did not improve from 0.00989
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0804 - accuracy: 0.9704 - val_loss: 0.3538 - val_accuracy: 0.8934
#
# Epoch 00028: val_loss did not improve from 0.00989
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0798 - accuracy: 0.9711 - val_loss: 0.1826 - val_accuracy: 0.9320
#
# Epoch 00029: val_loss did not improve from 0.00989
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0656 - accuracy: 0.9780 - val_loss: 0.2539 - val_accuracy: 0.9191
#
# Epoch 00030: val_loss did not improve from 0.00989
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0718 - accuracy: 0.9733 - val_loss: 0.2116 - val_accuracy: 0.9238
#
# Epoch 00031: val_loss did not improve from 0.00989
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0695 - accuracy: 0.9760 - val_loss: 0.1924 - val_accuracy: 0.9344
#
# Epoch 00032: val_loss did not improve from 0.00989
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0653 - accuracy: 0.9773 - val_loss: 0.2456 - val_accuracy: 0.9223
#
# Epoch 00033: val_loss did not improve from 0.00989
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0684 - accuracy: 0.9752 - val_loss: 0.2014 - val_accuracy: 0.9312
#
# Epoch 00034: val_loss did not improve from 0.00989
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0704 - accuracy: 0.9760 - val_loss: 0.1858 - val_accuracy: 0.9418
#
# Epoch 00035: val_loss did not improve from 0.00989
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0675 - accuracy: 0.9763 - val_loss: 0.1936 - val_accuracy: 0.9340
#
# Epoch 00036: val_loss did not improve from 0.00989
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0592 - accuracy: 0.9785 - val_loss: 0.1330 - val_accuracy: 0.9559
#
# Epoch 00037: val_loss did not improve from 0.00989
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0602 - accuracy: 0.9788 - val_loss: 0.1242 - val_accuracy: 0.9570
#
# Epoch 00038: val_loss did not improve from 0.00989
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0551 - accuracy: 0.9806 - val_loss: 0.1849 - val_accuracy: 0.9336
#
# Epoch 00039: val_loss did not improve from 0.00989
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0614 - accuracy: 0.9792 - val_loss: 0.1826 - val_accuracy: 0.9438
#
# ...
#
# Epoch 00020: val_loss did not improve from 0.00989
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1116 - accuracy: 0.9597 - val_loss: 0.1431 - val_accuracy: 0.9434
#
# Epoch 00021: val_loss did not improve from 0.00989
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1028 - accuracy: 0.9608 - val_loss: 0.1437 - val_accuracy: 0.9465
#
# Epoch 00022: val_loss did not improve from 0.00989
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1070 - accuracy: 0.9612 - val_loss: 0.1317 - val_accuracy: 0.9500
#
# Epoch 00023: val_loss did not improve from 0.00989
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0936 - accuracy: 0.9671 - val_loss: 0.2526 - val_accuracy: 0.9020
#
# Epoch 00024: val_loss did not improve from 0.00989
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0970 - accuracy: 0.9637 - val_loss: 0.2171 - val_accuracy: 0.9137
#
# Epoch 00025: val_loss did not improve from 0.00989
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0914 - accuracy: 0.9684 - val_loss: 0.1645 - val_accuracy: 0.9391
#
# Epoch 00026: val_loss did not improve from 0.00989
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0984 - accuracy: 0.9652 - val_loss: 0.1199 - val_accuracy: 0.9527
#
# Epoch 00027: val_loss did not improve from 0.00989
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0882 - accuracy: 0.9696 - val_loss: 0.2563 - val_accuracy: 0.8961
#
# Epoch 00028: val_loss did not improve from 0.00989
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0825 - accuracy: 0.9691 - val_loss: 0.1598 - val_accuracy: 0.9312
#
# Epoch 00029: val_loss did not improve from 0.00989
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0866 - accuracy: 0.9687 - val_loss: 0.1991 - val_accuracy: 0.9219
#
# Epoch 00030: val_loss did not improve from 0.00989
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0853 - accuracy: 0.9693 - val_loss: 0.1314 - val_accuracy: 0.9461
#
# Epoch 00031: val_loss did not improve from 0.00989
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0834 - accuracy: 0.9690 - val_loss: 0.1209 - val_accuracy: 0.9539
#
# Epoch 00032: val_loss did not improve from 0.00989
# Epoch 33/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0703 - accuracy: 0.9745 - val_loss: 0.1539 - val_accuracy: 0.9398
#
# Epoch 00033: val_loss did not improve from 0.00989
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0778 - accuracy: 0.9736 - val_loss: 0.1951 - val_accuracy: 0.9215
#
# Epoch 00034: val_loss did not improve from 0.00989
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0705 - accuracy: 0.9760 - val_loss: 0.1243 - val_accuracy: 0.9488
#
# Epoch 00035: val_loss did not improve from 0.00989
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0708 - accuracy: 0.9757 - val_loss: 0.1390 - val_accuracy: 0.9492
#
# Epoch 00036: val_loss did not improve from 0.00989
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0685 - accuracy: 0.9757 - val_loss: 0.2317 - val_accuracy: 0.9184
#
# Epoch 00037: val_loss did not improve from 0.00989
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0714 - accuracy: 0.9750 - val_loss: 0.1118 - val_accuracy: 0.9570
#
# Epoch 00038: val_loss did not improve from 0.00989
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0697 - accuracy: 0.9740 - val_loss: 0.2009 - val_accuracy: 0.9281
#
# Epoch 00039: val_loss did not improve from 0.00989
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0684 - accuracy: 0.9761 - val_loss: 0.1021 - val_accuracy: 0.9547
#
# Epoch 00040: val_loss did not improve from 0.00989
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0610 - accuracy: 0.9780 - val_loss: 0.2514 - val_accuracy: 0.9152
#
# Epoch 00041: val_loss did not improve from 0.00989
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0634 - accuracy: 0.9774 - val_loss: 0.2726 - val_accuracy: 0.9133
#
# Epoch 00042: val_loss did not improve from 0.00989
# Epoch 43/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0581 - accuracy: 0.9801 - val_loss: 0.1356 - val_accuracy: 0.9473
#
# Epoch 00043: val_loss did not improve from 0.00989
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0594 - accuracy: 0.9795 - val_loss: 0.2899 - val_accuracy: 0.9055
#
# Epoch 00044: val_loss did not improve from 0.00989
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0561 - accuracy: 0.9811 - val_loss: 0.2329 - val_accuracy: 0.9207
#
# Epoch 00045: val_loss did not improve from 0.00989
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0585 - accuracy: 0.9804 - val_loss: 0.1777 - val_accuracy: 0.9344
#
# Epoch 00046: val_loss did not improve from 0.00989
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0558 - accuracy: 0.9819 - val_loss: 0.2847 - val_accuracy: 0.8988
#
# Epoch 00047: val_loss did not improve from 0.00989
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0573 - accuracy: 0.9799 - val_loss: 0.1025 - val_accuracy: 0.9609
#
# Epoch 00048: val_loss did not improve from 0.00989
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0489 - accuracy: 0.9821 - val_loss: 0.1983 - val_accuracy: 0.9270
#
# Epoch 00049: val_loss did not improve from 0.00989
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0554 - accuracy: 0.9808 - val_loss: 0.2699 - val_accuracy: 0.9039
#
# Epoch 00050: val_loss did not improve from 0.00989
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0493 - accuracy: 0.9837 - val_loss: 0.2097 - val_accuracy: 0.9207
#
# Epoch 00051: val_loss did not improve from 0.00989
# Epoch 52/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0576 - accuracy: 0.9795 - val_loss: 0.1920 - val_accuracy: 0.9301
#
# Epoch 00052: val_loss did not improve from 0.00989
# Epoch 53/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0548 - accuracy: 0.9807 - val_loss: 0.2883 - val_accuracy: 0.9141
#
# Epoch 00053: val_loss did not improve from 0.00989
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0561 - accuracy: 0.9808 - val_loss: 0.2029 - val_accuracy: 0.9273
#
# Epoch 00054: val_loss did not improve from 0.00989
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0476 - accuracy: 0.9826 - val_loss: 0.0959 - val_accuracy: 0.9629
#
# Epoch 00055: val_loss did not improve from 0.00989
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0452 - accuracy: 0.9835 - val_loss: 0.1853 - val_accuracy: 0.9289
#
# Epoch 00056: val_loss did not improve from 0.00989
# Epoch 57/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0483 - accuracy: 0.9829 - val_loss: 0.1693 - val_accuracy: 0.9375
#
# Epoch 00057: val_loss did not improve from 0.00989
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0459 - accuracy: 0.9834 - val_loss: 0.1500 - val_accuracy: 0.9453
#
# Epoch 00058: val_loss did not improve from 0.00989
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0462 - accuracy: 0.9836 - val_loss: 0.0797 - val_accuracy: 0.9719
#
# Epoch 00059: val_loss did not improve from 0.00989
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0429 - accuracy: 0.9858 - val_loss: 0.0970 - val_accuracy: 0.9590
#
# Epoch 00060: val_loss did not improve from 0.00989
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0495 - accuracy: 0.9831 - val_loss: 0.2041 - val_accuracy: 0.9262
#
# Epoch 00061: val_loss did not improve from 0.00989
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0475 - accuracy: 0.9836 - val_loss: 0.1708 - val_accuracy: 0.9379
#
# Epoch 00062: val_loss did not improve from 0.00989
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0484 - accuracy: 0.9831 - val_loss: 0.1119 - val_accuracy: 0.9512
#
# Epoch 00063: val_loss did not improve from 0.00989
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0382 - accuracy: 0.9870 - val_loss: 0.1714 - val_accuracy: 0.9332
#
# Epoch 00064: val_loss did not improve from 0.00989
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0420 - accuracy: 0.9848 - val_loss: 0.0770 - val_accuracy: 0.9699
#
# Epoch 00065: val_loss did not improve from 0.00989
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0426 - accuracy: 0.9844 - val_loss: 0.1738 - val_accuracy: 0.9371
#
# Epoch 00066: val_loss did not improve from 0.00989
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0392 - accuracy: 0.9871 - val_loss: 0.1103 - val_accuracy: 0.9570
#
# Epoch 00067: val_loss did not improve from 0.00989
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0373 - accuracy: 0.9869 - val_loss: 0.1326 - val_accuracy: 0.9523
#
# Epoch 00068: val_loss did not improve from 0.00989
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0362 - accuracy: 0.9871 - val_loss: 0.1239 - val_accuracy: 0.9465
#
# Epoch 00069: val_loss did not improve from 0.00989
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0418 - accuracy: 0.9846 - val_loss: 0.1159 - val_accuracy: 0.9574
#
# Epoch 00070: val_loss did not improve from 0.00989
# Epoch 71/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0388 - accuracy: 0.9875 - val_loss: 0.1198 - val_accuracy: 0.9563
#
# Epoch 00071: val_loss did not improve from 0.00989
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0356 - accuracy: 0.9876 - val_loss: 0.1950 - val_accuracy: 0.9312
#
# Epoch 00072: val_loss did not improve from 0.00989
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0401 - accuracy: 0.9861 - val_loss: 0.1714 - val_accuracy: 0.9363
#
# Epoch 00073: val_loss did not improve from 0.00989
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.1930 - val_accuracy: 0.9324
#
# Epoch 00074: val_loss did not improve from 0.00989
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0409 - accuracy: 0.9864 - val_loss: 0.1780 - val_accuracy: 0.9367
#
# Epoch 00075: val_loss did not improve from 0.00989
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0364 - accuracy: 0.9869 - val_loss: 0.1846 - val_accuracy: 0.9363
#
# Epoch 00076: val_loss did not improve from 0.00989
# Epoch 77/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0351 - accuracy: 0.9862 - val_loss: 0.1752 - val_accuracy: 0.9391
#
# Epoch 00077: val_loss did not improve from 0.00989
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0356 - accuracy: 0.9882 - val_loss: 0.1121 - val_accuracy: 0.9527
#
# Epoch 00078: val_loss did not improve from 0.00989
# Epoch 79/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0372 - accuracy: 0.9873 - val_loss: 0.2196 - val_accuracy: 0.9180
#
# Epoch 00079: val_loss did not improve from 0.00989
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0374 - accuracy: 0.9867 - val_loss: 0.1135 - val_accuracy: 0.9527
#
# Epoch 00080: val_loss did not improve from 0.00989
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0352 - accuracy: 0.9874 - val_loss: 0.1575 - val_accuracy: 0.9453
#
# Epoch 00081: val_loss did not improve from 0.00989
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0397 - accuracy: 0.9854 - val_loss: 0.1300 - val_accuracy: 0.9527
#
# Epoch 00082: val_loss did not improve from 0.00989
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0379 - accuracy: 0.9874 - val_loss: 0.1197 - val_accuracy: 0.9535
#
# Epoch 00083: val_loss did not improve from 0.00989
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0366 - accuracy: 0.9873 - val_loss: 0.1111 - val_accuracy: 0.9559
#
# Epoch 00084: val_loss did not improve from 0.00989
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0338 - accuracy: 0.9890 - val_loss: 0.1689 - val_accuracy: 0.9371
#
# Epoch 00085: val_loss did not improve from 0.00989
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0347 - accuracy: 0.9894 - val_loss: 0.1403 - val_accuracy: 0.9496
#
# Epoch 00086: val_loss did not improve from 0.00989
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0343 - accuracy: 0.9890 - val_loss: 0.1542 - val_accuracy: 0.9422
#
# Epoch 00087: val_loss did not improve from 0.00989
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0333 - accuracy: 0.9888 - val_loss: 0.1289 - val_accuracy: 0.9527
#
# Epoch 00088: val_loss did not improve from 0.00989
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0326 - accuracy: 0.9900 - val_loss: 0.1219 - val_accuracy: 0.9574
#
# Epoch 00089: val_loss did not improve from 0.00989
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0355 - accuracy: 0.9875 - val_loss: 0.0994 - val_accuracy: 0.9617
#
# Epoch 00090: val_loss did not improve from 0.00989
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0297 - accuracy: 0.9896 - val_loss: 0.1209 - val_accuracy: 0.9563
#
# Epoch 00091: val_loss did not improve from 0.00989
# Epoch 92/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0300 - accuracy: 0.9887 - val_loss: 0.0861 - val_accuracy: 0.9668
#
# Epoch 00092: val_loss did not improve from 0.00989
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0291 - accuracy: 0.9899 - val_loss: 0.0893 - val_accuracy: 0.9668
#
# Epoch 00093: val_loss did not improve from 0.00989
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0330 - accuracy: 0.9883 - val_loss: 0.1608 - val_accuracy: 0.9449
#
# Epoch 00094: val_loss did not improve from 0.00989
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0329 - accuracy: 0.9885 - val_loss: 0.1494 - val_accuracy: 0.9461
#
# Epoch 00095: val_loss did not improve from 0.00989
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0335 - accuracy: 0.9887 - val_loss: 0.1303 - val_accuracy: 0.9523
#
# Epoch 00096: val_loss did not improve from 0.00989
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0278 - accuracy: 0.9913 - val_loss: 0.1435 - val_accuracy: 0.9457
#
# Epoch 00097: val_loss did not improve from 0.00989
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0306 - accuracy: 0.9887 - val_loss: 0.1146 - val_accuracy: 0.9578
#
# Epoch 00098: val_loss did not improve from 0.00989
# Epoch 99/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0270 - accuracy: 0.9907 - val_loss: 0.1184 - val_accuracy: 0.9563
#
# Epoch 00099: val_loss did not improve from 0.00989
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0306 - accuracy: 0.9896 - val_loss: 0.0733 - val_accuracy: 0.9734
#
# Epoch 00100: val_loss did not improve from 0.00989
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.9734
# Val Score:  [0.07325313985347748, 0.973437488079071]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      0.99      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       0.99      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.9956
# Test Accuracy: 99.56250190734863

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
