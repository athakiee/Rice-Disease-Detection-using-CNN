# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **OPTIMIZER TEST -- USING RMSprop AND BEST RESULT OF HIDDEN LAYER(4)**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_147 (Conv2D)          (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_221 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_184 (Bat (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_86 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_123 (Dropout)        (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_148 (Conv2D)          (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_222 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_185 (Bat (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_149 (Conv2D)          (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_223 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_186 (Bat (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_87 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_124 (Dropout)        (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_150 (Conv2D)          (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_224 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_187 (Bat (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_37 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_74 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_225 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_188 (Bat (None, 1024)              4096
# _________________________________________________________________
# dropout_125 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_75 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_226 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = RMSprop(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 5s 12ms/step - loss: 0.4615 - accuracy: 0.8648 - val_loss: 5.3689 - val_accuracy: 0.4738
#
# Epoch 00001: val_loss improved from inf to 5.36894, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.1564 - accuracy: 0.9492 - val_loss: 0.9141 - val_accuracy: 0.8004
#
# Epoch 00002: val_loss improved from 5.36894 to 0.91408, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0953 - accuracy: 0.9695 - val_loss: 3.7414 - val_accuracy: 0.5531
#
# Epoch 00003: val_loss did not improve from 0.91408
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0722 - accuracy: 0.9782 - val_loss: 18.0288 - val_accuracy: 0.4437
#
# Epoch 00004: val_loss did not improve from 0.91408
# Epoch 5/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0566 - accuracy: 0.9827 - val_loss: 0.9003 - val_accuracy: 0.8223
#
# Epoch 00005: val_loss improved from 0.91408 to 0.90025, saving model to model.h5
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0511 - accuracy: 0.9858 - val_loss: 1.5204 - val_accuracy: 0.7375
#
# Epoch 00006: val_loss did not improve from 0.90025
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0490 - accuracy: 0.9859 - val_loss: 0.2800 - val_accuracy: 0.9219
#
# Epoch 00007: val_loss improved from 0.90025 to 0.27996, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0450 - accuracy: 0.9878 - val_loss: 0.1251 - val_accuracy: 0.9711
#
# Epoch 00008: val_loss improved from 0.27996 to 0.12512, saving model to model.h5
# Epoch 9/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0309 - accuracy: 0.9913 - val_loss: 0.0485 - val_accuracy: 0.9832
#
# Epoch 00009: val_loss improved from 0.12512 to 0.04846, saving model to model.h5
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0324 - accuracy: 0.9910 - val_loss: 0.1055 - val_accuracy: 0.9711
#
# Epoch 00010: val_loss did not improve from 0.04846
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0321 - accuracy: 0.9910 - val_loss: 0.0856 - val_accuracy: 0.9750
#
# Epoch 00011: val_loss did not improve from 0.04846
# Epoch 12/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0212 - accuracy: 0.9938 - val_loss: 0.5006 - val_accuracy: 0.8895
#
# Epoch 00012: val_loss did not improve from 0.04846
# Epoch 13/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0260 - accuracy: 0.9926 - val_loss: 0.3034 - val_accuracy: 0.9383
#
# Epoch 00013: val_loss did not improve from 0.04846
# Epoch 14/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0228 - accuracy: 0.9930 - val_loss: 0.1535 - val_accuracy: 0.9652
#
# Epoch 00014: val_loss did not improve from 0.04846
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0330 - accuracy: 0.9924 - val_loss: 0.2585 - val_accuracy: 0.9355
#
# Epoch 00015: val_loss did not improve from 0.04846
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0261 - accuracy: 0.9932 - val_loss: 0.0096 - val_accuracy: 0.9977
#
# Epoch 00016: val_loss improved from 0.04846 to 0.00965, saving model to model.h5
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0211 - accuracy: 0.9947 - val_loss: 0.0373 - val_accuracy: 0.9937
#
# Epoch 00017: val_loss did not improve from 0.00965
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0263 - accuracy: 0.9927 - val_loss: 0.4182 - val_accuracy: 0.9355
#
# Epoch 00018: val_loss did not improve from 0.00965
# Epoch 19/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0223 - accuracy: 0.9940 - val_loss: 1.3137 - val_accuracy: 0.8461
#
# Epoch 00019: val_loss did not improve from 0.00965
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0211 - accuracy: 0.9941 - val_loss: 1.8113 - val_accuracy: 0.8180
#
# Epoch 00020: val_loss did not improve from 0.00965
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0243 - accuracy: 0.9943 - val_loss: 2.3995 - val_accuracy: 0.7594
#
# Epoch 00021: val_loss did not improve from 0.00965
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0274 - accuracy: 0.9947 - val_loss: 3.9561 - val_accuracy: 0.6687
#
# Epoch 00022: val_loss did not improve from 0.00965
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0235 - accuracy: 0.9939 - val_loss: 0.2526 - val_accuracy: 0.9480
#
# Epoch 00023: val_loss did not improve from 0.00965
# Epoch 24/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0192 - accuracy: 0.9956 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00024: val_loss improved from 0.00965 to 0.00427, saving model to model.h5
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0211 - accuracy: 0.9938 - val_loss: 0.2276 - val_accuracy: 0.9656
#
# Epoch 00025: val_loss did not improve from 0.00427
# Epoch 26/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 0.1010 - val_accuracy: 0.9738
#
# Epoch 00026: val_loss did not improve from 0.00427
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0191 - accuracy: 0.9948 - val_loss: 0.3633 - val_accuracy: 0.9219
#
# Epoch 00027: val_loss did not improve from 0.00427
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0161 - accuracy: 0.9961 - val_loss: 0.0032 - val_accuracy: 0.9980
#
# Epoch 00028: val_loss improved from 0.00427 to 0.00320, saving model to model.h5
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0181 - accuracy: 0.9948 - val_loss: 2.0812 - val_accuracy: 0.7324
#
# Epoch 00029: val_loss did not improve from 0.00320
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0194 - accuracy: 0.9952 - val_loss: 0.1938 - val_accuracy: 0.9652
#
# Epoch 00030: val_loss did not improve from 0.00320
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0299 - accuracy: 0.9925 - val_loss: 1.0008 - val_accuracy: 0.8430
#
# Epoch 00031: val_loss did not improve from 0.00320
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.2768 - val_accuracy: 0.9473
#
# Epoch 00032: val_loss did not improve from 0.00320
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0183 - accuracy: 0.9949 - val_loss: 0.5698 - val_accuracy: 0.9023
#
# Epoch 00033: val_loss did not improve from 0.00320
# Epoch 34/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0147 - accuracy: 0.9959 - val_loss: 0.0109 - val_accuracy: 0.9961
#
# Epoch 00034: val_loss did not improve from 0.00320
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0174 - accuracy: 0.9955 - val_loss: 0.6640 - val_accuracy: 0.8457
#
# Epoch 00035: val_loss did not improve from 0.00320
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0195 - accuracy: 0.9949 - val_loss: 0.0194 - val_accuracy: 0.9937
#
# Epoch 00036: val_loss did not improve from 0.00320
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0184 - accuracy: 0.9950 - val_loss: 0.0574 - val_accuracy: 0.9844
#
# Epoch 00037: val_loss did not improve from 0.00320
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0163 - accuracy: 0.9953 - val_loss: 0.0232 - val_accuracy: 0.9895
#
# Epoch 00038: val_loss did not improve from 0.00320
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 0.0097 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00320
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0189 - accuracy: 0.9957 - val_loss: 0.0087 - val_accuracy: 0.9977
#
# Epoch 00040: val_loss did not improve from 0.00320
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0193 - accuracy: 0.9952 - val_loss: 0.1074 - val_accuracy: 0.9820
#
# Epoch 00041: val_loss did not improve from 0.00320
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0154 - accuracy: 0.9960 - val_loss: 0.0091 - val_accuracy: 0.9977
#
# Epoch 00042: val_loss did not improve from 0.00320
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0164 - accuracy: 0.9961 - val_loss: 0.0129 - val_accuracy: 0.9957
#
# Epoch 00043: val_loss did not improve from 0.00320
# Epoch 44/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0156 - accuracy: 0.9959 - val_loss: 0.7157 - val_accuracy: 0.8738
#
# Epoch 00044: val_loss did not improve from 0.00320
# Epoch 45/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0183 - accuracy: 0.9951 - val_loss: 0.0069 - val_accuracy: 0.9969
#
# Epoch 00045: val_loss did not improve from 0.00320
# Epoch 46/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0187 - accuracy: 0.9958 - val_loss: 0.0174 - val_accuracy: 0.9957
#
# Epoch 00046: val_loss did not improve from 0.00320
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9955 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00047: val_loss did not improve from 0.00320
# Epoch 48/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0167 - accuracy: 0.9956 - val_loss: 0.0081 - val_accuracy: 0.9973
#
# Epoch 00048: val_loss did not improve from 0.00320
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0198 - accuracy: 0.9949 - val_loss: 0.1123 - val_accuracy: 0.9762
#
# Epoch 00049: val_loss did not improve from 0.00320
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.1543 - val_accuracy: 0.9656
#
# Epoch 00050: val_loss did not improve from 0.00320
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9967 - val_loss: 0.0174 - val_accuracy: 0.9953
#
# Epoch 00051: val_loss did not improve from 0.00320
# Epoch 52/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0175 - accuracy: 0.9954 - val_loss: 0.0667 - val_accuracy: 0.9852
#
# Epoch 00052: val_loss did not improve from 0.00320
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9969 - val_loss: 0.6125 - val_accuracy: 0.9000
#
# Epoch 00053: val_loss did not improve from 0.00320
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0182 - accuracy: 0.9961 - val_loss: 0.9282 - val_accuracy: 0.8789
#
# Epoch 00054: val_loss did not improve from 0.00320
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.3745 - val_accuracy: 0.9234
#
# Epoch 00055: val_loss did not improve from 0.00320
# Epoch 56/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0161 - accuracy: 0.9958 - val_loss: 0.6188 - val_accuracy: 0.9445
#
# Epoch 00056: val_loss did not improve from 0.00320
# Epoch 57/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.3486 - val_accuracy: 0.9441
#
# Epoch 00057: val_loss did not improve from 0.00320
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0165 - accuracy: 0.9958 - val_loss: 0.0527 - val_accuracy: 0.9906
#
# Epoch 00058: val_loss did not improve from 0.00320
# Epoch 59/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.1592 - val_accuracy: 0.9617
#
# Epoch 00059: val_loss did not improve from 0.00320
# Epoch 60/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0197 - accuracy: 0.9956 - val_loss: 0.5277 - val_accuracy: 0.9227
#
# Epoch 00060: val_loss did not improve from 0.00320
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0141 - accuracy: 0.9962 - val_loss: 0.2264 - val_accuracy: 0.9523
#
# Epoch 00061: val_loss did not improve from 0.00320
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0143 - accuracy: 0.9964 - val_loss: 0.0226 - val_accuracy: 0.9965
#
# Epoch 00062: val_loss did not improve from 0.00320
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0178 - accuracy: 0.9956 - val_loss: 0.0228 - val_accuracy: 0.9926
#
# Epoch 00063: val_loss did not improve from 0.00320
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0158 - accuracy: 0.9963 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00064: val_loss did not improve from 0.00320
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0148 - accuracy: 0.9967 - val_loss: 0.8963 - val_accuracy: 0.8539
#
# Epoch 00065: val_loss did not improve from 0.00320
# Epoch 66/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.3173 - val_accuracy: 0.9461
#
# Epoch 00066: val_loss did not improve from 0.00320
# Epoch 67/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.0512 - val_accuracy: 0.9895
#
# Epoch 00067: val_loss did not improve from 0.00320
# Epoch 68/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0168 - accuracy: 0.9962 - val_loss: 0.0330 - val_accuracy: 0.9945
#
# Epoch 00068: val_loss did not improve from 0.00320
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.2261 - val_accuracy: 0.9570
#
# Epoch 00069: val_loss did not improve from 0.00320
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0150 - accuracy: 0.9964 - val_loss: 0.0472 - val_accuracy: 0.9910
#
# Epoch 00070: val_loss did not improve from 0.00320
# Epoch 71/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 3.1912 - val_accuracy: 0.6273
#
# Epoch 00071: val_loss did not improve from 0.00320
# Epoch 72/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 1.4541 - val_accuracy: 0.9078
#
# Epoch 00072: val_loss did not improve from 0.00320
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.3933 - val_accuracy: 0.9184
#
# Epoch 00073: val_loss did not improve from 0.00320
# Epoch 74/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.0358 - val_accuracy: 0.9926
#
# Epoch 00074: val_loss did not improve from 0.00320
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0169 - accuracy: 0.9963 - val_loss: 0.3224 - val_accuracy: 0.9555
#
# Epoch 00075: val_loss did not improve from 0.00320
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9965 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00076: val_loss did not improve from 0.00320
# Epoch 77/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0121 - accuracy: 0.9970 - val_loss: 1.4447 - val_accuracy: 0.8535
#
# Epoch 00077: val_loss did not improve from 0.00320
# Epoch 78/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.0689 - val_accuracy: 0.9863
#
# Epoch 00078: val_loss did not improve from 0.00320
# Epoch 79/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0142 - accuracy: 0.9965 - val_loss: 0.1424 - val_accuracy: 0.9777
#
# Epoch 00079: val_loss did not improve from 0.00320
# Epoch 80/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0134 - accuracy: 0.9972 - val_loss: 0.0126 - val_accuracy: 0.9969
#
# Epoch 00080: val_loss did not improve from 0.00320
# Epoch 81/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0139 - accuracy: 0.9967 - val_loss: 2.3221 - val_accuracy: 0.7828
#
# Epoch 00081: val_loss did not improve from 0.00320
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9970 - val_loss: 0.0098 - val_accuracy: 0.9980
#
# Epoch 00082: val_loss did not improve from 0.00320
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0146 - accuracy: 0.9963 - val_loss: 0.9901 - val_accuracy: 0.8441
#
# Epoch 00083: val_loss did not improve from 0.00320
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00084: val_loss did not improve from 0.00320
# Epoch 85/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0107 - accuracy: 0.9975 - val_loss: 0.0181 - val_accuracy: 0.9941
#
# Epoch 00085: val_loss did not improve from 0.00320
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0105 - accuracy: 0.9975 - val_loss: 0.0066 - val_accuracy: 0.9977
#
# Epoch 00086: val_loss did not improve from 0.00320
# Epoch 87/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9962 - val_loss: 0.0569 - val_accuracy: 0.9871
#
# Epoch 00087: val_loss did not improve from 0.00320
# Epoch 88/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0142 - accuracy: 0.9962 - val_loss: 0.1632 - val_accuracy: 0.9691
#
# Epoch 00088: val_loss did not improve from 0.00320
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0100 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00320
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0083 - val_accuracy: 0.9977
#
# Epoch 00090: val_loss did not improve from 0.00320
# Epoch 91/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 0.0152 - val_accuracy: 0.9965
#
# Epoch 00091: val_loss did not improve from 0.00320
# Epoch 92/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.1420 - val_accuracy: 0.9762
#
# Epoch 00092: val_loss did not improve from 0.00320
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.1605 - val_accuracy: 0.9664
#
# Epoch 00093: val_loss did not improve from 0.00320
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0162 - val_accuracy: 0.9965
#
# Epoch 00094: val_loss did not improve from 0.00320
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00095: val_loss did not improve from 0.00320
# Epoch 96/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0096 - accuracy: 0.9977 - val_loss: 0.1170 - val_accuracy: 0.9816
#
# Epoch 00096: val_loss did not improve from 0.00320
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 0.0470 - val_accuracy: 0.9941
#
# Epoch 00097: val_loss did not improve from 0.00320
# Epoch 98/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0135 - accuracy: 0.9970 - val_loss: 0.5252 - val_accuracy: 0.9145
#
# Epoch 00098: val_loss did not improve from 0.00320
# Epoch 99/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00099: val_loss did not improve from 0.00320
# Epoch 100/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.3507 - val_accuracy: 0.9500
#
# Epoch 00100: val_loss did not improve from 0.00320
# 80/80 [==============================] - 0s 4ms/step - loss: 0.3507 - accuracy: 0.9500
# Val Score:  [0.3507412374019623, 0.949999988079071]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.4980 - accuracy: 0.8512 - val_loss: 4.0186 - val_accuracy: 0.5281
#
# Epoch 00001: val_loss did not improve from 0.00320
# Epoch 2/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.1730 - accuracy: 0.9428 - val_loss: 1.0105 - val_accuracy: 0.7453
#
# Epoch 00002: val_loss did not improve from 0.00320
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0989 - accuracy: 0.9679 - val_loss: 0.1239 - val_accuracy: 0.9793
#
# Epoch 00003: val_loss did not improve from 0.00320
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0770 - accuracy: 0.9768 - val_loss: 0.1094 - val_accuracy: 0.9707
#
# Epoch 00004: val_loss did not improve from 0.00320
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0626 - accuracy: 0.9825 - val_loss: 0.0532 - val_accuracy: 0.9875
#
# Epoch 00005: val_loss did not improve from 0.00320
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0474 - accuracy: 0.9865 - val_loss: 0.1830 - val_accuracy: 0.9383
#
# Epoch 00006: val_loss did not improve from 0.00320
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0391 - accuracy: 0.9888 - val_loss: 0.0295 - val_accuracy: 0.9934
#
# Epoch 00007: val_loss did not improve from 0.00320
# Epoch 8/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0401 - accuracy: 0.9897 - val_loss: 0.0640 - val_accuracy: 0.9828
#
# Epoch 00008: val_loss did not improve from 0.00320
# Epoch 9/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0307 - accuracy: 0.9909 - val_loss: 0.0181 - val_accuracy: 0.9937
#
# Epoch 00009: val_loss did not improve from 0.00320
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0313 - accuracy: 0.9913 - val_loss: 0.3896 - val_accuracy: 0.9367
#
# Epoch 00010: val_loss did not improve from 0.00320
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0249 - accuracy: 0.9933 - val_loss: 0.0333 - val_accuracy: 0.9891
#
# Epoch 00011: val_loss did not improve from 0.00320
# Epoch 12/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0254 - accuracy: 0.9932 - val_loss: 0.1347 - val_accuracy: 0.9723
#
# Epoch 00012: val_loss did not improve from 0.00320
# Epoch 13/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0203 - accuracy: 0.9935 - val_loss: 0.3204 - val_accuracy: 0.9402
#
# Epoch 00013: val_loss did not improve from 0.00320
# Epoch 14/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 1.0975 - val_accuracy: 0.8113
#
# Epoch 00014: val_loss did not improve from 0.00320
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0277 - accuracy: 0.9936 - val_loss: 0.0079 - val_accuracy: 0.9965
#
# Epoch 00015: val_loss did not improve from 0.00320
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0260 - accuracy: 0.9924 - val_loss: 0.8584 - val_accuracy: 0.8914
#
# Epoch 00016: val_loss did not improve from 0.00320
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 0.5772 - val_accuracy: 0.9156
#
# Epoch 00017: val_loss did not improve from 0.00320
# Epoch 18/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0198 - accuracy: 0.9943 - val_loss: 0.0141 - val_accuracy: 0.9961
#
# Epoch 00018: val_loss did not improve from 0.00320
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0202 - accuracy: 0.9948 - val_loss: 0.0101 - val_accuracy: 0.9965
#
# Epoch 00019: val_loss did not improve from 0.00320
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0212 - accuracy: 0.9943 - val_loss: 0.7767 - val_accuracy: 0.8605
#
# Epoch 00020: val_loss did not improve from 0.00320
# Epoch 21/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0257 - accuracy: 0.9942 - val_loss: 0.0926 - val_accuracy: 0.9699
#
# Epoch 00021: val_loss did not improve from 0.00320
# Epoch 22/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0162 - accuracy: 0.9960 - val_loss: 0.0191 - val_accuracy: 0.9937
#
# Epoch 00022: val_loss did not improve from 0.00320
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0168 - accuracy: 0.9958 - val_loss: 0.0982 - val_accuracy: 0.9809
#
# Epoch 00023: val_loss did not improve from 0.00320
# Epoch 24/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0213 - accuracy: 0.9949 - val_loss: 0.1281 - val_accuracy: 0.9676
#
# Epoch 00024: val_loss did not improve from 0.00320
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0152 - accuracy: 0.9963 - val_loss: 0.0528 - val_accuracy: 0.9820
#
# Epoch 00025: val_loss did not improve from 0.00320
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 1.7556 - val_accuracy: 0.8367
#
# Epoch 00026: val_loss did not improve from 0.00320
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0214 - accuracy: 0.9947 - val_loss: 0.0228 - val_accuracy: 0.9934
#
# Epoch 00027: val_loss did not improve from 0.00320
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9962 - val_loss: 0.0361 - val_accuracy: 0.9895
#
# Epoch 00028: val_loss did not improve from 0.00320
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9956 - val_loss: 0.3086 - val_accuracy: 0.9441
#
# Epoch 00029: val_loss did not improve from 0.00320
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.3308 - val_accuracy: 0.9281
#
# Epoch 00030: val_loss did not improve from 0.00320
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.0275 - val_accuracy: 0.9945
#
# Epoch 00031: val_loss did not improve from 0.00320
# Epoch 32/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.1183 - val_accuracy: 0.9715
#
# Epoch 00032: val_loss did not improve from 0.00320
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.0630 - val_accuracy: 0.9836
#
# Epoch 00033: val_loss did not improve from 0.00320
# Epoch 34/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0175 - accuracy: 0.9954 - val_loss: 0.5655 - val_accuracy: 0.8918
#
# Epoch 00034: val_loss did not improve from 0.00320
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0198 - accuracy: 0.9953 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00320
# Epoch 36/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0185 - accuracy: 0.9960 - val_loss: 0.0078 - val_accuracy: 0.9973
#
# Epoch 00036: val_loss did not improve from 0.00320
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9971 - val_loss: 0.1025 - val_accuracy: 0.9824
#
# Epoch 00037: val_loss did not improve from 0.00320
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0206 - accuracy: 0.9952 - val_loss: 0.1281 - val_accuracy: 0.9723
#
# Epoch 00038: val_loss did not improve from 0.00320
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0152 - accuracy: 0.9966 - val_loss: 0.5689 - val_accuracy: 0.8910
#
# Epoch 00039: val_loss did not improve from 0.00320
# Epoch 40/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0184 - accuracy: 0.9959 - val_loss: 0.0072 - val_accuracy: 0.9977
#
# Epoch 00040: val_loss did not improve from 0.00320
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0164 - accuracy: 0.9955 - val_loss: 0.0852 - val_accuracy: 0.9801
#
# Epoch 00041: val_loss did not improve from 0.00320
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.3307 - val_accuracy: 0.9352
#
# Epoch 00042: val_loss did not improve from 0.00320
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0152 - accuracy: 0.9963 - val_loss: 1.5520 - val_accuracy: 0.8102
#
# Epoch 00043: val_loss did not improve from 0.00320
# Epoch 44/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0135 - accuracy: 0.9964 - val_loss: 0.0072 - val_accuracy: 0.9965
#
# Epoch 00044: val_loss did not improve from 0.00320
# Epoch 45/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.1119 - val_accuracy: 0.9797
#
# Epoch 00045: val_loss did not improve from 0.00320
# Epoch 46/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0174 - accuracy: 0.9954 - val_loss: 0.0108 - val_accuracy: 0.9965
#
# Epoch 00046: val_loss did not improve from 0.00320
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.0410 - val_accuracy: 0.9895
#
# Epoch 00047: val_loss did not improve from 0.00320
# Epoch 48/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0184 - accuracy: 0.9953 - val_loss: 0.0065 - val_accuracy: 0.9973
#
# Epoch 00048: val_loss did not improve from 0.00320
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.0064 - val_accuracy: 0.9984
#
# Epoch 00049: val_loss did not improve from 0.00320
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0247 - val_accuracy: 0.9977
#
# Epoch 00050: val_loss did not improve from 0.00320
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.0255 - val_accuracy: 0.9969
#
# Epoch 00051: val_loss did not improve from 0.00320
# Epoch 52/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.0086 - val_accuracy: 0.9980
#
# Epoch 00052: val_loss did not improve from 0.00320
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0132 - accuracy: 0.9964 - val_loss: 0.0707 - val_accuracy: 0.9824
#
# Epoch 00053: val_loss did not improve from 0.00320
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0151 - accuracy: 0.9959 - val_loss: 1.2533 - val_accuracy: 0.8508
#
# Epoch 00054: val_loss did not improve from 0.00320
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0115 - accuracy: 0.9970 - val_loss: 0.0407 - val_accuracy: 0.9871
#
# Epoch 00055: val_loss did not improve from 0.00320
# Epoch 56/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0236 - val_accuracy: 0.9949
#
# Epoch 00056: val_loss did not improve from 0.00320
# Epoch 57/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0152 - accuracy: 0.9963 - val_loss: 0.0082 - val_accuracy: 0.9957
#
# Epoch 00057: val_loss did not improve from 0.00320
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0144 - accuracy: 0.9960 - val_loss: 0.0074 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00320
# Epoch 59/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.0080 - val_accuracy: 0.9957
#
# Epoch 00059: val_loss did not improve from 0.00320
# Epoch 60/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00060: val_loss did not improve from 0.00320
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0196 - accuracy: 0.9952 - val_loss: 0.0053 - val_accuracy: 0.9977
#
# Epoch 00061: val_loss did not improve from 0.00320
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.3652 - val_accuracy: 0.9418
#
# Epoch 00062: val_loss did not improve from 0.00320
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.0281 - val_accuracy: 0.9918
#
# Epoch 00063: val_loss did not improve from 0.00320
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.0899 - val_accuracy: 0.9852
#
# Epoch 00064: val_loss did not improve from 0.00320
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0114 - accuracy: 0.9972 - val_loss: 0.8685 - val_accuracy: 0.8828
#
# Epoch 00065: val_loss did not improve from 0.00320
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0140 - accuracy: 0.9967 - val_loss: 1.8343 - val_accuracy: 0.8199
#
# Epoch 00066: val_loss did not improve from 0.00320
# Epoch 67/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0138 - accuracy: 0.9965 - val_loss: 0.0652 - val_accuracy: 0.9891
#
# Epoch 00067: val_loss did not improve from 0.00320
# Epoch 68/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0118 - accuracy: 0.9968 - val_loss: 0.0583 - val_accuracy: 0.9871
#
# Epoch 00068: val_loss did not improve from 0.00320
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0113 - accuracy: 0.9975 - val_loss: 0.1030 - val_accuracy: 0.9797
#
# Epoch 00069: val_loss did not improve from 0.00320
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0140 - accuracy: 0.9965 - val_loss: 0.0553 - val_accuracy: 0.9879
#
# Epoch 00070: val_loss did not improve from 0.00320
# Epoch 71/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.1931 - val_accuracy: 0.9504
#
# Epoch 00071: val_loss did not improve from 0.00320
# Epoch 72/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0151 - accuracy: 0.9961 - val_loss: 2.7253 - val_accuracy: 0.8406
#
# Epoch 00072: val_loss did not improve from 0.00320
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00073: val_loss did not improve from 0.00320
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0067 - val_accuracy: 0.9977
#
# Epoch 00074: val_loss did not improve from 0.00320
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.0941 - val_accuracy: 0.9812
#
# Epoch 00075: val_loss did not improve from 0.00320
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9967 - val_loss: 0.0197 - val_accuracy: 0.9937
#
# Epoch 00076: val_loss did not improve from 0.00320
# Epoch 77/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.0152 - val_accuracy: 0.9953
#
# Epoch 00077: val_loss did not improve from 0.00320
# Epoch 78/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 0.0249 - val_accuracy: 0.9941
#
# Epoch 00078: val_loss did not improve from 0.00320
# Epoch 79/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0135 - accuracy: 0.9966 - val_loss: 0.0095 - val_accuracy: 0.9965
#
# Epoch 00079: val_loss did not improve from 0.00320
# Epoch 80/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 4.2538 - val_accuracy: 0.6578
#
# Epoch 00080: val_loss did not improve from 0.00320
# Epoch 81/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0345 - val_accuracy: 0.9895
#
# Epoch 00081: val_loss did not improve from 0.00320
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0125 - val_accuracy: 0.9973
#
# Epoch 00082: val_loss did not improve from 0.00320
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00083: val_loss did not improve from 0.00320
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0109 - val_accuracy: 0.9957
#
# Epoch 00084: val_loss did not improve from 0.00320
# Epoch 85/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0115 - accuracy: 0.9975 - val_loss: 0.7850 - val_accuracy: 0.8949
#
# Epoch 00085: val_loss did not improve from 0.00320
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 3.2046 - val_accuracy: 0.7477
#
# Epoch 00086: val_loss did not improve from 0.00320
# Epoch 87/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9967 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00087: val_loss improved from 0.00320 to 0.00225, saving model to model.h5
# Epoch 88/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.0742 - val_accuracy: 0.9883
#
# Epoch 00088: val_loss did not improve from 0.00225
# Epoch 89/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0577 - val_accuracy: 0.9875
#
# Epoch 00089: val_loss did not improve from 0.00225
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0105 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00225
# Epoch 91/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0083 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00225
# Epoch 92/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0114 - accuracy: 0.9973 - val_loss: 0.1359 - val_accuracy: 0.9770
#
# Epoch 00092: val_loss did not improve from 0.00225
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0151 - accuracy: 0.9963 - val_loss: 0.7910 - val_accuracy: 0.9098
#
# Epoch 00093: val_loss did not improve from 0.00225
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.1171 - val_accuracy: 0.9812
#
# Epoch 00094: val_loss did not improve from 0.00225
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0131 - val_accuracy: 0.9965
#
# Epoch 00095: val_loss did not improve from 0.00225
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.0189 - val_accuracy: 0.9957
#
# Epoch 00096: val_loss did not improve from 0.00225
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9970 - val_loss: 0.0076 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00225
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0134 - accuracy: 0.9970 - val_loss: 0.0263 - val_accuracy: 0.9949
#
# Epoch 00098: val_loss did not improve from 0.00225
# Epoch 99/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0128 - accuracy: 0.9968 - val_loss: 0.0029 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00225
# Epoch 100/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0089 - accuracy: 0.9976 - val_loss: 0.0289 - val_accuracy: 0.9937
#
# Epoch 00100: val_loss did not improve from 0.00225
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 0.9937
# Val Score:  [0.028930703178048134, 0.9937499761581421]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 5s 12ms/step - loss: 0.4327 - accuracy: 0.8783 - val_loss: 4.1336 - val_accuracy: 0.5598
#
# Epoch 00001: val_loss did not improve from 0.00225
# Epoch 2/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1499 - accuracy: 0.9524 - val_loss: 0.3405 - val_accuracy: 0.9203
#
# Epoch 00002: val_loss did not improve from 0.00225
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0904 - accuracy: 0.9718 - val_loss: 0.0523 - val_accuracy: 0.9840
#
# Epoch 00003: val_loss did not improve from 0.00225
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0639 - accuracy: 0.9793 - val_loss: 1.3888 - val_accuracy: 0.7992
#
# Epoch 00004: val_loss did not improve from 0.00225
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0550 - accuracy: 0.9821 - val_loss: 0.0285 - val_accuracy: 0.9910
#
# Epoch 00005: val_loss did not improve from 0.00225
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0455 - accuracy: 0.9870 - val_loss: 0.3822 - val_accuracy: 0.9129
#
# Epoch 00006: val_loss did not improve from 0.00225
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0329 - accuracy: 0.9908 - val_loss: 0.0373 - val_accuracy: 0.9891
#
# Epoch 00007: val_loss did not improve from 0.00225
# Epoch 8/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0344 - accuracy: 0.9908 - val_loss: 0.1017 - val_accuracy: 0.9730
#
# Epoch 00008: val_loss did not improve from 0.00225
# Epoch 9/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0258 - accuracy: 0.9921 - val_loss: 0.0737 - val_accuracy: 0.9840
#
# Epoch 00009: val_loss did not improve from 0.00225
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.0352 - val_accuracy: 0.9891
#
# Epoch 00010: val_loss did not improve from 0.00225
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0315 - accuracy: 0.9908 - val_loss: 0.1449 - val_accuracy: 0.9559
#
# Epoch 00011: val_loss did not improve from 0.00225
# Epoch 12/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0194 - accuracy: 0.9945 - val_loss: 0.0624 - val_accuracy: 0.9828
#
# Epoch 00012: val_loss did not improve from 0.00225
# Epoch 13/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0234 - accuracy: 0.9939 - val_loss: 0.1122 - val_accuracy: 0.9688
#
# Epoch 00013: val_loss did not improve from 0.00225
# Epoch 14/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0201 - accuracy: 0.9943 - val_loss: 0.1675 - val_accuracy: 0.9602
#
# Epoch 00014: val_loss did not improve from 0.00225
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0216 - accuracy: 0.9941 - val_loss: 0.0413 - val_accuracy: 0.9902
#
# Epoch 00015: val_loss did not improve from 0.00225
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0227 - accuracy: 0.9939 - val_loss: 0.0261 - val_accuracy: 0.9961
#
# Epoch 00016: val_loss did not improve from 0.00225
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0168 - accuracy: 0.9952 - val_loss: 0.0453 - val_accuracy: 0.9891
#
# Epoch 00017: val_loss did not improve from 0.00225
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 0.0281 - val_accuracy: 0.9926
#
# Epoch 00018: val_loss did not improve from 0.00225
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.0991 - val_accuracy: 0.9695
#
# Epoch 00019: val_loss did not improve from 0.00225
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0182 - accuracy: 0.9951 - val_loss: 0.0115 - val_accuracy: 0.9957
#
# Epoch 00020: val_loss did not improve from 0.00225
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0188 - accuracy: 0.9948 - val_loss: 0.0332 - val_accuracy: 0.9891
#
# Epoch 00021: val_loss did not improve from 0.00225
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0193 - accuracy: 0.9951 - val_loss: 0.0671 - val_accuracy: 0.9824
#
# Epoch 00022: val_loss did not improve from 0.00225
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0184 - accuracy: 0.9948 - val_loss: 1.2850 - val_accuracy: 0.8148
#
# Epoch 00023: val_loss did not improve from 0.00225
# Epoch 24/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.2028 - val_accuracy: 0.9598
#
# Epoch 00024: val_loss did not improve from 0.00225
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0146 - val_accuracy: 0.9957
#
# Epoch 00025: val_loss did not improve from 0.00225
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.4821 - val_accuracy: 0.9207
#
# Epoch 00026: val_loss did not improve from 0.00225
# Epoch 27/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00027: val_loss did not improve from 0.00225
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 0.2591 - val_accuracy: 0.9508
#
# Epoch 00028: val_loss did not improve from 0.00225
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00029: val_loss did not improve from 0.00225
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0167 - accuracy: 0.9955 - val_loss: 0.0117 - val_accuracy: 0.9973
#
# Epoch 00030: val_loss did not improve from 0.00225
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.1377 - val_accuracy: 0.9633
#
# Epoch 00031: val_loss did not improve from 0.00225
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0157 - accuracy: 0.9965 - val_loss: 0.0312 - val_accuracy: 0.9961
#
# Epoch 00032: val_loss did not improve from 0.00225
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0135 - accuracy: 0.9972 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00033: val_loss did not improve from 0.00225
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0103 - accuracy: 0.9959 - val_loss: 0.0074 - val_accuracy: 0.9977
#
# Epoch 00034: val_loss did not improve from 0.00225
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0138 - accuracy: 0.9963 - val_loss: 0.0122 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00225
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0149 - accuracy: 0.9962 - val_loss: 0.0496 - val_accuracy: 0.9844
#
# Epoch 00036: val_loss did not improve from 0.00225
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0148 - accuracy: 0.9968 - val_loss: 0.0735 - val_accuracy: 0.9805
#
# Epoch 00037: val_loss did not improve from 0.00225
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0193 - accuracy: 0.9960 - val_loss: 0.6137 - val_accuracy: 0.9066
#
# Epoch 00038: val_loss did not improve from 0.00225
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0047 - val_accuracy: 0.9984
#
# Epoch 00039: val_loss did not improve from 0.00225
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 0.0202 - val_accuracy: 0.9945
#
# Epoch 00040: val_loss did not improve from 0.00225
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.0097 - val_accuracy: 0.9973
#
# Epoch 00041: val_loss did not improve from 0.00225
# Epoch 42/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00203
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0175 - accuracy: 0.9954 - val_loss: 0.3253 - val_accuracy: 0.9238
#
# Epoch 00021: val_loss did not improve from 0.00203
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 0.0396 - val_accuracy: 0.9902
#
# Epoch 00022: val_loss did not improve from 0.00203
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.2021 - val_accuracy: 0.9656
#
# Epoch 00023: val_loss did not improve from 0.00203
# Epoch 24/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0231 - accuracy: 0.9952 - val_loss: 0.0195 - val_accuracy: 0.9926
#
# Epoch 00024: val_loss did not improve from 0.00203
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0145 - accuracy: 0.9964 - val_loss: 0.0891 - val_accuracy: 0.9828
#
# Epoch 00025: val_loss did not improve from 0.00203
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0860 - val_accuracy: 0.9789
#
# Epoch 00026: val_loss did not improve from 0.00203
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0181 - accuracy: 0.9951 - val_loss: 0.5143 - val_accuracy: 0.8922
#
# Epoch 00027: val_loss did not improve from 0.00203
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0137 - accuracy: 0.9959 - val_loss: 0.0268 - val_accuracy: 0.9937
#
# Epoch 00028: val_loss did not improve from 0.00203
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.2101 - val_accuracy: 0.9664
#
# Epoch 00029: val_loss did not improve from 0.00203
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9969 - val_loss: 0.0273 - val_accuracy: 0.9980
#
# Epoch 00030: val_loss did not improve from 0.00203
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.0906 - val_accuracy: 0.9937
#
# Epoch 00031: val_loss did not improve from 0.00203
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0166 - accuracy: 0.9958 - val_loss: 0.0204 - val_accuracy: 0.9969
#
# Epoch 00032: val_loss did not improve from 0.00203
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0130 - accuracy: 0.9965 - val_loss: 0.0896 - val_accuracy: 0.9766
#
# Epoch 00033: val_loss did not improve from 0.00203
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0093 - val_accuracy: 0.9965
#
# Epoch 00034: val_loss did not improve from 0.00203
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00203
# Epoch 36/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.1835 - val_accuracy: 0.9664
#
# Epoch 00036: val_loss did not improve from 0.00203
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9962 - val_loss: 0.0540 - val_accuracy: 0.9949
#
# Epoch 00037: val_loss did not improve from 0.00203
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.0332 - val_accuracy: 0.9906
#
# Epoch 00038: val_loss did not improve from 0.00203
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0037 - val_accuracy: 0.9984
#
# Epoch 00039: val_loss did not improve from 0.00203
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00040: val_loss did not improve from 0.00203
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0128 - accuracy: 0.9963 - val_loss: 0.0128 - val_accuracy: 0.9965
#
# Epoch 00041: val_loss did not improve from 0.00203
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.0080 - val_accuracy: 0.9977
#
# Epoch 00042: val_loss did not improve from 0.00203
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.0141 - val_accuracy: 0.9973
#
# Epoch 00043: val_loss did not improve from 0.00203
# Epoch 44/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0103 - val_accuracy: 0.9973
#
# Epoch 00044: val_loss did not improve from 0.00203
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00045: val_loss did not improve from 0.00203
# Epoch 46/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.0257 - val_accuracy: 0.9945
#
# Epoch 00046: val_loss did not improve from 0.00203
# Epoch 47/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0131 - accuracy: 0.9964 - val_loss: 0.0358 - val_accuracy: 0.9934
#
# Epoch 00047: val_loss did not improve from 0.00203
# Epoch 48/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0559 - val_accuracy: 0.9961
#
# Epoch 00048: val_loss did not improve from 0.00203
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9965 - val_loss: 0.5948 - val_accuracy: 0.8988
#
# Epoch 00049: val_loss did not improve from 0.00203
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.0127 - val_accuracy: 0.9953
#
# Epoch 00050: val_loss did not improve from 0.00203
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0147 - accuracy: 0.9966 - val_loss: 0.0068 - val_accuracy: 0.9977
#
# Epoch 00051: val_loss did not improve from 0.00203
# Epoch 52/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 0.0058 - val_accuracy: 0.9980
#
# Epoch 00052: val_loss did not improve from 0.00203
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.0150 - val_accuracy: 0.9977
#
# Epoch 00053: val_loss did not improve from 0.00203
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.0640 - val_accuracy: 0.9875
#
# Epoch 00054: val_loss did not improve from 0.00203
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00055: val_loss did not improve from 0.00203
# Epoch 56/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.0049 - val_accuracy: 0.9980
#
# Epoch 00056: val_loss did not improve from 0.00203
# Epoch 57/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0321 - val_accuracy: 0.9953
#
# Epoch 00057: val_loss did not improve from 0.00203
# Epoch 58/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0938 - val_accuracy: 0.9754
#
# Epoch 00058: val_loss did not improve from 0.00203
# Epoch 59/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0227 - val_accuracy: 0.9957
#
# Epoch 00059: val_loss did not improve from 0.00203
# Epoch 60/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0221 - val_accuracy: 0.9949
#
# Epoch 00060: val_loss did not improve from 0.00203
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.0153 - val_accuracy: 0.9961
#
# Epoch 00061: val_loss did not improve from 0.00203
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0085 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00203
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0984 - val_accuracy: 0.9797
#
# Epoch 00063: val_loss did not improve from 0.00203
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 0.1131 - val_accuracy: 0.9762
#
# Epoch 00064: val_loss did not improve from 0.00203
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.0364 - val_accuracy: 0.9906
#
# Epoch 00065: val_loss did not improve from 0.00203
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.2777 - val_accuracy: 0.9434
#
# Epoch 00066: val_loss did not improve from 0.00203
# Epoch 67/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00067: val_loss did not improve from 0.00203
# Epoch 68/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0371 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00203
# Epoch 69/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00069: val_loss did not improve from 0.00203
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.0239 - val_accuracy: 0.9930
#
# Epoch 00070: val_loss did not improve from 0.00203
# Epoch 71/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00203
# Epoch 72/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0105 - val_accuracy: 0.9961
#
# Epoch 00072: val_loss did not improve from 0.00203
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.0139 - val_accuracy: 0.9977
#
# Epoch 00073: val_loss did not improve from 0.00203
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.0059 - val_accuracy: 0.9984
#
# Epoch 00074: val_loss did not improve from 0.00203
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00075: val_loss did not improve from 0.00203
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.0060 - val_accuracy: 0.9973
#
# Epoch 00076: val_loss did not improve from 0.00203
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.0077 - val_accuracy: 0.9980
#
# Epoch 00077: val_loss did not improve from 0.00203
# Epoch 78/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0098 - accuracy: 0.9962 - val_loss: 0.0468 - val_accuracy: 0.9887
#
# Epoch 00078: val_loss did not improve from 0.00203
# Epoch 79/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.0080 - val_accuracy: 0.9965
#
# Epoch 00079: val_loss did not improve from 0.00203
# Epoch 80/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0213 - val_accuracy: 0.9965
#
# Epoch 00080: val_loss did not improve from 0.00203
# Epoch 81/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0126 - accuracy: 0.9974 - val_loss: 0.0068 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00203
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9973 - val_loss: 0.0368 - val_accuracy: 0.9918
#
# Epoch 00082: val_loss did not improve from 0.00203
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 0.0098 - val_accuracy: 0.9973
#
# Epoch 00083: val_loss did not improve from 0.00203
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0562 - val_accuracy: 0.9844
#
# Epoch 00084: val_loss did not improve from 0.00203
# Epoch 85/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00085: val_loss did not improve from 0.00203
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0161 - val_accuracy: 0.9941
#
# Epoch 00086: val_loss did not improve from 0.00203
# Epoch 87/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0029 - val_accuracy: 0.9988
#
# Epoch 00087: val_loss did not improve from 0.00203
# Epoch 88/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0226 - val_accuracy: 0.9977
#
# Epoch 00088: val_loss did not improve from 0.00203
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.0169 - val_accuracy: 0.9988
#
# Epoch 00089: val_loss did not improve from 0.00203
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.0292 - val_accuracy: 0.9906
#
# Epoch 00090: val_loss did not improve from 0.00203
# Epoch 91/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0121 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00203
# Epoch 92/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00092: val_loss did not improve from 0.00203
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0463 - val_accuracy: 0.9922
#
# Epoch 00093: val_loss did not improve from 0.00203
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.0133 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00203
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.0206 - val_accuracy: 0.9969
#
# Epoch 00095: val_loss did not improve from 0.00203
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0094 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00203
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0105 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00203
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0080 - val_accuracy: 0.9984
#
# Epoch 00098: val_loss did not improve from 0.00203
# Epoch 99/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00099: val_loss did not improve from 0.00203
# Epoch 100/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00100: val_loss did not improve from 0.00203
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9977
# Val Score:  [0.0060829902067780495, 0.9976562261581421]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 3ms/step - loss: 0.0057 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
