# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **OPTIMIZER TEST -- USING NADAM AND BEST RESULT OF HIDDEN LAYER(4)**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Nadam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_123 (Conv2D)          (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_185 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_154 (Bat (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_74 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_105 (Dropout)        (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_186 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_155 (Bat (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_125 (Conv2D)          (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_187 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_156 (Bat (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_75 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_106 (Dropout)        (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_126 (Conv2D)          (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_188 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_157 (Bat (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_62 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_189 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_158 (Bat (None, 1024)              4096
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_63 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_190 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Nadam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 7s 15ms/step - loss: 0.3550 - accuracy: 0.8918 - val_loss: 5.0291 - val_accuracy: 0.3281
#
# Epoch 00001: val_loss improved from inf to 5.02906, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1218 - accuracy: 0.9615 - val_loss: 0.6091 - val_accuracy: 0.8313
#
# Epoch 00002: val_loss improved from 5.02906 to 0.60906, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0867 - accuracy: 0.9719 - val_loss: 0.1538 - val_accuracy: 0.9590
#
# Epoch 00003: val_loss improved from 0.60906 to 0.15375, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0847 - accuracy: 0.9724 - val_loss: 0.1313 - val_accuracy: 0.9605
#
# Epoch 00004: val_loss improved from 0.15375 to 0.13128, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0531 - accuracy: 0.9823 - val_loss: 0.1473 - val_accuracy: 0.9582
#
# Epoch 00005: val_loss did not improve from 0.13128
# Epoch 6/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0530 - accuracy: 0.9836 - val_loss: 0.0545 - val_accuracy: 0.9844
#
# Epoch 00006: val_loss improved from 0.13128 to 0.05454, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0398 - accuracy: 0.9882 - val_loss: 0.1193 - val_accuracy: 0.9652
#
# Epoch 00007: val_loss did not improve from 0.05454
# Epoch 8/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0382 - accuracy: 0.9889 - val_loss: 0.0224 - val_accuracy: 0.9926
#
# Epoch 00008: val_loss improved from 0.05454 to 0.02239, saving model to model.h5
# Epoch 9/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0396 - accuracy: 0.9877 - val_loss: 0.0756 - val_accuracy: 0.9766
#
# Epoch 00009: val_loss did not improve from 0.02239
# Epoch 10/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0305 - accuracy: 0.9902 - val_loss: 0.0243 - val_accuracy: 0.9937
#
# Epoch 00010: val_loss did not improve from 0.02239
# Epoch 11/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0451 - accuracy: 0.9859 - val_loss: 0.6416 - val_accuracy: 0.8609
#
# Epoch 00011: val_loss did not improve from 0.02239
# Epoch 12/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0537 - accuracy: 0.9840 - val_loss: 0.0676 - val_accuracy: 0.9762
#
# Epoch 00012: val_loss did not improve from 0.02239
# Epoch 13/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0255 - accuracy: 0.9920 - val_loss: 0.0151 - val_accuracy: 0.9969
#
# Epoch 00013: val_loss improved from 0.02239 to 0.01510, saving model to model.h5
# Epoch 14/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0326 - accuracy: 0.9895 - val_loss: 0.0335 - val_accuracy: 0.9910
#
# Epoch 00014: val_loss did not improve from 0.01510
# Epoch 15/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0252 - accuracy: 0.9920 - val_loss: 0.8531 - val_accuracy: 0.8000
#
# Epoch 00015: val_loss did not improve from 0.01510
# Epoch 16/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0174 - accuracy: 0.9932 - val_loss: 0.2561 - val_accuracy: 0.9289
#
# Epoch 00016: val_loss did not improve from 0.01510
# Epoch 17/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0390 - accuracy: 0.9901 - val_loss: 0.6953 - val_accuracy: 0.8586
#
# Epoch 00017: val_loss did not improve from 0.01510
# Epoch 18/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0320 - accuracy: 0.9902 - val_loss: 0.4672 - val_accuracy: 0.8867
#
# Epoch 00018: val_loss did not improve from 0.01510
# Epoch 19/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0326 - accuracy: 0.9905 - val_loss: 0.0140 - val_accuracy: 0.9953
#
# Epoch 00019: val_loss improved from 0.01510 to 0.01396, saving model to model.h5
# Epoch 20/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0242 - accuracy: 0.9921 - val_loss: 0.0438 - val_accuracy: 0.9898
#
# Epoch 00020: val_loss did not improve from 0.01396
# Epoch 21/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.0374 - val_accuracy: 0.9848
#
# Epoch 00021: val_loss did not improve from 0.01396
# Epoch 22/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0303 - accuracy: 0.9910 - val_loss: 0.0139 - val_accuracy: 0.9957
#
# Epoch 00022: val_loss improved from 0.01396 to 0.01390, saving model to model.h5
# Epoch 23/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0812 - val_accuracy: 0.9762
#
# Epoch 00023: val_loss did not improve from 0.01390
# Epoch 24/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0257 - accuracy: 0.9923 - val_loss: 0.0087 - val_accuracy: 0.9969
#
# Epoch 00024: val_loss improved from 0.01390 to 0.00866, saving model to model.h5
# Epoch 25/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0266 - accuracy: 0.9929 - val_loss: 0.6944 - val_accuracy: 0.8941
#
# Epoch 00025: val_loss did not improve from 0.00866
# Epoch 26/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.6379 - val_accuracy: 0.8484
#
# Epoch 00026: val_loss did not improve from 0.00866
# Epoch 27/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0108 - accuracy: 0.9961 - val_loss: 0.0140 - val_accuracy: 0.9969
#
# Epoch 00027: val_loss did not improve from 0.00866
# Epoch 28/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.0773 - val_accuracy: 0.9797
#
# Epoch 00028: val_loss did not improve from 0.00866
# Epoch 29/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 0.0376 - val_accuracy: 0.9906
#
# Epoch 00029: val_loss did not improve from 0.00866
# Epoch 30/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0251 - accuracy: 0.9924 - val_loss: 0.0700 - val_accuracy: 0.9852
#
# Epoch 00030: val_loss did not improve from 0.00866
# Epoch 31/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0237 - accuracy: 0.9929 - val_loss: 0.0134 - val_accuracy: 0.9969
#
# Epoch 00031: val_loss did not improve from 0.00866
# Epoch 32/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0199 - accuracy: 0.9944 - val_loss: 0.0611 - val_accuracy: 0.9879
#
# Epoch 00032: val_loss did not improve from 0.00866
# Epoch 33/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0219 - accuracy: 0.9943 - val_loss: 0.0437 - val_accuracy: 0.9891
#
# Epoch 00033: val_loss did not improve from 0.00866
# Epoch 34/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0160 - accuracy: 0.9944 - val_loss: 0.2147 - val_accuracy: 0.9438
#
# Epoch 00034: val_loss did not improve from 0.00866
# Epoch 35/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00035: val_loss improved from 0.00866 to 0.00570, saving model to model.h5
# Epoch 36/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0158 - accuracy: 0.9954 - val_loss: 0.0736 - val_accuracy: 0.9770
#
# Epoch 00036: val_loss did not improve from 0.00570
# Epoch 37/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 0.1790 - val_accuracy: 0.9508
#
# Epoch 00037: val_loss did not improve from 0.00570
# Epoch 38/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0215 - accuracy: 0.9943 - val_loss: 0.0719 - val_accuracy: 0.9797
#
# Epoch 00038: val_loss did not improve from 0.00570
# Epoch 39/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 0.0099 - val_accuracy: 0.9961
#
# Epoch 00039: val_loss did not improve from 0.00570
# Epoch 40/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.0094 - val_accuracy: 0.9961
#
# Epoch 00040: val_loss did not improve from 0.00570
# Epoch 41/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.0055 - val_accuracy: 0.9977
#
# Epoch 00041: val_loss improved from 0.00570 to 0.00553, saving model to model.h5
# Epoch 42/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0203 - accuracy: 0.9944 - val_loss: 1.0342 - val_accuracy: 0.7957
#
# Epoch 00042: val_loss did not improve from 0.00553
# Epoch 43/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0224 - accuracy: 0.9935 - val_loss: 0.3155 - val_accuracy: 0.9211
#
# Epoch 00043: val_loss did not improve from 0.00553
# Epoch 44/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0251 - accuracy: 0.9931 - val_loss: 0.0065 - val_accuracy: 0.9973
#
# Epoch 00044: val_loss did not improve from 0.00553
# Epoch 45/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.0152 - val_accuracy: 0.9953
#
# Epoch 00045: val_loss did not improve from 0.00553
# Epoch 46/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0218 - val_accuracy: 0.9949
#
# Epoch 00046: val_loss did not improve from 0.00553
# Epoch 47/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.1576 - val_accuracy: 0.9629
#
# Epoch 00047: val_loss did not improve from 0.00553
# Epoch 48/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00048: val_loss improved from 0.00553 to 0.00454, saving model to model.h5
# Epoch 49/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.2692 - val_accuracy: 0.9348
#
# Epoch 00049: val_loss did not improve from 0.00454
# Epoch 50/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.0362 - val_accuracy: 0.9906
#
# Epoch 00050: val_loss did not improve from 0.00454
# Epoch 51/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0164 - accuracy: 0.9952 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00051: val_loss improved from 0.00454 to 0.00390, saving model to model.h5
# Epoch 52/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00052: val_loss did not improve from 0.00390
# Epoch 53/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 0.0055 - val_accuracy: 0.9973
#
# Epoch 00053: val_loss did not improve from 0.00390
# Epoch 54/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.0915 - val_accuracy: 0.9742
#
# Epoch 00054: val_loss did not improve from 0.00390
# Epoch 55/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0291 - accuracy: 0.9929 - val_loss: 0.0047 - val_accuracy: 0.9977
#
# Epoch 00055: val_loss did not improve from 0.00390
# Epoch 56/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00056: val_loss improved from 0.00390 to 0.00307, saving model to model.h5
# Epoch 57/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00057: val_loss improved from 0.00307 to 0.00208, saving model to model.h5
# Epoch 58/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0166 - accuracy: 0.9966 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00208
# Epoch 59/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00059: val_loss did not improve from 0.00208
# Epoch 60/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0070 - val_accuracy: 0.9980
#
# Epoch 00060: val_loss did not improve from 0.00208
# Epoch 61/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.0092 - val_accuracy: 0.9977
#
# Epoch 00061: val_loss did not improve from 0.00208
# Epoch 62/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.8351 - val_accuracy: 0.9141
#
# Epoch 00062: val_loss did not improve from 0.00208
# Epoch 63/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0124 - val_accuracy: 0.9969
#
# Epoch 00063: val_loss did not improve from 0.00208
# Epoch 64/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0182 - accuracy: 0.9955 - val_loss: 0.2279 - val_accuracy: 0.9582
#
# Epoch 00064: val_loss did not improve from 0.00208
# Epoch 65/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.0121 - val_accuracy: 0.9977
#
# Epoch 00065: val_loss did not improve from 0.00208
# Epoch 66/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 0.0107 - val_accuracy: 0.9973
#
# Epoch 00066: val_loss did not improve from 0.00208
# Epoch 67/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.9086 - val_accuracy: 0.8781
#
# Epoch 00067: val_loss did not improve from 0.00208
# Epoch 68/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.0075 - val_accuracy: 0.9973
#
# Epoch 00068: val_loss did not improve from 0.00208
# Epoch 69/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 0.0193 - val_accuracy: 0.9937
#
# Epoch 00069: val_loss did not improve from 0.00208
# Epoch 70/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.0052 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00208
# Epoch 71/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0073 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00208
# Epoch 72/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00072: val_loss did not improve from 0.00208
# Epoch 73/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00073: val_loss did not improve from 0.00208
# Epoch 74/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0092 - accuracy: 0.9964 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00208
# Epoch 75/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0133 - accuracy: 0.9966 - val_loss: 0.0307 - val_accuracy: 0.9922
#
# Epoch 00075: val_loss did not improve from 0.00208
# Epoch 76/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00208
# Epoch 77/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00077: val_loss did not improve from 0.00208
# Epoch 78/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0145 - accuracy: 0.9967 - val_loss: 0.0253 - val_accuracy: 0.9934
#
# Epoch 00078: val_loss did not improve from 0.00208
# Epoch 79/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.0093 - val_accuracy: 0.9969
#
# Epoch 00079: val_loss did not improve from 0.00208
# Epoch 80/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.0096 - val_accuracy: 0.9973
#
# Epoch 00080: val_loss did not improve from 0.00208
# Epoch 81/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0166 - accuracy: 0.9951 - val_loss: 0.0329 - val_accuracy: 0.9910
#
# Epoch 00081: val_loss did not improve from 0.00208
# Epoch 82/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0150 - accuracy: 0.9959 - val_loss: 0.0063 - val_accuracy: 0.9977
#
# Epoch 00082: val_loss did not improve from 0.00208
# Epoch 83/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0091 - val_accuracy: 0.9973
#
# Epoch 00083: val_loss did not improve from 0.00208
# Epoch 84/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0138 - accuracy: 0.9950 - val_loss: 0.0265 - val_accuracy: 0.9895
#
# Epoch 00084: val_loss did not improve from 0.00208
# Epoch 85/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.0029 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00208
# Epoch 86/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.1576 - val_accuracy: 0.9621
#
# Epoch 00086: val_loss did not improve from 0.00208
# Epoch 87/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0078 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00208
# Epoch 88/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0065 - accuracy: 0.9969 - val_loss: 0.0054 - val_accuracy: 0.9977
#
# Epoch 00088: val_loss did not improve from 0.00208
# Epoch 89/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0068 - accuracy: 0.9968 - val_loss: 0.0134 - val_accuracy: 0.9957
#
# Epoch 00089: val_loss did not improve from 0.00208
# Epoch 90/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0098 - accuracy: 0.9959 - val_loss: 0.0178 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00208
# Epoch 91/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0136 - accuracy: 0.9959 - val_loss: 0.0134 - val_accuracy: 0.9949
#
# Epoch 00091: val_loss did not improve from 0.00208
# Epoch 92/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.0050 - val_accuracy: 0.9980
#
# Epoch 00092: val_loss did not improve from 0.00208
# Epoch 93/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0135 - accuracy: 0.9961 - val_loss: 0.3514 - val_accuracy: 0.9316
#
# Epoch 00093: val_loss did not improve from 0.00208
# Epoch 94/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00094: val_loss did not improve from 0.00208
# Epoch 95/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.0235 - val_accuracy: 0.9930
#
# Epoch 00095: val_loss did not improve from 0.00208
# Epoch 96/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00096: val_loss did not improve from 0.00208
# Epoch 97/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00097: val_loss did not improve from 0.00208
# Epoch 98/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0143 - val_accuracy: 0.9969
#
# Epoch 00098: val_loss did not improve from 0.00208
# Epoch 99/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0122 - accuracy: 0.9968 - val_loss: 0.0420 - val_accuracy: 0.9852
#
# Epoch 00099: val_loss did not improve from 0.00208
# Epoch 100/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 1.6372 - val_accuracy: 0.8359
#
# Epoch 00100: val_loss did not improve from 0.00208
# 80/80 [==============================] - 0s 3ms/step - loss: 1.6372 - accuracy: 0.8359
# Val Score:  [1.6371917724609375, 0.8359375]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 6s 13ms/step - loss: 0.4836 - accuracy: 0.8570 - val_loss: 1.2452 - val_accuracy: 0.6719
#
# Epoch 00001: val_loss did not improve from 0.00208
# Epoch 2/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1688 - accuracy: 0.9409 - val_loss: 0.8260 - val_accuracy: 0.8012
#
# Epoch 00002: val_loss did not improve from 0.00208
# Epoch 3/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1158 - accuracy: 0.9605 - val_loss: 0.5782 - val_accuracy: 0.8125
#
# Epoch 00003: val_loss did not improve from 0.00208
# Epoch 4/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0889 - accuracy: 0.9688 - val_loss: 0.1688 - val_accuracy: 0.9418
#
# Epoch 00004: val_loss did not improve from 0.00208
# Epoch 5/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0803 - accuracy: 0.9738 - val_loss: 0.0618 - val_accuracy: 0.9750
#
# Epoch 00005: val_loss did not improve from 0.00208
# Epoch 6/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0605 - accuracy: 0.9792 - val_loss: 0.1871 - val_accuracy: 0.9621
#
# Epoch 00006: val_loss did not improve from 0.00208
# Epoch 7/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0569 - accuracy: 0.9805 - val_loss: 0.0255 - val_accuracy: 0.9906
#
# Epoch 00007: val_loss did not improve from 0.00208
# Epoch 8/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0450 - accuracy: 0.9841 - val_loss: 0.0295 - val_accuracy: 0.9922
#
# Epoch 00008: val_loss did not improve from 0.00208
# Epoch 9/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0492 - accuracy: 0.9839 - val_loss: 0.0393 - val_accuracy: 0.9855
#
# Epoch 00009: val_loss did not improve from 0.00208
# Epoch 10/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0426 - accuracy: 0.9866 - val_loss: 0.1933 - val_accuracy: 0.9305
#
# Epoch 00010: val_loss did not improve from 0.00208
# Epoch 11/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0478 - accuracy: 0.9841 - val_loss: 0.0374 - val_accuracy: 0.9898
#
# Epoch 00011: val_loss did not improve from 0.00208
# Epoch 12/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0410 - accuracy: 0.9870 - val_loss: 0.0554 - val_accuracy: 0.9801
#
# Epoch 00012: val_loss did not improve from 0.00208
# Epoch 13/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.0058 - val_accuracy: 0.9977
#
# Epoch 00013: val_loss did not improve from 0.00208
# Epoch 14/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0320 - accuracy: 0.9894 - val_loss: 0.0444 - val_accuracy: 0.9820
#
# Epoch 00014: val_loss did not improve from 0.00208
# Epoch 15/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0301 - accuracy: 0.9900 - val_loss: 0.3228 - val_accuracy: 0.9203
#
# Epoch 00015: val_loss did not improve from 0.00208
# Epoch 16/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0364 - accuracy: 0.9888 - val_loss: 0.1289 - val_accuracy: 0.9617
#
# Epoch 00016: val_loss did not improve from 0.00208
# Epoch 17/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0227 - accuracy: 0.9924 - val_loss: 0.6912 - val_accuracy: 0.8523
#
# Epoch 00017: val_loss did not improve from 0.00208
# Epoch 18/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.0120 - val_accuracy: 0.9961
#
# Epoch 00018: val_loss did not improve from 0.00208
# Epoch 19/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0352 - accuracy: 0.9896 - val_loss: 0.0913 - val_accuracy: 0.9660
#
# Epoch 00019: val_loss did not improve from 0.00208
# Epoch 20/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0231 - accuracy: 0.9923 - val_loss: 0.0213 - val_accuracy: 0.9926
#
# Epoch 00020: val_loss did not improve from 0.00208
# Epoch 21/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0444 - accuracy: 0.9877 - val_loss: 0.0213 - val_accuracy: 0.9910
#
# Epoch 00021: val_loss did not improve from 0.00208
# Epoch 22/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.0881 - val_accuracy: 0.9805
#
# Epoch 00022: val_loss did not improve from 0.00208
# Epoch 23/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0309 - accuracy: 0.9906 - val_loss: 0.4426 - val_accuracy: 0.9125
#
# Epoch 00023: val_loss did not improve from 0.00208
# Epoch 24/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0210 - accuracy: 0.9928 - val_loss: 0.0488 - val_accuracy: 0.9848
#
# Epoch 00024: val_loss did not improve from 0.00208
# Epoch 25/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.1405 - val_accuracy: 0.9629
#
# Epoch 00025: val_loss did not improve from 0.00208
# Epoch 26/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0272 - accuracy: 0.9902 - val_loss: 0.1566 - val_accuracy: 0.9504
#
# Epoch 00026: val_loss did not improve from 0.00208
# Epoch 27/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.0105 - val_accuracy: 0.9957
#
# Epoch 00027: val_loss did not improve from 0.00208
# Epoch 28/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0198 - accuracy: 0.9923 - val_loss: 0.0077 - val_accuracy: 0.9961
#
# Epoch 00028: val_loss did not improve from 0.00208
# Epoch 29/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0168 - accuracy: 0.9939 - val_loss: 0.0068 - val_accuracy: 0.9980
#
# Epoch 00029: val_loss did not improve from 0.00208
# Epoch 30/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 4.0247 - val_accuracy: 0.6477
#
# Epoch 00030: val_loss did not improve from 0.00208
# Epoch 31/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.0222 - val_accuracy: 0.9941
#
# Epoch 00031: val_loss did not improve from 0.00208
# Epoch 32/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0235 - accuracy: 0.9924 - val_loss: 0.0090 - val_accuracy: 0.9973
#
# Epoch 00032: val_loss did not improve from 0.00208
# Epoch 33/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0230 - accuracy: 0.9928 - val_loss: 0.0258 - val_accuracy: 0.9902
#
# Epoch 00033: val_loss did not improve from 0.00208
# Epoch 34/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0164 - accuracy: 0.9943 - val_loss: 0.0099 - val_accuracy: 0.9973
#
# Epoch 00034: val_loss did not improve from 0.00208
# Epoch 35/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0750 - val_accuracy: 0.9797
#
# Epoch 00035: val_loss did not improve from 0.00208
# Epoch 36/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.0654 - val_accuracy: 0.9785
#
# Epoch 00036: val_loss did not improve from 0.00208
# Epoch 37/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0151 - accuracy: 0.9943 - val_loss: 0.0936 - val_accuracy: 0.9805
#
# Epoch 00037: val_loss did not improve from 0.00208
# Epoch 38/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0179 - accuracy: 0.9943 - val_loss: 0.0112 - val_accuracy: 0.9969
#
# Epoch 00038: val_loss did not improve from 0.00208
# Epoch 39/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 0.0116 - val_accuracy: 0.9973
#
# Epoch 00039: val_loss did not improve from 0.00208
# Epoch 40/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.0457 - val_accuracy: 0.9828
#
# Epoch 00040: val_loss did not improve from 0.00208
# Epoch 41/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 0.0119 - val_accuracy: 0.9969
#
# Epoch 00041: val_loss did not improve from 0.00208
# Epoch 42/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00042: val_loss did not improve from 0.00208
# Epoch 43/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.0931 - val_accuracy: 0.9797
#
# Epoch 00043: val_loss did not improve from 0.00208
# Epoch 44/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.6017 - val_accuracy: 0.9035
#
# Epoch 00044: val_loss did not improve from 0.00208
# Epoch 45/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.0627 - val_accuracy: 0.9805
#
# Epoch 00045: val_loss did not improve from 0.00208
# Epoch 46/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.0155 - val_accuracy: 0.9953
#
# Epoch 00046: val_loss did not improve from 0.00208
# Epoch 47/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 0.0615 - val_accuracy: 0.9867
#
# Epoch 00047: val_loss did not improve from 0.00208
# Epoch 48/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.5321 - val_accuracy: 0.9141
#
# Epoch 00048: val_loss did not improve from 0.00208
# Epoch 49/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0170 - accuracy: 0.9941 - val_loss: 0.1892 - val_accuracy: 0.9621
#
# Epoch 00049: val_loss did not improve from 0.00208
# Epoch 50/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0118 - accuracy: 0.9959 - val_loss: 4.5789 - val_accuracy: 0.6523
#
# Epoch 00050: val_loss did not improve from 0.00208
# Epoch 51/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0136 - accuracy: 0.9959 - val_loss: 0.0131 - val_accuracy: 0.9965
#
# Epoch 00051: val_loss did not improve from 0.00208
# Epoch 52/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.0160 - val_accuracy: 0.9953
#
# Epoch 00052: val_loss did not improve from 0.00208
# Epoch 53/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.5949 - val_accuracy: 0.8801
#
# Epoch 00053: val_loss did not improve from 0.00208
# Epoch 54/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0291 - accuracy: 0.9922 - val_loss: 0.0274 - val_accuracy: 0.9902
#
# Epoch 00054: val_loss did not improve from 0.00208
# Epoch 55/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0174 - accuracy: 0.9945 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00055: val_loss did not improve from 0.00208
# Epoch 56/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.0115 - val_accuracy: 0.9961
#
# Epoch 00056: val_loss did not improve from 0.00208
# Epoch 57/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.0066 - val_accuracy: 0.9969
#
# Epoch 00057: val_loss did not improve from 0.00208
# Epoch 58/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0206 - val_accuracy: 0.9957
#
# Epoch 00058: val_loss did not improve from 0.00208
# Epoch 59/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0291 - val_accuracy: 0.9941
#
# Epoch 00059: val_loss did not improve from 0.00208
# Epoch 60/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.0116 - val_accuracy: 0.9965
#
# Epoch 00060: val_loss did not improve from 0.00208
# Epoch 61/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0136 - accuracy: 0.9948 - val_loss: 0.0323 - val_accuracy: 0.9953
#
# Epoch 00061: val_loss did not improve from 0.00208
# Epoch 62/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.0201 - val_accuracy: 0.9941
#
# Epoch 00062: val_loss did not improve from 0.00208
# Epoch 63/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 0.3347 - val_accuracy: 0.9234
#
# Epoch 00063: val_loss did not improve from 0.00208
# Epoch 64/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.4251 - val_accuracy: 0.9125
#
# Epoch 00064: val_loss did not improve from 0.00208
# Epoch 65/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 0.1733 - val_accuracy: 0.9543
#
# Epoch 00065: val_loss did not improve from 0.00208
# Epoch 66/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00066: val_loss did not improve from 0.00208
# Epoch 67/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0137 - accuracy: 0.9953 - val_loss: 0.0727 - val_accuracy: 0.9797
#
# Epoch 00067: val_loss did not improve from 0.00208
# Epoch 68/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0532 - val_accuracy: 0.9848
#
# Epoch 00068: val_loss did not improve from 0.00208
# Epoch 69/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0115 - accuracy: 0.9955 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00069: val_loss did not improve from 0.00208
# Epoch 70/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0173 - val_accuracy: 0.9949
#
# Epoch 00070: val_loss did not improve from 0.00208
# Epoch 71/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.0194 - val_accuracy: 0.9930
#
# Epoch 00071: val_loss did not improve from 0.00208
# Epoch 72/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0198 - accuracy: 0.9945 - val_loss: 0.0062 - val_accuracy: 0.9980
#
# Epoch 00072: val_loss did not improve from 0.00208
# Epoch 73/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0256 - val_accuracy: 0.9937
#
# Epoch 00073: val_loss did not improve from 0.00208
# Epoch 74/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.0098 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00208
# Epoch 75/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00208
# Epoch 76/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.1820 - val_accuracy: 0.9602
#
# Epoch 00076: val_loss did not improve from 0.00208
# Epoch 77/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00077: val_loss did not improve from 0.00208
# Epoch 78/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 0.0258 - val_accuracy: 0.9926
#
# Epoch 00078: val_loss did not improve from 0.00208
# Epoch 79/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.0096 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00208
# Epoch 80/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0114 - val_accuracy: 0.9969
#
# Epoch 00080: val_loss did not improve from 0.00208
# Epoch 81/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0072 - accuracy: 0.9968 - val_loss: 0.0216 - val_accuracy: 0.9930
#
# Epoch 00081: val_loss did not improve from 0.00208
# Epoch 82/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00082: val_loss did not improve from 0.00208
# Epoch 83/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0379 - val_accuracy: 0.9895
#
# Epoch 00083: val_loss did not improve from 0.00208
# Epoch 84/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.0658 - val_accuracy: 0.9859
#
# Epoch 00084: val_loss did not improve from 0.00208
# Epoch 85/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00208
# Epoch 86/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.0154 - val_accuracy: 0.9957
#
# Epoch 00086: val_loss did not improve from 0.00208
# Epoch 87/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0107 - accuracy: 0.9958 - val_loss: 0.4775 - val_accuracy: 0.9074
#
# Epoch 00087: val_loss did not improve from 0.00208
# Epoch 88/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.0065 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00208
# Epoch 89/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0027 - val_accuracy: 0.9988
#
# Epoch 00089: val_loss did not improve from 0.00208
# Epoch 90/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.0639 - val_accuracy: 0.9809
#
# Epoch 00090: val_loss did not improve from 0.00208
# Epoch 91/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00208
# Epoch 92/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0115 - val_accuracy: 0.9957
#
# Epoch 00092: val_loss did not improve from 0.00208
# Epoch 93/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.7490 - val_accuracy: 0.9039
#
# Epoch 00093: val_loss did not improve from 0.00208
# Epoch 94/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0632 - val_accuracy: 0.9809
#
# Epoch 00094: val_loss did not improve from 0.00208
# Epoch 95/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0122 - accuracy: 0.9953 - val_loss: 0.0588 - val_accuracy: 0.9836
#
# Epoch 00095: val_loss did not improve from 0.00208
# Epoch 96/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0161 - val_accuracy: 0.9957
#
# Epoch 00096: val_loss did not improve from 0.00208
# Epoch 97/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0158 - val_accuracy: 0.9953
#
# Epoch 00097: val_loss did not improve from 0.00208
# Epoch 98/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0070 - val_accuracy: 0.9973
#
# Epoch 00098: val_loss did not improve from 0.00208
# Epoch 99/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 0.0101 - val_accuracy: 0.9965
#
# Epoch 00099: val_loss did not improve from 0.00208
# Epoch 100/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 0.2639 - val_accuracy: 0.9426
#
# Epoch 00100: val_loss did not improve from 0.00208
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2639 - accuracy: 0.9426
# Val Score:  [0.2639444172382355, 0.942578136920929]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 6s 14ms/step - loss: 0.4079 - accuracy: 0.8745 - val_loss: 1.8229 - val_accuracy: 0.6023
#
# Epoch 00001: val_loss did not improve from 0.00208
# Epoch 2/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1252 - accuracy: 0.9563 - val_loss: 0.1538 - val_accuracy: 0.9461
#
# Epoch 00002: val_loss did not improve from 0.00208
# Epoch 3/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1037 - accuracy: 0.9646 - val_loss: 0.4837 - val_accuracy: 0.8363
#
# Epoch 00003: val_loss did not improve from 0.00208
# Epoch 4/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0803 - accuracy: 0.9747 - val_loss: 1.1763 - val_accuracy: 0.7773
#
# Epoch 00004: val_loss did not improve from 0.00208
# Epoch 5/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0539 - accuracy: 0.9828 - val_loss: 0.0677 - val_accuracy: 0.9797
#
# Epoch 00005: val_loss did not improve from 0.00208
# Epoch 6/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0423 - accuracy: 0.9858 - val_loss: 3.5781 - val_accuracy: 0.5758
#
# Epoch 00006: val_loss did not improve from 0.00208
# Epoch 7/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0509 - accuracy: 0.9854 - val_loss: 0.0380 - val_accuracy: 0.9875
#
# Epoch 00007: val_loss did not improve from 0.00208
# Epoch 8/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0419 - accuracy: 0.9860 - val_loss: 0.0445 - val_accuracy: 0.9848
#
# Epoch 00008: val_loss did not improve from 0.00208
# Epoch 9/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0319 - accuracy: 0.9886 - val_loss: 0.0586 - val_accuracy: 0.9797
#
# Epoch 00009: val_loss did not improve from 0.00208
# Epoch 10/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0339 - accuracy: 0.9897 - val_loss: 1.1341 - val_accuracy: 0.7797
#
# Epoch 00010: val_loss did not improve from 0.00208
# Epoch 11/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0361 - accuracy: 0.9881 - val_loss: 0.0326 - val_accuracy: 0.9879
#
# Epoch 00011: val_loss did not improve from 0.00208
# Epoch 12/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0361 - accuracy: 0.9885 - val_loss: 0.1013 - val_accuracy: 0.9676
#
# Epoch 00012: val_loss did not improve from 0.00208
# Epoch 13/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0310 - accuracy: 0.9902 - val_loss: 0.6364 - val_accuracy: 0.8738
#
# Epoch 00013: val_loss did not improve from 0.00208
# Epoch 14/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0294 - accuracy: 0.9901 - val_loss: 0.5908 - val_accuracy: 0.8746
#
# Epoch 00014: val_loss did not improve from 0.00208
# Epoch 15/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0319 - accuracy: 0.9897 - val_loss: 0.0195 - val_accuracy: 0.9937
#
# Epoch 00015: val_loss did not improve from 0.00208
# Epoch 16/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0277 - accuracy: 0.9922 - val_loss: 0.0058 - val_accuracy: 0.9984
#
# Epoch 00016: val_loss did not improve from 0.00208
# Epoch 17/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0173 - accuracy: 0.9937 - val_loss: 4.2621 - val_accuracy: 0.6148
#
# Epoch 00017: val_loss did not improve from 0.00208
# Epoch 18/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 0.0227 - val_accuracy: 0.9918
#
# Epoch 00018: val_loss did not improve from 0.00208
# Epoch 19/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00019: val_loss did not improve from 0.00208
# Epoch 20/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0201 - accuracy: 0.9932 - val_loss: 0.0076 - val_accuracy: 0.9980
#
# Epoch 00020: val_loss did not improve from 0.00208
# Epoch 21/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.1706 - val_accuracy: 0.9602
#
# Epoch 00021: val_loss did not improve from 0.00208
# Epoch 22/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0403 - accuracy: 0.9888 - val_loss: 0.0139 - val_accuracy: 0.9945
#
# Epoch 00022: val_loss did not improve from 0.00208
# Epoch 23/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0087 - val_accuracy: 0.9980
#
# Epoch 00023: val_loss did not improve from 0.00208
# Epoch 24/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 0.0152 - val_accuracy: 0.9961
#
# Epoch 00024: val_loss did not improve from 0.00208
# Epoch 25/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 0.7127 - val_accuracy: 0.8586
#
# Epoch 00025: val_loss did not improve from 0.00208
# Epoch 26/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0220 - accuracy: 0.9933 - val_loss: 0.1985 - val_accuracy: 0.9484
#
# Epoch 00026: val_loss did not improve from 0.00208
# Epoch 27/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0262 - accuracy: 0.9929 - val_loss: 0.0105 - val_accuracy: 0.9973
#
# Epoch 00027: val_loss did not improve from 0.00208
# Epoch 28/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0172 - accuracy: 0.9952 - val_loss: 0.0696 - val_accuracy: 0.9758
#
# Epoch 00028: val_loss did not improve from 0.00208
# Epoch 29/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0181 - accuracy: 0.9948 - val_loss: 0.0030 - val_accuracy: 0.9988
#
# Epoch 00029: val_loss did not improve from 0.00208
# Epoch 30/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0057 - val_accuracy: 0.9973
#
# Epoch 00030: val_loss did not improve from 0.00208
# Epoch 31/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0223 - accuracy: 0.9933 - val_loss: 0.0771 - val_accuracy: 0.9793
#
# Epoch 00031: val_loss did not improve from 0.00208
# Epoch 32/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0289 - accuracy: 0.9904 - val_loss: 0.0247 - val_accuracy: 0.9910
#
# Epoch 00032: val_loss did not improve from 0.00208
# Epoch 33/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.0284 - val_accuracy: 0.9961
#
# Epoch 00033: val_loss did not improve from 0.00208
# Epoch 34/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0283 - val_accuracy: 0.9930
#
# Epoch 00034: val_loss did not improve from 0.00208
# Epoch 35/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.0090 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00208
# Epoch 36/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0229 - accuracy: 0.9935 - val_loss: 0.0672 - val_accuracy: 0.9789
#
# Epoch 00036: val_loss did not improve from 0.00208
# Epoch 37/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0075 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss did not improve from 0.00208
# Epoch 38/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0120 - accuracy: 0.9950 - val_loss: 0.0889 - val_accuracy: 0.9676
#
# Epoch 00038: val_loss did not improve from 0.00208
# Epoch 39/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.0158 - val_accuracy: 0.9937
#
# Epoch 00039: val_loss did not improve from 0.00208
# Epoch 40/100
# ...
# Epoch 21/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0288 - accuracy: 0.9914 - val_loss: 0.0366 - val_accuracy: 0.9898
#
# Epoch 00021: val_loss did not improve from 0.00207
# Epoch 22/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0251 - accuracy: 0.9922 - val_loss: 0.1152 - val_accuracy: 0.9652
#
# Epoch 00022: val_loss did not improve from 0.00207
# Epoch 23/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0256 - accuracy: 0.9921 - val_loss: 0.0755 - val_accuracy: 0.9797
#
# Epoch 00023: val_loss did not improve from 0.00207
# Epoch 24/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0269 - val_accuracy: 0.9922
#
# Epoch 00024: val_loss did not improve from 0.00207
# Epoch 25/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0258 - accuracy: 0.9925 - val_loss: 1.1793 - val_accuracy: 0.7848
#
# Epoch 00025: val_loss did not improve from 0.00207
# Epoch 26/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0390 - accuracy: 0.9893 - val_loss: 0.4051 - val_accuracy: 0.9187
#
# Epoch 00026: val_loss did not improve from 0.00207
# Epoch 27/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0047 - val_accuracy: 0.9988
#
# Epoch 00027: val_loss did not improve from 0.00207
# Epoch 28/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.0334 - val_accuracy: 0.9898
#
# Epoch 00028: val_loss did not improve from 0.00207
# Epoch 29/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0182 - accuracy: 0.9939 - val_loss: 0.0167 - val_accuracy: 0.9965
#
# Epoch 00029: val_loss did not improve from 0.00207
# Epoch 30/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0219 - accuracy: 0.9934 - val_loss: 0.0116 - val_accuracy: 0.9961
#
# Epoch 00030: val_loss did not improve from 0.00207
# Epoch 31/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.3221 - val_accuracy: 0.9277
#
# Epoch 00031: val_loss did not improve from 0.00207
# Epoch 32/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.0046 - val_accuracy: 0.9980
#
# Epoch 00032: val_loss did not improve from 0.00207
# Epoch 33/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 2.6480 - val_accuracy: 0.7023
#
# Epoch 00033: val_loss did not improve from 0.00207
# Epoch 34/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0299 - accuracy: 0.9896 - val_loss: 0.0295 - val_accuracy: 0.9891
#
# Epoch 00034: val_loss did not improve from 0.00207
# Epoch 35/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0183 - accuracy: 0.9938 - val_loss: 0.0080 - val_accuracy: 0.9977
#
# Epoch 00035: val_loss did not improve from 0.00207
# Epoch 36/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0150 - accuracy: 0.9957 - val_loss: 0.0295 - val_accuracy: 0.9910
#
# Epoch 00036: val_loss did not improve from 0.00207
# Epoch 37/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0157 - accuracy: 0.9952 - val_loss: 0.1492 - val_accuracy: 0.9664
#
# Epoch 00037: val_loss did not improve from 0.00207
# Epoch 38/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.0091 - val_accuracy: 0.9969
#
# Epoch 00038: val_loss did not improve from 0.00207
# Epoch 39/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0080 - val_accuracy: 0.9973
#
# Epoch 00039: val_loss did not improve from 0.00207
# Epoch 40/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.0153 - val_accuracy: 0.9937
#
# Epoch 00040: val_loss did not improve from 0.00207
# Epoch 41/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0166 - accuracy: 0.9938 - val_loss: 0.0446 - val_accuracy: 0.9844
#
# Epoch 00041: val_loss did not improve from 0.00207
# Epoch 42/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0170 - accuracy: 0.9938 - val_loss: 0.0592 - val_accuracy: 0.9875
#
# Epoch 00042: val_loss did not improve from 0.00207
# Epoch 43/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0054 - val_accuracy: 0.9973
#
# Epoch 00043: val_loss did not improve from 0.00207
# Epoch 44/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0229 - val_accuracy: 0.9934
#
# Epoch 00044: val_loss did not improve from 0.00207
# Epoch 45/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00045: val_loss did not improve from 0.00207
# Epoch 46/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0174 - accuracy: 0.9939 - val_loss: 0.0530 - val_accuracy: 0.9836
#
# Epoch 00046: val_loss did not improve from 0.00207
# Epoch 47/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0200 - accuracy: 0.9939 - val_loss: 0.0193 - val_accuracy: 0.9941
#
# Epoch 00047: val_loss did not improve from 0.00207
# Epoch 48/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0152 - accuracy: 0.9945 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00048: val_loss did not improve from 0.00207
# Epoch 49/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.0883 - val_accuracy: 0.9668
#
# Epoch 00049: val_loss did not improve from 0.00207
# Epoch 50/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0179 - accuracy: 0.9940 - val_loss: 0.0231 - val_accuracy: 0.9945
#
# Epoch 00050: val_loss did not improve from 0.00207
# Epoch 51/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0446 - val_accuracy: 0.9852
#
# Epoch 00051: val_loss did not improve from 0.00207
# Epoch 52/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0070 - val_accuracy: 0.9980
#
# Epoch 00052: val_loss did not improve from 0.00207
# Epoch 53/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00053: val_loss did not improve from 0.00207
# Epoch 54/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0189 - accuracy: 0.9950 - val_loss: 0.3722 - val_accuracy: 0.9457
#
# Epoch 00054: val_loss did not improve from 0.00207
# Epoch 55/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0109 - accuracy: 0.9960 - val_loss: 0.0095 - val_accuracy: 0.9965
#
# Epoch 00055: val_loss did not improve from 0.00207
# Epoch 56/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0199 - accuracy: 0.9941 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00056: val_loss did not improve from 0.00207
# Epoch 57/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0210 - accuracy: 0.9939 - val_loss: 0.0701 - val_accuracy: 0.9855
#
# Epoch 00057: val_loss did not improve from 0.00207
# Epoch 58/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0095 - accuracy: 0.9962 - val_loss: 0.0068 - val_accuracy: 0.9973
#
# Epoch 00058: val_loss did not improve from 0.00207
# Epoch 59/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00059: val_loss did not improve from 0.00207
# Epoch 60/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00060: val_loss did not improve from 0.00207
# Epoch 61/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0227 - accuracy: 0.9937 - val_loss: 0.0251 - val_accuracy: 0.9926
#
# Epoch 00061: val_loss did not improve from 0.00207
# Epoch 62/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.6635 - val_accuracy: 0.9051
#
# Epoch 00062: val_loss did not improve from 0.00207
# Epoch 63/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0539 - accuracy: 0.9882 - val_loss: 0.0095 - val_accuracy: 0.9973
#
# Epoch 00063: val_loss did not improve from 0.00207
# Epoch 64/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.0102 - val_accuracy: 0.9969
#
# Epoch 00064: val_loss did not improve from 0.00207
# Epoch 65/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.0075 - val_accuracy: 0.9965
#
# Epoch 00065: val_loss did not improve from 0.00207
# Epoch 66/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00066: val_loss did not improve from 0.00207
# Epoch 67/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0051 - val_accuracy: 0.9973
#
# Epoch 00067: val_loss did not improve from 0.00207
# Epoch 68/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00207
# Epoch 69/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0135 - accuracy: 0.9951 - val_loss: 0.0055 - val_accuracy: 0.9980
#
# Epoch 00069: val_loss did not improve from 0.00207
# Epoch 70/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 1.3080 - val_accuracy: 0.7855
#
# Epoch 00070: val_loss did not improve from 0.00207
# Epoch 71/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00071: val_loss did not improve from 0.00207
# Epoch 72/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00072: val_loss did not improve from 0.00207
# Epoch 73/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0081 - accuracy: 0.9967 - val_loss: 0.2729 - val_accuracy: 0.9316
#
# Epoch 00073: val_loss did not improve from 0.00207
# Epoch 74/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.3610 - val_accuracy: 0.9414
#
# Epoch 00074: val_loss did not improve from 0.00207
# Epoch 75/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.0338 - val_accuracy: 0.9895
#
# Epoch 00075: val_loss did not improve from 0.00207
# Epoch 76/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00076: val_loss did not improve from 0.00207
# Epoch 77/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0171 - accuracy: 0.9960 - val_loss: 0.0616 - val_accuracy: 0.9887
#
# Epoch 00077: val_loss did not improve from 0.00207
# Epoch 78/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0083 - val_accuracy: 0.9961
#
# Epoch 00078: val_loss did not improve from 0.00207
# Epoch 79/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.0031 - val_accuracy: 0.9980
#
# Epoch 00079: val_loss did not improve from 0.00207
# Epoch 80/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00207
# Epoch 81/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0509 - val_accuracy: 0.9867
#
# Epoch 00081: val_loss did not improve from 0.00207
# Epoch 82/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.0171 - val_accuracy: 0.9941
#
# Epoch 00082: val_loss did not improve from 0.00207
# Epoch 83/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 0.0127 - val_accuracy: 0.9969
#
# Epoch 00083: val_loss did not improve from 0.00207
# Epoch 84/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.0127 - val_accuracy: 0.9969
#
# Epoch 00084: val_loss did not improve from 0.00207
# Epoch 85/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 2.8418 - val_accuracy: 0.7473
#
# Epoch 00085: val_loss did not improve from 0.00207
# Epoch 86/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0209 - accuracy: 0.9941 - val_loss: 0.0080 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00207
# Epoch 87/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0110 - accuracy: 0.9955 - val_loss: 0.0049 - val_accuracy: 0.9969
#
# Epoch 00087: val_loss did not improve from 0.00207
# Epoch 88/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.0860 - val_accuracy: 0.9742
#
# Epoch 00088: val_loss did not improve from 0.00207
# Epoch 89/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.1588 - val_accuracy: 0.9574
#
# Epoch 00089: val_loss did not improve from 0.00207
# Epoch 90/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00090: val_loss did not improve from 0.00207
# Epoch 91/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0087 - accuracy: 0.9966 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00207
# Epoch 92/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0096 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00207
# Epoch 93/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00093: val_loss did not improve from 0.00207
# Epoch 94/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00094: val_loss did not improve from 0.00207
# Epoch 95/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.1160 - val_accuracy: 0.9652
#
# Epoch 00095: val_loss did not improve from 0.00207
# Epoch 96/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.0064 - val_accuracy: 0.9977
#
# Epoch 00096: val_loss did not improve from 0.00207
# Epoch 97/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0040 - val_accuracy: 0.9984
#
# Epoch 00097: val_loss did not improve from 0.00207
# Epoch 98/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.1127 - val_accuracy: 0.9805
#
# Epoch 00098: val_loss did not improve from 0.00207
# Epoch 99/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.0047 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00207
# Epoch 100/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.0677 - val_accuracy: 0.9809
#
# Epoch 00100: val_loss did not improve from 0.00207
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0677 - accuracy: 0.9809
# Val Score:  [0.06768954545259476, 0.9808593988418579]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
