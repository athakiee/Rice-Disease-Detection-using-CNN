# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-5
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_72 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_108 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_109 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_91 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_110 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_92 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_111 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_93 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_36 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_112 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_37 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_113 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 1.0444 - accuracy: 0.6428 - val_loss: 2.7118 - val_accuracy: 0.4871
#
# Epoch 00001: val_loss improved from inf to 2.71181, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.6273 - accuracy: 0.7771 - val_loss: 0.4325 - val_accuracy: 0.8313
#
# Epoch 00002: val_loss improved from 2.71181 to 0.43248, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.4775 - accuracy: 0.8274 - val_loss: 0.2779 - val_accuracy: 0.8992
#
# Epoch 00003: val_loss improved from 0.43248 to 0.27789, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.4074 - accuracy: 0.8504 - val_loss: 0.2590 - val_accuracy: 0.9086
#
# Epoch 00004: val_loss improved from 0.27789 to 0.25899, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.3355 - accuracy: 0.8781 - val_loss: 0.2663 - val_accuracy: 0.8984
#
# Epoch 00005: val_loss did not improve from 0.25899
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3123 - accuracy: 0.8837 - val_loss: 0.2456 - val_accuracy: 0.9086
#
# Epoch 00006: val_loss improved from 0.25899 to 0.24557, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2763 - accuracy: 0.8968 - val_loss: 0.2359 - val_accuracy: 0.9098
#
# Epoch 00007: val_loss improved from 0.24557 to 0.23590, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2374 - accuracy: 0.9115 - val_loss: 0.2130 - val_accuracy: 0.9227
#
# Epoch 00008: val_loss improved from 0.23590 to 0.21298, saving model to model.h5
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2187 - accuracy: 0.9195 - val_loss: 0.2364 - val_accuracy: 0.9180
#
# Epoch 00009: val_loss did not improve from 0.21298
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1979 - accuracy: 0.9275 - val_loss: 0.1894 - val_accuracy: 0.9336
#
# Epoch 00010: val_loss improved from 0.21298 to 0.18941, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1898 - accuracy: 0.9293 - val_loss: 0.1979 - val_accuracy: 0.9309
#
# Epoch 00011: val_loss did not improve from 0.18941
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1761 - accuracy: 0.9373 - val_loss: 0.1785 - val_accuracy: 0.9367
#
# Epoch 00012: val_loss improved from 0.18941 to 0.17850, saving model to model.h5
# Epoch 13/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1483 - accuracy: 0.9440 - val_loss: 0.2219 - val_accuracy: 0.9176
#
# Epoch 00013: val_loss did not improve from 0.17850
# Epoch 14/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1437 - accuracy: 0.9454 - val_loss: 0.2235 - val_accuracy: 0.9187
#
# Epoch 00014: val_loss did not improve from 0.17850
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1425 - accuracy: 0.9483 - val_loss: 0.1860 - val_accuracy: 0.9309
#
# Epoch 00015: val_loss did not improve from 0.17850
# Epoch 16/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1253 - accuracy: 0.9538 - val_loss: 0.2247 - val_accuracy: 0.9148
#
# Epoch 00016: val_loss did not improve from 0.17850
# Epoch 17/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1192 - accuracy: 0.9541 - val_loss: 0.2256 - val_accuracy: 0.9187
#
# Epoch 00017: val_loss did not improve from 0.17850
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1155 - accuracy: 0.9578 - val_loss: 0.1996 - val_accuracy: 0.9289
#
# Epoch 00018: val_loss did not improve from 0.17850
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0997 - accuracy: 0.9626 - val_loss: 0.1941 - val_accuracy: 0.9363
#
# Epoch 00019: val_loss did not improve from 0.17850
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0963 - accuracy: 0.9638 - val_loss: 0.1994 - val_accuracy: 0.9277
#
# Epoch 00020: val_loss did not improve from 0.17850
# Epoch 21/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0975 - accuracy: 0.9650 - val_loss: 0.1885 - val_accuracy: 0.9289
#
# Epoch 00021: val_loss did not improve from 0.17850
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0850 - accuracy: 0.9684 - val_loss: 0.1922 - val_accuracy: 0.9305
#
# Epoch 00022: val_loss did not improve from 0.17850
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0783 - accuracy: 0.9729 - val_loss: 0.2004 - val_accuracy: 0.9340
#
# Epoch 00023: val_loss did not improve from 0.17850
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0810 - accuracy: 0.9723 - val_loss: 0.2046 - val_accuracy: 0.9301
#
# Epoch 00024: val_loss did not improve from 0.17850
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0846 - accuracy: 0.9703 - val_loss: 0.1477 - val_accuracy: 0.9445
#
# Epoch 00025: val_loss improved from 0.17850 to 0.14768, saving model to model.h5
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0737 - accuracy: 0.9756 - val_loss: 0.1474 - val_accuracy: 0.9473
#
# Epoch 00026: val_loss improved from 0.14768 to 0.14737, saving model to model.h5
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0743 - accuracy: 0.9737 - val_loss: 0.1634 - val_accuracy: 0.9406
#
# Epoch 00027: val_loss did not improve from 0.14737
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0684 - accuracy: 0.9765 - val_loss: 0.1441 - val_accuracy: 0.9453
#
# Epoch 00028: val_loss improved from 0.14737 to 0.14409, saving model to model.h5
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0729 - accuracy: 0.9742 - val_loss: 0.1514 - val_accuracy: 0.9477
#
# Epoch 00029: val_loss did not improve from 0.14409
# Epoch 30/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0631 - accuracy: 0.9802 - val_loss: 0.1209 - val_accuracy: 0.9535
#
# Epoch 00030: val_loss improved from 0.14409 to 0.12094, saving model to model.h5
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0644 - accuracy: 0.9777 - val_loss: 0.1945 - val_accuracy: 0.9320
#
# Epoch 00031: val_loss did not improve from 0.12094
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0586 - accuracy: 0.9814 - val_loss: 0.1487 - val_accuracy: 0.9520
#
# Epoch 00032: val_loss did not improve from 0.12094
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0466 - accuracy: 0.9829 - val_loss: 0.2221 - val_accuracy: 0.9305
#
# Epoch 00033: val_loss did not improve from 0.12094
# Epoch 34/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0556 - accuracy: 0.9800 - val_loss: 0.1852 - val_accuracy: 0.9418
#
# Epoch 00034: val_loss did not improve from 0.12094
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0480 - accuracy: 0.9830 - val_loss: 0.1361 - val_accuracy: 0.9539
#
# Epoch 00035: val_loss did not improve from 0.12094
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0445 - accuracy: 0.9839 - val_loss: 0.1289 - val_accuracy: 0.9547
#
# Epoch 00036: val_loss did not improve from 0.12094
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0448 - accuracy: 0.9844 - val_loss: 0.1303 - val_accuracy: 0.9582
#
# Epoch 00037: val_loss did not improve from 0.12094
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0448 - accuracy: 0.9861 - val_loss: 0.1054 - val_accuracy: 0.9656
#
# Epoch 00038: val_loss improved from 0.12094 to 0.10538, saving model to model.h5
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0366 - accuracy: 0.9882 - val_loss: 0.1047 - val_accuracy: 0.9648
#
# Epoch 00039: val_loss improved from 0.10538 to 0.10467, saving model to model.h5
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0402 - accuracy: 0.9869 - val_loss: 0.1178 - val_accuracy: 0.9621
#
# Epoch 00040: val_loss did not improve from 0.10467
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0393 - accuracy: 0.9882 - val_loss: 0.1472 - val_accuracy: 0.9527
#
# Epoch 00041: val_loss did not improve from 0.10467
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0382 - accuracy: 0.9867 - val_loss: 0.1350 - val_accuracy: 0.9559
#
# Epoch 00042: val_loss did not improve from 0.10467
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0354 - accuracy: 0.9886 - val_loss: 0.0689 - val_accuracy: 0.9754
#
# Epoch 00043: val_loss improved from 0.10467 to 0.06894, saving model to model.h5
# Epoch 44/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 0.1378 - val_accuracy: 0.9582
#
# Epoch 00044: val_loss did not improve from 0.06894
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0351 - accuracy: 0.9887 - val_loss: 0.0892 - val_accuracy: 0.9707
#
# Epoch 00045: val_loss did not improve from 0.06894
# Epoch 46/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0368 - accuracy: 0.9881 - val_loss: 0.1076 - val_accuracy: 0.9621
#
# Epoch 00046: val_loss did not improve from 0.06894
# Epoch 47/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0309 - accuracy: 0.9899 - val_loss: 0.0932 - val_accuracy: 0.9664
#
# Epoch 00047: val_loss did not improve from 0.06894
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0352 - accuracy: 0.9891 - val_loss: 0.1506 - val_accuracy: 0.9539
#
# Epoch 00048: val_loss did not improve from 0.06894
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0344 - accuracy: 0.9895 - val_loss: 0.1198 - val_accuracy: 0.9621
#
# Epoch 00049: val_loss did not improve from 0.06894
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0341 - accuracy: 0.9888 - val_loss: 0.0999 - val_accuracy: 0.9637
#
# Epoch 00050: val_loss did not improve from 0.06894
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0349 - accuracy: 0.9890 - val_loss: 0.1549 - val_accuracy: 0.9539
#
# Epoch 00051: val_loss did not improve from 0.06894
# Epoch 52/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.1401 - val_accuracy: 0.9520
#
# Epoch 00052: val_loss did not improve from 0.06894
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0271 - accuracy: 0.9910 - val_loss: 0.1437 - val_accuracy: 0.9520
#
# Epoch 00053: val_loss did not improve from 0.06894
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0287 - accuracy: 0.9907 - val_loss: 0.0886 - val_accuracy: 0.9688
#
# Epoch 00054: val_loss did not improve from 0.06894
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0251 - accuracy: 0.9903 - val_loss: 0.1326 - val_accuracy: 0.9594
#
# Epoch 00055: val_loss did not improve from 0.06894
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0243 - accuracy: 0.9918 - val_loss: 0.0993 - val_accuracy: 0.9664
#
# Epoch 00056: val_loss did not improve from 0.06894
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0265 - accuracy: 0.9920 - val_loss: 0.0943 - val_accuracy: 0.9695
#
# Epoch 00057: val_loss did not improve from 0.06894
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0263 - accuracy: 0.9911 - val_loss: 0.1181 - val_accuracy: 0.9625
#
# Epoch 00058: val_loss did not improve from 0.06894
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0258 - accuracy: 0.9910 - val_loss: 0.0958 - val_accuracy: 0.9715
#
# Epoch 00059: val_loss did not improve from 0.06894
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0260 - accuracy: 0.9917 - val_loss: 0.0749 - val_accuracy: 0.9711
#
# Epoch 00060: val_loss did not improve from 0.06894
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0199 - accuracy: 0.9943 - val_loss: 0.0831 - val_accuracy: 0.9746
#
# Epoch 00061: val_loss did not improve from 0.06894
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 0.0636 - val_accuracy: 0.9816
#
# Epoch 00062: val_loss improved from 0.06894 to 0.06359, saving model to model.h5
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0238 - accuracy: 0.9919 - val_loss: 0.1136 - val_accuracy: 0.9660
#
# Epoch 00063: val_loss did not improve from 0.06359
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0187 - accuracy: 0.9945 - val_loss: 0.0499 - val_accuracy: 0.9840
#
# Epoch 00064: val_loss improved from 0.06359 to 0.04986, saving model to model.h5
# Epoch 65/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0256 - accuracy: 0.9913 - val_loss: 0.0621 - val_accuracy: 0.9793
#
# Epoch 00065: val_loss did not improve from 0.04986
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9929 - val_loss: 0.1039 - val_accuracy: 0.9637
#
# Epoch 00066: val_loss did not improve from 0.04986
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9913 - val_loss: 0.1332 - val_accuracy: 0.9598
#
# Epoch 00067: val_loss did not improve from 0.04986
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0218 - accuracy: 0.9934 - val_loss: 0.0734 - val_accuracy: 0.9758
#
# Epoch 00068: val_loss did not improve from 0.04986
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0226 - accuracy: 0.9937 - val_loss: 0.1112 - val_accuracy: 0.9609
#
# Epoch 00069: val_loss did not improve from 0.04986
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0208 - accuracy: 0.9927 - val_loss: 0.0598 - val_accuracy: 0.9809
#
# Epoch 00070: val_loss did not improve from 0.04986
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.0693 - val_accuracy: 0.9754
#
# Epoch 00071: val_loss did not improve from 0.04986
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.0589 - val_accuracy: 0.9797
#
# Epoch 00072: val_loss did not improve from 0.04986
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0212 - accuracy: 0.9937 - val_loss: 0.0531 - val_accuracy: 0.9801
#
# Epoch 00073: val_loss did not improve from 0.04986
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.0589 - val_accuracy: 0.9801
#
# Epoch 00074: val_loss did not improve from 0.04986
# Epoch 75/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0686 - val_accuracy: 0.9777
#
# Epoch 00075: val_loss did not improve from 0.04986
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0180 - accuracy: 0.9939 - val_loss: 0.0659 - val_accuracy: 0.9766
#
# Epoch 00076: val_loss did not improve from 0.04986
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 0.0458 - val_accuracy: 0.9840
#
# Epoch 00077: val_loss improved from 0.04986 to 0.04577, saving model to model.h5
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0195 - accuracy: 0.9948 - val_loss: 0.0596 - val_accuracy: 0.9781
#
# Epoch 00078: val_loss did not improve from 0.04577
# Epoch 79/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.0540 - val_accuracy: 0.9781
#
# Epoch 00079: val_loss did not improve from 0.04577
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 0.0649 - val_accuracy: 0.9789
#
# Epoch 00080: val_loss did not improve from 0.04577
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0674 - val_accuracy: 0.9762
#
# Epoch 00081: val_loss did not improve from 0.04577
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0621 - val_accuracy: 0.9793
#
# Epoch 00082: val_loss did not improve from 0.04577
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.0593 - val_accuracy: 0.9793
#
# Epoch 00083: val_loss did not improve from 0.04577
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0556 - val_accuracy: 0.9797
#
# Epoch 00084: val_loss did not improve from 0.04577
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0546 - val_accuracy: 0.9805
#
# Epoch 00085: val_loss did not improve from 0.04577
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.0741 - val_accuracy: 0.9730
#
# Epoch 00086: val_loss did not improve from 0.04577
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 0.0817 - val_accuracy: 0.9723
#
# Epoch 00087: val_loss did not improve from 0.04577
# Epoch 88/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0164 - accuracy: 0.9957 - val_loss: 0.0473 - val_accuracy: 0.9848
#
# Epoch 00088: val_loss did not improve from 0.04577
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0393 - val_accuracy: 0.9867
#
# Epoch 00089: val_loss improved from 0.04577 to 0.03932, saving model to model.h5
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.0472 - val_accuracy: 0.9820
#
# Epoch 00090: val_loss did not improve from 0.03932
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0156 - accuracy: 0.9943 - val_loss: 0.0462 - val_accuracy: 0.9828
#
# Epoch 00091: val_loss did not improve from 0.03932
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.0359 - val_accuracy: 0.9879
#
# Epoch 00092: val_loss improved from 0.03932 to 0.03589, saving model to model.h5
# Epoch 93/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.0767 - val_accuracy: 0.9758
#
# Epoch 00093: val_loss did not improve from 0.03589
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9948 - val_loss: 0.0332 - val_accuracy: 0.9879
#
# Epoch 00094: val_loss improved from 0.03589 to 0.03324, saving model to model.h5
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.0325 - val_accuracy: 0.9891
#
# Epoch 00095: val_loss improved from 0.03324 to 0.03253, saving model to model.h5
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0490 - val_accuracy: 0.9824
#
# Epoch 00096: val_loss did not improve from 0.03253
# Epoch 97/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0648 - val_accuracy: 0.9770
#
# Epoch 00097: val_loss did not improve from 0.03253
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.0491 - val_accuracy: 0.9812
#
# Epoch 00098: val_loss did not improve from 0.03253
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0109 - accuracy: 0.9957 - val_loss: 0.0662 - val_accuracy: 0.9773
#
# Epoch 00099: val_loss did not improve from 0.03253
# Epoch 100/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0134 - accuracy: 0.9951 - val_loss: 0.0391 - val_accuracy: 0.9863
#
# Epoch 00100: val_loss did not improve from 0.03253
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9863
# Val Score:  [0.0390591137111187, 0.986328125]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.6688 - accuracy: 0.7763 - val_loss: 2.5901 - val_accuracy: 0.4004
#
# Epoch 00001: val_loss did not improve from 0.03253
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3873 - accuracy: 0.8626 - val_loss: 1.3319 - val_accuracy: 0.6715
#
# Epoch 00002: val_loss did not improve from 0.03253
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3187 - accuracy: 0.8855 - val_loss: 0.6523 - val_accuracy: 0.7883
#
# Epoch 00003: val_loss did not improve from 0.03253
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.2807 - accuracy: 0.8958 - val_loss: 0.8618 - val_accuracy: 0.7398
#
# Epoch 00004: val_loss did not improve from 0.03253
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2406 - accuracy: 0.9138 - val_loss: 0.9076 - val_accuracy: 0.7465
#
# Epoch 00005: val_loss did not improve from 0.03253
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2213 - accuracy: 0.9171 - val_loss: 0.9760 - val_accuracy: 0.7336
#
# Epoch 00006: val_loss did not improve from 0.03253
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2015 - accuracy: 0.9287 - val_loss: 1.0075 - val_accuracy: 0.7277
#
# Epoch 00007: val_loss did not improve from 0.03253
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1786 - accuracy: 0.9307 - val_loss: 1.1133 - val_accuracy: 0.7129
#
# Epoch 00008: val_loss did not improve from 0.03253
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1745 - accuracy: 0.9362 - val_loss: 1.0555 - val_accuracy: 0.7281
#
# Epoch 00009: val_loss did not improve from 0.03253
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1533 - accuracy: 0.9437 - val_loss: 1.0640 - val_accuracy: 0.7297
#
# Epoch 00010: val_loss did not improve from 0.03253
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1363 - accuracy: 0.9511 - val_loss: 1.1082 - val_accuracy: 0.7109
#
# Epoch 00011: val_loss did not improve from 0.03253
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1235 - accuracy: 0.9541 - val_loss: 1.0858 - val_accuracy: 0.7102
#
# Epoch 00012: val_loss did not improve from 0.03253
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1226 - accuracy: 0.9546 - val_loss: 1.1970 - val_accuracy: 0.7059
#
# Epoch 00013: val_loss did not improve from 0.03253
# Epoch 14/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1164 - accuracy: 0.9582 - val_loss: 0.8651 - val_accuracy: 0.7613
#
# Epoch 00014: val_loss did not improve from 0.03253
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1091 - accuracy: 0.9610 - val_loss: 1.1915 - val_accuracy: 0.7199
#
# Epoch 00015: val_loss did not improve from 0.03253
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1024 - accuracy: 0.9603 - val_loss: 0.9023 - val_accuracy: 0.7453
#
# Epoch 00016: val_loss did not improve from 0.03253
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0888 - accuracy: 0.9680 - val_loss: 0.8267 - val_accuracy: 0.7742
#
# Epoch 00017: val_loss did not improve from 0.03253
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0892 - accuracy: 0.9678 - val_loss: 1.1408 - val_accuracy: 0.7352
#
# Epoch 00018: val_loss did not improve from 0.03253
# Epoch 19/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0862 - accuracy: 0.9687 - val_loss: 0.8877 - val_accuracy: 0.7574
#
# Epoch 00019: val_loss did not improve from 0.03253
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0719 - accuracy: 0.9729 - val_loss: 0.9217 - val_accuracy: 0.7695
#
# Epoch 00020: val_loss did not improve from 0.03253
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0701 - accuracy: 0.9764 - val_loss: 0.8421 - val_accuracy: 0.7805
#
# Epoch 00021: val_loss did not improve from 0.03253
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0710 - accuracy: 0.9746 - val_loss: 0.8725 - val_accuracy: 0.7828
#
# Epoch 00022: val_loss did not improve from 0.03253
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0715 - accuracy: 0.9732 - val_loss: 0.7602 - val_accuracy: 0.8086
#
# Epoch 00023: val_loss did not improve from 0.03253
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0688 - accuracy: 0.9754 - val_loss: 0.9322 - val_accuracy: 0.7785
#
# Epoch 00024: val_loss did not improve from 0.03253
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0647 - accuracy: 0.9784 - val_loss: 1.1091 - val_accuracy: 0.7281
#
# Epoch 00025: val_loss did not improve from 0.03253
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0585 - accuracy: 0.9812 - val_loss: 0.7298 - val_accuracy: 0.8152
#
# Epoch 00026: val_loss did not improve from 0.03253
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0571 - accuracy: 0.9799 - val_loss: 0.7548 - val_accuracy: 0.8031
#
# Epoch 00027: val_loss did not improve from 0.03253
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0518 - accuracy: 0.9825 - val_loss: 0.6727 - val_accuracy: 0.8293
#
# Epoch 00028: val_loss did not improve from 0.03253
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0504 - accuracy: 0.9818 - val_loss: 0.7537 - val_accuracy: 0.8133
#
# Epoch 00029: val_loss did not improve from 0.03253
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0512 - accuracy: 0.9822 - val_loss: 0.5152 - val_accuracy: 0.8617
#
# Epoch 00030: val_loss did not improve from 0.03253
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0484 - accuracy: 0.9842 - val_loss: 0.5140 - val_accuracy: 0.8523
#
# Epoch 00031: val_loss did not improve from 0.03253
# Epoch 32/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0487 - accuracy: 0.9823 - val_loss: 0.6876 - val_accuracy: 0.8184
#
# Epoch 00032: val_loss did not improve from 0.03253
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0478 - accuracy: 0.9822 - val_loss: 0.4805 - val_accuracy: 0.8570
#
# Epoch 00033: val_loss did not improve from 0.03253
# Epoch 34/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0405 - accuracy: 0.9865 - val_loss: 0.6731 - val_accuracy: 0.8313
#
# Epoch 00034: val_loss did not improve from 0.03253
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0427 - accuracy: 0.9859 - val_loss: 0.7240 - val_accuracy: 0.8227
#
# Epoch 00035: val_loss did not improve from 0.03253
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0358 - accuracy: 0.9876 - val_loss: 0.6223 - val_accuracy: 0.8430
#
# Epoch 00036: val_loss did not improve from 0.03253
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0386 - accuracy: 0.9860 - val_loss: 0.3771 - val_accuracy: 0.8879
#
# Epoch 00037: val_loss did not improve from 0.03253
# Epoch 38/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0431 - accuracy: 0.9852 - val_loss: 0.4247 - val_accuracy: 0.8742
#
# Epoch 00038: val_loss did not improve from 0.03253
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0373 - accuracy: 0.9874 - val_loss: 0.2840 - val_accuracy: 0.9129
#
# Epoch 00039: val_loss did not improve from 0.03253
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 0.4439 - val_accuracy: 0.8867
#
# Epoch 00040: val_loss did not improve from 0.03253
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0364 - accuracy: 0.9873 - val_loss: 0.4767 - val_accuracy: 0.8652
#
# Epoch 00041: val_loss did not improve from 0.03253
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0334 - accuracy: 0.9881 - val_loss: 0.3315 - val_accuracy: 0.8977
#
# Epoch 00042: val_loss did not improve from 0.03253
# Epoch 43/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0304 - accuracy: 0.9890 - val_loss: 0.3486 - val_accuracy: 0.8980
#
# Epoch 00043: val_loss did not improve from 0.03253
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0382 - accuracy: 0.9866 - val_loss: 0.4140 - val_accuracy: 0.8773
#
# Epoch 00044: val_loss did not improve from 0.03253
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0266 - accuracy: 0.9911 - val_loss: 0.3344 - val_accuracy: 0.9074
#
# Epoch 00045: val_loss did not improve from 0.03253
# Epoch 46/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0295 - accuracy: 0.9901 - val_loss: 0.3160 - val_accuracy: 0.9035
#
# Epoch 00046: val_loss did not improve from 0.03253
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0291 - accuracy: 0.9898 - val_loss: 0.3747 - val_accuracy: 0.8988
#
# Epoch 00047: val_loss did not improve from 0.03253
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0302 - accuracy: 0.9905 - val_loss: 0.2950 - val_accuracy: 0.9055
#
# Epoch 00048: val_loss did not improve from 0.03253
# Epoch 49/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0280 - accuracy: 0.9904 - val_loss: 0.2178 - val_accuracy: 0.9266
#
# Epoch 00049: val_loss did not improve from 0.03253
# Epoch 50/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0288 - accuracy: 0.9899 - val_loss: 0.2662 - val_accuracy: 0.9117
#
# Epoch 00050: val_loss did not improve from 0.03253
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.2892 - val_accuracy: 0.9145
#
# Epoch 00051: val_loss did not improve from 0.03253
# Epoch 52/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0288 - accuracy: 0.9904 - val_loss: 0.4445 - val_accuracy: 0.8797
#
# Epoch 00052: val_loss did not improve from 0.03253
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0258 - accuracy: 0.9913 - val_loss: 0.2227 - val_accuracy: 0.9258
#
# Epoch 00053: val_loss did not improve from 0.03253
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0274 - accuracy: 0.9900 - val_loss: 0.3068 - val_accuracy: 0.9074
#
# Epoch 00054: val_loss did not improve from 0.03253
# Epoch 55/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0239 - accuracy: 0.9919 - val_loss: 0.2097 - val_accuracy: 0.9270
#
# Epoch 00055: val_loss did not improve from 0.03253
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.3135 - val_accuracy: 0.9090
#
# Epoch 00056: val_loss did not improve from 0.03253
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.3060 - val_accuracy: 0.9094
#
# Epoch 00057: val_loss did not improve from 0.03253
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0225 - accuracy: 0.9920 - val_loss: 0.2230 - val_accuracy: 0.9277
#
# Epoch 00058: val_loss did not improve from 0.03253
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0244 - accuracy: 0.9915 - val_loss: 0.1852 - val_accuracy: 0.9402
#
# Epoch 00059: val_loss did not improve from 0.03253
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0193 - accuracy: 0.9931 - val_loss: 0.2244 - val_accuracy: 0.9281
#
# Epoch 00060: val_loss did not improve from 0.03253
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0243 - accuracy: 0.9920 - val_loss: 0.1895 - val_accuracy: 0.9359
#
# Epoch 00061: val_loss did not improve from 0.03253
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0241 - accuracy: 0.9917 - val_loss: 0.1226 - val_accuracy: 0.9586
#
# Epoch 00062: val_loss did not improve from 0.03253
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.2049 - val_accuracy: 0.9359
#
# Epoch 00063: val_loss did not improve from 0.03253
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0241 - accuracy: 0.9928 - val_loss: 0.2216 - val_accuracy: 0.9305
#
# Epoch 00064: val_loss did not improve from 0.03253
# Epoch 65/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.1434 - val_accuracy: 0.9535
#
# Epoch 00065: val_loss did not improve from 0.03253
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0176 - accuracy: 0.9932 - val_loss: 0.1533 - val_accuracy: 0.9504
#
# Epoch 00066: val_loss did not improve from 0.03253
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 0.2335 - val_accuracy: 0.9277
#
# Epoch 00067: val_loss did not improve from 0.03253
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0205 - accuracy: 0.9932 - val_loss: 0.1036 - val_accuracy: 0.9625
#
# Epoch 00068: val_loss did not improve from 0.03253
# Epoch 69/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0221 - accuracy: 0.9922 - val_loss: 0.1632 - val_accuracy: 0.9453
#
# Epoch 00069: val_loss did not improve from 0.03253
# Epoch 70/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.1854 - val_accuracy: 0.9434
#
# Epoch 00070: val_loss did not improve from 0.03253
# Epoch 71/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.2247 - val_accuracy: 0.9336
#
# Epoch 00071: val_loss did not improve from 0.03253
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.2234 - val_accuracy: 0.9316
#
# Epoch 00072: val_loss did not improve from 0.03253
# Epoch 73/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.2720 - val_accuracy: 0.9223
#
# Epoch 00073: val_loss did not improve from 0.03253
# Epoch 74/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0169 - accuracy: 0.9948 - val_loss: 0.2283 - val_accuracy: 0.9328
#
# Epoch 00074: val_loss did not improve from 0.03253
# Epoch 75/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.1406 - val_accuracy: 0.9555
#
# Epoch 00075: val_loss did not improve from 0.03253
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.1595 - val_accuracy: 0.9496
#
# Epoch 00076: val_loss did not improve from 0.03253
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0191 - accuracy: 0.9930 - val_loss: 0.2472 - val_accuracy: 0.9305
#
# Epoch 00077: val_loss did not improve from 0.03253
# Epoch 78/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0151 - accuracy: 0.9953 - val_loss: 0.1990 - val_accuracy: 0.9414
#
# Epoch 00078: val_loss did not improve from 0.03253
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.1409 - val_accuracy: 0.9578
#
# Epoch 00079: val_loss did not improve from 0.03253
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0154 - accuracy: 0.9940 - val_loss: 0.2083 - val_accuracy: 0.9418
#
# Epoch 00080: val_loss did not improve from 0.03253
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.1643 - val_accuracy: 0.9488
#
# Epoch 00081: val_loss did not improve from 0.03253
# Epoch 82/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.1601 - val_accuracy: 0.9539
#
# Epoch 00082: val_loss did not improve from 0.03253
# Epoch 83/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0144 - accuracy: 0.9946 - val_loss: 0.2257 - val_accuracy: 0.9352
#
# Epoch 00083: val_loss did not improve from 0.03253
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 0.1640 - val_accuracy: 0.9465
#
# Epoch 00084: val_loss did not improve from 0.03253
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.0922 - val_accuracy: 0.9711
#
# Epoch 00085: val_loss did not improve from 0.03253
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.1163 - val_accuracy: 0.9652
#
# Epoch 00086: val_loss did not improve from 0.03253
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.1546 - val_accuracy: 0.9516
#
# Epoch 00087: val_loss did not improve from 0.03253
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.1112 - val_accuracy: 0.9652
#
# Epoch 00088: val_loss did not improve from 0.03253
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0151 - accuracy: 0.9945 - val_loss: 0.1339 - val_accuracy: 0.9566
#
# Epoch 00089: val_loss did not improve from 0.03253
# Epoch 90/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0770 - val_accuracy: 0.9734
#
# Epoch 00090: val_loss did not improve from 0.03253
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9951 - val_loss: 0.0978 - val_accuracy: 0.9715
#
# Epoch 00091: val_loss did not improve from 0.03253
# Epoch 92/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0123 - accuracy: 0.9951 - val_loss: 0.1492 - val_accuracy: 0.9559
#
# Epoch 00092: val_loss did not improve from 0.03253
# Epoch 93/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.0680 - val_accuracy: 0.9777
#
# Epoch 00093: val_loss did not improve from 0.03253
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9962 - val_loss: 0.0992 - val_accuracy: 0.9688
#
# Epoch 00094: val_loss did not improve from 0.03253
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0910 - val_accuracy: 0.9703
#
# Epoch 00095: val_loss did not improve from 0.03253
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0667 - val_accuracy: 0.9793
#
# Epoch 00096: val_loss did not improve from 0.03253
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.0514 - val_accuracy: 0.9840
#
# Epoch 00097: val_loss did not improve from 0.03253
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0628 - val_accuracy: 0.9789
#
# Epoch 00098: val_loss did not improve from 0.03253
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.0697 - val_accuracy: 0.9801
#
# Epoch 00099: val_loss did not improve from 0.03253
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0909 - val_accuracy: 0.9711
#
# Epoch 00100: val_loss did not improve from 0.03253
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0909 - accuracy: 0.9711
# Val Score:  [0.09093873202800751, 0.9710937738418579]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.7721 - accuracy: 0.7419 - val_loss: 2.8055 - val_accuracy: 0.4703
#
# Epoch 00001: val_loss did not improve from 0.03253
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.4594 - accuracy: 0.8416 - val_loss: 0.5016 - val_accuracy: 0.8340
#
# Epoch 00002: val_loss did not improve from 0.03253
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.3493 - accuracy: 0.8787 - val_loss: 0.5140 - val_accuracy: 0.8434
#
# Epoch 00003: val_loss did not improve from 0.03253
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.2933 - accuracy: 0.8941 - val_loss: 0.3825 - val_accuracy: 0.8727
#
# Epoch 00004: val_loss did not improve from 0.03253
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2554 - accuracy: 0.9132 - val_loss: 0.4145 - val_accuracy: 0.8676
#
# Epoch 00005: val_loss did not improve from 0.03253
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.2274 - accuracy: 0.9185 - val_loss: 0.3674 - val_accuracy: 0.8754
#
# Epoch 00006: val_loss did not improve from 0.03253
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1963 - accuracy: 0.9259 - val_loss: 0.2997 - val_accuracy: 0.8973
#
# Epoch 00007: val_loss did not improve from 0.03253
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1722 - accuracy: 0.9407 - val_loss: 0.2984 - val_accuracy: 0.8996
#
# Epoch 00008: val_loss did not improve from 0.03253
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1782 - accuracy: 0.9357 - val_loss: 0.3474 - val_accuracy: 0.8859
#
# Epoch 00009: val_loss did not improve from 0.03253
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1469 - accuracy: 0.9446 - val_loss: 0.2672 - val_accuracy: 0.9004
#
# Epoch 00010: val_loss did not improve from 0.03253
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1383 - accuracy: 0.9502 - val_loss: 0.2661 - val_accuracy: 0.9047
#
# Epoch 00011: val_loss did not improve from 0.03253
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1218 - accuracy: 0.9562 - val_loss: 0.2842 - val_accuracy: 0.9043
#
# Epoch 00012: val_loss did not improve from 0.03253
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1144 - accuracy: 0.9614 - val_loss: 0.2605 - val_accuracy: 0.9121
#
# Epoch 00013: val_loss did not improve from 0.03253
# Epoch 14/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1071 - accuracy: 0.9611 - val_loss: 0.2385 - val_accuracy: 0.9215
#
# Epoch 00014: val_loss did not improve from 0.03253
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1014 - accuracy: 0.9646 - val_loss: 0.2773 - val_accuracy: 0.9074
#
# Epoch 00015: val_loss did not improve from 0.03253
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0876 - accuracy: 0.9685 - val_loss: 0.2071 - val_accuracy: 0.9320
#
# Epoch 00016: val_loss did not improve from 0.03253
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0970 - accuracy: 0.9644 - val_loss: 0.1951 - val_accuracy: 0.9371
#
# Epoch 00017: val_loss did not improve from 0.03253
# Epoch 18/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0848 - accuracy: 0.9715 - val_loss: 0.1742 - val_accuracy: 0.9441
#
# Epoch 00018: val_loss did not improve from 0.03253
# Epoch 19/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0736 - accuracy: 0.9752 - val_loss: 0.2288 - val_accuracy: 0.9262
#
# Epoch 00019: val_loss did not improve from 0.03253
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0682 - accuracy: 0.9770 - val_loss: 0.1683 - val_accuracy: 0.9430
#
# Epoch 00020: val_loss did not improve from 0.03253
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0637 - accuracy: 0.9804 - val_loss: 0.1941 - val_accuracy: 0.9375
#
# Epoch 00021: val_loss did not improve from 0.03253
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0682 - accuracy: 0.9778 - val_loss: 0.1878 - val_accuracy: 0.9395
#
# Epoch 00022: val_loss did not improve from 0.03253
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0629 - accuracy: 0.9785 - val_loss: 0.1655 - val_accuracy: 0.9449
#
# Epoch 00023: val_loss did not improve from 0.03253
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0549 - accuracy: 0.9803 - val_loss: 0.1636 - val_accuracy: 0.9469
#
# Epoch 00024: val_loss did not improve from 0.03253
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0552 - accuracy: 0.9807 - val_loss: 0.1460 - val_accuracy: 0.9492
#
# Epoch 00025: val_loss did not improve from 0.03253
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0552 - accuracy: 0.9827 - val_loss: 0.1914 - val_accuracy: 0.9406
#
# Epoch 00026: val_loss did not improve from 0.03253
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0529 - accuracy: 0.9805 - val_loss: 0.1980 - val_accuracy: 0.9371
#
# Epoch 00027: val_loss did not improve from 0.03253
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0519 - accuracy: 0.9826 - val_loss: 0.1313 - val_accuracy: 0.9531
#
# Epoch 00028: val_loss did not improve from 0.03253
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0518 - accuracy: 0.9818 - val_loss: 0.1500 - val_accuracy: 0.9449
#
# Epoch 00029: val_loss did not improve from 0.03253
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0456 - accuracy: 0.9841 - val_loss: 0.1600 - val_accuracy: 0.9441
#
# Epoch 00030: val_loss did not improve from 0.03253
# Epoch 31/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0456 - accuracy: 0.9846 - val_loss: 0.1442 - val_accuracy: 0.9492
#
# Epoch 00031: val_loss did not improve from 0.03253
# Epoch 32/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0387 - accuracy: 0.9868 - val_loss: 0.2029 - val_accuracy: 0.9348
#
# Epoch 00032: val_loss did not improve from 0.03253
# Epoch 33/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0394 - accuracy: 0.9864 - val_loss: 0.1611 - val_accuracy: 0.9453
#
# Epoch 00033: val_loss did not improve from 0.03253
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0378 - accuracy: 0.9881 - val_loss: 0.1405 - val_accuracy: 0.9492
#
# Epoch 00034: val_loss did not improve from 0.03253
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0386 - accuracy: 0.9889 - val_loss: 0.1195 - val_accuracy: 0.9563
#
# Epoch 00035: val_loss did not improve from 0.03253
# Epoch 36/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0428 - accuracy: 0.9870 - val_loss: 0.1357 - val_accuracy: 0.9539
#
# Epoch 00036: val_loss did not improve from 0.03253
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0412 - accuracy: 0.9877 - val_loss: 0.1301 - val_accuracy: 0.9566
#
# Epoch 00037: val_loss did not improve from 0.03253
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0357 - accuracy: 0.9896 - val_loss: 0.1339 - val_accuracy: 0.9563
#
# Epoch 00038: val_loss did not improve from 0.03253
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0346 - accuracy: 0.9899 - val_loss: 0.1038 - val_accuracy: 0.9633
#
# Epoch 00039: val_loss did not improve from 0.03253
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0336 - accuracy: 0.9890 - val_loss: 0.0743 - val_accuracy: 0.9734
#
# ...
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0694 - accuracy: 0.9749 - val_loss: 0.1541 - val_accuracy: 0.9395
#
# Epoch 00021: val_loss did not improve from 0.02630
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0635 - accuracy: 0.9779 - val_loss: 0.1323 - val_accuracy: 0.9520
#
# Epoch 00022: val_loss did not improve from 0.02630
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0610 - accuracy: 0.9788 - val_loss: 0.1714 - val_accuracy: 0.9398
#
# Epoch 00023: val_loss did not improve from 0.02630
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0575 - accuracy: 0.9808 - val_loss: 0.1457 - val_accuracy: 0.9453
#
# Epoch 00024: val_loss did not improve from 0.02630
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0572 - accuracy: 0.9795 - val_loss: 0.1673 - val_accuracy: 0.9383
#
# Epoch 00025: val_loss did not improve from 0.02630
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0603 - accuracy: 0.9800 - val_loss: 0.1856 - val_accuracy: 0.9289
#
# Epoch 00026: val_loss did not improve from 0.02630
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0548 - accuracy: 0.9810 - val_loss: 0.1539 - val_accuracy: 0.9434
#
# Epoch 00027: val_loss did not improve from 0.02630
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0512 - accuracy: 0.9815 - val_loss: 0.1099 - val_accuracy: 0.9566
#
# Epoch 00028: val_loss did not improve from 0.02630
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0500 - accuracy: 0.9821 - val_loss: 0.1563 - val_accuracy: 0.9426
#
# Epoch 00029: val_loss did not improve from 0.02630
# Epoch 30/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0438 - accuracy: 0.9865 - val_loss: 0.1412 - val_accuracy: 0.9500
#
# Epoch 00030: val_loss did not improve from 0.02630
# Epoch 31/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0443 - accuracy: 0.9846 - val_loss: 0.0997 - val_accuracy: 0.9660
#
# Epoch 00031: val_loss did not improve from 0.02630
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0450 - accuracy: 0.9846 - val_loss: 0.0875 - val_accuracy: 0.9695
#
# Epoch 00032: val_loss did not improve from 0.02630
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0453 - accuracy: 0.9871 - val_loss: 0.0903 - val_accuracy: 0.9637
#
# Epoch 00033: val_loss did not improve from 0.02630
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0358 - accuracy: 0.9872 - val_loss: 0.1021 - val_accuracy: 0.9637
#
# Epoch 00034: val_loss did not improve from 0.02630
# Epoch 35/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0404 - accuracy: 0.9870 - val_loss: 0.1000 - val_accuracy: 0.9633
#
# Epoch 00035: val_loss did not improve from 0.02630
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0360 - accuracy: 0.9879 - val_loss: 0.1311 - val_accuracy: 0.9512
#
# Epoch 00036: val_loss did not improve from 0.02630
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0342 - accuracy: 0.9880 - val_loss: 0.1515 - val_accuracy: 0.9477
#
# Epoch 00037: val_loss did not improve from 0.02630
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0360 - accuracy: 0.9877 - val_loss: 0.0958 - val_accuracy: 0.9656
#
# Epoch 00038: val_loss did not improve from 0.02630
# Epoch 39/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0346 - accuracy: 0.9875 - val_loss: 0.0946 - val_accuracy: 0.9668
#
# Epoch 00039: val_loss did not improve from 0.02630
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0388 - accuracy: 0.9881 - val_loss: 0.0801 - val_accuracy: 0.9707
#
# Epoch 00040: val_loss did not improve from 0.02630
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0341 - accuracy: 0.9896 - val_loss: 0.0556 - val_accuracy: 0.9797
#
# Epoch 00041: val_loss did not improve from 0.02630
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0322 - accuracy: 0.9899 - val_loss: 0.0882 - val_accuracy: 0.9668
#
# Epoch 00042: val_loss did not improve from 0.02630
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0291 - accuracy: 0.9898 - val_loss: 0.0676 - val_accuracy: 0.9750
#
# Epoch 00043: val_loss did not improve from 0.02630
# Epoch 44/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 0.0780 - val_accuracy: 0.9723
#
# Epoch 00044: val_loss did not improve from 0.02630
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0312 - accuracy: 0.9904 - val_loss: 0.1012 - val_accuracy: 0.9656
#
# Epoch 00045: val_loss did not improve from 0.02630
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.0735 - val_accuracy: 0.9738
#
# Epoch 00046: val_loss did not improve from 0.02630
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0262 - accuracy: 0.9924 - val_loss: 0.0715 - val_accuracy: 0.9766
#
# Epoch 00047: val_loss did not improve from 0.02630
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0303 - accuracy: 0.9905 - val_loss: 0.0341 - val_accuracy: 0.9875
#
# Epoch 00048: val_loss did not improve from 0.02630
# Epoch 49/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0245 - accuracy: 0.9927 - val_loss: 0.0647 - val_accuracy: 0.9781
#
# Epoch 00049: val_loss did not improve from 0.02630
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 0.0533 - val_accuracy: 0.9820
#
# Epoch 00050: val_loss did not improve from 0.02630
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0241 - accuracy: 0.9927 - val_loss: 0.0432 - val_accuracy: 0.9879
#
# Epoch 00051: val_loss did not improve from 0.02630
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0242 - accuracy: 0.9933 - val_loss: 0.0513 - val_accuracy: 0.9832
#
# Epoch 00052: val_loss did not improve from 0.02630
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0202 - accuracy: 0.9933 - val_loss: 0.0483 - val_accuracy: 0.9844
#
# Epoch 00053: val_loss did not improve from 0.02630
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0225 - accuracy: 0.9921 - val_loss: 0.0417 - val_accuracy: 0.9863
#
# Epoch 00054: val_loss did not improve from 0.02630
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.0523 - val_accuracy: 0.9824
#
# Epoch 00055: val_loss did not improve from 0.02630
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9924 - val_loss: 0.0528 - val_accuracy: 0.9832
#
# Epoch 00056: val_loss did not improve from 0.02630
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0190 - accuracy: 0.9936 - val_loss: 0.0580 - val_accuracy: 0.9801
#
# Epoch 00057: val_loss did not improve from 0.02630
# Epoch 58/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.0597 - val_accuracy: 0.9809
#
# Epoch 00058: val_loss did not improve from 0.02630
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0177 - accuracy: 0.9950 - val_loss: 0.0750 - val_accuracy: 0.9746
#
# Epoch 00059: val_loss did not improve from 0.02630
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.0585 - val_accuracy: 0.9805
#
# Epoch 00060: val_loss did not improve from 0.02630
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0196 - accuracy: 0.9940 - val_loss: 0.0534 - val_accuracy: 0.9840
#
# Epoch 00061: val_loss did not improve from 0.02630
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0212 - accuracy: 0.9929 - val_loss: 0.0526 - val_accuracy: 0.9844
#
# Epoch 00062: val_loss did not improve from 0.02630
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.0420 - val_accuracy: 0.9848
#
# Epoch 00063: val_loss did not improve from 0.02630
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0202 - accuracy: 0.9940 - val_loss: 0.0377 - val_accuracy: 0.9867
#
# Epoch 00064: val_loss did not improve from 0.02630
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0210 - accuracy: 0.9941 - val_loss: 0.0330 - val_accuracy: 0.9891
#
# Epoch 00065: val_loss did not improve from 0.02630
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0174 - accuracy: 0.9953 - val_loss: 0.0428 - val_accuracy: 0.9867
#
# Epoch 00066: val_loss did not improve from 0.02630
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.0286 - val_accuracy: 0.9934
#
# Epoch 00067: val_loss did not improve from 0.02630
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0165 - accuracy: 0.9952 - val_loss: 0.0397 - val_accuracy: 0.9863
#
# Epoch 00068: val_loss did not improve from 0.02630
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9945 - val_loss: 0.0309 - val_accuracy: 0.9895
#
# Epoch 00069: val_loss did not improve from 0.02630
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.0488 - val_accuracy: 0.9844
#
# Epoch 00070: val_loss did not improve from 0.02630
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0283 - val_accuracy: 0.9910
#
# Epoch 00071: val_loss did not improve from 0.02630
# Epoch 72/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0142 - accuracy: 0.9952 - val_loss: 0.0531 - val_accuracy: 0.9840
#
# Epoch 00072: val_loss did not improve from 0.02630
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0165 - accuracy: 0.9947 - val_loss: 0.0436 - val_accuracy: 0.9871
#
# Epoch 00073: val_loss did not improve from 0.02630
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0169 - accuracy: 0.9953 - val_loss: 0.0300 - val_accuracy: 0.9918
#
# Epoch 00074: val_loss did not improve from 0.02630
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0426 - val_accuracy: 0.9879
#
# Epoch 00075: val_loss did not improve from 0.02630
# Epoch 76/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.0321 - val_accuracy: 0.9902
#
# Epoch 00076: val_loss did not improve from 0.02630
# Epoch 77/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.0421 - val_accuracy: 0.9871
#
# Epoch 00077: val_loss did not improve from 0.02630
# Epoch 78/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0404 - val_accuracy: 0.9891
#
# Epoch 00078: val_loss did not improve from 0.02630
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.0362 - val_accuracy: 0.9891
#
# Epoch 00079: val_loss did not improve from 0.02630
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.0350 - val_accuracy: 0.9891
#
# Epoch 00080: val_loss did not improve from 0.02630
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.0364 - val_accuracy: 0.9879
#
# Epoch 00081: val_loss did not improve from 0.02630
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0190 - val_accuracy: 0.9934
#
# Epoch 00082: val_loss improved from 0.02630 to 0.01896, saving model to model.h5
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0503 - val_accuracy: 0.9832
#
# Epoch 00083: val_loss did not improve from 0.01896
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.0305 - val_accuracy: 0.9910
#
# Epoch 00084: val_loss did not improve from 0.01896
# Epoch 85/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0254 - val_accuracy: 0.9930
#
# Epoch 00085: val_loss did not improve from 0.01896
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.0304 - val_accuracy: 0.9895
#
# Epoch 00086: val_loss did not improve from 0.01896
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.0509 - val_accuracy: 0.9840
#
# Epoch 00087: val_loss did not improve from 0.01896
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0307 - val_accuracy: 0.9906
#
# Epoch 00088: val_loss did not improve from 0.01896
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0127 - accuracy: 0.9955 - val_loss: 0.0309 - val_accuracy: 0.9883
#
# Epoch 00089: val_loss did not improve from 0.01896
# Epoch 90/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.0443 - val_accuracy: 0.9852
#
# Epoch 00090: val_loss did not improve from 0.01896
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0366 - val_accuracy: 0.9867
#
# Epoch 00091: val_loss did not improve from 0.01896
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0135 - accuracy: 0.9951 - val_loss: 0.0368 - val_accuracy: 0.9879
#
# Epoch 00092: val_loss did not improve from 0.01896
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.0228 - val_accuracy: 0.9918
#
# Epoch 00093: val_loss did not improve from 0.01896
# Epoch 94/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0331 - val_accuracy: 0.9891
#
# Epoch 00094: val_loss did not improve from 0.01896
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0242 - val_accuracy: 0.9918
#
# Epoch 00095: val_loss did not improve from 0.01896
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0277 - val_accuracy: 0.9906
#
# Epoch 00096: val_loss did not improve from 0.01896
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.0271 - val_accuracy: 0.9914
#
# Epoch 00097: val_loss did not improve from 0.01896
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.0170 - val_accuracy: 0.9945
#
# Epoch 00098: val_loss improved from 0.01896 to 0.01698, saving model to model.h5
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.0164 - val_accuracy: 0.9945
#
# Epoch 00099: val_loss improved from 0.01698 to 0.01640, saving model to model.h5
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.0177 - val_accuracy: 0.9941
#
# Epoch 00100: val_loss did not improve from 0.01640
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 0.9941
# Val Score:  [0.01774848997592926, 0.994140625]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      0.99      0.99       859
#            Brown spot       0.99      0.99      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       0.99      1.00      0.99       737
#
#              accuracy                           0.99      3200
#             macro avg       0.99      0.99      0.99      3200
#          weighted avg       0.99      0.99      0.99      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 0.9944
# Test Accuracy: 99.43749904632568

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
