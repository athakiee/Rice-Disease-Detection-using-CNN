# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **HIDDEN LAYER TEST -- USING ONLY 3 HIDDEN LAYER**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
#model.add(Conv2D(128, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 2022-07-21 00:53:53.680158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:53.818190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:53.819150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:53.820803: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-21 00:53:53.821119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:53.821936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:53.822640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:56.482185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:56.483083: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:56.483852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-21 00:53:56.485242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              6554624
# _________________________________________________________________
# activation_3 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_4 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 6,586,852
# Trainable params: 6,584,580
# Non-trainable params: 2,272
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# 2022-07-21 00:53:59.721179: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-07-21 00:54:01.504432: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 320/320 [==============================] - 11s 8ms/step - loss: 0.3888 - accuracy: 0.8701 - val_loss: 13.0375 - val_accuracy: 0.4746
#
# Epoch 00001: val_loss improved from inf to 13.03751, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1813 - accuracy: 0.9311 - val_loss: 0.8068 - val_accuracy: 0.7820
#
# Epoch 00002: val_loss improved from 13.03751 to 0.80679, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1147 - accuracy: 0.9599 - val_loss: 0.1177 - val_accuracy: 0.9613
#
# Epoch 00003: val_loss improved from 0.80679 to 0.11767, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0824 - accuracy: 0.9711 - val_loss: 1.4924 - val_accuracy: 0.6859
#
# Epoch 00004: val_loss did not improve from 0.11767
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0817 - accuracy: 0.9729 - val_loss: 1.6836 - val_accuracy: 0.7387
#
# Epoch 00005: val_loss did not improve from 0.11767
# Epoch 6/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0731 - accuracy: 0.9784 - val_loss: 0.2034 - val_accuracy: 0.9316
#
# Epoch 00006: val_loss did not improve from 0.11767
# Epoch 7/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0485 - accuracy: 0.9837 - val_loss: 0.0654 - val_accuracy: 0.9746
#
# Epoch 00007: val_loss improved from 0.11767 to 0.06541, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0549 - accuracy: 0.9812 - val_loss: 0.0108 - val_accuracy: 0.9973
#
# Epoch 00008: val_loss improved from 0.06541 to 0.01085, saving model to model.h5
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0500 - accuracy: 0.9823 - val_loss: 0.0229 - val_accuracy: 0.9934
#
# Epoch 00009: val_loss did not improve from 0.01085
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0535 - accuracy: 0.9833 - val_loss: 0.6359 - val_accuracy: 0.8070
#
# Epoch 00010: val_loss did not improve from 0.01085
# Epoch 11/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0463 - accuracy: 0.9859 - val_loss: 0.0464 - val_accuracy: 0.9844
#
# Epoch 00011: val_loss did not improve from 0.01085
# Epoch 12/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0376 - accuracy: 0.9884 - val_loss: 0.0278 - val_accuracy: 0.9922
#
# Epoch 00012: val_loss did not improve from 0.01085
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0394 - accuracy: 0.9885 - val_loss: 0.0571 - val_accuracy: 0.9820
#
# Epoch 00013: val_loss did not improve from 0.01085
# Epoch 14/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0307 - accuracy: 0.9909 - val_loss: 0.0407 - val_accuracy: 0.9840
#
# Epoch 00014: val_loss did not improve from 0.01085
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.6921 - val_accuracy: 0.8617
#
# Epoch 00015: val_loss did not improve from 0.01085
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0401 - accuracy: 0.9889 - val_loss: 0.0420 - val_accuracy: 0.9863
#
# Epoch 00016: val_loss did not improve from 0.01085
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0472 - accuracy: 0.9855 - val_loss: 0.0280 - val_accuracy: 0.9949
#
# Epoch 00017: val_loss did not improve from 0.01085
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0347 - accuracy: 0.9911 - val_loss: 0.0210 - val_accuracy: 0.9957
#
# Epoch 00018: val_loss did not improve from 0.01085
# Epoch 19/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0264 - accuracy: 0.9922 - val_loss: 0.0397 - val_accuracy: 0.9879
#
# Epoch 00019: val_loss did not improve from 0.01085
# Epoch 20/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0289 - accuracy: 0.9910 - val_loss: 0.0258 - val_accuracy: 0.9941
#
# Epoch 00020: val_loss did not improve from 0.01085
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.0438 - val_accuracy: 0.9867
#
# Epoch 00021: val_loss did not improve from 0.01085
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.0143 - val_accuracy: 0.9953
#
# Epoch 00022: val_loss did not improve from 0.01085
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0492 - val_accuracy: 0.9809
#
# Epoch 00023: val_loss did not improve from 0.01085
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0257 - accuracy: 0.9919 - val_loss: 0.6693 - val_accuracy: 0.8695
#
# Epoch 00024: val_loss did not improve from 0.01085
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0325 - accuracy: 0.9900 - val_loss: 0.9880 - val_accuracy: 0.8469
#
# Epoch 00025: val_loss did not improve from 0.01085
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0224 - accuracy: 0.9937 - val_loss: 0.0057 - val_accuracy: 0.9973
#
# Epoch 00026: val_loss improved from 0.01085 to 0.00571, saving model to model.h5
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0177 - accuracy: 0.9941 - val_loss: 0.0235 - val_accuracy: 0.9914
#
# Epoch 00027: val_loss did not improve from 0.00571
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.0293 - val_accuracy: 0.9906
#
# Epoch 00028: val_loss did not improve from 0.00571
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0222 - accuracy: 0.9934 - val_loss: 0.0303 - val_accuracy: 0.9930
#
# Epoch 00029: val_loss did not improve from 0.00571
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0309 - accuracy: 0.9909 - val_loss: 0.0241 - val_accuracy: 0.9922
#
# Epoch 00030: val_loss did not improve from 0.00571
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0197 - accuracy: 0.9936 - val_loss: 0.1335 - val_accuracy: 0.9586
#
# Epoch 00031: val_loss did not improve from 0.00571
# Epoch 32/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.0154 - val_accuracy: 0.9965
#
# Epoch 00032: val_loss did not improve from 0.00571
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 0.6715 - val_accuracy: 0.8516
#
# Epoch 00033: val_loss did not improve from 0.00571
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0321 - accuracy: 0.9918 - val_loss: 0.0550 - val_accuracy: 0.9891
#
# Epoch 00034: val_loss did not improve from 0.00571
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0149 - accuracy: 0.9949 - val_loss: 0.0114 - val_accuracy: 0.9969
#
# Epoch 00035: val_loss did not improve from 0.00571
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0199 - val_accuracy: 0.9949
#
# Epoch 00036: val_loss did not improve from 0.00571
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9967 - val_loss: 0.0157 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss did not improve from 0.00571
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0209 - accuracy: 0.9940 - val_loss: 0.0053 - val_accuracy: 0.9980
#
# Epoch 00038: val_loss improved from 0.00571 to 0.00526, saving model to model.h5
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0172 - accuracy: 0.9949 - val_loss: 0.0169 - val_accuracy: 0.9941
#
# Epoch 00039: val_loss did not improve from 0.00526
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0198 - accuracy: 0.9944 - val_loss: 0.2346 - val_accuracy: 0.9422
#
# Epoch 00040: val_loss did not improve from 0.00526
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0190 - accuracy: 0.9939 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00041: val_loss did not improve from 0.00526
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0207 - val_accuracy: 0.9957
#
# Epoch 00042: val_loss did not improve from 0.00526
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.5977 - val_accuracy: 0.8707
#
# Epoch 00043: val_loss did not improve from 0.00526
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0222 - val_accuracy: 0.9949
#
# Epoch 00044: val_loss did not improve from 0.00526
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0179 - accuracy: 0.9939 - val_loss: 0.0195 - val_accuracy: 0.9918
#
# Epoch 00045: val_loss did not improve from 0.00526
# Epoch 46/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0182 - accuracy: 0.9945 - val_loss: 0.0145 - val_accuracy: 0.9969
#
# Epoch 00046: val_loss did not improve from 0.00526
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 2.5242 - val_accuracy: 0.7863
#
# Epoch 00047: val_loss did not improve from 0.00526
# Epoch 48/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0322 - val_accuracy: 0.9934
#
# Epoch 00048: val_loss did not improve from 0.00526
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.0090 - val_accuracy: 0.9973
#
# Epoch 00049: val_loss did not improve from 0.00526
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.0070 - val_accuracy: 0.9977
#
# Epoch 00050: val_loss did not improve from 0.00526
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0158 - accuracy: 0.9949 - val_loss: 0.0080 - val_accuracy: 0.9980
#
# Epoch 00051: val_loss did not improve from 0.00526
# Epoch 52/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.0055 - val_accuracy: 0.9980
#
# Epoch 00052: val_loss did not improve from 0.00526
# Epoch 53/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0055 - val_accuracy: 0.9977
#
# Epoch 00053: val_loss did not improve from 0.00526
# Epoch 54/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0088 - accuracy: 0.9963 - val_loss: 0.0087 - val_accuracy: 0.9973
#
# Epoch 00054: val_loss did not improve from 0.00526
# Epoch 55/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.0083 - val_accuracy: 0.9980
#
# Epoch 00055: val_loss did not improve from 0.00526
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0166 - accuracy: 0.9954 - val_loss: 2.7127 - val_accuracy: 0.7852
#
# Epoch 00056: val_loss did not improve from 0.00526
# Epoch 57/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0131 - accuracy: 0.9966 - val_loss: 0.0139 - val_accuracy: 0.9965
#
# Epoch 00057: val_loss did not improve from 0.00526
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.7840 - val_accuracy: 0.8289
#
# Epoch 00058: val_loss did not improve from 0.00526
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.0093 - val_accuracy: 0.9980
#
# Epoch 00059: val_loss did not improve from 0.00526
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.0078 - val_accuracy: 0.9980
#
# Epoch 00060: val_loss did not improve from 0.00526
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0049 - val_accuracy: 0.9980
#
# Epoch 00061: val_loss improved from 0.00526 to 0.00490, saving model to model.h5
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.0078 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00490
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00063: val_loss improved from 0.00490 to 0.00433, saving model to model.h5
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.0420 - val_accuracy: 0.9852
#
# Epoch 00064: val_loss did not improve from 0.00433
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.0066 - val_accuracy: 0.9965
#
# Epoch 00065: val_loss did not improve from 0.00433
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0087 - val_accuracy: 0.9973
#
# Epoch 00066: val_loss did not improve from 0.00433
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0143 - val_accuracy: 0.9953
#
# Epoch 00067: val_loss did not improve from 0.00433
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 0.0128 - val_accuracy: 0.9961
#
# Epoch 00068: val_loss did not improve from 0.00433
# Epoch 69/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.0094 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00433
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00070: val_loss did not improve from 0.00433
# Epoch 71/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0088 - val_accuracy: 0.9969
#
# Epoch 00071: val_loss did not improve from 0.00433
# Epoch 72/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0086 - val_accuracy: 0.9973
#
# Epoch 00072: val_loss did not improve from 0.00433
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.0079 - val_accuracy: 0.9965
#
# Epoch 00073: val_loss did not improve from 0.00433
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0127 - val_accuracy: 0.9953
#
# Epoch 00074: val_loss did not improve from 0.00433
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0121 - val_accuracy: 0.9977
#
# Epoch 00075: val_loss did not improve from 0.00433
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0583 - val_accuracy: 0.9809
#
# Epoch 00076: val_loss did not improve from 0.00433
# Epoch 77/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0056 - val_accuracy: 0.9977
#
# Epoch 00077: val_loss did not improve from 0.00433
# Epoch 78/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.0104 - val_accuracy: 0.9973
#
# Epoch 00078: val_loss did not improve from 0.00433
# Epoch 79/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00433
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.0236 - val_accuracy: 0.9945
#
# Epoch 00080: val_loss did not improve from 0.00433
# Epoch 81/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9963 - val_loss: 0.0100 - val_accuracy: 0.9973
#
# Epoch 00081: val_loss did not improve from 0.00433
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 0.0047 - val_accuracy: 0.9984
#
# Epoch 00082: val_loss did not improve from 0.00433
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00083: val_loss did not improve from 0.00433
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.0083 - val_accuracy: 0.9973
#
# Epoch 00084: val_loss did not improve from 0.00433
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 0.0089 - val_accuracy: 0.9977
#
# Epoch 00085: val_loss did not improve from 0.00433
# Epoch 86/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0078 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00433
# Epoch 87/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 0.0115 - val_accuracy: 0.9977
#
# Epoch 00087: val_loss did not improve from 0.00433
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.0091 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00433
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9959 - val_loss: 0.0232 - val_accuracy: 0.9926
#
# Epoch 00089: val_loss did not improve from 0.00433
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0152 - val_accuracy: 0.9945
#
# Epoch 00090: val_loss did not improve from 0.00433
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0203 - val_accuracy: 0.9973
#
# Epoch 00091: val_loss did not improve from 0.00433
# Epoch 92/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.0110 - val_accuracy: 0.9969
#
# Epoch 00092: val_loss did not improve from 0.00433
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0127 - accuracy: 0.9964 - val_loss: 0.0152 - val_accuracy: 0.9965
#
# Epoch 00093: val_loss did not improve from 0.00433
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.6694 - val_accuracy: 0.9156
#
# Epoch 00094: val_loss did not improve from 0.00433
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0151 - val_accuracy: 0.9961
#
# Epoch 00095: val_loss did not improve from 0.00433
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.1359 - val_accuracy: 0.9688
#
# Epoch 00096: val_loss did not improve from 0.00433
# Epoch 97/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00433
# Epoch 98/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00098: val_loss did not improve from 0.00433
# Epoch 99/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.0137 - val_accuracy: 0.9965
#
# Epoch 00099: val_loss did not improve from 0.00433
# Epoch 100/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.0297 - val_accuracy: 0.9902
#
# Epoch 00100: val_loss did not improve from 0.00433
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 0.9902
# Val Score:  [0.029679421335458755, 0.990234375]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 3s 7ms/step - loss: 0.4232 - accuracy: 0.8585 - val_loss: 2.7516 - val_accuracy: 0.5633
#
# Epoch 00001: val_loss did not improve from 0.00433
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2182 - accuracy: 0.9215 - val_loss: 0.2076 - val_accuracy: 0.9270
#
# Epoch 00002: val_loss did not improve from 0.00433
# Epoch 3/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1334 - accuracy: 0.9532 - val_loss: 0.1963 - val_accuracy: 0.9254
#
# Epoch 00003: val_loss did not improve from 0.00433
# Epoch 4/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1092 - accuracy: 0.9612 - val_loss: 0.1518 - val_accuracy: 0.9453
#
# Epoch 00004: val_loss did not improve from 0.00433
# Epoch 5/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0822 - accuracy: 0.9710 - val_loss: 0.0550 - val_accuracy: 0.9812
#
# Epoch 00005: val_loss did not improve from 0.00433
# Epoch 6/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0614 - accuracy: 0.9780 - val_loss: 0.2021 - val_accuracy: 0.9375
#
# Epoch 00006: val_loss did not improve from 0.00433
# Epoch 7/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0491 - accuracy: 0.9834 - val_loss: 0.0518 - val_accuracy: 0.9828
#
# Epoch 00007: val_loss did not improve from 0.00433
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0469 - accuracy: 0.9849 - val_loss: 0.0172 - val_accuracy: 0.9934
#
# Epoch 00008: val_loss did not improve from 0.00433
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0374 - accuracy: 0.9881 - val_loss: 0.0124 - val_accuracy: 0.9961
#
# Epoch 00009: val_loss did not improve from 0.00433
# Epoch 10/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0479 - accuracy: 0.9845 - val_loss: 0.0162 - val_accuracy: 0.9926
#
# Epoch 00010: val_loss did not improve from 0.00433
# Epoch 11/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0373 - accuracy: 0.9879 - val_loss: 0.0365 - val_accuracy: 0.9855
#
# Epoch 00011: val_loss did not improve from 0.00433
# Epoch 12/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0339 - accuracy: 0.9895 - val_loss: 0.0152 - val_accuracy: 0.9965
#
# Epoch 00012: val_loss did not improve from 0.00433
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0284 - accuracy: 0.9911 - val_loss: 0.0373 - val_accuracy: 0.9902
#
# Epoch 00013: val_loss did not improve from 0.00433
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0318 - accuracy: 0.9905 - val_loss: 0.0232 - val_accuracy: 0.9926
#
# Epoch 00014: val_loss did not improve from 0.00433
# Epoch 15/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0305 - accuracy: 0.9896 - val_loss: 0.3782 - val_accuracy: 0.8852
#
# Epoch 00015: val_loss did not improve from 0.00433
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.0171 - val_accuracy: 0.9973
#
# Epoch 00016: val_loss did not improve from 0.00433
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0214 - accuracy: 0.9927 - val_loss: 0.0235 - val_accuracy: 0.9918
#
# Epoch 00017: val_loss did not improve from 0.00433
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0233 - accuracy: 0.9927 - val_loss: 0.0440 - val_accuracy: 0.9840
#
# Epoch 00018: val_loss did not improve from 0.00433
# Epoch 19/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0255 - accuracy: 0.9921 - val_loss: 0.1079 - val_accuracy: 0.9738
#
# Epoch 00019: val_loss did not improve from 0.00433
# Epoch 20/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0255 - accuracy: 0.9920 - val_loss: 0.0523 - val_accuracy: 0.9840
#
# Epoch 00020: val_loss did not improve from 0.00433
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0200 - accuracy: 0.9924 - val_loss: 0.0085 - val_accuracy: 0.9969
#
# Epoch 00021: val_loss did not improve from 0.00433
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.0100 - val_accuracy: 0.9965
#
# Epoch 00022: val_loss did not improve from 0.00433
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.0171 - val_accuracy: 0.9965
#
# Epoch 00023: val_loss did not improve from 0.00433
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0184 - accuracy: 0.9935 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00024: val_loss did not improve from 0.00433
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0214 - accuracy: 0.9938 - val_loss: 0.0131 - val_accuracy: 0.9941
#
# Epoch 00025: val_loss did not improve from 0.00433
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.0060 - val_accuracy: 0.9973
#
# Epoch 00026: val_loss did not improve from 0.00433
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9946 - val_loss: 0.0588 - val_accuracy: 0.9809
#
# Epoch 00027: val_loss did not improve from 0.00433
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0187 - accuracy: 0.9941 - val_loss: 0.0130 - val_accuracy: 0.9961
#
# Epoch 00028: val_loss did not improve from 0.00433
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0217 - accuracy: 0.9927 - val_loss: 0.9463 - val_accuracy: 0.8770
#
# Epoch 00029: val_loss did not improve from 0.00433
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.0074 - val_accuracy: 0.9973
#
# Epoch 00030: val_loss did not improve from 0.00433
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.0050 - val_accuracy: 0.9973
#
# Epoch 00031: val_loss did not improve from 0.00433
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0098 - accuracy: 0.9962 - val_loss: 0.0180 - val_accuracy: 0.9949
#
# Epoch 00032: val_loss did not improve from 0.00433
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.3133 - val_accuracy: 0.9312
#
# Epoch 00033: val_loss did not improve from 0.00433
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0198 - accuracy: 0.9927 - val_loss: 0.0268 - val_accuracy: 0.9910
#
# Epoch 00034: val_loss did not improve from 0.00433
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.0330 - val_accuracy: 0.9910
#
# Epoch 00035: val_loss did not improve from 0.00433
# Epoch 36/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.0584 - val_accuracy: 0.9805
#
# Epoch 00036: val_loss did not improve from 0.00433
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.0411 - val_accuracy: 0.9898
#
# Epoch 00037: val_loss did not improve from 0.00433
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.3354 - val_accuracy: 0.9258
#
# Epoch 00038: val_loss did not improve from 0.00433
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0193 - accuracy: 0.9943 - val_loss: 0.0094 - val_accuracy: 0.9961
#
# Epoch 00039: val_loss did not improve from 0.00433
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0155 - accuracy: 0.9951 - val_loss: 0.0052 - val_accuracy: 0.9988
#
# Epoch 00040: val_loss did not improve from 0.00433
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.5332 - val_accuracy: 0.8922
#
# Epoch 00041: val_loss did not improve from 0.00433
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0142 - accuracy: 0.9948 - val_loss: 0.1437 - val_accuracy: 0.9676
#
# Epoch 00042: val_loss did not improve from 0.00433
# Epoch 43/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.0046 - val_accuracy: 0.9973
#
# Epoch 00043: val_loss did not improve from 0.00433
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00044: val_loss did not improve from 0.00433
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0236 - accuracy: 0.9920 - val_loss: 0.6632 - val_accuracy: 0.8418
#
# Epoch 00045: val_loss did not improve from 0.00433
# Epoch 46/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0407 - val_accuracy: 0.9871
#
# Epoch 00046: val_loss did not improve from 0.00433
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0151 - val_accuracy: 0.9957
#
# Epoch 00047: val_loss did not improve from 0.00433
# Epoch 48/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.6451 - val_accuracy: 0.9184
#
# Epoch 00048: val_loss did not improve from 0.00433
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.0101 - val_accuracy: 0.9957
#
# Epoch 00049: val_loss did not improve from 0.00433
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0149 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00433
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0052 - val_accuracy: 0.9969
#
# Epoch 00051: val_loss did not improve from 0.00433
# Epoch 52/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.0222 - val_accuracy: 0.9937
#
# Epoch 00052: val_loss did not improve from 0.00433
# Epoch 53/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.2075 - val_accuracy: 0.9426
#
# Epoch 00053: val_loss did not improve from 0.00433
# Epoch 54/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 0.0107 - val_accuracy: 0.9949
#
# Epoch 00054: val_loss did not improve from 0.00433
# Epoch 55/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0095 - accuracy: 0.9962 - val_loss: 0.0077 - val_accuracy: 0.9977
#
# Epoch 00055: val_loss did not improve from 0.00433
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0072 - val_accuracy: 0.9977
#
# Epoch 00056: val_loss did not improve from 0.00433
# Epoch 57/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00057: val_loss did not improve from 0.00433
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0161 - accuracy: 0.9952 - val_loss: 0.0396 - val_accuracy: 0.9898
#
# Epoch 00058: val_loss did not improve from 0.00433
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0133 - val_accuracy: 0.9941
#
# Epoch 00059: val_loss did not improve from 0.00433
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00060: val_loss improved from 0.00433 to 0.00262, saving model to model.h5
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0086 - val_accuracy: 0.9957
#
# Epoch 00061: val_loss did not improve from 0.00262
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.0058 - val_accuracy: 0.9984
#
# Epoch 00062: val_loss did not improve from 0.00262
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0088 - accuracy: 0.9963 - val_loss: 0.0325 - val_accuracy: 0.9895
#
# Epoch 00063: val_loss did not improve from 0.00262
# Epoch 64/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9961 - val_loss: 0.0191 - val_accuracy: 0.9945
#
# Epoch 00064: val_loss did not improve from 0.00262
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.2692 - val_accuracy: 0.9441
#
# Epoch 00065: val_loss did not improve from 0.00262
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0221 - accuracy: 0.9927 - val_loss: 0.0242 - val_accuracy: 0.9898
#
# Epoch 00066: val_loss did not improve from 0.00262
# Epoch 67/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0116 - accuracy: 0.9957 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00067: val_loss improved from 0.00262 to 0.00214, saving model to model.h5
# Epoch 68/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0312 - val_accuracy: 0.9926
#
# Epoch 00068: val_loss did not improve from 0.00214
# Epoch 69/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00069: val_loss did not improve from 0.00214
# Epoch 70/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00070: val_loss did not improve from 0.00214
# Epoch 71/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.6211 - val_accuracy: 0.9223
#
# Epoch 00071: val_loss did not improve from 0.00214
# Epoch 72/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 0.0097 - val_accuracy: 0.9965
#
# Epoch 00072: val_loss did not improve from 0.00214
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9965 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00073: val_loss did not improve from 0.00214
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.2293 - val_accuracy: 0.9414
#
# Epoch 00074: val_loss did not improve from 0.00214
# Epoch 75/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00075: val_loss did not improve from 0.00214
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0265 - val_accuracy: 0.9918
#
# Epoch 00076: val_loss did not improve from 0.00214
# Epoch 77/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.2926 - val_accuracy: 0.9371
#
# Epoch 00077: val_loss did not improve from 0.00214
# Epoch 78/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0077 - accuracy: 0.9966 - val_loss: 0.0043 - val_accuracy: 0.9973
#
# Epoch 00078: val_loss did not improve from 0.00214
# Epoch 79/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0085 - accuracy: 0.9965 - val_loss: 0.0032 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00214
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9970 - val_loss: 0.5134 - val_accuracy: 0.9145
#
# Epoch 00080: val_loss did not improve from 0.00214
# Epoch 81/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0031 - val_accuracy: 0.9988
#
# Epoch 00081: val_loss did not improve from 0.00214
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00082: val_loss did not improve from 0.00214
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.9137 - val_accuracy: 0.8629
#
# Epoch 00083: val_loss did not improve from 0.00214
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.0119 - val_accuracy: 0.9957
#
# Epoch 00084: val_loss did not improve from 0.00214
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00214
# Epoch 86/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0046 - val_accuracy: 0.9984
#
# Epoch 00086: val_loss did not improve from 0.00214
# Epoch 87/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0063 - val_accuracy: 0.9973
#
# Epoch 00087: val_loss did not improve from 0.00214
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0071 - accuracy: 0.9969 - val_loss: 0.0028 - val_accuracy: 0.9988
#
# Epoch 00088: val_loss did not improve from 0.00214
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00089: val_loss did not improve from 0.00214
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00090: val_loss did not improve from 0.00214
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.0089 - val_accuracy: 0.9965
#
# Epoch 00091: val_loss did not improve from 0.00214
# Epoch 92/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0062 - accuracy: 0.9973 - val_loss: 0.0042 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00214
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0079 - val_accuracy: 0.9969
#
# Epoch 00093: val_loss did not improve from 0.00214
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0167 - val_accuracy: 0.9957
#
# Epoch 00094: val_loss did not improve from 0.00214
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0075 - accuracy: 0.9964 - val_loss: 0.0098 - val_accuracy: 0.9977
#
# Epoch 00095: val_loss did not improve from 0.00214
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9973 - val_loss: 0.0093 - val_accuracy: 0.9969
#
# Epoch 00096: val_loss did not improve from 0.00214
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 0.0078 - val_accuracy: 0.9969
#
# Epoch 00097: val_loss did not improve from 0.00214
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0122 - val_accuracy: 0.9965
#
# Epoch 00098: val_loss did not improve from 0.00214
# Epoch 99/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.0085 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00214
# Epoch 100/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0042 - val_accuracy: 0.9977
#
# Epoch 00100: val_loss did not improve from 0.00214
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.9977
# Val Score:  [0.0041903178207576275, 0.9976562261581421]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.4246 - accuracy: 0.8564 - val_loss: 2.7501 - val_accuracy: 0.5344
#
# Epoch 00001: val_loss did not improve from 0.00214
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1774 - accuracy: 0.9370 - val_loss: 0.7423 - val_accuracy: 0.7715
#
# Epoch 00002: val_loss did not improve from 0.00214
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1336 - accuracy: 0.9535 - val_loss: 0.2125 - val_accuracy: 0.9355
#
# Epoch 00003: val_loss did not improve from 0.00214
# Epoch 4/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0797 - accuracy: 0.9728 - val_loss: 0.0486 - val_accuracy: 0.9855
#
# Epoch 00004: val_loss did not improve from 0.00214
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0591 - accuracy: 0.9790 - val_loss: 0.0710 - val_accuracy: 0.9746
#
# Epoch 00005: val_loss did not improve from 0.00214
# Epoch 6/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0532 - accuracy: 0.9838 - val_loss: 0.0179 - val_accuracy: 0.9937
#
# Epoch 00006: val_loss did not improve from 0.00214
# Epoch 7/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0454 - accuracy: 0.9856 - val_loss: 0.2225 - val_accuracy: 0.9223
#
# Epoch 00007: val_loss did not improve from 0.00214
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0511 - accuracy: 0.9825 - val_loss: 0.0883 - val_accuracy: 0.9676
#
# Epoch 00008: val_loss did not improve from 0.00214
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0420 - accuracy: 0.9866 - val_loss: 0.4475 - val_accuracy: 0.8832
#
# Epoch 00009: val_loss did not improve from 0.00214
# Epoch 10/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0406 - accuracy: 0.9865 - val_loss: 0.0252 - val_accuracy: 0.9918
#
# Epoch 00010: val_loss did not improve from 0.00214
# Epoch 11/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0394 - accuracy: 0.9867 - val_loss: 0.1264 - val_accuracy: 0.9531
#
# Epoch 00011: val_loss did not improve from 0.00214
# Epoch 12/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0343 - accuracy: 0.9897 - val_loss: 0.0530 - val_accuracy: 0.9859
#
# Epoch 00012: val_loss did not improve from 0.00214
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0281 - accuracy: 0.9912 - val_loss: 0.0420 - val_accuracy: 0.9887
#
# Epoch 00013: val_loss did not improve from 0.00214
# Epoch 14/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0160 - accuracy: 0.9943 - val_loss: 0.0462 - val_accuracy: 0.9918
#
# Epoch 00014: val_loss did not improve from 0.00214
# Epoch 15/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0305 - accuracy: 0.9909 - val_loss: 0.1127 - val_accuracy: 0.9723
#
# Epoch 00015: val_loss did not improve from 0.00214
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0319 - accuracy: 0.9897 - val_loss: 0.0383 - val_accuracy: 0.9852
#
# Epoch 00016: val_loss did not improve from 0.00214
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.0143 - val_accuracy: 0.9949
#
# Epoch 00017: val_loss did not improve from 0.00214
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0288 - accuracy: 0.9910 - val_loss: 0.0195 - val_accuracy: 0.9918
#
# Epoch 00018: val_loss did not improve from 0.00214
# Epoch 19/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0372 - accuracy: 0.9884 - val_loss: 0.1628 - val_accuracy: 0.9563
#
# Epoch 00019: val_loss did not improve from 0.00214
# Epoch 20/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0206 - accuracy: 0.9942 - val_loss: 0.0267 - val_accuracy: 0.9934
#
# Epoch 00020: val_loss did not improve from 0.00214
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 0.0117 - val_accuracy: 0.9973
#
# Epoch 00021: val_loss did not improve from 0.00214
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0179 - accuracy: 0.9949 - val_loss: 0.0563 - val_accuracy: 0.9848
#
# Epoch 00022: val_loss did not improve from 0.00214
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.9934 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00023: val_loss did not improve from 0.00214
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0177 - accuracy: 0.9953 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00024: val_loss did not improve from 0.00214
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0153 - accuracy: 0.9962 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00025: val_loss did not improve from 0.00214
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.5022 - val_accuracy: 0.8957
#
# Epoch 00026: val_loss did not improve from 0.00214
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.0305 - val_accuracy: 0.9887
#
# Epoch 00027: val_loss did not improve from 0.00214
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0215 - accuracy: 0.9938 - val_loss: 0.0280 - val_accuracy: 0.9910
#
# Epoch 00028: val_loss did not improve from 0.00214
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0213 - accuracy: 0.9935 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00029: val_loss did not improve from 0.00214
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0219 - accuracy: 0.9931 - val_loss: 0.7244 - val_accuracy: 0.8535
#
# Epoch 00030: val_loss did not improve from 0.00214
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0229 - accuracy: 0.9924 - val_loss: 0.0147 - val_accuracy: 0.9969
#
# Epoch 00031: val_loss did not improve from 0.00214
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0167 - accuracy: 0.9953 - val_loss: 0.2278 - val_accuracy: 0.9312
#
# Epoch 00032: val_loss did not improve from 0.00214
# Epoch 33/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0178 - accuracy: 0.9943 - val_loss: 0.0750 - val_accuracy: 0.9832
#
# Epoch 00033: val_loss did not improve from 0.00214
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0120 - val_accuracy: 0.9957
#
# Epoch 00034: val_loss did not improve from 0.00214
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00035: val_loss did not improve from 0.00214
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 0.0134 - val_accuracy: 0.9949
#
# Epoch 00036: val_loss did not improve from 0.00214
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00037: val_loss did not improve from 0.00214
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.0144 - val_accuracy: 0.9934
#
# Epoch 00038: val_loss did not improve from 0.00214
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0180 - accuracy: 0.9945 - val_loss: 0.1068 - val_accuracy: 0.9711
#
# Epoch 00039: val_loss did not improve from 0.00214
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0179 - accuracy: 0.9943 - val_loss: 0.0100 - val_accuracy: 0.9961
#
# Epoch 00040: val_loss did not improve from 0.00214
# Epoch 41/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00214
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0202 - accuracy: 0.9950 - val_loss: 0.0175 - val_accuracy: 0.9945
#
# Epoch 00021: val_loss did not improve from 0.00214
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0192 - accuracy: 0.9948 - val_loss: 0.0295 - val_accuracy: 0.9914
#
# Epoch 00022: val_loss did not improve from 0.00214
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0216 - accuracy: 0.9936 - val_loss: 0.5319 - val_accuracy: 0.9059
#
# Epoch 00023: val_loss did not improve from 0.00214
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0201 - accuracy: 0.9939 - val_loss: 0.0707 - val_accuracy: 0.9820
#
# Epoch 00024: val_loss did not improve from 0.00214
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0235 - accuracy: 0.9923 - val_loss: 0.0403 - val_accuracy: 0.9863
#
# Epoch 00025: val_loss did not improve from 0.00214
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00026: val_loss did not improve from 0.00214
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0193 - val_accuracy: 0.9934
#
# Epoch 00027: val_loss did not improve from 0.00214
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0174 - accuracy: 0.9953 - val_loss: 0.1436 - val_accuracy: 0.9613
#
# Epoch 00028: val_loss did not improve from 0.00214
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0168 - accuracy: 0.9952 - val_loss: 0.5686 - val_accuracy: 0.8566
#
# Epoch 00029: val_loss did not improve from 0.00214
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0170 - accuracy: 0.9952 - val_loss: 0.0133 - val_accuracy: 0.9973
#
# Epoch 00030: val_loss did not improve from 0.00214
# Epoch 31/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0152 - accuracy: 0.9965 - val_loss: 0.0099 - val_accuracy: 0.9973
#
# Epoch 00031: val_loss did not improve from 0.00214
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0149 - accuracy: 0.9964 - val_loss: 0.2400 - val_accuracy: 0.9387
#
# Epoch 00032: val_loss did not improve from 0.00214
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0252 - val_accuracy: 0.9922
#
# Epoch 00033: val_loss did not improve from 0.00214
# Epoch 34/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.1102 - val_accuracy: 0.9672
#
# Epoch 00034: val_loss did not improve from 0.00214
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0188 - accuracy: 0.9944 - val_loss: 0.3057 - val_accuracy: 0.9113
#
# Epoch 00035: val_loss did not improve from 0.00214
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0232 - accuracy: 0.9927 - val_loss: 0.0329 - val_accuracy: 0.9910
#
# Epoch 00036: val_loss did not improve from 0.00214
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.1012 - val_accuracy: 0.9645
#
# Epoch 00037: val_loss did not improve from 0.00214
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0075 - val_accuracy: 0.9969
#
# Epoch 00038: val_loss did not improve from 0.00214
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.3490 - val_accuracy: 0.9062
#
# Epoch 00039: val_loss did not improve from 0.00214
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0223 - accuracy: 0.9931 - val_loss: 0.0139 - val_accuracy: 0.9953
#
# Epoch 00040: val_loss did not improve from 0.00214
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0237 - val_accuracy: 0.9926
#
# Epoch 00041: val_loss did not improve from 0.00214
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 0.0098 - val_accuracy: 0.9957
#
# Epoch 00042: val_loss did not improve from 0.00214
# Epoch 43/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.0056 - val_accuracy: 0.9977
#
# Epoch 00043: val_loss did not improve from 0.00214
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.0911 - val_accuracy: 0.9715
#
# Epoch 00044: val_loss did not improve from 0.00214
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.0181 - val_accuracy: 0.9930
#
# Epoch 00045: val_loss did not improve from 0.00214
# Epoch 46/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.0215 - val_accuracy: 0.9930
#
# Epoch 00046: val_loss did not improve from 0.00214
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0117 - accuracy: 0.9958 - val_loss: 0.0315 - val_accuracy: 0.9887
#
# Epoch 00047: val_loss did not improve from 0.00214
# Epoch 48/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0094 - val_accuracy: 0.9965
#
# Epoch 00048: val_loss did not improve from 0.00214
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 0.0056 - val_accuracy: 0.9969
#
# Epoch 00049: val_loss did not improve from 0.00214
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.4652 - val_accuracy: 0.9273
#
# Epoch 00050: val_loss did not improve from 0.00214
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0789 - val_accuracy: 0.9707
#
# Epoch 00051: val_loss did not improve from 0.00214
# Epoch 52/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.2682 - val_accuracy: 0.9070
#
# Epoch 00052: val_loss did not improve from 0.00214
# Epoch 53/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0239 - val_accuracy: 0.9910
#
# Epoch 00053: val_loss did not improve from 0.00214
# Epoch 54/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.0058 - val_accuracy: 0.9969
#
# Epoch 00054: val_loss did not improve from 0.00214
# Epoch 55/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0066 - val_accuracy: 0.9965
#
# Epoch 00055: val_loss did not improve from 0.00214
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0238 - val_accuracy: 0.9953
#
# Epoch 00056: val_loss did not improve from 0.00214
# Epoch 57/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 0.0151 - val_accuracy: 0.9949
#
# Epoch 00057: val_loss did not improve from 0.00214
# Epoch 58/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.3506 - val_accuracy: 0.9285
#
# Epoch 00058: val_loss did not improve from 0.00214
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0090 - accuracy: 0.9967 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00059: val_loss did not improve from 0.00214
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9970 - val_loss: 2.6322 - val_accuracy: 0.6992
#
# Epoch 00060: val_loss did not improve from 0.00214
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0077 - accuracy: 0.9967 - val_loss: 0.0315 - val_accuracy: 0.9902
#
# Epoch 00061: val_loss did not improve from 0.00214
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.0056 - val_accuracy: 0.9973
#
# Epoch 00062: val_loss did not improve from 0.00214
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0663 - val_accuracy: 0.9844
#
# Epoch 00063: val_loss did not improve from 0.00214
# Epoch 64/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00064: val_loss did not improve from 0.00214
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.7841 - val_accuracy: 0.8344
#
# Epoch 00065: val_loss did not improve from 0.00214
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0132 - accuracy: 0.9962 - val_loss: 0.1732 - val_accuracy: 0.9484
#
# Epoch 00066: val_loss did not improve from 0.00214
# Epoch 67/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9957 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00067: val_loss did not improve from 0.00214
# Epoch 68/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0074 - val_accuracy: 0.9977
#
# Epoch 00068: val_loss did not improve from 0.00214
# Epoch 69/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.0057 - val_accuracy: 0.9973
#
# Epoch 00069: val_loss did not improve from 0.00214
# Epoch 70/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0046 - val_accuracy: 0.9984
#
# Epoch 00070: val_loss did not improve from 0.00214
# Epoch 71/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0851 - val_accuracy: 0.9762
#
# Epoch 00071: val_loss did not improve from 0.00214
# Epoch 72/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0096 - accuracy: 0.9959 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00072: val_loss did not improve from 0.00214
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00073: val_loss did not improve from 0.00214
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0044 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00214
# Epoch 75/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0029 - val_accuracy: 0.9980
#
# Epoch 00075: val_loss did not improve from 0.00214
# Epoch 76/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00214
# Epoch 77/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00077: val_loss improved from 0.00214 to 0.00209, saving model to model.h5
# Epoch 78/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 0.3628 - val_accuracy: 0.9262
#
# Epoch 00078: val_loss did not improve from 0.00209
# Epoch 79/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0182 - accuracy: 0.9953 - val_loss: 0.0057 - val_accuracy: 0.9984
#
# Epoch 00079: val_loss did not improve from 0.00209
# Epoch 80/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.0067 - val_accuracy: 0.9980
#
# Epoch 00080: val_loss did not improve from 0.00209
# Epoch 81/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00209
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00082: val_loss did not improve from 0.00209
# Epoch 83/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.0595 - val_accuracy: 0.9836
#
# Epoch 00083: val_loss did not improve from 0.00209
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.0092 - val_accuracy: 0.9965
#
# Epoch 00084: val_loss did not improve from 0.00209
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.0286 - val_accuracy: 0.9914
#
# Epoch 00085: val_loss did not improve from 0.00209
# Epoch 86/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0051 - val_accuracy: 0.9984
#
# Epoch 00086: val_loss did not improve from 0.00209
# Epoch 87/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00087: val_loss did not improve from 0.00209
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00088: val_loss did not improve from 0.00209
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0048 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00209
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0169 - val_accuracy: 0.9930
#
# Epoch 00090: val_loss did not improve from 0.00209
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0223 - val_accuracy: 0.9937
#
# Epoch 00091: val_loss did not improve from 0.00209
# Epoch 92/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0053 - val_accuracy: 0.9980
#
# Epoch 00092: val_loss did not improve from 0.00209
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0078 - accuracy: 0.9970 - val_loss: 0.3044 - val_accuracy: 0.9418
#
# Epoch 00093: val_loss did not improve from 0.00209
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0078 - val_accuracy: 0.9980
#
# Epoch 00094: val_loss did not improve from 0.00209
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0094 - val_accuracy: 0.9965
#
# Epoch 00095: val_loss did not improve from 0.00209
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.0301 - val_accuracy: 0.9895
#
# Epoch 00096: val_loss did not improve from 0.00209
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00209
# Epoch 98/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00209
# Epoch 99/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 0.0225 - val_accuracy: 0.9953
#
# Epoch 00099: val_loss did not improve from 0.00209
# Epoch 100/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.2200 - val_accuracy: 0.9516
#
# Epoch 00100: val_loss did not improve from 0.00209
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2200 - accuracy: 0.9516
# Val Score:  [0.22004935145378113, 0.9515625238418579]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.9962
# Test Accuracy: 99.62499737739563

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
