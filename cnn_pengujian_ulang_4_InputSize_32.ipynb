# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-4
BS = 32
default_image_size = tuple((32, 32))
image_size = 0
directory_root = "../input/riceleaf"
width=32
height=32
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# activation_36 (Activation)   (None, 32, 32, 16)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 32, 32, 16)        64
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 10, 10, 16)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 10, 10, 16)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 10, 10, 32)        4640
# _________________________________________________________________
# activation_37 (Activation)   (None, 10, 10, 32)        0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 10, 10, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# activation_38 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 10, 10, 64)        256
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# activation_39 (Activation)   (None, 5, 5, 128)         0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 5, 5, 128)         512
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              3277824
# _________________________________________________________________
# activation_40 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_41 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 3,384,420
# Trainable params: 3,381,892
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 3s 7ms/step - loss: 0.6582 - accuracy: 0.7795 - val_loss: 2.4583 - val_accuracy: 0.4516
#
# Epoch 00001: val_loss improved from inf to 2.45834, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.3266 - accuracy: 0.8895 - val_loss: 0.2572 - val_accuracy: 0.8941
#
# Epoch 00002: val_loss improved from 2.45834 to 0.25719, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2391 - accuracy: 0.9161 - val_loss: 0.1208 - val_accuracy: 0.9523
#
# Epoch 00003: val_loss improved from 0.25719 to 0.12077, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1785 - accuracy: 0.9349 - val_loss: 0.1178 - val_accuracy: 0.9574
#
# Epoch 00004: val_loss improved from 0.12077 to 0.11778, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1491 - accuracy: 0.9481 - val_loss: 0.1864 - val_accuracy: 0.9316
#
# Epoch 00005: val_loss did not improve from 0.11778
# Epoch 6/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1334 - accuracy: 0.9522 - val_loss: 0.1584 - val_accuracy: 0.9480
#
# Epoch 00006: val_loss did not improve from 0.11778
# Epoch 7/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1117 - accuracy: 0.9596 - val_loss: 0.1814 - val_accuracy: 0.9461
#
# Epoch 00007: val_loss did not improve from 0.11778
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1045 - accuracy: 0.9645 - val_loss: 0.1976 - val_accuracy: 0.9254
#
# Epoch 00008: val_loss did not improve from 0.11778
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0929 - accuracy: 0.9675 - val_loss: 0.1634 - val_accuracy: 0.9480
#
# Epoch 00009: val_loss did not improve from 0.11778
# Epoch 10/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0828 - accuracy: 0.9697 - val_loss: 0.0736 - val_accuracy: 0.9707
#
# Epoch 00010: val_loss improved from 0.11778 to 0.07364, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0771 - accuracy: 0.9729 - val_loss: 0.0422 - val_accuracy: 0.9840
#
# Epoch 00011: val_loss improved from 0.07364 to 0.04216, saving model to model.h5
# Epoch 12/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0641 - accuracy: 0.9768 - val_loss: 0.0948 - val_accuracy: 0.9652
#
# Epoch 00012: val_loss did not improve from 0.04216
# Epoch 13/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0655 - accuracy: 0.9776 - val_loss: 0.1302 - val_accuracy: 0.9516
#
# Epoch 00013: val_loss did not improve from 0.04216
# Epoch 14/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0643 - accuracy: 0.9799 - val_loss: 0.0465 - val_accuracy: 0.9816
#
# Epoch 00014: val_loss did not improve from 0.04216
# Epoch 15/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0606 - accuracy: 0.9805 - val_loss: 0.1387 - val_accuracy: 0.9563
#
# Epoch 00015: val_loss did not improve from 0.04216
# Epoch 16/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0572 - accuracy: 0.9813 - val_loss: 0.0908 - val_accuracy: 0.9641
#
# Epoch 00016: val_loss did not improve from 0.04216
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0450 - accuracy: 0.9837 - val_loss: 0.0618 - val_accuracy: 0.9723
#
# Epoch 00017: val_loss did not improve from 0.04216
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0454 - accuracy: 0.9852 - val_loss: 0.1534 - val_accuracy: 0.9477
#
# Epoch 00018: val_loss did not improve from 0.04216
# Epoch 19/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0391 - accuracy: 0.9866 - val_loss: 0.0398 - val_accuracy: 0.9855
#
# Epoch 00019: val_loss improved from 0.04216 to 0.03976, saving model to model.h5
# Epoch 20/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0419 - accuracy: 0.9854 - val_loss: 0.0530 - val_accuracy: 0.9777
#
# Epoch 00020: val_loss did not improve from 0.03976
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0356 - accuracy: 0.9876 - val_loss: 0.0146 - val_accuracy: 0.9945
#
# Epoch 00021: val_loss improved from 0.03976 to 0.01461, saving model to model.h5
# Epoch 22/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0404 - accuracy: 0.9868 - val_loss: 0.0641 - val_accuracy: 0.9734
#
# Epoch 00022: val_loss did not improve from 0.01461
# Epoch 23/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0332 - accuracy: 0.9883 - val_loss: 0.0661 - val_accuracy: 0.9781
#
# Epoch 00023: val_loss did not improve from 0.01461
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0336 - accuracy: 0.9888 - val_loss: 0.0299 - val_accuracy: 0.9879
#
# Epoch 00024: val_loss did not improve from 0.01461
# Epoch 25/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0270 - accuracy: 0.9907 - val_loss: 0.0102 - val_accuracy: 0.9957
#
# Epoch 00025: val_loss improved from 0.01461 to 0.01020, saving model to model.h5
# Epoch 26/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0283 - accuracy: 0.9897 - val_loss: 0.0166 - val_accuracy: 0.9953
#
# Epoch 00026: val_loss did not improve from 0.01020
# Epoch 27/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0319 - accuracy: 0.9890 - val_loss: 0.0449 - val_accuracy: 0.9855
#
# Epoch 00027: val_loss did not improve from 0.01020
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0264 - accuracy: 0.9892 - val_loss: 0.0254 - val_accuracy: 0.9902
#
# Epoch 00028: val_loss did not improve from 0.01020
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0233 - accuracy: 0.9912 - val_loss: 0.0116 - val_accuracy: 0.9973
#
# Epoch 00029: val_loss did not improve from 0.01020
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0244 - accuracy: 0.9920 - val_loss: 0.0313 - val_accuracy: 0.9902
#
# Epoch 00030: val_loss did not improve from 0.01020
# Epoch 31/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 0.0064 - val_accuracy: 0.9973
#
# Epoch 00031: val_loss improved from 0.01020 to 0.00641, saving model to model.h5
# Epoch 32/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0268 - accuracy: 0.9901 - val_loss: 0.0261 - val_accuracy: 0.9910
#
# Epoch 00032: val_loss did not improve from 0.00641
# Epoch 33/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0235 - accuracy: 0.9915 - val_loss: 0.0097 - val_accuracy: 0.9953
#
# Epoch 00033: val_loss did not improve from 0.00641
# Epoch 34/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0205 - accuracy: 0.9928 - val_loss: 0.0064 - val_accuracy: 0.9973
#
# Epoch 00034: val_loss did not improve from 0.00641
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0206 - accuracy: 0.9916 - val_loss: 0.0476 - val_accuracy: 0.9820
#
# Epoch 00035: val_loss did not improve from 0.00641
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0180 - accuracy: 0.9933 - val_loss: 0.0070 - val_accuracy: 0.9977
#
# Epoch 00036: val_loss did not improve from 0.00641
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0199 - accuracy: 0.9921 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00037: val_loss did not improve from 0.00641
# Epoch 38/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0191 - accuracy: 0.9927 - val_loss: 0.0138 - val_accuracy: 0.9941
#
# Epoch 00038: val_loss did not improve from 0.00641
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 0.0075 - val_accuracy: 0.9965
#
# Epoch 00039: val_loss did not improve from 0.00641
# Epoch 40/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0193 - accuracy: 0.9932 - val_loss: 0.0075 - val_accuracy: 0.9969
#
# Epoch 00040: val_loss did not improve from 0.00641
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0139 - accuracy: 0.9937 - val_loss: 0.0052 - val_accuracy: 0.9973
#
# Epoch 00041: val_loss improved from 0.00641 to 0.00521, saving model to model.h5
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0167 - accuracy: 0.9933 - val_loss: 0.0042 - val_accuracy: 0.9984
#
# Epoch 00042: val_loss improved from 0.00521 to 0.00418, saving model to model.h5
# Epoch 43/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0179 - accuracy: 0.9933 - val_loss: 0.0070 - val_accuracy: 0.9965
#
# Epoch 00043: val_loss did not improve from 0.00418
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0134 - accuracy: 0.9945 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00044: val_loss improved from 0.00418 to 0.00299, saving model to model.h5
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0128 - accuracy: 0.9953 - val_loss: 0.0058 - val_accuracy: 0.9965
#
# Epoch 00045: val_loss did not improve from 0.00299
# Epoch 46/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00046: val_loss did not improve from 0.00299
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0097 - val_accuracy: 0.9961
#
# Epoch 00047: val_loss did not improve from 0.00299
# Epoch 48/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0187 - accuracy: 0.9936 - val_loss: 0.0170 - val_accuracy: 0.9937
#
# Epoch 00048: val_loss did not improve from 0.00299
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0133 - accuracy: 0.9937 - val_loss: 0.0083 - val_accuracy: 0.9965
#
# Epoch 00049: val_loss did not improve from 0.00299
# Epoch 50/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.0051 - val_accuracy: 0.9984
#
# Epoch 00050: val_loss did not improve from 0.00299
# Epoch 51/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0152 - val_accuracy: 0.9945
#
# Epoch 00051: val_loss did not improve from 0.00299
# Epoch 52/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9952 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00052: val_loss did not improve from 0.00299
# Epoch 53/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0132 - accuracy: 0.9940 - val_loss: 0.0120 - val_accuracy: 0.9957
#
# Epoch 00053: val_loss did not improve from 0.00299
# Epoch 54/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9956 - val_loss: 0.0052 - val_accuracy: 0.9977
#
# Epoch 00054: val_loss did not improve from 0.00299
# Epoch 55/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.0098 - val_accuracy: 0.9973
#
# Epoch 00055: val_loss did not improve from 0.00299
# Epoch 56/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0032 - val_accuracy: 0.9980
#
# Epoch 00056: val_loss did not improve from 0.00299
# Epoch 57/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0116 - accuracy: 0.9954 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00057: val_loss did not improve from 0.00299
# Epoch 58/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0104 - accuracy: 0.9960 - val_loss: 0.0054 - val_accuracy: 0.9969
#
# Epoch 00058: val_loss did not improve from 0.00299
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.0063 - val_accuracy: 0.9973
#
# Epoch 00059: val_loss did not improve from 0.00299
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9948 - val_loss: 0.0110 - val_accuracy: 0.9965
#
# Epoch 00060: val_loss did not improve from 0.00299
# Epoch 61/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9952 - val_loss: 0.0045 - val_accuracy: 0.9973
#
# Epoch 00061: val_loss did not improve from 0.00299
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9950 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00062: val_loss improved from 0.00299 to 0.00220, saving model to model.h5
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0110 - accuracy: 0.9958 - val_loss: 0.0051 - val_accuracy: 0.9973
#
# Epoch 00063: val_loss did not improve from 0.00220
# Epoch 64/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0111 - accuracy: 0.9950 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00064: val_loss did not improve from 0.00220
# Epoch 65/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0106 - accuracy: 0.9955 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00065: val_loss did not improve from 0.00220
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.0061 - val_accuracy: 0.9969
#
# Epoch 00066: val_loss did not improve from 0.00220
# Epoch 67/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0056 - val_accuracy: 0.9969
#
# Epoch 00067: val_loss did not improve from 0.00220
# Epoch 68/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0121 - val_accuracy: 0.9953
#
# Epoch 00068: val_loss did not improve from 0.00220
# Epoch 69/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0112 - accuracy: 0.9954 - val_loss: 0.0092 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00220
# Epoch 70/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0036 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00220
# Epoch 71/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0091 - accuracy: 0.9960 - val_loss: 0.0064 - val_accuracy: 0.9977
#
# Epoch 00071: val_loss did not improve from 0.00220
# Epoch 72/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0080 - accuracy: 0.9964 - val_loss: 0.0362 - val_accuracy: 0.9898
#
# Epoch 00072: val_loss did not improve from 0.00220
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00073: val_loss did not improve from 0.00220
# Epoch 74/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0084 - accuracy: 0.9964 - val_loss: 0.0065 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00220
# Epoch 75/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0105 - accuracy: 0.9960 - val_loss: 0.0078 - val_accuracy: 0.9969
#
# Epoch 00075: val_loss did not improve from 0.00220
# Epoch 76/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0126 - accuracy: 0.9952 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00220
# Epoch 77/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 0.0079 - val_accuracy: 0.9969
#
# Epoch 00077: val_loss did not improve from 0.00220
# Epoch 78/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00078: val_loss did not improve from 0.00220
# Epoch 79/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0073 - accuracy: 0.9967 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00079: val_loss did not improve from 0.00220
# Epoch 80/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0102 - accuracy: 0.9960 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00080: val_loss did not improve from 0.00220
# Epoch 81/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0075 - accuracy: 0.9970 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00081: val_loss did not improve from 0.00220
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0075 - accuracy: 0.9966 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00082: val_loss did not improve from 0.00220
# Epoch 83/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0080 - accuracy: 0.9960 - val_loss: 0.0042 - val_accuracy: 0.9969
#
# Epoch 00083: val_loss did not improve from 0.00220
# Epoch 84/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 0.0049 - val_accuracy: 0.9980
#
# Epoch 00084: val_loss did not improve from 0.00220
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00220
# Epoch 86/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0079 - val_accuracy: 0.9977
#
# Epoch 00086: val_loss did not improve from 0.00220
# Epoch 87/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00087: val_loss did not improve from 0.00220
# Epoch 88/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00088: val_loss did not improve from 0.00220
# Epoch 89/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0090 - accuracy: 0.9958 - val_loss: 0.0035 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00220
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00090: val_loss did not improve from 0.00220
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0064 - accuracy: 0.9971 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00091: val_loss did not improve from 0.00220
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.0048 - val_accuracy: 0.9984
#
# Epoch 00092: val_loss did not improve from 0.00220
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00093: val_loss did not improve from 0.00220
# Epoch 94/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0100 - accuracy: 0.9961 - val_loss: 0.0085 - val_accuracy: 0.9965
#
# Epoch 00094: val_loss did not improve from 0.00220
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.0076 - val_accuracy: 0.9977
#
# Epoch 00095: val_loss did not improve from 0.00220
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0080 - accuracy: 0.9966 - val_loss: 0.0129 - val_accuracy: 0.9949
#
# Epoch 00096: val_loss did not improve from 0.00220
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0105 - accuracy: 0.9958 - val_loss: 0.0119 - val_accuracy: 0.9961
#
# Epoch 00097: val_loss did not improve from 0.00220
# Epoch 98/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0098 - accuracy: 0.9958 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00098: val_loss improved from 0.00220 to 0.00218, saving model to model.h5
# Epoch 99/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0073 - accuracy: 0.9965 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00099: val_loss did not improve from 0.00218
# Epoch 100/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00100: val_loss improved from 0.00218 to 0.00210, saving model to model.h5
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 0.9988
# Val Score:  [0.002098080702126026, 0.998828113079071]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 3s 6ms/step - loss: 0.5663 - accuracy: 0.8238 - val_loss: 3.3513 - val_accuracy: 0.4922
#
# Epoch 00001: val_loss did not improve from 0.00210
# Epoch 2/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.2445 - accuracy: 0.9103 - val_loss: 0.5362 - val_accuracy: 0.8262
#
# Epoch 00002: val_loss did not improve from 0.00210
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1834 - accuracy: 0.9329 - val_loss: 0.3939 - val_accuracy: 0.8758
#
# Epoch 00003: val_loss did not improve from 0.00210
# Epoch 4/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1501 - accuracy: 0.9452 - val_loss: 0.1222 - val_accuracy: 0.9574
#
# Epoch 00004: val_loss did not improve from 0.00210
# Epoch 5/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1389 - accuracy: 0.9479 - val_loss: 0.1377 - val_accuracy: 0.9547
#
# Epoch 00005: val_loss did not improve from 0.00210
# Epoch 6/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1145 - accuracy: 0.9595 - val_loss: 0.2327 - val_accuracy: 0.9219
#
# Epoch 00006: val_loss did not improve from 0.00210
# Epoch 7/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0960 - accuracy: 0.9650 - val_loss: 0.2496 - val_accuracy: 0.9168
#
# Epoch 00007: val_loss did not improve from 0.00210
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0817 - accuracy: 0.9689 - val_loss: 0.0797 - val_accuracy: 0.9691
#
# Epoch 00008: val_loss did not improve from 0.00210
# Epoch 9/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0761 - accuracy: 0.9735 - val_loss: 0.0891 - val_accuracy: 0.9676
#
# Epoch 00009: val_loss did not improve from 0.00210
# Epoch 10/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0724 - accuracy: 0.9735 - val_loss: 0.1193 - val_accuracy: 0.9566
#
# Epoch 00010: val_loss did not improve from 0.00210
# Epoch 11/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0678 - accuracy: 0.9748 - val_loss: 0.1581 - val_accuracy: 0.9445
#
# Epoch 00011: val_loss did not improve from 0.00210
# Epoch 12/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0610 - accuracy: 0.9764 - val_loss: 0.0709 - val_accuracy: 0.9746
#
# Epoch 00012: val_loss did not improve from 0.00210
# Epoch 13/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0551 - accuracy: 0.9787 - val_loss: 0.0433 - val_accuracy: 0.9863
#
# Epoch 00013: val_loss did not improve from 0.00210
# Epoch 14/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0602 - accuracy: 0.9796 - val_loss: 0.0912 - val_accuracy: 0.9633
#
# Epoch 00014: val_loss did not improve from 0.00210
# Epoch 15/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0510 - accuracy: 0.9832 - val_loss: 0.0681 - val_accuracy: 0.9719
#
# Epoch 00015: val_loss did not improve from 0.00210
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0390 - accuracy: 0.9868 - val_loss: 0.1157 - val_accuracy: 0.9594
#
# Epoch 00016: val_loss did not improve from 0.00210
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0426 - accuracy: 0.9860 - val_loss: 0.0149 - val_accuracy: 0.9941
#
# Epoch 00017: val_loss did not improve from 0.00210
# Epoch 18/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0395 - accuracy: 0.9850 - val_loss: 0.0443 - val_accuracy: 0.9820
#
# Epoch 00018: val_loss did not improve from 0.00210
# Epoch 19/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0385 - accuracy: 0.9867 - val_loss: 0.0980 - val_accuracy: 0.9707
#
# Epoch 00019: val_loss did not improve from 0.00210
# Epoch 20/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0351 - accuracy: 0.9874 - val_loss: 0.0403 - val_accuracy: 0.9855
#
# Epoch 00020: val_loss did not improve from 0.00210
# Epoch 21/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0339 - accuracy: 0.9883 - val_loss: 0.0251 - val_accuracy: 0.9910
#
# Epoch 00021: val_loss did not improve from 0.00210
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0286 - accuracy: 0.9904 - val_loss: 0.0256 - val_accuracy: 0.9922
#
# Epoch 00022: val_loss did not improve from 0.00210
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0348 - accuracy: 0.9879 - val_loss: 0.0507 - val_accuracy: 0.9793
#
# Epoch 00023: val_loss did not improve from 0.00210
# Epoch 24/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0294 - accuracy: 0.9902 - val_loss: 0.0264 - val_accuracy: 0.9906
#
# Epoch 00024: val_loss did not improve from 0.00210
# Epoch 25/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0249 - accuracy: 0.9917 - val_loss: 0.0329 - val_accuracy: 0.9883
#
# Epoch 00025: val_loss did not improve from 0.00210
# Epoch 26/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0289 - accuracy: 0.9903 - val_loss: 0.0264 - val_accuracy: 0.9926
#
# Epoch 00026: val_loss did not improve from 0.00210
# Epoch 27/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.0293 - val_accuracy: 0.9898
#
# Epoch 00027: val_loss did not improve from 0.00210
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0240 - accuracy: 0.9910 - val_loss: 0.0238 - val_accuracy: 0.9922
#
# Epoch 00028: val_loss did not improve from 0.00210
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.0115 - val_accuracy: 0.9965
#
# Epoch 00029: val_loss did not improve from 0.00210
# Epoch 30/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0202 - accuracy: 0.9917 - val_loss: 0.0069 - val_accuracy: 0.9969
#
# Epoch 00030: val_loss did not improve from 0.00210
# Epoch 31/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0243 - accuracy: 0.9924 - val_loss: 0.0269 - val_accuracy: 0.9910
#
# Epoch 00031: val_loss did not improve from 0.00210
# Epoch 32/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0197 - accuracy: 0.9928 - val_loss: 0.0519 - val_accuracy: 0.9836
#
# Epoch 00032: val_loss did not improve from 0.00210
# Epoch 33/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0211 - accuracy: 0.9933 - val_loss: 0.0264 - val_accuracy: 0.9906
#
# Epoch 00033: val_loss did not improve from 0.00210
# Epoch 34/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0132 - accuracy: 0.9951 - val_loss: 0.0171 - val_accuracy: 0.9941
#
# Epoch 00034: val_loss did not improve from 0.00210
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0215 - accuracy: 0.9927 - val_loss: 0.0140 - val_accuracy: 0.9941
#
# Epoch 00035: val_loss did not improve from 0.00210
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9948 - val_loss: 0.0258 - val_accuracy: 0.9918
#
# Epoch 00036: val_loss did not improve from 0.00210
# Epoch 37/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 0.0120 - val_accuracy: 0.9949
#
# Epoch 00037: val_loss did not improve from 0.00210
# Epoch 38/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0168 - accuracy: 0.9937 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00038: val_loss did not improve from 0.00210
# Epoch 39/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0139 - accuracy: 0.9943 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00039: val_loss did not improve from 0.00210
# Epoch 40/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0185 - accuracy: 0.9929 - val_loss: 0.0267 - val_accuracy: 0.9902
#
# Epoch 00040: val_loss did not improve from 0.00210
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0173 - accuracy: 0.9938 - val_loss: 0.0105 - val_accuracy: 0.9969
#
# Epoch 00041: val_loss did not improve from 0.00210
# Epoch 42/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.0098 - val_accuracy: 0.9949
#
# Epoch 00042: val_loss did not improve from 0.00210
# Epoch 43/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9947 - val_loss: 0.0074 - val_accuracy: 0.9980
#
# Epoch 00043: val_loss did not improve from 0.00210
# Epoch 44/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.0069 - val_accuracy: 0.9973
#
# Epoch 00044: val_loss did not improve from 0.00210
# Epoch 45/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9956 - val_loss: 0.0106 - val_accuracy: 0.9965
#
# Epoch 00045: val_loss did not improve from 0.00210
# Epoch 46/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.0299 - val_accuracy: 0.9887
#
# Epoch 00046: val_loss did not improve from 0.00210
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 0.0131 - val_accuracy: 0.9957
#
# Epoch 00047: val_loss did not improve from 0.00210
# Epoch 48/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0139 - accuracy: 0.9942 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00048: val_loss did not improve from 0.00210
# Epoch 49/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.0387 - val_accuracy: 0.9895
#
# Epoch 00049: val_loss did not improve from 0.00210
# Epoch 50/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.0105 - val_accuracy: 0.9969
#
# Epoch 00050: val_loss did not improve from 0.00210
# Epoch 51/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0174 - accuracy: 0.9937 - val_loss: 0.0055 - val_accuracy: 0.9980
#
# Epoch 00051: val_loss did not improve from 0.00210
# Epoch 52/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.0103 - val_accuracy: 0.9961
#
# Epoch 00052: val_loss did not improve from 0.00210
# Epoch 53/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0115 - val_accuracy: 0.9961
#
# Epoch 00053: val_loss did not improve from 0.00210
# Epoch 54/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0122 - accuracy: 0.9948 - val_loss: 0.0097 - val_accuracy: 0.9965
#
# Epoch 00054: val_loss did not improve from 0.00210
# Epoch 55/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 0.0076 - val_accuracy: 0.9980
#
# Epoch 00055: val_loss did not improve from 0.00210
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.0109 - val_accuracy: 0.9969
#
# Epoch 00056: val_loss did not improve from 0.00210
# Epoch 57/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0101 - accuracy: 0.9955 - val_loss: 0.0164 - val_accuracy: 0.9957
#
# Epoch 00057: val_loss did not improve from 0.00210
# Epoch 58/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0128 - accuracy: 0.9948 - val_loss: 0.0089 - val_accuracy: 0.9957
#
# Epoch 00058: val_loss did not improve from 0.00210
# Epoch 59/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00059: val_loss did not improve from 0.00210
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 0.0074 - val_accuracy: 0.9977
#
# Epoch 00060: val_loss did not improve from 0.00210
# Epoch 61/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0093 - accuracy: 0.9962 - val_loss: 0.0053 - val_accuracy: 0.9973
#
# Epoch 00061: val_loss did not improve from 0.00210
# Epoch 62/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.0556 - val_accuracy: 0.9844
#
# Epoch 00062: val_loss did not improve from 0.00210
# Epoch 63/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9959 - val_loss: 0.0079 - val_accuracy: 0.9977
#
# Epoch 00063: val_loss did not improve from 0.00210
# Epoch 64/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00064: val_loss did not improve from 0.00210
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0103 - accuracy: 0.9954 - val_loss: 0.0156 - val_accuracy: 0.9949
#
# Epoch 00065: val_loss did not improve from 0.00210
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.0105 - val_accuracy: 0.9961
#
# Epoch 00066: val_loss did not improve from 0.00210
# Epoch 67/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.0103 - val_accuracy: 0.9953
#
# Epoch 00067: val_loss did not improve from 0.00210
# Epoch 68/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0091 - accuracy: 0.9959 - val_loss: 0.0152 - val_accuracy: 0.9957
#
# Epoch 00068: val_loss did not improve from 0.00210
# Epoch 69/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0087 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00210
# Epoch 70/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 0.0042 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00210
# Epoch 71/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0083 - val_accuracy: 0.9965
#
# Epoch 00071: val_loss did not improve from 0.00210
# Epoch 72/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0117 - accuracy: 0.9950 - val_loss: 0.0219 - val_accuracy: 0.9914
#
# Epoch 00072: val_loss did not improve from 0.00210
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0075 - accuracy: 0.9970 - val_loss: 0.0096 - val_accuracy: 0.9977
#
# Epoch 00073: val_loss did not improve from 0.00210
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9963 - val_loss: 0.0079 - val_accuracy: 0.9965
#
# Epoch 00074: val_loss did not improve from 0.00210
# Epoch 75/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0089 - accuracy: 0.9961 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00075: val_loss did not improve from 0.00210
# Epoch 76/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0105 - val_accuracy: 0.9957
#
# Epoch 00076: val_loss did not improve from 0.00210
# Epoch 77/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0078 - accuracy: 0.9962 - val_loss: 0.0118 - val_accuracy: 0.9957
#
# Epoch 00077: val_loss did not improve from 0.00210
# Epoch 78/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0107 - accuracy: 0.9958 - val_loss: 0.0067 - val_accuracy: 0.9973
#
# Epoch 00078: val_loss did not improve from 0.00210
# Epoch 79/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0063 - accuracy: 0.9972 - val_loss: 0.0068 - val_accuracy: 0.9973
#
# Epoch 00079: val_loss did not improve from 0.00210
# Epoch 80/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.0049 - val_accuracy: 0.9969
#
# Epoch 00080: val_loss did not improve from 0.00210
# Epoch 81/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0079 - accuracy: 0.9965 - val_loss: 0.0084 - val_accuracy: 0.9969
#
# Epoch 00081: val_loss did not improve from 0.00210
# Epoch 82/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00082: val_loss did not improve from 0.00210
# Epoch 83/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0078 - accuracy: 0.9966 - val_loss: 0.0052 - val_accuracy: 0.9984
#
# Epoch 00083: val_loss did not improve from 0.00210
# Epoch 84/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.0053 - val_accuracy: 0.9977
#
# Epoch 00084: val_loss did not improve from 0.00210
# Epoch 85/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.0058 - val_accuracy: 0.9973
#
# Epoch 00085: val_loss did not improve from 0.00210
# Epoch 86/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00210
# Epoch 87/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0099 - accuracy: 0.9961 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00210
# Epoch 88/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0083 - val_accuracy: 0.9969
#
# Epoch 00088: val_loss did not improve from 0.00210
# Epoch 89/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0055 - val_accuracy: 0.9969
#
# Epoch 00089: val_loss did not improve from 0.00210
# Epoch 90/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0114 - accuracy: 0.9950 - val_loss: 0.0052 - val_accuracy: 0.9969
#
# Epoch 00090: val_loss did not improve from 0.00210
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0073 - accuracy: 0.9967 - val_loss: 0.0038 - val_accuracy: 0.9977
#
# Epoch 00091: val_loss did not improve from 0.00210
# Epoch 92/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0059 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00210
# Epoch 93/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00093: val_loss did not improve from 0.00210
# Epoch 94/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0079 - accuracy: 0.9966 - val_loss: 0.0082 - val_accuracy: 0.9969
#
# Epoch 00094: val_loss did not improve from 0.00210
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00095: val_loss improved from 0.00210 to 0.00203, saving model to model.h5
# Epoch 96/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.0027 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00203
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0058 - accuracy: 0.9971 - val_loss: 0.0106 - val_accuracy: 0.9969
#
# Epoch 00097: val_loss did not improve from 0.00203
# Epoch 98/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0053 - accuracy: 0.9973 - val_loss: 0.0077 - val_accuracy: 0.9957
#
# Epoch 00098: val_loss did not improve from 0.00203
# Epoch 99/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.0027 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00203
# Epoch 100/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0085 - accuracy: 0.9965 - val_loss: 0.0054 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00203
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 0.9980
# Val Score:  [0.005448836833238602, 0.998046875]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 3s 6ms/step - loss: 0.5130 - accuracy: 0.8400 - val_loss: 1.1511 - val_accuracy: 0.5773
#
# Epoch 00001: val_loss did not improve from 0.00203
# Epoch 2/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.2549 - accuracy: 0.9042 - val_loss: 0.4408 - val_accuracy: 0.8320
#
# Epoch 00002: val_loss did not improve from 0.00203
# Epoch 3/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1944 - accuracy: 0.9286 - val_loss: 0.1408 - val_accuracy: 0.9461
#
# Epoch 00003: val_loss did not improve from 0.00203
# Epoch 4/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1550 - accuracy: 0.9417 - val_loss: 0.0930 - val_accuracy: 0.9711
#
# Epoch 00004: val_loss did not improve from 0.00203
# Epoch 5/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1345 - accuracy: 0.9506 - val_loss: 0.1042 - val_accuracy: 0.9668
#
# Epoch 00005: val_loss did not improve from 0.00203
# Epoch 6/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.1110 - accuracy: 0.9626 - val_loss: 0.0817 - val_accuracy: 0.9684
#
# Epoch 00006: val_loss did not improve from 0.00203
# Epoch 7/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.1008 - accuracy: 0.9652 - val_loss: 0.0585 - val_accuracy: 0.9770
#
# Epoch 00007: val_loss did not improve from 0.00203
# Epoch 8/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0914 - accuracy: 0.9667 - val_loss: 0.0794 - val_accuracy: 0.9691
#
# Epoch 00008: val_loss did not improve from 0.00203
# Epoch 9/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0819 - accuracy: 0.9715 - val_loss: 0.1032 - val_accuracy: 0.9613
#
# Epoch 00009: val_loss did not improve from 0.00203
# Epoch 10/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0762 - accuracy: 0.9729 - val_loss: 0.0881 - val_accuracy: 0.9656
#
# Epoch 00010: val_loss did not improve from 0.00203
# Epoch 11/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0701 - accuracy: 0.9767 - val_loss: 0.0323 - val_accuracy: 0.9906
#
# Epoch 00011: val_loss did not improve from 0.00203
# Epoch 12/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0632 - accuracy: 0.9781 - val_loss: 0.0275 - val_accuracy: 0.9898
#
# Epoch 00012: val_loss did not improve from 0.00203
# Epoch 13/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0541 - accuracy: 0.9823 - val_loss: 0.0387 - val_accuracy: 0.9867
#
# Epoch 00013: val_loss did not improve from 0.00203
# Epoch 14/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0498 - accuracy: 0.9820 - val_loss: 0.0509 - val_accuracy: 0.9848
#
# Epoch 00014: val_loss did not improve from 0.00203
# Epoch 15/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0454 - accuracy: 0.9849 - val_loss: 0.0287 - val_accuracy: 0.9906
#
# Epoch 00015: val_loss did not improve from 0.00203
# Epoch 16/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0466 - accuracy: 0.9847 - val_loss: 0.0352 - val_accuracy: 0.9906
#
# Epoch 00016: val_loss did not improve from 0.00203
# Epoch 17/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0441 - accuracy: 0.9856 - val_loss: 0.0444 - val_accuracy: 0.9863
#
# Epoch 00017: val_loss did not improve from 0.00203
# Epoch 18/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0377 - accuracy: 0.9858 - val_loss: 0.0605 - val_accuracy: 0.9840
#
# Epoch 00018: val_loss did not improve from 0.00203
# Epoch 19/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0361 - accuracy: 0.9872 - val_loss: 0.0144 - val_accuracy: 0.9953
#
# Epoch 00019: val_loss did not improve from 0.00203
# Epoch 20/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0330 - accuracy: 0.9891 - val_loss: 0.0295 - val_accuracy: 0.9898
#
# Epoch 00020: val_loss did not improve from 0.00203
# Epoch 21/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0353 - accuracy: 0.9872 - val_loss: 0.0141 - val_accuracy: 0.9941
#
# Epoch 00021: val_loss did not improve from 0.00203
# Epoch 22/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0297 - accuracy: 0.9902 - val_loss: 0.0349 - val_accuracy: 0.9875
#
# Epoch 00022: val_loss did not improve from 0.00203
# Epoch 23/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0280 - accuracy: 0.9896 - val_loss: 0.0236 - val_accuracy: 0.9910
#
# Epoch 00023: val_loss did not improve from 0.00203
# Epoch 24/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0304 - accuracy: 0.9890 - val_loss: 0.0148 - val_accuracy: 0.9945
#
# Epoch 00024: val_loss did not improve from 0.00203
# Epoch 25/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0277 - accuracy: 0.9897 - val_loss: 0.0104 - val_accuracy: 0.9949
#
# Epoch 00025: val_loss did not improve from 0.00203
# Epoch 26/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0235 - accuracy: 0.9922 - val_loss: 0.0242 - val_accuracy: 0.9922
#
# Epoch 00026: val_loss did not improve from 0.00203
# Epoch 27/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0217 - accuracy: 0.9917 - val_loss: 0.0131 - val_accuracy: 0.9953
#
# Epoch 00027: val_loss did not improve from 0.00203
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0218 - accuracy: 0.9927 - val_loss: 0.0094 - val_accuracy: 0.9957
#
# Epoch 00028: val_loss did not improve from 0.00203
# Epoch 29/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0219 - accuracy: 0.9919 - val_loss: 0.0908 - val_accuracy: 0.9734
#
# Epoch 00029: val_loss did not improve from 0.00203
# Epoch 30/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0265 - accuracy: 0.9900 - val_loss: 0.0135 - val_accuracy: 0.9949
#
# Epoch 00030: val_loss did not improve from 0.00203
# Epoch 31/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0176 - accuracy: 0.9936 - val_loss: 0.0117 - val_accuracy: 0.9965
#
# Epoch 00031: val_loss did not improve from 0.00203
# Epoch 32/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0230 - accuracy: 0.9915 - val_loss: 0.0094 - val_accuracy: 0.9965
#
# Epoch 00032: val_loss did not improve from 0.00203
# Epoch 33/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0074 - val_accuracy: 0.9961
#
# Epoch 00033: val_loss did not improve from 0.00203
# Epoch 34/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0178 - accuracy: 0.9929 - val_loss: 0.0331 - val_accuracy: 0.9875
#
# Epoch 00034: val_loss did not improve from 0.00203
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0198 - accuracy: 0.9930 - val_loss: 0.0096 - val_accuracy: 0.9961
#
# Epoch 00035: val_loss did not improve from 0.00203
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.0062 - val_accuracy: 0.9969
#
# Epoch 00036: val_loss did not improve from 0.00203
# Epoch 37/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0188 - accuracy: 0.9928 - val_loss: 0.0095 - val_accuracy: 0.9957
#
# Epoch 00037: val_loss did not improve from 0.00203
# Epoch 38/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 0.0084 - val_accuracy: 0.9977
#
# Epoch 00038: val_loss did not improve from 0.00203
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9936 - val_loss: 0.0220 - val_accuracy: 0.9914
#
# Epoch 00039: val_loss did not improve from 0.00203
# Epoch 40/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0142 - accuracy: 0.9945 - val_loss: 0.0051 - val_accuracy: 0.9969
#
# Epoch 00040: val_loss did not improve from 0.00203
# Epoch 41/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00200
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0435 - accuracy: 0.9850 - val_loss: 0.0441 - val_accuracy: 0.9848
#
# Epoch 00021: val_loss did not improve from 0.00200
# Epoch 22/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0410 - accuracy: 0.9862 - val_loss: 0.0225 - val_accuracy: 0.9898
#
# Epoch 00022: val_loss did not improve from 0.00200
# Epoch 23/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0411 - accuracy: 0.9853 - val_loss: 0.0641 - val_accuracy: 0.9758
#
# Epoch 00023: val_loss did not improve from 0.00200
# Epoch 24/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0343 - accuracy: 0.9871 - val_loss: 0.0648 - val_accuracy: 0.9797
#
# Epoch 00024: val_loss did not improve from 0.00200
# Epoch 25/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0404 - accuracy: 0.9880 - val_loss: 0.0182 - val_accuracy: 0.9934
#
# Epoch 00025: val_loss did not improve from 0.00200
# Epoch 26/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0309 - accuracy: 0.9885 - val_loss: 0.0636 - val_accuracy: 0.9770
#
# Epoch 00026: val_loss did not improve from 0.00200
# Epoch 27/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0304 - accuracy: 0.9896 - val_loss: 0.0599 - val_accuracy: 0.9793
#
# Epoch 00027: val_loss did not improve from 0.00200
# Epoch 28/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0286 - accuracy: 0.9901 - val_loss: 0.0231 - val_accuracy: 0.9922
#
# Epoch 00028: val_loss did not improve from 0.00200
# Epoch 29/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0265 - accuracy: 0.9902 - val_loss: 0.0555 - val_accuracy: 0.9836
#
# Epoch 00029: val_loss did not improve from 0.00200
# Epoch 30/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0254 - accuracy: 0.9910 - val_loss: 0.0515 - val_accuracy: 0.9840
#
# Epoch 00030: val_loss did not improve from 0.00200
# Epoch 31/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0270 - accuracy: 0.9919 - val_loss: 0.0340 - val_accuracy: 0.9891
#
# Epoch 00031: val_loss did not improve from 0.00200
# Epoch 32/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.0602 - val_accuracy: 0.9812
#
# Epoch 00032: val_loss did not improve from 0.00200
# Epoch 33/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0280 - accuracy: 0.9912 - val_loss: 0.0446 - val_accuracy: 0.9875
#
# Epoch 00033: val_loss did not improve from 0.00200
# Epoch 34/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0234 - accuracy: 0.9911 - val_loss: 0.0137 - val_accuracy: 0.9937
#
# Epoch 00034: val_loss did not improve from 0.00200
# Epoch 35/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0249 - accuracy: 0.9915 - val_loss: 0.0456 - val_accuracy: 0.9828
#
# Epoch 00035: val_loss did not improve from 0.00200
# Epoch 36/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.0172 - val_accuracy: 0.9945
#
# Epoch 00036: val_loss did not improve from 0.00200
# Epoch 37/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.0527 - val_accuracy: 0.9852
#
# Epoch 00037: val_loss did not improve from 0.00200
# Epoch 38/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0200 - accuracy: 0.9920 - val_loss: 0.0193 - val_accuracy: 0.9930
#
# Epoch 00038: val_loss did not improve from 0.00200
# Epoch 39/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.0145 - val_accuracy: 0.9949
#
# Epoch 00039: val_loss did not improve from 0.00200
# Epoch 40/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0190 - accuracy: 0.9931 - val_loss: 0.0186 - val_accuracy: 0.9937
#
# Epoch 00040: val_loss did not improve from 0.00200
# Epoch 41/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.0231 - val_accuracy: 0.9910
#
# Epoch 00041: val_loss did not improve from 0.00200
# Epoch 42/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0197 - accuracy: 0.9931 - val_loss: 0.0338 - val_accuracy: 0.9883
#
# Epoch 00042: val_loss did not improve from 0.00200
# Epoch 43/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0172 - accuracy: 0.9939 - val_loss: 0.0129 - val_accuracy: 0.9949
#
# Epoch 00043: val_loss did not improve from 0.00200
# Epoch 44/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.0125 - val_accuracy: 0.9953
#
# Epoch 00044: val_loss did not improve from 0.00200
# Epoch 45/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0174 - accuracy: 0.9937 - val_loss: 0.0249 - val_accuracy: 0.9922
#
# Epoch 00045: val_loss did not improve from 0.00200
# Epoch 46/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0172 - accuracy: 0.9936 - val_loss: 0.0116 - val_accuracy: 0.9965
#
# Epoch 00046: val_loss did not improve from 0.00200
# Epoch 47/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0163 - accuracy: 0.9932 - val_loss: 0.0072 - val_accuracy: 0.9969
#
# Epoch 00047: val_loss did not improve from 0.00200
# Epoch 48/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0147 - accuracy: 0.9949 - val_loss: 0.0135 - val_accuracy: 0.9953
#
# Epoch 00048: val_loss did not improve from 0.00200
# Epoch 49/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0161 - accuracy: 0.9938 - val_loss: 0.0107 - val_accuracy: 0.9949
#
# Epoch 00049: val_loss did not improve from 0.00200
# Epoch 50/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 0.0104 - val_accuracy: 0.9957
#
# Epoch 00050: val_loss did not improve from 0.00200
# Epoch 51/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.0079 - val_accuracy: 0.9969
#
# Epoch 00051: val_loss did not improve from 0.00200
# Epoch 52/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0046 - val_accuracy: 0.9984
#
# Epoch 00052: val_loss did not improve from 0.00200
# Epoch 53/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.0124 - val_accuracy: 0.9953
#
# Epoch 00053: val_loss did not improve from 0.00200
# Epoch 54/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00054: val_loss did not improve from 0.00200
# Epoch 55/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0179 - accuracy: 0.9929 - val_loss: 0.0070 - val_accuracy: 0.9969
#
# Epoch 00055: val_loss did not improve from 0.00200
# Epoch 56/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0172 - accuracy: 0.9934 - val_loss: 0.0071 - val_accuracy: 0.9969
#
# Epoch 00056: val_loss did not improve from 0.00200
# Epoch 57/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0127 - accuracy: 0.9955 - val_loss: 0.0067 - val_accuracy: 0.9977
#
# Epoch 00057: val_loss did not improve from 0.00200
# Epoch 58/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0147 - accuracy: 0.9940 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00200
# Epoch 59/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00059: val_loss did not improve from 0.00200
# Epoch 60/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9949 - val_loss: 0.0097 - val_accuracy: 0.9973
#
# Epoch 00060: val_loss did not improve from 0.00200
# Epoch 61/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0113 - accuracy: 0.9956 - val_loss: 0.0086 - val_accuracy: 0.9957
#
# Epoch 00061: val_loss did not improve from 0.00200
# Epoch 62/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00200
# Epoch 63/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0118 - accuracy: 0.9954 - val_loss: 0.0080 - val_accuracy: 0.9973
#
# Epoch 00063: val_loss did not improve from 0.00200
# Epoch 64/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00064: val_loss did not improve from 0.00200
# Epoch 65/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0114 - accuracy: 0.9952 - val_loss: 0.0086 - val_accuracy: 0.9973
#
# Epoch 00065: val_loss did not improve from 0.00200
# Epoch 66/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0198 - accuracy: 0.9920 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00066: val_loss did not improve from 0.00200
# Epoch 67/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.0080 - val_accuracy: 0.9953
#
# Epoch 00067: val_loss did not improve from 0.00200
# Epoch 68/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0118 - accuracy: 0.9951 - val_loss: 0.0085 - val_accuracy: 0.9965
#
# Epoch 00068: val_loss did not improve from 0.00200
# Epoch 69/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0074 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00200
# Epoch 70/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0127 - accuracy: 0.9953 - val_loss: 0.0052 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00200
# Epoch 71/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0107 - accuracy: 0.9956 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00071: val_loss did not improve from 0.00200
# Epoch 72/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0133 - accuracy: 0.9951 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00072: val_loss did not improve from 0.00200
# Epoch 73/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00200
# Epoch 74/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.0112 - val_accuracy: 0.9953
#
# Epoch 00074: val_loss did not improve from 0.00200
# Epoch 75/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0109 - accuracy: 0.9956 - val_loss: 0.0079 - val_accuracy: 0.9973
#
# Epoch 00075: val_loss did not improve from 0.00200
# Epoch 76/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00076: val_loss did not improve from 0.00200
# Epoch 77/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00077: val_loss did not improve from 0.00200
# Epoch 78/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0114 - val_accuracy: 0.9949
#
# Epoch 00078: val_loss did not improve from 0.00200
# Epoch 79/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0090 - accuracy: 0.9962 - val_loss: 0.0111 - val_accuracy: 0.9961
#
# Epoch 00079: val_loss did not improve from 0.00200
# Epoch 80/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0108 - accuracy: 0.9957 - val_loss: 0.0089 - val_accuracy: 0.9965
#
# Epoch 00080: val_loss did not improve from 0.00200
# Epoch 81/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00200
# Epoch 82/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 0.0057 - val_accuracy: 0.9977
#
# Epoch 00082: val_loss did not improve from 0.00200
# Epoch 83/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.0098 - val_accuracy: 0.9949
#
# Epoch 00083: val_loss did not improve from 0.00200
# Epoch 84/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0086 - accuracy: 0.9962 - val_loss: 0.0066 - val_accuracy: 0.9965
#
# Epoch 00084: val_loss did not improve from 0.00200
# Epoch 85/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0078 - accuracy: 0.9966 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00085: val_loss did not improve from 0.00200
# Epoch 86/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.0077 - val_accuracy: 0.9961
#
# Epoch 00086: val_loss did not improve from 0.00200
# Epoch 87/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0096 - accuracy: 0.9960 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00087: val_loss did not improve from 0.00200
# Epoch 88/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9953 - val_loss: 0.0033 - val_accuracy: 0.9977
#
# Epoch 00088: val_loss did not improve from 0.00200
# Epoch 89/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0062 - val_accuracy: 0.9969
#
# Epoch 00089: val_loss did not improve from 0.00200
# Epoch 90/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0046 - val_accuracy: 0.9977
#
# Epoch 00090: val_loss did not improve from 0.00200
# Epoch 91/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0097 - accuracy: 0.9957 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00200
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0097 - accuracy: 0.9955 - val_loss: 0.0084 - val_accuracy: 0.9973
#
# Epoch 00092: val_loss did not improve from 0.00200
# Epoch 93/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00093: val_loss did not improve from 0.00200
# Epoch 94/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.0054 - val_accuracy: 0.9973
#
# Epoch 00094: val_loss did not improve from 0.00200
# Epoch 95/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0087 - accuracy: 0.9962 - val_loss: 0.0051 - val_accuracy: 0.9969
#
# Epoch 00095: val_loss did not improve from 0.00200
# Epoch 96/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0104 - accuracy: 0.9957 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00200
# Epoch 97/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0102 - val_accuracy: 0.9953
#
# Epoch 00097: val_loss did not improve from 0.00200
# Epoch 98/100
# 320/320 [==============================] - 2s 6ms/step - loss: 0.0085 - accuracy: 0.9964 - val_loss: 0.0068 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00200
# Epoch 99/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.0056 - val_accuracy: 0.9973
#
# Epoch 00099: val_loss did not improve from 0.00200
# Epoch 100/100
# 320/320 [==============================] - 2s 5ms/step - loss: 0.0100 - accuracy: 0.9962 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00200
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.9980
# Val Score:  [0.004375376272946596, 0.998046875]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 0.9962
# Test Accuracy: 99.62499737739563

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
