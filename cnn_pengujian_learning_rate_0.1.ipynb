# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **LEARNING RATE TEST -- USING ADAM AND BEST RESULT OF HIDDEN LAYER(4)**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-1
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 2022-07-11 01:19:17.381884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:17.526449: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:17.527558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:17.529417: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-11 01:19:17.529778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:17.530863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:17.531878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:20.190696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:20.191766: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:20.192642: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 01:19:20.194425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# 2022-07-11 01:19:23.726233: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-07-11 01:19:25.835409: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 320/320 [==============================] - 12s 10ms/step - loss: 3.4432 - accuracy: 0.6786 - val_loss: 1.5631 - val_accuracy: 0.6305
#
# Epoch 00001: val_loss improved from inf to 1.56312, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.4868 - accuracy: 0.8421 - val_loss: 1.0200 - val_accuracy: 0.7816
#
# Epoch 00002: val_loss improved from 1.56312 to 1.02000, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.6250 - accuracy: 0.8306 - val_loss: 0.6822 - val_accuracy: 0.8004
#
# Epoch 00003: val_loss improved from 1.02000 to 0.68216, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.6268 - accuracy: 0.8532 - val_loss: 0.2329 - val_accuracy: 0.9328
#
# Epoch 00004: val_loss improved from 0.68216 to 0.23290, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.3030 - accuracy: 0.9075 - val_loss: 0.3533 - val_accuracy: 0.8977
#
# Epoch 00005: val_loss did not improve from 0.23290
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.2141 - accuracy: 0.9263 - val_loss: 0.3047 - val_accuracy: 0.9266
#
# Epoch 00006: val_loss did not improve from 0.23290
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1864 - accuracy: 0.9358 - val_loss: 0.4623 - val_accuracy: 0.8477
#
# Epoch 00007: val_loss did not improve from 0.23290
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1446 - accuracy: 0.9490 - val_loss: 0.1122 - val_accuracy: 0.9750
#
# Epoch 00008: val_loss improved from 0.23290 to 0.11220, saving model to model.h5
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1336 - accuracy: 0.9565 - val_loss: 0.1240 - val_accuracy: 0.9531
#
# Epoch 00009: val_loss did not improve from 0.11220
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1182 - accuracy: 0.9620 - val_loss: 0.1120 - val_accuracy: 0.9852
#
# Epoch 00010: val_loss improved from 0.11220 to 0.11201, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.1038 - accuracy: 0.9644 - val_loss: 0.0949 - val_accuracy: 0.9754
#
# Epoch 00011: val_loss improved from 0.11201 to 0.09487, saving model to model.h5
# Epoch 12/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0834 - accuracy: 0.9706 - val_loss: 2.1531 - val_accuracy: 0.8852
#
# Epoch 00012: val_loss did not improve from 0.09487
# Epoch 13/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0799 - accuracy: 0.9737 - val_loss: 0.7013 - val_accuracy: 0.8992
#
# Epoch 00013: val_loss did not improve from 0.09487
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0885 - accuracy: 0.9733 - val_loss: 0.1535 - val_accuracy: 0.9328
#
# Epoch 00014: val_loss did not improve from 0.09487
# Epoch 15/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0954 - accuracy: 0.9722 - val_loss: 0.6953 - val_accuracy: 0.9770
#
# Epoch 00015: val_loss did not improve from 0.09487
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1100 - accuracy: 0.9677 - val_loss: 0.1592 - val_accuracy: 0.9629
#
# Epoch 00016: val_loss did not improve from 0.09487
# Epoch 17/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.1037 - accuracy: 0.9707 - val_loss: 0.1223 - val_accuracy: 0.9613
#
# Epoch 00017: val_loss did not improve from 0.09487
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1270 - accuracy: 0.9655 - val_loss: 10.9112 - val_accuracy: 0.9289
#
# Epoch 00018: val_loss did not improve from 0.09487
# Epoch 19/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1068 - accuracy: 0.9707 - val_loss: 0.2027 - val_accuracy: 0.9484
#
# Epoch 00019: val_loss did not improve from 0.09487
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0794 - accuracy: 0.9795 - val_loss: 0.0414 - val_accuracy: 0.9852
#
# Epoch 00020: val_loss improved from 0.09487 to 0.04138, saving model to model.h5
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0725 - accuracy: 0.9780 - val_loss: 0.2841 - val_accuracy: 0.9230
#
# Epoch 00021: val_loss did not improve from 0.04138
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0674 - accuracy: 0.9799 - val_loss: 5.0158 - val_accuracy: 0.9875
#
# Epoch 00022: val_loss did not improve from 0.04138
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0380 - accuracy: 0.9877 - val_loss: 0.0138 - val_accuracy: 0.9973
#
# Epoch 00023: val_loss improved from 0.04138 to 0.01382, saving model to model.h5
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0474 - accuracy: 0.9867 - val_loss: 0.2194 - val_accuracy: 0.9953
#
# Epoch 00024: val_loss did not improve from 0.01382
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0446 - accuracy: 0.9866 - val_loss: 0.0095 - val_accuracy: 0.9973
#
# Epoch 00025: val_loss improved from 0.01382 to 0.00954, saving model to model.h5
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0503 - accuracy: 0.9863 - val_loss: 0.1155 - val_accuracy: 0.9934
#
# Epoch 00026: val_loss did not improve from 0.00954
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0374 - accuracy: 0.9887 - val_loss: 0.0456 - val_accuracy: 0.9883
#
# Epoch 00027: val_loss did not improve from 0.00954
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0413 - accuracy: 0.9884 - val_loss: 0.2209 - val_accuracy: 0.9922
#
# Epoch 00028: val_loss did not improve from 0.00954
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0683 - accuracy: 0.9835 - val_loss: 29.6337 - val_accuracy: 0.9820
#
# Epoch 00029: val_loss did not improve from 0.00954
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0530 - accuracy: 0.9875 - val_loss: 0.6296 - val_accuracy: 0.9480
#
# Epoch 00030: val_loss did not improve from 0.00954
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0619 - accuracy: 0.9850 - val_loss: 0.0236 - val_accuracy: 0.9937
#
# Epoch 00031: val_loss did not improve from 0.00954
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0485 - accuracy: 0.9881 - val_loss: 1.4956 - val_accuracy: 0.9727
#
# Epoch 00032: val_loss did not improve from 0.00954
# Epoch 33/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0458 - accuracy: 0.9879 - val_loss: 1.3378 - val_accuracy: 0.9937
#
# Epoch 00033: val_loss did not improve from 0.00954
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0457 - accuracy: 0.9876 - val_loss: 3.4888 - val_accuracy: 0.9898
#
# Epoch 00034: val_loss did not improve from 0.00954
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0290 - accuracy: 0.9923 - val_loss: 0.0143 - val_accuracy: 0.9969
#
# Epoch 00035: val_loss did not improve from 0.00954
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0249 - accuracy: 0.9925 - val_loss: 0.0054 - val_accuracy: 0.9980
#
# Epoch 00036: val_loss improved from 0.00954 to 0.00541, saving model to model.h5
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0309 - accuracy: 0.9910 - val_loss: 0.0136 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss did not improve from 0.00541
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0200 - accuracy: 0.9935 - val_loss: 0.0334 - val_accuracy: 0.9926
#
# Epoch 00038: val_loss did not improve from 0.00541
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0277 - accuracy: 0.9920 - val_loss: 0.1182 - val_accuracy: 0.9699
#
# Epoch 00039: val_loss did not improve from 0.00541
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0344 - accuracy: 0.9912 - val_loss: 0.0181 - val_accuracy: 0.9969
#
# Epoch 00040: val_loss did not improve from 0.00541
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0241 - accuracy: 0.9934 - val_loss: 1.6247 - val_accuracy: 0.9871
#
# Epoch 00041: val_loss did not improve from 0.00541
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0197 - accuracy: 0.9944 - val_loss: 2.0451 - val_accuracy: 0.9828
#
# Epoch 00042: val_loss did not improve from 0.00541
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0234 - accuracy: 0.9922 - val_loss: 0.0110 - val_accuracy: 0.9965
#
# Epoch 00043: val_loss did not improve from 0.00541
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0318 - accuracy: 0.9924 - val_loss: 0.0248 - val_accuracy: 0.9969
#
# Epoch 00044: val_loss did not improve from 0.00541
# Epoch 45/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0246 - accuracy: 0.9936 - val_loss: 0.0238 - val_accuracy: 0.9969
#
# Epoch 00045: val_loss did not improve from 0.00541
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0272 - accuracy: 0.9921 - val_loss: 3.1103 - val_accuracy: 0.9391
#
# Epoch 00046: val_loss did not improve from 0.00541
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.0167 - val_accuracy: 0.9957
#
# Epoch 00047: val_loss did not improve from 0.00541
# Epoch 48/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0216 - accuracy: 0.9938 - val_loss: 0.0225 - val_accuracy: 0.9930
#
# Epoch 00048: val_loss did not improve from 0.00541
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0196 - accuracy: 0.9944 - val_loss: 24.3028 - val_accuracy: 0.9785
#
# Epoch 00049: val_loss did not improve from 0.00541
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0339 - accuracy: 0.9907 - val_loss: 0.9554 - val_accuracy: 0.9934
#
# Epoch 00050: val_loss did not improve from 0.00541
# Epoch 51/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0313 - accuracy: 0.9918 - val_loss: 0.7398 - val_accuracy: 0.9781
#
# Epoch 00051: val_loss did not improve from 0.00541
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 29.1326 - val_accuracy: 0.9883
#
# Epoch 00052: val_loss did not improve from 0.00541
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9955 - val_loss: 1.3005 - val_accuracy: 0.9949
#
# Epoch 00053: val_loss did not improve from 0.00541
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.0074 - val_accuracy: 0.9973
#
# Epoch 00054: val_loss did not improve from 0.00541
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.0073 - val_accuracy: 0.9977
#
# Epoch 00055: val_loss did not improve from 0.00541
# Epoch 56/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0188 - accuracy: 0.9939 - val_loss: 0.0183 - val_accuracy: 0.9961
#
# Epoch 00056: val_loss did not improve from 0.00541
# Epoch 57/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.0322 - val_accuracy: 0.9961
#
# Epoch 00057: val_loss did not improve from 0.00541
# Epoch 58/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0216 - accuracy: 0.9934 - val_loss: 53.8845 - val_accuracy: 0.9875
#
# Epoch 00058: val_loss did not improve from 0.00541
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0205 - accuracy: 0.9944 - val_loss: 0.0102 - val_accuracy: 0.9969
#
# Epoch 00059: val_loss did not improve from 0.00541
# Epoch 60/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0183 - accuracy: 0.9947 - val_loss: 0.0298 - val_accuracy: 0.9961
#
# Epoch 00060: val_loss did not improve from 0.00541
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0137 - accuracy: 0.9957 - val_loss: 0.0145 - val_accuracy: 0.9969
#
# Epoch 00061: val_loss did not improve from 0.00541
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0188 - accuracy: 0.9942 - val_loss: 0.0156 - val_accuracy: 0.9953
#
# Epoch 00062: val_loss did not improve from 0.00541
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 3.5149 - val_accuracy: 0.9934
#
# Epoch 00063: val_loss did not improve from 0.00541
# Epoch 64/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0115 - accuracy: 0.9959 - val_loss: 0.6659 - val_accuracy: 0.9941
#
# Epoch 00064: val_loss did not improve from 0.00541
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 19.4511 - val_accuracy: 0.9906
#
# Epoch 00065: val_loss did not improve from 0.00541
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 6.0447 - val_accuracy: 0.9934
#
# Epoch 00066: val_loss did not improve from 0.00541
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 2.4891 - val_accuracy: 0.9922
#
# Epoch 00067: val_loss did not improve from 0.00541
# Epoch 68/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 31.4397 - val_accuracy: 0.9879
#
# Epoch 00068: val_loss did not improve from 0.00541
# Epoch 69/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 1.6618 - val_accuracy: 0.9953
#
# Epoch 00069: val_loss did not improve from 0.00541
# Epoch 70/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 31.9439 - val_accuracy: 0.9887
#
# Epoch 00070: val_loss did not improve from 0.00541
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0135 - accuracy: 0.9953 - val_loss: 0.5762 - val_accuracy: 0.9969
#
# Epoch 00071: val_loss did not improve from 0.00541
# Epoch 72/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.0348 - val_accuracy: 0.9973
#
# Epoch 00072: val_loss did not improve from 0.00541
# Epoch 73/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00073: val_loss did not improve from 0.00541
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 19.6748 - val_accuracy: 0.9602
#
# Epoch 00074: val_loss did not improve from 0.00541
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0119 - accuracy: 0.9968 - val_loss: 0.0076 - val_accuracy: 0.9980
#
# Epoch 00075: val_loss did not improve from 0.00541
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0141 - accuracy: 0.9961 - val_loss: 9.6658 - val_accuracy: 0.9945
#
# Epoch 00076: val_loss did not improve from 0.00541
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.1476 - val_accuracy: 0.9969
#
# Epoch 00077: val_loss did not improve from 0.00541
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 3334.5083 - val_accuracy: 0.9910
#
# Epoch 00078: val_loss did not improve from 0.00541
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.8799 - val_accuracy: 0.9961
#
# Epoch 00079: val_loss did not improve from 0.00541
# Epoch 80/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0378 - val_accuracy: 0.9930
#
# Epoch 00080: val_loss did not improve from 0.00541
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.1068 - val_accuracy: 0.9965
#
# Epoch 00081: val_loss did not improve from 0.00541
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0120 - val_accuracy: 0.9973
#
# Epoch 00082: val_loss did not improve from 0.00541
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00083: val_loss did not improve from 0.00541
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 7.6485 - val_accuracy: 0.9949
#
# Epoch 00084: val_loss did not improve from 0.00541
# Epoch 85/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0105 - val_accuracy: 0.9977
#
# Epoch 00085: val_loss did not improve from 0.00541
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9956 - val_loss: 0.0073 - val_accuracy: 0.9973
#
# Epoch 00086: val_loss did not improve from 0.00541
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.0086 - val_accuracy: 0.9973
#
# Epoch 00087: val_loss did not improve from 0.00541
# Epoch 88/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0684 - val_accuracy: 0.9945
#
# Epoch 00088: val_loss did not improve from 0.00541
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9964 - val_loss: 0.2264 - val_accuracy: 0.9969
#
# Epoch 00089: val_loss did not improve from 0.00541
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0112 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00541
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0127 - val_accuracy: 0.9973
#
# Epoch 00091: val_loss did not improve from 0.00541
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0169 - val_accuracy: 0.9973
#
# Epoch 00092: val_loss did not improve from 0.00541
# Epoch 93/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0107 - val_accuracy: 0.9973
#
# Epoch 00093: val_loss did not improve from 0.00541
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00541
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 4.7683 - val_accuracy: 0.9930
#
# Epoch 00095: val_loss did not improve from 0.00541
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.0126 - val_accuracy: 0.9973
#
# Epoch 00096: val_loss did not improve from 0.00541
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00097: val_loss improved from 0.00541 to 0.00309, saving model to model.h5
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0063 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00309
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0034 - val_accuracy: 0.9977
#
# Epoch 00099: val_loss did not improve from 0.00309
# Epoch 100/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.1230 - val_accuracy: 0.9969
#
# Epoch 00100: val_loss did not improve from 0.00309
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1230 - accuracy: 0.9969
# Val Score:  [0.12299581617116928, 0.996874988079071]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.8281 - accuracy: 0.7992 - val_loss: 1.6673 - val_accuracy: 0.6168
#
# Epoch 00001: val_loss did not improve from 0.00309
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2977 - accuracy: 0.9061 - val_loss: 3.3738 - val_accuracy: 0.5363
#
# Epoch 00002: val_loss did not improve from 0.00309
# Epoch 3/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1691 - accuracy: 0.9434 - val_loss: 0.3540 - val_accuracy: 0.9012
#
# Epoch 00003: val_loss did not improve from 0.00309
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1090 - accuracy: 0.9633 - val_loss: 0.0744 - val_accuracy: 0.9754
#
# Epoch 00004: val_loss did not improve from 0.00309
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1021 - accuracy: 0.9657 - val_loss: 1.1255 - val_accuracy: 0.7430
#
# Epoch 00005: val_loss did not improve from 0.00309
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0830 - accuracy: 0.9722 - val_loss: 0.0229 - val_accuracy: 0.9922
#
# Epoch 00006: val_loss did not improve from 0.00309
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0701 - accuracy: 0.9756 - val_loss: 0.4818 - val_accuracy: 0.8566
#
# Epoch 00007: val_loss did not improve from 0.00309
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0489 - accuracy: 0.9817 - val_loss: 0.2470 - val_accuracy: 0.9375
#
# Epoch 00008: val_loss did not improve from 0.00309
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0605 - accuracy: 0.9791 - val_loss: 0.0263 - val_accuracy: 0.9910
#
# Epoch 00009: val_loss did not improve from 0.00309
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0438 - accuracy: 0.9847 - val_loss: 0.2120 - val_accuracy: 0.9305
#
# Epoch 00010: val_loss did not improve from 0.00309
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0807 - accuracy: 0.9764 - val_loss: 0.1686 - val_accuracy: 0.9547
#
# Epoch 00011: val_loss did not improve from 0.00309
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0447 - accuracy: 0.9862 - val_loss: 0.2561 - val_accuracy: 0.9516
#
# Epoch 00012: val_loss did not improve from 0.00309
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0347 - accuracy: 0.9879 - val_loss: 0.3913 - val_accuracy: 0.9277
#
# Epoch 00013: val_loss did not improve from 0.00309
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0469 - accuracy: 0.9867 - val_loss: 8.5739 - val_accuracy: 0.6117
#
# Epoch 00014: val_loss did not improve from 0.00309
# Epoch 15/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0603 - accuracy: 0.9818 - val_loss: 0.0399 - val_accuracy: 0.9914
#
# Epoch 00015: val_loss did not improve from 0.00309
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0588 - accuracy: 0.9832 - val_loss: 0.1511 - val_accuracy: 0.9625
#
# Epoch 00016: val_loss did not improve from 0.00309
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0409 - accuracy: 0.9866 - val_loss: 0.3733 - val_accuracy: 0.9234
#
# Epoch 00017: val_loss did not improve from 0.00309
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0306 - accuracy: 0.9908 - val_loss: 0.7922 - val_accuracy: 0.8699
#
# Epoch 00018: val_loss did not improve from 0.00309
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0275 - accuracy: 0.9919 - val_loss: 0.1431 - val_accuracy: 0.9723
#
# Epoch 00019: val_loss did not improve from 0.00309
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0355 - accuracy: 0.9894 - val_loss: 0.0482 - val_accuracy: 0.9918
#
# Epoch 00020: val_loss did not improve from 0.00309
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0569 - accuracy: 0.9841 - val_loss: 0.2211 - val_accuracy: 0.9582
#
# Epoch 00021: val_loss did not improve from 0.00309
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0347 - accuracy: 0.9897 - val_loss: 0.0492 - val_accuracy: 0.9934
#
# Epoch 00022: val_loss did not improve from 0.00309
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0857 - accuracy: 0.9805 - val_loss: 0.0385 - val_accuracy: 0.9891
#
# Epoch 00023: val_loss did not improve from 0.00309
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0409 - accuracy: 0.9885 - val_loss: 0.0062 - val_accuracy: 0.9980
#
# Epoch 00024: val_loss did not improve from 0.00309
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0211 - accuracy: 0.9935 - val_loss: 0.0571 - val_accuracy: 0.9797
#
# Epoch 00025: val_loss did not improve from 0.00309
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0239 - accuracy: 0.9923 - val_loss: 0.0194 - val_accuracy: 0.9926
#
# Epoch 00026: val_loss did not improve from 0.00309
# Epoch 27/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.0643 - val_accuracy: 0.9848
#
# Epoch 00027: val_loss did not improve from 0.00309
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0119 - accuracy: 0.9947 - val_loss: 0.1026 - val_accuracy: 0.9746
#
# Epoch 00028: val_loss did not improve from 0.00309
# Epoch 29/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0291 - accuracy: 0.9923 - val_loss: 0.0278 - val_accuracy: 0.9965
#
# Epoch 00029: val_loss did not improve from 0.00309
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0237 - accuracy: 0.9929 - val_loss: 0.1874 - val_accuracy: 0.9480
#
# Epoch 00030: val_loss did not improve from 0.00309
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0309 - accuracy: 0.9915 - val_loss: 3.2221 - val_accuracy: 0.6695
#
# Epoch 00031: val_loss did not improve from 0.00309
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0270 - accuracy: 0.9934 - val_loss: 0.0344 - val_accuracy: 0.9965
#
# Epoch 00032: val_loss did not improve from 0.00309
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0207 - accuracy: 0.9939 - val_loss: 0.2096 - val_accuracy: 0.9328
#
# Epoch 00033: val_loss did not improve from 0.00309
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0140 - accuracy: 0.9949 - val_loss: 0.0939 - val_accuracy: 0.9766
#
# Epoch 00034: val_loss did not improve from 0.00309
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0260 - accuracy: 0.9927 - val_loss: 0.0317 - val_accuracy: 0.9926
#
# Epoch 00035: val_loss did not improve from 0.00309
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0240 - accuracy: 0.9927 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00036: val_loss did not improve from 0.00309
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0314 - accuracy: 0.9914 - val_loss: 0.6787 - val_accuracy: 0.8594
#
# Epoch 00037: val_loss did not improve from 0.00309
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 0.0167 - val_accuracy: 0.9969
#
# Epoch 00038: val_loss did not improve from 0.00309
# Epoch 39/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0223 - accuracy: 0.9942 - val_loss: 0.0201 - val_accuracy: 0.9930
#
# Epoch 00039: val_loss did not improve from 0.00309
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.0604 - val_accuracy: 0.9809
#
# Epoch 00040: val_loss did not improve from 0.00309
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.0335 - val_accuracy: 0.9957
#
# Epoch 00041: val_loss did not improve from 0.00309
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0153 - accuracy: 0.9954 - val_loss: 0.0890 - val_accuracy: 0.9789
#
# Epoch 00042: val_loss did not improve from 0.00309
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0209 - accuracy: 0.9933 - val_loss: 0.6618 - val_accuracy: 0.9152
#
# Epoch 00043: val_loss did not improve from 0.00309
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.0539 - val_accuracy: 0.9867
#
# Epoch 00044: val_loss did not improve from 0.00309
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.0169 - val_accuracy: 0.9957
#
# Epoch 00045: val_loss did not improve from 0.00309
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0238 - accuracy: 0.9941 - val_loss: 0.0387 - val_accuracy: 0.9930
#
# Epoch 00046: val_loss did not improve from 0.00309
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0194 - accuracy: 0.9941 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00047: val_loss did not improve from 0.00309
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 0.0849 - val_accuracy: 0.9852
#
# Epoch 00048: val_loss did not improve from 0.00309
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0166 - accuracy: 0.9947 - val_loss: 0.1575 - val_accuracy: 0.9684
#
# Epoch 00049: val_loss did not improve from 0.00309
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.2255 - val_accuracy: 0.9500
#
# Epoch 00050: val_loss did not improve from 0.00309
# Epoch 51/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.0370 - val_accuracy: 0.9922
#
# Epoch 00051: val_loss did not improve from 0.00309
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0201 - accuracy: 0.9948 - val_loss: 0.0580 - val_accuracy: 0.9871
#
# Epoch 00052: val_loss did not improve from 0.00309
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.0082 - val_accuracy: 0.9977
#
# Epoch 00053: val_loss did not improve from 0.00309
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.0239 - val_accuracy: 0.9953
#
# Epoch 00054: val_loss did not improve from 0.00309
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.0342 - val_accuracy: 0.9953
#
# Epoch 00055: val_loss did not improve from 0.00309
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0163 - accuracy: 0.9952 - val_loss: 1.2232 - val_accuracy: 0.8297
#
# Epoch 00056: val_loss did not improve from 0.00309
# Epoch 57/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0312 - accuracy: 0.9933 - val_loss: 0.0973 - val_accuracy: 0.9770
#
# Epoch 00057: val_loss did not improve from 0.00309
# Epoch 58/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.0081 - val_accuracy: 0.9977
#
# Epoch 00058: val_loss did not improve from 0.00309
# Epoch 59/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0110 - val_accuracy: 0.9977
#
# Epoch 00059: val_loss did not improve from 0.00309
# Epoch 60/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.0136 - val_accuracy: 0.9965
#
# Epoch 00060: val_loss did not improve from 0.00309
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0190 - accuracy: 0.9945 - val_loss: 0.0345 - val_accuracy: 0.9937
#
# Epoch 00061: val_loss did not improve from 0.00309
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.0102 - val_accuracy: 0.9969
#
# Epoch 00062: val_loss did not improve from 0.00309
# Epoch 63/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0189 - val_accuracy: 0.9945
#
# Epoch 00063: val_loss did not improve from 0.00309
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0202 - accuracy: 0.9946 - val_loss: 0.0136 - val_accuracy: 0.9984
#
# Epoch 00064: val_loss did not improve from 0.00309
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0840 - val_accuracy: 0.9836
#
# Epoch 00065: val_loss did not improve from 0.00309
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0156 - accuracy: 0.9946 - val_loss: 0.0461 - val_accuracy: 0.9914
#
# Epoch 00066: val_loss did not improve from 0.00309
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00067: val_loss did not improve from 0.00309
# Epoch 68/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 0.0190 - val_accuracy: 0.9969
#
# Epoch 00068: val_loss did not improve from 0.00309
# Epoch 69/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0170 - val_accuracy: 0.9953
#
# Epoch 00069: val_loss did not improve from 0.00309
# Epoch 70/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.2104 - val_accuracy: 0.9582
#
# Epoch 00070: val_loss did not improve from 0.00309
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0375 - val_accuracy: 0.9891
#
# Epoch 00071: val_loss did not improve from 0.00309
# Epoch 72/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0082 - val_accuracy: 0.9980
#
# Epoch 00072: val_loss did not improve from 0.00309
# Epoch 73/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0105 - accuracy: 0.9959 - val_loss: 0.0522 - val_accuracy: 0.9844
#
# Epoch 00073: val_loss did not improve from 0.00309
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.3238 - val_accuracy: 0.9316
#
# Epoch 00074: val_loss did not improve from 0.00309
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00309
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0379 - val_accuracy: 0.9891
#
# Epoch 00076: val_loss did not improve from 0.00309
# Epoch 77/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 0.0074 - val_accuracy: 0.9980
#
# Epoch 00077: val_loss did not improve from 0.00309
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0091 - val_accuracy: 0.9984
#
# Epoch 00078: val_loss did not improve from 0.00309
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0111 - val_accuracy: 0.9973
#
# Epoch 00079: val_loss did not improve from 0.00309
# Epoch 80/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 5.0743 - val_accuracy: 0.7312
#
# Epoch 00080: val_loss did not improve from 0.00309
# Epoch 81/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0142 - accuracy: 0.9958 - val_loss: 0.0201 - val_accuracy: 0.9961
#
# Epoch 00081: val_loss did not improve from 0.00309
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0161 - val_accuracy: 0.9980
#
# Epoch 00082: val_loss did not improve from 0.00309
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0154 - val_accuracy: 0.9984
#
# Epoch 00083: val_loss did not improve from 0.00309
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0093 - val_accuracy: 0.9980
#
# Epoch 00084: val_loss did not improve from 0.00309
# Epoch 85/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0042 - val_accuracy: 0.9984
#
# Epoch 00085: val_loss did not improve from 0.00309
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 1.0332 - val_accuracy: 0.8613
#
# Epoch 00086: val_loss did not improve from 0.00309
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9962 - val_loss: 0.0428 - val_accuracy: 0.9969
#
# Epoch 00087: val_loss did not improve from 0.00309
# Epoch 88/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.1091 - val_accuracy: 0.9746
#
# Epoch 00088: val_loss did not improve from 0.00309
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0074 - accuracy: 0.9967 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00089: val_loss did not improve from 0.00309
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0073 - val_accuracy: 0.9969
#
# Epoch 00090: val_loss did not improve from 0.00309
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.0253 - val_accuracy: 0.9937
#
# Epoch 00091: val_loss did not improve from 0.00309
# Epoch 92/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.0069 - val_accuracy: 0.9973
#
# Epoch 00092: val_loss did not improve from 0.00309
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0130 - accuracy: 0.9965 - val_loss: 0.0136 - val_accuracy: 0.9973
#
# Epoch 00093: val_loss did not improve from 0.00309
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0192 - val_accuracy: 0.9961
#
# Epoch 00094: val_loss did not improve from 0.00309
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 0.1007 - val_accuracy: 0.9805
#
# Epoch 00095: val_loss did not improve from 0.00309
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0028 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss improved from 0.00309 to 0.00277, saving model to model.h5
# Epoch 97/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0068 - val_accuracy: 0.9977
#
# Epoch 00097: val_loss did not improve from 0.00277
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9963 - val_loss: 0.0129 - val_accuracy: 0.9980
#
# Epoch 00098: val_loss did not improve from 0.00277
# Epoch 99/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0373 - val_accuracy: 0.9949
#
# Epoch 00099: val_loss did not improve from 0.00277
# Epoch 100/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0315 - val_accuracy: 0.9937
#
# Epoch 00100: val_loss did not improve from 0.00277
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9937
# Val Score:  [0.031546853482723236, 0.9937499761581421]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.5922 - accuracy: 0.8175 - val_loss: 0.8864 - val_accuracy: 0.6320
#
# Epoch 00001: val_loss did not improve from 0.00277
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2619 - accuracy: 0.9108 - val_loss: 0.6254 - val_accuracy: 0.7652
#
# Epoch 00002: val_loss did not improve from 0.00277
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1693 - accuracy: 0.9377 - val_loss: 0.0837 - val_accuracy: 0.9629
#
# Epoch 00003: val_loss did not improve from 0.00277
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1090 - accuracy: 0.9618 - val_loss: 0.0431 - val_accuracy: 0.9883
#
# Epoch 00004: val_loss did not improve from 0.00277
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0951 - accuracy: 0.9679 - val_loss: 0.0494 - val_accuracy: 0.9789
#
# Epoch 00005: val_loss did not improve from 0.00277
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0836 - accuracy: 0.9723 - val_loss: 0.2498 - val_accuracy: 0.9109
#
# Epoch 00006: val_loss did not improve from 0.00277
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0603 - accuracy: 0.9796 - val_loss: 0.1149 - val_accuracy: 0.9625
#
# Epoch 00007: val_loss did not improve from 0.00277
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0611 - accuracy: 0.9808 - val_loss: 0.3397 - val_accuracy: 0.9012
#
# Epoch 00008: val_loss did not improve from 0.00277
# Epoch 9/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0582 - accuracy: 0.9798 - val_loss: 0.7905 - val_accuracy: 0.8156
#
# Epoch 00009: val_loss did not improve from 0.00277
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0501 - accuracy: 0.9830 - val_loss: 0.4170 - val_accuracy: 0.9012
#
# Epoch 00010: val_loss did not improve from 0.00277
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0444 - accuracy: 0.9849 - val_loss: 0.0097 - val_accuracy: 0.9969
#
# Epoch 00011: val_loss did not improve from 0.00277
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0508 - accuracy: 0.9830 - val_loss: 0.4389 - val_accuracy: 0.9047
#
# Epoch 00012: val_loss did not improve from 0.00277
# Epoch 13/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0377 - accuracy: 0.9876 - val_loss: 0.4256 - val_accuracy: 0.9086
#
# Epoch 00013: val_loss did not improve from 0.00277
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0440 - accuracy: 0.9865 - val_loss: 0.2302 - val_accuracy: 0.9262
#
# Epoch 00014: val_loss did not improve from 0.00277
# Epoch 15/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0353 - accuracy: 0.9881 - val_loss: 0.0076 - val_accuracy: 0.9977
#
# Epoch 00015: val_loss did not improve from 0.00277
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0405 - accuracy: 0.9868 - val_loss: 0.2930 - val_accuracy: 0.9223
#
# Epoch 00016: val_loss did not improve from 0.00277
# Epoch 17/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0258 - accuracy: 0.9918 - val_loss: 0.0461 - val_accuracy: 0.9898
#
# Epoch 00017: val_loss did not improve from 0.00277
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0309 - accuracy: 0.9896 - val_loss: 0.2028 - val_accuracy: 0.9395
#
# Epoch 00018: val_loss did not improve from 0.00277
# Epoch 19/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0408 - accuracy: 0.9862 - val_loss: 0.4668 - val_accuracy: 0.8961
#
# Epoch 00019: val_loss did not improve from 0.00277
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0346 - accuracy: 0.9900 - val_loss: 0.0151 - val_accuracy: 0.9941
#
# Epoch 00020: val_loss did not improve from 0.00277
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0460 - accuracy: 0.9861 - val_loss: 0.0383 - val_accuracy: 0.9898
#
# Epoch 00021: val_loss did not improve from 0.00277
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0356 - accuracy: 0.9890 - val_loss: 0.2262 - val_accuracy: 0.9488
#
# Epoch 00022: val_loss did not improve from 0.00277
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0303 - accuracy: 0.9903 - val_loss: 0.2980 - val_accuracy: 0.9176
#
# Epoch 00023: val_loss did not improve from 0.00277
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0340 - accuracy: 0.9896 - val_loss: 0.0191 - val_accuracy: 0.9957
#
# Epoch 00024: val_loss did not improve from 0.00277
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0293 - accuracy: 0.9914 - val_loss: 0.0123 - val_accuracy: 0.9961
#
# Epoch 00025: val_loss did not improve from 0.00277
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0294 - accuracy: 0.9897 - val_loss: 0.0152 - val_accuracy: 0.9965
#
# Epoch 00026: val_loss did not improve from 0.00277
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.1342 - val_accuracy: 0.9625
#
# Epoch 00027: val_loss did not improve from 0.00277
# Epoch 28/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.1592 - val_accuracy: 0.9602
#
# Epoch 00028: val_loss did not improve from 0.00277
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0485 - accuracy: 0.9877 - val_loss: 0.0822 - val_accuracy: 0.9816
#
# Epoch 00029: val_loss did not improve from 0.00277
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0320 - accuracy: 0.9908 - val_loss: 0.0091 - val_accuracy: 0.9969
#
# Epoch 00030: val_loss did not improve from 0.00277
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0262 - accuracy: 0.9914 - val_loss: 0.1865 - val_accuracy: 0.9582
#
# Epoch 00031: val_loss did not improve from 0.00277
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0199 - accuracy: 0.9941 - val_loss: 0.0126 - val_accuracy: 0.9941
#
# Epoch 00032: val_loss did not improve from 0.00277
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0133 - accuracy: 0.9951 - val_loss: 0.0204 - val_accuracy: 0.9941
#
# Epoch 00033: val_loss did not improve from 0.00277
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.0336 - val_accuracy: 0.9867
#
# Epoch 00034: val_loss did not improve from 0.00277
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0257 - accuracy: 0.9930 - val_loss: 0.0161 - val_accuracy: 0.9965
#
# Epoch 00035: val_loss did not improve from 0.00277
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0171 - accuracy: 0.9939 - val_loss: 0.0664 - val_accuracy: 0.9816
#
# Epoch 00036: val_loss did not improve from 0.00277
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0214 - accuracy: 0.9930 - val_loss: 0.1008 - val_accuracy: 0.9805
#
# Epoch 00037: val_loss did not improve from 0.00277
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.1212 - val_accuracy: 0.9723
#
# Epoch 00038: val_loss did not improve from 0.00277
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00039: val_loss did not improve from 0.00277
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0122 - accuracy: 0.9953 - val_loss: 0.0563 - val_accuracy: 0.9895
#
# ...
#
# Epoch 00020: val_loss did not improve from 0.00195
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0299 - accuracy: 0.9903 - val_loss: 0.4637 - val_accuracy: 0.9148
#
# Epoch 00021: val_loss did not improve from 0.00195
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.0183 - val_accuracy: 0.9941
#
# Epoch 00022: val_loss did not improve from 0.00195
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.0039 - val_accuracy: 0.9984
#
# Epoch 00023: val_loss did not improve from 0.00195
# Epoch 24/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0198 - accuracy: 0.9930 - val_loss: 0.1671 - val_accuracy: 0.9574
#
# Epoch 00024: val_loss did not improve from 0.00195
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00025: val_loss did not improve from 0.00195
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0060 - val_accuracy: 0.9969
#
# Epoch 00026: val_loss did not improve from 0.00195
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0221 - accuracy: 0.9925 - val_loss: 0.0149 - val_accuracy: 0.9969
#
# Epoch 00027: val_loss did not improve from 0.00195
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.0411 - val_accuracy: 0.9883
#
# Epoch 00028: val_loss did not improve from 0.00195
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00029: val_loss did not improve from 0.00195
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.1654 - val_accuracy: 0.9617
#
# Epoch 00030: val_loss did not improve from 0.00195
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0164 - accuracy: 0.9943 - val_loss: 2.8600 - val_accuracy: 0.6918
#
# Epoch 00031: val_loss did not improve from 0.00195
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.0076 - val_accuracy: 0.9965
#
# Epoch 00032: val_loss did not improve from 0.00195
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0268 - accuracy: 0.9921 - val_loss: 0.0080 - val_accuracy: 0.9957
#
# Epoch 00033: val_loss did not improve from 0.00195
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.0220 - val_accuracy: 0.9914
#
# Epoch 00034: val_loss did not improve from 0.00195
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0193 - accuracy: 0.9945 - val_loss: 0.3769 - val_accuracy: 0.8867
#
# Epoch 00035: val_loss did not improve from 0.00195
# Epoch 36/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0196 - accuracy: 0.9944 - val_loss: 0.0264 - val_accuracy: 0.9910
#
# Epoch 00036: val_loss did not improve from 0.00195
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0165 - accuracy: 0.9951 - val_loss: 0.0085 - val_accuracy: 0.9961
#
# Epoch 00037: val_loss did not improve from 0.00195
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.0076 - val_accuracy: 0.9969
#
# Epoch 00038: val_loss did not improve from 0.00195
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9964 - val_loss: 0.0301 - val_accuracy: 0.9902
#
# Epoch 00039: val_loss did not improve from 0.00195
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0087 - val_accuracy: 0.9977
#
# Epoch 00040: val_loss did not improve from 0.00195
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.1568 - val_accuracy: 0.9691
#
# Epoch 00041: val_loss did not improve from 0.00195
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00042: val_loss did not improve from 0.00195
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0195 - accuracy: 0.9946 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00043: val_loss did not improve from 0.00195
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.0105 - val_accuracy: 0.9965
#
# Epoch 00044: val_loss did not improve from 0.00195
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0268 - val_accuracy: 0.9906
#
# Epoch 00045: val_loss did not improve from 0.00195
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0132 - accuracy: 0.9952 - val_loss: 1.2385 - val_accuracy: 0.9082
#
# Epoch 00046: val_loss did not improve from 0.00195
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0198 - accuracy: 0.9938 - val_loss: 0.1309 - val_accuracy: 0.9680
#
# Epoch 00047: val_loss did not improve from 0.00195
# Epoch 48/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00048: val_loss did not improve from 0.00195
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.0536 - val_accuracy: 0.9844
#
# Epoch 00049: val_loss did not improve from 0.00195
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 2.7294 - val_accuracy: 0.7344
#
# Epoch 00050: val_loss did not improve from 0.00195
# Epoch 51/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0212 - val_accuracy: 0.9953
#
# Epoch 00051: val_loss did not improve from 0.00195
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0209 - val_accuracy: 0.9957
#
# Epoch 00052: val_loss did not improve from 0.00195
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0140 - accuracy: 0.9948 - val_loss: 0.0829 - val_accuracy: 0.9848
#
# Epoch 00053: val_loss did not improve from 0.00195
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0211 - val_accuracy: 0.9965
#
# Epoch 00054: val_loss did not improve from 0.00195
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 1.5121 - val_accuracy: 0.8391
#
# Epoch 00055: val_loss did not improve from 0.00195
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0208 - val_accuracy: 0.9957
#
# Epoch 00056: val_loss did not improve from 0.00195
# Epoch 57/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0507 - val_accuracy: 0.9805
#
# Epoch 00057: val_loss did not improve from 0.00195
# Epoch 58/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0084 - accuracy: 0.9966 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00058: val_loss did not improve from 0.00195
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0115 - accuracy: 0.9953 - val_loss: 0.0242 - val_accuracy: 0.9949
#
# Epoch 00059: val_loss did not improve from 0.00195
# Epoch 60/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00060: val_loss did not improve from 0.00195
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0460 - val_accuracy: 0.9930
#
# Epoch 00061: val_loss did not improve from 0.00195
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.0330 - val_accuracy: 0.9918
#
# Epoch 00062: val_loss did not improve from 0.00195
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0054 - val_accuracy: 0.9977
#
# Epoch 00063: val_loss did not improve from 0.00195
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0046 - val_accuracy: 0.9980
#
# Epoch 00064: val_loss did not improve from 0.00195
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0041 - accuracy: 0.9982 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00065: val_loss did not improve from 0.00195
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0214 - accuracy: 0.9937 - val_loss: 0.0652 - val_accuracy: 0.9805
#
# Epoch 00066: val_loss did not improve from 0.00195
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0111 - accuracy: 0.9958 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00067: val_loss did not improve from 0.00195
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.1353 - val_accuracy: 0.9715
#
# Epoch 00068: val_loss did not improve from 0.00195
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 0.0106 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00195
# Epoch 70/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0123 - accuracy: 0.9949 - val_loss: 0.3133 - val_accuracy: 0.9598
#
# Epoch 00070: val_loss did not improve from 0.00195
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00071: val_loss did not improve from 0.00195
# Epoch 72/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0019 - val_accuracy: 0.9988
#
# Epoch 00072: val_loss improved from 0.00195 to 0.00192, saving model to model.h5
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0028 - val_accuracy: 0.9988
#
# Epoch 00073: val_loss did not improve from 0.00192
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9966 - val_loss: 0.0033 - val_accuracy: 0.9988
#
# Epoch 00074: val_loss did not improve from 0.00192
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0858 - val_accuracy: 0.9746
#
# Epoch 00075: val_loss did not improve from 0.00192
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00076: val_loss did not improve from 0.00192
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0056 - accuracy: 0.9976 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00077: val_loss did not improve from 0.00192
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00078: val_loss did not improve from 0.00192
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0038 - val_accuracy: 0.9984
#
# Epoch 00079: val_loss did not improve from 0.00192
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0125 - val_accuracy: 0.9961
#
# Epoch 00080: val_loss did not improve from 0.00192
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00192
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00082: val_loss did not improve from 0.00192
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0092 - accuracy: 0.9964 - val_loss: 0.0875 - val_accuracy: 0.9871
#
# Epoch 00083: val_loss did not improve from 0.00192
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00084: val_loss did not improve from 0.00192
# Epoch 85/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00192
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0031 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00192
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9962 - val_loss: 0.0073 - val_accuracy: 0.9973
#
# Epoch 00087: val_loss did not improve from 0.00192
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.4297 - val_accuracy: 0.9398
#
# Epoch 00088: val_loss did not improve from 0.00192
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.0032 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00192
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00192
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0063 - accuracy: 0.9968 - val_loss: 0.0081 - val_accuracy: 0.9977
#
# Epoch 00091: val_loss did not improve from 0.00192
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0035 - val_accuracy: 0.9984
#
# Epoch 00092: val_loss did not improve from 0.00192
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00093: val_loss did not improve from 0.00192
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0042 - val_accuracy: 0.9984
#
# Epoch 00094: val_loss did not improve from 0.00192
# Epoch 95/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.0289 - val_accuracy: 0.9910
#
# Epoch 00095: val_loss did not improve from 0.00192
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00192
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.2268 - val_accuracy: 0.9438
#
# Epoch 00097: val_loss did not improve from 0.00192
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.0205 - val_accuracy: 0.9945
#
# Epoch 00098: val_loss did not improve from 0.00192
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0155 - val_accuracy: 0.9945
#
# Epoch 00099: val_loss did not improve from 0.00192
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0080 - accuracy: 0.9966 - val_loss: 0.0094 - val_accuracy: 0.9977
#
# Epoch 00100: val_loss did not improve from 0.00192
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9977
# Val Score:  [0.00935857743024826, 0.9976562261581421]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 4ms/step - loss: 0.0041 - accuracy: 0.9962
# Test Accuracy: 99.62499737739563

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
