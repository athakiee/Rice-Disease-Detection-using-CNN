# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-4
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_48 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_72 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_73 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_74 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_75 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_76 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_77 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.5750 - accuracy: 0.8146 - val_loss: 1.7270 - val_accuracy: 0.6086
#
# Epoch 00001: val_loss improved from inf to 1.72698, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2268 - accuracy: 0.9220 - val_loss: 0.9129 - val_accuracy: 0.7477
#
# Epoch 00002: val_loss improved from 1.72698 to 0.91294, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1523 - accuracy: 0.9474 - val_loss: 0.6122 - val_accuracy: 0.8301
#
# Epoch 00003: val_loss improved from 0.91294 to 0.61220, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1135 - accuracy: 0.9631 - val_loss: 0.7647 - val_accuracy: 0.8020
#
# Epoch 00004: val_loss did not improve from 0.61220
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0863 - accuracy: 0.9691 - val_loss: 0.6295 - val_accuracy: 0.8336
#
# Epoch 00005: val_loss did not improve from 0.61220
# Epoch 6/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0762 - accuracy: 0.9740 - val_loss: 0.2796 - val_accuracy: 0.9094
#
# Epoch 00006: val_loss improved from 0.61220 to 0.27963, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0610 - accuracy: 0.9785 - val_loss: 0.6351 - val_accuracy: 0.8328
#
# Epoch 00007: val_loss did not improve from 0.27963
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0592 - accuracy: 0.9825 - val_loss: 0.3181 - val_accuracy: 0.9004
#
# Epoch 00008: val_loss did not improve from 0.27963
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0490 - accuracy: 0.9832 - val_loss: 0.2048 - val_accuracy: 0.9332
#
# Epoch 00009: val_loss improved from 0.27963 to 0.20481, saving model to model.h5
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0483 - accuracy: 0.9859 - val_loss: 0.2959 - val_accuracy: 0.9215
#
# Epoch 00010: val_loss did not improve from 0.20481
# Epoch 11/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0382 - accuracy: 0.9881 - val_loss: 0.1490 - val_accuracy: 0.9477
#
# Epoch 00011: val_loss improved from 0.20481 to 0.14898, saving model to model.h5
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0461 - accuracy: 0.9854 - val_loss: 0.1422 - val_accuracy: 0.9488
#
# Epoch 00012: val_loss improved from 0.14898 to 0.14221, saving model to model.h5
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0342 - accuracy: 0.9890 - val_loss: 0.2110 - val_accuracy: 0.9301
#
# Epoch 00013: val_loss did not improve from 0.14221
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0314 - accuracy: 0.9911 - val_loss: 0.0901 - val_accuracy: 0.9676
#
# Epoch 00014: val_loss improved from 0.14221 to 0.09011, saving model to model.h5
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0295 - accuracy: 0.9910 - val_loss: 0.1126 - val_accuracy: 0.9613
#
# Epoch 00015: val_loss did not improve from 0.09011
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0217 - accuracy: 0.9923 - val_loss: 0.1288 - val_accuracy: 0.9598
#
# Epoch 00016: val_loss did not improve from 0.09011
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0221 - accuracy: 0.9933 - val_loss: 0.0748 - val_accuracy: 0.9762
#
# Epoch 00017: val_loss improved from 0.09011 to 0.07477, saving model to model.h5
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0259 - accuracy: 0.9907 - val_loss: 0.1192 - val_accuracy: 0.9637
#
# Epoch 00018: val_loss did not improve from 0.07477
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0225 - accuracy: 0.9921 - val_loss: 0.0737 - val_accuracy: 0.9746
#
# Epoch 00019: val_loss improved from 0.07477 to 0.07374, saving model to model.h5
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.0425 - val_accuracy: 0.9887
#
# Epoch 00020: val_loss improved from 0.07374 to 0.04252, saving model to model.h5
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.0270 - val_accuracy: 0.9906
#
# Epoch 00021: val_loss improved from 0.04252 to 0.02704, saving model to model.h5
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0221 - accuracy: 0.9932 - val_loss: 0.0398 - val_accuracy: 0.9840
#
# Epoch 00022: val_loss did not improve from 0.02704
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0187 - accuracy: 0.9929 - val_loss: 0.0553 - val_accuracy: 0.9812
#
# Epoch 00023: val_loss did not improve from 0.02704
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0842 - val_accuracy: 0.9715
#
# Epoch 00024: val_loss did not improve from 0.02704
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0357 - val_accuracy: 0.9910
#
# Epoch 00025: val_loss did not improve from 0.02704
# Epoch 26/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0138 - accuracy: 0.9940 - val_loss: 0.0497 - val_accuracy: 0.9848
#
# Epoch 00026: val_loss did not improve from 0.02704
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.0180 - val_accuracy: 0.9930
#
# Epoch 00027: val_loss improved from 0.02704 to 0.01799, saving model to model.h5
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0217 - accuracy: 0.9933 - val_loss: 0.0619 - val_accuracy: 0.9805
#
# Epoch 00028: val_loss did not improve from 0.01799
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.0196 - val_accuracy: 0.9937
#
# Epoch 00029: val_loss did not improve from 0.01799
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.0173 - val_accuracy: 0.9934
#
# Epoch 00030: val_loss improved from 0.01799 to 0.01734, saving model to model.h5
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.0263 - val_accuracy: 0.9898
#
# Epoch 00031: val_loss did not improve from 0.01734
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0502 - val_accuracy: 0.9832
#
# Epoch 00032: val_loss did not improve from 0.01734
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0152 - val_accuracy: 0.9941
#
# Epoch 00033: val_loss improved from 0.01734 to 0.01524, saving model to model.h5
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.0077 - val_accuracy: 0.9969
#
# Epoch 00034: val_loss improved from 0.01524 to 0.00767, saving model to model.h5
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.0212 - val_accuracy: 0.9941
#
# Epoch 00035: val_loss did not improve from 0.00767
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0108 - val_accuracy: 0.9953
#
# Epoch 00036: val_loss did not improve from 0.00767
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0111 - accuracy: 0.9957 - val_loss: 0.0160 - val_accuracy: 0.9965
#
# Epoch 00037: val_loss did not improve from 0.00767
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.0299 - val_accuracy: 0.9902
#
# Epoch 00038: val_loss did not improve from 0.00767
# Epoch 39/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0422 - val_accuracy: 0.9898
#
# Epoch 00039: val_loss did not improve from 0.00767
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0090 - accuracy: 0.9965 - val_loss: 0.0196 - val_accuracy: 0.9945
#
# Epoch 00040: val_loss did not improve from 0.00767
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.0117 - val_accuracy: 0.9961
#
# Epoch 00041: val_loss did not improve from 0.00767
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0110 - val_accuracy: 0.9965
#
# Epoch 00042: val_loss did not improve from 0.00767
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9968 - val_loss: 0.0124 - val_accuracy: 0.9965
#
# Epoch 00043: val_loss did not improve from 0.00767
# Epoch 44/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0104 - accuracy: 0.9959 - val_loss: 0.0142 - val_accuracy: 0.9957
#
# Epoch 00044: val_loss did not improve from 0.00767
# Epoch 45/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0278 - val_accuracy: 0.9930
#
# Epoch 00045: val_loss did not improve from 0.00767
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9940 - val_loss: 0.0247 - val_accuracy: 0.9922
#
# Epoch 00046: val_loss did not improve from 0.00767
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9969 - val_loss: 0.0065 - val_accuracy: 0.9973
#
# Epoch 00047: val_loss improved from 0.00767 to 0.00647, saving model to model.h5
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0047 - val_accuracy: 0.9973
#
# Epoch 00048: val_loss improved from 0.00647 to 0.00466, saving model to model.h5
# Epoch 49/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0077 - accuracy: 0.9967 - val_loss: 0.0292 - val_accuracy: 0.9957
#
# Epoch 00049: val_loss did not improve from 0.00466
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.0136 - val_accuracy: 0.9953
#
# Epoch 00050: val_loss did not improve from 0.00466
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0218 - val_accuracy: 0.9941
#
# Epoch 00051: val_loss did not improve from 0.00466
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 0.0159 - val_accuracy: 0.9961
#
# Epoch 00052: val_loss did not improve from 0.00466
# Epoch 53/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0106 - val_accuracy: 0.9969
#
# Epoch 00053: val_loss did not improve from 0.00466
# Epoch 54/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0137 - val_accuracy: 0.9957
#
# Epoch 00054: val_loss did not improve from 0.00466
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0140 - val_accuracy: 0.9961
#
# Epoch 00055: val_loss did not improve from 0.00466
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9956 - val_loss: 0.0081 - val_accuracy: 0.9973
#
# Epoch 00056: val_loss did not improve from 0.00466
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0168 - val_accuracy: 0.9969
#
# Epoch 00057: val_loss did not improve from 0.00466
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0381 - val_accuracy: 0.9930
#
# Epoch 00058: val_loss did not improve from 0.00466
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9970 - val_loss: 0.0144 - val_accuracy: 0.9965
#
# Epoch 00059: val_loss did not improve from 0.00466
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.0173 - val_accuracy: 0.9961
#
# Epoch 00060: val_loss did not improve from 0.00466
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 0.0187 - val_accuracy: 0.9969
#
# Epoch 00061: val_loss did not improve from 0.00466
# Epoch 62/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00466
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0118 - val_accuracy: 0.9965
#
# Epoch 00063: val_loss did not improve from 0.00466
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.0138 - val_accuracy: 0.9969
#
# Epoch 00064: val_loss did not improve from 0.00466
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.0290 - val_accuracy: 0.9961
#
# Epoch 00065: val_loss did not improve from 0.00466
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9968 - val_loss: 0.0085 - val_accuracy: 0.9973
#
# Epoch 00066: val_loss did not improve from 0.00466
# Epoch 67/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.0689 - val_accuracy: 0.9902
#
# Epoch 00067: val_loss did not improve from 0.00466
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0261 - val_accuracy: 0.9961
#
# Epoch 00068: val_loss did not improve from 0.00466
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9975 - val_loss: 0.0240 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00466
# Epoch 70/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9969 - val_loss: 0.0115 - val_accuracy: 0.9969
#
# Epoch 00070: val_loss did not improve from 0.00466
# Epoch 71/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0083 - val_accuracy: 0.9973
#
# Epoch 00071: val_loss did not improve from 0.00466
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9972 - val_loss: 0.0073 - val_accuracy: 0.9977
#
# Epoch 00072: val_loss did not improve from 0.00466
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0049 - accuracy: 0.9976 - val_loss: 0.0158 - val_accuracy: 0.9965
#
# Epoch 00073: val_loss did not improve from 0.00466
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 0.0116 - val_accuracy: 0.9957
#
# Epoch 00074: val_loss did not improve from 0.00466
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0114 - val_accuracy: 0.9965
#
# Epoch 00075: val_loss did not improve from 0.00466
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9973 - val_loss: 0.0089 - val_accuracy: 0.9969
#
# Epoch 00076: val_loss did not improve from 0.00466
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0204 - val_accuracy: 0.9965
#
# Epoch 00077: val_loss did not improve from 0.00466
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 0.0091 - val_accuracy: 0.9973
#
# Epoch 00078: val_loss did not improve from 0.00466
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0112 - val_accuracy: 0.9953
#
# Epoch 00079: val_loss did not improve from 0.00466
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00080: val_loss did not improve from 0.00466
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0081 - val_accuracy: 0.9973
#
# Epoch 00081: val_loss did not improve from 0.00466
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0049 - accuracy: 0.9976 - val_loss: 0.0060 - val_accuracy: 0.9973
#
# Epoch 00082: val_loss did not improve from 0.00466
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0041 - accuracy: 0.9979 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00083: val_loss did not improve from 0.00466
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 0.0053 - val_accuracy: 0.9973
#
# Epoch 00084: val_loss did not improve from 0.00466
# Epoch 85/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00085: val_loss improved from 0.00466 to 0.00240, saving model to model.h5
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9969 - val_loss: 0.9001 - val_accuracy: 0.8672
#
# Epoch 00086: val_loss did not improve from 0.00240
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00240
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9973 - val_loss: 0.0036 - val_accuracy: 0.9977
#
# Epoch 00088: val_loss did not improve from 0.00240
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9976 - val_loss: 0.0106 - val_accuracy: 0.9965
#
# Epoch 00089: val_loss did not improve from 0.00240
# Epoch 90/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9976 - val_loss: 0.0230 - val_accuracy: 0.9930
#
# Epoch 00090: val_loss did not improve from 0.00240
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0049 - accuracy: 0.9980 - val_loss: 0.0136 - val_accuracy: 0.9969
#
# Epoch 00091: val_loss did not improve from 0.00240
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0059 - val_accuracy: 0.9965
#
# Epoch 00092: val_loss did not improve from 0.00240
# Epoch 93/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9975 - val_loss: 0.0205 - val_accuracy: 0.9961
#
# Epoch 00093: val_loss did not improve from 0.00240
# Epoch 94/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9972 - val_loss: 0.0054 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00240
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0035 - val_accuracy: 0.9977
#
# Epoch 00095: val_loss did not improve from 0.00240
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.0382 - val_accuracy: 0.9891
#
# Epoch 00096: val_loss did not improve from 0.00240
# Epoch 97/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9967 - val_loss: 0.0731 - val_accuracy: 0.9824
#
# Epoch 00097: val_loss did not improve from 0.00240
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.0123 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00240
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.0059 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00240
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0051 - accuracy: 0.9978 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00240
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9980
# Val Score:  [0.0046728081069886684, 0.998046875]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4102 - accuracy: 0.8655 - val_loss: 7.9738 - val_accuracy: 0.3070
#
# Epoch 00001: val_loss did not improve from 0.00240
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1737 - accuracy: 0.9394 - val_loss: 1.4454 - val_accuracy: 0.7063
#
# Epoch 00002: val_loss did not improve from 0.00240
# Epoch 3/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1127 - accuracy: 0.9604 - val_loss: 0.6908 - val_accuracy: 0.8098
#
# Epoch 00003: val_loss did not improve from 0.00240
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0881 - accuracy: 0.9703 - val_loss: 0.7361 - val_accuracy: 0.8234
#
# Epoch 00004: val_loss did not improve from 0.00240
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0715 - accuracy: 0.9751 - val_loss: 0.6955 - val_accuracy: 0.8395
#
# Epoch 00005: val_loss did not improve from 0.00240
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0612 - accuracy: 0.9797 - val_loss: 0.5264 - val_accuracy: 0.8727
#
# Epoch 00006: val_loss did not improve from 0.00240
# Epoch 7/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0552 - accuracy: 0.9830 - val_loss: 0.4141 - val_accuracy: 0.8840
#
# Epoch 00007: val_loss did not improve from 0.00240
# Epoch 8/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0473 - accuracy: 0.9825 - val_loss: 0.2741 - val_accuracy: 0.9262
#
# Epoch 00008: val_loss did not improve from 0.00240
# Epoch 9/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0421 - accuracy: 0.9863 - val_loss: 0.3724 - val_accuracy: 0.9113
#
# Epoch 00009: val_loss did not improve from 0.00240
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0417 - accuracy: 0.9864 - val_loss: 0.4105 - val_accuracy: 0.8957
#
# Epoch 00010: val_loss did not improve from 0.00240
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0377 - accuracy: 0.9884 - val_loss: 0.4419 - val_accuracy: 0.8922
#
# Epoch 00011: val_loss did not improve from 0.00240
# Epoch 12/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0303 - accuracy: 0.9910 - val_loss: 0.3831 - val_accuracy: 0.9020
#
# Epoch 00012: val_loss did not improve from 0.00240
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0363 - accuracy: 0.9893 - val_loss: 0.2029 - val_accuracy: 0.9441
#
# Epoch 00013: val_loss did not improve from 0.00240
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0283 - accuracy: 0.9919 - val_loss: 0.1538 - val_accuracy: 0.9543
#
# Epoch 00014: val_loss did not improve from 0.00240
# Epoch 15/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0312 - accuracy: 0.9906 - val_loss: 0.2257 - val_accuracy: 0.9402
#
# Epoch 00015: val_loss did not improve from 0.00240
# Epoch 16/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0298 - accuracy: 0.9917 - val_loss: 0.0654 - val_accuracy: 0.9824
#
# Epoch 00016: val_loss did not improve from 0.00240
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0233 - accuracy: 0.9932 - val_loss: 0.1362 - val_accuracy: 0.9586
#
# Epoch 00017: val_loss did not improve from 0.00240
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0257 - accuracy: 0.9921 - val_loss: 0.1439 - val_accuracy: 0.9617
#
# Epoch 00018: val_loss did not improve from 0.00240
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0249 - accuracy: 0.9917 - val_loss: 0.2607 - val_accuracy: 0.9305
#
# Epoch 00019: val_loss did not improve from 0.00240
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9937 - val_loss: 0.1164 - val_accuracy: 0.9609
#
# Epoch 00020: val_loss did not improve from 0.00240
# Epoch 21/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0208 - accuracy: 0.9941 - val_loss: 0.0317 - val_accuracy: 0.9934
#
# Epoch 00021: val_loss did not improve from 0.00240
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 0.0311 - val_accuracy: 0.9930
#
# Epoch 00022: val_loss did not improve from 0.00240
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 0.1585 - val_accuracy: 0.9586
#
# Epoch 00023: val_loss did not improve from 0.00240
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9940 - val_loss: 0.0780 - val_accuracy: 0.9770
#
# Epoch 00024: val_loss did not improve from 0.00240
# Epoch 25/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.0160 - val_accuracy: 0.9953
#
# Epoch 00025: val_loss did not improve from 0.00240
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.4312 - val_accuracy: 0.9145
#
# Epoch 00026: val_loss did not improve from 0.00240
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0190 - accuracy: 0.9933 - val_loss: 0.2087 - val_accuracy: 0.9504
#
# Epoch 00027: val_loss did not improve from 0.00240
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.0293 - val_accuracy: 0.9953
#
# Epoch 00028: val_loss did not improve from 0.00240
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9954 - val_loss: 0.0339 - val_accuracy: 0.9898
#
# Epoch 00029: val_loss did not improve from 0.00240
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0167 - val_accuracy: 0.9941
#
# Epoch 00030: val_loss did not improve from 0.00240
# Epoch 31/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0112 - accuracy: 0.9956 - val_loss: 0.0315 - val_accuracy: 0.9945
#
# Epoch 00031: val_loss did not improve from 0.00240
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0191 - val_accuracy: 0.9941
#
# Epoch 00032: val_loss did not improve from 0.00240
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.0541 - val_accuracy: 0.9863
#
# Epoch 00033: val_loss did not improve from 0.00240
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0310 - val_accuracy: 0.9906
#
# Epoch 00034: val_loss did not improve from 0.00240
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.0145 - val_accuracy: 0.9957
#
# Epoch 00035: val_loss did not improve from 0.00240
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.1153 - val_accuracy: 0.9777
#
# Epoch 00036: val_loss did not improve from 0.00240
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.0554 - val_accuracy: 0.9891
#
# Epoch 00037: val_loss did not improve from 0.00240
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0093 - accuracy: 0.9964 - val_loss: 0.0482 - val_accuracy: 0.9863
#
# Epoch 00038: val_loss did not improve from 0.00240
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0084 - accuracy: 0.9964 - val_loss: 0.0570 - val_accuracy: 0.9891
#
# Epoch 00039: val_loss did not improve from 0.00240
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0098 - accuracy: 0.9958 - val_loss: 0.0701 - val_accuracy: 0.9812
#
# Epoch 00040: val_loss did not improve from 0.00240
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 0.0348 - val_accuracy: 0.9926
#
# Epoch 00041: val_loss did not improve from 0.00240
# Epoch 42/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0335 - val_accuracy: 0.9918
#
# Epoch 00042: val_loss did not improve from 0.00240
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9959 - val_loss: 0.0298 - val_accuracy: 0.9922
#
# Epoch 00043: val_loss did not improve from 0.00240
# Epoch 44/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.0127 - val_accuracy: 0.9941
#
# Epoch 00044: val_loss did not improve from 0.00240
# Epoch 45/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0113 - accuracy: 0.9956 - val_loss: 0.0108 - val_accuracy: 0.9977
#
# Epoch 00045: val_loss did not improve from 0.00240
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0126 - val_accuracy: 0.9973
#
# Epoch 00046: val_loss did not improve from 0.00240
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0282 - val_accuracy: 0.9949
#
# Epoch 00047: val_loss did not improve from 0.00240
# Epoch 48/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0537 - val_accuracy: 0.9922
#
# Epoch 00048: val_loss did not improve from 0.00240
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0298 - val_accuracy: 0.9914
#
# Epoch 00049: val_loss did not improve from 0.00240
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0349 - val_accuracy: 0.9949
#
# Epoch 00050: val_loss did not improve from 0.00240
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0082 - accuracy: 0.9965 - val_loss: 0.0337 - val_accuracy: 0.9934
#
# Epoch 00051: val_loss did not improve from 0.00240
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9967 - val_loss: 0.0105 - val_accuracy: 0.9965
#
# Epoch 00052: val_loss did not improve from 0.00240
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.0079 - val_accuracy: 0.9973
#
# Epoch 00053: val_loss did not improve from 0.00240
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9965 - val_loss: 0.3709 - val_accuracy: 0.9438
#
# Epoch 00054: val_loss did not improve from 0.00240
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.0191 - val_accuracy: 0.9957
#
# Epoch 00055: val_loss did not improve from 0.00240
# Epoch 56/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9968 - val_loss: 0.0381 - val_accuracy: 0.9895
#
# Epoch 00056: val_loss did not improve from 0.00240
# Epoch 57/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 0.0188 - val_accuracy: 0.9949
#
# Epoch 00057: val_loss did not improve from 0.00240
# Epoch 58/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0226 - val_accuracy: 0.9957
#
# Epoch 00058: val_loss did not improve from 0.00240
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0338 - val_accuracy: 0.9914
#
# Epoch 00059: val_loss did not improve from 0.00240
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 0.0043 - val_accuracy: 0.9977
#
# Epoch 00060: val_loss did not improve from 0.00240
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0450 - val_accuracy: 0.9887
#
# Epoch 00061: val_loss did not improve from 0.00240
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.1592 - val_accuracy: 0.9730
#
# Epoch 00062: val_loss did not improve from 0.00240
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00063: val_loss improved from 0.00240 to 0.00228, saving model to model.h5
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0065 - accuracy: 0.9971 - val_loss: 0.0180 - val_accuracy: 0.9949
#
# Epoch 00064: val_loss did not improve from 0.00228
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.0056 - val_accuracy: 0.9977
#
# Epoch 00065: val_loss did not improve from 0.00228
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.0117 - val_accuracy: 0.9969
#
# Epoch 00066: val_loss did not improve from 0.00228
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0050 - val_accuracy: 0.9984
#
# Epoch 00067: val_loss did not improve from 0.00228
# Epoch 68/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0266 - val_accuracy: 0.9949
#
# Epoch 00068: val_loss did not improve from 0.00228
# Epoch 69/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9967 - val_loss: 0.0471 - val_accuracy: 0.9934
#
# Epoch 00069: val_loss did not improve from 0.00228
# Epoch 70/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0066 - accuracy: 0.9967 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00070: val_loss did not improve from 0.00228
# Epoch 71/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0138 - val_accuracy: 0.9965
#
# Epoch 00071: val_loss did not improve from 0.00228
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0111 - val_accuracy: 0.9980
#
# Epoch 00072: val_loss did not improve from 0.00228
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0053 - accuracy: 0.9975 - val_loss: 0.0070 - val_accuracy: 0.9973
#
# Epoch 00073: val_loss did not improve from 0.00228
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0081 - accuracy: 0.9960 - val_loss: 0.0142 - val_accuracy: 0.9949
#
# Epoch 00074: val_loss did not improve from 0.00228
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.0284 - val_accuracy: 0.9910
#
# Epoch 00075: val_loss did not improve from 0.00228
# Epoch 76/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0039 - val_accuracy: 0.9988
#
# Epoch 00076: val_loss did not improve from 0.00228
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0088 - accuracy: 0.9961 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00077: val_loss did not improve from 0.00228
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9975 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00078: val_loss did not improve from 0.00228
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0051 - accuracy: 0.9974 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00079: val_loss did not improve from 0.00228
# Epoch 80/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0065 - accuracy: 0.9973 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00080: val_loss improved from 0.00228 to 0.00197, saving model to model.h5
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00081: val_loss did not improve from 0.00197
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.1467 - val_accuracy: 0.9660
#
# Epoch 00082: val_loss did not improve from 0.00197
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9961 - val_loss: 0.0104 - val_accuracy: 0.9977
#
# Epoch 00083: val_loss did not improve from 0.00197
# Epoch 84/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 0.0064 - val_accuracy: 0.9973
#
# Epoch 00084: val_loss did not improve from 0.00197
# Epoch 85/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9978 - val_loss: 0.0087 - val_accuracy: 0.9969
#
# Epoch 00085: val_loss did not improve from 0.00197
# Epoch 86/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0041 - accuracy: 0.9981 - val_loss: 0.0029 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00197
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0108 - val_accuracy: 0.9973
#
# Epoch 00087: val_loss did not improve from 0.00197
# Epoch 88/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.0894 - val_accuracy: 0.9844
#
# Epoch 00088: val_loss did not improve from 0.00197
# Epoch 89/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0085 - val_accuracy: 0.9957
#
# Epoch 00089: val_loss did not improve from 0.00197
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.0090 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00197
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0047 - accuracy: 0.9979 - val_loss: 0.0107 - val_accuracy: 0.9969
#
# Epoch 00091: val_loss did not improve from 0.00197
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9973 - val_loss: 0.0143 - val_accuracy: 0.9973
#
# Epoch 00092: val_loss did not improve from 0.00197
# Epoch 93/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0053 - accuracy: 0.9974 - val_loss: 0.0101 - val_accuracy: 0.9957
#
# Epoch 00093: val_loss did not improve from 0.00197
# Epoch 94/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00197
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9961 - val_loss: 0.1526 - val_accuracy: 0.9770
#
# Epoch 00095: val_loss did not improve from 0.00197
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9975 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00096: val_loss did not improve from 0.00197
# Epoch 97/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0043 - accuracy: 0.9978 - val_loss: 0.0139 - val_accuracy: 0.9961
#
# Epoch 00097: val_loss did not improve from 0.00197
# Epoch 98/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0048 - accuracy: 0.9977 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00098: val_loss did not improve from 0.00197
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9973 - val_loss: 0.0140 - val_accuracy: 0.9961
#
# Epoch 00099: val_loss did not improve from 0.00197
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.0099 - val_accuracy: 0.9984
#
# Epoch 00100: val_loss did not improve from 0.00197
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9984
# Val Score:  [0.009895531460642815, 0.9984375238418579]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4331 - accuracy: 0.8505 - val_loss: 4.7043 - val_accuracy: 0.4926
#
# Epoch 00001: val_loss did not improve from 0.00197
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1687 - accuracy: 0.9389 - val_loss: 0.7730 - val_accuracy: 0.7996
#
# Epoch 00002: val_loss did not improve from 0.00197
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1003 - accuracy: 0.9650 - val_loss: 0.3200 - val_accuracy: 0.9168
#
# Epoch 00003: val_loss did not improve from 0.00197
# Epoch 4/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0813 - accuracy: 0.9717 - val_loss: 0.1372 - val_accuracy: 0.9555
#
# Epoch 00004: val_loss did not improve from 0.00197
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0558 - accuracy: 0.9800 - val_loss: 0.1838 - val_accuracy: 0.9523
#
# Epoch 00005: val_loss did not improve from 0.00197
# Epoch 6/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0480 - accuracy: 0.9826 - val_loss: 0.0722 - val_accuracy: 0.9793
#
# Epoch 00006: val_loss did not improve from 0.00197
# Epoch 7/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0450 - accuracy: 0.9849 - val_loss: 0.0771 - val_accuracy: 0.9727
#
# Epoch 00007: val_loss did not improve from 0.00197
# Epoch 8/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0343 - accuracy: 0.9876 - val_loss: 0.0293 - val_accuracy: 0.9887
#
# Epoch 00008: val_loss did not improve from 0.00197
# Epoch 9/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0303 - accuracy: 0.9896 - val_loss: 0.0464 - val_accuracy: 0.9863
#
# Epoch 00009: val_loss did not improve from 0.00197
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0301 - accuracy: 0.9908 - val_loss: 0.0552 - val_accuracy: 0.9852
#
# Epoch 00010: val_loss did not improve from 0.00197
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0256 - accuracy: 0.9914 - val_loss: 0.0464 - val_accuracy: 0.9852
#
# Epoch 00011: val_loss did not improve from 0.00197
# Epoch 12/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0326 - accuracy: 0.9909 - val_loss: 0.0161 - val_accuracy: 0.9941
#
# Epoch 00012: val_loss did not improve from 0.00197
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0253 - val_accuracy: 0.9914
#
# Epoch 00013: val_loss did not improve from 0.00197
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0234 - accuracy: 0.9918 - val_loss: 0.0203 - val_accuracy: 0.9945
#
# Epoch 00014: val_loss did not improve from 0.00197
# Epoch 15/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.0167 - val_accuracy: 0.9957
#
# Epoch 00015: val_loss did not improve from 0.00197
# Epoch 16/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0208 - accuracy: 0.9934 - val_loss: 0.0246 - val_accuracy: 0.9914
#
# Epoch 00016: val_loss did not improve from 0.00197
# Epoch 17/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0261 - accuracy: 0.9909 - val_loss: 0.0488 - val_accuracy: 0.9867
#
# Epoch 00017: val_loss did not improve from 0.00197
# Epoch 18/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.0261 - val_accuracy: 0.9930
#
# Epoch 00018: val_loss did not improve from 0.00197
# Epoch 19/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9949 - val_loss: 0.0139 - val_accuracy: 0.9953
#
# Epoch 00019: val_loss did not improve from 0.00197
# Epoch 20/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.0172 - val_accuracy: 0.9945
#
# Epoch 00020: val_loss did not improve from 0.00197
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.0218 - val_accuracy: 0.9930
#
# Epoch 00021: val_loss did not improve from 0.00197
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.0244 - val_accuracy: 0.9934
#
# Epoch 00022: val_loss did not improve from 0.00197
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0147 - accuracy: 0.9947 - val_loss: 0.0093 - val_accuracy: 0.9969
#
# Epoch 00023: val_loss did not improve from 0.00197
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.0256 - val_accuracy: 0.9926
#
# Epoch 00024: val_loss did not improve from 0.00197
# Epoch 25/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0153 - val_accuracy: 0.9953
#
# Epoch 00025: val_loss did not improve from 0.00197
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 0.0167 - val_accuracy: 0.9961
#
# Epoch 00026: val_loss did not improve from 0.00197
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0176 - val_accuracy: 0.9945
#
# Epoch 00027: val_loss did not improve from 0.00197
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.0070 - val_accuracy: 0.9965
#
# Epoch 00028: val_loss did not improve from 0.00197
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0069 - val_accuracy: 0.9973
#
# Epoch 00029: val_loss did not improve from 0.00197
# Epoch 30/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0118 - accuracy: 0.9957 - val_loss: 0.0478 - val_accuracy: 0.9883
#
# Epoch 00030: val_loss did not improve from 0.00197
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0122 - accuracy: 0.9946 - val_loss: 0.0286 - val_accuracy: 0.9922
#
# Epoch 00031: val_loss did not improve from 0.00197
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0173 - val_accuracy: 0.9961
#
# Epoch 00032: val_loss did not improve from 0.00197
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 0.0315 - val_accuracy: 0.9945
#
# Epoch 00033: val_loss did not improve from 0.00197
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9960 - val_loss: 0.0310 - val_accuracy: 0.9910
#
# Epoch 00034: val_loss did not improve from 0.00197
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0402 - val_accuracy: 0.9906
#
# Epoch 00035: val_loss did not improve from 0.00197
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9956 - val_loss: 0.0061 - val_accuracy: 0.9973
#
# Epoch 00036: val_loss did not improve from 0.00197
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0473 - val_accuracy: 0.9926
#
# Epoch 00037: val_loss did not improve from 0.00197
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.0623 - val_accuracy: 0.9910
#
# Epoch 00038: val_loss did not improve from 0.00197
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0099 - accuracy: 0.9959 - val_loss: 0.0267 - val_accuracy: 0.9930
#
# Epoch 00039: val_loss did not improve from 0.00197
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0325 - val_accuracy: 0.9949
#
# Epoch 00040: val_loss did not improve from 0.00197
# Epoch 41/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00188
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.2892 - val_accuracy: 0.9340
#
# Epoch 00021: val_loss did not improve from 0.00188
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0178 - accuracy: 0.9943 - val_loss: 0.1178 - val_accuracy: 0.9656
#
# Epoch 00022: val_loss did not improve from 0.00188
# Epoch 23/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0172 - accuracy: 0.9955 - val_loss: 0.1796 - val_accuracy: 0.9496
#
# Epoch 00023: val_loss did not improve from 0.00188
# Epoch 24/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.0795 - val_accuracy: 0.9738
#
# Epoch 00024: val_loss did not improve from 0.00188
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9949 - val_loss: 0.2239 - val_accuracy: 0.9398
#
# Epoch 00025: val_loss did not improve from 0.00188
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0135 - accuracy: 0.9950 - val_loss: 0.0614 - val_accuracy: 0.9824
#
# Epoch 00026: val_loss did not improve from 0.00188
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.1171 - val_accuracy: 0.9648
#
# Epoch 00027: val_loss did not improve from 0.00188
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0138 - accuracy: 0.9960 - val_loss: 0.2799 - val_accuracy: 0.9449
#
# Epoch 00028: val_loss did not improve from 0.00188
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.0326 - val_accuracy: 0.9879
#
# Epoch 00029: val_loss did not improve from 0.00188
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.0881 - val_accuracy: 0.9699
#
# Epoch 00030: val_loss did not improve from 0.00188
# Epoch 31/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0127 - accuracy: 0.9947 - val_loss: 0.2171 - val_accuracy: 0.9508
#
# Epoch 00031: val_loss did not improve from 0.00188
# Epoch 32/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.0537 - val_accuracy: 0.9855
#
# Epoch 00032: val_loss did not improve from 0.00188
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 0.0287 - val_accuracy: 0.9910
#
# Epoch 00033: val_loss did not improve from 0.00188
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0575 - val_accuracy: 0.9871
#
# Epoch 00034: val_loss did not improve from 0.00188
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.1105 - val_accuracy: 0.9730
#
# Epoch 00035: val_loss did not improve from 0.00188
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0247 - val_accuracy: 0.9926
#
# Epoch 00036: val_loss did not improve from 0.00188
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.0261 - val_accuracy: 0.9922
#
# Epoch 00037: val_loss did not improve from 0.00188
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9968 - val_loss: 0.0264 - val_accuracy: 0.9926
#
# Epoch 00038: val_loss did not improve from 0.00188
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.2733 - val_accuracy: 0.9449
#
# Epoch 00039: val_loss did not improve from 0.00188
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9972 - val_loss: 0.0408 - val_accuracy: 0.9863
#
# Epoch 00040: val_loss did not improve from 0.00188
# Epoch 41/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9965 - val_loss: 0.0499 - val_accuracy: 0.9879
#
# Epoch 00041: val_loss did not improve from 0.00188
# Epoch 42/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0329 - val_accuracy: 0.9922
#
# Epoch 00042: val_loss did not improve from 0.00188
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0202 - val_accuracy: 0.9941
#
# Epoch 00043: val_loss did not improve from 0.00188
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9957 - val_loss: 0.0355 - val_accuracy: 0.9914
#
# Epoch 00044: val_loss did not improve from 0.00188
# Epoch 45/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 0.0183 - val_accuracy: 0.9937
#
# Epoch 00045: val_loss did not improve from 0.00188
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0146 - val_accuracy: 0.9961
#
# Epoch 00046: val_loss did not improve from 0.00188
# Epoch 47/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0111 - val_accuracy: 0.9969
#
# Epoch 00047: val_loss did not improve from 0.00188
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0055 - accuracy: 0.9978 - val_loss: 0.0251 - val_accuracy: 0.9953
#
# Epoch 00048: val_loss did not improve from 0.00188
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9959 - val_loss: 0.0174 - val_accuracy: 0.9937
#
# Epoch 00049: val_loss did not improve from 0.00188
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.0180 - val_accuracy: 0.9937
#
# Epoch 00050: val_loss did not improve from 0.00188
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0361 - val_accuracy: 0.9898
#
# Epoch 00051: val_loss did not improve from 0.00188
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9964 - val_loss: 0.0338 - val_accuracy: 0.9922
#
# Epoch 00052: val_loss did not improve from 0.00188
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9966 - val_loss: 0.0252 - val_accuracy: 0.9949
#
# Epoch 00053: val_loss did not improve from 0.00188
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.0131 - val_accuracy: 0.9969
#
# Epoch 00054: val_loss did not improve from 0.00188
# Epoch 55/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.0369 - val_accuracy: 0.9934
#
# Epoch 00055: val_loss did not improve from 0.00188
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9966 - val_loss: 0.0187 - val_accuracy: 0.9953
#
# Epoch 00056: val_loss did not improve from 0.00188
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0441 - val_accuracy: 0.9875
#
# Epoch 00057: val_loss did not improve from 0.00188
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0122 - val_accuracy: 0.9965
#
# Epoch 00058: val_loss did not improve from 0.00188
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0481 - val_accuracy: 0.9875
#
# Epoch 00059: val_loss did not improve from 0.00188
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0069 - accuracy: 0.9969 - val_loss: 0.0285 - val_accuracy: 0.9918
#
# Epoch 00060: val_loss did not improve from 0.00188
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9966 - val_loss: 0.0142 - val_accuracy: 0.9957
#
# Epoch 00061: val_loss did not improve from 0.00188
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.0374 - val_accuracy: 0.9891
#
# Epoch 00062: val_loss did not improve from 0.00188
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0096 - val_accuracy: 0.9961
#
# Epoch 00063: val_loss did not improve from 0.00188
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.0156 - val_accuracy: 0.9937
#
# Epoch 00064: val_loss did not improve from 0.00188
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0152 - val_accuracy: 0.9949
#
# Epoch 00065: val_loss did not improve from 0.00188
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9974 - val_loss: 0.0132 - val_accuracy: 0.9965
#
# Epoch 00066: val_loss did not improve from 0.00188
# Epoch 67/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9970 - val_loss: 0.0193 - val_accuracy: 0.9941
#
# Epoch 00067: val_loss did not improve from 0.00188
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9976 - val_loss: 0.0079 - val_accuracy: 0.9973
#
# Epoch 00068: val_loss did not improve from 0.00188
# Epoch 69/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0046 - accuracy: 0.9977 - val_loss: 0.0172 - val_accuracy: 0.9973
#
# Epoch 00069: val_loss did not improve from 0.00188
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0206 - val_accuracy: 0.9941
#
# Epoch 00070: val_loss did not improve from 0.00188
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0049 - accuracy: 0.9978 - val_loss: 0.0204 - val_accuracy: 0.9969
#
# Epoch 00071: val_loss did not improve from 0.00188
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0149 - val_accuracy: 0.9937
#
# Epoch 00072: val_loss did not improve from 0.00188
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0045 - accuracy: 0.9981 - val_loss: 0.0169 - val_accuracy: 0.9969
#
# Epoch 00073: val_loss did not improve from 0.00188
# Epoch 74/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 0.0206 - val_accuracy: 0.9926
#
# Epoch 00074: val_loss did not improve from 0.00188
# Epoch 75/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9969 - val_loss: 0.0151 - val_accuracy: 0.9953
#
# Epoch 00075: val_loss did not improve from 0.00188
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9971 - val_loss: 0.0165 - val_accuracy: 0.9937
#
# Epoch 00076: val_loss did not improve from 0.00188
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9975 - val_loss: 0.0164 - val_accuracy: 0.9969
#
# Epoch 00077: val_loss did not improve from 0.00188
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9964 - val_loss: 0.0161 - val_accuracy: 0.9973
#
# Epoch 00078: val_loss did not improve from 0.00188
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 0.0221 - val_accuracy: 0.9953
#
# Epoch 00079: val_loss did not improve from 0.00188
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 0.0259 - val_accuracy: 0.9941
#
# Epoch 00080: val_loss did not improve from 0.00188
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0044 - accuracy: 0.9981 - val_loss: 0.0264 - val_accuracy: 0.9965
#
# Epoch 00081: val_loss did not improve from 0.00188
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 0.0187 - val_accuracy: 0.9937
#
# Epoch 00082: val_loss did not improve from 0.00188
# Epoch 83/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0044 - accuracy: 0.9979 - val_loss: 0.0325 - val_accuracy: 0.9930
#
# Epoch 00083: val_loss did not improve from 0.00188
# Epoch 84/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0220 - val_accuracy: 0.9957
#
# Epoch 00084: val_loss did not improve from 0.00188
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.0205 - val_accuracy: 0.9969
#
# Epoch 00085: val_loss did not improve from 0.00188
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.0109 - val_accuracy: 0.9969
#
# Epoch 00086: val_loss did not improve from 0.00188
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0059 - accuracy: 0.9971 - val_loss: 0.0042 - val_accuracy: 0.9984
#
# Epoch 00087: val_loss did not improve from 0.00188
# Epoch 88/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9972 - val_loss: 0.0150 - val_accuracy: 0.9961
#
# Epoch 00088: val_loss did not improve from 0.00188
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0071 - accuracy: 0.9969 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00089: val_loss did not improve from 0.00188
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0187 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00188
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0160 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00188
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0101 - val_accuracy: 0.9957
#
# Epoch 00092: val_loss did not improve from 0.00188
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0061 - accuracy: 0.9970 - val_loss: 0.0216 - val_accuracy: 0.9957
#
# Epoch 00093: val_loss did not improve from 0.00188
# Epoch 94/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.0168 - val_accuracy: 0.9977
#
# Epoch 00094: val_loss did not improve from 0.00188
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 0.0343 - val_accuracy: 0.9977
#
# Epoch 00095: val_loss did not improve from 0.00188
# Epoch 96/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9974 - val_loss: 0.0148 - val_accuracy: 0.9961
#
# Epoch 00096: val_loss did not improve from 0.00188
# Epoch 97/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0044 - accuracy: 0.9981 - val_loss: 0.0160 - val_accuracy: 0.9969
#
# Epoch 00097: val_loss did not improve from 0.00188
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0043 - accuracy: 0.9979 - val_loss: 0.0184 - val_accuracy: 0.9969
#
# Epoch 00098: val_loss did not improve from 0.00188
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0128 - val_accuracy: 0.9977
#
# Epoch 00099: val_loss did not improve from 0.00188
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0045 - accuracy: 0.9975 - val_loss: 0.0122 - val_accuracy: 0.9961
#
# Epoch 00100: val_loss did not improve from 0.00188
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9961
# Val Score:  [0.01222903747111559, 0.99609375]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
