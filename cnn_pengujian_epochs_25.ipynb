# %% [markdown]
# ## RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **EPOCHS 25 -- USING ADAM AND BEST RESULT OF HIDDEN LAYER(4) AND 0.001 LEARNING RATE**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 25
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 2022-07-11 04:27:02.451634: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:02.572285: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:02.573204: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:02.574482: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-11 04:27:02.574839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:02.575535: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:02.576151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:04.626021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:04.627028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:04.627724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:27:04.628839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# 2022-07-11 04:27:07.779798: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/25
# 2022-07-11 04:27:09.491577: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 320/320 [==============================] - 10s 9ms/step - loss: 0.3782 - accuracy: 0.8815 - val_loss: 3.1257 - val_accuracy: 0.6270
#
# Epoch 00001: val_loss improved from inf to 3.12575, saving model to model.h5
# Epoch 2/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1332 - accuracy: 0.9561 - val_loss: 0.2118 - val_accuracy: 0.9305
#
# Epoch 00002: val_loss improved from 3.12575 to 0.21177, saving model to model.h5
# Epoch 3/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0784 - accuracy: 0.9732 - val_loss: 0.7137 - val_accuracy: 0.8262
#
# Epoch 00003: val_loss did not improve from 0.21177
# Epoch 4/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0751 - accuracy: 0.9747 - val_loss: 0.1934 - val_accuracy: 0.9359
#
# Epoch 00004: val_loss improved from 0.21177 to 0.19338, saving model to model.h5
# Epoch 5/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0495 - accuracy: 0.9843 - val_loss: 0.1414 - val_accuracy: 0.9586
#
# Epoch 00005: val_loss improved from 0.19338 to 0.14139, saving model to model.h5
# Epoch 6/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0343 - accuracy: 0.9888 - val_loss: 0.6629 - val_accuracy: 0.8535
#
# Epoch 00006: val_loss did not improve from 0.14139
# Epoch 7/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0477 - accuracy: 0.9844 - val_loss: 2.5621 - val_accuracy: 0.5195
#
# Epoch 00007: val_loss did not improve from 0.14139
# Epoch 8/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0388 - accuracy: 0.9865 - val_loss: 0.0409 - val_accuracy: 0.9875
#
# Epoch 00008: val_loss improved from 0.14139 to 0.04093, saving model to model.h5
# Epoch 9/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0388 - accuracy: 0.9869 - val_loss: 0.3566 - val_accuracy: 0.9250
#
# Epoch 00009: val_loss did not improve from 0.04093
# Epoch 10/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0278 - accuracy: 0.9910 - val_loss: 0.0093 - val_accuracy: 0.9953
#
# Epoch 00010: val_loss improved from 0.04093 to 0.00926, saving model to model.h5
# Epoch 11/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.0147 - val_accuracy: 0.9949
#
# Epoch 00011: val_loss did not improve from 0.00926
# Epoch 12/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0350 - accuracy: 0.9894 - val_loss: 0.0392 - val_accuracy: 0.9859
#
# Epoch 00012: val_loss did not improve from 0.00926
# Epoch 13/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0420 - accuracy: 0.9864 - val_loss: 0.0601 - val_accuracy: 0.9855
#
# Epoch 00013: val_loss did not improve from 0.00926
# Epoch 14/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 0.3353 - val_accuracy: 0.9160
#
# Epoch 00014: val_loss did not improve from 0.00926
# Epoch 15/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0162 - accuracy: 0.9947 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00015: val_loss improved from 0.00926 to 0.00447, saving model to model.h5
# Epoch 16/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0196 - val_accuracy: 0.9949
#
# Epoch 00016: val_loss did not improve from 0.00447
# Epoch 17/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.2954 - val_accuracy: 0.9383
#
# Epoch 00017: val_loss did not improve from 0.00447
# Epoch 18/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0380 - accuracy: 0.9880 - val_loss: 0.4922 - val_accuracy: 0.8777
#
# Epoch 00018: val_loss did not improve from 0.00447
# Epoch 19/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0214 - accuracy: 0.9927 - val_loss: 2.8352 - val_accuracy: 0.7605
#
# Epoch 00019: val_loss did not improve from 0.00447
# Epoch 20/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.0573 - val_accuracy: 0.9820
#
# Epoch 00020: val_loss did not improve from 0.00447
# Epoch 21/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0347 - accuracy: 0.9898 - val_loss: 0.0278 - val_accuracy: 0.9922
#
# Epoch 00021: val_loss did not improve from 0.00447
# Epoch 22/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0179 - accuracy: 0.9933 - val_loss: 0.0529 - val_accuracy: 0.9820
#
# Epoch 00022: val_loss did not improve from 0.00447
# Epoch 23/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 1.0023 - val_accuracy: 0.8328
#
# Epoch 00023: val_loss did not improve from 0.00447
# Epoch 24/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0169 - accuracy: 0.9942 - val_loss: 0.0296 - val_accuracy: 0.9937
#
# Epoch 00024: val_loss did not improve from 0.00447
# Epoch 25/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.0206 - val_accuracy: 0.9941
#
# Epoch 00025: val_loss did not improve from 0.00447
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 0.9941
# Val Score:  [0.02063116244971752, 0.994140625]
# Training on Fold:  2
# Epoch 1/25
# 320/320 [==============================] - 4s 10ms/step - loss: 0.4004 - accuracy: 0.8766 - val_loss: 3.3006 - val_accuracy: 0.6086
#
# Epoch 00001: val_loss did not improve from 0.00447
# Epoch 2/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1289 - accuracy: 0.9565 - val_loss: 0.6827 - val_accuracy: 0.8078
#
# Epoch 00002: val_loss did not improve from 0.00447
# Epoch 3/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0933 - accuracy: 0.9697 - val_loss: 0.4898 - val_accuracy: 0.8551
#
# Epoch 00003: val_loss did not improve from 0.00447
# Epoch 4/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0733 - accuracy: 0.9749 - val_loss: 0.0251 - val_accuracy: 0.9910
#
# Epoch 00004: val_loss did not improve from 0.00447
# Epoch 5/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0571 - accuracy: 0.9812 - val_loss: 0.0191 - val_accuracy: 0.9941
#
# Epoch 00005: val_loss did not improve from 0.00447
# Epoch 6/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0462 - accuracy: 0.9861 - val_loss: 0.1316 - val_accuracy: 0.9555
#
# Epoch 00006: val_loss did not improve from 0.00447
# Epoch 7/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0386 - accuracy: 0.9884 - val_loss: 0.0507 - val_accuracy: 0.9844
#
# Epoch 00007: val_loss did not improve from 0.00447
# Epoch 8/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0479 - accuracy: 0.9852 - val_loss: 0.0275 - val_accuracy: 0.9930
#
# Epoch 00008: val_loss did not improve from 0.00447
# Epoch 9/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0414 - accuracy: 0.9864 - val_loss: 0.0134 - val_accuracy: 0.9961
#
# Epoch 00009: val_loss did not improve from 0.00447
# Epoch 10/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 0.0336 - val_accuracy: 0.9875
#
# Epoch 00010: val_loss did not improve from 0.00447
# Epoch 11/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0273 - accuracy: 0.9924 - val_loss: 0.0082 - val_accuracy: 0.9969
#
# Epoch 00011: val_loss did not improve from 0.00447
# Epoch 12/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9929 - val_loss: 0.0459 - val_accuracy: 0.9871
#
# Epoch 00012: val_loss did not improve from 0.00447
# Epoch 13/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0254 - accuracy: 0.9918 - val_loss: 0.0134 - val_accuracy: 0.9949
#
# Epoch 00013: val_loss did not improve from 0.00447
# Epoch 14/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0217 - accuracy: 0.9935 - val_loss: 0.0173 - val_accuracy: 0.9953
#
# Epoch 00014: val_loss did not improve from 0.00447
# Epoch 15/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0354 - accuracy: 0.9888 - val_loss: 0.0512 - val_accuracy: 0.9832
#
# Epoch 00015: val_loss did not improve from 0.00447
# Epoch 16/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0304 - accuracy: 0.9900 - val_loss: 0.0236 - val_accuracy: 0.9930
#
# Epoch 00016: val_loss did not improve from 0.00447
# Epoch 17/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.5879 - val_accuracy: 0.8793
#
# Epoch 00017: val_loss did not improve from 0.00447
# Epoch 18/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0302 - accuracy: 0.9917 - val_loss: 0.0135 - val_accuracy: 0.9961
#
# Epoch 00018: val_loss did not improve from 0.00447
# Epoch 19/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0219 - accuracy: 0.9933 - val_loss: 0.0057 - val_accuracy: 0.9969
#
# Epoch 00019: val_loss did not improve from 0.00447
# Epoch 20/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.1311 - val_accuracy: 0.9648
#
# Epoch 00020: val_loss did not improve from 0.00447
# Epoch 21/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0159 - accuracy: 0.9940 - val_loss: 0.0068 - val_accuracy: 0.9980
#
# Epoch 00021: val_loss did not improve from 0.00447
# Epoch 22/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0159 - accuracy: 0.9942 - val_loss: 0.0059 - val_accuracy: 0.9980
#
# Epoch 00022: val_loss did not improve from 0.00447
# Epoch 23/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00023: val_loss improved from 0.00447 to 0.00386, saving model to model.h5
# Epoch 24/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00024: val_loss improved from 0.00386 to 0.00304, saving model to model.h5
# Epoch 25/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00025: val_loss did not improve from 0.00304
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.9984
# Val Score:  [0.004375389311462641, 0.9984375238418579]
# Training on Fold:  3
# Epoch 1/25
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4177 - accuracy: 0.8710 - val_loss: 1.4380 - val_accuracy: 0.6227
#
# Epoch 00001: val_loss did not improve from 0.00304
# Epoch 2/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1641 - accuracy: 0.9403 - val_loss: 0.2799 - val_accuracy: 0.8973
#
# Epoch 00002: val_loss did not improve from 0.00304
# Epoch 3/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1000 - accuracy: 0.9654 - val_loss: 0.2373 - val_accuracy: 0.9125
#
# Epoch 00003: val_loss did not improve from 0.00304
# Epoch 4/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0699 - accuracy: 0.9761 - val_loss: 0.1971 - val_accuracy: 0.9328
#
# Epoch 00004: val_loss did not improve from 0.00304
# Epoch 5/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0461 - accuracy: 0.9840 - val_loss: 0.0358 - val_accuracy: 0.9898
#
# Epoch 00005: val_loss did not improve from 0.00304
# Epoch 6/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0409 - accuracy: 0.9864 - val_loss: 0.0190 - val_accuracy: 0.9934
#
# Epoch 00006: val_loss did not improve from 0.00304
# Epoch 7/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0340 - accuracy: 0.9885 - val_loss: 0.0549 - val_accuracy: 0.9816
#
# Epoch 00007: val_loss did not improve from 0.00304
# Epoch 8/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0305 - accuracy: 0.9896 - val_loss: 0.0686 - val_accuracy: 0.9695
#
# Epoch 00008: val_loss did not improve from 0.00304
# Epoch 9/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0328 - accuracy: 0.9882 - val_loss: 0.0105 - val_accuracy: 0.9961
#
# Epoch 00009: val_loss did not improve from 0.00304
# Epoch 10/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0239 - accuracy: 0.9924 - val_loss: 0.0103 - val_accuracy: 0.9965
#
# Epoch 00010: val_loss did not improve from 0.00304
# Epoch 11/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0282 - accuracy: 0.9911 - val_loss: 0.0236 - val_accuracy: 0.9914
#
# Epoch 00011: val_loss did not improve from 0.00304
# Epoch 12/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0217 - accuracy: 0.9926 - val_loss: 0.0663 - val_accuracy: 0.9852
#
# Epoch 00012: val_loss did not improve from 0.00304
# Epoch 13/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0300 - accuracy: 0.9886 - val_loss: 0.0129 - val_accuracy: 0.9945
#
# Epoch 00013: val_loss did not improve from 0.00304
# Epoch 14/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.0181 - val_accuracy: 0.9910
#
# Epoch 00014: val_loss did not improve from 0.00304
# Epoch 15/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0260 - accuracy: 0.9911 - val_loss: 0.4319 - val_accuracy: 0.8699
#
# Epoch 00015: val_loss did not improve from 0.00304
# Epoch 16/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.0085 - val_accuracy: 0.9980
#
# Epoch 00016: val_loss did not improve from 0.00304
# Epoch 17/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.0088 - val_accuracy: 0.9965
#
# Epoch 00017: val_loss did not improve from 0.00304
# Epoch 18/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00018: val_loss did not improve from 0.00304
# Epoch 19/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00019: val_loss did not improve from 0.00304
# Epoch 20/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0159 - accuracy: 0.9946 - val_loss: 0.0094 - val_accuracy: 0.9969
#
# Epoch 00020: val_loss did not improve from 0.00304
# Epoch 21/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0243 - accuracy: 0.9921 - val_loss: 0.0122 - val_accuracy: 0.9953
#
# Epoch 00021: val_loss did not improve from 0.00304
# Epoch 22/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9947 - val_loss: 0.1059 - val_accuracy: 0.9730
#
# Epoch 00022: val_loss did not improve from 0.00304
# Epoch 23/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0090 - val_accuracy: 0.9969
#
# Epoch 00023: val_loss did not improve from 0.00304
# Epoch 24/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 0.0503 - val_accuracy: 0.9836
#
# Epoch 00024: val_loss did not improve from 0.00304
# Epoch 25/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.2156 - val_accuracy: 0.9676
#
# Epoch 00025: val_loss did not improve from 0.00304
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2156 - accuracy: 0.9676
# Val Score:  [0.21556170284748077, 0.967578113079071]
# Training on Fold:  4
# Epoch 1/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.3988 - accuracy: 0.8701 - val_loss: 2.5983 - val_accuracy: 0.4895
#
# Epoch 00001: val_loss did not improve from 0.00304
# Epoch 2/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1295 - accuracy: 0.9515 - val_loss: 0.1490 - val_accuracy: 0.9359
#
# Epoch 00002: val_loss did not improve from 0.00304
# Epoch 3/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0812 - accuracy: 0.9705 - val_loss: 0.4869 - val_accuracy: 0.8449
#
# Epoch 00003: val_loss did not improve from 0.00304
# Epoch 4/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0479 - accuracy: 0.9847 - val_loss: 0.1867 - val_accuracy: 0.9242
#
# Epoch 00004: val_loss did not improve from 0.00304
# Epoch 5/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0471 - accuracy: 0.9835 - val_loss: 0.5537 - val_accuracy: 0.8387
#
# Epoch 00005: val_loss did not improve from 0.00304
# Epoch 6/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0357 - accuracy: 0.9884 - val_loss: 0.0773 - val_accuracy: 0.9711
#
# Epoch 00006: val_loss did not improve from 0.00304
# Epoch 7/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0253 - accuracy: 0.9913 - val_loss: 0.0620 - val_accuracy: 0.9801
#
# Epoch 00007: val_loss did not improve from 0.00304
# Epoch 8/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0380 - accuracy: 0.9874 - val_loss: 0.1727 - val_accuracy: 0.9371
#
# Epoch 00008: val_loss did not improve from 0.00304
# Epoch 9/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0228 - accuracy: 0.9926 - val_loss: 0.0415 - val_accuracy: 0.9840
#
# Epoch 00009: val_loss did not improve from 0.00304
# Epoch 10/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0209 - accuracy: 0.9921 - val_loss: 0.0335 - val_accuracy: 0.9871
#
# Epoch 00010: val_loss did not improve from 0.00304
# Epoch 11/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.0240 - val_accuracy: 0.9922
#
# Epoch 00011: val_loss did not improve from 0.00304
# Epoch 12/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0197 - accuracy: 0.9931 - val_loss: 1.3509 - val_accuracy: 0.7918
#
# Epoch 00012: val_loss did not improve from 0.00304
# Epoch 13/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9927 - val_loss: 0.0427 - val_accuracy: 0.9867
#
# Epoch 00013: val_loss did not improve from 0.00304
# Epoch 14/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0175 - accuracy: 0.9935 - val_loss: 0.1818 - val_accuracy: 0.9563
#
# Epoch 00014: val_loss did not improve from 0.00304
# Epoch 15/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.1442 - val_accuracy: 0.9559
#
# Epoch 00015: val_loss did not improve from 0.00304
# Epoch 16/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0216 - accuracy: 0.9923 - val_loss: 0.3456 - val_accuracy: 0.9168
#
# Epoch 00016: val_loss did not improve from 0.00304
# Epoch 17/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0185 - accuracy: 0.9928 - val_loss: 0.0490 - val_accuracy: 0.9871
#
# Epoch 00017: val_loss did not improve from 0.00304
# Epoch 18/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0201 - accuracy: 0.9930 - val_loss: 0.0062 - val_accuracy: 0.9965
#
# Epoch 00018: val_loss did not improve from 0.00304
# Epoch 19/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00019: val_loss did not improve from 0.00304
# Epoch 20/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0126 - accuracy: 0.9946 - val_loss: 0.0031 - val_accuracy: 0.9977
#
# Epoch 00020: val_loss did not improve from 0.00304
# Epoch 21/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0197 - accuracy: 0.9931 - val_loss: 1.8901 - val_accuracy: 0.7629
#
# Epoch 00021: val_loss did not improve from 0.00304
# Epoch 22/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0206 - accuracy: 0.9927 - val_loss: 0.0242 - val_accuracy: 0.9922
#
# Epoch 00022: val_loss did not improve from 0.00304
# Epoch 23/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9926 - val_loss: 0.0659 - val_accuracy: 0.9777
#
# Epoch 00023: val_loss did not improve from 0.00304
# Epoch 24/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.0255 - val_accuracy: 0.9906
#
# Epoch 00024: val_loss did not improve from 0.00304
# Epoch 25/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 0.1060 - val_accuracy: 0.9738
#
# Epoch 00025: val_loss did not improve from 0.00304
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1060 - accuracy: 0.9738
# Val Score:  [0.10601770877838135, 0.973828136920929]
# Training on Fold:  5
# Epoch 1/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.4035 - accuracy: 0.8691 - val_loss: 6.3790 - val_accuracy: 0.3520
#
# Epoch 00001: val_loss did not improve from 0.00304
# Epoch 2/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1406 - accuracy: 0.9499 - val_loss: 1.5099 - val_accuracy: 0.7488
#
# Epoch 00002: val_loss did not improve from 0.00304
# Epoch 3/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0922 - accuracy: 0.9684 - val_loss: 0.3865 - val_accuracy: 0.8969
#
# Epoch 00003: val_loss did not improve from 0.00304
# Epoch 4/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0665 - accuracy: 0.9758 - val_loss: 0.2958 - val_accuracy: 0.9215
#
# Epoch 00004: val_loss did not improve from 0.00304
# Epoch 5/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0486 - accuracy: 0.9840 - val_loss: 0.2072 - val_accuracy: 0.9371
#
# Epoch 00005: val_loss did not improve from 0.00304
# Epoch 6/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0458 - accuracy: 0.9847 - val_loss: 0.0311 - val_accuracy: 0.9910
#
# Epoch 00006: val_loss did not improve from 0.00304
# Epoch 7/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0330 - accuracy: 0.9891 - val_loss: 0.1143 - val_accuracy: 0.9680
#
# Epoch 00007: val_loss did not improve from 0.00304
# Epoch 8/25
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0324 - accuracy: 0.9893 - val_loss: 0.3177 - val_accuracy: 0.9035
#
# Epoch 00008: val_loss did not improve from 0.00304
# Epoch 9/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0250 - accuracy: 0.9912 - val_loss: 0.7808 - val_accuracy: 0.8754
#
# Epoch 00009: val_loss did not improve from 0.00304
# Epoch 10/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0374 - accuracy: 0.9882 - val_loss: 0.0382 - val_accuracy: 0.9867
#
# Epoch 00010: val_loss did not improve from 0.00304
# Epoch 11/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0234 - accuracy: 0.9922 - val_loss: 0.0191 - val_accuracy: 0.9937
#
# Epoch 00011: val_loss did not improve from 0.00304
# Epoch 12/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.0188 - val_accuracy: 0.9934
#
# Epoch 00012: val_loss did not improve from 0.00304
# Epoch 13/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0152 - accuracy: 0.9944 - val_loss: 0.0113 - val_accuracy: 0.9969
#
# Epoch 00013: val_loss did not improve from 0.00304
# Epoch 14/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0295 - accuracy: 0.9895 - val_loss: 0.0461 - val_accuracy: 0.9824
#
# Epoch 00014: val_loss did not improve from 0.00304
# Epoch 15/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0180 - accuracy: 0.9935 - val_loss: 0.0126 - val_accuracy: 0.9953
#
# Epoch 00015: val_loss did not improve from 0.00304
# Epoch 16/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.1343 - val_accuracy: 0.9570
#
# Epoch 00016: val_loss did not improve from 0.00304
# Epoch 17/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0219 - accuracy: 0.9927 - val_loss: 0.3242 - val_accuracy: 0.9230
#
# Epoch 00017: val_loss did not improve from 0.00304
# Epoch 18/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0212 - accuracy: 0.9923 - val_loss: 0.0099 - val_accuracy: 0.9961
#
# Epoch 00018: val_loss did not improve from 0.00304
# Epoch 19/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0183 - accuracy: 0.9930 - val_loss: 0.0112 - val_accuracy: 0.9957
#
# Epoch 00019: val_loss did not improve from 0.00304
# Epoch 20/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00020: val_loss did not improve from 0.00304
# Epoch 21/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0090 - val_accuracy: 0.9961
#
# Epoch 00021: val_loss did not improve from 0.00304
# Epoch 22/25
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0116 - accuracy: 0.9951 - val_loss: 0.0253 - val_accuracy: 0.9914
#
# Epoch 00022: val_loss did not improve from 0.00304
# Epoch 23/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0153 - accuracy: 0.9937 - val_loss: 0.4219 - val_accuracy: 0.8898
#
# Epoch 00023: val_loss did not improve from 0.00304
# Epoch 24/25
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0189 - accuracy: 0.9935 - val_loss: 0.2214 - val_accuracy: 0.9285
#
# Epoch 00024: val_loss did not improve from 0.00304
# Epoch 25/25
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0188 - accuracy: 0.9932 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00025: val_loss did not improve from 0.00304
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9965
# Val Score:  [0.008237931877374649, 0.9964843988418579]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       1.00      1.00      1.00       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       0.99      1.00      1.00       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9981
# Test Accuracy: 99.81250166893005

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
