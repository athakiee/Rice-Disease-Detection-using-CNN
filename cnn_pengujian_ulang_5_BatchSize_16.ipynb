# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-4
BS = 16
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_48 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_72 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_73 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_74 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_75 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 12800)             0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_76 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_77 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 640/640 [==============================] - 6s 8ms/step - loss: 0.5896 - accuracy: 0.8121 - val_loss: 0.5524 - val_accuracy: 0.8191
#
# Epoch 00001: val_loss improved from inf to 0.55238, saving model to model.h5
# Epoch 2/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.2510 - accuracy: 0.9117 - val_loss: 0.3036 - val_accuracy: 0.8977
#
# Epoch 00002: val_loss improved from 0.55238 to 0.30363, saving model to model.h5
# Epoch 3/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.1881 - accuracy: 0.9341 - val_loss: 0.2886 - val_accuracy: 0.9047
#
# Epoch 00003: val_loss improved from 0.30363 to 0.28861, saving model to model.h5
# Epoch 4/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.1334 - accuracy: 0.9530 - val_loss: 0.4499 - val_accuracy: 0.8719
#
# Epoch 00004: val_loss did not improve from 0.28861
# Epoch 5/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.1141 - accuracy: 0.9589 - val_loss: 0.1447 - val_accuracy: 0.9438
#
# Epoch 00005: val_loss improved from 0.28861 to 0.14475, saving model to model.h5
# Epoch 6/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0829 - accuracy: 0.9714 - val_loss: 0.1134 - val_accuracy: 0.9777
#
# Epoch 00006: val_loss improved from 0.14475 to 0.11338, saving model to model.h5
# Epoch 7/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0813 - accuracy: 0.9714 - val_loss: 0.0858 - val_accuracy: 0.9789
#
# Epoch 00007: val_loss improved from 0.11338 to 0.08576, saving model to model.h5
# Epoch 8/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0715 - accuracy: 0.9763 - val_loss: 0.0545 - val_accuracy: 0.9832
#
# Epoch 00008: val_loss improved from 0.08576 to 0.05451, saving model to model.h5
# Epoch 9/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0636 - accuracy: 0.9776 - val_loss: 0.0272 - val_accuracy: 0.9906
#
# Epoch 00009: val_loss improved from 0.05451 to 0.02719, saving model to model.h5
# Epoch 10/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0598 - accuracy: 0.9808 - val_loss: 0.1027 - val_accuracy: 0.9676
#
# Epoch 00010: val_loss did not improve from 0.02719
# Epoch 11/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0531 - accuracy: 0.9834 - val_loss: 0.0411 - val_accuracy: 0.9918
#
# Epoch 00011: val_loss did not improve from 0.02719
# Epoch 12/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0435 - accuracy: 0.9849 - val_loss: 0.0651 - val_accuracy: 0.9801
#
# Epoch 00012: val_loss did not improve from 0.02719
# Epoch 13/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0360 - accuracy: 0.9884 - val_loss: 0.0593 - val_accuracy: 0.9879
#
# Epoch 00013: val_loss did not improve from 0.02719
# Epoch 14/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0379 - accuracy: 0.9871 - val_loss: 0.0414 - val_accuracy: 0.9898
#
# Epoch 00014: val_loss did not improve from 0.02719
# Epoch 15/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0327 - accuracy: 0.9887 - val_loss: 0.0188 - val_accuracy: 0.9965
#
# Epoch 00015: val_loss improved from 0.02719 to 0.01881, saving model to model.h5
# Epoch 16/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0348 - accuracy: 0.9894 - val_loss: 0.1531 - val_accuracy: 0.9469
#
# Epoch 00016: val_loss did not improve from 0.01881
# Epoch 17/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0270 - accuracy: 0.9904 - val_loss: 0.0106 - val_accuracy: 0.9973
#
# Epoch 00017: val_loss improved from 0.01881 to 0.01059, saving model to model.h5
# Epoch 18/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0272 - accuracy: 0.9913 - val_loss: 0.0172 - val_accuracy: 0.9941
#
# Epoch 00018: val_loss did not improve from 0.01059
# Epoch 19/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0307 - accuracy: 0.9897 - val_loss: 0.0863 - val_accuracy: 0.9730
#
# Epoch 00019: val_loss did not improve from 0.01059
# Epoch 20/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0239 - accuracy: 0.9922 - val_loss: 0.0116 - val_accuracy: 0.9957
#
# Epoch 00020: val_loss did not improve from 0.01059
# Epoch 21/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.0275 - val_accuracy: 0.9957
#
# Epoch 00021: val_loss did not improve from 0.01059
# Epoch 22/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0228 - accuracy: 0.9928 - val_loss: 0.0166 - val_accuracy: 0.9945
#
# Epoch 00022: val_loss did not improve from 0.01059
# Epoch 23/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 0.0201 - val_accuracy: 0.9945
#
# Epoch 00023: val_loss did not improve from 0.01059
# Epoch 24/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 0.0690 - val_accuracy: 0.9770
#
# Epoch 00024: val_loss did not improve from 0.01059
# Epoch 25/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0200 - accuracy: 0.9936 - val_loss: 0.0124 - val_accuracy: 0.9969
#
# Epoch 00025: val_loss did not improve from 0.01059
# Epoch 26/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.0278 - val_accuracy: 0.9953
#
# Epoch 00026: val_loss did not improve from 0.01059
# Epoch 27/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0094 - val_accuracy: 0.9969
#
# Epoch 00027: val_loss improved from 0.01059 to 0.00939, saving model to model.h5
# Epoch 28/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0173 - accuracy: 0.9945 - val_loss: 0.0429 - val_accuracy: 0.9867
#
# Epoch 00028: val_loss did not improve from 0.00939
# Epoch 29/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0186 - accuracy: 0.9943 - val_loss: 0.0159 - val_accuracy: 0.9957
#
# Epoch 00029: val_loss did not improve from 0.00939
# Epoch 30/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0210 - accuracy: 0.9932 - val_loss: 0.1001 - val_accuracy: 0.9711
#
# Epoch 00030: val_loss did not improve from 0.00939
# Epoch 31/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0168 - accuracy: 0.9941 - val_loss: 0.0180 - val_accuracy: 0.9937
#
# Epoch 00031: val_loss did not improve from 0.00939
# Epoch 32/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.0095 - val_accuracy: 0.9977
#
# Epoch 00032: val_loss did not improve from 0.00939
# Epoch 33/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0145 - accuracy: 0.9949 - val_loss: 0.0033 - val_accuracy: 0.9988
#
# Epoch 00033: val_loss improved from 0.00939 to 0.00328, saving model to model.h5
# Epoch 34/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0188 - accuracy: 0.9941 - val_loss: 0.0094 - val_accuracy: 0.9977
#
# Epoch 00034: val_loss did not improve from 0.00328
# Epoch 35/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.0077 - val_accuracy: 0.9969
#
# Epoch 00035: val_loss did not improve from 0.00328
# Epoch 36/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0149 - accuracy: 0.9949 - val_loss: 0.0754 - val_accuracy: 0.9762
#
# Epoch 00036: val_loss did not improve from 0.00328
# Epoch 37/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0138 - accuracy: 0.9952 - val_loss: 0.0073 - val_accuracy: 0.9973
#
# Epoch 00037: val_loss did not improve from 0.00328
# Epoch 38/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.1666 - val_accuracy: 0.9812
#
# Epoch 00038: val_loss did not improve from 0.00328
# Epoch 39/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0081 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00328
# Epoch 40/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.0196 - val_accuracy: 0.9949
#
# Epoch 00040: val_loss did not improve from 0.00328
# Epoch 41/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.0058 - val_accuracy: 0.9980
#
# Epoch 00041: val_loss did not improve from 0.00328
# Epoch 42/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.0088 - val_accuracy: 0.9977
#
# Epoch 00042: val_loss did not improve from 0.00328
# Epoch 43/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00043: val_loss did not improve from 0.00328
# Epoch 44/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.0131 - val_accuracy: 0.9953
#
# Epoch 00044: val_loss did not improve from 0.00328
# Epoch 45/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.0090 - val_accuracy: 0.9973
#
# Epoch 00045: val_loss did not improve from 0.00328
# Epoch 46/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.0111 - val_accuracy: 0.9973
#
# Epoch 00046: val_loss did not improve from 0.00328
# Epoch 47/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 0.0061 - val_accuracy: 0.9973
#
# Epoch 00047: val_loss did not improve from 0.00328
# Epoch 48/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00048: val_loss did not improve from 0.00328
# Epoch 49/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0092 - accuracy: 0.9964 - val_loss: 0.0208 - val_accuracy: 0.9965
#
# Epoch 00049: val_loss did not improve from 0.00328
# Epoch 50/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.0069 - val_accuracy: 0.9977
#
# Epoch 00050: val_loss did not improve from 0.00328
# Epoch 51/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.0072 - val_accuracy: 0.9957
#
# Epoch 00051: val_loss did not improve from 0.00328
# Epoch 52/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0090 - val_accuracy: 0.9973
#
# Epoch 00052: val_loss did not improve from 0.00328
# Epoch 53/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0091 - val_accuracy: 0.9980
#
# Epoch 00053: val_loss did not improve from 0.00328
# Epoch 54/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0119 - accuracy: 0.9957 - val_loss: 0.0049 - val_accuracy: 0.9969
#
# Epoch 00054: val_loss did not improve from 0.00328
# Epoch 55/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0082 - val_accuracy: 0.9977
#
# Epoch 00055: val_loss did not improve from 0.00328
# Epoch 56/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.0427 - val_accuracy: 0.9852
#
# Epoch 00056: val_loss did not improve from 0.00328
# Epoch 57/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00057: val_loss did not improve from 0.00328
# Epoch 58/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00058: val_loss improved from 0.00328 to 0.00233, saving model to model.h5
# Epoch 59/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00059: val_loss did not improve from 0.00233
# Epoch 60/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0089 - accuracy: 0.9963 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00060: val_loss did not improve from 0.00233
# Epoch 61/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0136 - accuracy: 0.9964 - val_loss: 0.0053 - val_accuracy: 0.9980
#
# Epoch 00061: val_loss did not improve from 0.00233
# Epoch 62/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00062: val_loss did not improve from 0.00233
# Epoch 63/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.0102 - val_accuracy: 0.9965
#
# Epoch 00063: val_loss did not improve from 0.00233
# Epoch 64/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0055 - val_accuracy: 0.9980
#
# Epoch 00064: val_loss did not improve from 0.00233
# Epoch 65/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 0.0070 - val_accuracy: 0.9980
#
# Epoch 00065: val_loss did not improve from 0.00233
# Epoch 66/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00066: val_loss did not improve from 0.00233
# Epoch 67/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.0245 - val_accuracy: 0.9969
#
# Epoch 00067: val_loss did not improve from 0.00233
# Epoch 68/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.0196 - val_accuracy: 0.9977
#
# Epoch 00068: val_loss did not improve from 0.00233
# Epoch 69/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 0.0176 - val_accuracy: 0.9969
#
# Epoch 00069: val_loss did not improve from 0.00233
# Epoch 70/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0096 - accuracy: 0.9961 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00233
# Epoch 71/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0074 - accuracy: 0.9966 - val_loss: 0.0151 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00233
# Epoch 72/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0123 - val_accuracy: 0.9984
#
# Epoch 00072: val_loss did not improve from 0.00233
# Epoch 73/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0063 - accuracy: 0.9974 - val_loss: 0.0096 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00233
# Epoch 74/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0152 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00233
# Epoch 75/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0085 - accuracy: 0.9964 - val_loss: 0.0067 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00233
# Epoch 76/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0051 - accuracy: 0.9975 - val_loss: 0.0126 - val_accuracy: 0.9977
#
# Epoch 00076: val_loss did not improve from 0.00233
# Epoch 77/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0089 - accuracy: 0.9964 - val_loss: 0.0356 - val_accuracy: 0.9973
#
# Epoch 00077: val_loss did not improve from 0.00233
# Epoch 78/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.0052 - val_accuracy: 0.9977
#
# Epoch 00078: val_loss did not improve from 0.00233
# Epoch 79/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 0.0076 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00233
# Epoch 80/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0049 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00233
# Epoch 81/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0089 - accuracy: 0.9965 - val_loss: 0.0100 - val_accuracy: 0.9977
#
# Epoch 00081: val_loss did not improve from 0.00233
# Epoch 82/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0135 - accuracy: 0.9944 - val_loss: 0.0100 - val_accuracy: 0.9969
#
# Epoch 00082: val_loss did not improve from 0.00233
# Epoch 83/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0203 - val_accuracy: 0.9977
#
# Epoch 00083: val_loss did not improve from 0.00233
# Epoch 84/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0064 - accuracy: 0.9972 - val_loss: 0.0090 - val_accuracy: 0.9977
#
# Epoch 00084: val_loss did not improve from 0.00233
# Epoch 85/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0101 - val_accuracy: 0.9973
#
# Epoch 00085: val_loss did not improve from 0.00233
# Epoch 86/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0059 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00233
# Epoch 87/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0047 - val_accuracy: 0.9977
#
# Epoch 00087: val_loss did not improve from 0.00233
# Epoch 88/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.0053 - val_accuracy: 0.9969
#
# Epoch 00088: val_loss did not improve from 0.00233
# Epoch 89/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0140 - val_accuracy: 0.9973
#
# Epoch 00089: val_loss did not improve from 0.00233
# Epoch 90/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.0097 - val_accuracy: 0.9973
#
# Epoch 00090: val_loss did not improve from 0.00233
# Epoch 91/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0080 - accuracy: 0.9970 - val_loss: 0.0089 - val_accuracy: 0.9977
#
# Epoch 00091: val_loss did not improve from 0.00233
# Epoch 92/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0075 - accuracy: 0.9970 - val_loss: 0.0078 - val_accuracy: 0.9973
#
# Epoch 00092: val_loss did not improve from 0.00233
# Epoch 93/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00093: val_loss did not improve from 0.00233
# Epoch 94/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0064 - accuracy: 0.9970 - val_loss: 0.0132 - val_accuracy: 0.9973
#
# Epoch 00094: val_loss did not improve from 0.00233
# Epoch 95/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0063 - val_accuracy: 0.9980
#
# Epoch 00095: val_loss did not improve from 0.00233
# Epoch 96/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0086 - accuracy: 0.9964 - val_loss: 0.0047 - val_accuracy: 0.9984
#
# Epoch 00096: val_loss did not improve from 0.00233
# Epoch 97/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0061 - accuracy: 0.9968 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00233
# Epoch 98/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00098: val_loss did not improve from 0.00233
# Epoch 99/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0054 - accuracy: 0.9976 - val_loss: 0.0060 - val_accuracy: 0.9969
#
# Epoch 00099: val_loss did not improve from 0.00233
# Epoch 100/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0080 - accuracy: 0.9965 - val_loss: 0.0101 - val_accuracy: 0.9977
#
# Epoch 00100: val_loss did not improve from 0.00233
# 80/80 [==============================] - 1s 4ms/step - loss: 0.0101 - accuracy: 0.9977
# Val Score:  [0.010055353865027428, 0.9976562261581421]
# Training on Fold:  2
# Epoch 1/100
# 640/640 [==============================] - 6s 8ms/step - loss: 0.4308 - accuracy: 0.8669 - val_loss: 0.5198 - val_accuracy: 0.8180
#
# Epoch 00001: val_loss did not improve from 0.00233
# Epoch 2/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.1756 - accuracy: 0.9394 - val_loss: 0.5775 - val_accuracy: 0.8258
#
# Epoch 00002: val_loss did not improve from 0.00233
# Epoch 3/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.1221 - accuracy: 0.9578 - val_loss: 0.2879 - val_accuracy: 0.9195
#
# Epoch 00003: val_loss did not improve from 0.00233
# Epoch 4/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0996 - accuracy: 0.9659 - val_loss: 0.3772 - val_accuracy: 0.8719
#
# Epoch 00004: val_loss did not improve from 0.00233
# Epoch 5/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0931 - accuracy: 0.9688 - val_loss: 0.0650 - val_accuracy: 0.9777
#
# Epoch 00005: val_loss did not improve from 0.00233
# Epoch 6/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0699 - accuracy: 0.9768 - val_loss: 0.0921 - val_accuracy: 0.9785
#
# Epoch 00006: val_loss did not improve from 0.00233
# Epoch 7/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0651 - accuracy: 0.9781 - val_loss: 0.1017 - val_accuracy: 0.9656
#
# Epoch 00007: val_loss did not improve from 0.00233
# Epoch 8/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0474 - accuracy: 0.9839 - val_loss: 0.1683 - val_accuracy: 0.9527
#
# Epoch 00008: val_loss did not improve from 0.00233
# Epoch 9/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0523 - accuracy: 0.9812 - val_loss: 0.0830 - val_accuracy: 0.9719
#
# Epoch 00009: val_loss did not improve from 0.00233
# Epoch 10/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0474 - accuracy: 0.9825 - val_loss: 0.1124 - val_accuracy: 0.9719
#
# Epoch 00010: val_loss did not improve from 0.00233
# Epoch 11/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0378 - accuracy: 0.9870 - val_loss: 0.0638 - val_accuracy: 0.9844
#
# Epoch 00011: val_loss did not improve from 0.00233
# Epoch 12/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0346 - accuracy: 0.9896 - val_loss: 0.0339 - val_accuracy: 0.9906
#
# Epoch 00012: val_loss did not improve from 0.00233
# Epoch 13/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0309 - accuracy: 0.9895 - val_loss: 0.0366 - val_accuracy: 0.9930
#
# Epoch 00013: val_loss did not improve from 0.00233
# Epoch 14/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 0.0498 - val_accuracy: 0.9863
#
# Epoch 00014: val_loss did not improve from 0.00233
# Epoch 15/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0228 - accuracy: 0.9928 - val_loss: 0.0216 - val_accuracy: 0.9934
#
# Epoch 00015: val_loss did not improve from 0.00233
# Epoch 16/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0258 - accuracy: 0.9916 - val_loss: 0.0312 - val_accuracy: 0.9891
#
# Epoch 00016: val_loss did not improve from 0.00233
# Epoch 17/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0265 - accuracy: 0.9902 - val_loss: 0.0101 - val_accuracy: 0.9957
#
# Epoch 00017: val_loss did not improve from 0.00233
# Epoch 18/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0248 - accuracy: 0.9909 - val_loss: 0.0134 - val_accuracy: 0.9949
#
# Epoch 00018: val_loss did not improve from 0.00233
# Epoch 19/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0226 - accuracy: 0.9934 - val_loss: 0.0340 - val_accuracy: 0.9910
#
# Epoch 00019: val_loss did not improve from 0.00233
# Epoch 20/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0242 - accuracy: 0.9926 - val_loss: 0.0177 - val_accuracy: 0.9945
#
# Epoch 00020: val_loss did not improve from 0.00233
# Epoch 21/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.0094 - val_accuracy: 0.9980
#
# Epoch 00021: val_loss did not improve from 0.00233
# Epoch 22/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 0.0182 - val_accuracy: 0.9922
#
# Epoch 00022: val_loss did not improve from 0.00233
# Epoch 23/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0152 - accuracy: 0.9949 - val_loss: 0.0918 - val_accuracy: 0.9812
#
# Epoch 00023: val_loss did not improve from 0.00233
# Epoch 24/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.0206 - val_accuracy: 0.9934
#
# Epoch 00024: val_loss did not improve from 0.00233
# Epoch 25/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0182 - val_accuracy: 0.9949
#
# Epoch 00025: val_loss did not improve from 0.00233
# Epoch 26/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.0154 - val_accuracy: 0.9973
#
# Epoch 00026: val_loss did not improve from 0.00233
# Epoch 27/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 0.9969
#
# Epoch 00027: val_loss did not improve from 0.00233
# Epoch 28/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0110 - accuracy: 0.9972 - val_loss: 0.0235 - val_accuracy: 0.9937
#
# Epoch 00028: val_loss did not improve from 0.00233
# Epoch 29/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0136 - accuracy: 0.9957 - val_loss: 0.0706 - val_accuracy: 0.9793
#
# Epoch 00029: val_loss did not improve from 0.00233
# Epoch 30/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0192 - accuracy: 0.9933 - val_loss: 0.0069 - val_accuracy: 0.9980
#
# Epoch 00030: val_loss did not improve from 0.00233
# Epoch 31/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.0132 - val_accuracy: 0.9973
#
# Epoch 00031: val_loss did not improve from 0.00233
# Epoch 32/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0164 - accuracy: 0.9957 - val_loss: 0.0133 - val_accuracy: 0.9969
#
# Epoch 00032: val_loss did not improve from 0.00233
# Epoch 33/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.0132 - val_accuracy: 0.9957
#
# Epoch 00033: val_loss did not improve from 0.00233
# Epoch 34/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.0165 - val_accuracy: 0.9969
#
# Epoch 00034: val_loss did not improve from 0.00233
# Epoch 35/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.0108 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00233
# Epoch 36/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.0060 - val_accuracy: 0.9973
#
# Epoch 00036: val_loss did not improve from 0.00233
# Epoch 37/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0144 - accuracy: 0.9947 - val_loss: 0.0070 - val_accuracy: 0.9969
#
# Epoch 00037: val_loss did not improve from 0.00233
# Epoch 38/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0108 - accuracy: 0.9959 - val_loss: 0.0133 - val_accuracy: 0.9949
#
# Epoch 00038: val_loss did not improve from 0.00233
# Epoch 39/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0121 - accuracy: 0.9964 - val_loss: 0.0063 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00233
# Epoch 40/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00040: val_loss did not improve from 0.00233
# Epoch 41/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.0133 - val_accuracy: 0.9957
#
# Epoch 00041: val_loss did not improve from 0.00233
# Epoch 42/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.0043 - val_accuracy: 0.9973
#
# Epoch 00042: val_loss did not improve from 0.00233
# Epoch 43/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 0.0095 - val_accuracy: 0.9969
#
# Epoch 00043: val_loss did not improve from 0.00233
# Epoch 44/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0130 - accuracy: 0.9943 - val_loss: 0.0115 - val_accuracy: 0.9973
#
# Epoch 00044: val_loss did not improve from 0.00233
# Epoch 45/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0172 - val_accuracy: 0.9957
#
# Epoch 00045: val_loss did not improve from 0.00233
# Epoch 46/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.0140 - val_accuracy: 0.9973
#
# Epoch 00046: val_loss did not improve from 0.00233
# Epoch 47/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.0213 - val_accuracy: 0.9941
#
# Epoch 00047: val_loss did not improve from 0.00233
# Epoch 48/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00048: val_loss did not improve from 0.00233
# Epoch 49/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.0450 - val_accuracy: 0.9906
#
# Epoch 00049: val_loss did not improve from 0.00233
# Epoch 50/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0105 - accuracy: 0.9960 - val_loss: 0.0179 - val_accuracy: 0.9961
#
# Epoch 00050: val_loss did not improve from 0.00233
# Epoch 51/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00051: val_loss did not improve from 0.00233
# Epoch 52/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0095 - accuracy: 0.9962 - val_loss: 0.0042 - val_accuracy: 0.9973
#
# Epoch 00052: val_loss did not improve from 0.00233
# Epoch 53/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0171 - val_accuracy: 0.9957
#
# Epoch 00053: val_loss did not improve from 0.00233
# Epoch 54/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0771 - val_accuracy: 0.9770
#
# Epoch 00054: val_loss did not improve from 0.00233
# Epoch 55/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0124 - accuracy: 0.9955 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00055: val_loss did not improve from 0.00233
# Epoch 56/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.0078 - val_accuracy: 0.9973
#
# Epoch 00056: val_loss did not improve from 0.00233
# Epoch 57/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0069 - accuracy: 0.9971 - val_loss: 0.0051 - val_accuracy: 0.9969
#
# Epoch 00057: val_loss did not improve from 0.00233
# Epoch 58/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0027 - val_accuracy: 0.9988
#
# Epoch 00058: val_loss did not improve from 0.00233
# Epoch 59/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0068 - val_accuracy: 0.9977
#
# Epoch 00059: val_loss did not improve from 0.00233
# Epoch 60/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.0038 - val_accuracy: 0.9977
#
# Epoch 00060: val_loss did not improve from 0.00233
# Epoch 61/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0085 - accuracy: 0.9964 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00061: val_loss did not improve from 0.00233
# Epoch 62/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0057 - val_accuracy: 0.9977
#
# Epoch 00062: val_loss did not improve from 0.00233
# Epoch 63/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 0.0344 - val_accuracy: 0.9906
#
# Epoch 00063: val_loss did not improve from 0.00233
# Epoch 64/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0086 - accuracy: 0.9966 - val_loss: 0.0057 - val_accuracy: 0.9977
#
# Epoch 00064: val_loss did not improve from 0.00233
# Epoch 65/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00065: val_loss did not improve from 0.00233
# Epoch 66/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0242 - val_accuracy: 0.9930
#
# Epoch 00066: val_loss did not improve from 0.00233
# Epoch 67/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00067: val_loss did not improve from 0.00233
# Epoch 68/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0055 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00233
# Epoch 69/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0125 - val_accuracy: 0.9973
#
# Epoch 00069: val_loss did not improve from 0.00233
# Epoch 70/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00233
# Epoch 71/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0080 - val_accuracy: 0.9973
#
# Epoch 00071: val_loss did not improve from 0.00233
# Epoch 72/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0049 - val_accuracy: 0.9984
#
# Epoch 00072: val_loss did not improve from 0.00233
# Epoch 73/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0050 - accuracy: 0.9976 - val_loss: 0.0071 - val_accuracy: 0.9973
#
# Epoch 00073: val_loss did not improve from 0.00233
# Epoch 74/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0077 - accuracy: 0.9966 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00074: val_loss did not improve from 0.00233
# Epoch 75/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.0067 - val_accuracy: 0.9973
#
# Epoch 00075: val_loss did not improve from 0.00233
# Epoch 76/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0067 - val_accuracy: 0.9969
#
# Epoch 00076: val_loss did not improve from 0.00233
# Epoch 77/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0050 - val_accuracy: 0.9973
#
# Epoch 00077: val_loss did not improve from 0.00233
# Epoch 78/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0065 - val_accuracy: 0.9969
#
# Epoch 00078: val_loss did not improve from 0.00233
# Epoch 79/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0084 - accuracy: 0.9963 - val_loss: 0.0065 - val_accuracy: 0.9980
#
# Epoch 00079: val_loss did not improve from 0.00233
# Epoch 80/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00233
# Epoch 81/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.0033 - val_accuracy: 0.9988
#
# Epoch 00081: val_loss did not improve from 0.00233
# Epoch 82/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00082: val_loss did not improve from 0.00233
# Epoch 83/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0053 - accuracy: 0.9974 - val_loss: 0.0066 - val_accuracy: 0.9973
#
# Epoch 00083: val_loss did not improve from 0.00233
# Epoch 84/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0078 - accuracy: 0.9967 - val_loss: 0.0042 - val_accuracy: 0.9977
#
# Epoch 00084: val_loss did not improve from 0.00233
# Epoch 85/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 0.0065 - val_accuracy: 0.9973
#
# Epoch 00085: val_loss did not improve from 0.00233
# Epoch 86/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0065 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00233
# Epoch 87/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0025 - val_accuracy: 0.9988
#
# Epoch 00087: val_loss did not improve from 0.00233
# Epoch 88/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00088: val_loss did not improve from 0.00233
# Epoch 89/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00233
# Epoch 90/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0067 - val_accuracy: 0.9965
#
# Epoch 00090: val_loss did not improve from 0.00233
# Epoch 91/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0105 - accuracy: 0.9959 - val_loss: 0.0091 - val_accuracy: 0.9973
#
# Epoch 00091: val_loss did not improve from 0.00233
# Epoch 92/100
# 80/80 [==============================] - 1s 4ms/step - loss: 0.0330 - accuracy: 0.9887
# Val Score:  [0.03297016769647598, 0.9886718988418579]
# Training on Fold:  3
# Epoch 1/100
# 640/640 [==============================] - 6s 8ms/step - loss: 0.4725 - accuracy: 0.8528 - val_loss: 0.8759 - val_accuracy: 0.7430
#
# Epoch 00001: val_loss did not improve from 0.00233
# Epoch 2/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.2025 - accuracy: 0.9276 - val_loss: 0.2574 - val_accuracy: 0.9187
#
# Epoch 00002: val_loss did not improve from 0.00233
# Epoch 3/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.1412 - accuracy: 0.9502 - val_loss: 0.1710 - val_accuracy: 0.9430
#
# Epoch 00003: val_loss did not improve from 0.00233
# Epoch 4/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.1150 - accuracy: 0.9583 - val_loss: 0.1623 - val_accuracy: 0.9457
#
# Epoch 00004: val_loss did not improve from 0.00233
# Epoch 5/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0938 - accuracy: 0.9685 - val_loss: 0.2411 - val_accuracy: 0.9180
#
# Epoch 00005: val_loss did not improve from 0.00233
# Epoch 6/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0851 - accuracy: 0.9709 - val_loss: 0.1608 - val_accuracy: 0.9484
#
# Epoch 00006: val_loss did not improve from 0.00233
# Epoch 7/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0766 - accuracy: 0.9750 - val_loss: 0.1462 - val_accuracy: 0.9473
#
# Epoch 00007: val_loss did not improve from 0.00233
# Epoch 8/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0651 - accuracy: 0.9777 - val_loss: 0.1191 - val_accuracy: 0.9664
#
# Epoch 00008: val_loss did not improve from 0.00233
# Epoch 9/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0539 - accuracy: 0.9826 - val_loss: 0.0465 - val_accuracy: 0.9859
#
# Epoch 00009: val_loss did not improve from 0.00233
# Epoch 10/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0527 - accuracy: 0.9832 - val_loss: 0.0784 - val_accuracy: 0.9789
#
# Epoch 00010: val_loss did not improve from 0.00233
# Epoch 11/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0430 - accuracy: 0.9864 - val_loss: 0.0303 - val_accuracy: 0.9906
#
# Epoch 00011: val_loss did not improve from 0.00233
# Epoch 12/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0367 - accuracy: 0.9873 - val_loss: 0.0294 - val_accuracy: 0.9918
#
# Epoch 00012: val_loss did not improve from 0.00233
# Epoch 13/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0400 - accuracy: 0.9875 - val_loss: 0.0794 - val_accuracy: 0.9836
#
# Epoch 00013: val_loss did not improve from 0.00233
# Epoch 14/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0342 - accuracy: 0.9894 - val_loss: 0.1174 - val_accuracy: 0.9617
#
# Epoch 00014: val_loss did not improve from 0.00233
# Epoch 15/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0346 - accuracy: 0.9889 - val_loss: 0.0812 - val_accuracy: 0.9801
#
# Epoch 00015: val_loss did not improve from 0.00233
# Epoch 16/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0268 - accuracy: 0.9913 - val_loss: 0.0800 - val_accuracy: 0.9836
#
# Epoch 00016: val_loss did not improve from 0.00233
# Epoch 17/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0279 - accuracy: 0.9917 - val_loss: 0.0892 - val_accuracy: 0.9746
#
# Epoch 00017: val_loss did not improve from 0.00233
# Epoch 18/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0274 - accuracy: 0.9902 - val_loss: 0.0175 - val_accuracy: 0.9941
#
# Epoch 00018: val_loss did not improve from 0.00233
# Epoch 19/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0289 - accuracy: 0.9920 - val_loss: 0.0089 - val_accuracy: 0.9965
#
# Epoch 00019: val_loss did not improve from 0.00233
# Epoch 20/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0249 - accuracy: 0.9923 - val_loss: 0.0188 - val_accuracy: 0.9937
#
# Epoch 00020: val_loss did not improve from 0.00233
# Epoch 21/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.0338 - val_accuracy: 0.9945
#
# Epoch 00021: val_loss did not improve from 0.00233
# Epoch 22/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0203 - accuracy: 0.9928 - val_loss: 0.0284 - val_accuracy: 0.9914
#
# Epoch 00022: val_loss did not improve from 0.00233
# Epoch 23/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0209 - accuracy: 0.9930 - val_loss: 0.0153 - val_accuracy: 0.9961
#
# Epoch 00023: val_loss did not improve from 0.00233
# Epoch 24/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0174 - accuracy: 0.9947 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00024: val_loss did not improve from 0.00233
# Epoch 25/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0199 - accuracy: 0.9938 - val_loss: 0.0700 - val_accuracy: 0.9961
#
# Epoch 00025: val_loss did not improve from 0.00233
# Epoch 26/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 0.0284 - val_accuracy: 0.9961
#
# Epoch 00026: val_loss did not improve from 0.00233
# Epoch 27/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0200 - accuracy: 0.9944 - val_loss: 0.0179 - val_accuracy: 0.9945
#
# Epoch 00027: val_loss did not improve from 0.00233
# Epoch 28/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0212 - accuracy: 0.9940 - val_loss: 0.0275 - val_accuracy: 0.9977
#
# Epoch 00028: val_loss did not improve from 0.00233
# Epoch 29/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0177 - accuracy: 0.9948 - val_loss: 0.0111 - val_accuracy: 0.9961
#
# Epoch 00029: val_loss did not improve from 0.00233
# Epoch 30/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00030: val_loss did not improve from 0.00233
# Epoch 31/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0197 - accuracy: 0.9943 - val_loss: 0.0090 - val_accuracy: 0.9977
#
# Epoch 00031: val_loss did not improve from 0.00233
# Epoch 32/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0233 - accuracy: 0.9935 - val_loss: 0.0266 - val_accuracy: 0.9914
#
# Epoch 00032: val_loss did not improve from 0.00233
# Epoch 33/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00033: val_loss did not improve from 0.00233
# Epoch 34/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0162 - accuracy: 0.9947 - val_loss: 0.0358 - val_accuracy: 0.9926
#
# Epoch 00034: val_loss did not improve from 0.00233
# Epoch 35/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00035: val_loss did not improve from 0.00233
# Epoch 36/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 0.0090 - val_accuracy: 0.9965
#
# Epoch 00036: val_loss did not improve from 0.00233
# Epoch 37/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0162 - val_accuracy: 0.9937
#
# Epoch 00037: val_loss did not improve from 0.00233
# Epoch 38/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0142 - accuracy: 0.9948 - val_loss: 0.0895 - val_accuracy: 0.9832
#
# Epoch 00038: val_loss did not improve from 0.00233
# Epoch 39/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0128 - accuracy: 0.9963 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00039: val_loss did not improve from 0.00233
# Epoch 40/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0137 - accuracy: 0.9945 - val_loss: 0.0272 - val_accuracy: 0.9910
#
# Epoch 00040: val_loss did not improve from 0.00233
# Epoch 41/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.0101 - val_accuracy: 0.9969
#
# Epoch 00041: val_loss did not improve from 0.00233
# Epoch 42/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00042: val_loss did not improve from 0.00233
# Epoch 43/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00043: val_loss did not improve from 0.00233
# Epoch 44/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00044: val_loss did not improve from 0.00233
# Epoch 45/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0110 - accuracy: 0.9956 - val_loss: 0.0106 - val_accuracy: 0.9965
#
# Epoch 00045: val_loss did not improve from 0.00233
# Epoch 46/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.0071 - val_accuracy: 0.9977
#
# Epoch 00046: val_loss did not improve from 0.00233
# Epoch 47/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 0.0067 - val_accuracy: 0.9973
#
# Epoch 00047: val_loss did not improve from 0.00233
# Epoch 48/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.0085 - val_accuracy: 0.9953
#
# Epoch 00048: val_loss did not improve from 0.00233
# Epoch 49/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00049: val_loss improved from 0.00233 to 0.00216, saving model to model.h5
# Epoch 50/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.0058 - val_accuracy: 0.9977
#
# Epoch 00050: val_loss did not improve from 0.00216
# Epoch 51/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00195
# Epoch 21/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0259 - accuracy: 0.9915 - val_loss: 0.0558 - val_accuracy: 0.9875
#
# Epoch 00021: val_loss did not improve from 0.00195
# Epoch 22/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0214 - accuracy: 0.9940 - val_loss: 0.0119 - val_accuracy: 0.9965
#
# Epoch 00022: val_loss did not improve from 0.00195
# Epoch 23/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.0093 - val_accuracy: 0.9973
#
# Epoch 00023: val_loss did not improve from 0.00195
# Epoch 24/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0253 - accuracy: 0.9918 - val_loss: 0.0246 - val_accuracy: 0.9957
#
# Epoch 00024: val_loss did not improve from 0.00195
# Epoch 25/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.0372 - val_accuracy: 0.9922
#
# Epoch 00025: val_loss did not improve from 0.00195
# Epoch 26/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0216 - accuracy: 0.9942 - val_loss: 0.0290 - val_accuracy: 0.9918
#
# Epoch 00026: val_loss did not improve from 0.00195
# Epoch 27/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 0.0086 - val_accuracy: 0.9977
#
# Epoch 00027: val_loss did not improve from 0.00195
# Epoch 28/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0184 - accuracy: 0.9947 - val_loss: 0.0481 - val_accuracy: 0.9895
#
# Epoch 00028: val_loss did not improve from 0.00195
# Epoch 29/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0202 - accuracy: 0.9941 - val_loss: 0.0573 - val_accuracy: 0.9949
#
# Epoch 00029: val_loss did not improve from 0.00195
# Epoch 30/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0181 - accuracy: 0.9948 - val_loss: 0.0665 - val_accuracy: 0.9945
#
# Epoch 00030: val_loss did not improve from 0.00195
# Epoch 31/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0163 - accuracy: 0.9938 - val_loss: 0.0369 - val_accuracy: 0.9965
#
# Epoch 00031: val_loss did not improve from 0.00195
# Epoch 32/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0325 - val_accuracy: 0.9969
#
# Epoch 00032: val_loss did not improve from 0.00195
# Epoch 33/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0468 - val_accuracy: 0.9930
#
# Epoch 00033: val_loss did not improve from 0.00195
# Epoch 34/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.0331 - val_accuracy: 0.9965
#
# Epoch 00034: val_loss did not improve from 0.00195
# Epoch 35/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 0.0414 - val_accuracy: 0.9973
#
# Epoch 00035: val_loss did not improve from 0.00195
# Epoch 36/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.0173 - val_accuracy: 0.9965
#
# Epoch 00036: val_loss did not improve from 0.00195
# Epoch 37/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0127 - accuracy: 0.9964 - val_loss: 0.0258 - val_accuracy: 0.9953
#
# Epoch 00037: val_loss did not improve from 0.00195
# Epoch 38/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0124 - accuracy: 0.9955 - val_loss: 0.0297 - val_accuracy: 0.9937
#
# Epoch 00038: val_loss did not improve from 0.00195
# Epoch 39/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0434 - val_accuracy: 0.9914
#
# Epoch 00039: val_loss did not improve from 0.00195
# Epoch 40/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0144 - val_accuracy: 0.9961
#
# Epoch 00040: val_loss did not improve from 0.00195
# Epoch 41/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0203 - val_accuracy: 0.9969
#
# Epoch 00041: val_loss did not improve from 0.00195
# Epoch 42/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0118 - accuracy: 0.9956 - val_loss: 0.0157 - val_accuracy: 0.9953
#
# Epoch 00042: val_loss did not improve from 0.00195
# Epoch 43/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.0209 - val_accuracy: 0.9957
#
# Epoch 00043: val_loss did not improve from 0.00195
# Epoch 44/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0243 - val_accuracy: 0.9949
#
# Epoch 00044: val_loss did not improve from 0.00195
# Epoch 45/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0208 - val_accuracy: 0.9973
#
# Epoch 00045: val_loss did not improve from 0.00195
# Epoch 46/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0176 - val_accuracy: 0.9977
#
# Epoch 00046: val_loss did not improve from 0.00195
# Epoch 47/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0116 - accuracy: 0.9958 - val_loss: 0.0347 - val_accuracy: 0.9965
#
# Epoch 00047: val_loss did not improve from 0.00195
# Epoch 48/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0123 - accuracy: 0.9954 - val_loss: 0.0193 - val_accuracy: 0.9957
#
# Epoch 00048: val_loss did not improve from 0.00195
# Epoch 49/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0171 - val_accuracy: 0.9973
#
# Epoch 00049: val_loss did not improve from 0.00195
# Epoch 50/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0470 - val_accuracy: 0.9977
#
# Epoch 00050: val_loss did not improve from 0.00195
# Epoch 51/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0371 - val_accuracy: 0.9977
#
# Epoch 00051: val_loss did not improve from 0.00195
# Epoch 52/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.0268 - val_accuracy: 0.9961
#
# Epoch 00052: val_loss did not improve from 0.00195
# Epoch 53/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0291 - val_accuracy: 0.9977
#
# Epoch 00053: val_loss did not improve from 0.00195
# Epoch 54/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0137 - accuracy: 0.9955 - val_loss: 0.0329 - val_accuracy: 0.9977
#
# Epoch 00054: val_loss did not improve from 0.00195
# Epoch 55/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 0.0159 - val_accuracy: 0.9980
#
# Epoch 00055: val_loss did not improve from 0.00195
# Epoch 56/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0206 - val_accuracy: 0.9969
#
# Epoch 00056: val_loss did not improve from 0.00195
# Epoch 57/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0116 - accuracy: 0.9958 - val_loss: 0.0475 - val_accuracy: 0.9973
#
# Epoch 00057: val_loss did not improve from 0.00195
# Epoch 58/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0338 - val_accuracy: 0.9973
#
# Epoch 00058: val_loss did not improve from 0.00195
# Epoch 59/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0120 - accuracy: 0.9953 - val_loss: 0.0313 - val_accuracy: 0.9973
#
# Epoch 00059: val_loss did not improve from 0.00195
# Epoch 60/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 0.0232 - val_accuracy: 0.9973
#
# Epoch 00060: val_loss did not improve from 0.00195
# Epoch 61/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.0364 - val_accuracy: 0.9965
#
# Epoch 00061: val_loss did not improve from 0.00195
# Epoch 62/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0088 - accuracy: 0.9963 - val_loss: 0.0212 - val_accuracy: 0.9973
#
# Epoch 00062: val_loss did not improve from 0.00195
# Epoch 63/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0238 - val_accuracy: 0.9965
#
# Epoch 00063: val_loss did not improve from 0.00195
# Epoch 64/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0078 - accuracy: 0.9967 - val_loss: 0.0162 - val_accuracy: 0.9961
#
# Epoch 00064: val_loss did not improve from 0.00195
# Epoch 65/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.0299 - val_accuracy: 0.9965
#
# Epoch 00065: val_loss did not improve from 0.00195
# Epoch 66/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0066 - val_accuracy: 0.9977
#
# Epoch 00066: val_loss did not improve from 0.00195
# Epoch 67/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0064 - val_accuracy: 0.9961
#
# Epoch 00067: val_loss did not improve from 0.00195
# Epoch 68/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.0129 - val_accuracy: 0.9977
#
# Epoch 00068: val_loss did not improve from 0.00195
# Epoch 69/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0130 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00195
# Epoch 70/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0124 - val_accuracy: 0.9957
#
# Epoch 00070: val_loss did not improve from 0.00195
# Epoch 71/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0103 - accuracy: 0.9959 - val_loss: 0.0149 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00195
# Epoch 72/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0079 - accuracy: 0.9968 - val_loss: 0.0132 - val_accuracy: 0.9984
#
# Epoch 00072: val_loss did not improve from 0.00195
# Epoch 73/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0104 - accuracy: 0.9957 - val_loss: 0.0059 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00195
# Epoch 74/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00074: val_loss did not improve from 0.00195
# Epoch 75/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.0188 - val_accuracy: 0.9977
#
# Epoch 00075: val_loss did not improve from 0.00195
# Epoch 76/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.0131 - val_accuracy: 0.9977
#
# Epoch 00076: val_loss did not improve from 0.00195
# Epoch 77/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.0179 - val_accuracy: 0.9980
#
# Epoch 00077: val_loss did not improve from 0.00195
# Epoch 78/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0073 - accuracy: 0.9965 - val_loss: 0.0077 - val_accuracy: 0.9977
#
# Epoch 00078: val_loss did not improve from 0.00195
# Epoch 79/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.0240 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00195
# Epoch 80/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0143 - val_accuracy: 0.9977
#
# Epoch 00080: val_loss did not improve from 0.00195
# Epoch 81/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0082 - val_accuracy: 0.9977
#
# Epoch 00081: val_loss did not improve from 0.00195
# Epoch 82/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0265 - val_accuracy: 0.9973
#
# Epoch 00082: val_loss did not improve from 0.00195
# Epoch 83/100
# 640/640 [==============================] - 5s 8ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00083: val_loss did not improve from 0.00195
# Epoch 84/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0117 - val_accuracy: 0.9980
#
# Epoch 00084: val_loss did not improve from 0.00195
# Epoch 85/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0094 - accuracy: 0.9964 - val_loss: 0.0331 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00195
# Epoch 86/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0295 - val_accuracy: 0.9977
#
# Epoch 00086: val_loss did not improve from 0.00195
# Epoch 87/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0061 - accuracy: 0.9974 - val_loss: 0.0115 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00195
# Epoch 88/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0258 - val_accuracy: 0.9973
#
# Epoch 00088: val_loss did not improve from 0.00195
# Epoch 89/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0516 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00195
# Epoch 90/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00090: val_loss did not improve from 0.00195
# Epoch 91/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0069 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00195
# Epoch 92/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0112 - val_accuracy: 0.9977
#
# Epoch 00092: val_loss did not improve from 0.00195
# Epoch 93/100
# 640/640 [==============================] - 5s 7ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0236 - val_accuracy: 0.9977
#
# Epoch 00093: val_loss did not improve from 0.00195
# Epoch 94/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0174 - val_accuracy: 0.9973
#
# Epoch 00094: val_loss did not improve from 0.00195
# Epoch 95/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.0209 - val_accuracy: 0.9977
#
# Epoch 00095: val_loss did not improve from 0.00195
# Epoch 96/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0071 - accuracy: 0.9968 - val_loss: 0.0209 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00195
# Epoch 97/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0123 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00195
# Epoch 98/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0060 - accuracy: 0.9974 - val_loss: 0.0063 - val_accuracy: 0.9980
#
# Epoch 00098: val_loss did not improve from 0.00195
# Epoch 99/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.0071 - accuracy: 0.9970 - val_loss: 0.0230 - val_accuracy: 0.9961
#
# Epoch 00099: val_loss did not improve from 0.00195
# Epoch 100/100
# 640/640 [==============================] - 4s 7ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0113 - val_accuracy: 0.9965
#
# Epoch 00100: val_loss did not improve from 0.00195
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9965
# Val Score:  [0.011288870126008987, 0.9964843988418579]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 4ms/step - loss: 0.0044 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
