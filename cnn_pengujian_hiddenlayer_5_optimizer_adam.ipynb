# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **HIDDEN LAYER TEST -- USING ONLY 5 HIDDEN LAYER**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    model.add(Conv2D(256, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_93 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_143 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_118 (Bat (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_56 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_144 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_119 (Bat (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_145 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_120 (Bat (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_57 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_146 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_121 (Bat (None, 10, 10, 128)       512
# _________________________________________________________________
# conv2d_97 (Conv2D)           (None, 10, 10, 256)       295168
# _________________________________________________________________
# activation_147 (Activation)  (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_122 (Bat (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_50 (Dense)             (None, 1024)              6554624
# _________________________________________________________________
# activation_148 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_123 (Bat (None, 1024)              4096
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_51 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_149 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 6,957,412
# Trainable params: 6,954,372
# Non-trainable params: 3,040
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.3592 - accuracy: 0.8803 - val_loss: 9.3732 - val_accuracy: 0.2527
#
# Epoch 00001: val_loss improved from inf to 9.37324, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1637 - accuracy: 0.9435 - val_loss: 0.2402 - val_accuracy: 0.9141
#
# Epoch 00002: val_loss improved from 9.37324 to 0.24019, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1424 - accuracy: 0.9517 - val_loss: 0.3565 - val_accuracy: 0.9129
#
# Epoch 00003: val_loss did not improve from 0.24019
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0943 - accuracy: 0.9688 - val_loss: 0.2662 - val_accuracy: 0.9301
#
# Epoch 00004: val_loss did not improve from 0.24019
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0587 - accuracy: 0.9798 - val_loss: 0.4311 - val_accuracy: 0.8723
#
# Epoch 00005: val_loss did not improve from 0.24019
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0555 - accuracy: 0.9810 - val_loss: 0.1019 - val_accuracy: 0.9656
#
# Epoch 00006: val_loss improved from 0.24019 to 0.10188, saving model to model.h5
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0481 - accuracy: 0.9853 - val_loss: 0.0877 - val_accuracy: 0.9777
#
# Epoch 00007: val_loss improved from 0.10188 to 0.08769, saving model to model.h5
# Epoch 8/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0591 - accuracy: 0.9794 - val_loss: 0.5584 - val_accuracy: 0.8309
#
# Epoch 00008: val_loss did not improve from 0.08769
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0374 - accuracy: 0.9878 - val_loss: 0.0153 - val_accuracy: 0.9953
#
# Epoch 00009: val_loss improved from 0.08769 to 0.01534, saving model to model.h5
# Epoch 10/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0341 - accuracy: 0.9884 - val_loss: 0.0168 - val_accuracy: 0.9934
#
# Epoch 00010: val_loss did not improve from 0.01534
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0328 - accuracy: 0.9894 - val_loss: 0.0090 - val_accuracy: 0.9965
#
# Epoch 00011: val_loss improved from 0.01534 to 0.00904, saving model to model.h5
# Epoch 12/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0446 - accuracy: 0.9862 - val_loss: 2.6543 - val_accuracy: 0.6836
#
# Epoch 00012: val_loss did not improve from 0.00904
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0652 - accuracy: 0.9817 - val_loss: 0.4291 - val_accuracy: 0.9184
#
# Epoch 00013: val_loss did not improve from 0.00904
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0304 - accuracy: 0.9892 - val_loss: 0.0194 - val_accuracy: 0.9945
#
# Epoch 00014: val_loss did not improve from 0.00904
# Epoch 15/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0196 - accuracy: 0.9938 - val_loss: 0.2208 - val_accuracy: 0.9215
#
# Epoch 00015: val_loss did not improve from 0.00904
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.0153 - val_accuracy: 0.9969
#
# Epoch 00016: val_loss did not improve from 0.00904
# Epoch 17/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0381 - accuracy: 0.9881 - val_loss: 0.2837 - val_accuracy: 0.9355
#
# Epoch 00017: val_loss did not improve from 0.00904
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0776 - accuracy: 0.9776 - val_loss: 0.0423 - val_accuracy: 0.9859
#
# Epoch 00018: val_loss did not improve from 0.00904
# Epoch 19/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0228 - accuracy: 0.9922 - val_loss: 0.0161 - val_accuracy: 0.9941
#
# Epoch 00019: val_loss did not improve from 0.00904
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0220 - accuracy: 0.9936 - val_loss: 0.0606 - val_accuracy: 0.9805
#
# Epoch 00020: val_loss did not improve from 0.00904
# Epoch 21/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0289 - accuracy: 0.9909 - val_loss: 0.0604 - val_accuracy: 0.9770
#
# Epoch 00021: val_loss did not improve from 0.00904
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 1.7144 - val_accuracy: 0.7230
#
# Epoch 00022: val_loss did not improve from 0.00904
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.2006 - val_accuracy: 0.9254
#
# Epoch 00023: val_loss did not improve from 0.00904
# Epoch 24/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0242 - accuracy: 0.9921 - val_loss: 0.0530 - val_accuracy: 0.9812
#
# Epoch 00024: val_loss did not improve from 0.00904
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.0119 - val_accuracy: 0.9949
#
# Epoch 00025: val_loss did not improve from 0.00904
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.0378 - val_accuracy: 0.9906
#
# Epoch 00026: val_loss did not improve from 0.00904
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0245 - accuracy: 0.9927 - val_loss: 0.0103 - val_accuracy: 0.9961
#
# Epoch 00027: val_loss did not improve from 0.00904
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.0117 - val_accuracy: 0.9969
#
# Epoch 00028: val_loss did not improve from 0.00904
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9957 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00029: val_loss improved from 0.00904 to 0.00887, saving model to model.h5
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0236 - val_accuracy: 0.9949
#
# Epoch 00030: val_loss did not improve from 0.00887
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0527 - accuracy: 0.9868 - val_loss: 0.2533 - val_accuracy: 0.9449
#
# Epoch 00031: val_loss did not improve from 0.00887
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0226 - accuracy: 0.9926 - val_loss: 0.0073 - val_accuracy: 0.9977
#
# Epoch 00032: val_loss improved from 0.00887 to 0.00734, saving model to model.h5
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.1104 - val_accuracy: 0.9652
#
# Epoch 00033: val_loss did not improve from 0.00734
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0109 - accuracy: 0.9958 - val_loss: 0.1959 - val_accuracy: 0.9477
#
# Epoch 00034: val_loss did not improve from 0.00734
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.1145 - val_accuracy: 0.9586
#
# Epoch 00035: val_loss did not improve from 0.00734
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0140 - val_accuracy: 0.9961
#
# Epoch 00036: val_loss did not improve from 0.00734
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0368 - accuracy: 0.9889 - val_loss: 0.0064 - val_accuracy: 0.9984
#
# Epoch 00037: val_loss improved from 0.00734 to 0.00641, saving model to model.h5
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0155 - val_accuracy: 0.9973
#
# Epoch 00038: val_loss did not improve from 0.00641
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9952 - val_loss: 0.0081 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00641
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0165 - accuracy: 0.9956 - val_loss: 0.0812 - val_accuracy: 0.9676
#
# Epoch 00040: val_loss did not improve from 0.00641
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0051 - val_accuracy: 0.9977
#
# Epoch 00041: val_loss improved from 0.00641 to 0.00506, saving model to model.h5
# Epoch 42/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 0.0203 - val_accuracy: 0.9930
#
# Epoch 00042: val_loss did not improve from 0.00506
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0163 - accuracy: 0.9954 - val_loss: 0.0310 - val_accuracy: 0.9867
#
# Epoch 00043: val_loss did not improve from 0.00506
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00044: val_loss improved from 0.00506 to 0.00481, saving model to model.h5
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 1.6924 - val_accuracy: 0.7672
#
# Epoch 00045: val_loss did not improve from 0.00481
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 0.0213 - val_accuracy: 0.9922
#
# Epoch 00046: val_loss did not improve from 0.00481
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 0.1756 - val_accuracy: 0.9543
#
# Epoch 00047: val_loss did not improve from 0.00481
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0019 - val_accuracy: 0.9988
#
# Epoch 00048: val_loss improved from 0.00481 to 0.00194, saving model to model.h5
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00049: val_loss did not improve from 0.00194
# Epoch 50/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00050: val_loss did not improve from 0.00194
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.6102 - val_accuracy: 0.8641
#
# Epoch 00051: val_loss did not improve from 0.00194
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0798 - val_accuracy: 0.9762
#
# Epoch 00052: val_loss did not improve from 0.00194
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00053: val_loss did not improve from 0.00194
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00054: val_loss did not improve from 0.00194
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0158 - val_accuracy: 0.9934
#
# Epoch 00055: val_loss did not improve from 0.00194
# Epoch 56/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.2615 - val_accuracy: 0.9469
#
# Epoch 00056: val_loss did not improve from 0.00194
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0187 - accuracy: 0.9941 - val_loss: 0.0266 - val_accuracy: 0.9934
#
# Epoch 00057: val_loss did not improve from 0.00194
# Epoch 58/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00194
# Epoch 59/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.2235 - val_accuracy: 0.9312
#
# Epoch 00059: val_loss did not improve from 0.00194
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0154 - val_accuracy: 0.9957
#
# Epoch 00060: val_loss did not improve from 0.00194
# Epoch 61/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.0120 - val_accuracy: 0.9953
#
# Epoch 00061: val_loss did not improve from 0.00194
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.0088 - val_accuracy: 0.9973
#
# Epoch 00062: val_loss did not improve from 0.00194
# Epoch 63/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 0.0630 - val_accuracy: 0.9781
#
# Epoch 00063: val_loss did not improve from 0.00194
# Epoch 64/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0063 - val_accuracy: 0.9973
#
# Epoch 00064: val_loss did not improve from 0.00194
# Epoch 65/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0065 - val_accuracy: 0.9973
#
# Epoch 00065: val_loss did not improve from 0.00194
# Epoch 66/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0020 - val_accuracy: 0.9984
#
# Epoch 00066: val_loss did not improve from 0.00194
# Epoch 67/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00067: val_loss did not improve from 0.00194
# Epoch 68/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.1038 - val_accuracy: 0.9707
#
# Epoch 00068: val_loss did not improve from 0.00194
# Epoch 69/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00069: val_loss did not improve from 0.00194
# Epoch 70/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.1882 - val_accuracy: 0.9684
#
# Epoch 00070: val_loss did not improve from 0.00194
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.2584 - val_accuracy: 0.9438
#
# Epoch 00071: val_loss did not improve from 0.00194
# Epoch 72/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0110 - val_accuracy: 0.9961
#
# Epoch 00072: val_loss did not improve from 0.00194
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.0225 - val_accuracy: 0.9945
#
# Epoch 00073: val_loss did not improve from 0.00194
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0105 - accuracy: 0.9975 - val_loss: 0.1111 - val_accuracy: 0.9742
#
# Epoch 00074: val_loss did not improve from 0.00194
# Epoch 75/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.0042 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00194
# Epoch 76/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0031 - val_accuracy: 0.9980
#
# Epoch 00076: val_loss did not improve from 0.00194
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0109 - val_accuracy: 0.9961
#
# Epoch 00077: val_loss did not improve from 0.00194
# Epoch 78/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0046 - val_accuracy: 0.9984
#
# Epoch 00078: val_loss did not improve from 0.00194
# Epoch 79/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0026 - val_accuracy: 0.9980
#
# Epoch 00079: val_loss did not improve from 0.00194
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.0090 - val_accuracy: 0.9980
#
# Epoch 00080: val_loss did not improve from 0.00194
# Epoch 81/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0074 - val_accuracy: 0.9973
#
# Epoch 00081: val_loss did not improve from 0.00194
# Epoch 82/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00082: val_loss did not improve from 0.00194
# Epoch 83/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.6553 - val_accuracy: 0.9137
#
# Epoch 00083: val_loss did not improve from 0.00194
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0130 - accuracy: 0.9951 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00084: val_loss did not improve from 0.00194
# Epoch 85/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0054 - val_accuracy: 0.9977
#
# Epoch 00085: val_loss did not improve from 0.00194
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00086: val_loss did not improve from 0.00194
# Epoch 87/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0153 - val_accuracy: 0.9941
#
# Epoch 00087: val_loss did not improve from 0.00194
# Epoch 88/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00194
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.2524 - val_accuracy: 0.9367
#
# Epoch 00089: val_loss did not improve from 0.00194
# Epoch 90/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0090 - accuracy: 0.9967 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00194
# Epoch 91/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00194
# Epoch 92/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00092: val_loss did not improve from 0.00194
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9965 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00093: val_loss did not improve from 0.00194
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.0068 - val_accuracy: 0.9973
#
# Epoch 00094: val_loss did not improve from 0.00194
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.0131 - val_accuracy: 0.9969
#
# Epoch 00095: val_loss did not improve from 0.00194
# Epoch 96/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0131 - accuracy: 0.9964 - val_loss: 0.0052 - val_accuracy: 0.9984
#
# Epoch 00096: val_loss did not improve from 0.00194
# Epoch 97/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 0.3156 - val_accuracy: 0.9699
#
# Epoch 00097: val_loss did not improve from 0.00194
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0370 - val_accuracy: 0.9875
#
# Epoch 00098: val_loss did not improve from 0.00194
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00099: val_loss did not improve from 0.00194
# Epoch 100/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9968 - val_loss: 0.0266 - val_accuracy: 0.9910
#
# Epoch 00100: val_loss did not improve from 0.00194
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9910
# Val Score:  [0.026587286964058876, 0.991015613079071]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4859 - accuracy: 0.8414 - val_loss: 2.4219 - val_accuracy: 0.5094
#
# Epoch 00001: val_loss did not improve from 0.00194
# Epoch 2/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1752 - accuracy: 0.9364 - val_loss: 1.7346 - val_accuracy: 0.6242
#
# Epoch 00002: val_loss did not improve from 0.00194
# Epoch 3/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1232 - accuracy: 0.9564 - val_loss: 0.1206 - val_accuracy: 0.9555
#
# Epoch 00003: val_loss did not improve from 0.00194
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0891 - accuracy: 0.9682 - val_loss: 0.2819 - val_accuracy: 0.8902
#
# Epoch 00004: val_loss did not improve from 0.00194
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0696 - accuracy: 0.9780 - val_loss: 0.0489 - val_accuracy: 0.9855
#
# Epoch 00005: val_loss did not improve from 0.00194
# Epoch 6/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0605 - accuracy: 0.9783 - val_loss: 0.0243 - val_accuracy: 0.9922
#
# Epoch 00006: val_loss did not improve from 0.00194
# Epoch 7/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0457 - accuracy: 0.9844 - val_loss: 0.0811 - val_accuracy: 0.9715
#
# Epoch 00007: val_loss did not improve from 0.00194
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0471 - accuracy: 0.9855 - val_loss: 0.0265 - val_accuracy: 0.9930
#
# Epoch 00008: val_loss did not improve from 0.00194
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0518 - accuracy: 0.9835 - val_loss: 0.1882 - val_accuracy: 0.9383
#
# Epoch 00009: val_loss did not improve from 0.00194
# Epoch 10/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0409 - accuracy: 0.9869 - val_loss: 0.2450 - val_accuracy: 0.9187
#
# Epoch 00010: val_loss did not improve from 0.00194
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0331 - accuracy: 0.9883 - val_loss: 2.4459 - val_accuracy: 0.6816
#
# Epoch 00011: val_loss did not improve from 0.00194
# Epoch 12/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0372 - accuracy: 0.9871 - val_loss: 0.1481 - val_accuracy: 0.9629
#
# Epoch 00012: val_loss did not improve from 0.00194
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0265 - accuracy: 0.9911 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00013: val_loss did not improve from 0.00194
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0282 - accuracy: 0.9912 - val_loss: 0.1945 - val_accuracy: 0.9422
#
# Epoch 00014: val_loss did not improve from 0.00194
# Epoch 15/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0285 - accuracy: 0.9915 - val_loss: 0.0223 - val_accuracy: 0.9934
#
# Epoch 00015: val_loss did not improve from 0.00194
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0417 - accuracy: 0.9865 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00016: val_loss did not improve from 0.00194
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0399 - accuracy: 0.9876 - val_loss: 0.0259 - val_accuracy: 0.9918
#
# Epoch 00017: val_loss did not improve from 0.00194
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0317 - accuracy: 0.9897 - val_loss: 0.0087 - val_accuracy: 0.9969
#
# Epoch 00018: val_loss did not improve from 0.00194
# Epoch 19/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0240 - accuracy: 0.9926 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00019: val_loss did not improve from 0.00194
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0225 - accuracy: 0.9926 - val_loss: 0.0134 - val_accuracy: 0.9973
#
# Epoch 00020: val_loss did not improve from 0.00194
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0289 - accuracy: 0.9917 - val_loss: 0.0103 - val_accuracy: 0.9969
#
# Epoch 00021: val_loss did not improve from 0.00194
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0198 - accuracy: 0.9927 - val_loss: 0.0111 - val_accuracy: 0.9961
#
# Epoch 00022: val_loss did not improve from 0.00194
# Epoch 23/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0343 - accuracy: 0.9915 - val_loss: 0.0130 - val_accuracy: 0.9941
#
# Epoch 00023: val_loss did not improve from 0.00194
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 0.0046 - val_accuracy: 0.9984
#
# Epoch 00024: val_loss did not improve from 0.00194
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0126 - accuracy: 0.9953 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00025: val_loss did not improve from 0.00194
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00026: val_loss did not improve from 0.00194
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 0.1210 - val_accuracy: 0.9746
#
# Epoch 00027: val_loss did not improve from 0.00194
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.0079 - val_accuracy: 0.9961
#
# Epoch 00028: val_loss did not improve from 0.00194
# Epoch 29/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.0444 - val_accuracy: 0.9871
#
# Epoch 00029: val_loss did not improve from 0.00194
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0201 - accuracy: 0.9942 - val_loss: 0.0089 - val_accuracy: 0.9977
#
# Epoch 00030: val_loss did not improve from 0.00194
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.0489 - val_accuracy: 0.9852
#
# Epoch 00031: val_loss did not improve from 0.00194
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0154 - accuracy: 0.9944 - val_loss: 0.0132 - val_accuracy: 0.9961
#
# Epoch 00032: val_loss did not improve from 0.00194
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0228 - val_accuracy: 0.9906
#
# Epoch 00033: val_loss did not improve from 0.00194
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0282 - accuracy: 0.9917 - val_loss: 0.0078 - val_accuracy: 0.9984
#
# Epoch 00034: val_loss did not improve from 0.00194
# Epoch 35/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.0579 - val_accuracy: 0.9863
#
# Epoch 00035: val_loss did not improve from 0.00194
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0164 - accuracy: 0.9952 - val_loss: 0.2133 - val_accuracy: 0.9387
#
# Epoch 00036: val_loss did not improve from 0.00194
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.0166 - val_accuracy: 0.9945
#
# Epoch 00037: val_loss did not improve from 0.00194
# Epoch 38/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.6786 - val_accuracy: 0.8629
#
# Epoch 00038: val_loss did not improve from 0.00194
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0149 - accuracy: 0.9945 - val_loss: 0.0066 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00194
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0239 - accuracy: 0.9933 - val_loss: 0.0053 - val_accuracy: 0.9973
#
# Epoch 00040: val_loss did not improve from 0.00194
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0176 - accuracy: 0.9937 - val_loss: 0.1501 - val_accuracy: 0.9590
#
# Epoch 00041: val_loss did not improve from 0.00194
# Epoch 42/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0153 - accuracy: 0.9957 - val_loss: 0.0032 - val_accuracy: 0.9980
#
# Epoch 00042: val_loss did not improve from 0.00194
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00043: val_loss did not improve from 0.00194
# Epoch 44/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00044: val_loss did not improve from 0.00194
# Epoch 45/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.6847 - val_accuracy: 0.8367
#
# Epoch 00045: val_loss did not improve from 0.00194
# Epoch 46/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0436 - val_accuracy: 0.9883
#
# Epoch 00046: val_loss did not improve from 0.00194
# Epoch 47/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0263 - accuracy: 0.9929 - val_loss: 0.0277 - val_accuracy: 0.9922
#
# Epoch 00047: val_loss did not improve from 0.00194
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0199 - accuracy: 0.9940 - val_loss: 0.0494 - val_accuracy: 0.9852
#
# Epoch 00048: val_loss did not improve from 0.00194
# Epoch 49/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 0.0240 - val_accuracy: 0.9910
#
# Epoch 00049: val_loss did not improve from 0.00194
# Epoch 50/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0309 - val_accuracy: 0.9891
#
# Epoch 00050: val_loss did not improve from 0.00194
# Epoch 51/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0135 - accuracy: 0.9951 - val_loss: 0.0064 - val_accuracy: 0.9973
#
# Epoch 00051: val_loss did not improve from 0.00194
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0115 - accuracy: 0.9955 - val_loss: 0.0111 - val_accuracy: 0.9969
#
# Epoch 00052: val_loss did not improve from 0.00194
# Epoch 53/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00053: val_loss did not improve from 0.00194
# Epoch 54/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0053 - val_accuracy: 0.9980
#
# Epoch 00054: val_loss did not improve from 0.00194
# Epoch 55/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0046 - val_accuracy: 0.9969
#
# Epoch 00055: val_loss did not improve from 0.00194
# Epoch 56/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 0.1285 - val_accuracy: 0.9570
#
# Epoch 00056: val_loss did not improve from 0.00194
# Epoch 57/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0433 - val_accuracy: 0.9906
#
# Epoch 00057: val_loss did not improve from 0.00194
# Epoch 58/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 0.0097 - val_accuracy: 0.9961
#
# Epoch 00058: val_loss did not improve from 0.00194
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0094 - accuracy: 0.9962 - val_loss: 0.0067 - val_accuracy: 0.9977
#
# Epoch 00059: val_loss did not improve from 0.00194
# Epoch 60/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00060: val_loss did not improve from 0.00194
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.9994 - val_accuracy: 0.8066
#
# Epoch 00061: val_loss did not improve from 0.00194
# Epoch 62/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0092 - accuracy: 0.9963 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00062: val_loss did not improve from 0.00194
# Epoch 63/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0070 - val_accuracy: 0.9969
#
# Epoch 00063: val_loss did not improve from 0.00194
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9972 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00064: val_loss did not improve from 0.00194
# Epoch 65/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0033 - val_accuracy: 0.9977
#
# Epoch 00065: val_loss did not improve from 0.00194
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00066: val_loss did not improve from 0.00194
# Epoch 67/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 0.0054 - val_accuracy: 0.9969
#
# Epoch 00067: val_loss did not improve from 0.00194
# Epoch 68/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 0.0062 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00194
# Epoch 69/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0070 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00194
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.0080 - val_accuracy: 0.9977
#
# Epoch 00070: val_loss did not improve from 0.00194
# Epoch 71/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0122 - accuracy: 0.9958 - val_loss: 0.0971 - val_accuracy: 0.9766
#
# Epoch 00071: val_loss did not improve from 0.00194
# Epoch 72/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9939 - val_loss: 0.0187 - val_accuracy: 0.9953
#
# Epoch 00072: val_loss did not improve from 0.00194
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.2273 - val_accuracy: 0.9230
#
# Epoch 00073: val_loss did not improve from 0.00194
# Epoch 74/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0025 - val_accuracy: 0.9980
#
# Epoch 00074: val_loss did not improve from 0.00194
# Epoch 75/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0069 - accuracy: 0.9969 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00075: val_loss did not improve from 0.00194
# Epoch 76/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00076: val_loss did not improve from 0.00194
# Epoch 77/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00077: val_loss did not improve from 0.00194
# Epoch 78/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00078: val_loss did not improve from 0.00194
# Epoch 79/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0193 - accuracy: 0.9946 - val_loss: 0.0243 - val_accuracy: 0.9930
#
# Epoch 00079: val_loss did not improve from 0.00194
# Epoch 80/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0040 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00194
# Epoch 81/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00081: val_loss did not improve from 0.00194
# Epoch 82/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0383 - val_accuracy: 0.9914
#
# Epoch 00082: val_loss did not improve from 0.00194
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9979 - val_loss: 0.0063 - val_accuracy: 0.9977
#
# Epoch 00083: val_loss did not improve from 0.00194
# Epoch 84/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00084: val_loss did not improve from 0.00194
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9973 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00085: val_loss did not improve from 0.00194
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.0050 - val_accuracy: 0.9984
#
# Epoch 00086: val_loss did not improve from 0.00194
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0151 - accuracy: 0.9958 - val_loss: 0.0119 - val_accuracy: 0.9969
#
# Epoch 00087: val_loss did not improve from 0.00194
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00088: val_loss did not improve from 0.00194
# Epoch 89/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00089: val_loss did not improve from 0.00194
# Epoch 90/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00090: val_loss did not improve from 0.00194
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00194
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00092: val_loss did not improve from 0.00194
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00093: val_loss did not improve from 0.00194
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00094: val_loss did not improve from 0.00194
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00095: val_loss did not improve from 0.00194
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00194
# Epoch 97/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9966 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00097: val_loss did not improve from 0.00194
# Epoch 98/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0030 - val_accuracy: 0.9988
#
# Epoch 00098: val_loss did not improve from 0.00194
# Epoch 99/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00099: val_loss did not improve from 0.00194
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9970 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00194
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9980
# Val Score:  [0.005675916559994221, 0.998046875]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4339 - accuracy: 0.8521 - val_loss: 6.1612 - val_accuracy: 0.4719
#
# Epoch 00001: val_loss did not improve from 0.00194
# Epoch 2/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1765 - accuracy: 0.9354 - val_loss: 0.2535 - val_accuracy: 0.9047
#
# Epoch 00002: val_loss did not improve from 0.00194
# Epoch 3/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.1061 - accuracy: 0.9615 - val_loss: 0.5126 - val_accuracy: 0.8691
#
# Epoch 00003: val_loss did not improve from 0.00194
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0877 - accuracy: 0.9691 - val_loss: 0.5100 - val_accuracy: 0.8762
#
# Epoch 00004: val_loss did not improve from 0.00194
# Epoch 5/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0725 - accuracy: 0.9753 - val_loss: 0.4426 - val_accuracy: 0.8727
#
# Epoch 00005: val_loss did not improve from 0.00194
# Epoch 6/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0704 - accuracy: 0.9761 - val_loss: 0.0966 - val_accuracy: 0.9660
#
# Epoch 00006: val_loss did not improve from 0.00194
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0563 - accuracy: 0.9817 - val_loss: 0.0474 - val_accuracy: 0.9840
#
# Epoch 00007: val_loss did not improve from 0.00194
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0414 - accuracy: 0.9847 - val_loss: 0.1496 - val_accuracy: 0.9445
#
# Epoch 00008: val_loss did not improve from 0.00194
# Epoch 9/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0407 - accuracy: 0.9868 - val_loss: 0.0208 - val_accuracy: 0.9965
#
# Epoch 00009: val_loss did not improve from 0.00194
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0376 - accuracy: 0.9867 - val_loss: 0.2449 - val_accuracy: 0.9203
#
# Epoch 00010: val_loss did not improve from 0.00194
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0342 - accuracy: 0.9886 - val_loss: 0.5662 - val_accuracy: 0.8199
#
# Epoch 00011: val_loss did not improve from 0.00194
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0331 - accuracy: 0.9895 - val_loss: 0.2940 - val_accuracy: 0.9281
#
# Epoch 00012: val_loss did not improve from 0.00194
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0446 - accuracy: 0.9862 - val_loss: 0.1416 - val_accuracy: 0.9520
#
# Epoch 00013: val_loss did not improve from 0.00194
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0371 - accuracy: 0.9870 - val_loss: 0.0109 - val_accuracy: 0.9957
#
# Epoch 00014: val_loss did not improve from 0.00194
# Epoch 15/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.0496 - val_accuracy: 0.9789
#
# Epoch 00015: val_loss did not improve from 0.00194
# Epoch 16/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.0065 - val_accuracy: 0.9973
#
# Epoch 00016: val_loss did not improve from 0.00194
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 0.0178 - val_accuracy: 0.9937
#
# Epoch 00017: val_loss did not improve from 0.00194
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0331 - accuracy: 0.9902 - val_loss: 0.0135 - val_accuracy: 0.9953
#
# Epoch 00018: val_loss did not improve from 0.00194
# Epoch 19/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0392 - accuracy: 0.9887 - val_loss: 0.0460 - val_accuracy: 0.9887
#
# Epoch 00019: val_loss did not improve from 0.00194
# Epoch 20/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 0.1121 - val_accuracy: 0.9609
#
# Epoch 00020: val_loss did not improve from 0.00194
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0562 - val_accuracy: 0.9777
#
# Epoch 00021: val_loss did not improve from 0.00194
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0188 - accuracy: 0.9942 - val_loss: 0.0279 - val_accuracy: 0.9918
#
# Epoch 00022: val_loss did not improve from 0.00194
# Epoch 23/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0244 - accuracy: 0.9924 - val_loss: 0.1035 - val_accuracy: 0.9730
#
# Epoch 00023: val_loss did not improve from 0.00194
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.0277 - val_accuracy: 0.9898
#
# Epoch 00024: val_loss did not improve from 0.00194
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 0.0518 - val_accuracy: 0.9887
#
# Epoch 00025: val_loss did not improve from 0.00194
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.0980 - val_accuracy: 0.9680
#
# Epoch 00026: val_loss did not improve from 0.00194
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0194 - accuracy: 0.9944 - val_loss: 0.0903 - val_accuracy: 0.9723
#
# Epoch 00027: val_loss did not improve from 0.00194
# Epoch 28/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0357 - accuracy: 0.9885 - val_loss: 0.1984 - val_accuracy: 0.9543
#
# Epoch 00028: val_loss did not improve from 0.00194
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0325 - accuracy: 0.9899 - val_loss: 1.5146 - val_accuracy: 0.8277
#
# Epoch 00029: val_loss did not improve from 0.00194
# Epoch 30/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.1783 - val_accuracy: 0.9488
#
# Epoch 00030: val_loss did not improve from 0.00194
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0204 - accuracy: 0.9942 - val_loss: 0.3168 - val_accuracy: 0.9180
#
# Epoch 00031: val_loss did not improve from 0.00194
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0176 - accuracy: 0.9941 - val_loss: 0.0184 - val_accuracy: 0.9957
#
# Epoch 00032: val_loss did not improve from 0.00194
# Epoch 33/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0131 - accuracy: 0.9974 - val_loss: 0.0063 - val_accuracy: 0.9965
#
# Epoch 00033: val_loss did not improve from 0.00194
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 0.0101 - val_accuracy: 0.9957
#
# Epoch 00034: val_loss did not improve from 0.00194
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0227 - accuracy: 0.9942 - val_loss: 0.0190 - val_accuracy: 0.9941
#
# Epoch 00035: val_loss did not improve from 0.00194
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00036: val_loss did not improve from 0.00194
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00037: val_loss did not improve from 0.00194
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.2787 - val_accuracy: 0.9363
#
# Epoch 00038: val_loss did not improve from 0.00194
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0209 - accuracy: 0.9942 - val_loss: 0.0199 - val_accuracy: 0.9965
#
# Epoch 00039: val_loss did not improve from 0.00194
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.0136 - val_accuracy: 0.9957
#
# Epoch 00040: val_loss did not improve from 0.00194
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0319 - accuracy: 0.9910 - val_loss: 0.0124 - val_accuracy: 0.9965
#
# Epoch 00041: val_loss did not improve from 0.00194
# Epoch 42/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00193
# Epoch 21/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0296 - accuracy: 0.9895 - val_loss: 0.2812 - val_accuracy: 0.9332
#
# Epoch 00021: val_loss did not improve from 0.00193
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0239 - accuracy: 0.9922 - val_loss: 0.2045 - val_accuracy: 0.9559
#
# Epoch 00022: val_loss did not improve from 0.00193
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 0.0293 - val_accuracy: 0.9910
#
# Epoch 00023: val_loss did not improve from 0.00193
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0168 - accuracy: 0.9936 - val_loss: 0.0062 - val_accuracy: 0.9969
#
# Epoch 00024: val_loss did not improve from 0.00193
# Epoch 25/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0198 - accuracy: 0.9928 - val_loss: 0.0181 - val_accuracy: 0.9937
#
# Epoch 00025: val_loss did not improve from 0.00193
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0171 - accuracy: 0.9936 - val_loss: 0.2214 - val_accuracy: 0.9500
#
# Epoch 00026: val_loss did not improve from 0.00193
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0332 - accuracy: 0.9895 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00027: val_loss did not improve from 0.00193
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0221 - accuracy: 0.9934 - val_loss: 0.0229 - val_accuracy: 0.9945
#
# Epoch 00028: val_loss did not improve from 0.00193
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00029: val_loss did not improve from 0.00193
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.0092 - val_accuracy: 0.9965
#
# Epoch 00030: val_loss did not improve from 0.00193
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.0169 - val_accuracy: 0.9934
#
# Epoch 00031: val_loss did not improve from 0.00193
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0164 - accuracy: 0.9941 - val_loss: 0.4029 - val_accuracy: 0.8840
#
# Epoch 00032: val_loss did not improve from 0.00193
# Epoch 33/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.0299 - val_accuracy: 0.9902
#
# Epoch 00033: val_loss did not improve from 0.00193
# Epoch 34/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 0.0514 - val_accuracy: 0.9840
#
# Epoch 00034: val_loss did not improve from 0.00193
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.4375 - val_accuracy: 0.8957
#
# Epoch 00035: val_loss did not improve from 0.00193
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0158 - accuracy: 0.9937 - val_loss: 0.0299 - val_accuracy: 0.9914
#
# Epoch 00036: val_loss did not improve from 0.00193
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0136 - accuracy: 0.9944 - val_loss: 0.1192 - val_accuracy: 0.9598
#
# Epoch 00037: val_loss did not improve from 0.00193
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.0056 - val_accuracy: 0.9969
#
# Epoch 00038: val_loss did not improve from 0.00193
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0153 - accuracy: 0.9948 - val_loss: 0.0090 - val_accuracy: 0.9977
#
# Epoch 00039: val_loss did not improve from 0.00193
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0154 - accuracy: 0.9951 - val_loss: 0.0073 - val_accuracy: 0.9980
#
# Epoch 00040: val_loss did not improve from 0.00193
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0141 - accuracy: 0.9949 - val_loss: 0.1365 - val_accuracy: 0.9629
#
# Epoch 00041: val_loss did not improve from 0.00193
# Epoch 42/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0184 - accuracy: 0.9941 - val_loss: 0.2422 - val_accuracy: 0.9336
#
# Epoch 00042: val_loss did not improve from 0.00193
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0129 - accuracy: 0.9953 - val_loss: 0.0099 - val_accuracy: 0.9969
#
# Epoch 00043: val_loss did not improve from 0.00193
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.0448 - val_accuracy: 0.9863
#
# Epoch 00044: val_loss did not improve from 0.00193
# Epoch 45/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.1280 - val_accuracy: 0.9727
#
# Epoch 00045: val_loss did not improve from 0.00193
# Epoch 46/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.0242 - val_accuracy: 0.9918
#
# Epoch 00046: val_loss did not improve from 0.00193
# Epoch 47/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.2125 - val_accuracy: 0.9395
#
# Epoch 00047: val_loss did not improve from 0.00193
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0169 - accuracy: 0.9956 - val_loss: 0.0714 - val_accuracy: 0.9781
#
# Epoch 00048: val_loss did not improve from 0.00193
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.1525 - val_accuracy: 0.9520
#
# Epoch 00049: val_loss did not improve from 0.00193
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.0050 - val_accuracy: 0.9984
#
# Epoch 00050: val_loss did not improve from 0.00193
# Epoch 51/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00051: val_loss did not improve from 0.00193
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00052: val_loss did not improve from 0.00193
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.0072 - val_accuracy: 0.9969
#
# Epoch 00053: val_loss did not improve from 0.00193
# Epoch 54/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0144 - accuracy: 0.9949 - val_loss: 0.0644 - val_accuracy: 0.9848
#
# Epoch 00054: val_loss did not improve from 0.00193
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0092 - accuracy: 0.9966 - val_loss: 0.0038 - val_accuracy: 0.9988
#
# Epoch 00055: val_loss did not improve from 0.00193
# Epoch 56/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0035 - val_accuracy: 0.9984
#
# Epoch 00056: val_loss did not improve from 0.00193
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0674 - val_accuracy: 0.9777
#
# Epoch 00057: val_loss did not improve from 0.00193
# Epoch 58/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.1484 - val_accuracy: 0.9578
#
# Epoch 00058: val_loss did not improve from 0.00193
# Epoch 59/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0133 - accuracy: 0.9952 - val_loss: 0.0081 - val_accuracy: 0.9949
#
# Epoch 00059: val_loss did not improve from 0.00193
# Epoch 60/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0114 - val_accuracy: 0.9965
#
# Epoch 00060: val_loss did not improve from 0.00193
# Epoch 61/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00061: val_loss did not improve from 0.00193
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0109 - accuracy: 0.9956 - val_loss: 0.0048 - val_accuracy: 0.9977
#
# Epoch 00062: val_loss did not improve from 0.00193
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.0074 - val_accuracy: 0.9965
#
# Epoch 00063: val_loss did not improve from 0.00193
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.0058 - val_accuracy: 0.9977
#
# Epoch 00064: val_loss did not improve from 0.00193
# Epoch 65/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0346 - val_accuracy: 0.9902
#
# Epoch 00065: val_loss did not improve from 0.00193
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0238 - val_accuracy: 0.9898
#
# Epoch 00066: val_loss did not improve from 0.00193
# Epoch 67/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.0304 - val_accuracy: 0.9871
#
# Epoch 00067: val_loss did not improve from 0.00193
# Epoch 68/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00068: val_loss did not improve from 0.00193
# Epoch 69/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0094 - accuracy: 0.9964 - val_loss: 0.0607 - val_accuracy: 0.9812
#
# Epoch 00069: val_loss did not improve from 0.00193
# Epoch 70/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00070: val_loss did not improve from 0.00193
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0056 - accuracy: 0.9976 - val_loss: 0.0064 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00193
# Epoch 72/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0154 - val_accuracy: 0.9941
#
# Epoch 00072: val_loss did not improve from 0.00193
# Epoch 73/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00073: val_loss did not improve from 0.00193
# Epoch 74/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9950 - val_loss: 0.5365 - val_accuracy: 0.8949
#
# Epoch 00074: val_loss did not improve from 0.00193
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0608 - val_accuracy: 0.9863
#
# Epoch 00075: val_loss did not improve from 0.00193
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0160 - val_accuracy: 0.9949
#
# Epoch 00076: val_loss did not improve from 0.00193
# Epoch 77/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.0047 - val_accuracy: 0.9988
#
# Epoch 00077: val_loss did not improve from 0.00193
# Epoch 78/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0084 - val_accuracy: 0.9961
#
# Epoch 00078: val_loss did not improve from 0.00193
# Epoch 79/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0075 - accuracy: 0.9967 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00079: val_loss did not improve from 0.00193
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0103 - val_accuracy: 0.9988
#
# Epoch 00080: val_loss did not improve from 0.00193
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0088 - accuracy: 0.9964 - val_loss: 0.0019 - val_accuracy: 0.9988
#
# Epoch 00081: val_loss did not improve from 0.00193
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0144 - val_accuracy: 0.9957
#
# Epoch 00082: val_loss did not improve from 0.00193
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00083: val_loss did not improve from 0.00193
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0930 - val_accuracy: 0.9742
#
# Epoch 00084: val_loss did not improve from 0.00193
# Epoch 85/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0324 - val_accuracy: 0.9922
#
# Epoch 00085: val_loss did not improve from 0.00193
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00193
# Epoch 87/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9965 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00193
# Epoch 88/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0061 - accuracy: 0.9972 - val_loss: 0.2568 - val_accuracy: 0.9391
#
# Epoch 00088: val_loss did not improve from 0.00193
# Epoch 89/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0091 - accuracy: 0.9962 - val_loss: 0.0057 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00193
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0065 - accuracy: 0.9971 - val_loss: 0.0154 - val_accuracy: 0.9965
#
# Epoch 00090: val_loss did not improve from 0.00193
# Epoch 91/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0072 - val_accuracy: 0.9980
#
# Epoch 00091: val_loss did not improve from 0.00193
# Epoch 92/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0047 - val_accuracy: 0.9984
#
# Epoch 00092: val_loss did not improve from 0.00193
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9974 - val_loss: 0.6072 - val_accuracy: 0.9051
#
# Epoch 00093: val_loss did not improve from 0.00193
# Epoch 94/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 0.1407 - val_accuracy: 0.9699
#
# Epoch 00094: val_loss did not improve from 0.00193
# Epoch 95/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00095: val_loss did not improve from 0.00193
# Epoch 96/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0142 - val_accuracy: 0.9945
#
# Epoch 00096: val_loss did not improve from 0.00193
# Epoch 97/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0089 - accuracy: 0.9962 - val_loss: 0.0057 - val_accuracy: 0.9977
#
# Epoch 00097: val_loss did not improve from 0.00193
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00098: val_loss did not improve from 0.00193
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00099: val_loss did not improve from 0.00193
# Epoch 100/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0078 - accuracy: 0.9966 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00193
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 0.9980
# Val Score:  [0.00407274067401886, 0.998046875]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 3ms/step - loss: 0.0095 - accuracy: 0.9962
# Test Accuracy: 99.62499737739563

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
