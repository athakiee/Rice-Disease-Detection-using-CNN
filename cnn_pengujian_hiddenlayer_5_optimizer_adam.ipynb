# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **HIDDEN LAYER TEST -- USING ONLY 5 HIDDEN LAYER**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    model.add(Conv2D(256, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_63 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_101 (Activation)  (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_82 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_102 (Activation)  (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_83 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_103 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_84 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_104 (Activation)  (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_85 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 10, 10, 256)       295168
# _________________________________________________________________
# activation_105 (Activation)  (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_86 (Batc (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_38 (Dense)             (None, 1024)              6554624
# _________________________________________________________________
# activation_106 (Activation)  (None, 1024)              0
# _________________________________________________________________
# batch_normalization_87 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_39 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_107 (Activation)  (None, 4)                 0
# =================================================================
# Total params: 6,957,412
# Trainable params: 6,954,372
# Non-trainable params: 3,040
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 4s 9ms/step - loss: 0.4482 - accuracy: 0.8467 - val_loss: 4.2428 - val_accuracy: 0.4965
#
# Epoch 00001: val_loss improved from inf to 4.24275, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2033 - accuracy: 0.9285 - val_loss: 2.1267 - val_accuracy: 0.6609
#
# Epoch 00002: val_loss improved from 4.24275 to 2.12670, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.1289 - accuracy: 0.9556 - val_loss: 0.5944 - val_accuracy: 0.8281
#
# Epoch 00003: val_loss improved from 2.12670 to 0.59444, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0947 - accuracy: 0.9692 - val_loss: 0.2130 - val_accuracy: 0.9289
#
# Epoch 00004: val_loss improved from 0.59444 to 0.21305, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0841 - accuracy: 0.9724 - val_loss: 0.4008 - val_accuracy: 0.8781
#
# Epoch 00005: val_loss did not improve from 0.21305
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0891 - accuracy: 0.9692 - val_loss: 0.4536 - val_accuracy: 0.8805
#
# Epoch 00006: val_loss did not improve from 0.21305
# Epoch 7/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0531 - accuracy: 0.9831 - val_loss: 0.2172 - val_accuracy: 0.9434
#
# Epoch 00007: val_loss did not improve from 0.21305
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0645 - accuracy: 0.9800 - val_loss: 0.5704 - val_accuracy: 0.8512
#
# Epoch 00008: val_loss did not improve from 0.21305
# Epoch 9/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0782 - accuracy: 0.9741 - val_loss: 1.3296 - val_accuracy: 0.7324
#
# Epoch 00009: val_loss did not improve from 0.21305
# Epoch 10/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0577 - accuracy: 0.9830 - val_loss: 0.5854 - val_accuracy: 0.8590
#
# Epoch 00010: val_loss did not improve from 0.21305
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0436 - accuracy: 0.9857 - val_loss: 0.2388 - val_accuracy: 0.9227
#
# Epoch 00011: val_loss did not improve from 0.21305
# Epoch 12/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0562 - accuracy: 0.9844 - val_loss: 0.1892 - val_accuracy: 0.9473
#
# Epoch 00012: val_loss improved from 0.21305 to 0.18918, saving model to model.h5
# Epoch 13/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0265 - accuracy: 0.9911 - val_loss: 0.0782 - val_accuracy: 0.9711
#
# Epoch 00013: val_loss improved from 0.18918 to 0.07815, saving model to model.h5
# Epoch 14/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0455 - accuracy: 0.9874 - val_loss: 0.0262 - val_accuracy: 0.9906
#
# Epoch 00014: val_loss improved from 0.07815 to 0.02623, saving model to model.h5
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0263 - accuracy: 0.9920 - val_loss: 0.3462 - val_accuracy: 0.9082
#
# Epoch 00015: val_loss did not improve from 0.02623
# Epoch 16/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0362 - accuracy: 0.9896 - val_loss: 3.8491 - val_accuracy: 0.6195
#
# Epoch 00016: val_loss did not improve from 0.02623
# Epoch 17/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0415 - accuracy: 0.9866 - val_loss: 0.0917 - val_accuracy: 0.9723
#
# Epoch 00017: val_loss did not improve from 0.02623
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0305 - accuracy: 0.9906 - val_loss: 0.0224 - val_accuracy: 0.9930
#
# Epoch 00018: val_loss improved from 0.02623 to 0.02237, saving model to model.h5
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0249 - accuracy: 0.9927 - val_loss: 0.0072 - val_accuracy: 0.9969
#
# Epoch 00019: val_loss improved from 0.02237 to 0.00720, saving model to model.h5
# Epoch 20/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0276 - accuracy: 0.9903 - val_loss: 0.0598 - val_accuracy: 0.9836
#
# Epoch 00020: val_loss did not improve from 0.00720
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.1196 - val_accuracy: 0.9633
#
# Epoch 00021: val_loss did not improve from 0.00720
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0360 - accuracy: 0.9888 - val_loss: 0.0040 - val_accuracy: 0.9973
#
# Epoch 00022: val_loss improved from 0.00720 to 0.00404, saving model to model.h5
# Epoch 23/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0363 - accuracy: 0.9898 - val_loss: 0.0707 - val_accuracy: 0.9758
#
# Epoch 00023: val_loss did not improve from 0.00404
# Epoch 24/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0305 - accuracy: 0.9919 - val_loss: 0.0773 - val_accuracy: 0.9793
#
# Epoch 00024: val_loss did not improve from 0.00404
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0327 - accuracy: 0.9910 - val_loss: 0.0201 - val_accuracy: 0.9918
#
# Epoch 00025: val_loss did not improve from 0.00404
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0255 - accuracy: 0.9923 - val_loss: 0.0277 - val_accuracy: 0.9930
#
# Epoch 00026: val_loss did not improve from 0.00404
# Epoch 27/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0240 - accuracy: 0.9924 - val_loss: 0.2860 - val_accuracy: 0.9410
#
# Epoch 00027: val_loss did not improve from 0.00404
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0192 - accuracy: 0.9938 - val_loss: 0.2571 - val_accuracy: 0.9430
#
# Epoch 00028: val_loss did not improve from 0.00404
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 1.7922 - val_accuracy: 0.7898
#
# Epoch 00029: val_loss did not improve from 0.00404
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0126 - val_accuracy: 0.9957
#
# Epoch 00030: val_loss did not improve from 0.00404
# Epoch 31/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0217 - accuracy: 0.9938 - val_loss: 0.0201 - val_accuracy: 0.9937
#
# Epoch 00031: val_loss did not improve from 0.00404
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.0930 - val_accuracy: 0.9777
#
# Epoch 00032: val_loss did not improve from 0.00404
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0187 - accuracy: 0.9936 - val_loss: 0.0683 - val_accuracy: 0.9828
#
# Epoch 00033: val_loss did not improve from 0.00404
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0193 - accuracy: 0.9940 - val_loss: 0.0472 - val_accuracy: 0.9844
#
# Epoch 00034: val_loss did not improve from 0.00404
# Epoch 35/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0204 - accuracy: 0.9942 - val_loss: 0.0429 - val_accuracy: 0.9887
#
# Epoch 00035: val_loss did not improve from 0.00404
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0182 - accuracy: 0.9947 - val_loss: 0.0319 - val_accuracy: 0.9922
#
# Epoch 00036: val_loss did not improve from 0.00404
# Epoch 37/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0147 - accuracy: 0.9961 - val_loss: 0.0166 - val_accuracy: 0.9961
#
# Epoch 00037: val_loss did not improve from 0.00404
# Epoch 38/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0170 - accuracy: 0.9937 - val_loss: 0.0307 - val_accuracy: 0.9887
#
# Epoch 00038: val_loss did not improve from 0.00404
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.0100 - val_accuracy: 0.9961
#
# Epoch 00039: val_loss did not improve from 0.00404
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.4865 - val_accuracy: 0.9109
#
# Epoch 00040: val_loss did not improve from 0.00404
# Epoch 41/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0157 - accuracy: 0.9956 - val_loss: 0.0066 - val_accuracy: 0.9980
#
# Epoch 00041: val_loss did not improve from 0.00404
# Epoch 42/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0432 - val_accuracy: 0.9844
#
# Epoch 00042: val_loss did not improve from 0.00404
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00043: val_loss improved from 0.00404 to 0.00351, saving model to model.h5
# Epoch 44/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0254 - accuracy: 0.9935 - val_loss: 0.0209 - val_accuracy: 0.9945
#
# Epoch 00044: val_loss did not improve from 0.00351
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0024 - val_accuracy: 0.9988
#
# Epoch 00045: val_loss improved from 0.00351 to 0.00238, saving model to model.h5
# Epoch 46/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0079 - val_accuracy: 0.9977
#
# Epoch 00046: val_loss did not improve from 0.00238
# Epoch 47/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0223 - accuracy: 0.9932 - val_loss: 0.0319 - val_accuracy: 0.9902
#
# Epoch 00047: val_loss did not improve from 0.00238
# Epoch 48/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0141 - accuracy: 0.9964 - val_loss: 0.0433 - val_accuracy: 0.9848
#
# Epoch 00048: val_loss did not improve from 0.00238
# Epoch 49/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 0.0115 - val_accuracy: 0.9965
#
# Epoch 00049: val_loss did not improve from 0.00238
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0175 - accuracy: 0.9949 - val_loss: 0.1443 - val_accuracy: 0.9559
#
# Epoch 00050: val_loss did not improve from 0.00238
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00051: val_loss did not improve from 0.00238
# Epoch 52/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0100 - val_accuracy: 0.9969
#
# Epoch 00052: val_loss did not improve from 0.00238
# Epoch 53/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0089 - val_accuracy: 0.9973
#
# Epoch 00053: val_loss did not improve from 0.00238
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.1455 - val_accuracy: 0.9762
#
# Epoch 00054: val_loss did not improve from 0.00238
# Epoch 55/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.7229 - val_accuracy: 0.8977
#
# Epoch 00055: val_loss did not improve from 0.00238
# Epoch 56/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0068 - accuracy: 0.9970 - val_loss: 0.0100 - val_accuracy: 0.9969
#
# Epoch 00056: val_loss did not improve from 0.00238
# Epoch 57/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0134 - val_accuracy: 0.9957
#
# Epoch 00057: val_loss did not improve from 0.00238
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.9934 - val_accuracy: 0.8500
#
# Epoch 00058: val_loss did not improve from 0.00238
# Epoch 59/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0112 - val_accuracy: 0.9973
#
# Epoch 00059: val_loss did not improve from 0.00238
# Epoch 60/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0184 - accuracy: 0.9956 - val_loss: 5.2055 - val_accuracy: 0.7469
#
# Epoch 00060: val_loss did not improve from 0.00238
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0143 - accuracy: 0.9955 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00061: val_loss did not improve from 0.00238
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0109 - accuracy: 0.9960 - val_loss: 0.0615 - val_accuracy: 0.9902
#
# Epoch 00062: val_loss did not improve from 0.00238
# Epoch 63/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0091 - val_accuracy: 0.9969
#
# Epoch 00063: val_loss did not improve from 0.00238
# Epoch 64/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0213 - val_accuracy: 0.9937
#
# Epoch 00064: val_loss did not improve from 0.00238
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.1707 - val_accuracy: 0.9770
#
# Epoch 00065: val_loss did not improve from 0.00238
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.2044 - val_accuracy: 0.9578
#
# Epoch 00066: val_loss did not improve from 0.00238
# Epoch 67/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00067: val_loss did not improve from 0.00238
# Epoch 68/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.1138 - val_accuracy: 0.9695
#
# Epoch 00068: val_loss did not improve from 0.00238
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0151 - accuracy: 0.9959 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00069: val_loss did not improve from 0.00238
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0058 - val_accuracy: 0.9973
#
# Epoch 00070: val_loss did not improve from 0.00238
# Epoch 71/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0177 - accuracy: 0.9952 - val_loss: 0.0859 - val_accuracy: 0.9762
#
# Epoch 00071: val_loss did not improve from 0.00238
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0637 - val_accuracy: 0.9824
#
# Epoch 00072: val_loss did not improve from 0.00238
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0541 - val_accuracy: 0.9832
#
# Epoch 00073: val_loss did not improve from 0.00238
# Epoch 74/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0134 - accuracy: 0.9954 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00074: val_loss did not improve from 0.00238
# Epoch 75/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0264 - val_accuracy: 0.9914
#
# Epoch 00075: val_loss did not improve from 0.00238
# Epoch 76/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9974 - val_loss: 0.0079 - val_accuracy: 0.9980
#
# Epoch 00076: val_loss did not improve from 0.00238
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0143 - val_accuracy: 0.9961
#
# Epoch 00077: val_loss did not improve from 0.00238
# Epoch 78/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.0192 - val_accuracy: 0.9945
#
# Epoch 00078: val_loss did not improve from 0.00238
# Epoch 79/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0071 - accuracy: 0.9970 - val_loss: 0.0083 - val_accuracy: 0.9984
#
# Epoch 00079: val_loss did not improve from 0.00238
# Epoch 80/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0092 - accuracy: 0.9964 - val_loss: 0.0099 - val_accuracy: 0.9973
#
# Epoch 00080: val_loss did not improve from 0.00238
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0090 - accuracy: 0.9965 - val_loss: 0.0281 - val_accuracy: 0.9941
#
# Epoch 00081: val_loss did not improve from 0.00238
# Epoch 82/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0172 - accuracy: 0.9960 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00082: val_loss did not improve from 0.00238
# Epoch 83/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.0364 - val_accuracy: 0.9906
#
# Epoch 00083: val_loss did not improve from 0.00238
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0755 - val_accuracy: 0.9766
#
# Epoch 00084: val_loss did not improve from 0.00238
# Epoch 85/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9973 - val_loss: 0.0071 - val_accuracy: 0.9984
#
# Epoch 00085: val_loss did not improve from 0.00238
# Epoch 86/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00238
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0023 - val_accuracy: 0.9984
#
# Epoch 00087: val_loss improved from 0.00238 to 0.00232, saving model to model.h5
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9958 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00088: val_loss did not improve from 0.00232
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 0.0091 - val_accuracy: 0.9969
#
# Epoch 00089: val_loss did not improve from 0.00232
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00090: val_loss did not improve from 0.00232
# Epoch 91/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0092 - val_accuracy: 0.9973
#
# Epoch 00091: val_loss did not improve from 0.00232
# Epoch 92/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.0884 - val_accuracy: 0.9730
#
# Epoch 00092: val_loss did not improve from 0.00232
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0111 - val_accuracy: 0.9965
#
# Epoch 00093: val_loss did not improve from 0.00232
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0037 - val_accuracy: 0.9980
#
# Epoch 00094: val_loss did not improve from 0.00232
# Epoch 95/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.0122 - val_accuracy: 0.9941
#
# Epoch 00095: val_loss did not improve from 0.00232
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00232
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.0050 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00232
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.0256 - val_accuracy: 0.9937
#
# Epoch 00098: val_loss did not improve from 0.00232
# Epoch 99/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0118 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00232
# Epoch 100/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 0.0139 - val_accuracy: 0.9965
#
# Epoch 00100: val_loss did not improve from 0.00232
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9965
# Val Score:  [0.013905076310038567, 0.9964843988418579]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.4941 - accuracy: 0.8331 - val_loss: 1.1440 - val_accuracy: 0.7004
#
# Epoch 00001: val_loss did not improve from 0.00232
# Epoch 2/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.2075 - accuracy: 0.9286 - val_loss: 0.8845 - val_accuracy: 0.7449
#
# Epoch 00002: val_loss did not improve from 0.00232
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1425 - accuracy: 0.9501 - val_loss: 0.3901 - val_accuracy: 0.8734
#
# Epoch 00003: val_loss did not improve from 0.00232
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1042 - accuracy: 0.9617 - val_loss: 0.8705 - val_accuracy: 0.7746
#
# Epoch 00004: val_loss did not improve from 0.00232
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0807 - accuracy: 0.9714 - val_loss: 0.0920 - val_accuracy: 0.9652
#
# Epoch 00005: val_loss did not improve from 0.00232
# Epoch 6/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0751 - accuracy: 0.9738 - val_loss: 0.3526 - val_accuracy: 0.8855
#
# Epoch 00006: val_loss did not improve from 0.00232
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0593 - accuracy: 0.9802 - val_loss: 0.3995 - val_accuracy: 0.8996
#
# Epoch 00007: val_loss did not improve from 0.00232
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0640 - accuracy: 0.9786 - val_loss: 0.1252 - val_accuracy: 0.9594
#
# Epoch 00008: val_loss did not improve from 0.00232
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0548 - accuracy: 0.9839 - val_loss: 0.0219 - val_accuracy: 0.9945
#
# Epoch 00009: val_loss did not improve from 0.00232
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0559 - accuracy: 0.9813 - val_loss: 0.2898 - val_accuracy: 0.9227
#
# Epoch 00010: val_loss did not improve from 0.00232
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0424 - accuracy: 0.9870 - val_loss: 0.1135 - val_accuracy: 0.9672
#
# Epoch 00011: val_loss did not improve from 0.00232
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.0833 - val_accuracy: 0.9684
#
# Epoch 00012: val_loss did not improve from 0.00232
# Epoch 13/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0324 - accuracy: 0.9896 - val_loss: 0.2890 - val_accuracy: 0.9273
#
# Epoch 00013: val_loss did not improve from 0.00232
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0282 - accuracy: 0.9902 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00014: val_loss did not improve from 0.00232
# Epoch 15/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0449 - accuracy: 0.9868 - val_loss: 0.9706 - val_accuracy: 0.8129
#
# Epoch 00015: val_loss did not improve from 0.00232
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0385 - accuracy: 0.9874 - val_loss: 0.7119 - val_accuracy: 0.8555
#
# Epoch 00016: val_loss did not improve from 0.00232
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0402 - accuracy: 0.9896 - val_loss: 0.3456 - val_accuracy: 0.8902
#
# Epoch 00017: val_loss did not improve from 0.00232
# Epoch 18/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0109 - val_accuracy: 0.9961
#
# Epoch 00018: val_loss did not improve from 0.00232
# Epoch 19/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0300 - accuracy: 0.9898 - val_loss: 0.0362 - val_accuracy: 0.9871
#
# Epoch 00019: val_loss did not improve from 0.00232
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0531 - accuracy: 0.9840 - val_loss: 0.0166 - val_accuracy: 0.9941
#
# Epoch 00020: val_loss did not improve from 0.00232
# Epoch 21/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0289 - accuracy: 0.9911 - val_loss: 0.0591 - val_accuracy: 0.9805
#
# Epoch 00021: val_loss did not improve from 0.00232
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0183 - accuracy: 0.9934 - val_loss: 0.0055 - val_accuracy: 0.9965
#
# Epoch 00022: val_loss did not improve from 0.00232
# Epoch 23/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0048 - val_accuracy: 0.9980
#
# Epoch 00023: val_loss did not improve from 0.00232
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0167 - accuracy: 0.9951 - val_loss: 0.0266 - val_accuracy: 0.9934
#
# Epoch 00024: val_loss did not improve from 0.00232
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.0053 - val_accuracy: 0.9980
#
# Epoch 00025: val_loss did not improve from 0.00232
# Epoch 26/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0240 - accuracy: 0.9926 - val_loss: 0.0399 - val_accuracy: 0.9891
#
# Epoch 00026: val_loss did not improve from 0.00232
# Epoch 27/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.0234 - val_accuracy: 0.9926
#
# Epoch 00027: val_loss did not improve from 0.00232
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.0304 - val_accuracy: 0.9898
#
# Epoch 00028: val_loss did not improve from 0.00232
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.5044 - val_accuracy: 0.9059
#
# Epoch 00029: val_loss did not improve from 0.00232
# Epoch 30/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0268 - accuracy: 0.9917 - val_loss: 0.0164 - val_accuracy: 0.9949
#
# Epoch 00030: val_loss did not improve from 0.00232
# Epoch 31/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 0.0404 - val_accuracy: 0.9902
#
# Epoch 00031: val_loss did not improve from 0.00232
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.0889 - val_accuracy: 0.9699
#
# Epoch 00032: val_loss did not improve from 0.00232
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0152 - accuracy: 0.9945 - val_loss: 0.0320 - val_accuracy: 0.9887
#
# Epoch 00033: val_loss did not improve from 0.00232
# Epoch 34/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.5770 - val_accuracy: 0.8773
#
# Epoch 00034: val_loss did not improve from 0.00232
# Epoch 35/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.0076 - val_accuracy: 0.9969
#
# Epoch 00035: val_loss did not improve from 0.00232
# Epoch 36/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0179 - accuracy: 0.9939 - val_loss: 0.0151 - val_accuracy: 0.9957
#
# Epoch 00036: val_loss did not improve from 0.00232
# Epoch 37/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0214 - accuracy: 0.9948 - val_loss: 0.0051 - val_accuracy: 0.9973
#
# Epoch 00037: val_loss did not improve from 0.00232
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0136 - val_accuracy: 0.9937
#
# Epoch 00038: val_loss did not improve from 0.00232
# Epoch 39/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0432 - val_accuracy: 0.9824
#
# Epoch 00039: val_loss did not improve from 0.00232
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9962 - val_loss: 0.0042 - val_accuracy: 0.9977
#
# Epoch 00040: val_loss did not improve from 0.00232
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00041: val_loss improved from 0.00232 to 0.00223, saving model to model.h5
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.2593 - val_accuracy: 0.9457
#
# Epoch 00042: val_loss did not improve from 0.00223
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 0.0021 - val_accuracy: 0.9984
#
# Epoch 00043: val_loss improved from 0.00223 to 0.00205, saving model to model.h5
# Epoch 44/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0245 - accuracy: 0.9916 - val_loss: 0.0110 - val_accuracy: 0.9949
#
# Epoch 00044: val_loss did not improve from 0.00205
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9966 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00045: val_loss did not improve from 0.00205
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0175 - accuracy: 0.9950 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00046: val_loss did not improve from 0.00205
# Epoch 47/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0113 - accuracy: 0.9953 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00047: val_loss did not improve from 0.00205
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00048: val_loss did not improve from 0.00205
# Epoch 49/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.0040 - val_accuracy: 0.9984
#
# Epoch 00049: val_loss did not improve from 0.00205
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00050: val_loss did not improve from 0.00205
# Epoch 51/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0945 - val_accuracy: 0.9727
#
# Epoch 00051: val_loss did not improve from 0.00205
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0159 - accuracy: 0.9953 - val_loss: 0.0261 - val_accuracy: 0.9914
#
# Epoch 00052: val_loss did not improve from 0.00205
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00053: val_loss did not improve from 0.00205
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0034 - val_accuracy: 0.9988
#
# Epoch 00054: val_loss did not improve from 0.00205
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0125 - accuracy: 0.9952 - val_loss: 0.0057 - val_accuracy: 0.9973
#
# Epoch 00055: val_loss did not improve from 0.00205
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0038 - val_accuracy: 0.9984
#
# Epoch 00056: val_loss did not improve from 0.00205
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00057: val_loss did not improve from 0.00205
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00058: val_loss did not improve from 0.00205
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.0026 - val_accuracy: 0.9980
#
# Epoch 00059: val_loss did not improve from 0.00205
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 2.2718 - val_accuracy: 0.8164
#
# Epoch 00060: val_loss did not improve from 0.00205
# Epoch 61/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.0040 - val_accuracy: 0.9984
#
# Epoch 00061: val_loss did not improve from 0.00205
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.0060 - val_accuracy: 0.9965
#
# Epoch 00062: val_loss did not improve from 0.00205
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.0046 - val_accuracy: 0.9977
#
# Epoch 00063: val_loss did not improve from 0.00205
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00064: val_loss did not improve from 0.00205
# Epoch 65/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00065: val_loss did not improve from 0.00205
# Epoch 66/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00066: val_loss did not improve from 0.00205
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0080 - val_accuracy: 0.9961
#
# Epoch 00067: val_loss did not improve from 0.00205
# Epoch 68/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0141 - accuracy: 0.9948 - val_loss: 0.0083 - val_accuracy: 0.9969
#
# Epoch 00068: val_loss did not improve from 0.00205
# Epoch 69/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00205
# Epoch 70/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0113 - val_accuracy: 0.9969
#
# Epoch 00070: val_loss did not improve from 0.00205
# Epoch 71/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0033 - val_accuracy: 0.9977
#
# Epoch 00071: val_loss did not improve from 0.00205
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0118 - val_accuracy: 0.9961
#
# Epoch 00072: val_loss did not improve from 0.00205
# Epoch 73/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00073: val_loss did not improve from 0.00205
# Epoch 74/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0080 - val_accuracy: 0.9969
#
# Epoch 00074: val_loss did not improve from 0.00205
# Epoch 75/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 4.1592 - val_accuracy: 0.7617
#
# Epoch 00075: val_loss did not improve from 0.00205
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.0114 - val_accuracy: 0.9941
#
# Epoch 00076: val_loss did not improve from 0.00205
# Epoch 77/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.0124 - val_accuracy: 0.9937
#
# Epoch 00077: val_loss did not improve from 0.00205
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00078: val_loss did not improve from 0.00205
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.3539 - val_accuracy: 0.9125
#
# Epoch 00079: val_loss did not improve from 0.00205
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 0.1341 - val_accuracy: 0.9750
#
# Epoch 00080: val_loss did not improve from 0.00205
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0106 - accuracy: 0.9958 - val_loss: 0.0058 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00205
# Epoch 82/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9964 - val_loss: 0.0220 - val_accuracy: 0.9930
#
# Epoch 00082: val_loss did not improve from 0.00205
# Epoch 83/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.3576 - val_accuracy: 0.9348
#
# Epoch 00083: val_loss did not improve from 0.00205
# Epoch 84/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00084: val_loss did not improve from 0.00205
# Epoch 85/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00085: val_loss did not improve from 0.00205
# Epoch 86/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0031 - val_accuracy: 0.9980
#
# Epoch 00086: val_loss did not improve from 0.00205
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0023 - val_accuracy: 0.9988
#
# Epoch 00087: val_loss did not improve from 0.00205
# Epoch 88/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9979 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00088: val_loss improved from 0.00205 to 0.00201, saving model to model.h5
# Epoch 89/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0778 - val_accuracy: 0.9844
#
# Epoch 00089: val_loss did not improve from 0.00201
# Epoch 90/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0046 - val_accuracy: 0.9977
#
# Epoch 00090: val_loss did not improve from 0.00201
# Epoch 91/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0104 - val_accuracy: 0.9969
#
# Epoch 00091: val_loss did not improve from 0.00201
# Epoch 92/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00092: val_loss did not improve from 0.00201
# Epoch 93/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00093: val_loss did not improve from 0.00201
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0029 - val_accuracy: 0.9980
#
# Epoch 00094: val_loss did not improve from 0.00201
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0247 - accuracy: 0.9944 - val_loss: 0.1277 - val_accuracy: 0.9621
#
# Epoch 00095: val_loss did not improve from 0.00201
# Epoch 96/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0094 - val_accuracy: 0.9969
#
# Epoch 00096: val_loss did not improve from 0.00201
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.0030 - val_accuracy: 0.9988
#
# Epoch 00097: val_loss did not improve from 0.00201
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00098: val_loss did not improve from 0.00201
# Epoch 99/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0019 - val_accuracy: 0.9984
#
# Epoch 00099: val_loss improved from 0.00201 to 0.00192, saving model to model.h5
# Epoch 100/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9972 - val_loss: 0.0102 - val_accuracy: 0.9965
#
# Epoch 00100: val_loss did not improve from 0.00192
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9965
# Val Score:  [0.010221830569207668, 0.9964843988418579]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.4010 - accuracy: 0.8668 - val_loss: 2.8408 - val_accuracy: 0.4922
#
# Epoch 00001: val_loss did not improve from 0.00192
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1395 - accuracy: 0.9508 - val_loss: 1.0090 - val_accuracy: 0.7102
#
# Epoch 00002: val_loss did not improve from 0.00192
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0988 - accuracy: 0.9654 - val_loss: 0.2202 - val_accuracy: 0.9352
#
# Epoch 00003: val_loss did not improve from 0.00192
# Epoch 4/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0974 - accuracy: 0.9653 - val_loss: 0.1165 - val_accuracy: 0.9582
#
# Epoch 00004: val_loss did not improve from 0.00192
# Epoch 5/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0601 - accuracy: 0.9777 - val_loss: 0.0790 - val_accuracy: 0.9750
#
# Epoch 00005: val_loss did not improve from 0.00192
# Epoch 6/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0559 - accuracy: 0.9819 - val_loss: 0.4294 - val_accuracy: 0.8922
#
# Epoch 00006: val_loss did not improve from 0.00192
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0521 - accuracy: 0.9809 - val_loss: 0.4163 - val_accuracy: 0.8691
#
# Epoch 00007: val_loss did not improve from 0.00192
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0426 - accuracy: 0.9840 - val_loss: 0.4222 - val_accuracy: 0.8805
#
# Epoch 00008: val_loss did not improve from 0.00192
# Epoch 9/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0332 - accuracy: 0.9890 - val_loss: 0.0192 - val_accuracy: 0.9926
#
# Epoch 00009: val_loss did not improve from 0.00192
# Epoch 10/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0442 - accuracy: 0.9854 - val_loss: 0.0272 - val_accuracy: 0.9906
#
# Epoch 00010: val_loss did not improve from 0.00192
# Epoch 11/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0330 - accuracy: 0.9886 - val_loss: 0.0126 - val_accuracy: 0.9949
#
# Epoch 00011: val_loss did not improve from 0.00192
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0251 - accuracy: 0.9909 - val_loss: 0.0113 - val_accuracy: 0.9961
#
# Epoch 00012: val_loss did not improve from 0.00192
# Epoch 13/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0256 - accuracy: 0.9918 - val_loss: 0.0342 - val_accuracy: 0.9871
#
# Epoch 00013: val_loss did not improve from 0.00192
# Epoch 14/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0327 - accuracy: 0.9893 - val_loss: 0.0411 - val_accuracy: 0.9848
#
# Epoch 00014: val_loss did not improve from 0.00192
# Epoch 15/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.0410 - val_accuracy: 0.9898
#
# Epoch 00015: val_loss did not improve from 0.00192
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0301 - accuracy: 0.9900 - val_loss: 0.0880 - val_accuracy: 0.9730
#
# Epoch 00016: val_loss did not improve from 0.00192
# Epoch 17/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0348 - accuracy: 0.9875 - val_loss: 0.0050 - val_accuracy: 0.9973
#
# Epoch 00017: val_loss did not improve from 0.00192
# Epoch 18/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.0787 - val_accuracy: 0.9777
#
# Epoch 00018: val_loss did not improve from 0.00192
# Epoch 19/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0174 - accuracy: 0.9938 - val_loss: 0.0091 - val_accuracy: 0.9973
#
# Epoch 00019: val_loss did not improve from 0.00192
# Epoch 20/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0250 - accuracy: 0.9922 - val_loss: 0.1258 - val_accuracy: 0.9637
#
# Epoch 00020: val_loss did not improve from 0.00192
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0264 - accuracy: 0.9901 - val_loss: 0.0071 - val_accuracy: 0.9980
#
# Epoch 00021: val_loss did not improve from 0.00192
# Epoch 22/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.0087 - val_accuracy: 0.9961
#
# Epoch 00022: val_loss did not improve from 0.00192
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.0079 - val_accuracy: 0.9980
#
# Epoch 00023: val_loss did not improve from 0.00192
# Epoch 24/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0357 - accuracy: 0.9889 - val_loss: 0.8955 - val_accuracy: 0.8492
#
# Epoch 00024: val_loss did not improve from 0.00192
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 0.0327 - val_accuracy: 0.9891
#
# Epoch 00025: val_loss did not improve from 0.00192
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0043 - val_accuracy: 0.9977
#
# Epoch 00026: val_loss did not improve from 0.00192
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0083 - val_accuracy: 0.9977
#
# Epoch 00027: val_loss did not improve from 0.00192
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0090 - val_accuracy: 0.9969
#
# Epoch 00028: val_loss did not improve from 0.00192
# Epoch 29/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.0116 - val_accuracy: 0.9969
#
# Epoch 00029: val_loss did not improve from 0.00192
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0126 - accuracy: 0.9951 - val_loss: 0.0049 - val_accuracy: 0.9969
#
# Epoch 00030: val_loss did not improve from 0.00192
# Epoch 31/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 0.0086 - val_accuracy: 0.9961
#
# Epoch 00031: val_loss did not improve from 0.00192
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.0422 - val_accuracy: 0.9852
#
# Epoch 00032: val_loss did not improve from 0.00192
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 0.0297 - val_accuracy: 0.9891
#
# Epoch 00033: val_loss did not improve from 0.00192
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0210 - accuracy: 0.9937 - val_loss: 0.2119 - val_accuracy: 0.9320
#
# Epoch 00034: val_loss did not improve from 0.00192
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.3224 - val_accuracy: 0.9121
#
# Epoch 00035: val_loss did not improve from 0.00192
# Epoch 36/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0158 - accuracy: 0.9951 - val_loss: 0.4985 - val_accuracy: 0.9090
#
# Epoch 00036: val_loss did not improve from 0.00192
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 0.0031 - val_accuracy: 0.9980
#
# Epoch 00037: val_loss did not improve from 0.00192
# Epoch 38/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0146 - accuracy: 0.9940 - val_loss: 0.0509 - val_accuracy: 0.9824
#
# Epoch 00038: val_loss did not improve from 0.00192
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.0057 - val_accuracy: 0.9984
#
# Epoch 00039: val_loss did not improve from 0.00192
# Epoch 40/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0083 - accuracy: 0.9963 - val_loss: 0.0926 - val_accuracy: 0.9742
#
# Epoch 00040: val_loss did not improve from 0.00192
# Epoch 41/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00188
# Epoch 21/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0229 - accuracy: 0.9935 - val_loss: 0.0514 - val_accuracy: 0.9863
#
# Epoch 00021: val_loss did not improve from 0.00188
# Epoch 22/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0267 - accuracy: 0.9921 - val_loss: 0.6127 - val_accuracy: 0.8598
#
# Epoch 00022: val_loss did not improve from 0.00188
# Epoch 23/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0249 - accuracy: 0.9925 - val_loss: 0.0212 - val_accuracy: 0.9926
#
# Epoch 00023: val_loss did not improve from 0.00188
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0242 - accuracy: 0.9918 - val_loss: 0.0084 - val_accuracy: 0.9973
#
# Epoch 00024: val_loss did not improve from 0.00188
# Epoch 25/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.0197 - val_accuracy: 0.9926
#
# Epoch 00025: val_loss did not improve from 0.00188
# Epoch 26/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0235 - accuracy: 0.9928 - val_loss: 0.0242 - val_accuracy: 0.9918
#
# Epoch 00026: val_loss did not improve from 0.00188
# Epoch 27/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 0.0168 - val_accuracy: 0.9941
#
# Epoch 00027: val_loss did not improve from 0.00188
# Epoch 28/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0174 - accuracy: 0.9936 - val_loss: 0.0156 - val_accuracy: 0.9949
#
# Epoch 00028: val_loss did not improve from 0.00188
# Epoch 29/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0228 - accuracy: 0.9935 - val_loss: 0.1102 - val_accuracy: 0.9719
#
# Epoch 00029: val_loss did not improve from 0.00188
# Epoch 30/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00030: val_loss did not improve from 0.00188
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0213 - accuracy: 0.9924 - val_loss: 0.0261 - val_accuracy: 0.9910
#
# Epoch 00031: val_loss did not improve from 0.00188
# Epoch 32/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0200 - accuracy: 0.9944 - val_loss: 0.0202 - val_accuracy: 0.9941
#
# Epoch 00032: val_loss did not improve from 0.00188
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.0296 - val_accuracy: 0.9914
#
# Epoch 00033: val_loss did not improve from 0.00188
# Epoch 34/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0161 - accuracy: 0.9945 - val_loss: 0.3294 - val_accuracy: 0.9309
#
# Epoch 00034: val_loss did not improve from 0.00188
# Epoch 35/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0388 - val_accuracy: 0.9863
#
# Epoch 00035: val_loss did not improve from 0.00188
# Epoch 36/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.0652 - val_accuracy: 0.9793
#
# Epoch 00036: val_loss did not improve from 0.00188
# Epoch 37/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0654 - val_accuracy: 0.9801
#
# Epoch 00037: val_loss did not improve from 0.00188
# Epoch 38/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00038: val_loss did not improve from 0.00188
# Epoch 39/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.0064 - val_accuracy: 0.9980
#
# Epoch 00039: val_loss did not improve from 0.00188
# Epoch 40/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0150 - accuracy: 0.9957 - val_loss: 0.0329 - val_accuracy: 0.9883
#
# Epoch 00040: val_loss did not improve from 0.00188
# Epoch 41/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0130 - accuracy: 0.9951 - val_loss: 0.0314 - val_accuracy: 0.9914
#
# Epoch 00041: val_loss did not improve from 0.00188
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0222 - accuracy: 0.9935 - val_loss: 0.0034 - val_accuracy: 0.9977
#
# Epoch 00042: val_loss did not improve from 0.00188
# Epoch 43/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0085 - val_accuracy: 0.9977
#
# Epoch 00043: val_loss did not improve from 0.00188
# Epoch 44/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0687 - val_accuracy: 0.9828
#
# Epoch 00044: val_loss did not improve from 0.00188
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 0.0093 - val_accuracy: 0.9965
#
# Epoch 00045: val_loss did not improve from 0.00188
# Epoch 46/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0112 - val_accuracy: 0.9961
#
# Epoch 00046: val_loss did not improve from 0.00188
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0148 - val_accuracy: 0.9937
#
# Epoch 00047: val_loss did not improve from 0.00188
# Epoch 48/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0124 - val_accuracy: 0.9945
#
# Epoch 00048: val_loss did not improve from 0.00188
# Epoch 49/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.0590 - val_accuracy: 0.9812
#
# Epoch 00049: val_loss did not improve from 0.00188
# Epoch 50/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.0114 - val_accuracy: 0.9957
#
# Epoch 00050: val_loss did not improve from 0.00188
# Epoch 51/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.0676 - val_accuracy: 0.9812
#
# Epoch 00051: val_loss did not improve from 0.00188
# Epoch 52/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00052: val_loss did not improve from 0.00188
# Epoch 53/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 0.0142 - val_accuracy: 0.9945
#
# Epoch 00053: val_loss did not improve from 0.00188
# Epoch 54/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0109 - accuracy: 0.9957 - val_loss: 4.0036 - val_accuracy: 0.6957
#
# Epoch 00054: val_loss did not improve from 0.00188
# Epoch 55/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0084 - val_accuracy: 0.9973
#
# Epoch 00055: val_loss did not improve from 0.00188
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0078 - accuracy: 0.9966 - val_loss: 0.1146 - val_accuracy: 0.9691
#
# Epoch 00056: val_loss did not improve from 0.00188
# Epoch 57/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0084 - val_accuracy: 0.9977
#
# Epoch 00057: val_loss did not improve from 0.00188
# Epoch 58/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 11.3957 - val_accuracy: 0.5121
#
# Epoch 00058: val_loss did not improve from 0.00188
# Epoch 59/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0113 - accuracy: 0.9956 - val_loss: 0.0374 - val_accuracy: 0.9883
#
# Epoch 00059: val_loss did not improve from 0.00188
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9968 - val_loss: 0.0031 - val_accuracy: 0.9984
#
# Epoch 00060: val_loss did not improve from 0.00188
# Epoch 61/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.0280 - val_accuracy: 0.9922
#
# Epoch 00061: val_loss did not improve from 0.00188
# Epoch 62/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0089 - accuracy: 0.9959 - val_loss: 0.0035 - val_accuracy: 0.9984
#
# Epoch 00062: val_loss did not improve from 0.00188
# Epoch 63/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0065 - accuracy: 0.9970 - val_loss: 0.0088 - val_accuracy: 0.9957
#
# Epoch 00063: val_loss did not improve from 0.00188
# Epoch 64/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00064: val_loss did not improve from 0.00188
# Epoch 65/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0193 - val_accuracy: 0.9941
#
# Epoch 00065: val_loss did not improve from 0.00188
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0165 - accuracy: 0.9947 - val_loss: 0.0828 - val_accuracy: 0.9734
#
# Epoch 00066: val_loss did not improve from 0.00188
# Epoch 67/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00067: val_loss did not improve from 0.00188
# Epoch 68/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0084 - accuracy: 0.9965 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00068: val_loss did not improve from 0.00188
# Epoch 69/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0126 - val_accuracy: 0.9953
#
# Epoch 00069: val_loss did not improve from 0.00188
# Epoch 70/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9975 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00070: val_loss did not improve from 0.00188
# Epoch 71/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00188
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00072: val_loss did not improve from 0.00188
# Epoch 73/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00073: val_loss did not improve from 0.00188
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.0735 - val_accuracy: 0.9770
#
# Epoch 00074: val_loss did not improve from 0.00188
# Epoch 75/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0084 - accuracy: 0.9961 - val_loss: 0.0544 - val_accuracy: 0.9805
#
# Epoch 00075: val_loss did not improve from 0.00188
# Epoch 76/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00076: val_loss did not improve from 0.00188
# Epoch 77/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9967 - val_loss: 0.0081 - val_accuracy: 0.9969
#
# Epoch 00077: val_loss did not improve from 0.00188
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0068 - val_accuracy: 0.9973
#
# Epoch 00078: val_loss did not improve from 0.00188
# Epoch 79/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9961 - val_loss: 0.0068 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00188
# Epoch 80/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00080: val_loss did not improve from 0.00188
# Epoch 81/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00081: val_loss did not improve from 0.00188
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0073 - val_accuracy: 0.9977
#
# Epoch 00082: val_loss did not improve from 0.00188
# Epoch 83/100
# 320/320 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0032 - val_accuracy: 0.9988
#
# Epoch 00083: val_loss did not improve from 0.00188
# Epoch 84/100
# 320/320 [==============================] - 2s 8ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.1065 - val_accuracy: 0.9746
#
# Epoch 00084: val_loss did not improve from 0.00188
# Epoch 85/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0038 - val_accuracy: 0.9977
#
# Epoch 00085: val_loss did not improve from 0.00188
# Epoch 86/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00086: val_loss did not improve from 0.00188
# Epoch 87/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0114 - accuracy: 0.9956 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00087: val_loss did not improve from 0.00188
# Epoch 88/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.0063 - val_accuracy: 0.9969
#
# Epoch 00088: val_loss did not improve from 0.00188
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0054 - accuracy: 0.9974 - val_loss: 0.0037 - val_accuracy: 0.9977
#
# Epoch 00089: val_loss did not improve from 0.00188
# Epoch 90/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0027 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00188
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00091: val_loss did not improve from 0.00188
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00092: val_loss did not improve from 0.00188
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0034 - val_accuracy: 0.9984
#
# Epoch 00093: val_loss did not improve from 0.00188
# Epoch 94/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0130 - val_accuracy: 0.9980
#
# Epoch 00094: val_loss did not improve from 0.00188
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0021 - val_accuracy: 0.9984
#
# Epoch 00095: val_loss did not improve from 0.00188
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9971 - val_loss: 0.0021 - val_accuracy: 0.9984
#
# Epoch 00096: val_loss did not improve from 0.00188
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0078 - val_accuracy: 0.9969
#
# Epoch 00097: val_loss did not improve from 0.00188
# Epoch 98/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.0024 - val_accuracy: 0.9984
#
# Epoch 00098: val_loss did not improve from 0.00188
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.0034 - val_accuracy: 0.9988
#
# Epoch 00099: val_loss did not improve from 0.00188
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.0026 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00188
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 0.9980
# Val Score:  [0.0026160073466598988, 0.998046875]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 4ms/step - loss: 0.0035 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
