# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Nadam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
#model.add(Conv2D(256, (3, 3), padding="same"))
#model.add(Activation("relu"))
#model.add(BatchNormalization(axis=chanDim))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# 2022-08-04 07:06:26.009098: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:26.174995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:26.175777: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:26.177574: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-04 07:06:26.177947: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:26.178739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:26.179521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:28.575113: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:28.575954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:28.576632: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-04 07:06:28.578223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              13108224
# _________________________________________________________________
# activation_4 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Nadam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# 2022-08-04 07:06:31.914329: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-08-04 07:06:34.799859: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 320/320 [==============================] - 13s 14ms/step - loss: 0.4086 - accuracy: 0.8705 - val_loss: 5.7110 - val_accuracy: 0.4648
#
# Epoch 00001: val_loss improved from inf to 5.71099, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.1403 - accuracy: 0.9520 - val_loss: 1.3649 - val_accuracy: 0.7488
#
# Epoch 00002: val_loss improved from 5.71099 to 1.36494, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1002 - accuracy: 0.9680 - val_loss: 0.3433 - val_accuracy: 0.8902
#
# Epoch 00003: val_loss improved from 1.36494 to 0.34333, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0736 - accuracy: 0.9766 - val_loss: 0.1327 - val_accuracy: 0.9535
#
# Epoch 00004: val_loss improved from 0.34333 to 0.13266, saving model to model.h5
# Epoch 5/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0641 - accuracy: 0.9794 - val_loss: 0.3421 - val_accuracy: 0.8988
#
# Epoch 00005: val_loss did not improve from 0.13266
# Epoch 6/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0465 - accuracy: 0.9846 - val_loss: 1.5464 - val_accuracy: 0.7332
#
# Epoch 00006: val_loss did not improve from 0.13266
# Epoch 7/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0463 - accuracy: 0.9854 - val_loss: 0.9795 - val_accuracy: 0.8449
#
# Epoch 00007: val_loss did not improve from 0.13266
# Epoch 8/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0465 - accuracy: 0.9836 - val_loss: 0.9795 - val_accuracy: 0.8281
#
# Epoch 00008: val_loss did not improve from 0.13266
# Epoch 9/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0416 - accuracy: 0.9863 - val_loss: 1.6647 - val_accuracy: 0.7000
#
# Epoch 00009: val_loss did not improve from 0.13266
# Epoch 10/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.1307 - val_accuracy: 0.9508
#
# Epoch 00010: val_loss improved from 0.13266 to 0.13074, saving model to model.h5
# Epoch 11/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0335 - accuracy: 0.9889 - val_loss: 0.0433 - val_accuracy: 0.9840
#
# Epoch 00011: val_loss improved from 0.13074 to 0.04326, saving model to model.h5
# Epoch 12/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0320 - accuracy: 0.9890 - val_loss: 0.0631 - val_accuracy: 0.9781
#
# Epoch 00012: val_loss did not improve from 0.04326
# Epoch 13/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0424 - accuracy: 0.9871 - val_loss: 1.5258 - val_accuracy: 0.7770
#
# Epoch 00013: val_loss did not improve from 0.04326
# Epoch 14/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0346 - accuracy: 0.9879 - val_loss: 0.0601 - val_accuracy: 0.9812
#
# Epoch 00014: val_loss did not improve from 0.04326
# Epoch 15/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0540 - accuracy: 0.9850 - val_loss: 0.2864 - val_accuracy: 0.9535
#
# Epoch 00015: val_loss did not improve from 0.04326
# Epoch 16/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0346 - accuracy: 0.9895 - val_loss: 0.0359 - val_accuracy: 0.9898
#
# Epoch 00016: val_loss improved from 0.04326 to 0.03586, saving model to model.h5
# Epoch 17/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0264 - accuracy: 0.9919 - val_loss: 0.4724 - val_accuracy: 0.9187
#
# Epoch 00017: val_loss did not improve from 0.03586
# Epoch 18/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0269 - accuracy: 0.9908 - val_loss: 0.7798 - val_accuracy: 0.8582
#
# Epoch 00018: val_loss did not improve from 0.03586
# Epoch 19/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0144 - accuracy: 0.9949 - val_loss: 0.0881 - val_accuracy: 0.9727
#
# Epoch 00019: val_loss did not improve from 0.03586
# Epoch 20/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0210 - accuracy: 0.9935 - val_loss: 0.1594 - val_accuracy: 0.9633
#
# Epoch 00020: val_loss did not improve from 0.03586
# Epoch 21/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0301 - accuracy: 0.9909 - val_loss: 0.0111 - val_accuracy: 0.9969
#
# Epoch 00021: val_loss improved from 0.03586 to 0.01107, saving model to model.h5
# Epoch 22/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0240 - accuracy: 0.9929 - val_loss: 0.7573 - val_accuracy: 0.8727
#
# Epoch 00022: val_loss did not improve from 0.01107
# Epoch 23/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0325 - accuracy: 0.9900 - val_loss: 0.2400 - val_accuracy: 0.9344
#
# Epoch 00023: val_loss did not improve from 0.01107
# Epoch 24/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0343 - accuracy: 0.9910 - val_loss: 3.8079 - val_accuracy: 0.5836
#
# Epoch 00024: val_loss did not improve from 0.01107
# Epoch 25/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0207 - accuracy: 0.9936 - val_loss: 0.0569 - val_accuracy: 0.9809
#
# Epoch 00025: val_loss did not improve from 0.01107
# Epoch 26/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0168 - accuracy: 0.9942 - val_loss: 0.0707 - val_accuracy: 0.9781
#
# Epoch 00026: val_loss did not improve from 0.01107
# Epoch 27/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0314 - accuracy: 0.9914 - val_loss: 0.7081 - val_accuracy: 0.8781
#
# Epoch 00027: val_loss did not improve from 0.01107
# Epoch 28/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.0164 - val_accuracy: 0.9934
#
# Epoch 00028: val_loss did not improve from 0.01107
# Epoch 29/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0174 - accuracy: 0.9943 - val_loss: 1.3589 - val_accuracy: 0.8137
#
# Epoch 00029: val_loss did not improve from 0.01107
# Epoch 30/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0203 - accuracy: 0.9936 - val_loss: 1.8197 - val_accuracy: 0.7988
#
# Epoch 00030: val_loss did not improve from 0.01107
# Epoch 31/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0178 - accuracy: 0.9939 - val_loss: 0.0357 - val_accuracy: 0.9926
#
# Epoch 00031: val_loss did not improve from 0.01107
# Epoch 32/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 8.7107 - val_accuracy: 0.4574
#
# Epoch 00032: val_loss did not improve from 0.01107
# Epoch 33/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 2.1918 - val_accuracy: 0.6949
#
# Epoch 00033: val_loss did not improve from 0.01107
# Epoch 34/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0199 - accuracy: 0.9931 - val_loss: 0.0578 - val_accuracy: 0.9887
#
# Epoch 00034: val_loss did not improve from 0.01107
# Epoch 35/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0210 - accuracy: 0.9934 - val_loss: 0.8589 - val_accuracy: 0.8250
#
# Epoch 00035: val_loss did not improve from 0.01107
# Epoch 36/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 0.0553 - val_accuracy: 0.9855
#
# Epoch 00036: val_loss did not improve from 0.01107
# Epoch 37/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 0.0052 - val_accuracy: 0.9977
#
# Epoch 00037: val_loss improved from 0.01107 to 0.00515, saving model to model.h5
# Epoch 38/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0228 - accuracy: 0.9938 - val_loss: 0.1431 - val_accuracy: 0.9664
#
# Epoch 00038: val_loss did not improve from 0.00515
# Epoch 39/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0124 - accuracy: 0.9949 - val_loss: 0.0088 - val_accuracy: 0.9980
#
# Epoch 00039: val_loss did not improve from 0.00515
# Epoch 40/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0304 - val_accuracy: 0.9891
#
# Epoch 00040: val_loss did not improve from 0.00515
# Epoch 41/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 1.9792 - val_accuracy: 0.7797
#
# Epoch 00041: val_loss did not improve from 0.00515
# Epoch 42/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0257 - accuracy: 0.9931 - val_loss: 0.2108 - val_accuracy: 0.9512
#
# Epoch 00042: val_loss did not improve from 0.00515
# Epoch 43/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 18.6556 - val_accuracy: 0.5465
#
# Epoch 00043: val_loss did not improve from 0.00515
# Epoch 44/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.0098 - val_accuracy: 0.9965
#
# Epoch 00044: val_loss did not improve from 0.00515
# Epoch 45/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0135 - accuracy: 0.9950 - val_loss: 2.9344 - val_accuracy: 0.5430
#
# Epoch 00045: val_loss did not improve from 0.00515
# Epoch 46/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0507 - accuracy: 0.9890 - val_loss: 0.0164 - val_accuracy: 0.9957
#
# Epoch 00046: val_loss did not improve from 0.00515
# Epoch 47/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0096 - val_accuracy: 0.9969
#
# Epoch 00047: val_loss did not improve from 0.00515
# Epoch 48/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.1990 - val_accuracy: 0.9566
#
# Epoch 00048: val_loss did not improve from 0.00515
# Epoch 49/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.1341 - val_accuracy: 0.9699
#
# Epoch 00049: val_loss did not improve from 0.00515
# Epoch 50/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0176 - accuracy: 0.9952 - val_loss: 0.0055 - val_accuracy: 0.9973
#
# Epoch 00050: val_loss did not improve from 0.00515
# Epoch 51/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.0019 - val_accuracy: 0.9988
#
# Epoch 00051: val_loss improved from 0.00515 to 0.00190, saving model to model.h5
# Epoch 52/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0123 - accuracy: 0.9967 - val_loss: 1.4052 - val_accuracy: 0.7637
#
# Epoch 00052: val_loss did not improve from 0.00190
# Epoch 53/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0142 - accuracy: 0.9965 - val_loss: 0.0148 - val_accuracy: 0.9953
#
# Epoch 00053: val_loss did not improve from 0.00190
# Epoch 54/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0196 - accuracy: 0.9948 - val_loss: 0.0340 - val_accuracy: 0.9898
#
# Epoch 00054: val_loss did not improve from 0.00190
# Epoch 55/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.0109 - val_accuracy: 0.9977
#
# Epoch 00055: val_loss did not improve from 0.00190
# Epoch 56/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0199 - accuracy: 0.9939 - val_loss: 0.0088 - val_accuracy: 0.9965
#
# Epoch 00056: val_loss did not improve from 0.00190
# Epoch 57/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0142 - accuracy: 0.9958 - val_loss: 0.0069 - val_accuracy: 0.9969
#
# Epoch 00057: val_loss did not improve from 0.00190
# Epoch 58/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.0303 - val_accuracy: 0.9949
#
# Epoch 00058: val_loss did not improve from 0.00190
# Epoch 59/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0055 - val_accuracy: 0.9980
#
# Epoch 00059: val_loss did not improve from 0.00190
# Epoch 60/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 2.8159 - val_accuracy: 0.6902
#
# Epoch 00060: val_loss did not improve from 0.00190
# Epoch 61/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0136 - accuracy: 0.9957 - val_loss: 2.2293 - val_accuracy: 0.7793
#
# Epoch 00061: val_loss did not improve from 0.00190
# Epoch 62/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.5412 - val_accuracy: 0.8719
#
# Epoch 00062: val_loss did not improve from 0.00190
# Epoch 63/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0217 - val_accuracy: 0.9949
#
# Epoch 00063: val_loss did not improve from 0.00190
# Epoch 64/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0196 - accuracy: 0.9948 - val_loss: 1.2795 - val_accuracy: 0.8160
#
# Epoch 00064: val_loss did not improve from 0.00190
# Epoch 65/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 0.1081 - val_accuracy: 0.9691
#
# Epoch 00065: val_loss did not improve from 0.00190
# Epoch 66/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.9100 - val_accuracy: 0.8742
#
# Epoch 00066: val_loss did not improve from 0.00190
# Epoch 67/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.0072 - val_accuracy: 0.9965
#
# Epoch 00067: val_loss did not improve from 0.00190
# Epoch 68/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0600 - val_accuracy: 0.9859
#
# Epoch 00068: val_loss did not improve from 0.00190
# Epoch 69/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0062 - accuracy: 0.9975 - val_loss: 0.0275 - val_accuracy: 0.9926
#
# Epoch 00069: val_loss did not improve from 0.00190
# Epoch 70/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.0128 - val_accuracy: 0.9965
#
# Epoch 00070: val_loss did not improve from 0.00190
# Epoch 71/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.1393 - val_accuracy: 0.9719
#
# Epoch 00071: val_loss did not improve from 0.00190
# Epoch 72/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0154 - accuracy: 0.9963 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00072: val_loss did not improve from 0.00190
# Epoch 73/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0862 - val_accuracy: 0.9785
#
# Epoch 00073: val_loss did not improve from 0.00190
# Epoch 74/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.0036 - val_accuracy: 0.9977
#
# Epoch 00074: val_loss did not improve from 0.00190
# Epoch 75/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.0593 - val_accuracy: 0.9828
#
# Epoch 00075: val_loss did not improve from 0.00190
# Epoch 76/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0192 - accuracy: 0.9943 - val_loss: 0.0062 - val_accuracy: 0.9977
#
# Epoch 00076: val_loss did not improve from 0.00190
# Epoch 77/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0061 - val_accuracy: 0.9980
#
# Epoch 00077: val_loss did not improve from 0.00190
# Epoch 78/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.0094 - val_accuracy: 0.9965
#
# Epoch 00078: val_loss did not improve from 0.00190
# Epoch 79/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 7.0376 - val_accuracy: 0.5059
#
# Epoch 00079: val_loss did not improve from 0.00190
# Epoch 80/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0042 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00190
# Epoch 81/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0100 - val_accuracy: 0.9980
#
# Epoch 00081: val_loss did not improve from 0.00190
# Epoch 82/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0136 - accuracy: 0.9954 - val_loss: 1.4409 - val_accuracy: 0.8734
#
# Epoch 00082: val_loss did not improve from 0.00190
# Epoch 83/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0828 - val_accuracy: 0.9738
#
# Epoch 00083: val_loss did not improve from 0.00190
# Epoch 84/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0252 - accuracy: 0.9926 - val_loss: 2.7806 - val_accuracy: 0.7488
#
# Epoch 00084: val_loss did not improve from 0.00190
# Epoch 85/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0077 - accuracy: 0.9965 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00085: val_loss did not improve from 0.00190
# Epoch 86/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0387 - val_accuracy: 0.9914
#
# Epoch 00086: val_loss did not improve from 0.00190
# Epoch 87/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00087: val_loss did not improve from 0.00190
# Epoch 88/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.1541 - val_accuracy: 0.9625
#
# Epoch 00088: val_loss did not improve from 0.00190
# Epoch 89/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.3682 - val_accuracy: 0.9344
#
# Epoch 00089: val_loss did not improve from 0.00190
# Epoch 90/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.1008 - val_accuracy: 0.9750
#
# Epoch 00090: val_loss did not improve from 0.00190
# Epoch 91/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0149 - accuracy: 0.9963 - val_loss: 0.0105 - val_accuracy: 0.9965
#
# Epoch 00091: val_loss did not improve from 0.00190
# Epoch 92/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.1095 - val_accuracy: 0.9750
#
# Epoch 00092: val_loss did not improve from 0.00190
# Epoch 93/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0040 - val_accuracy: 0.9984
#
# Epoch 00093: val_loss did not improve from 0.00190
# Epoch 94/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0088 - accuracy: 0.9973 - val_loss: 1.1551 - val_accuracy: 0.8363
#
# Epoch 00094: val_loss did not improve from 0.00190
# Epoch 95/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0086 - val_accuracy: 0.9980
#
# Epoch 00095: val_loss did not improve from 0.00190
# Epoch 96/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0107 - accuracy: 0.9971 - val_loss: 0.3746 - val_accuracy: 0.9059
#
# Epoch 00096: val_loss did not improve from 0.00190
# Epoch 97/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0145 - accuracy: 0.9964 - val_loss: 0.1730 - val_accuracy: 0.9602
#
# Epoch 00097: val_loss did not improve from 0.00190
# Epoch 98/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.2051 - val_accuracy: 0.9512
#
# Epoch 00098: val_loss did not improve from 0.00190
# Epoch 99/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.1966 - val_accuracy: 0.9582
#
# Epoch 00099: val_loss did not improve from 0.00190
# Epoch 100/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0068 - val_accuracy: 0.9977
#
# Epoch 00100: val_loss did not improve from 0.00190
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9977
# Val Score:  [0.0067987688817083836, 0.9976562261581421]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 6s 13ms/step - loss: 0.4555 - accuracy: 0.8474 - val_loss: 2.0564 - val_accuracy: 0.5992
#
# Epoch 00001: val_loss did not improve from 0.00190
# Epoch 2/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.2012 - accuracy: 0.9246 - val_loss: 0.0976 - val_accuracy: 0.9648
#
# Epoch 00002: val_loss did not improve from 0.00190
# Epoch 3/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.1198 - accuracy: 0.9592 - val_loss: 0.4788 - val_accuracy: 0.8680
#
# Epoch 00003: val_loss did not improve from 0.00190
# Epoch 4/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0904 - accuracy: 0.9683 - val_loss: 0.0788 - val_accuracy: 0.9723
#
# Epoch 00004: val_loss did not improve from 0.00190
# Epoch 5/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0692 - accuracy: 0.9757 - val_loss: 0.1213 - val_accuracy: 0.9555
#
# Epoch 00005: val_loss did not improve from 0.00190
# Epoch 6/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0678 - accuracy: 0.9773 - val_loss: 0.0866 - val_accuracy: 0.9727
#
# Epoch 00006: val_loss did not improve from 0.00190
# Epoch 7/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0539 - accuracy: 0.9826 - val_loss: 2.1454 - val_accuracy: 0.7074
#
# Epoch 00007: val_loss did not improve from 0.00190
# Epoch 8/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0536 - accuracy: 0.9829 - val_loss: 0.0196 - val_accuracy: 0.9945
#
# Epoch 00008: val_loss did not improve from 0.00190
# Epoch 9/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0484 - accuracy: 0.9835 - val_loss: 0.1775 - val_accuracy: 0.9395
#
# Epoch 00009: val_loss did not improve from 0.00190
# Epoch 10/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0361 - accuracy: 0.9885 - val_loss: 0.3017 - val_accuracy: 0.9262
#
# Epoch 00010: val_loss did not improve from 0.00190
# Epoch 11/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0408 - accuracy: 0.9854 - val_loss: 0.0290 - val_accuracy: 0.9871
#
# Epoch 00011: val_loss did not improve from 0.00190
# Epoch 12/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0307 - accuracy: 0.9901 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00012: val_loss did not improve from 0.00190
# Epoch 13/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0310 - accuracy: 0.9887 - val_loss: 0.0306 - val_accuracy: 0.9883
#
# Epoch 00013: val_loss did not improve from 0.00190
# Epoch 14/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0477 - accuracy: 0.9857 - val_loss: 0.1087 - val_accuracy: 0.9664
#
# Epoch 00014: val_loss did not improve from 0.00190
# Epoch 15/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0319 - accuracy: 0.9897 - val_loss: 0.0187 - val_accuracy: 0.9922
#
# Epoch 00015: val_loss did not improve from 0.00190
# Epoch 16/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0292 - accuracy: 0.9907 - val_loss: 0.0063 - val_accuracy: 0.9965
#
# Epoch 00016: val_loss did not improve from 0.00190
# Epoch 17/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0304 - accuracy: 0.9893 - val_loss: 0.0151 - val_accuracy: 0.9934
#
# Epoch 00017: val_loss did not improve from 0.00190
# Epoch 18/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0253 - accuracy: 0.9905 - val_loss: 0.0501 - val_accuracy: 0.9812
#
# Epoch 00018: val_loss did not improve from 0.00190
# Epoch 19/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0381 - accuracy: 0.9884 - val_loss: 0.2537 - val_accuracy: 0.9488
#
# Epoch 00019: val_loss did not improve from 0.00190
# Epoch 20/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0223 - accuracy: 0.9929 - val_loss: 0.0094 - val_accuracy: 0.9969
#
# Epoch 00020: val_loss did not improve from 0.00190
# Epoch 21/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.6029 - val_accuracy: 0.8703
#
# Epoch 00021: val_loss did not improve from 0.00190
# Epoch 22/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0238 - accuracy: 0.9913 - val_loss: 0.0168 - val_accuracy: 0.9934
#
# Epoch 00022: val_loss did not improve from 0.00190
# Epoch 23/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.0811 - val_accuracy: 0.9789
#
# Epoch 00023: val_loss did not improve from 0.00190
# Epoch 24/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0247 - accuracy: 0.9918 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00024: val_loss did not improve from 0.00190
# Epoch 25/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0320 - accuracy: 0.9900 - val_loss: 0.0573 - val_accuracy: 0.9832
#
# Epoch 00025: val_loss did not improve from 0.00190
# Epoch 26/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0247 - val_accuracy: 0.9910
#
# Epoch 00026: val_loss did not improve from 0.00190
# Epoch 27/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.0893 - val_accuracy: 0.9695
#
# Epoch 00027: val_loss did not improve from 0.00190
# Epoch 28/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0168 - accuracy: 0.9939 - val_loss: 0.1220 - val_accuracy: 0.9703
#
# Epoch 00028: val_loss did not improve from 0.00190
# Epoch 29/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0191 - accuracy: 0.9929 - val_loss: 0.0155 - val_accuracy: 0.9945
#
# Epoch 00029: val_loss did not improve from 0.00190
# Epoch 30/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0235 - accuracy: 0.9932 - val_loss: 0.0173 - val_accuracy: 0.9945
#
# Epoch 00030: val_loss did not improve from 0.00190
# Epoch 31/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 4.0255 - val_accuracy: 0.7582
#
# Epoch 00031: val_loss did not improve from 0.00190
# Epoch 32/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0218 - accuracy: 0.9933 - val_loss: 0.0839 - val_accuracy: 0.9695
#
# Epoch 00032: val_loss did not improve from 0.00190
# Epoch 33/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.0094 - val_accuracy: 0.9973
#
# Epoch 00033: val_loss did not improve from 0.00190
# Epoch 34/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0159 - accuracy: 0.9937 - val_loss: 0.5657 - val_accuracy: 0.8910
#
# Epoch 00034: val_loss did not improve from 0.00190
# Epoch 35/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0297 - accuracy: 0.9919 - val_loss: 0.2435 - val_accuracy: 0.9453
#
# Epoch 00035: val_loss did not improve from 0.00190
# Epoch 36/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.0052 - val_accuracy: 0.9984
#
# Epoch 00036: val_loss did not improve from 0.00190
# Epoch 37/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.1210 - val_accuracy: 0.9738
#
# Epoch 00037: val_loss did not improve from 0.00190
# Epoch 38/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0172 - accuracy: 0.9949 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00038: val_loss did not improve from 0.00190
# Epoch 39/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0258 - accuracy: 0.9927 - val_loss: 0.0417 - val_accuracy: 0.9859
#
# Epoch 00039: val_loss did not improve from 0.00190
# Epoch 40/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 0.0062 - val_accuracy: 0.9973
#
# Epoch 00040: val_loss did not improve from 0.00190
# Epoch 41/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.2106 - val_accuracy: 0.9520
#
# Epoch 00041: val_loss did not improve from 0.00190
# Epoch 42/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.2240 - val_accuracy: 0.9500
#
# Epoch 00042: val_loss did not improve from 0.00190
# Epoch 43/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.3219 - val_accuracy: 0.9293
#
# Epoch 00043: val_loss did not improve from 0.00190
# Epoch 44/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.0324 - val_accuracy: 0.9906
#
# Epoch 00044: val_loss did not improve from 0.00190
# Epoch 45/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0275 - accuracy: 0.9906 - val_loss: 0.0061 - val_accuracy: 0.9977
#
# Epoch 00045: val_loss did not improve from 0.00190
# Epoch 46/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0154 - val_accuracy: 0.9949
#
# Epoch 00046: val_loss did not improve from 0.00190
# Epoch 47/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0160 - accuracy: 0.9949 - val_loss: 0.0214 - val_accuracy: 0.9918
#
# Epoch 00047: val_loss did not improve from 0.00190
# Epoch 48/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.1763 - val_accuracy: 0.9625
#
# Epoch 00048: val_loss did not improve from 0.00190
# Epoch 49/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0305 - accuracy: 0.9915 - val_loss: 0.0091 - val_accuracy: 0.9965
#
# Epoch 00049: val_loss did not improve from 0.00190
# Epoch 50/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00050: val_loss did not improve from 0.00190
# Epoch 51/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.0195 - val_accuracy: 0.9918
#
# Epoch 00051: val_loss did not improve from 0.00190
# Epoch 52/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0081 - accuracy: 0.9966 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00052: val_loss did not improve from 0.00190
# Epoch 53/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0137 - accuracy: 0.9944 - val_loss: 0.0073 - val_accuracy: 0.9980
#
# Epoch 00053: val_loss did not improve from 0.00190
# Epoch 54/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0122 - accuracy: 0.9956 - val_loss: 0.0976 - val_accuracy: 0.9781
#
# Epoch 00054: val_loss did not improve from 0.00190
# Epoch 55/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.0475 - val_accuracy: 0.9898
#
# Epoch 00055: val_loss did not improve from 0.00190
# Epoch 56/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0149 - accuracy: 0.9959 - val_loss: 0.0548 - val_accuracy: 0.9816
#
# Epoch 00056: val_loss did not improve from 0.00190
# Epoch 57/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0196 - accuracy: 0.9943 - val_loss: 0.7824 - val_accuracy: 0.9109
#
# Epoch 00057: val_loss did not improve from 0.00190
# Epoch 58/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.1695 - val_accuracy: 0.9629
#
# Epoch 00058: val_loss did not improve from 0.00190
# Epoch 59/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.0048 - val_accuracy: 0.9984
#
# Epoch 00059: val_loss did not improve from 0.00190
# Epoch 60/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.0292 - val_accuracy: 0.9922
#
# Epoch 00060: val_loss did not improve from 0.00190
# Epoch 61/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0149 - accuracy: 0.9947 - val_loss: 0.0393 - val_accuracy: 0.9891
#
# Epoch 00061: val_loss did not improve from 0.00190
# Epoch 62/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0509 - val_accuracy: 0.9828
#
# Epoch 00062: val_loss did not improve from 0.00190
# Epoch 63/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00063: val_loss did not improve from 0.00190
# Epoch 64/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.0107 - val_accuracy: 0.9969
#
# Epoch 00064: val_loss did not improve from 0.00190
# Epoch 65/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0158 - accuracy: 0.9954 - val_loss: 0.0373 - val_accuracy: 0.9902
#
# Epoch 00065: val_loss did not improve from 0.00190
# Epoch 66/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 0.0061 - val_accuracy: 0.9973
#
# Epoch 00066: val_loss did not improve from 0.00190
# Epoch 67/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.0091 - val_accuracy: 0.9977
#
# Epoch 00067: val_loss did not improve from 0.00190
# Epoch 68/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 2.3358 - val_accuracy: 0.7422
#
# Epoch 00068: val_loss did not improve from 0.00190
# Epoch 69/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00190
# Epoch 70/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0037 - val_accuracy: 0.9984
#
# Epoch 00070: val_loss did not improve from 0.00190
# Epoch 71/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.0524 - val_accuracy: 0.9867
#
# Epoch 00071: val_loss did not improve from 0.00190
# Epoch 72/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0130 - val_accuracy: 0.9965
#
# Epoch 00072: val_loss did not improve from 0.00190
# Epoch 73/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0180 - accuracy: 0.9949 - val_loss: 0.0052 - val_accuracy: 0.9973
#
# Epoch 00073: val_loss did not improve from 0.00190
# Epoch 74/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0085 - accuracy: 0.9966 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00190
# Epoch 75/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0445 - val_accuracy: 0.9910
#
# Epoch 00075: val_loss did not improve from 0.00190
# Epoch 76/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0511 - val_accuracy: 0.9852
#
# Epoch 00076: val_loss did not improve from 0.00190
# Epoch 77/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0106 - accuracy: 0.9968 - val_loss: 0.0126 - val_accuracy: 0.9973
#
# Epoch 00077: val_loss did not improve from 0.00190
# Epoch 78/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0236 - val_accuracy: 0.9922
#
# Epoch 00078: val_loss did not improve from 0.00190
# Epoch 79/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0202 - accuracy: 0.9945 - val_loss: 0.9640 - val_accuracy: 0.8801
#
# Epoch 00079: val_loss did not improve from 0.00190
# Epoch 80/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0178 - val_accuracy: 0.9949
#
# Epoch 00080: val_loss did not improve from 0.00190
# Epoch 81/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1555 - val_accuracy: 0.9613
#
# Epoch 00081: val_loss did not improve from 0.00190
# Epoch 82/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.0093 - val_accuracy: 0.9965
#
# Epoch 00082: val_loss did not improve from 0.00190
# Epoch 83/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.0126 - val_accuracy: 0.9961
#
# Epoch 00083: val_loss did not improve from 0.00190
# Epoch 84/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0607 - val_accuracy: 0.9824
#
# Epoch 00084: val_loss did not improve from 0.00190
# Epoch 85/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.3297 - val_accuracy: 0.9418
#
# Epoch 00085: val_loss did not improve from 0.00190
# Epoch 86/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0168 - accuracy: 0.9954 - val_loss: 0.0084 - val_accuracy: 0.9977
#
# Epoch 00086: val_loss did not improve from 0.00190
# Epoch 87/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.0890 - val_accuracy: 0.9855
#
# Epoch 00087: val_loss did not improve from 0.00190
# Epoch 88/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0204 - accuracy: 0.9949 - val_loss: 0.3856 - val_accuracy: 0.9324
#
# Epoch 00088: val_loss did not improve from 0.00190
# Epoch 89/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 0.0083 - val_accuracy: 0.9965
#
# Epoch 00089: val_loss did not improve from 0.00190
# Epoch 90/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0117 - accuracy: 0.9958 - val_loss: 0.2718 - val_accuracy: 0.9383
#
# Epoch 00090: val_loss did not improve from 0.00190
# Epoch 91/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.0082 - val_accuracy: 0.9961
#
# Epoch 00091: val_loss did not improve from 0.00190
# Epoch 92/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0078 - val_accuracy: 0.9965
#
# Epoch 00092: val_loss did not improve from 0.00190
# Epoch 93/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0088 - accuracy: 0.9957 - val_loss: 0.0164 - val_accuracy: 0.9941
#
# Epoch 00093: val_loss did not improve from 0.00190
# Epoch 94/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0224 - val_accuracy: 0.9941
#
# Epoch 00094: val_loss did not improve from 0.00190
# Epoch 95/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0085 - val_accuracy: 0.9969
#
# Epoch 00095: val_loss did not improve from 0.00190
# Epoch 96/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.1909 - val_accuracy: 0.9668
#
# Epoch 00096: val_loss did not improve from 0.00190
# Epoch 97/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0150 - accuracy: 0.9957 - val_loss: 0.0035 - val_accuracy: 0.9980
#
# Epoch 00097: val_loss did not improve from 0.00190
# Epoch 98/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.3258 - val_accuracy: 0.9488
#
# Epoch 00098: val_loss did not improve from 0.00190
# Epoch 99/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0092 - accuracy: 0.9962 - val_loss: 0.0235 - val_accuracy: 0.9961
#
# Epoch 00099: val_loss did not improve from 0.00190
# Epoch 100/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00100: val_loss did not improve from 0.00190
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.9980
# Val Score:  [0.003884516190737486, 0.998046875]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 6s 14ms/step - loss: 0.4296 - accuracy: 0.8621 - val_loss: 0.5928 - val_accuracy: 0.7492
#
# Epoch 00001: val_loss did not improve from 0.00190
# Epoch 2/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1721 - accuracy: 0.9411 - val_loss: 0.6837 - val_accuracy: 0.7816
#
# Epoch 00002: val_loss did not improve from 0.00190
# Epoch 3/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.1011 - accuracy: 0.9635 - val_loss: 0.1502 - val_accuracy: 0.9375
#
# Epoch 00003: val_loss did not improve from 0.00190
# Epoch 4/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0702 - accuracy: 0.9748 - val_loss: 0.0272 - val_accuracy: 0.9871
#
# Epoch 00004: val_loss did not improve from 0.00190
# Epoch 5/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0583 - accuracy: 0.9778 - val_loss: 0.8906 - val_accuracy: 0.8238
#
# Epoch 00005: val_loss did not improve from 0.00190
# Epoch 6/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0607 - accuracy: 0.9788 - val_loss: 0.4105 - val_accuracy: 0.8977
#
# Epoch 00006: val_loss did not improve from 0.00190
# Epoch 7/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.0074 - val_accuracy: 0.9977
#
# Epoch 00007: val_loss did not improve from 0.00190
# Epoch 8/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0387 - accuracy: 0.9873 - val_loss: 0.0499 - val_accuracy: 0.9840
#
# Epoch 00008: val_loss did not improve from 0.00190
# Epoch 9/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0479 - accuracy: 0.9833 - val_loss: 0.2214 - val_accuracy: 0.9391
#
# Epoch 00009: val_loss did not improve from 0.00190
# Epoch 10/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0346 - accuracy: 0.9889 - val_loss: 0.2556 - val_accuracy: 0.9215
#
# Epoch 00010: val_loss did not improve from 0.00190
# Epoch 11/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0291 - accuracy: 0.9901 - val_loss: 0.5387 - val_accuracy: 0.8879
#
# Epoch 00011: val_loss did not improve from 0.00190
# Epoch 12/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 0.0199 - val_accuracy: 0.9941
#
# Epoch 00012: val_loss did not improve from 0.00190
# Epoch 13/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0305 - accuracy: 0.9889 - val_loss: 0.2153 - val_accuracy: 0.9324
#
# Epoch 00013: val_loss did not improve from 0.00190
# Epoch 14/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0384 - accuracy: 0.9885 - val_loss: 0.4384 - val_accuracy: 0.8941
#
# Epoch 00014: val_loss did not improve from 0.00190
# Epoch 15/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0274 - accuracy: 0.9919 - val_loss: 0.0903 - val_accuracy: 0.9715
#
# Epoch 00015: val_loss did not improve from 0.00190
# Epoch 16/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0328 - accuracy: 0.9876 - val_loss: 0.1166 - val_accuracy: 0.9664
#
# Epoch 00016: val_loss did not improve from 0.00190
# Epoch 17/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0289 - accuracy: 0.9907 - val_loss: 0.0364 - val_accuracy: 0.9848
#
# Epoch 00017: val_loss did not improve from 0.00190
# Epoch 18/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0231 - accuracy: 0.9919 - val_loss: 0.2488 - val_accuracy: 0.9309
#
# Epoch 00018: val_loss did not improve from 0.00190
# Epoch 19/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0265 - accuracy: 0.9921 - val_loss: 0.2500 - val_accuracy: 0.9398
#
# Epoch 00019: val_loss did not improve from 0.00190
# Epoch 20/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0265 - accuracy: 0.9916 - val_loss: 0.0034 - val_accuracy: 0.9980
#
# Epoch 00020: val_loss did not improve from 0.00190
# Epoch 21/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0128 - val_accuracy: 0.9953
#
# Epoch 00021: val_loss did not improve from 0.00190
# Epoch 22/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.0151 - val_accuracy: 0.9965
#
# Epoch 00022: val_loss did not improve from 0.00190
# Epoch 23/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0261 - accuracy: 0.9910 - val_loss: 1.9206 - val_accuracy: 0.7480
#
# Epoch 00023: val_loss did not improve from 0.00190
# Epoch 24/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0293 - accuracy: 0.9926 - val_loss: 1.2026 - val_accuracy: 0.7836
#
# Epoch 00024: val_loss did not improve from 0.00190
# Epoch 25/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.0167 - val_accuracy: 0.9949
#
# Epoch 00025: val_loss did not improve from 0.00190
# Epoch 26/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0231 - accuracy: 0.9933 - val_loss: 0.1218 - val_accuracy: 0.9617
#
# Epoch 00026: val_loss did not improve from 0.00190
# Epoch 27/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0237 - accuracy: 0.9920 - val_loss: 2.1880 - val_accuracy: 0.7937
#
# Epoch 00027: val_loss did not improve from 0.00190
# Epoch 28/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0230 - accuracy: 0.9921 - val_loss: 3.5604 - val_accuracy: 0.7043
#
# Epoch 00028: val_loss did not improve from 0.00190
# Epoch 29/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0219 - accuracy: 0.9922 - val_loss: 0.0182 - val_accuracy: 0.9926
#
# Epoch 00029: val_loss did not improve from 0.00190
# Epoch 30/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0126 - accuracy: 0.9954 - val_loss: 0.0075 - val_accuracy: 0.9984
#
# Epoch 00030: val_loss did not improve from 0.00190
# Epoch 31/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0239 - accuracy: 0.9935 - val_loss: 1.7662 - val_accuracy: 0.8234
#
# Epoch 00031: val_loss did not improve from 0.00190
# Epoch 32/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0195 - accuracy: 0.9932 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00032: val_loss did not improve from 0.00190
# Epoch 33/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0210 - accuracy: 0.9926 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00033: val_loss did not improve from 0.00190
# Epoch 34/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.0084 - val_accuracy: 0.9980
#
# Epoch 00034: val_loss did not improve from 0.00190
# Epoch 35/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00035: val_loss did not improve from 0.00190
# Epoch 36/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0168 - accuracy: 0.9959 - val_loss: 0.0587 - val_accuracy: 0.9859
#
# Epoch 00036: val_loss did not improve from 0.00190
# Epoch 37/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.5395 - val_accuracy: 0.8699
#
# Epoch 00037: val_loss did not improve from 0.00190
# Epoch 38/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0108 - accuracy: 0.9959 - val_loss: 0.0842 - val_accuracy: 0.9750
#
# Epoch 00038: val_loss did not improve from 0.00190
# Epoch 39/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.0057 - val_accuracy: 0.9984
#
# Epoch 00039: val_loss did not improve from 0.00190
# Epoch 40/100
# ...
# Epoch 21/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0293 - accuracy: 0.9902 - val_loss: 0.0370 - val_accuracy: 0.9871
#
# Epoch 00021: val_loss did not improve from 0.00190
# Epoch 22/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.0372 - val_accuracy: 0.9879
#
# Epoch 00022: val_loss did not improve from 0.00190
# Epoch 23/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.0745 - val_accuracy: 0.9727
#
# Epoch 00023: val_loss did not improve from 0.00190
# Epoch 24/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0251 - accuracy: 0.9935 - val_loss: 0.8917 - val_accuracy: 0.8254
#
# Epoch 00024: val_loss did not improve from 0.00190
# Epoch 25/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0307 - accuracy: 0.9908 - val_loss: 0.0237 - val_accuracy: 0.9922
#
# Epoch 00025: val_loss did not improve from 0.00190
# Epoch 26/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.1519 - val_accuracy: 0.9590
#
# Epoch 00026: val_loss did not improve from 0.00190
# Epoch 27/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00027: val_loss did not improve from 0.00190
# Epoch 28/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0198 - val_accuracy: 0.9934
#
# Epoch 00028: val_loss did not improve from 0.00190
# Epoch 29/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.0218 - val_accuracy: 0.9941
#
# Epoch 00029: val_loss did not improve from 0.00190
# Epoch 30/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00030: val_loss did not improve from 0.00190
# Epoch 31/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0167 - accuracy: 0.9938 - val_loss: 0.0138 - val_accuracy: 0.9949
#
# Epoch 00031: val_loss did not improve from 0.00190
# Epoch 32/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0192 - accuracy: 0.9946 - val_loss: 0.1344 - val_accuracy: 0.9535
#
# Epoch 00032: val_loss did not improve from 0.00190
# Epoch 33/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.0721 - val_accuracy: 0.9812
#
# Epoch 00033: val_loss did not improve from 0.00190
# Epoch 34/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0159 - accuracy: 0.9939 - val_loss: 0.0606 - val_accuracy: 0.9848
#
# Epoch 00034: val_loss did not improve from 0.00190
# Epoch 35/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0237 - accuracy: 0.9933 - val_loss: 0.0585 - val_accuracy: 0.9871
#
# Epoch 00035: val_loss did not improve from 0.00190
# Epoch 36/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 0.1009 - val_accuracy: 0.9727
#
# Epoch 00036: val_loss did not improve from 0.00190
# Epoch 37/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0278 - accuracy: 0.9911 - val_loss: 0.0279 - val_accuracy: 0.9930
#
# Epoch 00037: val_loss did not improve from 0.00190
# Epoch 38/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0159 - accuracy: 0.9940 - val_loss: 0.8407 - val_accuracy: 0.8402
#
# Epoch 00038: val_loss did not improve from 0.00190
# Epoch 39/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.0082 - val_accuracy: 0.9969
#
# Epoch 00039: val_loss did not improve from 0.00190
# Epoch 40/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0178 - accuracy: 0.9943 - val_loss: 0.0342 - val_accuracy: 0.9914
#
# Epoch 00040: val_loss did not improve from 0.00190
# Epoch 41/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0113 - val_accuracy: 0.9965
#
# Epoch 00041: val_loss did not improve from 0.00190
# Epoch 42/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 0.0082 - val_accuracy: 0.9977
#
# Epoch 00042: val_loss did not improve from 0.00190
# Epoch 43/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 0.0027 - val_accuracy: 0.9984
#
# Epoch 00043: val_loss did not improve from 0.00190
# Epoch 44/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0066 - accuracy: 0.9970 - val_loss: 0.0052 - val_accuracy: 0.9980
#
# Epoch 00044: val_loss did not improve from 0.00190
# Epoch 45/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0173 - accuracy: 0.9954 - val_loss: 0.1383 - val_accuracy: 0.9727
#
# Epoch 00045: val_loss did not improve from 0.00190
# Epoch 46/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0315 - accuracy: 0.9904 - val_loss: 0.0646 - val_accuracy: 0.9770
#
# Epoch 00046: val_loss did not improve from 0.00190
# Epoch 47/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0185 - accuracy: 0.9941 - val_loss: 2.1679 - val_accuracy: 0.7059
#
# Epoch 00047: val_loss did not improve from 0.00190
# Epoch 48/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.0159 - val_accuracy: 0.9953
#
# Epoch 00048: val_loss did not improve from 0.00190
# Epoch 49/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0032 - val_accuracy: 0.9984
#
# Epoch 00049: val_loss did not improve from 0.00190
# Epoch 50/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.2392 - val_accuracy: 0.9379
#
# Epoch 00050: val_loss did not improve from 0.00190
# Epoch 51/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.3328 - val_accuracy: 0.9176
#
# Epoch 00051: val_loss did not improve from 0.00190
# Epoch 52/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.0144 - val_accuracy: 0.9949
#
# Epoch 00052: val_loss did not improve from 0.00190
# Epoch 53/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.0042 - val_accuracy: 0.9980
#
# Epoch 00053: val_loss did not improve from 0.00190
# Epoch 54/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 2.7936 - val_accuracy: 0.7367
#
# Epoch 00054: val_loss did not improve from 0.00190
# Epoch 55/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.2229 - val_accuracy: 0.9430
#
# Epoch 00055: val_loss did not improve from 0.00190
# Epoch 56/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0045 - val_accuracy: 0.9980
#
# Epoch 00056: val_loss did not improve from 0.00190
# Epoch 57/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0036 - val_accuracy: 0.9980
#
# Epoch 00057: val_loss did not improve from 0.00190
# Epoch 58/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00058: val_loss did not improve from 0.00190
# Epoch 59/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.1270 - val_accuracy: 0.9680
#
# Epoch 00059: val_loss did not improve from 0.00190
# Epoch 60/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.0150 - val_accuracy: 0.9937
#
# Epoch 00060: val_loss did not improve from 0.00190
# Epoch 61/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 0.0117 - val_accuracy: 0.9969
#
# Epoch 00061: val_loss did not improve from 0.00190
# Epoch 62/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0135 - val_accuracy: 0.9969
#
# Epoch 00062: val_loss did not improve from 0.00190
# Epoch 63/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00063: val_loss did not improve from 0.00190
# Epoch 64/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0314 - val_accuracy: 0.9937
#
# Epoch 00064: val_loss did not improve from 0.00190
# Epoch 65/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.0098 - val_accuracy: 0.9969
#
# Epoch 00065: val_loss did not improve from 0.00190
# Epoch 66/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0061 - val_accuracy: 0.9973
#
# Epoch 00066: val_loss did not improve from 0.00190
# Epoch 67/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0139 - accuracy: 0.9949 - val_loss: 0.0158 - val_accuracy: 0.9949
#
# Epoch 00067: val_loss did not improve from 0.00190
# Epoch 68/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.0076 - val_accuracy: 0.9961
#
# Epoch 00068: val_loss did not improve from 0.00190
# Epoch 69/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.0298 - val_accuracy: 0.9906
#
# Epoch 00069: val_loss did not improve from 0.00190
# Epoch 70/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0308 - val_accuracy: 0.9895
#
# Epoch 00070: val_loss did not improve from 0.00190
# Epoch 71/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0078 - accuracy: 0.9970 - val_loss: 0.0030 - val_accuracy: 0.9980
#
# Epoch 00071: val_loss did not improve from 0.00190
# Epoch 72/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0183 - val_accuracy: 0.9945
#
# Epoch 00072: val_loss did not improve from 0.00190
# Epoch 73/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0135 - accuracy: 0.9964 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00073: val_loss did not improve from 0.00190
# Epoch 74/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0246 - val_accuracy: 0.9949
#
# Epoch 00074: val_loss did not improve from 0.00190
# Epoch 75/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0097 - accuracy: 0.9971 - val_loss: 0.0056 - val_accuracy: 0.9980
#
# Epoch 00075: val_loss did not improve from 0.00190
# Epoch 76/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0093 - accuracy: 0.9962 - val_loss: 0.0702 - val_accuracy: 0.9887
#
# Epoch 00076: val_loss did not improve from 0.00190
# Epoch 77/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.0059 - val_accuracy: 0.9977
#
# Epoch 00077: val_loss did not improve from 0.00190
# Epoch 78/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0041 - val_accuracy: 0.9980
#
# Epoch 00078: val_loss did not improve from 0.00190
# Epoch 79/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0228 - accuracy: 0.9945 - val_loss: 0.0047 - val_accuracy: 0.9973
#
# Epoch 00079: val_loss did not improve from 0.00190
# Epoch 80/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 0.0149 - val_accuracy: 0.9973
#
# Epoch 00080: val_loss did not improve from 0.00190
# Epoch 81/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0124 - val_accuracy: 0.9961
#
# Epoch 00081: val_loss did not improve from 0.00190
# Epoch 82/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0076 - accuracy: 0.9969 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00082: val_loss did not improve from 0.00190
# Epoch 83/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0037 - val_accuracy: 0.9984
#
# Epoch 00083: val_loss did not improve from 0.00190
# Epoch 84/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0064 - val_accuracy: 0.9969
#
# Epoch 00084: val_loss did not improve from 0.00190
# Epoch 85/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0213 - val_accuracy: 0.9949
#
# Epoch 00085: val_loss did not improve from 0.00190
# Epoch 86/100
# 320/320 [==============================] - 4s 13ms/step - loss: 0.0132 - accuracy: 0.9962 - val_loss: 0.0021 - val_accuracy: 0.9984
#
# Epoch 00086: val_loss did not improve from 0.00190
# Epoch 87/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.0112 - val_accuracy: 0.9957
#
# Epoch 00087: val_loss did not improve from 0.00190
# Epoch 88/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0124 - val_accuracy: 0.9957
#
# Epoch 00088: val_loss did not improve from 0.00190
# Epoch 89/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00089: val_loss did not improve from 0.00190
# Epoch 90/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.0168 - val_accuracy: 0.9957
#
# Epoch 00090: val_loss did not improve from 0.00190
# Epoch 91/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0582 - val_accuracy: 0.9852
#
# Epoch 00091: val_loss did not improve from 0.00190
# Epoch 92/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0090 - accuracy: 0.9965 - val_loss: 0.0789 - val_accuracy: 0.9754
#
# Epoch 00092: val_loss did not improve from 0.00190
# Epoch 93/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0154 - accuracy: 0.9958 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00093: val_loss did not improve from 0.00190
# Epoch 94/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0157 - accuracy: 0.9960 - val_loss: 0.0100 - val_accuracy: 0.9965
#
# Epoch 00094: val_loss did not improve from 0.00190
# Epoch 95/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.0097 - val_accuracy: 0.9969
#
# Epoch 00095: val_loss did not improve from 0.00190
# Epoch 96/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0080 - accuracy: 0.9963 - val_loss: 0.0912 - val_accuracy: 0.9680
#
# Epoch 00096: val_loss did not improve from 0.00190
# Epoch 97/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0420 - val_accuracy: 0.9895
#
# Epoch 00097: val_loss did not improve from 0.00190
# Epoch 98/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0086 - accuracy: 0.9961 - val_loss: 0.0027 - val_accuracy: 0.9980
#
# Epoch 00098: val_loss did not improve from 0.00190
# Epoch 99/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00099: val_loss did not improve from 0.00190
# Epoch 100/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.0106 - val_accuracy: 0.9961
#
# Epoch 00100: val_loss did not improve from 0.00190
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9961
# Val Score:  [0.010563617572188377, 0.99609375]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
