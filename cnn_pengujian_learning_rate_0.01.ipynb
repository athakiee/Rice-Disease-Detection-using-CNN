# %% [markdown]
# # RICE LEAF DISEASE DETECTION USING CONVOLUTIONAL NEURAL NETWORK
# **LEARNING RATE TEST 0.01 -- USING ADAM AND BEST RESULT OF HIDDEN LAYER(4)**

# %% [markdown]
# **IMPORT LIBRARY CNN**

# %%
import numpy as np
import pickle
import cv2
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import seaborn as sn

from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.models import load_model

# %% [markdown]
# **INITIAL STATE**

# %%
EPOCHS = 100
INIT_LR = 1e-2
BS = 32
default_image_size = tuple((64, 64))
image_size = 0
directory_root = "../input/riceleaf"
width=64
height=64
depth=3
n_folds= 5

# %% [markdown]
# **LOADING DATASET**

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Health ...
# [INFO] Processing Brown spot ...
# [INFO] Processing Bacterial leaf blight ...
# [INFO] Processing Leaf smut ...
# [INFO] Image loading completed

# %%
image_size = len(image_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(label_binarizer.classes_)
# Out:
# ['Bacterial leaf blight' 'Brown spot' 'Health' 'Leaf smut']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 225.0

# %% [markdown]
# **SPLITTING DATASET**

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **CREATING MODEL CNN**

# %%
def create_model():
    
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1
    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    
#Layer 1
    model.add(Conv2D(16, (3, 3), padding="same",input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

#Layer 2
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 3
    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

#Layer 4
    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

#Layer 5
    #model.add(Conv2D(256, (3, 3), padding="same"))
    #model.add(Activation("relu"))
    #model.add(BatchNormalization(axis=chanDim))
    #model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.25))

#Classification Layer
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation("softmax"))

    return model

# %%
model = create_model()
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_36 (Activation)   (None, 64, 64, 16)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 64, 64, 16)        64
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 21, 21, 16)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 21, 21, 16)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 21, 21, 32)        4640
# _________________________________________________________________
# activation_37 (Activation)   (None, 21, 21, 32)        0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 21, 21, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# activation_38 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 10, 10, 128)       73856
# _________________________________________________________________
# activation_39 (Activation)   (None, 10, 10, 128)       0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 10, 10, 128)       512
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              13108224
# _________________________________________________________________
# activation_40 (Activation)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 4100
# _________________________________________________________________
# activation_41 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 13,214,820
# Trainable params: 13,212,292
# Non-trainable params: 2,528
# _________________________________________________________________

# %% [markdown]
# **INITIATE OPTIMIZER**

# %%
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
# distribution
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
# train the network
print("[INFO] training network...")
# Out:
# [INFO] training network...

# %% [markdown]
# **CHECKPOINT CREATING MODEL FOR CROSS VALIDATION**

# %%
filepath="model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size):
    model = create_model()
    model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    results = model.fit(t_x, t_y,validation_data=(val_x, val_y), epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)  
    print("Val Score: ", model.evaluate(val_x, val_y))
    
    return results

# %% [markdown]
# **TRAINING DATA WITH CROSS VALIDATION**

# %%
#save the model history in a list after fitting so that we can plot later
model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.2, random_state=0)
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs=EPOCHS, batch_size=BS))
print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# Epoch 1/100
# 320/320 [==============================] - 5s 12ms/step - loss: 0.7113 - accuracy: 0.8080 - val_loss: 6.2787 - val_accuracy: 0.4770
#
# Epoch 00001: val_loss improved from inf to 6.27868, saving model to model.h5
# Epoch 2/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.4794 - accuracy: 0.8668 - val_loss: 0.2361 - val_accuracy: 0.9160
#
# Epoch 00002: val_loss improved from 6.27868 to 0.23609, saving model to model.h5
# Epoch 3/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.2772 - accuracy: 0.9173 - val_loss: 0.1373 - val_accuracy: 0.9539
#
# Epoch 00003: val_loss improved from 0.23609 to 0.13730, saving model to model.h5
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2179 - accuracy: 0.9377 - val_loss: 0.7647 - val_accuracy: 0.8168
#
# Epoch 00004: val_loss did not improve from 0.13730
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1563 - accuracy: 0.9502 - val_loss: 1.9041 - val_accuracy: 0.6473
#
# Epoch 00005: val_loss did not improve from 0.13730
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.3932 - accuracy: 0.8689 - val_loss: 0.3316 - val_accuracy: 0.8664
#
# Epoch 00006: val_loss did not improve from 0.13730
# Epoch 7/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.2407 - accuracy: 0.9163 - val_loss: 0.2980 - val_accuracy: 0.9086
#
# Epoch 00007: val_loss did not improve from 0.13730
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1716 - accuracy: 0.9382 - val_loss: 0.1511 - val_accuracy: 0.9402
#
# Epoch 00008: val_loss did not improve from 0.13730
# Epoch 9/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1131 - accuracy: 0.9587 - val_loss: 0.2347 - val_accuracy: 0.9207
#
# Epoch 00009: val_loss did not improve from 0.13730
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0938 - accuracy: 0.9690 - val_loss: 0.1574 - val_accuracy: 0.9500
#
# Epoch 00010: val_loss did not improve from 0.13730
# Epoch 11/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0857 - accuracy: 0.9706 - val_loss: 0.1502 - val_accuracy: 0.9602
#
# Epoch 00011: val_loss did not improve from 0.13730
# Epoch 12/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0763 - accuracy: 0.9750 - val_loss: 0.4123 - val_accuracy: 0.8777
#
# Epoch 00012: val_loss did not improve from 0.13730
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0768 - accuracy: 0.9726 - val_loss: 0.2188 - val_accuracy: 0.9219
#
# Epoch 00013: val_loss did not improve from 0.13730
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0720 - accuracy: 0.9752 - val_loss: 0.0545 - val_accuracy: 0.9812
#
# Epoch 00014: val_loss improved from 0.13730 to 0.05453, saving model to model.h5
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0672 - accuracy: 0.9773 - val_loss: 0.0359 - val_accuracy: 0.9887
#
# Epoch 00015: val_loss improved from 0.05453 to 0.03594, saving model to model.h5
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0824 - accuracy: 0.9734 - val_loss: 0.5861 - val_accuracy: 0.8711
#
# Epoch 00016: val_loss did not improve from 0.03594
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0653 - accuracy: 0.9787 - val_loss: 0.0528 - val_accuracy: 0.9828
#
# Epoch 00017: val_loss did not improve from 0.03594
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0580 - accuracy: 0.9815 - val_loss: 0.0457 - val_accuracy: 0.9863
#
# Epoch 00018: val_loss did not improve from 0.03594
# Epoch 19/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0504 - accuracy: 0.9827 - val_loss: 0.0293 - val_accuracy: 0.9875
#
# Epoch 00019: val_loss improved from 0.03594 to 0.02931, saving model to model.h5
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0486 - accuracy: 0.9829 - val_loss: 0.1113 - val_accuracy: 0.9684
#
# Epoch 00020: val_loss did not improve from 0.02931
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0490 - accuracy: 0.9847 - val_loss: 0.1189 - val_accuracy: 0.9801
#
# Epoch 00021: val_loss did not improve from 0.02931
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0376 - accuracy: 0.9881 - val_loss: 0.0178 - val_accuracy: 0.9953
#
# Epoch 00022: val_loss improved from 0.02931 to 0.01781, saving model to model.h5
# Epoch 23/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0389 - accuracy: 0.9885 - val_loss: 0.0167 - val_accuracy: 0.9941
#
# Epoch 00023: val_loss improved from 0.01781 to 0.01672, saving model to model.h5
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0354 - accuracy: 0.9894 - val_loss: 0.0483 - val_accuracy: 0.9941
#
# Epoch 00024: val_loss did not improve from 0.01672
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.2491 - val_accuracy: 0.9602
#
# Epoch 00025: val_loss did not improve from 0.01672
# Epoch 26/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 5.1299 - val_accuracy: 0.9504
#
# Epoch 00026: val_loss did not improve from 0.01672
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.1198 - val_accuracy: 0.9676
#
# Epoch 00027: val_loss did not improve from 0.01672
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0251 - accuracy: 0.9925 - val_loss: 0.0171 - val_accuracy: 0.9941
#
# Epoch 00028: val_loss did not improve from 0.01672
# Epoch 29/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0331 - accuracy: 0.9904 - val_loss: 0.0313 - val_accuracy: 0.9898
#
# Epoch 00029: val_loss did not improve from 0.01672
# Epoch 30/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0754 - accuracy: 0.9841 - val_loss: 0.1337 - val_accuracy: 0.9871
#
# Epoch 00030: val_loss did not improve from 0.01672
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0408 - accuracy: 0.9876 - val_loss: 0.0231 - val_accuracy: 0.9926
#
# Epoch 00031: val_loss did not improve from 0.01672
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0223 - accuracy: 0.9933 - val_loss: 0.0695 - val_accuracy: 0.9891
#
# Epoch 00032: val_loss did not improve from 0.01672
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0222 - accuracy: 0.9930 - val_loss: 0.0212 - val_accuracy: 0.9937
#
# Epoch 00033: val_loss did not improve from 0.01672
# Epoch 34/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0242 - accuracy: 0.9923 - val_loss: 1.7248 - val_accuracy: 0.8379
#
# Epoch 00034: val_loss did not improve from 0.01672
# Epoch 35/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0242 - accuracy: 0.9913 - val_loss: 2.9676 - val_accuracy: 0.9875
#
# Epoch 00035: val_loss did not improve from 0.01672
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0370 - accuracy: 0.9888 - val_loss: 0.0454 - val_accuracy: 0.9949
#
# Epoch 00036: val_loss did not improve from 0.01672
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.1824 - val_accuracy: 0.9945
#
# Epoch 00037: val_loss did not improve from 0.01672
# Epoch 38/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0217 - accuracy: 0.9929 - val_loss: 0.7990 - val_accuracy: 0.8961
#
# Epoch 00038: val_loss did not improve from 0.01672
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0234 - accuracy: 0.9917 - val_loss: 0.0642 - val_accuracy: 0.9910
#
# Epoch 00039: val_loss did not improve from 0.01672
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 0.0134 - val_accuracy: 0.9949
#
# Epoch 00040: val_loss improved from 0.01672 to 0.01337, saving model to model.h5
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0171 - accuracy: 0.9955 - val_loss: 0.0107 - val_accuracy: 0.9961
#
# Epoch 00041: val_loss improved from 0.01337 to 0.01066, saving model to model.h5
# Epoch 42/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0185 - accuracy: 0.9942 - val_loss: 0.0129 - val_accuracy: 0.9961
#
# Epoch 00042: val_loss did not improve from 0.01066
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0151 - accuracy: 0.9953 - val_loss: 1.3012 - val_accuracy: 0.9879
#
# Epoch 00043: val_loss did not improve from 0.01066
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.4484 - val_accuracy: 0.9664
#
# Epoch 00044: val_loss did not improve from 0.01066
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.0512 - val_accuracy: 0.9855
#
# Epoch 00045: val_loss did not improve from 0.01066
# Epoch 46/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.0127 - val_accuracy: 0.9945
#
# Epoch 00046: val_loss did not improve from 0.01066
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 2.7024 - val_accuracy: 0.9922
#
# Epoch 00047: val_loss did not improve from 0.01066
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0166 - accuracy: 0.9954 - val_loss: 13.9389 - val_accuracy: 0.9539
#
# Epoch 00048: val_loss did not improve from 0.01066
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0168 - accuracy: 0.9952 - val_loss: 0.0176 - val_accuracy: 0.9984
#
# Epoch 00049: val_loss did not improve from 0.01066
# Epoch 50/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.0091 - val_accuracy: 0.9973
#
# Epoch 00050: val_loss improved from 0.01066 to 0.00914, saving model to model.h5
# Epoch 51/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0163 - val_accuracy: 0.9957
#
# Epoch 00051: val_loss did not improve from 0.00914
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0102 - val_accuracy: 0.9977
#
# Epoch 00052: val_loss did not improve from 0.00914
# Epoch 53/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.0220 - val_accuracy: 0.9969
#
# Epoch 00053: val_loss did not improve from 0.00914
# Epoch 54/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0116 - val_accuracy: 0.9961
#
# Epoch 00054: val_loss did not improve from 0.00914
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 32.8684 - val_accuracy: 0.9949
#
# Epoch 00055: val_loss did not improve from 0.00914
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.0393 - val_accuracy: 0.9941
#
# Epoch 00056: val_loss did not improve from 0.00914
# Epoch 57/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0196 - accuracy: 0.9949 - val_loss: 0.0484 - val_accuracy: 0.9910
#
# Epoch 00057: val_loss did not improve from 0.00914
# Epoch 58/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 0.0581 - val_accuracy: 0.9910
#
# Epoch 00058: val_loss did not improve from 0.00914
# Epoch 59/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0161 - accuracy: 0.9957 - val_loss: 251.7955 - val_accuracy: 0.7145
#
# Epoch 00059: val_loss did not improve from 0.00914
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0186 - accuracy: 0.9942 - val_loss: 0.1203 - val_accuracy: 0.9965
#
# Epoch 00060: val_loss did not improve from 0.00914
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.0069 - val_accuracy: 0.9973
#
# Epoch 00061: val_loss improved from 0.00914 to 0.00686, saving model to model.h5
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0125 - val_accuracy: 0.9953
#
# Epoch 00062: val_loss did not improve from 0.00686
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 0.0745 - val_accuracy: 0.9820
#
# Epoch 00063: val_loss did not improve from 0.00686
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0166 - accuracy: 0.9937 - val_loss: 0.5552 - val_accuracy: 0.9570
#
# Epoch 00064: val_loss did not improve from 0.00686
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0115 - accuracy: 0.9959 - val_loss: 0.0139 - val_accuracy: 0.9949
#
# Epoch 00065: val_loss did not improve from 0.00686
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 1.9529 - val_accuracy: 0.9797
#
# Epoch 00066: val_loss did not improve from 0.00686
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 2.4499 - val_accuracy: 0.9227
#
# Epoch 00067: val_loss did not improve from 0.00686
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.0087 - val_accuracy: 0.9965
#
# Epoch 00068: val_loss did not improve from 0.00686
# Epoch 69/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.1749 - val_accuracy: 0.9906
#
# Epoch 00069: val_loss did not improve from 0.00686
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9958 - val_loss: 0.0098 - val_accuracy: 0.9961
#
# Epoch 00070: val_loss did not improve from 0.00686
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 0.0132 - val_accuracy: 0.9965
#
# Epoch 00071: val_loss did not improve from 0.00686
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0098 - accuracy: 0.9962 - val_loss: 0.0197 - val_accuracy: 0.9961
#
# Epoch 00072: val_loss did not improve from 0.00686
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.0040 - val_accuracy: 0.9984
#
# Epoch 00073: val_loss improved from 0.00686 to 0.00403, saving model to model.h5
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.0183 - val_accuracy: 0.9941
#
# Epoch 00074: val_loss did not improve from 0.00403
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0142 - accuracy: 0.9951 - val_loss: 0.0144 - val_accuracy: 0.9973
#
# Epoch 00075: val_loss did not improve from 0.00403
# Epoch 76/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.3089 - val_accuracy: 0.9359
#
# Epoch 00076: val_loss did not improve from 0.00403
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0145 - val_accuracy: 0.9969
#
# Epoch 00077: val_loss did not improve from 0.00403
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 9.3212 - val_accuracy: 0.9684
#
# Epoch 00078: val_loss did not improve from 0.00403
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.2583 - val_accuracy: 0.9418
#
# Epoch 00079: val_loss did not improve from 0.00403
# Epoch 80/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0057 - val_accuracy: 0.9984
#
# Epoch 00080: val_loss did not improve from 0.00403
# Epoch 81/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 30.3766 - val_accuracy: 0.8711
#
# Epoch 00081: val_loss did not improve from 0.00403
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0083 - accuracy: 0.9963 - val_loss: 0.0742 - val_accuracy: 0.9957
#
# Epoch 00082: val_loss did not improve from 0.00403
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 5.9734 - val_accuracy: 0.9547
#
# Epoch 00083: val_loss did not improve from 0.00403
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.0237 - val_accuracy: 0.9941
#
# Epoch 00084: val_loss did not improve from 0.00403
# Epoch 85/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.0116 - val_accuracy: 0.9961
#
# Epoch 00085: val_loss did not improve from 0.00403
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.2430 - val_accuracy: 0.9965
#
# Epoch 00086: val_loss did not improve from 0.00403
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0050 - val_accuracy: 0.9984
#
# Epoch 00087: val_loss did not improve from 0.00403
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0155 - accuracy: 0.9954 - val_loss: 20.8305 - val_accuracy: 0.9641
#
# Epoch 00088: val_loss did not improve from 0.00403
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00089: val_loss improved from 0.00403 to 0.00264, saving model to model.h5
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.0060 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00264
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.0194 - val_accuracy: 0.9937
#
# Epoch 00091: val_loss did not improve from 0.00264
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0133 - val_accuracy: 0.9957
#
# Epoch 00092: val_loss did not improve from 0.00264
# Epoch 93/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.1330 - val_accuracy: 0.9957
#
# Epoch 00093: val_loss did not improve from 0.00264
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.0177 - val_accuracy: 0.9961
#
# Epoch 00094: val_loss did not improve from 0.00264
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 0.0038 - val_accuracy: 0.9984
#
# Epoch 00095: val_loss did not improve from 0.00264
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9962 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00264
# Epoch 97/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0073 - accuracy: 0.9970 - val_loss: 0.2484 - val_accuracy: 0.9926
#
# Epoch 00097: val_loss did not improve from 0.00264
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.2508 - val_accuracy: 0.9961
#
# Epoch 00098: val_loss did not improve from 0.00264
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 0.0092 - val_accuracy: 0.9977
#
# Epoch 00099: val_loss did not improve from 0.00264
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00100: val_loss improved from 0.00264 to 0.00259, saving model to model.h5
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 0.9984
# Val Score:  [0.002592851873487234, 0.9984375238418579]
# Training on Fold:  2
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.7742 - accuracy: 0.8082 - val_loss: 1.0703 - val_accuracy: 0.6824
#
# Epoch 00001: val_loss did not improve from 0.00259
# Epoch 2/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.3376 - accuracy: 0.8891 - val_loss: 0.3841 - val_accuracy: 0.8762
#
# Epoch 00002: val_loss did not improve from 0.00259
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1752 - accuracy: 0.9367 - val_loss: 0.3973 - val_accuracy: 0.8613
#
# Epoch 00003: val_loss did not improve from 0.00259
# Epoch 4/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1154 - accuracy: 0.9586 - val_loss: 0.0618 - val_accuracy: 0.9801
#
# Epoch 00004: val_loss did not improve from 0.00259
# Epoch 5/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1099 - accuracy: 0.9636 - val_loss: 0.1505 - val_accuracy: 0.9488
#
# Epoch 00005: val_loss did not improve from 0.00259
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2474 - accuracy: 0.9247 - val_loss: 2.6693 - val_accuracy: 0.5945
#
# Epoch 00006: val_loss did not improve from 0.00259
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1965 - accuracy: 0.9391 - val_loss: 0.1288 - val_accuracy: 0.9625
#
# Epoch 00007: val_loss did not improve from 0.00259
# Epoch 8/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1100 - accuracy: 0.9675 - val_loss: 0.0483 - val_accuracy: 0.9883
#
# Epoch 00008: val_loss did not improve from 0.00259
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0777 - accuracy: 0.9748 - val_loss: 0.1878 - val_accuracy: 0.9477
#
# Epoch 00009: val_loss did not improve from 0.00259
# Epoch 10/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0736 - accuracy: 0.9753 - val_loss: 0.0170 - val_accuracy: 0.9941
#
# Epoch 00010: val_loss did not improve from 0.00259
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0539 - accuracy: 0.9822 - val_loss: 0.0289 - val_accuracy: 0.9906
#
# Epoch 00011: val_loss did not improve from 0.00259
# Epoch 12/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0558 - accuracy: 0.9814 - val_loss: 0.3802 - val_accuracy: 0.9078
#
# Epoch 00012: val_loss did not improve from 0.00259
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0516 - accuracy: 0.9825 - val_loss: 0.0262 - val_accuracy: 0.9918
#
# Epoch 00013: val_loss did not improve from 0.00259
# Epoch 14/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0471 - accuracy: 0.9854 - val_loss: 1.3295 - val_accuracy: 0.7273
#
# Epoch 00014: val_loss did not improve from 0.00259
# Epoch 15/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0521 - accuracy: 0.9838 - val_loss: 0.1426 - val_accuracy: 0.9520
#
# Epoch 00015: val_loss did not improve from 0.00259
# Epoch 16/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0429 - accuracy: 0.9868 - val_loss: 0.0192 - val_accuracy: 0.9930
#
# Epoch 00016: val_loss did not improve from 0.00259
# Epoch 17/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0634 - accuracy: 0.9806 - val_loss: 0.0227 - val_accuracy: 0.9906
#
# Epoch 00017: val_loss did not improve from 0.00259
# Epoch 18/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0444 - accuracy: 0.9871 - val_loss: 0.0126 - val_accuracy: 0.9957
#
# Epoch 00018: val_loss did not improve from 0.00259
# Epoch 19/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0361 - accuracy: 0.9889 - val_loss: 0.0079 - val_accuracy: 0.9973
#
# Epoch 00019: val_loss did not improve from 0.00259
# Epoch 20/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0389 - accuracy: 0.9889 - val_loss: 0.1198 - val_accuracy: 0.9766
#
# Epoch 00020: val_loss did not improve from 0.00259
# Epoch 21/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0427 - accuracy: 0.9864 - val_loss: 0.4684 - val_accuracy: 0.9109
#
# Epoch 00021: val_loss did not improve from 0.00259
# Epoch 22/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0247 - accuracy: 0.9910 - val_loss: 0.0091 - val_accuracy: 0.9953
#
# Epoch 00022: val_loss did not improve from 0.00259
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0321 - accuracy: 0.9898 - val_loss: 0.0505 - val_accuracy: 0.9812
#
# Epoch 00023: val_loss did not improve from 0.00259
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0300 - accuracy: 0.9902 - val_loss: 0.2258 - val_accuracy: 0.9496
#
# Epoch 00024: val_loss did not improve from 0.00259
# Epoch 25/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0325 - accuracy: 0.9909 - val_loss: 0.0928 - val_accuracy: 0.9816
#
# Epoch 00025: val_loss did not improve from 0.00259
# Epoch 26/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0794 - val_accuracy: 0.9762
#
# Epoch 00026: val_loss did not improve from 0.00259
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0204 - accuracy: 0.9939 - val_loss: 0.3355 - val_accuracy: 0.9297
#
# Epoch 00027: val_loss did not improve from 0.00259
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0452 - accuracy: 0.9877 - val_loss: 0.5807 - val_accuracy: 0.9000
#
# Epoch 00028: val_loss did not improve from 0.00259
# Epoch 29/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0314 - accuracy: 0.9920 - val_loss: 0.0379 - val_accuracy: 0.9902
#
# Epoch 00029: val_loss did not improve from 0.00259
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0335 - accuracy: 0.9896 - val_loss: 0.0186 - val_accuracy: 0.9941
#
# Epoch 00030: val_loss did not improve from 0.00259
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0066 - val_accuracy: 0.9973
#
# Epoch 00031: val_loss did not improve from 0.00259
# Epoch 32/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0303 - accuracy: 0.9920 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00032: val_loss did not improve from 0.00259
# Epoch 33/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.0073 - val_accuracy: 0.9980
#
# Epoch 00033: val_loss did not improve from 0.00259
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.0059 - val_accuracy: 0.9984
#
# Epoch 00034: val_loss did not improve from 0.00259
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0212 - accuracy: 0.9929 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00035: val_loss did not improve from 0.00259
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0259 - accuracy: 0.9936 - val_loss: 0.0260 - val_accuracy: 0.9945
#
# Epoch 00036: val_loss did not improve from 0.00259
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0201 - accuracy: 0.9942 - val_loss: 0.0717 - val_accuracy: 0.9824
#
# Epoch 00037: val_loss did not improve from 0.00259
# Epoch 38/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0393 - val_accuracy: 0.9937
#
# Epoch 00038: val_loss did not improve from 0.00259
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0199 - accuracy: 0.9942 - val_loss: 0.0381 - val_accuracy: 0.9918
#
# Epoch 00039: val_loss did not improve from 0.00259
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0209 - accuracy: 0.9948 - val_loss: 0.0251 - val_accuracy: 0.9953
#
# Epoch 00040: val_loss did not improve from 0.00259
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 0.1333 - val_accuracy: 0.9719
#
# Epoch 00041: val_loss did not improve from 0.00259
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0266 - accuracy: 0.9932 - val_loss: 0.0031 - val_accuracy: 0.9988
#
# Epoch 00042: val_loss did not improve from 0.00259
# Epoch 43/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.0260 - val_accuracy: 0.9926
#
# Epoch 00043: val_loss did not improve from 0.00259
# Epoch 44/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.0093 - val_accuracy: 0.9973
#
# Epoch 00044: val_loss did not improve from 0.00259
# Epoch 45/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0134 - accuracy: 0.9946 - val_loss: 0.0048 - val_accuracy: 0.9969
#
# Epoch 00045: val_loss did not improve from 0.00259
# Epoch 46/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0178 - accuracy: 0.9948 - val_loss: 0.0125 - val_accuracy: 0.9969
#
# Epoch 00046: val_loss did not improve from 0.00259
# Epoch 47/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0190 - accuracy: 0.9933 - val_loss: 0.0144 - val_accuracy: 0.9949
#
# Epoch 00047: val_loss did not improve from 0.00259
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.0508 - val_accuracy: 0.9887
#
# Epoch 00048: val_loss did not improve from 0.00259
# Epoch 49/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 0.0129 - val_accuracy: 0.9965
#
# Epoch 00049: val_loss did not improve from 0.00259
# Epoch 50/100
# 320/320 [==============================] - 4s 12ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.0136 - val_accuracy: 0.9957
#
# Epoch 00050: val_loss did not improve from 0.00259
# Epoch 51/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0075 - val_accuracy: 0.9980
#
# Epoch 00051: val_loss did not improve from 0.00259
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0135 - accuracy: 0.9953 - val_loss: 0.5551 - val_accuracy: 0.8922
#
# Epoch 00052: val_loss did not improve from 0.00259
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.0687 - val_accuracy: 0.9848
#
# Epoch 00053: val_loss did not improve from 0.00259
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.0198 - val_accuracy: 0.9926
#
# Epoch 00054: val_loss did not improve from 0.00259
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0099 - val_accuracy: 0.9961
#
# Epoch 00055: val_loss did not improve from 0.00259
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.0180 - val_accuracy: 0.9949
#
# Epoch 00056: val_loss did not improve from 0.00259
# Epoch 57/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0166 - accuracy: 0.9944 - val_loss: 0.0223 - val_accuracy: 0.9945
#
# Epoch 00057: val_loss did not improve from 0.00259
# Epoch 58/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.0084 - val_accuracy: 0.9977
#
# Epoch 00058: val_loss did not improve from 0.00259
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0134 - accuracy: 0.9954 - val_loss: 0.0169 - val_accuracy: 0.9945
#
# Epoch 00059: val_loss did not improve from 0.00259
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.0132 - val_accuracy: 0.9953
#
# Epoch 00060: val_loss did not improve from 0.00259
# Epoch 61/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0209 - accuracy: 0.9947 - val_loss: 0.0063 - val_accuracy: 0.9969
#
# Epoch 00061: val_loss did not improve from 0.00259
# Epoch 62/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00062: val_loss did not improve from 0.00259
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0090 - val_accuracy: 0.9969
#
# Epoch 00063: val_loss did not improve from 0.00259
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.9069 - val_accuracy: 0.8887
#
# Epoch 00064: val_loss did not improve from 0.00259
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0160 - accuracy: 0.9956 - val_loss: 0.0044 - val_accuracy: 0.9980
#
# Epoch 00065: val_loss did not improve from 0.00259
# Epoch 66/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0220 - val_accuracy: 0.9922
#
# Epoch 00066: val_loss did not improve from 0.00259
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0030 - val_accuracy: 0.9977
#
# Epoch 00067: val_loss did not improve from 0.00259
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0053 - val_accuracy: 0.9980
#
# Epoch 00068: val_loss did not improve from 0.00259
# Epoch 69/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 0.0059 - val_accuracy: 0.9977
#
# Epoch 00069: val_loss did not improve from 0.00259
# Epoch 70/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0096 - val_accuracy: 0.9973
#
# Epoch 00070: val_loss did not improve from 0.00259
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.0175 - val_accuracy: 0.9957
#
# Epoch 00071: val_loss did not improve from 0.00259
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 0.0302 - val_accuracy: 0.9910
#
# Epoch 00072: val_loss did not improve from 0.00259
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00073: val_loss improved from 0.00259 to 0.00219, saving model to model.h5
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.0048 - val_accuracy: 0.9973
#
# Epoch 00074: val_loss did not improve from 0.00219
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.0039 - val_accuracy: 0.9977
#
# Epoch 00075: val_loss did not improve from 0.00219
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.3231 - val_accuracy: 0.9258
#
# Epoch 00076: val_loss did not improve from 0.00219
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.0049 - val_accuracy: 0.9980
#
# Epoch 00077: val_loss did not improve from 0.00219
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.0020 - val_accuracy: 0.9988
#
# Epoch 00078: val_loss improved from 0.00219 to 0.00201, saving model to model.h5
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.0564 - val_accuracy: 0.9816
#
# Epoch 00079: val_loss did not improve from 0.00201
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9965 - val_loss: 0.0518 - val_accuracy: 0.9863
#
# Epoch 00080: val_loss did not improve from 0.00201
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00081: val_loss did not improve from 0.00201
# Epoch 82/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0196 - accuracy: 0.9946 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00082: val_loss did not improve from 0.00201
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0447 - val_accuracy: 0.9914
#
# Epoch 00083: val_loss did not improve from 0.00201
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0663 - val_accuracy: 0.9863
#
# Epoch 00084: val_loss did not improve from 0.00201
# Epoch 85/100
# 320/320 [==============================] - 4s 11ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0041 - val_accuracy: 0.9973
#
# Epoch 00085: val_loss did not improve from 0.00201
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00086: val_loss did not improve from 0.00201
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0545 - val_accuracy: 0.9859
#
# Epoch 00087: val_loss did not improve from 0.00201
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.0033 - val_accuracy: 0.9977
#
# Epoch 00088: val_loss did not improve from 0.00201
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.0160 - val_accuracy: 0.9965
#
# Epoch 00089: val_loss did not improve from 0.00201
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0088 - accuracy: 0.9962 - val_loss: 0.0071 - val_accuracy: 0.9980
#
# Epoch 00090: val_loss did not improve from 0.00201
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.0026 - val_accuracy: 0.9984
#
# Epoch 00091: val_loss did not improve from 0.00201
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.0039 - val_accuracy: 0.9980
#
# Epoch 00092: val_loss did not improve from 0.00201
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.0138 - val_accuracy: 0.9965
#
# Epoch 00093: val_loss did not improve from 0.00201
# Epoch 94/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0101 - val_accuracy: 0.9969
#
# Epoch 00094: val_loss did not improve from 0.00201
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0058 - val_accuracy: 0.9977
#
# Epoch 00095: val_loss did not improve from 0.00201
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0043 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00201
# Epoch 97/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0120 - val_accuracy: 0.9957
#
# Epoch 00097: val_loss did not improve from 0.00201
# Epoch 98/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0064 - val_accuracy: 0.9977
#
# Epoch 00098: val_loss did not improve from 0.00201
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0059 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00201
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 0.0138 - val_accuracy: 0.9969
#
# Epoch 00100: val_loss did not improve from 0.00201
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9969
# Val Score:  [0.0138125941157341, 0.996874988079071]
# Training on Fold:  3
# Epoch 1/100
# 320/320 [==============================] - 4s 10ms/step - loss: 0.5493 - accuracy: 0.8387 - val_loss: 1.8560 - val_accuracy: 0.6355
#
# Epoch 00001: val_loss did not improve from 0.00201
# Epoch 2/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.2023 - accuracy: 0.9305 - val_loss: 0.4180 - val_accuracy: 0.8465
#
# Epoch 00002: val_loss did not improve from 0.00201
# Epoch 3/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.1266 - accuracy: 0.9569 - val_loss: 0.1606 - val_accuracy: 0.9344
#
# Epoch 00003: val_loss did not improve from 0.00201
# Epoch 4/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.1116 - accuracy: 0.9628 - val_loss: 0.1143 - val_accuracy: 0.9586
#
# Epoch 00004: val_loss did not improve from 0.00201
# Epoch 5/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0864 - accuracy: 0.9706 - val_loss: 1.5280 - val_accuracy: 0.7605
#
# Epoch 00005: val_loss did not improve from 0.00201
# Epoch 6/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0645 - accuracy: 0.9786 - val_loss: 1.1880 - val_accuracy: 0.7707
#
# Epoch 00006: val_loss did not improve from 0.00201
# Epoch 7/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0716 - accuracy: 0.9756 - val_loss: 0.0266 - val_accuracy: 0.9914
#
# Epoch 00007: val_loss did not improve from 0.00201
# Epoch 8/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0558 - accuracy: 0.9818 - val_loss: 0.0148 - val_accuracy: 0.9941
#
# Epoch 00008: val_loss did not improve from 0.00201
# Epoch 9/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0657 - accuracy: 0.9812 - val_loss: 1.7211 - val_accuracy: 0.7566
#
# Epoch 00009: val_loss did not improve from 0.00201
# Epoch 10/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0361 - accuracy: 0.9884 - val_loss: 0.0202 - val_accuracy: 0.9937
#
# Epoch 00010: val_loss did not improve from 0.00201
# Epoch 11/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0457 - accuracy: 0.9844 - val_loss: 0.0205 - val_accuracy: 0.9937
#
# Epoch 00011: val_loss did not improve from 0.00201
# Epoch 12/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0325 - accuracy: 0.9901 - val_loss: 0.0464 - val_accuracy: 0.9836
#
# Epoch 00012: val_loss did not improve from 0.00201
# Epoch 13/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0501 - accuracy: 0.9861 - val_loss: 0.0750 - val_accuracy: 0.9773
#
# Epoch 00013: val_loss did not improve from 0.00201
# Epoch 14/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0374 - accuracy: 0.9867 - val_loss: 0.0243 - val_accuracy: 0.9937
#
# Epoch 00014: val_loss did not improve from 0.00201
# Epoch 15/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0298 - accuracy: 0.9895 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00015: val_loss did not improve from 0.00201
# Epoch 16/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0566 - accuracy: 0.9851 - val_loss: 0.3350 - val_accuracy: 0.9020
#
# Epoch 00016: val_loss did not improve from 0.00201
# Epoch 17/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0515 - accuracy: 0.9852 - val_loss: 0.0161 - val_accuracy: 0.9945
#
# Epoch 00017: val_loss did not improve from 0.00201
# Epoch 18/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0251 - accuracy: 0.9912 - val_loss: 0.0205 - val_accuracy: 0.9941
#
# Epoch 00018: val_loss did not improve from 0.00201
# Epoch 19/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0239 - accuracy: 0.9929 - val_loss: 0.0436 - val_accuracy: 0.9844
#
# Epoch 00019: val_loss did not improve from 0.00201
# Epoch 20/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 2.5937 - val_accuracy: 0.6066
#
# Epoch 00020: val_loss did not improve from 0.00201
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.5026 - val_accuracy: 0.8988
#
# Epoch 00021: val_loss did not improve from 0.00201
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0230 - accuracy: 0.9937 - val_loss: 0.0109 - val_accuracy: 0.9949
#
# Epoch 00022: val_loss did not improve from 0.00201
# Epoch 23/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0248 - accuracy: 0.9924 - val_loss: 0.2580 - val_accuracy: 0.9238
#
# Epoch 00023: val_loss did not improve from 0.00201
# Epoch 24/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0215 - accuracy: 0.9923 - val_loss: 0.1773 - val_accuracy: 0.9578
#
# Epoch 00024: val_loss did not improve from 0.00201
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0159 - accuracy: 0.9940 - val_loss: 2.6488 - val_accuracy: 0.7895
#
# Epoch 00025: val_loss did not improve from 0.00201
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0336 - accuracy: 0.9895 - val_loss: 0.0305 - val_accuracy: 0.9914
#
# Epoch 00026: val_loss did not improve from 0.00201
# Epoch 27/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0235 - accuracy: 0.9931 - val_loss: 0.0188 - val_accuracy: 0.9945
#
# Epoch 00027: val_loss did not improve from 0.00201
# Epoch 28/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0362 - accuracy: 0.9896 - val_loss: 0.0350 - val_accuracy: 0.9887
#
# Epoch 00028: val_loss did not improve from 0.00201
# Epoch 29/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0218 - accuracy: 0.9926 - val_loss: 0.1324 - val_accuracy: 0.9660
#
# Epoch 00029: val_loss did not improve from 0.00201
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0172 - accuracy: 0.9951 - val_loss: 1.0136 - val_accuracy: 0.8578
#
# Epoch 00030: val_loss did not improve from 0.00201
# Epoch 31/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0818 - val_accuracy: 0.9777
#
# Epoch 00031: val_loss did not improve from 0.00201
# Epoch 32/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0157 - accuracy: 0.9956 - val_loss: 0.0379 - val_accuracy: 0.9918
#
# Epoch 00032: val_loss did not improve from 0.00201
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0635 - val_accuracy: 0.9824
#
# Epoch 00033: val_loss did not improve from 0.00201
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0195 - accuracy: 0.9938 - val_loss: 0.0758 - val_accuracy: 0.9793
#
# Epoch 00034: val_loss did not improve from 0.00201
# Epoch 35/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0292 - accuracy: 0.9928 - val_loss: 0.0319 - val_accuracy: 0.9906
#
# Epoch 00035: val_loss did not improve from 0.00201
# Epoch 36/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0256 - accuracy: 0.9929 - val_loss: 0.7513 - val_accuracy: 0.8641
#
# Epoch 00036: val_loss did not improve from 0.00201
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.0407 - val_accuracy: 0.9863
#
# Epoch 00037: val_loss did not improve from 0.00201
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.0416 - val_accuracy: 0.9879
#
# Epoch 00038: val_loss did not improve from 0.00201
# Epoch 39/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.0806 - val_accuracy: 0.9703
#
# Epoch 00039: val_loss did not improve from 0.00201
# Epoch 40/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.1426 - val_accuracy: 0.9605
#
# Epoch 00040: val_loss did not improve from 0.00201
# Epoch 41/100
# ...
#
# Epoch 00020: val_loss did not improve from 0.00196
# Epoch 21/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0246 - accuracy: 0.9916 - val_loss: 0.0932 - val_accuracy: 0.9754
#
# Epoch 00021: val_loss did not improve from 0.00196
# Epoch 22/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0177 - accuracy: 0.9944 - val_loss: 0.0063 - val_accuracy: 0.9977
#
# Epoch 00022: val_loss did not improve from 0.00196
# Epoch 23/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0175 - accuracy: 0.9933 - val_loss: 0.0200 - val_accuracy: 0.9961
#
# Epoch 00023: val_loss did not improve from 0.00196
# Epoch 24/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.0604 - val_accuracy: 0.9820
#
# Epoch 00024: val_loss did not improve from 0.00196
# Epoch 25/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0164 - accuracy: 0.9940 - val_loss: 0.0550 - val_accuracy: 0.9836
#
# Epoch 00025: val_loss did not improve from 0.00196
# Epoch 26/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0244 - accuracy: 0.9916 - val_loss: 0.0837 - val_accuracy: 0.9738
#
# Epoch 00026: val_loss did not improve from 0.00196
# Epoch 27/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.0700 - val_accuracy: 0.9777
#
# Epoch 00027: val_loss did not improve from 0.00196
# Epoch 28/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.0073 - val_accuracy: 0.9977
#
# Epoch 00028: val_loss did not improve from 0.00196
# Epoch 29/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0224 - accuracy: 0.9933 - val_loss: 0.0104 - val_accuracy: 0.9973
#
# Epoch 00029: val_loss did not improve from 0.00196
# Epoch 30/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 0.0610 - val_accuracy: 0.9797
#
# Epoch 00030: val_loss did not improve from 0.00196
# Epoch 31/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 0.0241 - val_accuracy: 0.9926
#
# Epoch 00031: val_loss did not improve from 0.00196
# Epoch 32/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.0356 - val_accuracy: 0.9906
#
# Epoch 00032: val_loss did not improve from 0.00196
# Epoch 33/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0122 - accuracy: 0.9947 - val_loss: 0.1070 - val_accuracy: 0.9652
#
# Epoch 00033: val_loss did not improve from 0.00196
# Epoch 34/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0060 - accuracy: 0.9970 - val_loss: 0.4350 - val_accuracy: 0.9051
#
# Epoch 00034: val_loss did not improve from 0.00196
# Epoch 35/100
# 320/320 [==============================] - 3s 11ms/step - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.1058 - val_accuracy: 0.9746
#
# Epoch 00035: val_loss did not improve from 0.00196
# Epoch 36/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0171 - accuracy: 0.9943 - val_loss: 0.0539 - val_accuracy: 0.9871
#
# Epoch 00036: val_loss did not improve from 0.00196
# Epoch 37/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0238 - accuracy: 0.9934 - val_loss: 0.0091 - val_accuracy: 0.9961
#
# Epoch 00037: val_loss did not improve from 0.00196
# Epoch 38/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.0185 - val_accuracy: 0.9937
#
# Epoch 00038: val_loss did not improve from 0.00196
# Epoch 39/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0125 - accuracy: 0.9949 - val_loss: 0.0144 - val_accuracy: 0.9965
#
# Epoch 00039: val_loss did not improve from 0.00196
# Epoch 40/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.0067 - val_accuracy: 0.9977
#
# Epoch 00040: val_loss did not improve from 0.00196
# Epoch 41/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0078 - accuracy: 0.9970 - val_loss: 0.1715 - val_accuracy: 0.9488
#
# Epoch 00041: val_loss did not improve from 0.00196
# Epoch 42/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0022 - val_accuracy: 0.9988
#
# Epoch 00042: val_loss did not improve from 0.00196
# Epoch 43/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.5222 - val_accuracy: 0.9008
#
# Epoch 00043: val_loss did not improve from 0.00196
# Epoch 44/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.3350 - val_accuracy: 0.9203
#
# Epoch 00044: val_loss did not improve from 0.00196
# Epoch 45/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0152 - accuracy: 0.9949 - val_loss: 0.0643 - val_accuracy: 0.9789
#
# Epoch 00045: val_loss did not improve from 0.00196
# Epoch 46/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0072 - accuracy: 0.9969 - val_loss: 0.2906 - val_accuracy: 0.9305
#
# Epoch 00046: val_loss did not improve from 0.00196
# Epoch 47/100
# 320/320 [==============================] - 5s 15ms/step - loss: 0.0109 - accuracy: 0.9964 - val_loss: 0.0019 - val_accuracy: 0.9988
#
# Epoch 00047: val_loss improved from 0.00196 to 0.00195, saving model to model.h5
# Epoch 48/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0036 - val_accuracy: 0.9977
#
# Epoch 00048: val_loss did not improve from 0.00195
# Epoch 49/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0300 - val_accuracy: 0.9883
#
# Epoch 00049: val_loss did not improve from 0.00195
# Epoch 50/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0138 - accuracy: 0.9956 - val_loss: 0.0221 - val_accuracy: 0.9937
#
# Epoch 00050: val_loss did not improve from 0.00195
# Epoch 51/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0111 - val_accuracy: 0.9937
#
# Epoch 00051: val_loss did not improve from 0.00195
# Epoch 52/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0087 - val_accuracy: 0.9977
#
# Epoch 00052: val_loss did not improve from 0.00195
# Epoch 53/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00053: val_loss did not improve from 0.00195
# Epoch 54/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0677 - val_accuracy: 0.9848
#
# Epoch 00054: val_loss did not improve from 0.00195
# Epoch 55/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0108 - accuracy: 0.9959 - val_loss: 0.0146 - val_accuracy: 0.9953
#
# Epoch 00055: val_loss did not improve from 0.00195
# Epoch 56/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.0788 - val_accuracy: 0.9852
#
# Epoch 00056: val_loss did not improve from 0.00195
# Epoch 57/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0182 - val_accuracy: 0.9953
#
# Epoch 00057: val_loss did not improve from 0.00195
# Epoch 58/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0047 - val_accuracy: 0.9977
#
# Epoch 00058: val_loss did not improve from 0.00195
# Epoch 59/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 6.7266 - val_accuracy: 0.6125
#
# Epoch 00059: val_loss did not improve from 0.00195
# Epoch 60/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.2384 - val_accuracy: 0.9367
#
# Epoch 00060: val_loss did not improve from 0.00195
# Epoch 61/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0042 - accuracy: 0.9980 - val_loss: 0.0051 - val_accuracy: 0.9980
#
# Epoch 00061: val_loss did not improve from 0.00195
# Epoch 62/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 0.0026 - val_accuracy: 0.9988
#
# Epoch 00062: val_loss did not improve from 0.00195
# Epoch 63/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00063: val_loss did not improve from 0.00195
# Epoch 64/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.0022 - val_accuracy: 0.9984
#
# Epoch 00064: val_loss did not improve from 0.00195
# Epoch 65/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.5041 - val_accuracy: 0.8977
#
# Epoch 00065: val_loss did not improve from 0.00195
# Epoch 66/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0114 - accuracy: 0.9959 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00066: val_loss did not improve from 0.00195
# Epoch 67/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0958 - val_accuracy: 0.9676
#
# Epoch 00067: val_loss did not improve from 0.00195
# Epoch 68/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.4427 - val_accuracy: 0.9121
#
# Epoch 00068: val_loss did not improve from 0.00195
# Epoch 69/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.0350 - val_accuracy: 0.9898
#
# Epoch 00069: val_loss did not improve from 0.00195
# Epoch 70/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.1999 - val_accuracy: 0.9602
#
# Epoch 00070: val_loss did not improve from 0.00195
# Epoch 71/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0102 - accuracy: 0.9959 - val_loss: 0.0106 - val_accuracy: 0.9965
#
# Epoch 00071: val_loss did not improve from 0.00195
# Epoch 72/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0871 - val_accuracy: 0.9793
#
# Epoch 00072: val_loss did not improve from 0.00195
# Epoch 73/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0030 - val_accuracy: 0.9984
#
# Epoch 00073: val_loss did not improve from 0.00195
# Epoch 74/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 0.0214 - val_accuracy: 0.9926
#
# Epoch 00074: val_loss did not improve from 0.00195
# Epoch 75/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0033 - val_accuracy: 0.9980
#
# Epoch 00075: val_loss did not improve from 0.00195
# Epoch 76/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.0040 - val_accuracy: 0.9980
#
# Epoch 00076: val_loss did not improve from 0.00195
# Epoch 77/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0050 - accuracy: 0.9976 - val_loss: 0.0021 - val_accuracy: 0.9988
#
# Epoch 00077: val_loss did not improve from 0.00195
# Epoch 78/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0088 - val_accuracy: 0.9977
#
# Epoch 00078: val_loss did not improve from 0.00195
# Epoch 79/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0041 - val_accuracy: 0.9977
#
# Epoch 00079: val_loss did not improve from 0.00195
# Epoch 80/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0085 - accuracy: 0.9967 - val_loss: 0.0026 - val_accuracy: 0.9980
#
# Epoch 00080: val_loss did not improve from 0.00195
# Epoch 81/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00081: val_loss did not improve from 0.00195
# Epoch 82/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 4.0752 - val_accuracy: 0.7348
#
# Epoch 00082: val_loss did not improve from 0.00195
# Epoch 83/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0844 - val_accuracy: 0.9820
#
# Epoch 00083: val_loss did not improve from 0.00195
# Epoch 84/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0073 - val_accuracy: 0.9984
#
# Epoch 00084: val_loss did not improve from 0.00195
# Epoch 85/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.2576 - val_accuracy: 0.9477
#
# Epoch 00085: val_loss did not improve from 0.00195
# Epoch 86/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0386 - val_accuracy: 0.9879
#
# Epoch 00086: val_loss did not improve from 0.00195
# Epoch 87/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 1.1780 - val_accuracy: 0.8566
#
# Epoch 00087: val_loss did not improve from 0.00195
# Epoch 88/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 0.0090 - val_accuracy: 0.9969
#
# Epoch 00088: val_loss did not improve from 0.00195
# Epoch 89/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0095 - val_accuracy: 0.9973
#
# Epoch 00089: val_loss did not improve from 0.00195
# Epoch 90/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0025 - val_accuracy: 0.9984
#
# Epoch 00090: val_loss did not improve from 0.00195
# Epoch 91/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0104 - val_accuracy: 0.9969
#
# Epoch 00091: val_loss did not improve from 0.00195
# Epoch 92/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.0300 - val_accuracy: 0.9926
#
# Epoch 00092: val_loss did not improve from 0.00195
# Epoch 93/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0096 - accuracy: 0.9961 - val_loss: 0.0045 - val_accuracy: 0.9977
#
# Epoch 00093: val_loss did not improve from 0.00195
# Epoch 94/100
# 320/320 [==============================] - 3s 10ms/step - loss: 0.0122 - accuracy: 0.9956 - val_loss: 0.0047 - val_accuracy: 0.9980
#
# Epoch 00094: val_loss did not improve from 0.00195
# Epoch 95/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.0053 - val_accuracy: 0.9977
#
# Epoch 00095: val_loss did not improve from 0.00195
# Epoch 96/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0066 - accuracy: 0.9971 - val_loss: 0.0038 - val_accuracy: 0.9980
#
# Epoch 00096: val_loss did not improve from 0.00195
# Epoch 97/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0152 - val_accuracy: 0.9961
#
# Epoch 00097: val_loss did not improve from 0.00195
# Epoch 98/100
# 320/320 [==============================] - 3s 9ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.0076 - val_accuracy: 0.9973
#
# Epoch 00098: val_loss did not improve from 0.00195
# Epoch 99/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0057 - val_accuracy: 0.9980
#
# Epoch 00099: val_loss did not improve from 0.00195
# Epoch 100/100
# 320/320 [==============================] - 3s 8ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.0409 - val_accuracy: 0.9852
#
# Epoch 00100: val_loss did not improve from 0.00195
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0409 - accuracy: 0.9852
# Val Score:  [0.0408710278570652, 0.985156238079071]
# ====================================================================================

# %% [markdown]
# **RESULT OF TRAINING DATA PROCESS**

# %%
#FOLD 1
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[0].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 1.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 1')
plt.plot(model_history[0].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[0].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 1.jpg")
plt.show()

# %%
#FOLD 2
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[1].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 2.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 2')
plt.plot(model_history[1].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[1].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 2.jpg")
plt.show()

# %%
#FOLD 3
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[2].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 3.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 3')
plt.plot(model_history[2].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[2].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 3.jpg")
plt.show()

# %%
#FOLD 4
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[3].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 4.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 4')
plt.plot(model_history[3].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[3].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 4.jpg")
plt.show()

# %%
#FOLD 5
#Train and validation accuracy
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['accuracy'], label='Train Accuracy', color='blue', )
plt.plot(model_history[4].history['val_accuracy'], label='Val Accuracy', color='red', )
plt.legend()
plt.savefig("Accuracy_fold 5.jpg")
plt.show()

plt.figure()

#Train and validation loss
plt.title('Training and Validation Accuracy Fold 5')
plt.plot(model_history[4].history['loss'], label='Train Loss', color='blue', )
plt.plot(model_history[4].history['val_loss'], label='Val Loss', color='red', )
plt.legend()
plt.savefig("Loss_fold 5.jpg")
plt.show()

# %% [markdown]
# **LOAD BEST MODEL BY RESULT**

# %%
modeltest = load_model('model.h5')

# %% [markdown]
# **EVALUATING PARAMETER**

# %%
print("[INFO] evaluating network...")
predictions = modeltest.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=label_binarizer.classes_))
# Out:
# [INFO] evaluating network...
#                        precision    recall  f1-score   support
#
# Bacterial leaf blight       1.00      1.00      1.00       859
#            Brown spot       0.99      1.00      0.99       837
#                Health       1.00      1.00      1.00       767
#             Leaf smut       1.00      0.99      0.99       737
#
#              accuracy                           1.00      3200
#             macro avg       1.00      1.00      1.00      3200
#          weighted avg       1.00      1.00      1.00      3200

# %%
print("[INFO] Calculating model accuracy")
scores = modeltest.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 100/100 [==============================] - 1s 4ms/step - loss: 0.0042 - accuracy: 0.9966
# Test Accuracy: 99.65624809265137

# %% [markdown]
# **CONFUSION MATRIX**

# %%
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1),predictions.argmax(axis=1))
x_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
y_axis_labels = ['Bacterial leaf blight', 'Brown spot', 'Leaf blight', 'Healthy']
sn.heatmap(confusion_matrix, xticklabels=x_axis_labels, yticklabels=y_axis_labels, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
